# %% [markdown]
# ## <span style=color:blue>Patterns used in Programming Assignment 2 Part 2(version using util.py file)  </span>

# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %%
# test that utils.py has been imported well
# util.hello_world()

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>
#
# <span style=color:blue>E.g., see https://docs.sqlalchemy.org/en/20/core/engines.html for how to construct the URLs that the create_engine command uses.  Also, one should store the user/password into environment variables and read them in to populate the URL.  </span>
#
# <span style=color:blue>E.g., see https://stackoverflow.com/questions/4906977/how-can-i-access-environment-variables-in-python for how to work with environment variables on mac, </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>Working with btree indexing</span>

# %% [markdown]
# <span style=color:blue>I will encourage students to build a query that computes, for each year, the number of reviews that happened in that year. </span>

# %%
q = util.query_reviews_by_year_counts()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('2009', 56),
#  ('2010', 449),
#  ('2011', 1905),
#  ('2012', 3872),
#  ('2013', 7317),
#  ('2014', 14203),
#  ('2015', 28465),
#  ('2016', 48527),
#  ('2017', 66146),
#  ('2018', 95137),
#  ('2019', 126469),
#  ('2020', 51172),
#  ('2021', 109415),
#  ('2022', 196136),
#  ('2023', 228831),
#  ('2024', 8710)]

# %% [markdown]
# <span style=color:blue>Likewise, the next query gives a count of listings within the prices ranges 0 <= p < 100, 100 <= p < 200, ..., 900 <= p < 1000 and '1000_and_above'

# %%
q = util.query_listings_price_ranges_counts()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('000s', 1735),
#  ('1000_and_above', 226),
#  ('100s', 6362),
#  ('200s', 2875),
#  ('300s', 1307),
#  ('400s', 519),
#  ('500s', 233),
#  ('600s', 146),
#  ('700s', 95),
#  ('800s', 85),
#  ('900s', 75),
#  ('NULL', 7195)]

# %% [markdown]
# <span style=color:blue>And here is a query that gives the counts of occurrences in the reviews table, for three selected words</span>

# %%
q = util.query_reviews_words_counts()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('apartment', 195261), ('awesome', 27938), ('horrible', 859), (None, 762752)]

# %% [markdown]
# <span style=color:blue>First, here is an example of the queries we are using for the testing with b-tree indexes </span>

# %%
date_start = '2015-01-01'
date_end = '2015-12-31'

q = util.build_query_listings_join_reviews(date_start, date_end)

print(q)
# Out:
# SELECT DISTINCT l.id, l.name
# FROM listings l, reviews r
# WHERE l.id = r.listing_id
#   AND r.date >= '2015-01-01'
#   AND r.date <= '2015-12-31'
# ORDER BY l.id;

# %% [markdown]
# <span style=color:blue>My big vision was to have the students set up some infrastructure so that they could easily experiment with a variety of different queries and indexes, and do explorations of things on their own.  So, in util.py I have some helper functions that enable someone to specify a list of indexes, and then run experiments for all combinations of that list.  However, at present I'm thinking that will take people to far into some weeds.   </span>
#
# <span style=color:blue>I am now thinking that I may ask the students to only build files like my files perf_test_v01.json and ts_perf_test_v01.json.  Or I might find time to do some update-based experiments, again for the same set of indexes that are involved with perf_test_v01.json and ts_perf_test_v01.json.  In either case, most likely, they will only have to think about the indexes date_in_reviews, id_in_listings, and comments_tsv_in_reviews. <span>
#
# <span style=color:blue>With regards to storing results, I was originally thinking about this assignment, and about enabling the students to explore different index combinations over time.  So I developed a helper function that would read a json file from my disk, add to it, and then write it out again.  That way, I would be adding performance information over many programming/execution sessions.  This is my function util.fetch_and_update_perf_data(perf_file, perf_summary).  However, I am now thinking that the students don't need to bother with that, given that they will be given quite specific files that they are supposed to generate.<span>

# %% [markdown]
# <span style=color:blue>This generates a json file 'perf_test_v01.json'.  </span>
#
# <span style=color:blue>This produces a lot of log info which may be helpful ... </span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

all_indexes = [['date','reviews'], ['id','listings'], ['price','listings'], ['comments_tsv', 'reviews', 'gin']] 

q_dict = {}
# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_join_reviews(date_start, date_end)
# pprint.pp(q_dict)

i_spec = [['id','listings'], ['date','reviews']]

perf_file = 'listings_join_reviews_v01.json'

# setting count to 3 for now so that things run faster
count = 3

for q in q_dict:
    print('\n====>>> Now working on query:', q)
    perf_summary = util.run_one_query_and_multi_index_specs(db_eng, all_indexes, q, q_dict[q], i_spec, count)
    # print('\nThe perf_summary of running query', q, 'is as follows:') 
    # pprint.pp(perf_summary)
    updated_perf_summary = util.fetch_and_update_perf_data(perf_file, perf_summary)

print('\nThe value of updated perf_summary is:')
pprint.pp(updated_perf_summary, sort_dicts=True)
# Out:
# ====>>> Now working on query: listings_join_review_2009
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2010
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2011
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2012
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2013
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2014
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2015
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2016
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2017
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2018
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2020
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2021
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2022
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2023
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2024
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# The value of updated perf_summary is:
# {'listings_join_review_2009': {'__': {'avg': 0.2128,
#                                       'exec_count': 3,
#                                       'max': 0.2273,
#                                       'min': 0.2021,
#                                       'std': 0.0106,
#                                       'timestamp': '2024-05-07-23:23:06'},
#                                '__date_in_reviews__': {'avg': 0.0177,
#                                                        'exec_count': 3,
#                                                        'max': 0.0199,
#                                                        'min': 0.0162,
#                                                        'std': 0.0016,
#                                                        'timestamp': '2024-05-07-23:23:07'},
#                                '__id_in_listings__': {'avg': 0.1932,
#                                                       'exec_count': 3,
#                                                       'max': 0.1973,
#                                                       'min': 0.1868,
#                                                       'std': 0.0046,
#                                                       'timestamp': '2024-05-07-23:23:07'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0165,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.017,
#                                                                        'min': 0.0161,
#                                                                        'std': 0.0004,
#                                                                        'timestamp': '2024-05-07-23:23:08'}},
#  'listings_join_review_2010': {'__': {'avg': 0.2177,
#                                       'exec_count': 3,
#                                       'max': 0.2234,
#                                       'min': 0.2094,
#                                       'std': 0.006,
#                                       'timestamp': '2024-05-07-23:23:08'},
#                                '__date_in_reviews__': {'avg': 0.0174,
#                                                        'exec_count': 3,
#                                                        'max': 0.0209,
#                                                        'min': 0.0151,
#                                                        'std': 0.0025,
#                                                        'timestamp': '2024-05-07-23:23:10'},
#                                '__id_in_listings__': {'avg': 0.2077,
#                                                       'exec_count': 3,
#                                                       'max': 0.2158,
#                                                       'min': 0.2034,
#                                                       'std': 0.0057,
#                                                       'timestamp': '2024-05-07-23:23:09'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0152,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.016,
#                                                                        'min': 0.0148,
#                                                                        'std': 0.0005,
#                                                                        'timestamp': '2024-05-07-23:23:10'}},
#  'listings_join_review_2011': {'__': {'avg': 0.2047,
#                                       'exec_count': 3,
#                                       'max': 0.2074,
#                                       'min': 0.2031,
#                                       'std': 0.0019,
#                                       'timestamp': '2024-05-07-23:23:10'},
#                                '__date_in_reviews__': {'avg': 0.0202,
#                                                        'exec_count': 3,
#                                                        'max': 0.0245,
#                                                        'min': 0.0176,
#                                                        'std': 0.003,
#                                                        'timestamp': '2024-05-07-23:23:12'},
#                                '__id_in_listings__': {'avg': 0.2048,
#                                                       'exec_count': 3,
#                                                       'max': 0.2069,
#                                                       'min': 0.2023,
#                                                       'std': 0.0019,
#                                                       'timestamp': '2024-05-07-23:23:11'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0197,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0206,
#                                                                        'min': 0.0182,
#                                                                        'std': 0.0011,
#                                                                        'timestamp': '2024-05-07-23:23:12'}},
#  'listings_join_review_2012': {'__': {'avg': 0.2136,
#                                       'exec_count': 3,
#                                       'max': 0.2199,
#                                       'min': 0.2094,
#                                       'std': 0.0045,
#                                       'timestamp': '2024-05-07-23:23:12'},
#                                '__date_in_reviews__': {'avg': 0.0301,
#                                                        'exec_count': 3,
#                                                        'max': 0.0345,
#                                                        'min': 0.0249,
#                                                        'std': 0.004,
#                                                        'timestamp': '2024-05-07-23:23:14'},
#                                '__id_in_listings__': {'avg': 0.2114,
#                                                       'exec_count': 3,
#                                                       'max': 0.2161,
#                                                       'min': 0.204,
#                                                       'std': 0.0053,
#                                                       'timestamp': '2024-05-07-23:23:13'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0232,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0235,
#                                                                        'min': 0.0228,
#                                                                        'std': 0.0003,
#                                                                        'timestamp': '2024-05-07-23:23:14'}},
#  'listings_join_review_2013': {'__': {'avg': 0.2083,
#                                       'exec_count': 3,
#                                       'max': 0.2107,
#                                       'min': 0.2049,
#                                       'std': 0.0025,
#                                       'timestamp': '2024-05-07-23:23:15'},
#                                '__date_in_reviews__': {'avg': 0.034,
#                                                        'exec_count': 3,
#                                                        'max': 0.0437,
#                                                        'min': 0.029,
#                                                        'std': 0.0069,
#                                                        'timestamp': '2024-05-07-23:23:16'},
#                                '__id_in_listings__': {'avg': 0.2115,
#                                                       'exec_count': 3,
#                                                       'max': 0.2274,
#                                                       'min': 0.2013,
#                                                       'std': 0.0114,
#                                                       'timestamp': '2024-05-07-23:23:15'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.029,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0308,
#                                                                        'min': 0.0273,
#                                                                        'std': 0.0014,
#                                                                        'timestamp': '2024-05-07-23:23:16'}},
#  'listings_join_review_2014': {'__': {'avg': 0.2225,
#                                       'exec_count': 3,
#                                       'max': 0.2307,
#                                       'min': 0.2105,
#                                       'std': 0.0087,
#                                       'timestamp': '2024-05-07-23:23:17'},
#                                '__date_in_reviews__': {'avg': 0.0507,
#                                                        'exec_count': 3,
#                                                        'max': 0.0653,
#                                                        'min': 0.0425,
#                                                        'std': 0.0104,
#                                                        'timestamp': '2024-05-07-23:23:18'},
#                                '__id_in_listings__': {'avg': 0.2166,
#                                                       'exec_count': 3,
#                                                       'max': 0.225,
#                                                       'min': 0.2116,
#                                                       'std': 0.0059,
#                                                       'timestamp': '2024-05-07-23:23:18'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0421,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0434,
#                                                                        'min': 0.0403,
#                                                                        'std': 0.0013,
#                                                                        'timestamp': '2024-05-07-23:23:19'}},
#  'listings_join_review_2015': {'__': {'avg': 0.2359,
#                                       'exec_count': 3,
#                                       'max': 0.2459,
#                                       'min': 0.2287,
#                                       'std': 0.0073,
#                                       'timestamp': '2024-05-07-23:23:19'},
#                                '__date_in_reviews__': {'avg': 0.0815,
#                                                        'exec_count': 3,
#                                                        'max': 0.1014,
#                                                        'min': 0.0715,
#                                                        'std': 0.0141,
#                                                        'timestamp': '2024-05-07-23:23:21'},
#                                '__id_in_listings__': {'avg': 0.2341,
#                                                       'exec_count': 3,
#                                                       'max': 0.2438,
#                                                       'min': 0.226,
#                                                       'std': 0.0074,
#                                                       'timestamp': '2024-05-07-23:23:20'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0729,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0737,
#                                                                        'min': 0.0719,
#                                                                        'std': 0.0007,
#                                                                        'timestamp': '2024-05-07-23:23:21'}},
#  'listings_join_review_2016': {'__': {'avg': 0.2374,
#                                       'exec_count': 3,
#                                       'max': 0.2379,
#                                       'min': 0.2371,
#                                       'std': 0.0004,
#                                       'timestamp': '2024-05-07-23:23:22'},
#                                '__date_in_reviews__': {'avg': 0.0965,
#                                                        'exec_count': 3,
#                                                        'max': 0.1134,
#                                                        'min': 0.0744,
#                                                        'std': 0.0163,
#                                                        'timestamp': '2024-05-07-23:23:24'},
#                                '__id_in_listings__': {'avg': 0.244,
#                                                       'exec_count': 3,
#                                                       'max': 0.2531,
#                                                       'min': 0.2393,
#                                                       'std': 0.0064,
#                                                       'timestamp': '2024-05-07-23:23:23'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.066,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0674,
#                                                                        'min': 0.0639,
#                                                                        'std': 0.0015,
#                                                                        'timestamp': '2024-05-07-23:23:24'}},
#  'listings_join_review_2017': {'__': {'avg': 0.2466,
#                                       'exec_count': 3,
#                                       'max': 0.2474,
#                                       'min': 0.2454,
#                                       'std': 0.0009,
#                                       'timestamp': '2024-05-07-23:23:25'},
#                                '__date_in_reviews__': {'avg': 0.1372,
#                                                        'exec_count': 3,
#                                                        'max': 0.1558,
#                                                        'min': 0.1261,
#                                                        'std': 0.0133,
#                                                        'timestamp': '2024-05-07-23:23:27'},
#                                '__id_in_listings__': {'avg': 0.2515,
#                                                       'exec_count': 3,
#                                                       'max': 0.2533,
#                                                       'min': 0.248,
#                                                       'std': 0.0025,
#                                                       'timestamp': '2024-05-07-23:23:26'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1144,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.1164,
#                                                                        'min': 0.1118,
#                                                                        'std': 0.0019,
#                                                                        'timestamp': '2024-05-07-23:23:27'}},
#  'listings_join_review_2018': {'__': {'avg': 0.5074,
#                                       'exec_count': 3,
#                                       'max': 0.518,
#                                       'min': 0.4978,
#                                       'std': 0.0083,
#                                       'timestamp': '2024-05-07-23:23:29'},
#                                '__date_in_reviews__': {'avg': 0.2016,
#                                                        'exec_count': 3,
#                                                        'max': 0.2303,
#                                                        'min': 0.1849,
#                                                        'std': 0.0204,
#                                                        'timestamp': '2024-05-07-23:23:31'},
#                                '__id_in_listings__': {'avg': 0.5049,
#                                                       'exec_count': 3,
#                                                       'max': 0.5113,
#                                                       'min': 0.493,
#                                                       'std': 0.0085,
#                                                       'timestamp': '2024-05-07-23:23:30'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1769,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.1774,
#                                                                        'min': 0.1759,
#                                                                        'std': 0.0007,
#                                                                        'timestamp': '2024-05-07-23:23:32'}},
#  'listings_join_review_2019': {'__': {'avg': 0.5257,
#                                       'exec_count': 3,
#                                       'max': 0.5417,
#                                       'min': 0.5176,
#                                       'std': 0.0113,
#                                       'timestamp': '2024-05-07-23:23:34'},
#                                '__date_in_reviews__': {'avg': 0.527,
#                                                        'exec_count': 3,
#                                                        'max': 0.535,
#                                                        'min': 0.5141,
#                                                        'std': 0.0092,
#                                                        'timestamp': '2024-05-07-23:23:38'},
#                                '__id_in_listings__': {'avg': 0.5286,
#                                                       'exec_count': 3,
#                                                       'max': 0.5396,
#                                                       'min': 0.5164,
#                                                       'std': 0.0095,
#                                                       'timestamp': '2024-05-07-23:23:35'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.5396,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.5701,
#                                                                        'min': 0.5228,
#                                                                        'std': 0.0216,
#                                                                        'timestamp': '2024-05-07-23:23:39'}},
#  'listings_join_review_2020': {'__': {'avg': 0.2657,
#                                       'exec_count': 3,
#                                       'max': 0.2705,
#                                       'min': 0.2628,
#                                       'std': 0.0034,
#                                       'timestamp': '2024-05-07-23:23:40'},
#                                '__date_in_reviews__': {'avg': 0.097,
#                                                        'exec_count': 3,
#                                                        'max': 0.1307,
#                                                        'min': 0.0777,
#                                                        'std': 0.0239,
#                                                        'timestamp': '2024-05-07-23:23:42'},
#                                '__id_in_listings__': {'avg': 0.2699,
#                                                       'exec_count': 3,
#                                                       'max': 0.2737,
#                                                       'min': 0.2634,
#                                                       'std': 0.0046,
#                                                       'timestamp': '2024-05-07-23:23:41'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.095,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.1224,
#                                                                        'min': 0.0759,
#                                                                        'std': 0.0199,
#                                                                        'timestamp': '2024-05-07-23:23:42'}},
#  'listings_join_review_2021': {'__': {'avg': 0.5206,
#                                       'exec_count': 3,
#                                       'max': 0.5279,
#                                       'min': 0.5112,
#                                       'std': 0.007,
#                                       'timestamp': '2024-05-07-23:23:44'},
#                                '__date_in_reviews__': {'avg': 0.226,
#                                                        'exec_count': 3,
#                                                        'max': 0.2582,
#                                                        'min': 0.2061,
#                                                        'std': 0.023,
#                                                        'timestamp': '2024-05-07-23:23:47'},
#                                '__id_in_listings__': {'avg': 0.5127,
#                                                       'exec_count': 3,
#                                                       'max': 0.5162,
#                                                       'min': 0.5073,
#                                                       'std': 0.0039,
#                                                       'timestamp': '2024-05-07-23:23:45'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.2104,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.2116,
#                                                                        'min': 0.2094,
#                                                                        'std': 0.0009,
#                                                                        'timestamp': '2024-05-07-23:23:47'}},
#  'listings_join_review_2022': {'__': {'avg': 0.5854,
#                                       'exec_count': 3,
#                                       'max': 0.6124,
#                                       'min': 0.5711,
#                                       'std': 0.0191,
#                                       'timestamp': '2024-05-07-23:23:49'},
#                                '__date_in_reviews__': {'avg': 0.5844,
#                                                        'exec_count': 3,
#                                                        'max': 0.6116,
#                                                        'min': 0.5659,
#                                                        'std': 0.0196,
#                                                        'timestamp': '2024-05-07-23:23:53'},
#                                '__id_in_listings__': {'avg': 0.5686,
#                                                       'exec_count': 3,
#                                                       'max': 0.5754,
#                                                       'min': 0.5647,
#                                                       'std': 0.0049,
#                                                       'timestamp': '2024-05-07-23:23:51'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.581,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.5974,
#                                                                        'min': 0.5686,
#                                                                        'std': 0.0121,
#                                                                        'timestamp': '2024-05-07-23:23:55'}},
#  'listings_join_review_2023': {'__': {'avg': 0.3253,
#                                       'exec_count': 3,
#                                       'max': 0.3676,
#                                       'min': 0.3005,
#                                       'std': 0.0301,
#                                       'timestamp': '2024-05-07-23:23:56'},
#                                '__date_in_reviews__': {'avg': 0.3167,
#                                                        'exec_count': 3,
#                                                        'max': 0.3424,
#                                                        'min': 0.3019,
#                                                        'std': 0.0182,
#                                                        'timestamp': '2024-05-07-23:23:59'},
#                                '__id_in_listings__': {'avg': 0.3123,
#                                                       'exec_count': 3,
#                                                       'max': 0.3358,
#                                                       'min': 0.2884,
#                                                       'std': 0.0194,
#                                                       'timestamp': '2024-05-07-23:23:57'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.3329,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.3781,
#                                                                        'min': 0.3052,
#                                                                        'std': 0.0322,
#                                                                        'timestamp': '2024-05-07-23:24:00'}},
#  'listings_join_review_2024': {'__': {'avg': 0.2266,
#                                       'exec_count': 3,
#                                       'max': 0.232,
#                                       'min': 0.2234,
#                                       'std': 0.0038,
#                                       'timestamp': '2024-05-07-23:24:01'},
#                                '__date_in_reviews__': {'avg': 0.0428,
#                                                        'exec_count': 3,
#                                                        'max': 0.0566,
#                                                        'min': 0.0358,
#                                                        'std': 0.0098,
#                                                        'timestamp': '2024-05-07-23:24:02'},
#                                '__id_in_listings__': {'avg': 0.2075,
#                                                       'exec_count': 3,
#                                                       'max': 0.2095,
#                                                       'min': 0.2062,
#                                                       'std': 0.0014,
#                                                       'timestamp': '2024-05-07-23:24:01'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0361,
#                                                                        'exec_count': 3,
#                                                                        'max': 0.0378,
#                                                                        'min': 0.0349,
#                                                                        'std': 0.0012,
#                                                                        'timestamp': '2024-05-07-23:24:02'}}}

# %% [markdown]
# ### <span style=color:blue>Working with text indexing</span>

# %% [markdown]
# <span style=color:blue>First, here are examples of the 2 kinds of query we are working with.  I might decide to ask the students to experiment with a second word.  (I need to find a word with different behavior!)</span>
#
# ### <span style=color:blue>NOTE: please see the double "%%" in the first query -- this is a kind of escape character so that sqlalchemy will be able to work with the "%" signs.  </span>

# %%
word = 'awesome'
start_date = '2015-01-01'
end_date = '2015-12-31'

q1 = util.build_query_reviews_no_index(word, start_date, end_date)
q2 = util.build_query_reviews_ts(word, start_date, end_date)

print('q1 is:')
print(q1)
print('\nq2 is:')
print(q2)
# Out:
# q1 is:
# SELECT *
# FROM reviews r
# WHERE comments ILIKE '%%awesome%%'
#   AND date >= '2015-01-01'
#   AND date <= '2015-12-31';
#
# q2 is:
# SELECT *
# FROM reviews r
# WHERE comments_tsv @@ to_tsquery('awesome')
#   AND date >= '2015-01-01'
#   AND date <= '2015-12-31';

# %% [markdown]
# <span style=color:blue>The next cell generates the file 'ts_pef_test_v01.json'<span>
#
# <span style=color:blue>For these experiments the "no-index" case is making a search against the comments column of reviews, whereas the "with-index" case is making a search against the comments_tsv column of reviews.  So I don't need to drop the index on comments_tsv when running the "no-index" case.  This makes it simpler than the b-tree situation</span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

perf_file = 'ts_perf_test_v01.json'

# using a low count so that the query without index runs reasonably quickly
count = 50

# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    print('\nEntering loop for yr = ', str(yr))
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    for word in ['horrible', 'awesome', 'apartment']:
        print('Entering sub-loop for word: ', word)
        perf_info = util.run_one_text_query_without_with_ts_index(db_eng, word, date_start, date_end, count)
        print('perf_file for the run for year "', yr, '" and word "', word, '" is:')
        pprint.pp(perf_info)
        updated_perf_summary = util.fetch_and_update_ts_perf_data(perf_file, perf_info)




print('After running all years, the updated perf_summary info, in sorted order, is:')
# the sorted(...items()) returns list of ordered pairs; 
#     for each pair, the first element is a key in the dictionary
#                    and the second element is the value associated with that key
pprint.pp(sorted(updated_perf_summary.items()))
# Out:
# Entering loop for yr =  2009
# Entering sub-loop for word:  horrible
# {'avg': 0.0028,
#  'min': 0.0021,
#  'max': 0.0079,
#  'std': 0.0008,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:02'}
# {'avg': 0.0021,
#  'min': 0.0016,
#  'max': 0.0032,
#  'std': 0.0004,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# perf_file for the run for year " 2009 " and word " horrible " is:
# {'horrible_2009': {'no_ts_index': {'avg': 0.0028,
#                                    'min': 0.0021,
#                                    'max': 0.0079,
#                                    'std': 0.0008,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:02'},
#                    'with_ts_index': {'avg': 0.0021,
#                                      'min': 0.0016,
#                                      'max': 0.0032,
#                                      'std': 0.0004,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:24:03'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.0023,
#  'min': 0.0019,
#  'max': 0.0031,
#  'std': 0.0003,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# {'avg': 0.0017,
#  'min': 0.0014,
#  'max': 0.0031,
#  'std': 0.0004,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# perf_file for the run for year " 2009 " and word " awesome " is:
# {'awesome_2009': {'no_ts_index': {'avg': 0.0023,
#                                   'min': 0.0019,
#                                   'max': 0.0031,
#                                   'std': 0.0003,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:24:03'},
#                   'with_ts_index': {'avg': 0.0017,
#                                     'min': 0.0014,
#                                     'max': 0.0031,
#                                     'std': 0.0004,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:03'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.0024,
#  'min': 0.002,
#  'max': 0.0037,
#  'std': 0.0004,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# {'avg': 0.0019,
#  'min': 0.0016,
#  'max': 0.0025,
#  'std': 0.0002,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# perf_file for the run for year " 2009 " and word " apartment " is:
# {'apartment_2009': {'no_ts_index': {'avg': 0.0024,
#                                     'min': 0.002,
#                                     'max': 0.0037,
#                                     'std': 0.0004,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:03'},
#                     'with_ts_index': {'avg': 0.0019,
#                                       'min': 0.0016,
#                                       'max': 0.0025,
#                                       'std': 0.0002,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:24:03'}}}
#
# Entering loop for yr =  2010
# Entering sub-loop for word:  horrible
# {'avg': 0.0044,
#  'min': 0.0039,
#  'max': 0.0058,
#  'std': 0.0005,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# {'avg': 0.003,
#  'min': 0.0024,
#  'max': 0.0046,
#  'std': 0.0004,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:03'}
# perf_file for the run for year " 2010 " and word " horrible " is:
# {'horrible_2010': {'no_ts_index': {'avg': 0.0044,
#                                    'min': 0.0039,
#                                    'max': 0.0058,
#                                    'std': 0.0005,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:03'},
#                    'with_ts_index': {'avg': 0.003,
#                                      'min': 0.0024,
#                                      'max': 0.0046,
#                                      'std': 0.0004,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:24:03'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.0044,
#  'min': 0.0039,
#  'max': 0.0054,
#  'std': 0.0004,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:04'}
# {'avg': 0.0026,
#  'min': 0.0023,
#  'max': 0.0032,
#  'std': 0.0002,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:04'}
# perf_file for the run for year " 2010 " and word " awesome " is:
# {'awesome_2010': {'no_ts_index': {'avg': 0.0044,
#                                   'min': 0.0039,
#                                   'max': 0.0054,
#                                   'std': 0.0004,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:24:04'},
#                   'with_ts_index': {'avg': 0.0026,
#                                     'min': 0.0023,
#                                     'max': 0.0032,
#                                     'std': 0.0002,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:04'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.0055,
#  'min': 0.005,
#  'max': 0.0064,
#  'std': 0.0003,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:04'}
# {'avg': 0.0042,
#  'min': 0.0037,
#  'max': 0.0055,
#  'std': 0.0004,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:04'}
# perf_file for the run for year " 2010 " and word " apartment " is:
# {'apartment_2010': {'no_ts_index': {'avg': 0.0055,
#                                     'min': 0.005,
#                                     'max': 0.0064,
#                                     'std': 0.0003,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:04'},
#                     'with_ts_index': {'avg': 0.0042,
#                                       'min': 0.0037,
#                                       'max': 0.0055,
#                                       'std': 0.0004,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:24:04'}}}
#
# Entering loop for yr =  2011
# Entering sub-loop for word:  horrible
# {'avg': 0.0119,
#  'min': 0.0111,
#  'max': 0.0136,
#  'std': 0.0005,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:05'}
# {'avg': 0.0063,
#  'min': 0.0058,
#  'max': 0.0071,
#  'std': 0.0003,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:05'}
# perf_file for the run for year " 2011 " and word " horrible " is:
# {'horrible_2011': {'no_ts_index': {'avg': 0.0119,
#                                    'min': 0.0111,
#                                    'max': 0.0136,
#                                    'std': 0.0005,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:05'},
#                    'with_ts_index': {'avg': 0.0063,
#                                      'min': 0.0058,
#                                      'max': 0.0071,
#                                      'std': 0.0003,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:24:05'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.0125,
#  'min': 0.0117,
#  'max': 0.014,
#  'std': 0.0005,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:06'}
# {'avg': 0.0072,
#  'min': 0.006,
#  'max': 0.0135,
#  'std': 0.0016,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:06'}
# perf_file for the run for year " 2011 " and word " awesome " is:
# {'awesome_2011': {'no_ts_index': {'avg': 0.0125,
#                                   'min': 0.0117,
#                                   'max': 0.014,
#                                   'std': 0.0005,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:24:06'},
#                   'with_ts_index': {'avg': 0.0072,
#                                     'min': 0.006,
#                                     'max': 0.0135,
#                                     'std': 0.0016,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:06'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.0175,
#  'min': 0.0161,
#  'max': 0.0289,
#  'std': 0.0024,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:07'}
# {'avg': 0.0126,
#  'min': 0.0107,
#  'max': 0.0178,
#  'std': 0.0014,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:08'}
# perf_file for the run for year " 2011 " and word " apartment " is:
# {'apartment_2011': {'no_ts_index': {'avg': 0.0175,
#                                     'min': 0.0161,
#                                     'max': 0.0289,
#                                     'std': 0.0024,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:07'},
#                     'with_ts_index': {'avg': 0.0126,
#                                       'min': 0.0107,
#                                       'max': 0.0178,
#                                       'std': 0.0014,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:24:08'}}}
#
# Entering loop for yr =  2012
# Entering sub-loop for word:  horrible
# {'avg': 0.023,
#  'min': 0.0216,
#  'max': 0.0326,
#  'std': 0.0016,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:09'}
# {'avg': 0.0111,
#  'min': 0.01,
#  'max': 0.0136,
#  'std': 0.0007,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:09'}
# perf_file for the run for year " 2012 " and word " horrible " is:
# {'horrible_2012': {'no_ts_index': {'avg': 0.023,
#                                    'min': 0.0216,
#                                    'max': 0.0326,
#                                    'std': 0.0016,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:09'},
#                    'with_ts_index': {'avg': 0.0111,
#                                      'min': 0.01,
#                                      'max': 0.0136,
#                                      'std': 0.0007,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:24:09'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.0243,
#  'min': 0.0233,
#  'max': 0.0262,
#  'std': 0.0006,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:11'}
# {'avg': 0.0116,
#  'min': 0.0109,
#  'max': 0.013,
#  'std': 0.0005,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:11'}
# perf_file for the run for year " 2012 " and word " awesome " is:
# {'awesome_2012': {'no_ts_index': {'avg': 0.0243,
#                                   'min': 0.0233,
#                                   'max': 0.0262,
#                                   'std': 0.0006,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:24:11'},
#                   'with_ts_index': {'avg': 0.0116,
#                                     'min': 0.0109,
#                                     'max': 0.013,
#                                     'std': 0.0005,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:11'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.0357,
#  'min': 0.0336,
#  'max': 0.0385,
#  'std': 0.001,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:13'}
# {'avg': 0.0251,
#  'min': 0.0236,
#  'max': 0.0283,
#  'std': 0.001,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:14'}
# perf_file for the run for year " 2012 " and word " apartment " is:
# {'apartment_2012': {'no_ts_index': {'avg': 0.0357,
#                                     'min': 0.0336,
#                                     'max': 0.0385,
#                                     'std': 0.001,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:13'},
#                     'with_ts_index': {'avg': 0.0251,
#                                       'min': 0.0236,
#                                       'max': 0.0283,
#                                       'std': 0.001,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:24:14'}}}
#
# Entering loop for yr =  2013
# Entering sub-loop for word:  horrible
# {'avg': 0.0418,
#  'min': 0.039,
#  'max': 0.0537,
#  'std': 0.0028,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:16'}
# {'avg': 0.0194,
#  'min': 0.018,
#  'max': 0.0239,
#  'std': 0.0009,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:17'}
# perf_file for the run for year " 2013 " and word " horrible " is:
# {'horrible_2013': {'no_ts_index': {'avg': 0.0418,
#                                    'min': 0.039,
#                                    'max': 0.0537,
#                                    'std': 0.0028,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:16'},
#                    'with_ts_index': {'avg': 0.0194,
#                                      'min': 0.018,
#                                      'max': 0.0239,
#                                      'std': 0.0009,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:24:17'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.0453,
#  'min': 0.0432,
#  'max': 0.0482,
#  'std': 0.0012,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:19'}
# {'avg': 0.0219,
#  'min': 0.0199,
#  'max': 0.0251,
#  'std': 0.0014,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:21'}
# perf_file for the run for year " 2013 " and word " awesome " is:
# {'awesome_2013': {'no_ts_index': {'avg': 0.0453,
#                                   'min': 0.0432,
#                                   'max': 0.0482,
#                                   'std': 0.0012,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:24:19'},
#                   'with_ts_index': {'avg': 0.0219,
#                                     'min': 0.0199,
#                                     'max': 0.0251,
#                                     'std': 0.0014,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:21'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.0691,
#  'min': 0.0636,
#  'max': 0.116,
#  'std': 0.0072,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:24'}
# {'avg': 0.0497,
#  'min': 0.0435,
#  'max': 0.0954,
#  'std': 0.0094,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:27'}
# perf_file for the run for year " 2013 " and word " apartment " is:
# {'apartment_2013': {'no_ts_index': {'avg': 0.0691,
#                                     'min': 0.0636,
#                                     'max': 0.116,
#                                     'std': 0.0072,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:24'},
#                     'with_ts_index': {'avg': 0.0497,
#                                       'min': 0.0435,
#                                       'max': 0.0954,
#                                       'std': 0.0094,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:24:27'}}}
#
# Entering loop for yr =  2014
# Entering sub-loop for word:  horrible
# {'avg': 0.0788,
#  'min': 0.0744,
#  'max': 0.0932,
#  'std': 0.0027,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:30'}
# {'avg': 0.0364,
#  'min': 0.0342,
#  'max': 0.0405,
#  'std': 0.0014,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:32'}
# perf_file for the run for year " 2014 " and word " horrible " is:
# {'horrible_2014': {'no_ts_index': {'avg': 0.0788,
#                                    'min': 0.0744,
#                                    'max': 0.0932,
#                                    'std': 0.0027,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:30'},
#                    'with_ts_index': {'avg': 0.0364,
#                                      'min': 0.0342,
#                                      'max': 0.0405,
#                                      'std': 0.0014,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:24:32'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.0856,
#  'min': 0.0826,
#  'max': 0.0891,
#  'std': 0.0015,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:37'}
# {'avg': 0.0391,
#  'min': 0.0374,
#  'max': 0.0408,
#  'std': 0.0009,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:39'}
# perf_file for the run for year " 2014 " and word " awesome " is:
# {'awesome_2014': {'no_ts_index': {'avg': 0.0856,
#                                   'min': 0.0826,
#                                   'max': 0.0891,
#                                   'std': 0.0015,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:24:37'},
#                   'with_ts_index': {'avg': 0.0391,
#                                     'min': 0.0374,
#                                     'max': 0.0408,
#                                     'std': 0.0009,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:39'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.1272,
#  'min': 0.1196,
#  'max': 0.1738,
#  'std': 0.0115,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:45'}
# {'avg': 0.0907,
#  'min': 0.0846,
#  'max': 0.1392,
#  'std': 0.0107,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:49'}
# perf_file for the run for year " 2014 " and word " apartment " is:
# {'apartment_2014': {'no_ts_index': {'avg': 0.1272,
#                                     'min': 0.1196,
#                                     'max': 0.1738,
#                                     'std': 0.0115,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:24:45'},
#                     'with_ts_index': {'avg': 0.0907,
#                                       'min': 0.0846,
#                                       'max': 0.1392,
#                                       'std': 0.0107,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:24:49'}}}
#
# Entering loop for yr =  2015
# Entering sub-loop for word:  horrible
# {'avg': 0.1449,
#  'min': 0.1416,
#  'max': 0.1703,
#  'std': 0.0044,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:24:57'}
# {'avg': 0.0698,
#  'min': 0.0667,
#  'max': 0.0727,
#  'std': 0.0011,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:00'}
# perf_file for the run for year " 2015 " and word " horrible " is:
# {'horrible_2015': {'no_ts_index': {'avg': 0.1449,
#                                    'min': 0.1416,
#                                    'max': 0.1703,
#                                    'std': 0.0044,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:24:57'},
#                    'with_ts_index': {'avg': 0.0698,
#                                      'min': 0.0667,
#                                      'max': 0.0727,
#                                      'std': 0.0011,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:25:00'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.1595,
#  'min': 0.1555,
#  'max': 0.2031,
#  'std': 0.0065,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:08'}
# {'avg': 0.0786,
#  'min': 0.0735,
#  'max': 0.1104,
#  'std': 0.0052,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:12'}
# perf_file for the run for year " 2015 " and word " awesome " is:
# {'awesome_2015': {'no_ts_index': {'avg': 0.1595,
#                                   'min': 0.1555,
#                                   'max': 0.2031,
#                                   'std': 0.0065,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:25:08'},
#                   'with_ts_index': {'avg': 0.0786,
#                                     'min': 0.0735,
#                                     'max': 0.1104,
#                                     'std': 0.0052,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:25:12'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.2459,
#  'min': 0.2272,
#  'max': 0.3112,
#  'std': 0.0217,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:24'}
# {'avg': 0.1823,
#  'min': 0.163,
#  'max': 0.2381,
#  'std': 0.0211,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:33'}
# perf_file for the run for year " 2015 " and word " apartment " is:
# {'apartment_2015': {'no_ts_index': {'avg': 0.2459,
#                                     'min': 0.2272,
#                                     'max': 0.3112,
#                                     'std': 0.0217,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:25:24'},
#                     'with_ts_index': {'avg': 0.1823,
#                                       'min': 0.163,
#                                       'max': 0.2381,
#                                       'std': 0.0211,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:25:33'}}}
#
# Entering loop for yr =  2016
# Entering sub-loop for word:  horrible
# {'avg': 0.2166,
#  'min': 0.2103,
#  'max': 0.2541,
#  'std': 0.0092,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:44'}
# {'avg': 0.0614,
#  'min': 0.0565,
#  'max': 0.1109,
#  'std': 0.0076,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:47'}
# perf_file for the run for year " 2016 " and word " horrible " is:
# {'horrible_2016': {'no_ts_index': {'avg': 0.2166,
#                                    'min': 0.2103,
#                                    'max': 0.2541,
#                                    'std': 0.0092,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:25:44'},
#                    'with_ts_index': {'avg': 0.0614,
#                                      'min': 0.0565,
#                                      'max': 0.1109,
#                                      'std': 0.0076,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:25:47'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.2377,
#  'min': 0.2283,
#  'max': 0.251,
#  'std': 0.0064,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:25:59'}
# {'avg': 0.068,
#  'min': 0.0633,
#  'max': 0.0799,
#  'std': 0.0045,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:26:03'}
# perf_file for the run for year " 2016 " and word " awesome " is:
# {'awesome_2016': {'no_ts_index': {'avg': 0.2377,
#                                   'min': 0.2283,
#                                   'max': 0.251,
#                                   'std': 0.0064,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:25:59'},
#                   'with_ts_index': {'avg': 0.068,
#                                     'min': 0.0633,
#                                     'max': 0.0799,
#                                     'std': 0.0045,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:26:03'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.3535,
#  'min': 0.3233,
#  'max': 0.4019,
#  'std': 0.0233,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:26:20'}
# {'avg': 0.1749,
#  'min': 0.1405,
#  'max': 0.2953,
#  'std': 0.0316,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:26:29'}
# perf_file for the run for year " 2016 " and word " apartment " is:
# {'apartment_2016': {'no_ts_index': {'avg': 0.3535,
#                                     'min': 0.3233,
#                                     'max': 0.4019,
#                                     'std': 0.0233,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:26:20'},
#                     'with_ts_index': {'avg': 0.1749,
#                                       'min': 0.1405,
#                                       'max': 0.2953,
#                                       'std': 0.0316,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:26:29'}}}
#
# Entering loop for yr =  2017
# Entering sub-loop for word:  horrible
# {'avg': 0.2835,
#  'min': 0.2594,
#  'max': 0.3221,
#  'std': 0.013,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:26:43'}
# {'avg': 0.1048,
#  'min': 0.0956,
#  'max': 0.1136,
#  'std': 0.0036,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:26:49'}
# perf_file for the run for year " 2017 " and word " horrible " is:
# {'horrible_2017': {'no_ts_index': {'avg': 0.2835,
#                                    'min': 0.2594,
#                                    'max': 0.3221,
#                                    'std': 0.013,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:26:43'},
#                    'with_ts_index': {'avg': 0.1048,
#                                      'min': 0.0956,
#                                      'max': 0.1136,
#                                      'std': 0.0036,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:26:49'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.3269,
#  'min': 0.3191,
#  'max': 0.4058,
#  'std': 0.0131,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:27:05'}
# {'avg': 0.1134,
#  'min': 0.1065,
#  'max': 0.1446,
#  'std': 0.0081,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:27:11'}
# perf_file for the run for year " 2017 " and word " awesome " is:
# {'awesome_2017': {'no_ts_index': {'avg': 0.3269,
#                                   'min': 0.3191,
#                                   'max': 0.4058,
#                                   'std': 0.0131,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:27:05'},
#                   'with_ts_index': {'avg': 0.1134,
#                                     'min': 0.1065,
#                                     'max': 0.1446,
#                                     'std': 0.0081,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:27:11'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.4318,
#  'min': 0.4106,
#  'max': 0.4704,
#  'std': 0.022,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:27:32'}
# {'avg': 0.1996,
#  'min': 0.1784,
#  'max': 0.2437,
#  'std': 0.0222,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:27:42'}
# perf_file for the run for year " 2017 " and word " apartment " is:
# {'apartment_2017': {'no_ts_index': {'avg': 0.4318,
#                                     'min': 0.4106,
#                                     'max': 0.4704,
#                                     'std': 0.022,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:27:32'},
#                     'with_ts_index': {'avg': 0.1996,
#                                       'min': 0.1784,
#                                       'max': 0.2437,
#                                       'std': 0.0222,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:27:42'}}}
#
# Entering loop for yr =  2018
# Entering sub-loop for word:  horrible
# {'avg': 0.1798,
#  'min': 0.1748,
#  'max': 0.19,
#  'std': 0.0034,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:27:51'}
# {'avg': 0.1342,
#  'min': 0.1286,
#  'max': 0.1464,
#  'std': 0.0043,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:27:58'}
# perf_file for the run for year " 2018 " and word " horrible " is:
# {'horrible_2018': {'no_ts_index': {'avg': 0.1798,
#                                    'min': 0.1748,
#                                    'max': 0.19,
#                                    'std': 0.0034,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:27:51'},
#                    'with_ts_index': {'avg': 0.1342,
#                                      'min': 0.1286,
#                                      'max': 0.1464,
#                                      'std': 0.0043,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:27:58'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.1999,
#  'min': 0.1895,
#  'max': 0.245,
#  'std': 0.0122,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:28:08'}
# {'avg': 0.1529,
#  'min': 0.141,
#  'max': 0.2358,
#  'std': 0.0143,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:28:16'}
# perf_file for the run for year " 2018 " and word " awesome " is:
# {'awesome_2018': {'no_ts_index': {'avg': 0.1999,
#                                   'min': 0.1895,
#                                   'max': 0.245,
#                                   'std': 0.0122,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:28:08'},
#                   'with_ts_index': {'avg': 0.1529,
#                                     'min': 0.141,
#                                     'max': 0.2358,
#                                     'std': 0.0143,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:28:16'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.3229,
#  'min': 0.2781,
#  'max': 0.377,
#  'std': 0.0292,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:28:32'}
# {'avg': 0.2719,
#  'min': 0.2374,
#  'max': 0.3272,
#  'std': 0.0285,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:28:45'}
# perf_file for the run for year " 2018 " and word " apartment " is:
# {'apartment_2018': {'no_ts_index': {'avg': 0.3229,
#                                     'min': 0.2781,
#                                     'max': 0.377,
#                                     'std': 0.0292,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:28:32'},
#                     'with_ts_index': {'avg': 0.2719,
#                                       'min': 0.2374,
#                                       'max': 0.3272,
#                                       'std': 0.0285,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:28:45'}}}
#
# Entering loop for yr =  2019
# Entering sub-loop for word:  horrible
# {'avg': 1.306,
#  'min': 1.1758,
#  'max': 1.7302,
#  'std': 0.1221,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:29:51'}
# {'avg': 0.1776,
#  'min': 0.1665,
#  'max': 0.2037,
#  'std': 0.0093,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:29:59'}
# perf_file for the run for year " 2019 " and word " horrible " is:
# {'horrible_2019': {'no_ts_index': {'avg': 1.306,
#                                    'min': 1.1758,
#                                    'max': 1.7302,
#                                    'std': 0.1221,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:29:51'},
#                    'with_ts_index': {'avg': 0.1776,
#                                      'min': 0.1665,
#                                      'max': 0.2037,
#                                      'std': 0.0093,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:29:59'}}}
# Entering sub-loop for word:  awesome
# {'avg': 1.3387,
#  'min': 1.2359,
#  'max': 1.561,
#  'std': 0.0699,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:31:06'}
# {'avg': 0.1987,
#  'min': 0.1808,
#  'max': 0.272,
#  'std': 0.0172,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:31:16'}
# perf_file for the run for year " 2019 " and word " awesome " is:
# {'awesome_2019': {'no_ts_index': {'avg': 1.3387,
#                                   'min': 1.2359,
#                                   'max': 1.561,
#                                   'std': 0.0699,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:31:06'},
#                   'with_ts_index': {'avg': 0.1987,
#                                     'min': 0.1808,
#                                     'max': 0.272,
#                                     'std': 0.0172,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:31:16'}}}
# Entering sub-loop for word:  apartment
# {'avg': 1.4153,
#  'min': 1.2889,
#  'max': 1.5578,
#  'std': 0.0639,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:32:27'}
# {'avg': 0.3318,
#  'min': 0.2829,
#  'max': 0.4119,
#  'std': 0.0347,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:32:44'}
# perf_file for the run for year " 2019 " and word " apartment " is:
# {'apartment_2019': {'no_ts_index': {'avg': 1.4153,
#                                     'min': 1.2889,
#                                     'max': 1.5578,
#                                     'std': 0.0639,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:32:27'},
#                     'with_ts_index': {'avg': 0.3318,
#                                       'min': 0.2829,
#                                       'max': 0.4119,
#                                       'std': 0.0347,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:32:44'}}}
#
# Entering loop for yr =  2020
# Entering sub-loop for word:  horrible
# {'avg': 0.1568,
#  'min': 0.1464,
#  'max': 0.2063,
#  'std': 0.0081,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:32:52'}
# {'avg': 0.0585,
#  'min': 0.0557,
#  'max': 0.0687,
#  'std': 0.0023,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:32:54'}
# perf_file for the run for year " 2020 " and word " horrible " is:
# {'horrible_2020': {'no_ts_index': {'avg': 0.1568,
#                                    'min': 0.1464,
#                                    'max': 0.2063,
#                                    'std': 0.0081,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:32:52'},
#                    'with_ts_index': {'avg': 0.0585,
#                                      'min': 0.0557,
#                                      'max': 0.0687,
#                                      'std': 0.0023,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:32:54'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.1694,
#  'min': 0.1645,
#  'max': 0.2006,
#  'std': 0.0054,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:33:03'}
# {'avg': 0.0629,
#  'min': 0.0598,
#  'max': 0.0676,
#  'std': 0.0023,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:33:06'}
# perf_file for the run for year " 2020 " and word " awesome " is:
# {'awesome_2020': {'no_ts_index': {'avg': 0.1694,
#                                   'min': 0.1645,
#                                   'max': 0.2006,
#                                   'std': 0.0054,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:33:03'},
#                   'with_ts_index': {'avg': 0.0629,
#                                     'min': 0.0598,
#                                     'max': 0.0676,
#                                     'std': 0.0023,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:33:06'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.2141,
#  'min': 0.2019,
#  'max': 0.2558,
#  'std': 0.014,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:33:17'}
# {'avg': 0.1055,
#  'min': 0.0923,
#  'max': 0.153,
#  'std': 0.0172,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:33:22'}
# perf_file for the run for year " 2020 " and word " apartment " is:
# {'apartment_2020': {'no_ts_index': {'avg': 0.2141,
#                                     'min': 0.2019,
#                                     'max': 0.2558,
#                                     'std': 0.014,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:33:17'},
#                     'with_ts_index': {'avg': 0.1055,
#                                       'min': 0.0923,
#                                       'max': 0.153,
#                                       'std': 0.0172,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:33:22'}}}
#
# Entering loop for yr =  2021
# Entering sub-loop for word:  horrible
# {'avg': 1.131,
#  'min': 1.073,
#  'max': 1.2921,
#  'std': 0.0615,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:34:19'}
# {'avg': 0.1459,
#  'min': 0.1364,
#  'max': 0.1654,
#  'std': 0.0071,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:34:26'}
# perf_file for the run for year " 2021 " and word " horrible " is:
# {'horrible_2021': {'no_ts_index': {'avg': 1.131,
#                                    'min': 1.073,
#                                    'max': 1.2921,
#                                    'std': 0.0615,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:34:19'},
#                    'with_ts_index': {'avg': 0.1459,
#                                      'min': 0.1364,
#                                      'max': 0.1654,
#                                      'std': 0.0071,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:34:26'}}}
# Entering sub-loop for word:  awesome
# {'avg': 1.2236,
#  'min': 1.1674,
#  'max': 1.3014,
#  'std': 0.0328,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:35:27'}
# {'avg': 0.1535,
#  'min': 0.143,
#  'max': 0.2121,
#  'std': 0.0102,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:35:35'}
# perf_file for the run for year " 2021 " and word " awesome " is:
# {'awesome_2021': {'no_ts_index': {'avg': 1.2236,
#                                   'min': 1.1674,
#                                   'max': 1.3014,
#                                   'std': 0.0328,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:35:27'},
#                   'with_ts_index': {'avg': 0.1535,
#                                     'min': 0.143,
#                                     'max': 0.2121,
#                                     'std': 0.0102,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:35:35'}}}
# Entering sub-loop for word:  apartment
# {'avg': 1.3107,
#  'min': 1.2105,
#  'max': 1.7631,
#  'std': 0.0911,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:36:40'}
# {'avg': 0.2438,
#  'min': 0.2124,
#  'max': 0.324,
#  'std': 0.0269,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:36:53'}
# perf_file for the run for year " 2021 " and word " apartment " is:
# {'apartment_2021': {'no_ts_index': {'avg': 1.3107,
#                                     'min': 1.2105,
#                                     'max': 1.7631,
#                                     'std': 0.0911,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:36:40'},
#                     'with_ts_index': {'avg': 0.2438,
#                                       'min': 0.2124,
#                                       'max': 0.324,
#                                       'std': 0.0269,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:36:53'}}}
#
# Entering loop for yr =  2022
# Entering sub-loop for word:  horrible
# {'avg': 1.1539,
#  'min': 1.1026,
#  'max': 1.2815,
#  'std': 0.0385,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:37:50'}
# {'avg': 0.236,
#  'min': 0.2221,
#  'max': 0.2617,
#  'std': 0.0097,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:38:02'}
# perf_file for the run for year " 2022 " and word " horrible " is:
# {'horrible_2022': {'no_ts_index': {'avg': 1.1539,
#                                    'min': 1.1026,
#                                    'max': 1.2815,
#                                    'std': 0.0385,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:37:50'},
#                    'with_ts_index': {'avg': 0.236,
#                                      'min': 0.2221,
#                                      'max': 0.2617,
#                                      'std': 0.0097,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:38:02'}}}
# Entering sub-loop for word:  awesome
# {'avg': 1.1984,
#  'min': 1.155,
#  'max': 1.3054,
#  'std': 0.0322,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:39:02'}
# {'avg': 0.2539,
#  'min': 0.2361,
#  'max': 0.3804,
#  'std': 0.0283,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:39:15'}
# perf_file for the run for year " 2022 " and word " awesome " is:
# {'awesome_2022': {'no_ts_index': {'avg': 1.1984,
#                                   'min': 1.155,
#                                   'max': 1.3054,
#                                   'std': 0.0322,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:39:02'},
#                   'with_ts_index': {'avg': 0.2539,
#                                     'min': 0.2361,
#                                     'max': 0.3804,
#                                     'std': 0.0283,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:39:15'}}}
# Entering sub-loop for word:  apartment
# {'avg': 1.3693,
#  'min': 1.2701,
#  'max': 1.5782,
#  'std': 0.0521,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:40:23'}
# {'avg': 0.425,
#  'min': 0.3809,
#  'max': 0.4836,
#  'std': 0.0277,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:40:44'}
# perf_file for the run for year " 2022 " and word " apartment " is:
# {'apartment_2022': {'no_ts_index': {'avg': 1.3693,
#                                     'min': 1.2701,
#                                     'max': 1.5782,
#                                     'std': 0.0521,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:40:23'},
#                     'with_ts_index': {'avg': 0.425,
#                                       'min': 0.3809,
#                                       'max': 0.4836,
#                                       'std': 0.0277,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:40:44'}}}
#
# Entering loop for yr =  2023
# Entering sub-loop for word:  horrible
# {'avg': 1.2566,
#  'min': 1.0966,
#  'max': 1.6952,
#  'std': 0.1121,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:41:47'}
# {'avg': 0.3133,
#  'min': 0.259,
#  'max': 0.4763,
#  'std': 0.0345,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:42:03'}
# perf_file for the run for year " 2023 " and word " horrible " is:
# {'horrible_2023': {'no_ts_index': {'avg': 1.2566,
#                                    'min': 1.0966,
#                                    'max': 1.6952,
#                                    'std': 0.1121,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:41:47'},
#                    'with_ts_index': {'avg': 0.3133,
#                                      'min': 0.259,
#                                      'max': 0.4763,
#                                      'std': 0.0345,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:42:03'}}}
# Entering sub-loop for word:  awesome
# {'avg': 1.2693,
#  'min': 1.1582,
#  'max': 1.4853,
#  'std': 0.0805,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:43:06'}
# {'avg': 0.282,
#  'min': 0.2645,
#  'max': 0.3265,
#  'std': 0.0118,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:43:21'}
# perf_file for the run for year " 2023 " and word " awesome " is:
# {'awesome_2023': {'no_ts_index': {'avg': 1.2693,
#                                   'min': 1.1582,
#                                   'max': 1.4853,
#                                   'std': 0.0805,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:43:06'},
#                   'with_ts_index': {'avg': 0.282,
#                                     'min': 0.2645,
#                                     'max': 0.3265,
#                                     'std': 0.0118,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:43:21'}}}
# Entering sub-loop for word:  apartment
# {'avg': 1.3627,
#  'min': 1.2748,
#  'max': 1.4519,
#  'std': 0.0447,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:29'}
# {'avg': 0.4485,
#  'min': 0.402,
#  'max': 0.551,
#  'std': 0.033,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:51'}
# perf_file for the run for year " 2023 " and word " apartment " is:
# {'apartment_2023': {'no_ts_index': {'avg': 1.3627,
#                                     'min': 1.2748,
#                                     'max': 1.4519,
#                                     'std': 0.0447,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:44:29'},
#                     'with_ts_index': {'avg': 0.4485,
#                                       'min': 0.402,
#                                       'max': 0.551,
#                                       'std': 0.033,
#                                       'exec_count': 50,
#                                       'timestamp': '2024-05-07-23:44:51'}}}
#
# Entering loop for yr =  2024
# Entering sub-loop for word:  horrible
# {'avg': 0.032,
#  'min': 0.0292,
#  'max': 0.0396,
#  'std': 0.0015,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:53'}
# {'avg': 0.0214,
#  'min': 0.0194,
#  'max': 0.0271,
#  'std': 0.0014,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:54'}
# perf_file for the run for year " 2024 " and word " horrible " is:
# {'horrible_2024': {'no_ts_index': {'avg': 0.032,
#                                    'min': 0.0292,
#                                    'max': 0.0396,
#                                    'std': 0.0015,
#                                    'exec_count': 50,
#                                    'timestamp': '2024-05-07-23:44:53'},
#                    'with_ts_index': {'avg': 0.0214,
#                                      'min': 0.0194,
#                                      'max': 0.0271,
#                                      'std': 0.0014,
#                                      'exec_count': 50,
#                                      'timestamp': '2024-05-07-23:44:54'}}}
# Entering sub-loop for word:  awesome
# {'avg': 0.033,
#  'min': 0.0314,
#  'max': 0.0341,
#  'std': 0.0006,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:55'}
# {'avg': 0.0204,
#  'min': 0.0193,
#  'max': 0.0227,
#  'std': 0.0007,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:56'}
# perf_file for the run for year " 2024 " and word " awesome " is:
# {'awesome_2024': {'no_ts_index': {'avg': 0.033,
#                                   'min': 0.0314,
#                                   'max': 0.0341,
#                                   'std': 0.0006,
#                                   'exec_count': 50,
#                                   'timestamp': '2024-05-07-23:44:55'},
#                   'with_ts_index': {'avg': 0.0204,
#                                     'min': 0.0193,
#                                     'max': 0.0227,
#                                     'std': 0.0007,
#                                     'exec_count': 50,
#                                     'timestamp': '2024-05-07-23:44:56'}}}
# Entering sub-loop for word:  apartment
# {'avg': 0.0379,
#  'min': 0.0363,
#  'max': 0.0396,
#  'std': 0.0008,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:44:58'}
# {'avg': 0.0279,
#  'min': 0.0255,
#  'max': 0.0452,
#  'std': 0.0028,
#  'exec_count': 50,
#  'timestamp': '2024-05-07-23:45:00'}
# ...
#                    'timestamp': '2024-05-07-23:44:58'},
#    'with_ts_index': {'avg': 0.0279,
#                      'min': 0.0255,
#                      'max': 0.0452,
#                      'std': 0.0028,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:45:00'}}),
#  ('awesome_2009',
#   {'no_ts_index': {'avg': 0.0023,
#                    'min': 0.0019,
#                    'max': 0.0031,
#                    'std': 0.0003,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:03'},
#    'with_ts_index': {'avg': 0.0017,
#                      'min': 0.0014,
#                      'max': 0.0031,
#                      'std': 0.0004,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:03'}}),
#  ('awesome_2010',
#   {'no_ts_index': {'avg': 0.0044,
#                    'min': 0.0039,
#                    'max': 0.0054,
#                    'std': 0.0004,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:04'},
#    'with_ts_index': {'avg': 0.0026,
#                      'min': 0.0023,
#                      'max': 0.0032,
#                      'std': 0.0002,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:04'}}),
#  ('awesome_2011',
#   {'no_ts_index': {'avg': 0.0125,
#                    'min': 0.0117,
#                    'max': 0.014,
#                    'std': 0.0005,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:06'},
#    'with_ts_index': {'avg': 0.0072,
#                      'min': 0.006,
#                      'max': 0.0135,
#                      'std': 0.0016,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:06'}}),
#  ('awesome_2012',
#   {'no_ts_index': {'avg': 0.0243,
#                    'min': 0.0233,
#                    'max': 0.0262,
#                    'std': 0.0006,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:11'},
#    'with_ts_index': {'avg': 0.0116,
#                      'min': 0.0109,
#                      'max': 0.013,
#                      'std': 0.0005,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:11'}}),
#  ('awesome_2013',
#   {'no_ts_index': {'avg': 0.0453,
#                    'min': 0.0432,
#                    'max': 0.0482,
#                    'std': 0.0012,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:19'},
#    'with_ts_index': {'avg': 0.0219,
#                      'min': 0.0199,
#                      'max': 0.0251,
#                      'std': 0.0014,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:21'}}),
#  ('awesome_2014',
#   {'no_ts_index': {'avg': 0.0856,
#                    'min': 0.0826,
#                    'max': 0.0891,
#                    'std': 0.0015,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:37'},
#    'with_ts_index': {'avg': 0.0391,
#                      'min': 0.0374,
#                      'max': 0.0408,
#                      'std': 0.0009,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:39'}}),
#  ('awesome_2015',
#   {'no_ts_index': {'avg': 0.1595,
#                    'min': 0.1555,
#                    'max': 0.2031,
#                    'std': 0.0065,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:25:08'},
#    'with_ts_index': {'avg': 0.0786,
#                      'min': 0.0735,
#                      'max': 0.1104,
#                      'std': 0.0052,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:25:12'}}),
#  ('awesome_2016',
#   {'no_ts_index': {'avg': 0.2377,
#                    'min': 0.2283,
#                    'max': 0.251,
#                    'std': 0.0064,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:25:59'},
#    'with_ts_index': {'avg': 0.068,
#                      'min': 0.0633,
#                      'max': 0.0799,
#                      'std': 0.0045,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:26:03'}}),
#  ('awesome_2017',
#   {'no_ts_index': {'avg': 0.3269,
#                    'min': 0.3191,
#                    'max': 0.4058,
#                    'std': 0.0131,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:27:05'},
#    'with_ts_index': {'avg': 0.1134,
#                      'min': 0.1065,
#                      'max': 0.1446,
#                      'std': 0.0081,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:27:11'}}),
#  ('awesome_2018',
#   {'no_ts_index': {'avg': 0.1999,
#                    'min': 0.1895,
#                    'max': 0.245,
#                    'std': 0.0122,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:28:08'},
#    'with_ts_index': {'avg': 0.1529,
#                      'min': 0.141,
#                      'max': 0.2358,
#                      'std': 0.0143,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:28:16'}}),
#  ('awesome_2019',
#   {'no_ts_index': {'avg': 1.3387,
#                    'min': 1.2359,
#                    'max': 1.561,
#                    'std': 0.0699,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:31:06'},
#    'with_ts_index': {'avg': 0.1987,
#                      'min': 0.1808,
#                      'max': 0.272,
#                      'std': 0.0172,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:31:16'}}),
#  ('awesome_2020',
#   {'no_ts_index': {'avg': 0.1694,
#                    'min': 0.1645,
#                    'max': 0.2006,
#                    'std': 0.0054,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:33:03'},
#    'with_ts_index': {'avg': 0.0629,
#                      'min': 0.0598,
#                      'max': 0.0676,
#                      'std': 0.0023,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:33:06'}}),
#  ('awesome_2021',
#   {'no_ts_index': {'avg': 1.2236,
#                    'min': 1.1674,
#                    'max': 1.3014,
#                    'std': 0.0328,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:35:27'},
#    'with_ts_index': {'avg': 0.1535,
#                      'min': 0.143,
#                      'max': 0.2121,
#                      'std': 0.0102,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:35:35'}}),
#  ('awesome_2022',
#   {'no_ts_index': {'avg': 1.1984,
#                    'min': 1.155,
#                    'max': 1.3054,
#                    'std': 0.0322,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:39:02'},
#    'with_ts_index': {'avg': 0.2539,
#                      'min': 0.2361,
#                      'max': 0.3804,
#                      'std': 0.0283,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:39:15'}}),
#  ('awesome_2023',
#   {'no_ts_index': {'avg': 1.2693,
#                    'min': 1.1582,
#                    'max': 1.4853,
#                    'std': 0.0805,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:43:06'},
#    'with_ts_index': {'avg': 0.282,
#                      'min': 0.2645,
#                      'max': 0.3265,
#                      'std': 0.0118,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:43:21'}}),
#  ('awesome_2024',
#   {'no_ts_index': {'avg': 0.033,
#                    'min': 0.0314,
#                    'max': 0.0341,
#                    'std': 0.0006,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:44:55'},
#    'with_ts_index': {'avg': 0.0204,
#                      'min': 0.0193,
#                      'max': 0.0227,
#                      'std': 0.0007,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:44:56'}}),
#  ('horrible_2009',
#   {'no_ts_index': {'avg': 0.0028,
#                    'min': 0.0021,
#                    'max': 0.0079,
#                    'std': 0.0008,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:02'},
#    'with_ts_index': {'avg': 0.0021,
#                      'min': 0.0016,
#                      'max': 0.0032,
#                      'std': 0.0004,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:03'}}),
#  ('horrible_2010',
#   {'no_ts_index': {'avg': 0.0044,
#                    'min': 0.0039,
#                    'max': 0.0058,
#                    'std': 0.0005,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:03'},
#    'with_ts_index': {'avg': 0.003,
#                      'min': 0.0024,
#                      'max': 0.0046,
#                      'std': 0.0004,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:03'}}),
#  ('horrible_2011',
#   {'no_ts_index': {'avg': 0.0119,
#                    'min': 0.0111,
#                    'max': 0.0136,
#                    'std': 0.0005,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:05'},
#    'with_ts_index': {'avg': 0.0063,
#                      'min': 0.0058,
#                      'max': 0.0071,
#                      'std': 0.0003,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:05'}}),
#  ('horrible_2012',
#   {'no_ts_index': {'avg': 0.023,
#                    'min': 0.0216,
#                    'max': 0.0326,
#                    'std': 0.0016,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:09'},
#    'with_ts_index': {'avg': 0.0111,
#                      'min': 0.01,
#                      'max': 0.0136,
#                      'std': 0.0007,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:09'}}),
#  ('horrible_2013',
#   {'no_ts_index': {'avg': 0.0418,
#                    'min': 0.039,
#                    'max': 0.0537,
#                    'std': 0.0028,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:16'},
#    'with_ts_index': {'avg': 0.0194,
#                      'min': 0.018,
#                      'max': 0.0239,
#                      'std': 0.0009,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:17'}}),
#  ('horrible_2014',
#   {'no_ts_index': {'avg': 0.0788,
#                    'min': 0.0744,
#                    'max': 0.0932,
#                    'std': 0.0027,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:30'},
#    'with_ts_index': {'avg': 0.0364,
#                      'min': 0.0342,
#                      'max': 0.0405,
#                      'std': 0.0014,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:24:32'}}),
#  ('horrible_2015',
#   {'no_ts_index': {'avg': 0.1449,
#                    'min': 0.1416,
#                    'max': 0.1703,
#                    'std': 0.0044,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:24:57'},
#    'with_ts_index': {'avg': 0.0698,
#                      'min': 0.0667,
#                      'max': 0.0727,
#                      'std': 0.0011,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:25:00'}}),
#  ('horrible_2016',
#   {'no_ts_index': {'avg': 0.2166,
#                    'min': 0.2103,
#                    'max': 0.2541,
#                    'std': 0.0092,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:25:44'},
#    'with_ts_index': {'avg': 0.0614,
#                      'min': 0.0565,
#                      'max': 0.1109,
#                      'std': 0.0076,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:25:47'}}),
#  ('horrible_2017',
#   {'no_ts_index': {'avg': 0.2835,
#                    'min': 0.2594,
#                    'max': 0.3221,
#                    'std': 0.013,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:26:43'},
#    'with_ts_index': {'avg': 0.1048,
#                      'min': 0.0956,
#                      'max': 0.1136,
#                      'std': 0.0036,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:26:49'}}),
#  ('horrible_2018',
#   {'no_ts_index': {'avg': 0.1798,
#                    'min': 0.1748,
#                    'max': 0.19,
#                    'std': 0.0034,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:27:51'},
#    'with_ts_index': {'avg': 0.1342,
#                      'min': 0.1286,
#                      'max': 0.1464,
#                      'std': 0.0043,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:27:58'}}),
#  ('horrible_2019',
#   {'no_ts_index': {'avg': 1.306,
#                    'min': 1.1758,
#                    'max': 1.7302,
#                    'std': 0.1221,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:29:51'},
#    'with_ts_index': {'avg': 0.1776,
#                      'min': 0.1665,
#                      'max': 0.2037,
#                      'std': 0.0093,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:29:59'}}),
#  ('horrible_2020',
#   {'no_ts_index': {'avg': 0.1568,
#                    'min': 0.1464,
#                    'max': 0.2063,
#                    'std': 0.0081,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:32:52'},
#    'with_ts_index': {'avg': 0.0585,
#                      'min': 0.0557,
#                      'max': 0.0687,
#                      'std': 0.0023,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:32:54'}}),
#  ('horrible_2021',
#   {'no_ts_index': {'avg': 1.131,
#                    'min': 1.073,
#                    'max': 1.2921,
#                    'std': 0.0615,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:34:19'},
#    'with_ts_index': {'avg': 0.1459,
#                      'min': 0.1364,
#                      'max': 0.1654,
#                      'std': 0.0071,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:34:26'}}),
#  ('horrible_2022',
#   {'no_ts_index': {'avg': 1.1539,
#                    'min': 1.1026,
#                    'max': 1.2815,
#                    'std': 0.0385,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:37:50'},
#    'with_ts_index': {'avg': 0.236,
#                      'min': 0.2221,
#                      'max': 0.2617,
#                      'std': 0.0097,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:38:02'}}),
#  ('horrible_2023',
#   {'no_ts_index': {'avg': 1.2566,
#                    'min': 1.0966,
#                    'max': 1.6952,
#                    'std': 0.1121,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:41:47'},
#    'with_ts_index': {'avg': 0.3133,
#                      'min': 0.259,
#                      'max': 0.4763,
#                      'std': 0.0345,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:42:03'}}),
#  ('horrible_2024',
#   {'no_ts_index': {'avg': 0.032,
#                    'min': 0.0292,
#                    'max': 0.0396,
#                    'std': 0.0015,
#                    'exec_count': 50,
#                    'timestamp': '2024-05-07-23:44:53'},
#    'with_ts_index': {'avg': 0.0214,
#                      'min': 0.0194,
#                      'max': 0.0271,
#                      'std': 0.0014,
#                      'exec_count': 50,
#                      'timestamp': '2024-05-07-23:44:54'}})]

# %%
# Out:
# [('apartment_2009',
#   {'no_ts_index': {'avg': 0.0033,
#                    'min': 0.0028,
#                    'max': 0.004,
#                    'std': 0.0005,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.002,
#                      'min': 0.0019,
#                      'max': 0.0021,
#                      'std': 0.0001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2010',
#   {'no_ts_index': {'avg': 0.0059,
#                    'min': 0.0053,
#                    'max': 0.0067,
#                    'std': 0.0006,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0038,
#                      'min': 0.0037,
#                      'max': 0.0041,
#                      'std': 0.0002,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2011',
#   {'no_ts_index': {'avg': 0.0168,
#                    'min': 0.016,
#                    'max': 0.0173,
#                    'std': 0.0006,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0122,
#                      'min': 0.0111,
#                      'max': 0.0133,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2012',
#   {'no_ts_index': {'avg': 0.0351,
#                    'min': 0.0334,
#                    'max': 0.0376,
#                    'std': 0.0018,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0234,
#                      'min': 0.0224,
#                      'max': 0.024,
#                      'std': 0.0007,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2013',
#   {'no_ts_index': {'avg': 0.0631,
#                    'min': 0.0604,
#                    'max': 0.0645,
#                    'std': 0.0019,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:30'},
#    'with_ts_index': {'avg': 0.0446,
#                      'min': 0.0438,
#                      'max': 0.046,
#                      'std': 0.001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('apartment_2014',
#   {'no_ts_index': {'avg': 0.1203,
#                    'min': 0.1198,
#                    'max': 0.1206,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:31'},
#    'with_ts_index': {'avg': 0.085,
#                      'min': 0.0827,
#                      'max': 0.0885,
#                      'std': 0.0025,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:31'}}),
#  ('apartment_2015',
#   {'no_ts_index': {'avg': 0.2357,
#                    'min': 0.2217,
#                    'max': 0.2603,
#                    'std': 0.0174,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:33'},
#    'with_ts_index': {'avg': 0.1576,
#                      'min': 0.1526,
#                      'max': 0.1621,
#                      'std': 0.0039,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:34'}}),
#  ('apartment_2016',
#   {'no_ts_index': {'avg': 0.3443,
#                    'min': 0.3217,
#                    'max': 0.3799,
#                    'std': 0.0255,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:37'},
#    'with_ts_index': {'avg': 0.1759,
#                      'min': 0.1556,
#                      'max': 0.2009,
#                      'std': 0.0188,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:37'}}),
#  ('apartment_2017',
#   {'no_ts_index': {'avg': 0.398,
#                    'min': 0.3958,
#                    'max': 0.3995,
#                    'std': 0.0016,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:41'},
#    'with_ts_index': {'avg': 0.1914,
#                      'min': 0.1754,
#                      'max': 0.2202,
#                      'std': 0.0204,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:41'}}),
#  ('apartment_2018',
#   {'no_ts_index': {'avg': 0.2974,
#                    'min': 0.2709,
#                    'max': 0.3157,
#                    'std': 0.0192,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:44'},
#    'with_ts_index': {'avg': 0.2476,
#                      'min': 0.2262,
#                      'max': 0.2831,
#                      'std': 0.0253,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:45'}}),
#  ('apartment_2019',
#   {'no_ts_index': {'avg': 1.2681,
#                    'min': 1.2306,
#                    'max': 1.287,
#                    'std': 0.0265,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:57'},
#    'with_ts_index': {'avg': 0.2997,
#                      'min': 0.2738,
#                      'max': 0.3509,
#                      'std': 0.0362,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:57'}}),
#  ('apartment_2020',
#   {'no_ts_index': {'avg': 0.206,
#                    'min': 0.2001,
#                    'max': 0.2154,
#                    'std': 0.0067,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:59'},
#    'with_ts_index': {'avg': 0.116,
#                      'min': 0.095,
#                      'max': 0.1474,
#                      'std': 0.0226,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:00'}}),
#  ('apartment_2021',
#   {'no_ts_index': {'avg': 1.2317,
#                    'min': 1.2095,
#                    'max': 1.2759,
#                    'std': 0.0313,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:11'},
#    'with_ts_index': {'avg': 0.23,
#                      'min': 0.2067,
#                      'max': 0.2679,
#                      'std': 0.027,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:12'}}),
#  ('apartment_2022',
#   {'no_ts_index': {'avg': 1.3292,
#                    'min': 1.2969,
#                    'max': 1.3576,
#                    'std': 0.0249,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:24'},
#    'with_ts_index': {'avg': 0.4105,
#                      'min': 0.392,
#                      'max': 0.4243,
#                      'std': 0.0136,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:26'}}),
#  ('apartment_2023',
#   {'no_ts_index': {'avg': 1.3937,
#                    'min': 1.3481,
#                    'max': 1.4245,
#                    'std': 0.0329,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:38'},
#    'with_ts_index': {'avg': 0.4205,
#                      'min': 0.3971,
#                      'max': 0.4624,
#                      'std': 0.0297,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:39'}}),
#  ('apartment_2024',
#   {'no_ts_index': {'avg': 0.0382,
#                    'min': 0.0379,
#                    'max': 0.0386,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:40'},
#    'with_ts_index': {'avg': 0.0425,
#                      'min': 0.0273,
#                      'max': 0.0718,
#                      'std': 0.0207,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:40'}}),
#  ('awesome_2009',
#   {'no_ts_index': {'avg': 0.0034,
#                    'min': 0.0029,
#                    'max': 0.004,
#                    'std': 0.0005,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0031,
#                      'min': 0.0025,
#                      'max': 0.0038,
#                      'std': 0.0006,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2010',
#   {'no_ts_index': {'avg': 0.0051,
#                    'min': 0.0047,
#                    'max': 0.006,
#                    'std': 0.0006,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.003,
#                      'min': 0.0027,
#                      'max': 0.0035,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2011',
#   {'no_ts_index': {'avg': 0.0128,
#                    'min': 0.0125,
#                    'max': 0.0131,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0065,
#                      'min': 0.0061,
#                      'max': 0.0068,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2012',
#   {'no_ts_index': {'avg': 0.0246,
#                    'min': 0.0244,
#                    'max': 0.0248,
#                    'std': 0.0002,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0118,
#                      'min': 0.0115,
#                      'max': 0.0121,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2013',
#   {'no_ts_index': {'avg': 0.0432,
#                    'min': 0.0428,
#                    'max': 0.0435,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:30'},
#    'with_ts_index': {'avg': 0.0205,
#                      'min': 0.0203,
#                      'max': 0.0208,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('awesome_2014',
#   {'no_ts_index': {'avg': 0.0832,
#                    'min': 0.0823,
#                    'max': 0.0841,
#                    'std': 0.0007,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:31'},
#    'with_ts_index': {'avg': 0.0369,
#                      'min': 0.0361,
#                      'max': 0.0379,
#                      'std': 0.0008,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:31'}}),
#  ('awesome_2015',
#   {'no_ts_index': {'avg': 0.1549,
#                    'min': 0.153,
#                    'max': 0.1562,
#                    'std': 0.0014,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:33'},
#    'with_ts_index': {'avg': 0.0763,
#                      'min': 0.0753,
#                      'max': 0.077,
#                      'std': 0.0007,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:33'}}),
#  ('awesome_2016',
#   {'no_ts_index': {'avg': 0.2309,
#                    'min': 0.2274,
#                    'max': 0.2363,
#                    'std': 0.0039,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:35'},
#    'with_ts_index': {'avg': 0.0622,
#                      'min': 0.0603,
#                      'max': 0.0631,
#                      'std': 0.0013,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:36'}}),
#  ('awesome_2017',
#   {'no_ts_index': {'avg': 0.2983,
#                    'min': 0.2924,
#                    'max': 0.3093,
#                    'std': 0.0078,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:39'},
#    'with_ts_index': {'avg': 0.1033,
#                      'min': 0.1023,
#                      'max': 0.1044,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:40'}}),
#  ('awesome_2018',
#   {'no_ts_index': {'avg': 0.1868,
#                    'min': 0.1854,
#                    'max': 0.1892,
#                    'std': 0.0017,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:43'},
#    'with_ts_index': {'avg': 0.1336,
#                      'min': 0.1322,
#                      'max': 0.1348,
#                      'std': 0.0011,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:43'}}),
#  ('awesome_2019',
#   {'no_ts_index': {'avg': 1.1879,
#                    'min': 1.1531,
#                    'max': 1.2075,
#                    'std': 0.0247,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:52'},
#    'with_ts_index': {'avg': 0.1694,
#                      'min': 0.1693,
#                      'max': 0.1697,
#                      'std': 0.0002,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:53'}}),
#  ('awesome_2020',
#   {'no_ts_index': {'avg': 0.1712,
#                    'min': 0.1706,
#                    'max': 0.1718,
#                    'std': 0.0005,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:59'},
#    'with_ts_index': {'avg': 0.0649,
#                      'min': 0.0628,
#                      'max': 0.0679,
#                      'std': 0.0022,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:59'}}),
#  ('awesome_2021',
#   {'no_ts_index': {'avg': 1.1617,
#                    'min': 1.1442,
#                    'max': 1.1781,
#                    'std': 0.0139,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:07'},
#    'with_ts_index': {'avg': 0.1435,
#                      'min': 0.1429,
#                      'max': 0.1442,
#                      'std': 0.0005,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:08'}}),
#  ('awesome_2022',
#   {'no_ts_index': {'avg': 1.2214,
#                    'min': 1.212,
#                    'max': 1.2277,
#                    'std': 0.0068,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:20'},
#    'with_ts_index': {'avg': 0.2481,
#                      'min': 0.2424,
#                      'max': 0.2519,
#                      'std': 0.0041,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:20'}}),
#  ('awesome_2023',
#   {'no_ts_index': {'avg': 1.1884,
#                    'min': 1.1486,
#                    'max': 1.2309,
#                    'std': 0.0337,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:33'},
#    'with_ts_index': {'avg': 0.2651,
#                      'min': 0.2628,
#                      'max': 0.2668,
#                      'std': 0.0017,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:34'}}),
#  ('awesome_2024',
#   {'no_ts_index': {'avg': 0.0325,
#                    'min': 0.0316,
#                    'max': 0.0337,
#                    'std': 0.0009,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:40'},
#    'with_ts_index': {'avg': 0.02,
#                      'min': 0.0197,
#                      'max': 0.0203,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:40'}}),
#  ('horrible_2009',
#   {'no_ts_index': {'avg': 0.005,
#                    'min': 0.0042,
#                    'max': 0.0065,
#                    'std': 0.0011,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0042,
#                      'min': 0.0031,
#                      'max': 0.0055,
#                      'std': 0.001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2010',
#   {'no_ts_index': {'avg': 0.0053,
#                    'min': 0.0042,
#                    'max': 0.0064,
#                    'std': 0.0009,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0038,
#                      'min': 0.0034,
#                      'max': 0.0046,
#                      'std': 0.0006,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2011',
#   {'no_ts_index': {'avg': 0.0134,
#                    'min': 0.0128,
#                    'max': 0.0139,
#                    'std': 0.0004,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.007,
#                      'min': 0.0057,
#                      'max': 0.0078,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2012',
#   {'no_ts_index': {'avg': 0.025,
#                    'min': 0.0228,
#                    'max': 0.0282,
#                    'std': 0.0024,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0112,
#                      'min': 0.0105,
#                      'max': 0.0126,
#                      'std': 0.001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2013',
#   {'no_ts_index': {'avg': 0.0424,
#                    'min': 0.0396,
#                    'max': 0.0472,
#                    'std': 0.0034,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0216,
#                      'min': 0.0187,
#                      'max': 0.0267,
#                      'std': 0.0036,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('horrible_2014',
#   {'no_ts_index': {'avg': 0.0792,
#                    'min': 0.0739,
#                    'max': 0.0845,
#                    'std': 0.0043,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:30'},
#    'with_ts_index': {'avg': 0.0357,
#                      'min': 0.0338,
#                      'max': 0.0393,
#                      'std': 0.0025,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('horrible_2015',
#   {'no_ts_index': {'avg': 0.1489,
#                    'min': 0.1379,
#                    'max': 0.1608,
#                    'std': 0.0094,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:32'},
#    'with_ts_index': {'avg': 0.0664,
#                      'min': 0.0641,
#                      'max': 0.0702,
#                      'std': 0.0027,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:32'}}),
#  ('horrible_2016',
#   {'no_ts_index': {'avg': 0.2249,
#                    'min': 0.2185,
#                    'max': 0.2285,
#                    'std': 0.0045,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:35'},
#    'with_ts_index': {'avg': 0.0614,
#                      'min': 0.0564,
#                      'max': 0.0713,
#                      'std': 0.0069,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:35'}}),
#  ('horrible_2017',
#   {'no_ts_index': {'avg': 0.2611,
#                    'min': 0.2455,
#                    'max': 0.273,
#                    'std': 0.0115,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:38'},
#    'with_ts_index': {'avg': 0.0913,
#                      'min': 0.0885,
#                      'max': 0.0937,
#                      'std': 0.0022,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:38'}}),
#  ('horrible_2018',
#   {'no_ts_index': {'avg': 0.1651,
#                    'min': 0.1644,
#                    'max': 0.1666,
#                    'std': 0.0011,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:42'},
#    'with_ts_index': {'avg': 0.1271,
#                      'min': 0.1255,
#                      'max': 0.1293,
#                      'std': 0.0016,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:42'}}),
#  ('horrible_2019',
#   {'no_ts_index': {'avg': 1.1021,
#                    'min': 1.06,
#                    'max': 1.1349,
#                    'std': 0.0313,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:48'},
#    'with_ts_index': {'avg': 0.1708,
#                      'min': 0.1645,
#                      'max': 0.1741,
#                      'std': 0.0045,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:49'}}),
#  ('horrible_2020',
#   {'no_ts_index': {'avg': 0.1679,
#                    'min': 0.1521,
#                    'max': 0.1975,
#                    'std': 0.0209,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:58'},
#    'with_ts_index': {'avg': 0.0569,
#                      'min': 0.0536,
#                      'max': 0.0604,
#                      'std': 0.0028,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:58'}}),
#  ('horrible_2021',
#   {'no_ts_index': {'avg': 1.1571,
#                    'min': 1.1228,
#                    'max': 1.2001,
#                    'std': 0.0321,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:03'},
#    'with_ts_index': {'avg': 0.1422,
#                      'min': 0.1367,
#                      'max': 0.1454,
#                      'std': 0.0039,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:04'}}),
#  ('horrible_2022',
#   {'no_ts_index': {'avg': 1.0886,
#                    'min': 1.0824,
#                    'max': 1.0928,
#                    'std': 0.0045,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:15'},
#    'with_ts_index': {'avg': 0.2282,
#                      'min': 0.2272,
#                      'max': 0.2293,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:16'}}),
#  ('horrible_2023',
#   {'no_ts_index': {'avg': 1.074,
#                    'min': 1.0641,
#                    'max': 1.0908,
#                    'std': 0.0119,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:29'},
#    'with_ts_index': {'avg': 0.2557,
#                      'min': 0.2522,
#                      'max': 0.2612,
#                      'std': 0.0039,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:30'}}),
#  ('horrible_2024',
#   {'no_ts_index': {'avg': 0.0322,
#                    'min': 0.03,
#                    'max': 0.0361,
#                    'std': 0.0028,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:40'},
#    'with_ts_index': {'avg': 0.0199,
#                      'min': 0.0197,
#                      'max': 0.0202,
#                      'std': 0.0002,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:40'}})]

# %% [markdown]
# ### <span style=color:blue>Here is an interesting query, in which we can vary three things: price range of the listing, year of when a review was made, and whether one of the 3 main words is in the review.

# %%
q_using_ts_index = """select count(*)
from listings l, reviews r
where l.id = r.listing_id
  and r.date >= '2015-01-01' and r.date <= '2015-12-31'
  and comments_tsv @@ to_tsquery('awesome')
  and l.price >= 300 and l.price < 400"""

# notice that I'm using the double "%%"; sqlalchemy reads that as "%"
q_not_using_ts_index = """select count(*)
from listings l, reviews r
where l.id = r.listing_id
  and r.date >= '2015-01-01' and r.date <= '2015-12-31'
  and comments ilike '%%awesome%%'
  and l.price >= 300 and l.price < 400"""

count = 10
perf_with_ts_index, time_list = util.run_one_query(db_eng, q_using_ts_index, count)
perf_no_ts_index, time_list = util.run_one_query(db_eng, q_not_using_ts_index, count)

print('Perf profile when using ts index is:')
pprint.pp(perf_with_ts_index)

print('\nPerf profile when NOT using ts index is:')
pprint.pp(perf_no_ts_index)
# Out:
# Perf profile when using ts index is:
# {'avg': 0.0754,
#  'min': 0.069,
#  'max': 0.1181,
#  'std': 0.0143,
#  'count': 10,
#  'timestamp': '2024-05-07-19:13:16'}
#
# Perf profile when NOT using ts index is:
# {'avg': 0.1434,
#  'min': 0.1412,
#  'max': 0.1457,
#  'std': 0.0015,
#  'count': 10,
#  'timestamp': '2024-05-07-19:13:17'}

# %%
print('0100s'[1:4])
# Out:
# 100
