# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>Cleaning up indexes before working to build reviews_join_listings.json </span>
#
# <span style=color:blue>This cell illustrates a few things.  First, I have a list of "all_indexes" which holds most (but actually not all) of the indexes I have been using; this includes all indexes used when building the three .json files.  I do not list comments_tsv_in_reviews in all_indexes, because comments_tsv_in_reviews gets special treatment, and once created is never dropped.  </span>
#
# <span style=color:blue>In this cell I drop all the indexes in all_indexes, and check that everything (except for comments_tsv_in_reviews) has been dropped.</span>

# %%
all_indexes = [['datetime','reviews'], 
               ['id','listings'],
               ['neighbourhood','listings'], 
               ['neighbourhood_group','listings'],
               ['price','listings']]                 # used when I was playing with price ranges

for i_spec in all_indexes:
    result = util.add_drop_index(db_eng, 'drop', i_spec)
    print('Inside the loop, here is the result of calling add_drop_index on the table "' \
          + str(i_spec[1]) + '"')
    # Note: add_drop_index is called multiple times for some tables
    # Also, when creating this notebook I have run this cell multiple times, so the indexes are already flushed out
    pprint.pp(result)

print('\n\nCurrent set of indexes in effect is:')
indexes_in_effect = util.fetch_all_index_info(db_eng, all_indexes)
pprint.pp(indexes_in_effect, width=150)
# Out:
# Inside the loop, here is the result of calling add_drop_index on the table "reviews"
# [('new_york_city', 'reviews', 'comments_tsv_in_reviews', None, 'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)')]
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# [('new_york_city', 'listings', 'neighbourhood_in_listings', None, 'CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)')]
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# []
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# []
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# []
#
#
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}

# %% [markdown]
# ### <span style=color:blue>Now working to build the file listings_in_reviews.json    </span>

# %% [markdown]
# <span style=color:blue>First step is to build up a dictionary of the queries to be used</span>

# %%
q_dict = {}
# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    q_name = 'listings_join_reviews_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_join_reviews(date_start, date_end)
# pprint.pp(q_dict)

pprint.pp(q_dict['listings_join_reviews_2015'])
# Out:
# ('SELECT DISTINCT l.id, l.name\n'
#  'FROM listings l, reviews r \n'
#  'WHERE l.id = r.listing_id\n'
#  "  AND r.datetime >= '2015-01-01'\n"
#  "  AND r.datetime <= '2015-12-31'\n"
#  'ORDER BY l.id;')

# %% [markdown]
# <span style=color:blue>Now invoking a loop that will build the file</span>

# %%
# keeping all_indexes in this cell, in case I run the cell stand-alone during development 
all_indexes = [['datetime','reviews'], 
               ['id','listings'],
               ['neighbourhood','listings'], 
               ['neighbourhood_group','listings'],
               ['price','listings']]                 # used when I was playing with price ranges

i_spec_list = [['datetime','reviews'], ['neighbourhood', 'listings']]

perf_file = 'listings_join_reviews_on_mac_v01.json'

# setting count to 3 for now so that things run faster
count = 50

for q in q_dict:    # for testing, replace q_dict with : ['listings_join_reviews_2015']:
    print('\n====>>> Now working on query:', q)
    perf_summary = util.run_one_query_and_multi_index_specs(db_eng, all_indexes, q, q_dict[q], i_spec_list, count)
    # print('\nThe perf_summary of running query', q, 'is as follows:') 
    # pprint.pp(perf_summary)
    updated_perf_summary = util.fetch_and_update_perf_data_merge_deeper_merge(perf_file, perf_summary)

print('\nThe value of updated perf_summary is:')
pprint.pp(updated_perf_summary, sort_dicts=True)
# Out:
# ====>>> Now working on query: listings_join_reviews_2009
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2010
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2011
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2012
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2013
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2014
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2015
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2016
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2017
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2018
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2020
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2021
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2022
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2023
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2024
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)']}
#
# Now invoking run_one_query
#
# The value of updated perf_summary is:
# {'listings_join_reviews_2009': {'__': {'avg': 0.317,
#                                        'exec_count': 50,
#                                        'max': 0.3672,
#                                        'min': 0.3055,
#                                        'std': 0.0135,
#                                        'timestamp': '2024-05-09-07:43:57'},
#                                 '__datetime_in_reviews__': {'avg': 0.0148,
#                                                             'exec_count': 50,
#                                                             'max': 0.0201,
#                                                             'min': 0.0133,
#                                                             'std': 0.0014,
#                                                             'timestamp': '2024-05-09-07:43:59'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0144,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0194,
#                                                                                        'min': 0.0132,
#                                                                                        'std': 0.001,
#                                                                                        'timestamp': '2024-05-09-07:44:16'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3076,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3401,
#                                                                   'min': 0.3011,
#                                                                   'std': 0.0067,
#                                                                   'timestamp': '2024-05-09-07:44:14'}},
#  'listings_join_reviews_2010': {'__': {'avg': 0.3031,
#                                        'exec_count': 50,
#                                        'max': 0.3266,
#                                        'min': 0.298,
#                                        'std': 0.0054,
#                                        'timestamp': '2024-05-09-07:44:31'},
#                                 '__datetime_in_reviews__': {'avg': 0.0151,
#                                                             'exec_count': 50,
#                                                             'max': 0.0206,
#                                                             'min': 0.0137,
#                                                             'std': 0.0011,
#                                                             'timestamp': '2024-05-09-07:44:32'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0153,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0204,
#                                                                                        'min': 0.0142,
#                                                                                        'std': 0.0011,
#                                                                                        'timestamp': '2024-05-09-07:44:49'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3065,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3435,
#                                                                   'min': 0.2993,
#                                                                   'std': 0.0072,
#                                                                   'timestamp': '2024-05-09-07:44:48'}},
#  'listings_join_reviews_2011': {'__': {'avg': 0.3094,
#                                        'exec_count': 50,
#                                        'max': 0.3248,
#                                        'min': 0.3006,
#                                        'std': 0.0058,
#                                        'timestamp': '2024-05-09-07:45:05'},
#                                 '__datetime_in_reviews__': {'avg': 0.0177,
#                                                             'exec_count': 50,
#                                                             'max': 0.0237,
#                                                             'min': 0.0164,
#                                                             'std': 0.0011,
#                                                             'timestamp': '2024-05-09-07:45:06'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0176,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0232,
#                                                                                        'min': 0.0162,
#                                                                                        'std': 0.001,
#                                                                                        'timestamp': '2024-05-09-07:45:24'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.311,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3234,
#                                                                   'min': 0.3026,
#                                                                   'std': 0.0047,
#                                                                   'timestamp': '2024-05-09-07:45:22'}},
#  'listings_join_reviews_2012': {'__': {'avg': 0.3093,
#                                        'exec_count': 50,
#                                        'max': 0.3457,
#                                        'min': 0.3019,
#                                        'std': 0.0065,
#                                        'timestamp': '2024-05-09-07:45:39'},
#                                 '__datetime_in_reviews__': {'avg': 0.0213,
#                                                             'exec_count': 50,
#                                                             'max': 0.031,
#                                                             'min': 0.0196,
#                                                             'std': 0.0017,
#                                                             'timestamp': '2024-05-09-07:45:41'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0217,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0291,
#                                                                                        'min': 0.0188,
#                                                                                        'std': 0.0016,
#                                                                                        'timestamp': '2024-05-09-07:45:58'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3092,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3299,
#                                                                   'min': 0.3021,
#                                                                   'std': 0.0064,
#                                                                   'timestamp': '2024-05-09-07:45:57'}},
#  'listings_join_reviews_2013': {'__': {'avg': 0.3081,
#                                        'exec_count': 50,
#                                        'max': 0.3217,
#                                        'min': 0.303,
#                                        'std': 0.0045,
#                                        'timestamp': '2024-05-09-07:46:14'},
#                                 '__datetime_in_reviews__': {'avg': 0.0242,
#                                                             'exec_count': 50,
#                                                             'max': 0.0355,
#                                                             'min': 0.0228,
#                                                             'std': 0.0019,
#                                                             'timestamp': '2024-05-09-07:46:16'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0243,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0305,
#                                                                                        'min': 0.0227,
#                                                                                        'std': 0.0013,
#                                                                                        'timestamp': '2024-05-09-07:46:33'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3109,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3827,
#                                                                   'min': 0.3042,
#                                                                   'std': 0.0111,
#                                                                   'timestamp': '2024-05-09-07:46:31'}},
#  'listings_join_reviews_2014': {'__': {'avg': 0.3141,
#                                        'exec_count': 50,
#                                        'max': 0.3856,
#                                        'min': 0.3065,
#                                        'std': 0.0122,
#                                        'timestamp': '2024-05-09-07:46:49'},
#                                 '__datetime_in_reviews__': {'avg': 0.0333,
#                                                             'exec_count': 50,
#                                                             'max': 0.0504,
#                                                             'min': 0.0311,
#                                                             'std': 0.0026,
#                                                             'timestamp': '2024-05-09-07:46:52'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.033,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0378,
#                                                                                        'min': 0.031,
#                                                                                        'std': 0.0015,
#                                                                                        'timestamp': '2024-05-09-07:47:10'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.317,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3614,
#                                                                   'min': 0.3073,
#                                                                   'std': 0.0123,
#                                                                   'timestamp': '2024-05-09-07:47:08'}},
#  'listings_join_reviews_2015': {'__': {'avg': 0.3314,
#                                        'exec_count': 50,
#                                        'max': 0.3865,
#                                        'min': 0.3255,
#                                        'std': 0.0089,
#                                        'timestamp': '2024-05-09-07:47:27'},
#                                 '__datetime_in_reviews__': {'avg': 0.0534,
#                                                             'exec_count': 50,
#                                                             'max': 0.0801,
#                                                             'min': 0.0501,
#                                                             'std': 0.0045,
#                                                             'timestamp': '2024-05-09-07:47:30'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0523,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0558,
#                                                                                        'min': 0.0497,
#                                                                                        'std': 0.0016,
#                                                                                        'timestamp': '2024-05-09-07:47:50'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.334,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3471,
#                                                                   'min': 0.3281,
#                                                                   'std': 0.0041,
#                                                                   'timestamp': '2024-05-09-07:47:47'}},
#  'listings_join_reviews_2016': {'__': {'avg': 0.3513,
#                                        'exec_count': 50,
#                                        'max': 0.4013,
#                                        'min': 0.3393,
#                                        'std': 0.0133,
#                                        'timestamp': '2024-05-09-07:48:08'},
#                                 '__datetime_in_reviews__': {'avg': 0.0668,
#                                                             'exec_count': 50,
#                                                             'max': 0.1123,
#                                                             'min': 0.0607,
#                                                             'std': 0.0094,
#                                                             'timestamp': '2024-05-09-07:48:12'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0692,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.1241,
#                                                                                        'min': 0.0619,
#                                                                                        'std': 0.0121,
#                                                                                        'timestamp': '2024-05-09-07:48:34'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3529,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3945,
#                                                                   'min': 0.3441,
#                                                                   'std': 0.0114,
#                                                                   'timestamp': '2024-05-09-07:48:30'}},
#  'listings_join_reviews_2017': {'__': {'avg': 0.368,
#                                        'exec_count': 50,
#                                        'max': 0.474,
#                                        'min': 0.3565,
#                                        'std': 0.0204,
#                                        'timestamp': '2024-05-09-07:48:53'},
#                                 '__datetime_in_reviews__': {'avg': 0.1469,
#                                                             'exec_count': 50,
#                                                             'max': 0.1809,
#                                                             'min': 0.1421,
#                                                             'std': 0.0057,
#                                                             'timestamp': '2024-05-09-07:49:01'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.1461,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.1519,
#                                                                                        'min': 0.1424,
#                                                                                        'std': 0.0021,
#                                                                                        'timestamp': '2024-05-09-07:49:27'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.361,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3896,
#                                                                   'min': 0.3548,
#                                                                   'std': 0.0058,
#                                                                   'timestamp': '2024-05-09-07:49:19'}},
#  'listings_join_reviews_2018': {'__': {'avg': 0.8072,
#                                        'exec_count': 50,
#                                        'max': 0.8557,
#                                        'min': 0.7846,
#                                        'std': 0.0158,
#                                        'timestamp': '2024-05-09-07:50:07'},
#                                 '__datetime_in_reviews__': {'avg': 0.1917,
#                                                             'exec_count': 50,
#                                                             'max': 0.2332,
#                                                             'min': 0.1846,
#                                                             'std': 0.0107,
#                                                             'timestamp': '2024-05-09-07:50:18'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.1925,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.2434,
#                                                                                        'min': 0.1848,
#                                                                                        'std': 0.0116,
#                                                                                        'timestamp': '2024-05-09-07:51:09'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.8051,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.8766,
#                                                                   'min': 0.79,
#                                                                   'std': 0.0161,
#                                                                   'timestamp': '2024-05-09-07:50:58'}},
#  'listings_join_reviews_2019': {'__': {'avg': 0.8223,
#                                        'exec_count': 50,
#                                        'max': 0.8963,
#                                        'min': 0.808,
#                                        'std': 0.0168,
#                                        'timestamp': '2024-05-09-07:51:50'},
#                                 '__datetime_in_reviews__': {'avg': 0.2373,
#                                                             'exec_count': 50,
#                                                             'max': 0.2846,
#                                                             'min': 0.2275,
#                                                             'std': 0.0142,
#                                                             'timestamp': '2024-05-09-07:52:03'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.2375,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.2791,
#                                                                                        'min': 0.2275,
#                                                                                        'std': 0.0123,
#                                                                                        'timestamp': '2024-05-09-07:52:56'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.8222,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.8717,
#                                                                   'min': 0.8055,
#                                                                   'std': 0.015,
#                                                                   'timestamp': '2024-05-09-07:52:44'}},
#  'listings_join_reviews_2020': {'__': {'avg': 0.3591,
#                                        'exec_count': 50,
#                                        'max': 0.4093,
#                                        'min': 0.347,
#                                        'std': 0.0152,
#                                        'timestamp': '2024-05-09-07:53:14'},
#                                 '__datetime_in_reviews__': {'avg': 0.1398,
#                                                             'exec_count': 50,
#                                                             'max': 0.1922,
#                                                             'min': 0.131,
#                                                             'std': 0.0134,
#                                                             'timestamp': '2024-05-09-07:53:22'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.1412,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.1869,
#                                                                                        'min': 0.1331,
#                                                                                        'std': 0.0134,
#                                                                                        'timestamp': '2024-05-09-07:53:48'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3602,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.4056,
#                                                                   'min': 0.3515,
#                                                                   'std': 0.0113,
#                                                                   'timestamp': '2024-05-09-07:53:40'}},
#  'listings_join_reviews_2021': {'__': {'avg': 0.8294,
#                                        'exec_count': 50,
#                                        'max': 0.888,
#                                        'min': 0.8055,
#                                        'std': 0.0186,
#                                        'timestamp': '2024-05-09-07:54:30'},
#                                 '__datetime_in_reviews__': {'avg': 0.2173,
#                                                             'exec_count': 50,
#                                                             'max': 0.2617,
#                                                             'min': 0.2071,
#                                                             'std': 0.0137,
#                                                             'timestamp': '2024-05-09-07:54:41'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.2155,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.2572,
#                                                                                        'min': 0.2066,
#                                                                                        'std': 0.0125,
#                                                                                        'timestamp': '2024-05-09-07:55:34'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.8183,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.8644,
#                                                                   'min': 0.8049,
#                                                                   'std': 0.0136,
#                                                                   'timestamp': '2024-05-09-07:55:22'}},
#  'listings_join_reviews_2022': {'__': {'avg': 0.8713,
#                                        'exec_count': 50,
#                                        'max': 0.9402,
#                                        'min': 0.8458,
#                                        'std': 0.0214,
#                                        'timestamp': '2024-05-09-07:56:17'},
#                                 '__datetime_in_reviews__': {'avg': 0.8782,
#                                                             'exec_count': 50,
#                                                             'max': 0.9577,
#                                                             'min': 0.8481,
#                                                             'std': 0.0262,
#                                                             'timestamp': '2024-05-09-07:57:02'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.873,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.918,
#                                                                                        'min': 0.8499,
#                                                                                        'std': 0.0199,
#                                                                                        'timestamp': '2024-05-09-07:58:32'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.9001,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.9705,
#                                                                   'min': 0.8575,
#                                                                   'std': 0.0316,
#                                                                   'timestamp': '2024-05-09-07:57:47'}},
#  'listings_join_reviews_2023': {'__': {'avg': 0.8948,
#                                        'exec_count': 50,
#                                        'max': 0.9574,
#                                        'min': 0.8686,
#                                        'std': 0.0208,
#                                        'timestamp': '2024-05-09-07:59:17'},
#                                 '__datetime_in_reviews__': {'avg': 0.8906,
#                                                             'exec_count': 50,
#                                                             'max': 0.9332,
#                                                             'min': 0.8653,
#                                                             'std': 0.0205,
#                                                             'timestamp': '2024-05-09-08:00:02'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.9224,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 1.0589,
#                                                                                        'min': 0.8764,
#                                                                                        'std': 0.0341,
#                                                                                        'timestamp': '2024-05-09-08:01:33'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.8893,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.9351,
#                                                                   'min': 0.8658,
#                                                                   'std': 0.0202,
#                                                                   'timestamp': '2024-05-09-08:00:46'}},
#  'listings_join_reviews_2024': {'__': {'avg': 0.3119,
#                                        'exec_count': 50,
#                                        'max': 0.331,
#                                        'min': 0.3059,
#                                        'std': 0.0047,
#                                        'timestamp': '2024-05-09-08:01:49'},
#                                 '__datetime_in_reviews__': {'avg': 0.0317,
#                                                             'exec_count': 50,
#                                                             'max': 0.0492,
#                                                             'min': 0.0293,
#                                                             'std': 0.0027,
#                                                             'timestamp': '2024-05-09-08:01:51'},
#                                 '__datetime_in_reviews__neighbourhood_in_listings__': {'avg': 0.0322,
#                                                                                        'exec_count': 50,
#                                                                                        'max': 0.0403,
#                                                                                        'min': 0.0299,
#                                                                                        'std': 0.0021,
#                                                                                        'timestamp': '2024-05-09-08:02:10'},
#                                 '__neighbourhood_in_listings__': {'avg': 0.3188,
#                                                                   'exec_count': 50,
#                                                                   'max': 0.3656,
#                                                                   'min': 0.3101,
#                                                                   'std': 0.0126,
#                                                                   'timestamp': '2024-05-09-08:02:07'}}}
