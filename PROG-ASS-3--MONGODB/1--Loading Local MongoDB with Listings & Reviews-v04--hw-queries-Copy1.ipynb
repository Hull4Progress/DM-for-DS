# %% [markdown]
# ### <span style=color:blue> Loading Listings & Reviews data from postgresql into local MongoDB    </span>

# %%
import sys
import json
import csv
import yaml

import importlib

import math

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
# NOTE: I moved my util.py to the directory "helper_functions" -- seems like a better name
sys.path.append('helper_functions/')
import util

# %%
# test that utils.py has been imported well
util.hello_world()
# Out:
# hello world

# %% [markdown]
# <span style=color:blue>Getting PostgreSQL connection set up</span>

# %%
# Load the env file 

dotenv_path = 'env_variables.env'
load_dotenv(dotenv_path=dotenv_path)

# Import the env variables

load_dotenv()

schema = os.getenv('DISC_6_SCHEMA')
port = os.getenv('DISC_6_PORT')
host = os.getenv('DISC_6_HOST')
database = os.getenv('DISC_6_DB')
password = os.getenv('DISC_6_PASSWORD')
connection = os.getenv('DISC_6_CONNECTION')

# Create the db engine 

db_eng = create_engine(f"postgresql+psycopg2://{connection}:{password}@{host}:{port}/{database}",
                       connect_args={'options': '-csearch_path={}'.format(schema)},
                       isolation_level = 'SERIALIZABLE')

print("Successfully created db engine.")
# Out:
# Successfully created db engine.

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# <span style=color:blue>Setting up collection "listings" in mongodb</span>

# %%
# I have (or will have) a database "airbnb"
db = client.airbnb

# inside the "airbnb" database, I have (or will have) a collection "listings"
listings = db.listings
print(db.list_collection_names())
# I have some other collections in my airbnb database...
# Out:
# ['testing', 'listings_previously_built', 'listings_test', 'calendar_previously_built', 'listings']

# %% [markdown]
# ### <span style=color:blue>As preparation for the next steps, I have a created table reviewm in my PostgreSQL using DBeaver, in which I dropped the comments_tsv column (because not needed), renamed column "id" to "review_id" (so that it is not repeating the "id" column of the listings table, and dropped the datetime column.</span>
#
# <span style=color:blue>In the following I focus on the query q10, which fetches a left join based on all listing_ids with prefix '10'.  This is useful for doing testing.  For your assignment you should use the left join query that includes all listings.</span>

# %%
import importlib
import util
# using this in case I have added stuff to util.py
importlib.reload(util)

# some other queries I was experimenting with
# q = util.build_query_full_join_listings_reviewsm()
# q = util.build_query_left_join_listings_reviewsm_null_right()

q10 = util.build_query_left_join_listings_reviewsm_10()
q = util.build_query_left_join_listings_reviewsm()

print('We will be using the following queries, produced by functions I defined in util.py:\n')
print(q10)
print()
print(q)
# Out:
# We will be using the following queries, produced by functions I defined in util.py:
#
# select *
# from listings l left join reviewsm r
#         on l.id = r.listing_id
#   where left(l.id,2) = '10'
# -- this query fetches data for 3313 listings, useful for testing
#
# select *
# from listings l left join reviewsm r
#         on l.id = r.listing_id

# %%
with db_eng.connect() as conn:
    df_ljr10 = pd.read_sql(q10, con=conn)
    # df_ljr = pd.read_sql(q, con=conn)

# %%
print(df_ljr10.head())
# print(df_ljr.head())
# Out:
#                     id                                               name  \
# 0  1007898112628596835         Rental unit in Bronx · 2 bedrooms · 1 bath
# 1  1032550134459701382  Rental unit in Queens · ★4.70 · 1 bedroom · 1 ...
# 2  1032550134459701382  Rental unit in Queens · ★4.70 · 1 bedroom · 1 ...
# 3  1032550134459701382  Rental unit in Queens · ★4.70 · 1 bedroom · 1 ...
# 4  1032550134459701382  Rental unit in Queens · ★4.70 · 1 bedroom · 1 ...
#
#      host_id host_name neighbourhood_group       neighbourhood   latitude  \
# 0  481526228   Michael               Bronx  Westchester Square  40.842243
# 1  231138233     Filiz              Queens           Ridgewood  40.704277
# 2  231138233     Filiz              Queens           Ridgewood  40.704277
# 3  231138233     Filiz              Queens           Ridgewood  40.704277
# 4  231138233     Filiz              Queens           Ridgewood  40.704277
#
#    longitude        room_type  price  ...  calculated_host_listings_count  \
# 0 -73.853096  Entire home/apt  319.0  ...                               1
# 1 -73.899640     Private room   53.0  ...                               7
# 2 -73.899640     Private room   53.0  ...                               7
# 3 -73.899640     Private room   53.0  ...                               7
# 4 -73.899640     Private room   53.0  ...                               7
#
#    availability_365 number_of_reviews_ltm             license  \
# 0                89                     0  OSE-STRREG-0001056
# 1                12                    10              Exempt
# 2                12                    10              Exempt
# 3                12                    10              Exempt
# 4                12                    10              Exempt
#
#             listing_id            review_id        date reviewer_id  \
# 0                 None                 None        None        None
# 1  1032550134459701382  1065325856879341430  2024-01-09   132995195
# 2  1032550134459701382  1070333492280511414  2024-01-16   508836613
# 3  1032550134459701382  1054421039025663398  2023-12-25   259730471
# 4  1032550134459701382  1036333028660540366  2023-11-30    53964877
#
#   reviewer_name                                           comments
# 0          None                                               None
# 1        Collin  Clean and cheap with a flexible check-in time ...
# 2        Forbes                                         Great stay
# 3     Parity Is  Very responsive. Excellent place to stay at. 1...
# 4           Moe  Place is clean and area is quite. The host is ...
#
# [5 rows x 24 columns]

# %%
# print(df_ljr.shape)
# should be 998,310 rows in df_ljr.  This is
#     number of records in listings whose id do not show up in reviews['listing_id'] =  11,500
#   + number of reviews                                                              = 986,810

print(df_ljr10.shape)
# you might want to check this number against what you expect based on what exploration
#    you do with DBeaver
# Out:
# (25103, 24)

# %% [markdown]
# ### <span style=color:blue>The left outer join has between 0 and many records for each listing_id.  There is one record for each review about that listing.  We will now re-format this data into a list of dictionaries.  Each dictionary will have the data for one listing along with a list of all of the associated reviews. </span>

# %%
cols = df_ljr10.columns.tolist()
# cols = df_ljr.columns.tolist()
print(cols)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'license', 'listing_id', 'review_id', 'date', 'reviewer_id', 'reviewer_name', 'comments']

# %% [markdown]
# <span style=color:blue>As a first step, we build a list of dictionaries with just the listing data.  To do this we use pandas to create a new dataframe with the reviews-related columns dropped</span>

# %%
# to do a projection and remove duplicates
cols_of_listings = ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 
                    'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 
                    'minimum_nights', 'number_of_reviews', 'last_review', 
                    'reviews_per_month', 'calculated_host_listings_count', 
                    'availability_365', 'number_of_reviews_ltm', 'license']
cols_of_reviews = ['listing_id', 'review_id', 'date', 'reviewer_id', 
                   'reviewer_name', 'comments']

df_ljr10_new = df_ljr10.drop(cols_of_reviews, axis=1).drop_duplicates()


print(df_ljr10_new.shape)
# print(df_ljr_new.head(10))

# print(df_ljr_new.iloc[13870])
# Out:
# (3313, 18)

# %% [markdown]
# <span style=color:blue>Converting the dataframe into a list of dictionaries     </span>

# %%
dict_ljr10_new = df_ljr10_new.to_dict('records')
print(len(dict_ljr10_new))
pprint.pp(dict_ljr10_new[0])
# Out:
# 3313
# {'id': '1007898112628596835',
#  'name': 'Rental unit in Bronx · 2 bedrooms · 1 bath',
#  'host_id': '481526228',
#  'host_name': 'Michael',
#  'neighbourhood_group': 'Bronx',
#  'neighbourhood': 'Westchester Square',
#  'latitude': 40.842243,
#  'longitude': -73.853096,
#  'room_type': 'Entire home/apt',
#  'price': 319.0,
#  'minimum_nights': 2,
#  'number_of_reviews': 0,
#  'last_review': None,
#  'reviews_per_month': nan,
#  'calculated_host_listings_count': 1,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 0,
#  'license': 'OSE-STRREG-0001056'}

# %% [markdown]
# <span style=color:blue>Let's try loading what we have so far into MongoDB, into a temporary collection     </span>

# %%
# testing with a new, temporary collection
listings_test = db.listings_test

try:
    result = listings_test.insert_many(dict_ljr10_new)
    print('\nLast element of result for the last run was:')
    print(result.inserted_ids[-1:])
except Exception as e:
    print('There was an error when loading the dictionary into MongoDB:')
    print(e)
# Out:
# There was an error when loading the dictionary into MongoDB:
# cannot encode object: datetime.date(2024, 1, 29), of type: <class 'datetime.date'>

# %% [markdown]
# <span style=color:blue>MongoDB does not handle dates, only datetimes.  Here is a function to convert the dates into datetimes.  (An alternative would have been to convert the dates in our table reviewsm into datetimes.)

# %%
# This converts date to datetime.  It also converts various kinds of
#     null values into None, which loads into MongoDB without creating errors
def convert_date_to_datetime(dt):
    if pd.isnull(dt):           # tests whether dt is None, NaN, or DaT (not a date)
        return None
    elif type(dt) == pd._libs.tslibs.nattype.NaTType:  # including this, but see below
        return None
    else:
        temp = datetime(dt.year, dt.month, dt.day)
        ts = temp.timestamp()
        new_dt = datetime.fromtimestamp(ts)
        return new_dt

# testing various cases:
# Here are four dictionaries to test with
dict1 = {'foo':1, 'date': date(2023,1,2)}
dict2 = {'goo':2, 'date': math.nan}
dict3 = {'hoo':3, 'date': None}
dict4 = {'koo':4, 'date': pd.NaT}

if pd.isnull(dict3['date']):        # pd.isnull tests whether something is 
    print("dict4['date'] tested positive as NaT")    
else:
    print("dict4['date'] did not test positive as NaT")
    

print(dict1)
dict1['date'] = convert_date_to_datetime(dict1['date'])
print(dict1)

print()
print(dict2)
dict2['date'] = convert_date_to_datetime(dict2['date'])
print(dict2)

print()
print(dict3)
dict3['date'] = convert_date_to_datetime(dict3['date'])
print(dict3)

print()
print(dict4)
dict4['date'] = convert_date_to_datetime(dict4['date'])
print(dict4)
# Out:
# dict4['date'] tested positive as NaT
# {'foo': 1, 'date': datetime.date(2023, 1, 2)}
# {'foo': 1, 'date': datetime.datetime(2023, 1, 2, 0, 0)}
#
# {'goo': 2, 'date': nan}
# {'goo': 2, 'date': None}
#
# {'hoo': 3, 'date': None}
# {'hoo': 3, 'date': None}
#
# {'koo': 4, 'date': NaT}
# {'koo': 4, 'date': None}

# %% [markdown]
# <span style=color:blue>Use pandas to replace the dates in the "last_review" column with datetimes</span>

# %%
# trying to replace all dates by datetimes (or None)

# df_ljr10_new['last_review'] = df_ljr10_new['last_review'].apply(convert_date_to_datetime)

# could also have written
df_ljr10_new['last_review'] = df_ljr10_new['last_review'].apply(lambda x: convert_date_to_datetime(x))

# %%
print(df_ljr10_new.head())
# Out:
#                      id                                               name  \
# 0   1007898112628596835         Rental unit in Bronx · 2 bedrooms · 1 bath
# 1   1032550134459701382  Rental unit in Queens · ★4.70 · 1 bedroom · 1 ...
# 11  1061632971843436364  Hotel in Queens · ★4.40 · 1 bedroom · 1 bed · ...
# 16  1039753101132672547  Rental unit in New York · ★New · Studio · 1 be...
# 17  1024485974616152538  Home in Staten Island · ★New · 1 bedroom · 2 b...
#
#       host_id   host_name neighbourhood_group       neighbourhood   latitude  \
# 0   481526228     Michael               Bronx  Westchester Square  40.842243
# 1   231138233       Filiz              Queens           Ridgewood  40.704277
# 11  544554359  John Hotel              Queens            Flushing  40.760290
# 16  371213084       Nabel           Manhattan   Battery Park City  40.711452
# 17  524771414     Shaimaa       Staten Island          St. George  40.640290
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.853096  Entire home/apt  319.0               2                  0
# 1  -73.899640     Private room   53.0               1                 10
# 11 -73.834370     Private room  104.0               1                  5
# 16 -74.016230  Entire home/apt  160.0              30                  0
# 17 -74.085480     Private room   47.0              30                  0
#
#    last_review  reviews_per_month  calculated_host_listings_count  \
# 0          NaT                NaN                               1
# 1   2024-01-29               4.35                               7
# 11  2024-01-20               5.00                               5
# 16         NaT                NaN                               1
# 17         NaT                NaN                               2
#
#     availability_365  number_of_reviews_ltm             license
# 0                 89                      0  OSE-STRREG-0001056
# 1                 12                     10              Exempt
# 11               113                      5              Exempt
# 16               189                      0
# 17                89                      0

# %%
# As you can see in the result from the last cell,
#   somehow the NaT's are still there, in spite of the special case included in
#   the function convert_time_to_timestamp()
#   BTW, curiously, on very small dataframes the convert_time_to_timestamp() does convert NaT to None

# Happily, all of the actual dates have converted into datetimes, as illustrated by the following:
#    Using "iloc" because the index values in df_ljr10_new are not consecutive
print(type(df_ljr10_new.iloc[0, 12]))  # 12 is position of 'last_review'
print(df_ljr10_new.iloc[0,12])
print(type(df_ljr10_new.iloc[1, 12]))  
print(df_ljr10_new.iloc[1,12])
print(type(df_ljr10_new.iloc[2, 12]))  
print(df_ljr10_new.iloc[2,12])
print(type(df_ljr10_new.iloc[3, 12]))  
print(df_ljr10_new.iloc[3,12])
# Out:
# <class 'pandas._libs.tslibs.nattype.NaTType'>
# NaT
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2024-01-29 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2024-01-20 00:00:00
# <class 'pandas._libs.tslibs.nattype.NaTType'>
# NaT

# %%
# recomputing dict_ljr10_new
dict_ljr10_new = df_ljr10_new.to_dict('records')
print(len(dict_ljr10_new))
pprint.pp(dict_ljr10_new[0:2])
# Out:
# 3313
# [{'id': '1007898112628596835',
#   'name': 'Rental unit in Bronx · 2 bedrooms · 1 bath',
#   'host_id': '481526228',
#   'host_name': 'Michael',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Westchester Square',
#   'latitude': 40.842243,
#   'longitude': -73.853096,
#   'room_type': 'Entire home/apt',
#   'price': 319.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 0,
#   'last_review': NaT,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 0,
#   'license': 'OSE-STRREG-0001056'},
#  {'id': '1032550134459701382',
#   'name': 'Rental unit in Queens · ★4.70 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '231138233',
#   'host_name': 'Filiz',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Ridgewood',
#   'latitude': 40.704277,
#   'longitude': -73.89964,
#   'room_type': 'Private room',
#   'price': 53.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 10,
#   'last_review': Timestamp('2024-01-29 00:00:00'),
#   'reviews_per_month': 4.35,
#   'calculated_host_listings_count': 7,
#   'availability_365': 12,
#   'number_of_reviews_ltm': 10,
#   'license': 'Exempt'}]

# %%
# However, the load into MongoDB still fails, because of the NaT values
#    As noted above, the convert_time_to_timestamp did not convert the NaT values
try:
    result = listings_test.insert_many(dict_ljr10_new)
    print('\nLast element of result for the last run was:')
    print(result.inserted_ids[-1:])
except Exception as e:
    print('\nThere was an error when loading the dictionary into MongoDB:')
    print(e)
# Out:
# There was an error when loading the dictionary into MongoDB:
# NaTType does not support utcoffset

# %% [markdown]
# <span style=color:blue>OK, so let's convert the NaT's in the dictionary rather than in pandas  </span>

# %%
for doc in dict_ljr10_new:
    if pd.isnull(doc['last_review']): 
        doc['last_review'] = None

pprint.pp(dict_ljr10_new[0:10])
# Out:
# [{'id': '1007898112628596835',
#   'name': 'Rental unit in Bronx · 2 bedrooms · 1 bath',
#   'host_id': '481526228',
#   'host_name': 'Michael',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Westchester Square',
#   'latitude': 40.842243,
#   'longitude': -73.853096,
#   'room_type': 'Entire home/apt',
#   'price': 319.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 0,
#   'license': 'OSE-STRREG-0001056',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9d7')},
#  {'id': '1032550134459701382',
#   'name': 'Rental unit in Queens · ★4.70 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '231138233',
#   'host_name': 'Filiz',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Ridgewood',
#   'latitude': 40.704277,
#   'longitude': -73.89964,
#   'room_type': 'Private room',
#   'price': 53.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 10,
#   'last_review': Timestamp('2024-01-29 00:00:00'),
#   'reviews_per_month': 4.35,
#   'calculated_host_listings_count': 7,
#   'availability_365': 12,
#   'number_of_reviews_ltm': 10,
#   'license': 'Exempt',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9d8')},
#  {'id': '1061632971843436364',
#   'name': 'Hotel in Queens · ★4.40 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '544554359',
#   'host_name': 'John Hotel',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Flushing',
#   'latitude': 40.76029,
#   'longitude': -73.83437,
#   'room_type': 'Private room',
#   'price': 104.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 5,
#   'last_review': Timestamp('2024-01-20 00:00:00'),
#   'reviews_per_month': 5.0,
#   'calculated_host_listings_count': 5,
#   'availability_365': 113,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9d9')},
#  {'id': '1039753101132672547',
#   'name': 'Rental unit in New York · ★New · Studio · 1 bed · 1 bath',
#   'host_id': '371213084',
#   'host_name': 'Nabel',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Battery Park City',
#   'latitude': 40.711452,
#   'longitude': -74.01623,
#   'room_type': 'Entire home/apt',
#   'price': 160.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 189,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9da')},
#  {'id': '1024485974616152538',
#   'name': 'Home in Staten Island · ★New · 1 bedroom · 2 beds · 1 bath',
#   'host_id': '524771414',
#   'host_name': 'Shaimaa',
#   'neighbourhood_group': 'Staten Island',
#   'neighbourhood': 'St. George',
#   'latitude': 40.64029,
#   'longitude': -74.08548,
#   'room_type': 'Private room',
#   'price': 47.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 2,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9db')},
#  {'id': '1023371010670890196',
#   'name': 'Rental unit in Queens · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '369751744',
#   'host_name': 'Rahul Kabir',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Kew Gardens',
#   'latitude': 40.706287,
#   'longitude': -73.8317,
#   'room_type': 'Private room',
#   'price': 60.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 263,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9dc')},
#  {'id': '1019618568571379980',
#   'name': 'Guest suite in Queens · ★New · 3 bedrooms · 3 beds · 2 baths',
#   'host_id': '486462988',
#   'host_name': 'Tyler',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Rosedale',
#   'latitude': 40.65508,
#   'longitude': -73.742,
#   'room_type': 'Private room',
#   'price': 193.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 256,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9dd')},
#  {'id': '1080615169929014643',
#   'name': 'Home in Queens · ★New · Studio · 2 beds · 1 shared bath',
#   'host_id': '148123938',
#   'host_name': 'Sabrina',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Springfield Gardens',
#   'latitude': 40.67251,
#   'longitude': -73.76162,
#   'room_type': 'Shared room',
#   'price': 127.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 2,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9de')},
#  {'id': '1063126161307363729',
#   'name': 'Home in Brooklyn · ★New · 2 bedrooms · 1 bath',
#   'host_id': '496617784',
#   'host_name': 'Valleix',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'East Flatbush',
#   'latitude': 40.63863,
#   'longitude': -73.93949,
#   'room_type': 'Private room',
#   'price': 137.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 2,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 0,
#   'license': 'OSE-STRREG-0001130',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9df')},
#  {'id': '1034089973112248847',
#   'name': 'Rental unit in Queens · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '548292248',
#   'host_name': 'John',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Rosedale',
#   'latitude': 40.66297,
#   'longitude': -73.73398,
#   'room_type': 'Private room',
#   'price': 70.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 2,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b58f9e0')}]

# %% [markdown]
# <span style=color:blue>Now trying the load again    </span>

# %%
try:
    result = listings_test.insert_many(dict_ljr10_new)
    print('\nLast element of result for the last run was:')
    print(result.inserted_ids[-1:])
except Exception as e:
    print('\nThere was an error when loading the dictionary into MongoDB:')
    print(e)
# Out:
# Last element of result for the last run was:
# [ObjectId('6658d7d82d77bbd68b5906c7')]

# %% [markdown]
# <span style=color:blue>Now we add, for each listing, a list of all reviews for that listing     </span>

# %%
i = 0

# We will keep track of the time to do each 1000 listings
time1 = datetime.now()


for d in dict_ljr10_new:
    i += 1

    # building a df with just reviews info, and corresponding to the listing we are focusing on
    df_reviews_one_listing = df_ljr10.loc[df_ljr10['id'] == d['id']].drop(cols_of_listings, axis=1)

    # Note: This does not run super quickly.  As an alternative I tried pulling this 
    #    data with a query against PostgreSQL, but it was even slower

    # there are no null values in the 'date' column of reviews, so we can do the
    #    date to datetime conversion using pandas
    df_reviews_one_listing['date'] = df_reviews_one_listing['date'].apply(lambda x: convert_date_to_datetime(x))

    dicts_reviews_one_listing = df_reviews_one_listing.to_dict('records')

    # Need special handling for the case of no reviews 
    if len(dicts_reviews_one_listing) == 1 and dicts_reviews_one_listing[0]['review_id'] is None:
        d['reviews'] = {}
    else:
        d['reviews'] = dicts_reviews_one_listing

    if i % 1000 == 0:
        time2 = datetime.now()
        time_taken = util.time_diff(time1,time2)
        print('Have now completed step number:', str(i), 'and it took', str(time_taken), 'seconds' )
        time1 = datetime.now()

    # given the time it takes to do 1000 listings, how long will it take to do all of the listings?

print()
print(len(dict_ljr10_new))
print()
pprint.pp(dict_ljr10_new[-10:])
# Out:
# Have now completed step number: 1000 and it took 3.137363 seconds
# Have now completed step number: 2000 and it took 3.194379 seconds
# Have now completed step number: 3000 and it took 3.38387 seconds
#
# 3313
#
# [{'id': '1051404502211155820',
#   'name': 'Rental unit in Queens · ★New · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '490393628',
#   'host_name': 'Veronica',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.766,
#   'longitude': -73.92658,
#   'room_type': 'Private room',
#   'price': 65.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 2,
#   'availability_365': 254,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906be'),
#   'reviews': {}},
#  {'id': '1025204455815288168',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '407304997',
#   'host_name': 'Boomerang',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.755417,
#   'longitude': -73.982544,
#   'room_type': 'Entire home/apt',
#   'price': 280.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 33,
#   'availability_365': 149,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906bf'),
#   'reviews': {}},
#  {'id': '1003665546182490793',
#   'name': 'Rental unit in New York · Studio · 1 bed · 1 bath',
#   'host_id': '61391963',
#   'host_name': 'Stay With Vibe',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.76995,
#   'longitude': -73.95646,
#   'room_type': 'Entire home/apt',
#   'price': 69.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 130,
#   'availability_365': 254,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c0'),
#   'reviews': {}},
#  {'id': '1028444698699878344',
#   'name': 'Rental unit in New York · ★4.82 · 2 bedrooms · 2 beds · 2 baths',
#   'host_id': '446651246',
#   'host_name': 'Slavy',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.75506,
#   'longitude': -73.99249,
#   'room_type': 'Entire home/apt',
#   'price': 443.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 11,
#   'last_review': Timestamp('2024-02-09 00:00:00'),
#   'reviews_per_month': 4.23,
#   'calculated_host_listings_count': 1,
#   'availability_365': 320,
#   'number_of_reviews_ltm': 11,
#   'license': 'Exempt',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c1'),
#   'reviews': [{'listing_id': '1028444698699878344',
#                'review_id': '1041424102909452549',
#                'date': Timestamp('2023-12-07 00:00:00'),
#                'reviewer_id': '199659424',
#                'reviewer_name': 'Alyssa',
#                'comments': 'Great spot'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1032631224948395725',
#                'date': Timestamp('2023-11-25 00:00:00'),
#                'reviewer_id': '3613737',
#                'reviewer_name': 'Gian Marco',
#                'comments': "We appreciate so much Slavy's place and assistance "
#                            'throughout our stay.<br/>The location is '
#                            'excellent, conveniently situated between North '
#                            'Chelsea and Meatpacking. The well-known area '
#                            'called "Hudson Yards" is filled with trendy '
#                            'restaurants and luxury shops.<br/>The apartment is '
#                            'just delightful, with two opposite bedrooms and '
#                            'bathrooms providing us with the total comfort and '
#                            'privacy we needed.<br/>The entire place was '
#                            'spotlessly clean and thoughtfully '
#                            'decorated.<br/>The host was extremely nice and '
#                            'responsive, even on Thanksgiving day.<br/>We loved '
#                            'it here!'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1034872575913322281',
#                'date': Timestamp('2023-11-28 00:00:00'),
#                'reviewer_id': '37530861',
#                'reviewer_name': 'Ivano',
#                'comments': 'Alejandro’s loft is gigantic! Very well maintained '
#                            'and everything was up to order and very '
#                            'comfortable <br/>The master bathroom is something '
#                            'out of this world! Probably the most beautiful '
#                            'bathroom I ever seen<br/>Plenty of space, '
#                            'extremely clean and the communication with the '
#                            'host was always fluent <br/>The area SOHO no need '
#                            'presentation, simply the best! <br/>I will '
#                            'definitely come back!'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1037741730230705748',
#                'date': Timestamp('2023-12-02 00:00:00'),
#                'reviewer_id': '402731077',
#                'reviewer_name': 'Ambra',
#                'comments': 'Had an amazing stay!! <br/>This apartment was '
#                            'absolutely perfectly placed.<br/>Walking distance '
#                            'to Empire State Building, Times Square/Broadway '
#                            "and Hudson's yard.<br/>Really clean inside, nicely "
#                            'furnished and a safe building. Great for couples '
#                            'as two bedrooms and two bathrooms.<br/>I would '
#                            'definitely recommend the deli downstairs too. Open '
#                            '24 hours a day. Great place x'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1039181927102040794',
#                'date': Timestamp('2023-12-04 00:00:00'),
#                'reviewer_id': '10866514',
#                'reviewer_name': 'Richard',
#                'comments': 'This beautiful apartment was just perfect! The '
#                            'large kitchen and living open concept gave us more '
#                            'space then we need it for entertaining and gather '
#                            'all together <br/>The 2 also very large bedrooms '
#                            'were extremely comfortable, quite and very well '
#                            'equipped <br/>The master bathroom in suite was an '
#                            'addition very much appreciated <br/>The apartment '
#                            'was sparkly clean and extremely well maintained '
#                            '<br/>The location is simply superb, Judy few '
#                            'blocks from the major train stations and subway, '
#                            'limitless options of places where to go to eat, '
#                            'shops, coffees shops, very cute cafes etc '
#                            'etc.<br/>Also the Hudson Yard mall is Just few '
#                            'minutes away by walk <br/>The host, Slavy is the '
#                            'perfect host! <br/>From the very first inquire to '
#                            'the check out process he was always available and '
#                            'very through <br/>This is probably the best Airbnb '
#                            'I’ve been so far!'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1051484325095337577',
#                'date': Timestamp('2023-12-21 00:00:00'),
#                'reviewer_id': '167803739',
#                'reviewer_name': 'Dan',
#                'comments': 'Close to everything. Was able to walk to Central '
#                            'Park, Times Square, Rockefeller Center, and the '
#                            'Edge Observation Deck. 2Bros pizza is a 2min walk. '
#                            '<br/>Slavy is an excellent host and would '
#                            'definitely stay here again. The building was very '
#                            'quiet at night even being in the heart of the '
#                            'city. <br/>Thank you for everything Slavy you’re '
#                            'the best!'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1055161014901138364',
#                'date': Timestamp('2023-12-26 00:00:00'),
#                'reviewer_id': '14959486',
#                'reviewer_name': 'Sharon',
#                'comments': 'The house is very clean and tidy. The kitchen is '
#                            'amazing and it is nice for us to cook a Xmas '
#                            'dinner! The toilets are very clean except the '
#                            'showers are not strong enough.<br/>It nears the '
#                            'main street and we found it very convenient to buy '
#                            'food / walk to the timesquare /shopping '
#                            'around.<br/>We also asked for one more extra bed '
#                            'as we have 6 people in total and Slavy prepared us '
#                            'a queen-sized blowing matress which gave us a '
#                            'wonderful night.'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1062351069567286172',
#                'date': Timestamp('2024-01-05 00:00:00'),
#                'reviewer_id': '134117379',
#                'reviewer_name': 'Linda',
#                'comments': 'It is well located, right next to a small '
#                            'deli/grocery store offering many basic amenities, '
#                            'open 24/7. The inside of the appartment and its '
#                            'location is exactly like the pictures. Everything '
#                            'is clean, and the place is well equipped. Slavy is '
#                            'an efficient host, answering all of my questions, '
#                            'no matter the time of the day.'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1069695230237994121',
#                'date': Timestamp('2024-01-15 00:00:00'),
#                'reviewer_id': '286397784',
#                'reviewer_name': 'Caleb',
#                'comments': 'Great place to stay and close to Times Square. '
#                            'Slavey very helpful and responds quickly.'},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1080720409951354335',
#                'date': Timestamp('2024-01-30 00:00:00'),
#                'reviewer_id': '20534917',
#                'reviewer_name': 'Roxane',
#                'comments': "We were in New York for 3 days for work. Slavy's "
#                            'apartment was perfect for my colleague and me. Two '
#                            'spacious bedrooms, larger than some hotels in NY, '
#                            'two bathrooms, one of which was directly in the '
#                            'bedroom. Both bathrooms were renovated with modern '
#                            'taste. The apartment was large for NY standards '
#                            'and equipped with everything necessary. The '
#                            'kitchen was functional.<br/>We had an unexpected '
#                            'situation and had to leave earlier than planned. '
#                            'Slavy immediately responded to messages, and we '
#                            'were able to discuss over the phone. He was '
#                            'understanding and handled the situation very well. '
#                            "<br/>I highly recommend Slavy's appartement."},
#               {'listing_id': '1028444698699878344',
#                'review_id': '1087775005025506615',
#                'date': Timestamp('2024-02-09 00:00:00'),
#                'reviewer_id': '297692974',
#                'reviewer_name': 'Chris',
#                'comments': 'Slavy was great from the moment I booked my stay. '
#                            'He got us in early, gave very clear instructions, '
#                            'and was super responsive. Highly recommend this '
#                            'spot for a genuine NYC experience. <br/>Really '
#                            'cool bathroom area. Kitchen fully stocked with '
#                            'dishes and cookware. Nice big mirrors in the '
#                            'bedrooms. <br/>Also a really cool deli right '
#                            'beneath the apartment!'}]},
#  {'id': '1008184314665292948',
#   'name': 'Rental unit in New York · 3 bedrooms · 5 beds · 2 baths',
#   'host_id': '521756969',
#   'host_name': 'Rienne',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Harlem',
#   'latitude': 40.79916,
#   'longitude': -73.9421,
#   'room_type': 'Entire home/apt',
#   'price': 150.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 325,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c2'),
#   'reviews': {}},
#  {'id': '1050067537509382432',
#   'name': 'Rental unit in New York · ★New · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '61391963',
#   'host_name': 'Stay With Vibe',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.76969,
#   'longitude': -73.95859,
#   'room_type': 'Entire home/apt',
#   'price': 75.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': Timestamp('2024-01-28 00:00:00'),
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 130,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 1,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c3'),
#   'reviews': [{'listing_id': '1050067537509382432',
#                'review_id': '1079018969768316366',
#                'date': Timestamp('2024-01-28 00:00:00'),
#                'reviewer_id': '464924370',
#                'reviewer_name': 'Matthew',
#                'comments': 'Thank you for the stay, we enjoyed the place very '
#                            'much and it’s always great time living in the '
#                            'upper east side'}]},
#  {'id': '1056192637030192096',
#   'name': 'Rental unit in New York · ★New · Studio · 2 beds · 1 bath',
#   'host_id': '224733902',
#   'host_name': 'CozySuites Copake',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.77043,
#   'longitude': -73.95679,
#   'room_type': 'Entire home/apt',
#   'price': 68.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 8,
#   'availability_365': 272,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c4'),
#   'reviews': {}},
#  {'id': '1081977194515794377',
#   'name': 'Rental unit in New York · ★New · 1 bedroom · 1 bath',
#   'host_id': '235205106',
#   'host_name': 'Desara',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Gramercy',
#   'latitude': 40.737854,
#   'longitude': -73.984215,
#   'room_type': 'Entire home/apt',
#   'price': 150.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 164,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c5'),
#   'reviews': {}},
#  {'id': '1084121726692781496',
#   'name': 'Condo in Brooklyn · ★New · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '692628',
#   'host_name': 'Max',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.69564,
#   'longitude': -73.948364,
#   'room_type': 'Entire home/apt',
#   'price': 120.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 36,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c6'),
#   'reviews': {}},
#  {'id': '1052259410309987157',
#   'name': 'Rental unit in New York · ★New · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '415840703',
#   'host_name': 'Anyplace',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.741405,
#   'longitude': -73.994,
#   'room_type': 'Entire home/apt',
#   'price': 115.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 35,
#   'availability_365': 345,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   '_id': ObjectId('6658d7d82d77bbd68b5906c7'),
#   'reviews': {}}]

# %% [markdown]
# <span style=color:blue>Sanity check, that we did not lose any listings </span>

# %%
print(len(dict_ljr10_new))
# Out:
# 3313

# %% [markdown]
# <span style=color:blue>Now loading dict_ljr10_new into mongodb.   </span>
#
# <span style=color:blue>The loading is done 100 documents at a time, with a last small lot </span>

# %%
print(len(dict_ljr10_new) % 100)
print(len(dict_ljr10_new))
# Out:
# 13
# 3313

# %%
# CAUTION: the first step here erases db.listing
#    I have kept this here during testing
db.listings.drop()


listings = db.listings

time0 = datetime.now()
time1 = datetime.now()

for i in range(0,33):
# for i in range(0,10):
    result = listings.insert_many(dict_ljr10_new[100*i:100*(i+1)])

    time2 = datetime.now()
    time_taken = util.time_diff(time1,time2)
    print('Have now completed step number:', str(i), 'and it took', str(time_taken), 'seconds' )
    time1 = datetime.now()
    
time3 = datetime.now()


print('\nThe last ObjectID in the collection is:')
print(result.inserted_ids[-1:])

# print('\nThe time to do the load of 39K documents into local mongodb, with a total of about 300MB was:')
print('\nThe time for this run was:')
print(util.time_diff(time0,time3))



# this is for the last 13 records in dict_ljr10_new, but built for arbitrary number of records
result = listings.insert_many(dict_ljr10_new[3300:])


print('\nThe total number of documents in the collection db.listings is now:')
print(listings.count_documents({}))

print('\nLast few ObjectIds of result for the last run was:')
print(result.inserted_ids[-5:])

print('\nThe last few documents of result for the last run was:')
# Curiously, the next line fetches only the object ids, not the full documents
# out = listings.find({'_id' : {'$in' : result.inserted_ids[-5:]} } )
# pprint.pp(out)
outdocs = []
for o in result.inserted_ids[-5:]:
    outdocs.append(listings.find_one({ '_id': o}))
pprint.pp(outdocs)
# Out:
# Have now completed step number: 0 and it took 0.103784 seconds
# Have now completed step number: 1 and it took 0.026726 seconds
# Have now completed step number: 2 and it took 0.004255 seconds
# Have now completed step number: 3 and it took 0.007909 seconds
# Have now completed step number: 4 and it took 0.005486 seconds
# Have now completed step number: 5 and it took 0.021856 seconds
# Have now completed step number: 6 and it took 0.01311 seconds
# Have now completed step number: 7 and it took 0.015675 seconds
# Have now completed step number: 8 and it took 0.00939 seconds
# Have now completed step number: 9 and it took 0.00479 seconds
# Have now completed step number: 10 and it took 0.031557 seconds
# Have now completed step number: 11 and it took 0.008377 seconds
# Have now completed step number: 12 and it took 0.017266 seconds
# Have now completed step number: 13 and it took 0.002597 seconds
# Have now completed step number: 14 and it took 0.004067 seconds
# Have now completed step number: 15 and it took 0.00349 seconds
# Have now completed step number: 16 and it took 0.007656 seconds
# Have now completed step number: 17 and it took 0.007409 seconds
# Have now completed step number: 18 and it took 0.010506 seconds
# Have now completed step number: 19 and it took 0.004798 seconds
# Have now completed step number: 20 and it took 0.005944 seconds
# Have now completed step number: 21 and it took 0.030821 seconds
# Have now completed step number: 22 and it took 0.004654 seconds
# Have now completed step number: 23 and it took 0.014761 seconds
# Have now completed step number: 24 and it took 0.007933 seconds
# Have now completed step number: 25 and it took 0.003796 seconds
# Have now completed step number: 26 and it took 0.003816 seconds
# Have now completed step number: 27 and it took 0.02178 seconds
# Have now completed step number: 28 and it took 0.008677 seconds
# Have now completed step number: 29 and it took 0.02098 seconds
# Have now completed step number: 30 and it took 0.011118 seconds
# Have now completed step number: 31 and it took 0.056669 seconds
# Have now completed step number: 32 and it took 0.033729 seconds
#
# The last ObjectID in the collection is:
# [ObjectId('6658d7d82d77bbd68b5906ba')]
#
# The time for this run was:
# 0.53729
#
# The total number of documents in the collection db.listings is now:
# 3313
#
# Last few ObjectIds of result for the last run was:
# [ObjectId('6658d7d82d77bbd68b5906c3'), ObjectId('6658d7d82d77bbd68b5906c4'), ObjectId('6658d7d82d77bbd68b5906c5'), ObjectId('6658d7d82d77bbd68b5906c6'), ObjectId('6658d7d82d77bbd68b5906c7')]
#
# The last few documents of result for the last run was:
# [{'_id': ObjectId('6658d7d82d77bbd68b5906c3'),
#   'id': '1050067537509382432',
#   'name': 'Rental unit in New York · ★New · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '61391963',
#   'host_name': 'Stay With Vibe',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.76969,
#   'longitude': -73.95859,
#   'room_type': 'Entire home/apt',
#   'price': 75.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2024, 1, 28, 0, 0),
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 130,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 1,
#   'license': '',
#   'reviews': [{'listing_id': '1050067537509382432',
#                'review_id': '1079018969768316366',
#                'date': datetime.datetime(2024, 1, 28, 0, 0),
#                'reviewer_id': '464924370',
#                'reviewer_name': 'Matthew',
#                'comments': 'Thank you for the stay, we enjoyed the place very '
#                            'much and it’s always great time living in the '
#                            'upper east side'}]},
#  {'_id': ObjectId('6658d7d82d77bbd68b5906c4'),
#   'id': '1056192637030192096',
#   'name': 'Rental unit in New York · ★New · Studio · 2 beds · 1 bath',
#   'host_id': '224733902',
#   'host_name': 'CozySuites Copake',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.77043,
#   'longitude': -73.95679,
#   'room_type': 'Entire home/apt',
#   'price': 68.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 8,
#   'availability_365': 272,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': {}},
#  {'_id': ObjectId('6658d7d82d77bbd68b5906c5'),
#   'id': '1081977194515794377',
#   'name': 'Rental unit in New York · ★New · 1 bedroom · 1 bath',
#   'host_id': '235205106',
#   'host_name': 'Desara',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Gramercy',
#   'latitude': 40.737854,
#   'longitude': -73.984215,
#   'room_type': 'Entire home/apt',
#   'price': 150.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 164,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': {}},
#  {'_id': ObjectId('6658d7d82d77bbd68b5906c6'),
#   'id': '1084121726692781496',
#   'name': 'Condo in Brooklyn · ★New · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '692628',
#   'host_name': 'Max',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.69564,
#   'longitude': -73.948364,
#   'room_type': 'Entire home/apt',
#   'price': 120.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 1,
#   'availability_365': 36,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': {}},
#  {'_id': ObjectId('6658d7d82d77bbd68b5906c7'),
#   'id': '1052259410309987157',
#   'name': 'Rental unit in New York · ★New · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '415840703',
#   'host_name': 'Anyplace',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.741405,
#   'longitude': -73.994,
#   'room_type': 'Entire home/apt',
#   'price': 115.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': None,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 35,
#   'availability_365': 345,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': {}}]

# %% [markdown]
# <span style=color:blue>Here is a query testing against the 'last_review' values    </span>

# %%
cursor = listings.find( { 'last_review' : { '$lte' : datetime(2024,1,1,0,0,0,0)}})
l = list(cursor)
print(len(l))
# pprint.pp(l)
# Out:
# 449

# %% [markdown]
# <span style=color:blue>Interestingly, you cannot write the dictionary we created out to a json file...     </span>

# %%
def write_dict_to_json(dict, filename):
    with open(filename, 'w') as fp:
        json.dump(dict, fp)

try:
    filename = 'listings_with_reviews_embedded__v01.json'
    write_dict_to_json(dict_ljr10_new, filename)
except Exception as e:
    print('\nThere was an error, as follows:')
    print(e)
    print()

# There are some suggestions at
#   https://stackoverflow.com/questions/50404559/python-error-typeerror-object-of-type-timestamp-is-not-json-serializable
# Out:
# There was an error, as follows:
# Object of type ObjectId is not JSON serializable

# %% [markdown]
# <span style=color:blue>Query 1: How many listings have last_review between February 1, 2021, and March 15, 2023 </span>
#
# <span style=color:blue>Note: to include March 15, 2023, you should use <= 2023-03-16 00:00:00</span>

# %%
cursor = listings.find( { '$and' : [{ 'last_review' : {'$gte' : datetime(2021,2,1,0,0,0,0)}},
                                    { 'last_review' : {'$lte' : datetime(2023,3,16,0,0,0,0)}}
                                    ]
                         })
                                        
l = list(cursor)
print(len(l))
# Out:
# 31

# %% [markdown]
# <span style=color:blue>Query 2: How many listings have an array of reviews with length at least 50? </span>
#
# <span style=color:blue>Can take inspiration from https://stackoverflow.com/questions/41918605/mongodb-find-array-length-greater-than-specified-size</span>

# %%
# counting starts at 0
cursor = listings.find( { 'reviews.49' : { '$exists': True} } )
l = list(cursor)
print(len(l))
# Out:
# 108

# %% [markdown]
# <span style=color:blue> Query 3: Output is the number of listings that have a review containing the word "awesome" (case sensitive) OR a review containing the word "amazing" (case sensitive).  </span>
#
# <span style=color:blue> Query 4: Output is the number of listings that have a review containing the word "awesome" (case insensitive) OR a review containing the word "amazing" (case insensitive).  </span>

# %%
cursor = listings.find( { '$or' : [ {'reviews.comments' : { '$regex':  '^.*awesome.*$' , '$options': 'i'  } } ,
                                    {'reviews.comments' :  { '$regex':  '^.*amazing.*$' , '$options': 'i'    } }
                                  ]
                        }
                      )
l = list(cursor)
print(len(l))
i = 0
for d in l[0:5]:
    i += 1
    print('\nReviews for listing number', i)
    for r in d['reviews']:
        pprint.pp(r['comments'])
# Out:
# 384
#
# Reviews for listing number 1
# ('Honestly Amazing Host Very Helpful And Responsive And Accommodating! The '
#  'Apartment Was Clean And Included Toiletries/Amenities! Parking Was Very Easy '
#  'To Find Which Was Great! I Would Definitely Recommend Booking Here!!')
#
# Reviews for listing number 2
# 'A really nice place in a useful location.'
# 'An attractive apartment in a great location.'
# ('Beautiful appt., lovely neighbourhood. Everything as described, only better. '
#  'Will be staying again hopefully!\r'
#  '<br/>')
# 'Awesome! Recommended.'
# 'LOVE IT!!!'
# 'Very comfortable, characterful apartment in a great location in Greenpoint!'
# ('Had a great stay arranged at the last minute.  Very responsive host, stylish '
#  'apartment, and great location.')
# ('Great!  Maya is very kind and accommodating. Her place was perfect for our '
#  'stay, very cozy and well situated.  ')
# ('Accurately described place, stylish and in a great location. Maya was '
#  'responsive and friendly. We had a great stay and would highly recommend!')
# ('Maya’s place was amazingly well located and she couldn’t have been more '
#  'communicative and accommodating. Would recommend to any young people '
#  'visiting.')
# ('This is a lovely apartment in a great part of town.  It was uncluttered but '
#  'had everything I needed.  On my arrival, the place was spotless.  i would '
#  'definitely stay here again.')
# ("Loved Maya's duplex in Brooklyn! When I was researching properties in New "
#  'York and Brooklyn for my trip, my top priorities were inspiring interiors, '
#  'great neighborhood restaurants and shops, and safe location since I was '
#  'travelling alone. I was very pleased on all counts.\r'
#  '<br/>\r'
#  '<br/>Maya gave wonderful suggestions on transportation, restaurants, organic '
#  'food shops, and businesses in Greenpoint that she hand wrote on a map. The '
#  'ferry from India Street took 10 minutes to get to 34th Street in Manhattan, '
#  'and the taxi ride to and from La Guardia Airport about 20 minutes. \r'
#  '<br/>\r'
#  "<br/>Five Leaves Restaurant & Bar and Paulie Gee's for pizza were great "
#  'recommendations. Also had a great Sunday brunch at Lokal. Enjoyed shopping '
#  "at Le Grenier, Maya's antiques shop on Greenpoint Avenue, which is as "
#  'inspiring as her apartment. I look forward to exploring more of this area on '
#  'my next trip to New York')
# ("My friend Jenny and I stayed at Mayas place for two weeks. The stay couldn't "
#  'have been nicer. The apartment is very nice and clean and well equipped, the '
#  'neighborhood is fantastic and Maya was a great host. She was very '
#  'accommodating and helpful. We will return! And we can definitely recommend '
#  'staying at Mayas place.')
# ("Maya's appartement is an amazing duplex so close to Greenpoint station and "
#  'the Greenpoint Ferry Pier. We had an excellent time there and had real fun '
#  'discovering the many artefacts decorating this beautiful little home away '
#  'from home.\r'
#  '<br/>\r'
#  "<br/>Getting to the city is always more fun using the Ferry, they're about "
#  '30 minutes appart south and northbound at the India St/Greenpoint ferry '
#  'stop. The stop is at a 5/8 min walk from the appartement.\r'
#  '<br/>\r'
#  '<br/>We will go again !')
# ('The apartment was just perfect, we felt at home, so cozy and nicely '
#  'decorated! Great neighborhood (ferry, bars, shops, bike rental..)\r'
#  '<br/>We highly recommend this great place!')
# ("Great place in a great neighborhood! I couldn't of asked for a better first "
#  "airbnb experience. I highly reccomend Maya's beautiful duplex and would stay "
#  'here again in an instant! ')
# ('Maya was very responsive to emails and requests.  The space is spacious.  '
#  'The bedroom is located in the basement which is something that we were '
#  'unaware of but otherwise, the place is good stay!')
# ("Maya's apartment was exactly what it looked like in the pictures. "
#  'Beautifully furnished and very well taken care of. It was quite clean, what '
#  'we appreciated a lot, and had everything we needed, like kitchen supplies, '
#  'comfy towels and bedsheets.  The location is also very good, close to '
#  'subways and to the India Ferry (very fun to ride in sunny days). Thanks a '
#  'lot Maya!')
# ("We spent 8 nights in Maya's lovely apartment and had a wonderful time. It "
#  'was really spacious, beautifully decorated and in a great location close to '
#  'the Subway, lots of shops and bars and restaurants. We saw Maya a few times '
#  'and she was the perfect host, very warm and welcoming and left a really '
#  'useful list of nice places to eat/drink/shop and hang out around '
#  'Greenpoint. \r'
#  '<br/>\r'
#  "<br/>We would highly recommend Maya's place to anyone.\r"
#  '<br/>\r'
#  '<br/>Thanks Maya! \r'
#  '<br/>\r'
#  '<br/>Mary and Jop x')
# ('Our stay at the one bedroom apartment hosted by Maya M. in Greenpoint, '
#  'Brooklyn, was excellent. The apartment is clean and stylish and the '
#  'neighborhood is charming and safe. We cooked several meals in the small '
#  'kitchen and found it had all the basics needed to get the job done well. '
#  'Maya was responsive and easy to deal with and everything was done as '
#  'promised. We would definitely stay there again. ')
# ('It was a great pleasure to stay at Mayas apartment. The rooms were lovely '
#  'decorated and it was quiet enough space for us three. For us three the 65 m² '
#  'are just perfect. Maya left us some nice cards with the best places around. '
#  'The Five leaves is your tip for a lovely breakfast and some nice supper. '
#  'Lots of great stores and shops are literately around the corner and the area '
#  'is really safe. It is only a short trip to Manhattan or a short walk to '
#  'Williamsburg. \r'
#  '<br/>It was really a lovely time at Mayas place! Thank you a lot!')
# ('\r'
#  '<br/>Beautiful and well located apartment. The street is very quiet. Many '
#  'shops around... And Maya is very nice. We had a very good time.\r'
#  '<br/>\r'
#  '<br/>Cet appartement est très joli et bien équipé, dans une rue calme. '
#  'Quartier commerçant. Maya est très disponible. Nous avons passé une semaine '
#  'agréable.')
# ('Lovely place, great location, Maya was super helpful - perfect place to stay '
#  'in NY - a bargain! ')
# ("I didn't get to meet Maya in person during my stay, but she was great about "
#  'communicating quickly through email and text. Check-in/check-out was easy - '
#  'Maya worked hard to accommodate our schedule, which was nice of her. The '
#  'duplex was super cute and clean, just like in the pictures. The neighborhood '
#  'was quiet and residential, but if you walk over a block or two, you reach '
#  'main roads w/ lots of delis/places to eat. The subway stop for the G line is '
#  "very close by so you're only a short walk away from getting to where you "
#  'want to go in the city.\r'
#  '<br/>\r'
#  '<br/>Overall, I had a great stay here. The Greenpoint area really made me '
#  'fall in love with Brooklyn as a whole. Maya left us a map/list of '
#  'suggestions for places to eat/visit in the neighborhood and she was spot on. '
#  "I'd love to come back and stay here on a future visit. Thanks, Maya!")
# ("My boyfriend and I stayed in Maya's lovely apartment for a week. The "
#  'apartment was very clean and comfortable, and it was great to be provided '
#  'with a map with a few suggestions of eateries/shops/bars.\r'
#  '<br/>The location was excellent-an easy 5min walk to the subway (Greenpoint '
#  "Ave), and even closer to the bus. It's fantastic being so close to a strip "
#  'of shops with cafes, restaurants and grocery stores.\r'
#  "<br/>Key pick up and drop off was a breeze, and we didn't have any issues "
#  'throughout our stay.\r'
#  '<br/>We look forward to staying here again!')
# ('The apartment was lovely and well located in Greenpoint, close to '
#  'Williamsburg, on a quiet tree lined street. It was also really close to '
#  'Greenpoint Ave subway. Maya was only a call away if required but we did not '
#  'really need to. Thank you Maya, we had an amazing week. We were sad to leave '
#  'Greenpoint/Williamsburg, it was such a friendly place.')
# ("Maya's apartment was perfect. Clean, elegantly decorated and in a fantastic "
#  'position. We loved Greenpoint and the kitchen was great with everything you '
#  "need in case you stay in one night. Although it's not likely with such great "
#  "food at your doorstep. Make sure to try Paulie Gee's for fantastic pizza.\r"
#  '<br/>thanks Maya')
# ('A fabulous apartment in a fabulous location, Greenpoint and Williamsburg on '
#  'your doorstep and Manhattan very close by.  Maya was easy to communicate '
#  'with and her instructions were easy to follow.  We would stay here again.  ')
# ("We had a wonderful stay at Maya's apartment. It's a great space with "
#  'everything you need. Perfect location! She was so accommodating. We would '
#  'definitely stay there again.')
# ('The apt. is perfect to get to know Greenpoint and Williamsburg, wonderful '
#  'cafes and restaurants are nearby. The duplex was clean with nice vintage '
#  'furniture as shown on the photos. Our only point of critique was the '
#  'bedroom, which was a little bit too cold and noisy (heating tube) for us, '
#  'but  in summary we would definately come back again!')
# ('A lovely and stylish apartment in a great part of Brooklyn, felt like home '
#  'after a couple of days. Away from the bustle of Manhattan and only 15 '
#  'minutes away on the subway, (Greenpoint Ave. station is around the '
#  'corner). \r'
#  '<br/>Greenpoint is a nice area with some great neighbourhood restaurants and '
#  'bars, for great shopping head to Bedford Avenue. \r'
#  '<br/>Maya was very easy to communicate with and the process was very '
#  'straightforward. Would stay here again. Thanks Maya!\r'
#  '<br/>')
# ('We had an excellent stay at Maya"s.  Very good restaurants,  bars, and '
#  'grocery stores within walking distance.  The atmosphere of the neighborhood '
#  'was wonderful.  Very friendly people. The apartment was beautiful and  we '
#  'would highly recommend it.  The subway connection very close as well.')
# ("When my mum and I was planning our trip to New York we didn't want to live "
#  'in Manhattan and so we found this great apartment! The apartment was very '
#  'nice in a quiet street and we fell in love with the neighborhood. The only '
#  "complaint was that the apartment was really hot and we couldn't really "
#  'figure out how the heaters worked. Other than that we had a great stay! ')
# ("Enjoyed our week long stay at Maya's apartment. Large, well equipped and "
#  'clean space to come home to after a day of touring around New York. Also '
#  'enjoyed the cute antiques decorating the place, made it feel more homely. '
#  'Maya was easy to contact when we needed her and left us a wonderful guide to '
#  'the local area- which we checked out a lot! Just a short  20 minute commute '
#  'into central manhattan via subway but also a great excuse to explore '
#  'Brooklyn (and more specifically Greenpoint). Would recommend highly. ')
# ('the loft was quiet charming,clean with vintage furniture.There was a bed for '
#  'a couple downstair, and a sofa bed quiet confortable in the living room. The '
#  'street was charming , near the subway and not far from Bedford street. But '
#  'you need half an hour to reach center of Manhattan. ')
# ("Maya's place was a joy to stay at. Everything about the stay was lovely. The "
#  'house had everything we needed and was a relief to come back to at night. '
#  'Maya was really kind and communicative. The house housed three of us really '
#  'comfortably — no door from the bedroom, just stairs, but I slept on the sofa '
#  'and it was cosy and nice. I really enjoyed the Greenpoint area.')
# ("Maya's apt. was a great place for my Father to stay.  It was a beautiful  "
#  "place, and the greenpoint neighborhood was perfect for my Dad.  Maya's place "
#  'comes highly recommended from My Dad and I.')
# ('This place is wonderful, exactly as it looks in the photos and Greenpoint is '
#  "a very cool neighborhood! I will be coming back next time I'm in NYC\r"
#  '<br/>Thanks Maya! ')
# ('The duplex was great - spacious & clean with a wonderful layout and '
#  'location.  Maya was extremely responsive and accommodating and everything '
#  "went like clockwork.  Highly recommended!  I'd definitely stay here again!")
# ('Great location, easy to find! Greenpoint has free street parking & I only '
#  'had to move the car once over a 5 day stay. Maya made a map with a guide to '
#  'the neighbourhood which came in use many times. Will definitely stay here '
#  'again on our next visit to NYC.')
# ('Appartement plein de charme bien situé dans un quartier agréable plein de '
#  'commerces et proche du métro. Idéal pour un séjour à 4, la chambre donne '
#  "cependant sur la rue qui heureusement n'est pas très bruyante. ")
# ('Great location (well for us anyways), nice and quiet and Maya was very easy '
#  'to deal with. Keen to check out her other offerings on our next jaunt :)')
# ('The apartment looks just like the pictures... quaint and cosy, in a up and '
#  'coming part of Brooklyn. It is conviently located to Williamsburg. Bedford '
#  'ave, is only a 15 minute walk away. However the G line that takes you into '
#  "Manhatten isn't the most convnient line, with no express  connection into "
#  'the city. \r'
#  '<br/>\r'
#  '<br/>Only a few negatives about the apartment and that is the fact it '
#  "doesn't really sleep 4 adults comfortably. The sofa bed is more of a large "
#  'single than a double. Also with the weather not being great the apartment '
#  'was a little cold. \r'
#  '<br/>\r'
#  "<br/>Overall we had a plesant stay. If you're looking for a mod cons "
#  "apartment this isn't for you. But for a trendy, well located spot -  its "
#  'perfect. ')
# ('The duplex is in a great location in Greenpoint, a quiet tree-lined street, '
#  'just off the main drag for shops and near excellent restaurants.  The '
#  'kitchen is well stocked, and the upstairs is light and airy.  The bathroom '
#  'is good sized and, amazingly, there is enough shelf space for 3 people to '
#  "put their toiletry kits, hairdryers, etc.   There's a huge closet downstairs "
#  'so everything from suitcases can be hung up.  Very convenient, clean and we '
#  'had a wonderful time!  ')
# ('We had a great stay in Brooklyn. The duplex is very nice. The neighbourhood '
#  'is quiet and safe and there are many bars and restaurants at a few min. '
#  'walk. Maya is a great host.')
# ('We had a great week in New York and the appartment was perfect. Just '
#  'everything you need and greenpoint is really nice. If you want to go to '
#  'manhattan you can just take the subway after a short walk. Maya responded '
#  'very quickly and the appartment was clean, so we would definitely reccomend '
#  'this one!')
# ('Great place to stay in Brooklyn! Check in and out was easy and the loft is '
#  'decorated beautifully. The location is wonderful, lots of amazing '
#  'restaurants within walking distance and close to the subway. Maya was quick '
#  'to respond to emails and had great recommendations on restaurants in the '
#  'neighborhood. It was a great experience. ')
# ('This apartment is a wonderful base to explore Brooklyn and Manhattan from - '
#  "cosy and stylish, it's in a funky area full of cafes, Polish restaurants and "
#  'cool shops. The ferry across to Manhattan is quick and easy (cab fares back '
#  "surprisingly cheap) and Maya's map full of suggestions was absolutely "
#  "invaluable - our stay wouldn't have been the same without it. As all the "
#  'other wonderful reviews attest, this really is a great choice when headed to '
#  'New York. ')
# ("My cousin and I enjoyed the quiet neighbourhood with it's easy access by "
#  'ferry to Manhattan. We were out most of the day so found it relaxing to get '
#  'back to a bit of peace and quite. The list of amenities that Maya leaves for '
#  'guests was very helpful and we tried out some very good local cafes.')
# ('Maya is super responsive - prompt and accommodating to our inquiries and '
#  'requests. Great location - quiet street, yet close to shopping and eating. '
#  "Everything is within a 10 - 20 minute walk.  If you're into cycling, highly "
#  'recommend renting or bringing a bike which will get you around more quickly '
#  'than the subway. You can pick up a free NYC bike map from any bike shop.')
# ('The apartment was great and had everything we needed (plus an orange couch '
#  'we craved).  Maya was very nice and organized in her communications.  Even '
#  'though she was out of town, she made sure to stay in touch.  Also, when a '
#  'friend from the neighborhood stopped by, he admired the annotated map Maya '
#  'had left as hitting all the right notes!\r'
#  '<br/>  ')
# ('Maya’s apartment is lovely and full of light.  The kitchen is spacious and '
#  'has everything you need.  The bathroom is roomy.  The sleeping arrangement '
#  'fits three people comfortably.  The location is very convenient, close to '
#  'Manhattan and only three blocks away from the subway station.  The '
#  'neighborhood is beautiful, safe and peaceful.  It has everything you may '
#  'need just steps away.  Maya prepared a detail map of the neighborhood that '
#  'was very useful.  The ferry ride was fun.  Maya is a friendly host and '
#  'answers any question diligently.  We had a great time!  Thank you Maya!')
# ('The apartment was great. Everything you need. Easy walking distance to '
#  'Williamsburg and steps away from the amenities of Greenpoint PLUS the '
#  'subway. \r'
#  '<br/>Brooklyn is a fab alternative to the altogether busier and more '
#  'hectic/over-priced Manhattan. As a past resident of the city I always prefer '
#  'to stay in this area (bo wszystko jest po polsku!).\r'
#  '<br/>I will definitely stay with Maya again and highly recommend to anyone '
#  'considering one of her apartments.\r'
#  '<br/>')
# ("Cute apartment, great location.  Stayed in Brooklyn to attend my sister's "
#  'wedding but this was a perfect location for any trip to NY. Lots of great '
#  'local spots nearby and easy walk to the subway and into the city.  Maya is a '
#  'great host and given my experience, I would not hesitate reccommending any '
#  'of her apartments.')
# ('The apartment was attractive and clean. Maya made our stay very comfortable '
#  'and was available for questions if we had any. The apartment is located in a '
#  'beautiful tree lined street. We were able to explore a variety of '
#  'restaurants and had simple access to Manhattan. Highly recommended!')
# ("It's a cosy Duplex with everything you could need and the street is nice and "
#  'quiet.\r'
#  '<br/>')
# ('Cute space, near the train and some cute areas.  Would definitely rent from '
#  'Maya again if we visit Brooklyn again!')
# ('Just had a wonderful month long stay in this cute cosy flat. The area felt '
#  'very safe and everything you could want only a short walk away.Very easy '
#  'access to Manhattan.\r'
#  '<br/>The apartment  has loads of character and the photos are very '
#  'accurate.\r'
#  '<br/>Only reason I did not give 5 stars was because we had no control over '
#  'the heating but having said that we were never cold! \r'
#  '<br/>All in all a very good value little apartment which we can highly '
#  'recommend .')
# ('this is  a lovely little apartment. nicely furnished and comfortable. so '
#  'much better than staying in a hotel!\r'
#  '<br/>greenpoint is  a great area, with plenty of cool independent boutiques '
#  'and places to eat. its a short walk to wiliamsburg and the east river ferry '
#  'stops nearby which is a brilliant way to get around.\r'
#  '<br/>maya was friendly and helpful, i would totally recommend staying here!')
# ('Maya was a great host. Her  communication was excellent and she was very '
#  'accommodating.  Her duplex worked well for our needs. The location could not '
#  'be better. The space was quiet, clean, bright and well organized. \r'
#  '<br/>\r'
#  '<br/>The only drawback for us was having to navigate the narrow spiral '
#  'staircase with 2  younger children. We managed it without incident and other '
#  'than that the experience was perfect.\r'
#  '<br/>\r'
#  '<br/>Thank you, Maya.')
# ('Maya was very helpful and friendly, and the apartment was so very nice.  '
#  'Great location, and airy and uncluttered - though very well equipped with '
#  'everything we needed.  A great host and a lovely place to stay in Brooklyn!')
# ('this is a very comfortable space to stay. Maya was very responsive to my '
#  'questions and when we arrived there was a helpful map with recommended spots '
#  '/ activities. Greenpoint is a great and centralized location to reach much '
#  "of NY. I hope to stay at one or more of Maya's other properties someday if I "
#  "don't move to Brooklyn first.\r"
#  '<br/>')
# ("I have stayed in Maya's properties several times. She is always helpful, "
#  'diligent, and responds promptly. The two properties that I have stayed in '
#  'are very comfortable and just as described. Thanks again Maya!')
# ("everything was great, we loved staying at Maya's place! her map with "
#  'suggestions of places to go was amazing! specially the polish bakery and '
#  "Paulie Gee's Pizza")
# ("I didn't expect to spend so much time in Greenpoint, however after falling "
#  "in love with Maya's apartment, and then discovering the incredible "
#  'neighborhood around it, even Williamsburg seemed like a stretch.\r'
#  "<br/>Breakfast at Five Leaves, donuts at Peter Pans, coffee at Grumpy's, "
#  "beers and burrito's at Calexico's, and incredible shopping on Franklin St!  "
#  'This Greenpoint apartment was the perfect settlement to truly discover an '
#  'amazing area, and only a two minute walk to the subway for the (surprisingly '
#  'few) times we wanted to explore elsewhere. \r'
#  '<br/>\r'
#  '<br/>Also recommend making the most of the east river ferry - a very '
#  'pleasant way to go from Greenpoint to Wall St.\r'
#  '<br/>\r'
#  '<br/>')
# ("Maya's place feels like my Brooklyn home away from home. The first time I "
#  'stayed I was with my husband and it was perfect for two.This last visit I '
#  'went by myself and wanted to be able to get up in the morning and come back '
#  'at night and be in a place that was completely comfortable , secure and '
#  "quiet. So I stayed in Maya's place again.  It's close to my favorite "
#  "restaurant Five Leaves, which is right down the street. it's a block away "
#  'from Manhattan ave which has everything you need , like a red velvet donut '
#  "from Peter Pan bakery. It's a 10 minute walk to the L that takes you right "
#  "into Manhattan .   I look forward to my next visit to Brooklyn and Maya's "
#  'place is definitely my first choice.')
# ('Mayas place was great. Really cool neighbourhood and a great place to start '
#  'discovering Greenpont. Maya was really friendly and helpful. You could not '
#  'ask for more. We definatly coming back here. Thanks!')
# ("L'appartement de Maya est charmant et très bien équipé. Beaucoup de "
#  'commerces à proximité et les transports en commun à deux coins de rue. Je '
#  'recommande vivement cette adresse. Marie\r'
#  '<br/>')
# 'Fantastic apartment! Beautifully located, very clean! '
# "Great place, cool area and the host, we'll come back!"
# ('Thank you Maya, our stay was just perfect !\r'
#  '<br/>The neighborhood is so quite and welcoming, non touristic and easy to '
#  'reach from Manhattan. Good restaurants and magical views on the Brooklyn '
#  'Bridge and on Manhattan island from East River piers.\r'
#  "<br/>For sure, when we come back to NYC, we will stay again in one of Maya's "
#  'beautiful and homy places. ')
# ('Thank you Maya for a lovely stay in Brooklyn! Loved how the basement bedroom '
#  'cooled us down on those hot nights. The trains were just a hop, skip and a '
#  'jump away. The ferry too!! And the neighborhood was charming.. shops, '
#  "restaurants, and cafes. Can't wait to visit again!!")
# ('Maya has created a wonderful piece of the world in the historic Greenpoint '
#  'Duplex. Some great vintage pieces and very comfortable. She was very '
#  "flexible with check in and the map with suggestions for cafe's, bar's and "
#  'shopping was extremely helpful for someone new to the area. Thanks Maya!')
# ("Maya has been a fantastic, really easy to get in contact even if I didn't "
#  'met her. No problem for the keys!\r'
#  '<br/>The house is very nice and clean! A bit small for three people, mainly '
#  'for the one sleeping on the sofa. Overall is very good!\r'
#  '<br/>The area is amazing!\r'
#  "<br/>Next time I'll go to NY I will contact Maya again!\r"
#  '<br/>Andrea ')
# ("My stay in Maya's apartment was smooth from start to finish. She always "
#  'replied to messages within a few hours which was most helpful given the '
#  "fairly short notice.<br/>We didn't get to meet Maya when checking in and out "
#  'but were given easy instructions to find the keys. We found the apartment '
#  'extremely clean, large (such high ceilings!) and quaint as well as superbly '
#  "located. <br/>Greenpoint is an exciting area and we used Maya's thoughtful "
#  'list of recommendation list to visit a few spots like Five Leave cafe and '
#  "Lobster Shack which were all within walking distance. Williamsburg's finest "
#  'street, Bedford Avenue was an easy 15 minute walk away and you have good '
#  'access to the G train (4 mins walk) or L train (15-20).<br/>We really hope '
#  "we can stay in one of Maya's apartments again!")
# ("Maya's place is on a quaint and lovely tree-lined street in Greenpoint.  "
#  'Inside, the furnishings were just as delightful as pictured and the living '
#  'space was actually larger than expected.  The bathroom was lovely, '
#  'especially the wide shower head! \r'
#  '<br/>\r'
#  '<br/>We found Maya very responsive and she even let us check in early, '
#  'facilitating the key transfer process with ease. \r'
#  '<br/>\r'
#  '<br/>Transportation wise, we did find that the G train (closest line to the '
#  'apartment) did not run as regularly as other trains and it also did not go '
#  'directly into Manhattan (a transfer to another train is required).  However, '
#  "we found it a pleasant walk to the L train on Bedford Ave, so this didn't "
#  'bother us too much.  \r'
#  '<br/>\r'
#  '<br/>Highly recommended!  ')
# ("Our stay in Maya's flat was very good. Greenpoint is a cool area full of "
#  "nice bars, restaurants and small shops which we could enjoy thanks to Maya's "
#  'advices. If you are planning to stay for a few days in New York I would '
#  'strongly recommend the area for two reasons: the flat is nice, roomy and has '
#  'everything you need and the area makes you feel more like a "new yorker" ( '
#  'you get to know the everyday life of the locals and is not as crowded as '
#  'Manhattan). Also the views you get from the skyline (just a few blocks away '
#  'from the flat) are amazing. And finally, getting to Midtown is very ease and '
#  'fast with the G line :)')
# ('Maya and her apartment were both great!  We had a wonderful time in '
#  'Greenpoint.  The location was perfect. We were able to walk to great '
#  'restaurants, shops and bars as well as had easy access to the L & G subway '
#  'lines and the ferry, which is a great way to get around! ')
# ('The duplex is exactly as pictured. Very clean and beautiful. Close to one of '
#  'my favorite restaurants in greenpoint, five leaves, and some really cool '
#  "bars (matchless, no name, Enid's). Maya was very helpful and made it very "
#  'easy to check in. I would definitely recommend this listing to anyone. ')
# ("Maya's Greenpoint duplex was a dream - even more beautiful than I expected. "
#  'The apartment is located in a nicer part of Greenpoint with easy access to '
#  'the G line and a short walk to McCarren Park for morning jogs. Excellent '
#  "kitchen, bathroom and laundry facilities and the bed has to be the best I've "
#  'slept in for a long time! Maya was easy to deal with and everything was '
#  'organised perfectly. I would definitely stay here again - and hopefully '
#  'soon!')
# ("It was a real pleasure to stay in Maya's appartment. A very confortable "
#  'place. We really enjoyed our trip. Besides, the area is really cool. Laurent '
#  'and Virginie from Paris.')
# ('El apartamento se encuentra ena buena ubicación, cerca de williamsburg. Es '
#  'una bonita zona con algunos buenos restaurantes cerca. Para llegar a '
#  'Manhatan hay buena conexion de metro y se llega muy rápido.Es una buena '
#  'opción si no quieres gastarte mucho dinero hospedandote en el centro de '
#  'Nueva York.')
# ('Merci Maya! We had a blast in NYC, the apartment was perfect even if we were '
#  "not there that much. Greenpoint is a must to see and it's very easy to go to "
#  'Manhattan by metro. Our coup de coeur, crossing the Brooklyn Bridge with a '
#  "CityBike :-)) To much to see in 3 day thought, we'll need to come back!!!")
# ("Maya's flat is beautiful and in a very desirable & quiet neighborhood, yet "
#  'close to a subway and within easy access by a bicycle from everywhere in '
#  'Brooklyn.')
# 'The apartment is great and in an excellent location. I would stay again. '
# ('We had a wonderful stay in Greenpoint. The duplex is lovely, and the map '
#  'Maya left of the local area was very helpful. An easy walk to the subway or '
#  'ferry and plenty of nearby shops. We had a short wait when we arrived '
#  "because we hadn't been given key instructions, but Maya was quick to get "
#  'them to us. Overall, a great stay. ')
# ('What a perfect spot! Loved the location, Greenpoint had everything you could '
#  'want and you felt like not another tourist in Manhatten. The apartment is '
#  'perfect and very well equipped. really comfy bed!\r'
#  '<br/>\r'
#  '<br/>Short walk to two subway stations that will take you into Manhatten. '
#  "Fantastic delis and bakery's on Manhatten Ave as well as some great bars and "
#  'restaurants on or just off Franklins Ave. \r'
#  '<br/>\r'
#  "<br/>Would definitely recommend Maya's apartment without hesitation. \r"
#  '<br/>\r'
#  '<br/>')
# ("I had wonderful week in Maya's appartment. The appartment is clean, safe, "
#  'spacious for two persons and exactly as shown on the photographs. The metro '
#  'is pretty close and it is fast to get to the other nice spots in NYC. \r'
#  '<br/>\r'
#  "<br/>Unfortunately i didn't have chance to meet Maya in person, but she was "
#  'so nice to explain everything per mail/messages. Thanks again for the '
#  'Greenpoint restaurant map - there are some great recommendations!\r'
#  '<br/>\r'
#  '<br/>We had a great stay! ')
# ('Very happy we made this choice.  A perfect little apartment, comfortable and '
#  'stylishly decorated.  Would def recommend.')
# ('Maya was an amazing host and her apartment was beautiful! Communication was '
#  'clear, prompt and friendly and the listing is as lovely as it looks in the '
#  'pictures and in a super convenient location for public transport. Great '
#  'cafés, bars and restaurants in the area (for Australians - there are quite a '
#  'few cafés nearby that do a killer flat white). Greenpoint is a great '
#  'neighbourhood and my new favourite place in New York!')
# ('Maya is a great, attentive host with a beautiful home. It is as wonderful '
#  '(and stylish) as the photographs depict, and is located in our favourite '
#  'part of Brooklyn. Definitely check out the recommendations Maya leaves, we '
#  'loved Peter Pan for doughnuts, Five Leaves for amazing breakfasts and retro '
#  'bowling! Thanks again, we will be back! ')
# ("Maya's place is just adorable! perfect home away from home. Everything "
#  'needed was provided & much more. She even had places recommended to go to '
#  'around the area. \r'
#  '<br/>& Maya was the best host. the easiest to communicate and very '
#  'accommodating to situations like check in and out times and luggage drop '
#  'off/pick up. \r'
#  "<br/>She makes sure you're stay is the best possible. \r"
#  '<br/>\r'
#  '<br/>Thanks Maya!')
# ('Maya and her "Sweet Historic Greenpoint Duplex were both just fantastic! '
#  "Clear instructions, lovely place, great location . . . couldn't ask for "
#  'more. Well, I did want to watch the BCS championship and, as duly noted, '
#  'there was no TV, so had to keep refreshing my browser to update the score.\r'
#  '<br/>\r'
#  "<br/>Five stars! My only regret is that I didn't stay here during two "
#  'earlier trips, when I spent two- to three-times the nightly charge on piece '
#  'of shit little hotel rooms in trendy, obnoxious hotels in Greenpoint. Never '
#  "again. This being my first real experience with Airbnb, I don't know if I'm "
#  'ever going to stay in a hotel in NYC again!')
# ("Staying in Maya's lovely little apartment for a week was great. The space is "
#  'really cute and light filled and has everything you would need. It was very '
#  'clean and Maya very generously provides any supplies you may need as well as '
#  'a very helpful guide to Greenpoint and Williamsburg.\r'
#  '<br/>Greenpoint is a wonderful neighbourhood, it feels very local whilst '
#  'still having some amazing cafes and shopping and is an easy walk to '
#  "Williamsburg. It's about a 15-20 minute subway ride to the island with one "
#  'transfer.\r'
#  '<br/>We had a freak snow storm during our stay so the basement area where '
#  'the bedroom is did get a bit cold but there is an additional heater supplied '
#  'which does warm up the space a bit. Also if you have a bulky suitcase, you '
#  'may find it difficult to get it down the little staircase but there are '
#  'cupboards provided on the top level.\r'
#  "<br/>I would definitely recommend Maya's place for anyone who wants a "
#  '"local" experience of New York. It\'s beautifully decorated and close to so '
#  'many little gems. Thanks Maya!')
# ('Was a beautiful Apartment, my two artists were very happy\r'
#  '<br/>\r'
#  '<br/>Thank you Maya for being great\r'
#  '<br/>\r'
#  '<br/>I would highly reccomend your home \r'
#  '<br/>\r'
#  '<br/>Best \r'
#  '<br/>Amie')
# ("This was my fifth time renting from Maya (if that's not a ringing "
#  "endorsement, I don't know what is!), and my first time staying in the sweet "
#  'historic duplex. It certainly was sweet, and I was more than happy with '
#  'everything. Maya is a truly wonderful host. Everything is always very clean, '
#  'comfortable and well-decorated/designed. Yet another amazing stay! I '
#  "couldn't ask for anything more.")
# ('This apartment worked out great. Loved the location, really safe and '
#  'friendly area. We would easily stay here again and recommend it to '
#  'friends. \r'
#  '<br/>')
# ('Fabulous location for subway, restaurants, coffee shops and boutiques.  The '
#  'apartment bedroom is in the lower level, accessible by a very narrow spiral '
#  'staircase. We made one trip down and up a day.  We could not navigate '
#  'luggage down there and the only bathroom is up the spiral stairs.  There is '
#  'not a microwave which would have been nice for warming leftovers and '
#  'coffee.  There is also no TV which only mattered because of the Olympics.  '
#  'Other then that, it was as described and quite charming. ')
# ("Maya 's place is our home away from home in Brooklyn. It is the sanctuary "
#  'you need after a  full day of  taking in Manhattan. We often have a meal at '
#  "Five Leaves restaurant which is about 5 blocks away and it's an easy and "
#  'picturesque walk to the subway. ')
# ("Everything was great about our stay at Maya's place. The check-in and "
#  'check-out process was smooth, the apartment was very cozy and the '
#  'neighborhood was lovely--within walking distance of the G line, restaurants, '
#  'and shops.  \r'
#  '<br/>Thanks \r'
#  '<br/>')
# ('Such a perfect space! The location is stunning, and the actual duplex is '
#  'exactly as pictured (if not better). Maya was so personable, helpful, and '
#  'flexible. She even has a map of the neighborhood with detailed '
#  "recommendations for restaurants, shops, cafe's, and activities. It's a "
#  'fairly easy commute into Manhattan on the G or L train. The walk to the L '
#  'station is a bit farther, but you get to walk past McCarren Park (a '
#  'favorite) and through the heart of Williamsburg, and the train comes much '
#  'more often. We even ended up adding an extra night to our trip, we loved it '
#  "so much! We felt absolutely at home during our stay and can't wait to come "
#  'back. ')
# ('A brilliant location in Greenpoint, Brooklyn!  After always staying in '
#  'Manhattan on previous visits to New York, we decided to try Brooklyn and I '
#  'will always stay here for future visits!  Maya was very accommodating, '
#  'especially on our late check out and her map that she provided of local '
#  'shops, restaurants and bars was excellent.  I can only highly recommend that '
#  'you stay here. ')
# ("Maya's apartment is very comfortable and we especially appreciated the nice "
#  'clean bathroom and kitchen area.  The spiral staircase to the bedroom was '
#  'not a problem for us.  This would also be a nice apartment for a lengthy '
#  'stay.  Very convenient to subway and to lots of good markets and restaurants '
#  'in the Greenpoint neighborhood.   Easy communication with Maya for arrival '
#  'and departure as well as contact number for any questions.')
# ('We had fantastic days at Brooklyn! The apartment was great: tidy and well '
#  'equipped, in an interesting neighborhood with a lot of good shops, cafes and '
#  'restaurants, close to the metro. The communication with maya was without any '
#  'problems. Thanks a lot! \r'
#  '<br/>So why should you go to NYC? Discover BROOKLYN!\r'
#  '<br/>Maya - at any time again!     ')
# ('We had a great stay. The neighbourhood is absolutely great. Brooklyn is our '
#  'new discovery. Consider renting bikes: a great way to discover Brooklyn & '
#  'Manhatten. \r'
#  '<br/>\r'
#  '<br/>Maya, thaks thanks for your hospitality and tips for the '
#  'neighbourhood!!!\r'
#  '<br/>')
# ('We had fantastic days at Brooklyn! The apartment was great: tidy and well '
#  'equipped, in an interesting neighborhood with a lot of good shops, cafes and '
#  'restaurants, close to the metro. The communication was without any problems. '
#  'Thanks a lot Maya!')
# ('The apartment was ideal for our trip. It comfortably slept 3 friends and was '
#  'really beautifully furnished and spacious. We liked it so much we all wanted '
#  "to live there.  It's set in a great location on a quiet tree lined street so "
#  'was quiet to sleep, but was literally a few blocks away from a really '
#  'bustling neighbourhood with lots of tasty restaurants and interesting '
#  "nightlilfe.  I'd definitely recommend staying, its great value for money and "
#  'Maya was at hand to answer any questions etc.  Would use this apartment for '
#  'a return visit!')
# ("Maya's apartment was really great to stay at.  It was both tasteful and "
#  'comfortable, with a location that is on a quiet street but super close to '
#  'everything.  I especially loved her hand-written notes on all the best '
#  'places to go in Greenpoint!  It was a wonderful stay.')
# ("My boyfriend and I stayed in Maya's cozy appartement for three nights! And I "
#  "wished we could have stayed even longer! We felt in love with Maya's "
#  'appartement and the neighborhood!\r'
#  '<br/>The location is very convenient, close to Manhattan and only three '
#  'blocks away from the subway station. The neighborhood is beautiful, safe and '
#  'peaceful. We felt really save there! And the area has everything you may '
#  'need just steps away. (good restaurants, bars and shopping places, nice '
#  'parks!) Maya prepared a detail map of the neighborhood that was very useful. '
#  'She was easy to deal with and everything was organised perfectly. Maya was '
#  'very responsive to emails and requests:) We had a great time! and we would '
#  'love to stay there again if we come back to NY! Thank you Maya!')
# ('Everything was absolutely wonderful!\r'
#  '<br/>The flat is decorated in a very pleasant way, the kitchen offers enough '
#  'space and everything was very clean and cosy.\r'
#  '<br/>The street is so green and charming. Just around the corner you can '
#  'find everything you need: nice cafes, bookstore, natural supermarket and '
#  'more.\r'
#  '<br/>Very nice - just 3blocks down there was our favorite restaurant: the '
#  'five leaves.')
# ('Wir haben uns bei Maya sehr wohl gefühlt. Die Wohnung ist einfach und schön, '
#  'und bietet genügend Platz für eine kleine Familie. Die Nachbarschaft ist '
#  'wirklich phantastisch und eine Entdeckung. Es war unser erster Aufenthalt in '
#  'Brooklyn und Greenpoint im besonderen, und wir würden jederzeit gerne '
#  'dorthin zurückkehren. Schöne Cafés, Restaurants und sehr besondere Läden. '
#  'Die tägliche Fahrt mit der East River Ferry nach Manhattan war jedesmal ein '
#  'Traum. Alles in allem sehr zu empfehlen!')
# ('A fantastic apartment near the heart of hipster Brooklyn which comfortably '
#  'fits two or three people. A short walking distance to subway and bus stops, '
#  'with plenty of nearby convenience stores, cute cafes and unique bars.  '
#  "Maya's place is spacious and well-kept with comfortable furniture, a clean "
#  'bathroom and a few vintage-style flourishes which make for a truly '
#  'individual experience. The apartment was very clean when we arrived and the '
#  'use of the washer and dryer ensured every part of our stay was hassle-free. '
#  'The wi-fi internet connection was very quick, though it should be noted '
#  'there is no TV in the apartment. Maya was always quick to respond to our '
#  'emails when we had any queries and was a fantastic host. I would recommend '
#  'this apartment to anyone wanting to stay a little bit away from the hustle '
#  'and bustle of the city itself, but still within easy commuting distance. '
#  'During my stay, I found the distance to major tourist attractions (Time '
#  'Square, Empire State Building, Statue of Liberty, Central Park, etc) was '
#  'usually about 30-45 minutes via public transport.')
# ('The place was really nicely decollated and very comfortable. At night, the '
#  'neighborhood is a bit darker than I thought, but it was very safe. Lots of '
#  'taxies around the Manhattan Street, and the train station is very close! '
#  'Loved staying there :) ')
# ("Maya's apartment was in a great location in Greenpoint. Easy walking "
#  'distance to subway. Excellent restaurants and cafes nearby. Comfortable and '
#  'clean. Met Maya upon arrival. Very welcoming with handy hints about local '
#  'area. Good communication during our stay. ')
# ('A lovely home in a quiet, but well connected neighbourhood. Maya has thought '
#  'if all the finishing touches that make airbnb so good (fresh coffee and '
#  "creamer in the fridge). Always available and very helpful. I'd recommend a "
#  'stay here to any independent travellers looking for a respite from the noise '
#  'of Manhattan. <br/>Thanks Maya! ')
# ("Loved Greenpoint and Maya's apartment just made it a home from home! Will "
#  'definately be staying there again when we return to Greenpoint. Thanks again '
#  'Maya')
# ('Maya was an outstanding host and her apartment in Greenpoint was amazing. '
#  'The location was so perfect for us, nearby great restaurants, shops, and '
#  'cafes too. Just a short trip to Manhattan, and Williamsburg too. Loved decor '
#  'and the detail Maya put into the apartment, really made it feel like a home '
#  "of our own. Would definitely stay at Maya's place if we're ever back in "
#  'Brooklyn. Thanks!')
# 'We had a great time and loved the apartment. Nice quiet neighborhood.'
# ("I had a great stay at Maya's apartment. It's clean, well styled and on a "
#  'nice tree lined street in Greenpoint. Collecting & returning keys was hassle '
#  'free. Maya was very respondent on text if I had any questions on anything. '
#  '<br/>I highly recommend staying here!')
# ('Maya did her best to accommodate our erratic schedule. We never met her but '
#  'she responded to email communications quickly and helpfully. ')
# ('Maya made us feel very welcome and always responded to texts quickly. The '
#  'flat is a great base for exploring Greenpoint and Williamsburg. The flat is '
#  'as it looks on the site and is really comfortable. All in all a great trip '
#  'to New York. ')
# ('The apartment is as described, clean, sunny & comfortable.\r'
#  '<br/>\r'
#  '<br/>Extremely quiet street--very nice to return to after a busy day in '
#  'Manhattan.\r'
#  '<br/>\r'
#  '<br/>Easy access to subways, restaurants & shops.')
# ('Maya is a wonderful host! The apartment was perfect, stylish, and just as '
#  'pictured. The neighborhood is, of course, incredible and Maya really went '
#  'the extra mile to help us feel welcome in it. Thanks again for a great stay!')
# ('Maya is a wonderfully gracious host. She responded promptly to all my texts '
#  'with  cheerful, caring responses.\r'
#  '<br/>The neighborhood is quiet and safe, within a block or two of shopping.\r'
#  "<br/>Maya's apartment is bright, spacious and meticulously clean. The access "
#  'to the bedroom is by way of a spiral staircase  to the lower level, which '
#  'could be challenging for anyone with limited mobility. \r'
#  "<br/>Overall, we were very happy with our stay and wouldn't hesitate to book "
#  'it again.')
# ('Maya was amazing and made the whole experience so easy! \r'
#  '<br/>\r'
#  '<br/>I booked this apartment for a colleague who was attending a conference '
#  'in Brooklyn and he just loved it. The apartment is in a great location and '
#  'felt like home!')
# ("Maya's apartment was a lovely home away from home! The soaring ceilings and "
#  'bright light make it a true gem and the neighborhood has so many great '
#  'places.')
# ("Maya's room  is located in the really nice place. Green Point is a very "
#  'fashionable area. Convenient to go anywhere!!<br/>I could live without '
#  'inconvenience. Maya is so cute, and she has freedom heart. Also if there is '
#  'to come to Brooklyn, I want to stay.')
# ('It is a beautiful flat in a nice, quiet area with good access to other parts '
#  'of town. Maya was great to communicate with and answered my questions '
#  'promptly. We would definately come back.')
# ("This is our second visit to one of Maya's properties. This particular "
#  'location worked out great for my husband and I. It was in a perfect location '
#  "and it fit our needs as far as safety and comfort. It's an adorable "
#  'apartment that has everything a couple needs. Maya was very accommodating as '
#  'always. We will be back. We may try the historic storefront again. Wow! '
#  "Can't believe the new park by the water.. How lucky is that. ")
# ('\r'
#  '<br/>The description was accurate.  The neighbourhood was interesting and '
#  'vibrant.  the host gave clear instructions and promptly answered any '
#  'questions.')
# ('We absolutely loved our stay at the house in Greenpoint. Maya was so '
#  'accommodating from start to finish. The house was as beautiful in person as '
#  'it was online. I was worried about there being no air conditioning but the '
#  'house stayed cool the entire time. We had work at the Brooklyn Expo Center '
#  'so the location could not have been better. Greenpoint is a wonderful '
#  'neighborhood and we are so happy we had the chance to explore it a bit. I '
#  'look forward to returning in the near future. Thank you Maya for your '
#  'awesome hospitality!')
# ("Maya's house was roomy, comfortable and perfectly located near the G train "
#  '(and Peter Pan donuts!)\r'
#  '<br/>\r'
#  "<br/>The listing showed AC but it wasn't installed when we got there. I "
#  'wrote Maya about it and she replied quickly and had it installed within the '
#  'day. Super responsive and ready to help. Highly recommend! ')
# ('Maya was a great host, everything was very easy!  She was very responsive '
#  'and helpful!  Definitely recommend!')
# ("Deuxième location pour nous d'un appartement que gère Maya et sommes encore "
#  'une fois ravis ! Simplicité et rapidité dans la communication, appartement '
#  'impeccable à notre arrivée, petites attentions et  pour nous faire visiter '
#  'le quartier - un petit plan de ses adresses favorites - en plus du '
#  'magnifique et confortable appartement. Nous y avons passé 5 jours, '
#  'appartement sur une rue très tranquille de Greenpoint -  avec une station de '
#  'métro à 3 minutes à pied et le ferry qui dessert Brooklyn, Queens et '
#  'Manhattan à moins de 10 minutes. Une adresse sûre tenue par  une hôte  '
#  'formidable ! Merci Maya ;-)\r'
#  '<br/>\r'
#  '<br/>\r'
#  '<br/>')
# ('The flat in Greenpoint was cozy and similar to the images on the website. '
#  'The location in Greenpoint is perfect and everything needed was within a '
#  'short walk. Maya was responsive via texts and answered quickly.')
# ...
#  "journée.<br/>Instructions très clair dans l'ensemble.<br/>Merci de nous "
#  'avoir accueilli !')
# ('Maya was very kind and always quick with her responses.  Would definitely '
#  'stay here again.')
# ('Beautiful neighbourhood. Safe and clean place to stay while visiting with '
#  'friends or for solo travel. Furniture coverings and stacks of magazines take '
#  'away from the overall appeal of the living room compared to posted photos. '
#  'Fan and dehumidifier in basement were helpful in moving fresh air to replace '
#  'the stale but hard to fall asleep to. Excellent choice for an affordable '
#  'stay in greenpoint.')
# ('Maya was terrific. She checked in with us coming and going and was ready to '
#  'help at any point. We love and appreciate her spacious Greenpoint Brooklyn '
#  'duplex. <br/>We’d stay here again on our next trip! <br/>Lots of little '
#  'extras in the kitchen and bathroom if needed.')
# ('Super beautiful neighbourhood with great restaurants and a park close by. '
#  'Maya’s home is a lovely Brooklyn gem, cozy with a wonderful interior.')
# ('Loved our stay at Maya’s place! Perfect location for getting the bus or '
#  'subway, a ton of great shops and places to eat locally!<br/>Apartment was '
#  'really nice, good size and really quiet. It’s been really hot while we’ve '
#  'been in NY so the fan in the bedroom was a god send, maybe an extra fan in '
#  'the living room would be perfection 👌🏻. <br/>Maya was really accommodating '
#  'with letting us check out later than normal to fit in with our flights, '
#  'meant we didn’t have to find somewhere for our bags for the last '
#  'day!<br/>Would definitely recommend and would stay again when we come back! '
#  '<br/>Favourite places to eat nearby:  Forma Pasta Factory, Paulie Gee’s '
#  'Pizza, Bagel Point, Palomas, Calexico, Peter Pan Bakery.')
# ("Maya's place is a great option for a Greenpoint getaway. It's in a sweet "
#  'location and the cozy atmosphere makes you feel right at home.')
# 'Clean, great location and easy to navigate!'
# ('Wir haben uns bei Maya sehr wohl gefühlt. Es war alles sehr unkompliziert '
#  'und uns wurde immer schnell geantwortet. <br/>Die Lage ist perfekt. U-Bahn '
#  'ist zu Fuß in wenigen Minuten erreichbar und alle Geschäfte die man braucht '
#  'sind sofort ums Eck. <br/>Auch die Wohnung ist nett eingerichtet und war mit '
#  'allem nötigen ausgestattet. <br/>Wir können Mayas Unterkunft jedem ans Herz '
#  'legen.')
# ('It was a great neighborhood and pretty convenient.  The place could use more '
#  'lighting. Otherwise perfect')
# ("Traveling in NYC with kids can be challenging, but Maya's place and "
#  'hospitality made it easy. The apartment was clean and comfortable with a '
#  'well-appointed kitchen and super clean bathroom, plus plenty of fresh '
#  'linens. The main living area was spacious and comfortable and was the '
#  'perfect home base to come back to after adventuring around the city. Kids '
#  'loved the spiral staircase to the basement bedroom. There were AC units in '
#  'both the living area and bedroom to keep it dry and cool (we visited in '
#  'August). Maya was super friendly in her communications and was able to '
#  'provide some flexibility with check in and check out times, which was above '
#  'and beyond. All in all we had a fantastic stay here and I would highly '
#  'recommend!')
# ('Unique residence nestled in iconic Greenpoint neighborhood!  <br/>Pros: '
#  '<br/>- Walking distance from everything: cafes, bars, subway and restaurants '
#  '(Le Fanfare if you get the chance)!.  Cannot beat the location!  <br/>- Host '
#  'extremely communicative!  We locked ourselves out and she made sure we were '
#  'taken care of right away.  Always responsive.<br/>- Extras in the bathroom / '
#  'fridge available.<br/>- Cottage feel.<br/>- Maya offered a late check-out if '
#  "needed.<br/>Cons: <br/>- The apartment's bedroom is not as well lit as it is "
#  'in the photos (note: you cannot open the curtains to let light in).  <br/>- '
#  "Bedroom is musty.  Has 2 air conditioners but didn't seem to help.<br/>- "
#  'There is an extremely narrow spiral staircase that leads to the bedroom.  '
#  '<br/>- No dresser (only a closet), so you will live out of your suitcase if '
#  "you have items that you don't hang.<br/>Overall a pleasant stay and "
#  'accommodating host!')
# ('Maya’s place is cute and cozy near lots of restaurants, cafes and the G '
#  'subway train. We enjoyed our stay. Maya was also very accommodating.')
# ("Maya's place was very cute and had everything we needed for our stay, "
#  'including laundry! It was super walkable to nearby bars, cafes, and '
#  'restaurants, as well as the G line for easy access to other parts of the '
#  'city. Maya was very communicative and a great host.')
# 'Excellent location, very comfortable bed'
# 'Maya is a terrific host and made this staying unforgettable'
# ('Second time, we love staying here. Great for two people and love the '
#  'neighborhood.')
# ('We loved our stay in Maya’s place. It was a fantastic location for our week '
#  'in New York. Plenty of great spots to eat and drink in the area and easy '
#  'access to Manhattan when we wanted to explore there. The staircase to the '
#  'downstairs bedroom is very narrow but manageable. We had everything we '
#  'needed and Maya was very responsive when we had any questions.')
# 'Simply a great apt with all the conveniences of home.'
# 'Great location and great house!\r<br/>'
# 'The apartment was lovely and just as pictured.'
#
# Reviews for listing number 3
# 'EXCELLENT LOCATION SUPER CLEAN!!!'
# ('Blair was a very generous & responsive host. Very quick & easy access. '
#  'Everything was clean and prepared prior to arriving. Highly Recommend '
#  "blair's spot here in east village !")
# ('Although the rooms were tiny (not much floor space), everything was brand '
#  'new and spotlessly clean.  The newly renovated building was also clean and '
#  "quiet.  The apartment was conveniently located in New York's trendy Lower "
#  'East Side.')
# 'Great place and awesome communication with Noura!'
# ('We visited NYC as a group of 5 guys in our mid-twenties for 3 nights and '
#  'were pleased with the close proximity of the location of the airbnb to '
#  'bars/restaurants in the area. It felt very "neighborhoodly", lively at '
#  'times, and a little away from the main touristy parts of NYC which is '
#  'exactly what we were looking for. The place was unique and while it was a '
#  'bit narrow, it had sufficient space for all of us considering its prime '
#  'location in NYC. There was also a small private backyard which could be '
#  'accessed from one of the bedroom doors which is definitely a rarity. 2 of '
#  'the bedrooms and a half bathroom are located below street level. While we '
#  'did experience some issues with the WiFi being spotty and not getting hot '
#  'water one of the days, both issues got resolved. Blair, one of the hosts, '
#  'was super responsive and helpful during our entire stay and would answer any '
#  'questions in a prompt manner regardless of the time of day. A great area to '
#  'stay in for a group of friends or families.')
# ('Fantastic hosts, very proactive and genuinely interested in making sure '
#  'everything goes well with your stay.  The apartment is very quirky but it is '
#  'absolutely a 4 bedroom flat in the East Villiage.  Ceilings are a little low '
#  'and there is not a lot of space to move around the beds.  In fact, there '
#  "isn't a lot of extra space at all but that is 100% what living in NYC is "
#  'like so its pretty authentic.  The amenities are thoughtful and use the '
#  'space efficiently.  Washer and Dryer is a plus. Pretty much everything you '
#  'need is nearby.')
# ('Noura & Blair were great, and accommodated all our travel requests as best '
#  'they could!  Would stay here again.')
# ('Hosts tried hard to make things nice. Outdoor space was useful with the dog. '
#  'Kitchen was nice. Bathrooms nice. Everything is NYC tight space but that was '
#  'expected. We would stay there again.')
# ('Response host, met us with keys for check in. Easy to communicate with. 4 '
#  'bedrooms in convenient east village. Every thing was clean and comfortable')
# ('Perfect location for us. Right in the heart of East Village. Great '
#  'neighborhood to walk around in with plenty of food options and small shops. '
#  'Comfortable bedding for all five of us.  It is nice to have a tv monitor in '
#  'every room. <br/>Taxis are rare to pass by in front of the property, but the '
#  'Ubers came within a minute every time they were ordered.')
# 'Alojamiento muy comodo y bonito.'
# ('Loved staying in this neighborhood - six adults stayed in the apartment and '
#  'we all loved the proximity to great restaurants, bars and shopping, all the '
#  'reasons we visit New York!  This apartment was truly a great value!')
# ("We absolutely loved our stay at Blair's and hope to return many times! A "
#  'true gem in one of the best NYC locations you can ask for. Blair met us '
#  'outside, helped unload our bags, and gave us a tour of the apartment. We had '
#  'a wonderful weekend and can not say enough about this Airbnb. Thank you! We '
#  'will stay again!')
# ('Our host was very nice and always responsive when needed. His place '
#  'accommodated 7 of us in the city which is hard to find. Definitely recommend '
#  'booking with him. His prices are also very fair!')
#
# Reviews for listing number 4
# ('We had a wonderful time at this appartment. It is very conveniently located '
#  'in Brooklyn on a residential street with two supermarkets  at 1 minute '
#  'walking distance, and just a short walk to the subway. It took us only 35 '
#  'minutes to get to the Guggenheim!\r'
#  "<br/> The living room has a comfortable couch, but we didn't watch much TV "
#  'as we we out most of the time.\r'
#  '<br/>The owners were really sweet, they arranged bagels, milk and juice so '
#  'for our first breakfast, Towels were comfy. \r'
#  '<br/>The living room is long but a bit narrow, the floor below with bedrooms '
#  'and bathroom has a lot of space. We slept well in the double bed, our kids '
#  'slept comfortably in the single beds in the other rooms. One of the beds is '
#  'a little shorter than regular size though. There are aircons in the bedrooms '
#  'and in the dining area, which managed well in the heatwave.The plants '
#  'outside needed watering though! \r'
#  '<br/>We would definitely choose this place if we go back to NY!')
# ('We were so grateful to have stumbled upon this listing.  We recently made '
#  'our first visit to NYC (with our 5 and 7 year old in tow).   The space was '
#  'perfect for us - a true home away from home.  Lots of space for a family of '
#  'four, AC for those hot city nights, and bagels, milk and juice in the fridge '
#  'when we arrived after a long journey - what a relief!  \r'
#  '<br/>\r'
#  '<br/>The neighbourhood was AMAZING!!!  A quick walk and easy subway ride to '
#  'the sights, but far enough away from the hustle and bustle to relax at the '
#  'end of the day.   Only a block to a grocery store and tons of wonderful '
#  'restaurants.   There was even a playground a block away.  \r'
#  '<br/>\r'
#  "<br/>Here's hoping we can stay here again if we get a chance to visit "
#  'again!  A+++.')
# ('We had a wonderful time in Brooklyn/NYC, due largely to the wonderful '
#  'accommodations we found on AirBnB. The brownstone is spacious and '
#  'beautifully appointed. The location is perfect for families  and for '
#  'couples; it was close to shopping, restaurants, markets, and transit. The '
#  'deck and backyard are luxuries we also enjoyed on our trip. We would stay '
#  'here again and we highly recommend it!')
# ('Le logement a beaucoup de charme, est très confortable et bien situé. Le '
#  "quartier est sûr et très sympa et la présence d'un parc à 300 m environ "
#  "donne la possibilité aux sportifs de s'exprimer dans la nature. A 20 Mn de "
#  'Manhattan par plusieurs Métro possibles.\r'
#  '<br/>Bref, un excellent séjour en famille à NY grâce entre autres à la '
#  'qualité du logement et la gentillesse de Vera sa propriétaire. Un grand '
#  'Merci.')
# ('My family had a fantastic week staying here.  The apartment is gorgeous, '
#  'very comfortable and the neighborhood is great.  There are multiple transit '
#  "options close by (the 'R' is two blocks away and several other trains can be "
#  'had with a slightly longer walk).  Park Slope itself has many great shops '
#  'and places to eat along with Prospect Park being a short walk away and a '
#  'beautiful place to spend the day.  Vera was quick to respond to any and all '
#  'questions and the description and photographs of the unit were spot on (it '
#  'looks even better than the pictures, which is not usually the case).  Highly '
#  'recommend!')
# ('We (parents + three teens) had a great time in this spacious and well '
#  'equipped apartment.  After busy days of visits in Brooklyn and Manhattan '
#  'this is exactly the place where you want to stay for an enjoyable evening '
#  'and a quiet night.  The two floors, the deck (with BBQ and table) and the '
#  'garden (with plenty of toys, balls etc.) make you feel home.  Decoration is '
#  'pleasant and gives a warm atmosphere.  The house is also close to shops, '
#  'restaurants and metro stations.  No doubt that we would like to come back.')
# ('Vi havde en fantastisk uge i Brooklyn og følte os hjemme i lejligheden. Den '
#  'levede fuldt op til beskrivelsen og Vera havde købt ind til morgenmad, der '
#  'var bagels, juice, æg, smør og kaffe... Der var rent og gode beskrivelser '
#  'af, hvordan vi brugte diverse elektriske maskiner. Når vi havde spørgsmål, '
#  'svarede Vera tilbage hurtigt på mailen. Vi følte os vejledt og meget '
#  'velkommen.\r'
#  '<br/>\r'
#  '<br/>Lejligheden ligger i et fantastisk hyggeligt område, trygt og sikkert - '
#  'med masser af restauranter, gode butikker og spændende seværdigheder. Det '
#  'var fantastisk at bo i Brooklyn og ikke på Manhatten. Naboerne mv var '
#  'imødekommende, hilste på gaden og det var nemt at få tips og rådgivning '
#  'omkring diverse seværdigheder...\r'
#  '<br/>\r'
#  '<br/>Det var rigtigt dejligt med både terasse og "back yard" - selvom det '
#  'var så varmt i juli at vi ikke kunne holde ud at være derude midt på dagen.\r'
#  '<br/>\r'
#  '<br/>Bestemt en lejlighed vi vil overveje at bo i igen. Det fungerede '
#  'perfekt for os!')
# ('We had a splendid time in this flat. The relative quiet of the neighborhood '
#  'was a welcome change from the daily hustle bustle we experienced in '
#  'Manhattan.\r'
#  '<br/>The host provided bagels for us in the freezer. The flat was easy to '
#  'find. There also was a booklet with instructions for everything, from the '
#  'air conditioning to the television. We used the free wifi to stay in touch '
#  'with our folks at home.\r'
#  '<br/>The flat is very spacious, clean and we immediately felt at home there. '
#  'The shower is great!\r'
#  '<br/>Vera was always available for questions via mail and text, always with '
#  'a quick answer for everything.\r'
#  '<br/>The neighborhood feels very safe and one of the neighbors told us to '
#  'ring his doorbell if we needed anything. At home abroad indeed.')
#
# Reviews for listing number 5
# ("Had a great stay at Max's place. We felt very at home. Super comfortable and "
#  'clean with a nice view of the city with an awesome rooftop balcony. Very '
#  'convenient and close to the train. Cool, hip and trendy bars and restaurants '
#  'close by as well')
# ("Max's apartment was super conveniently located for my needs, right in the "
#  "heart of Bushwick and very close to the L train. Although I wouldn't "
#  "describe it as 'homey' the place was comfortable and worked well for a "
#  'single traveler such as myself looking to spend some time out in the city. '
#  "There's a ice looking patio with a great view which I'm sure is nice in the "
#  'warmer months. Thanks!')
# ('Host was very welcoming and understood about our late check in and check out '
#  'times! Very good communication, apartment was great and in very good '
#  "location! I suggest trying Tina's and the rookery, good for breakfast and "
#  'dinner. Would 100% stay here again!')

# %%
# counting starts at 0
cursor = listings.find( { 'reviews.29.comments' : { '$regex':  '^.*awesome.*$'    } } )
l = list(cursor)
print(len(l))
pprint.pp(l[0:5])
# Out:
# 4
# [{'_id': ObjectId('6658d7d82d77bbd68b58fae7'),
#   'id': '1043046',
#   'name': 'Rental unit in New York · ★4.90 · Studio · 1 bed · 1 bath',
#   'host_id': '2335804',
#   'host_name': 'Lindsay',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.74118,
#   'longitude': -74.00071,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 72,
#   'last_review': datetime.datetime(2020, 3, 15, 0, 0),
#   'reviews_per_month': 0.62,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': [{'listing_id': '1043046',
#                'review_id': '341292751',
#                'date': datetime.datetime(2018, 10, 26, 0, 0),
#                'reviewer_id': '1618825',
#                'reviewer_name': 'Leron',
#                'comments': 'Great place, great location!'},
#               {'listing_id': '1043046',
#                'review_id': '65891831',
#                'date': datetime.datetime(2016, 3, 17, 0, 0),
#                'reviewer_id': '10217681',
#                'reviewer_name': 'Vivi',
#                'comments': 'Wonderful place! Great location, Lindsay was '
#                            'really nice and would recommend her place to '
#                            'anyone!'},
#               {'listing_id': '1043046',
#                'review_id': '24562638',
#                'date': datetime.datetime(2014, 12, 30, 0, 0),
#                'reviewer_id': '9628930',
#                'reviewer_name': 'Brandi',
#                'comments': "Lindsay's place was the perfect location!  Very "
#                            'quiet despite being right in the middle of '
#                            'everything! We thoroughly enjoyed our stay and '
#                            'would recommend it for your visit to NYC '},
#               {'listing_id': '1043046',
#                'review_id': '25037769',
#                'date': datetime.datetime(2015, 1, 5, 0, 0),
#                'reviewer_id': '24201194',
#                'reviewer_name': 'Peter',
#                'comments': 'Spent 5 nights during New Years at this perfectly '
#                            'located studio apartment. Although we never met '
#                            'face-to-face, Lindsay was a great host. Very '
#                            'communicative and was available when needed. She '
#                            'had everything ready and had a useful "one-sheet" '
#                            'overview of the apartment that included everything '
#                            'from wifi password to how to hook up to the stereo '
#                            'system. The apartment was clean and perfect for '
#                            'two (not much space for anyone or anything else).\r'
#                            '<br/>\r'
#                            '<br/>What we loved most about this apartment is '
#                            "the location! Perfect spot if you're in town to "
#                            'explore the city. You are literally STEPS from the '
#                            'A, C & E lines plus 1-2 blocks from the 1, 2, 3 & '
#                            'L. Within 5 minute walk to a few supermarkets and '
#                            'Chelsea Market, as well as CVS and Duane Reade. '
#                            "Couldn't have asked for a better situated place to "
#                            'crash!\r'
#                            '<br/>\r'
#                            '<br/>Will definitely stay again, highly '
#                            "recommended if you're in NYC to explore."},
#               {'listing_id': '1043046',
#                'review_id': '22107573',
#                'date': datetime.datetime(2014, 10, 30, 0, 0),
#                'reviewer_id': '21459478',
#                'reviewer_name': 'Leah',
#                'comments': 'Lindsay and her place are great. We had a '
#                            'wonderful stay. Beautiful apartment, FANTASTIC '
#                            'location (literally right next door to so many '
#                            'train lines, the high line, amazing '
#                            'restaurants...), and a really good deal for New '
#                            'York. 10/10 - everyone should stay here! '},
#               {'listing_id': '1043046',
#                'review_id': '16581426',
#                'date': datetime.datetime(2014, 7, 29, 0, 0),
#                'reviewer_id': '18142785',
#                'reviewer_name': 'Sonsoles',
#                'comments': 'La casa muy acogedora y muy bien ubicada lindsay '
#                            'nos ha tratado de maravilla'},
#               {'listing_id': '1043046',
#                'review_id': '18919893',
#                'date': datetime.datetime(2014, 9, 2, 0, 0),
#                'reviewer_id': '15982584',
#                'reviewer_name': 'Juan',
#                'comments': 'Lindsay was a great host! We had some last minute '
#                            'bumps in our trip but she accommodated herself and '
#                            'helped us in anything she could. The apartment was '
#                            'really clean and one of the best locations Ive '
#                            'seen, great quiet neighborhood and a metro station '
#                            'two steps away. We also got to meet Emma, her dog, '
#                            "who is one of the cutest dog I've seen. I highly "
#                            "recommend Lindsay's apartment to everyone!"},
#               {'listing_id': '1043046',
#                'review_id': '20441511',
#                'date': datetime.datetime(2014, 9, 29, 0, 0),
#                'reviewer_id': '1609879',
#                'reviewer_name': 'Joanne And Ron',
#                'comments': 'Lindsay was extremely welcoming.  She was open to '
#                            'meeting us to give us the key and a tour of the '
#                            'apt at a time that was convenient for us.  The apt '
#                            'was a cute little studio that served our needs '
#                            'perfectly.  The kitchen was adequately supplied, '
#                            'the apt was clean and homey.   We surely would '
#                            'stay here again.'},
#               {'listing_id': '1043046',
#                'review_id': '21616543',
#                'date': datetime.datetime(2014, 10, 20, 0, 0),
#                'reviewer_id': '4631944',
#                'reviewer_name': 'Jessica',
#                'comments': 'Lindsay was an excellent host! Very welcoming and '
#                            'friendly. She met us at the apartment to let us '
#                            'in, and left us with a very detailed list of '
#                            'instructions. She even gave us restaurant '
#                            'recommendations in the area and helped us out with '
#                            'the subway. Her apartment suited our needs '
#                            'perfectly. It was comfortable, clean, conveniently '
#                            'located, reasonably priced, and quiet. The '
#                            'building seemed very safe during our stay. I would '
#                            'definitely recommend this apartment for your stay '
#                            'in NYC!'},
#               {'listing_id': '1043046',
#                'review_id': '22700170',
#                'date': datetime.datetime(2014, 11, 12, 0, 0),
#                'reviewer_id': '1785024',
#                'reviewer_name': 'Charlotte',
#                'comments': 'Lindsay is a great host! Eveything was eprfectly '
#                            'fine when I arrived. The location of the flat is '
#                            'wonderful as close to several subway stations and '
#                            'in the heart of trendy districts (Meatpacking, '
#                            'West Village and Geenwich). You can find easily '
#                            'all you need at 5mn by walk \r'
#                            '<br/>Besides the flat has a view on a courtyard '
#                            'then you can sleep very well\r'
#                            '<br/>I definitely recommend the flat of Linsday'},
#               {'listing_id': '1043046',
#                'review_id': '22989839',
#                'date': datetime.datetime(2014, 11, 19, 0, 0),
#                'reviewer_id': '1314268',
#                'reviewer_name': 'Kimber',
#                'comments': "Lindsay's apartment is exactly what I expected "
#                            "based on the description in the listing. It's warm "
#                            'and welcoming and very comfortable. The apartment '
#                            'is super cozy and I felt very at home there. The '
#                            'courtyard-facing apartment is really quiet and '
#                            'peaceful.\r'
#                            '<br/>\r'
#                            '<br/>She was easy to contact and even provided her '
#                            'brother as an alternative contact person in case I '
#                            'needed additional help, which I did initially, '
#                            "which was no fault of hers. They're a great team! "
#                            'The whole process was simple. \r'
#                            '<br/>\r'
#                            "<br/>I would love to stay here again! It's close "
#                            'to everything and the neighborhood is really cute '
#                            'and safe!'},
#               {'listing_id': '1043046',
#                'review_id': '27588122',
#                'date': datetime.datetime(2015, 3, 8, 0, 0),
#                'reviewer_id': '23410491',
#                'reviewer_name': 'Jörn',
#                'comments': "We spent 3 nights in Lindsay's apartment and would "
#                            'highly recommend it! Perfectly clean and cozy, '
#                            "with everything that's needed for your daily life. "
#                            'The location is absolutely perfect, since places '
#                            'such as Meatpacking District, Chelsea Market, High '
#                            'Line, etc. are just around the corner. Also great: '
#                            'There is a subway station literally next door, '
#                            'with connections to all parts of Manhattan as well '
#                            'as a direct train to Brooklyn. <br/>Try the French '
#                            'bar/restaurant on the other side of W 15 '
#                            'St!<br/>Thanks for having us - a great '
#                            'experience! '},
#               {'listing_id': '1043046',
#                'review_id': '33936422',
#                'date': datetime.datetime(2015, 6, 2, 0, 0),
#                'reviewer_id': '8860111',
#                'reviewer_name': 'Adele',
#                'comments': 'The studio was just as described. Lindsey made '
#                            'sure I had everything I needed, and although she '
#                            'was out of town left a contact for any '
#                            'emergencies.\r'
#                            '<br/>This was a perfect location, steps from the '
#                            'subway and lots of dining options. It was also '
#                            "only a block and a half from my daughter's "
#                            'apartment which made it the perfect location for '
#                            'me.\r'
#                            "<br/>I can't think of one thing Lindsay could have "
#                            'done better. She was very thoughtful as a host.'},
#               {'listing_id': '1043046',
#                'review_id': '44183172',
#                'date': datetime.datetime(2015, 8, 24, 0, 0),
#                'reviewer_id': '15582221',
#                'reviewer_name': 'Danielle',
#                'comments': 'I recently stayed 5 nights with my sister in '
#                            "Lindsay's NYC apartment. We had an amazing stay! "
#                            "Lindsay's apartment was perfect. The location is "
#                            'ideal. Check in and check out was smooth, no '
#                            'troubles at all. I highly recommend the little '
#                            'restaurant across the street and I highly '
#                            "recommend Lindsay's apartment in general!\r"
#                            '<br/>\r'
#                            '<br/>Thank you Lindsay! '},
#               {'listing_id': '1043046',
#                'review_id': '65004327',
#                'date': datetime.datetime(2016, 3, 10, 0, 0),
#                'reviewer_id': '51291401',
#                'reviewer_name': 'Carolyn',
#                'comments': 'We never met Lindsay but she was extremely helpful '
#                            'and provided us with more information then we '
#                            'could have asked for.  Her place was perfect for '
#                            'us.  Only steps away from the Metro which was very '
#                            'handy with such a busy sightseeing schedule.  She '
#                            'had everything we needed. Even allowing us to use '
#                            'her hair dryer, iron and providing cupboard and '
#                            'draw space.  We highly recommend staying here and '
#                            'would love to again in the future.\r'
#                            '<br/>Thanks Lindsay'},
#               {'listing_id': '1043046',
#                'review_id': '66974519',
#                'date': datetime.datetime(2016, 3, 26, 0, 0),
#                'reviewer_id': '16492424',
#                'reviewer_name': 'Jasmin',
#                'comments': "Staying at Lindsay's studio was great, the "
#                            'location was even better than expected! '
#                            '<br/>Everything essential for the daily need is '
#                            'around the corner including Chelsea market (we '
#                            'were there almost every day!), several '
#                            'supermarkets, two main subway stations or the '
#                            'empire cake shop (sooo awesome!). We stayed for 6 '
#                            'nights and enjoyed every minute at her cozy place! '
#                            'Right from the beginning, the communication with '
#                            'Lindsay was very nice, she was very friendly and '
#                            'helpful, and It was like coming to the apartment '
#                            'of a good old friend. '},
#               {'listing_id': '1043046',
#                'review_id': '75989875',
#                'date': datetime.datetime(2016, 5, 24, 0, 0),
#                'reviewer_id': '72396504',
#                'reviewer_name': 'Karen',
#                'comments': 'This was my virgin AirBnB experience and it '
#                            "couldn't have gone any better.  Communications "
#                            'with Lindsay were smooth and speedy.  The '
#                            'apartment was comfortable, clean, cozy, quiet and '
#                            'lovely to return to at the end of each day.  It '
#                            'felt like I was coming home....Thanks Lindsay!'},
#               {'listing_id': '1043046',
#                'review_id': '161033647',
#                'date': datetime.datetime(2017, 6, 16, 0, 0),
#                'reviewer_id': '21645588',
#                'reviewer_name': 'Elizabeth',
#                'comments': 'Lindsay is a terrific host. Her place is clean and '
#                            'is accurately presented. The apartment building is '
#                            'quiet and very safe. Great location for getting '
#                            'all around the city. Good value for NYC.'},
#               {'listing_id': '1043046',
#                'review_id': '68073157',
#                'date': datetime.datetime(2016, 4, 2, 0, 0),
#                'reviewer_id': '42590209',
#                'reviewer_name': 'Anni',
#                'comments': 'Lindsay was an amazing home. Although she was not '
#                            'in Manhattan at that time, she arranged everything '
#                            'with the key and so on. The apartment is cozy and '
#                            'the area is just perfect for a trip to New York! I '
#                            'would definitely stay at her place again!'},
#               {'listing_id': '1043046',
#                'review_id': '166487728',
#                'date': datetime.datetime(2017, 7, 3, 0, 0),
#                'reviewer_id': '12353509',
#                'reviewer_name': 'Melissa',
#                'comments': 'This is a lovely apartment, quiet and comfortable, '
#                            'yet easily accessible to everything.  I have spent '
#                            'a lot of time in New York, but I had never stayed '
#                            "in this neighborhood and I honestly think it's my "
#                            "favorite part of the city now.  It's a lovely, "
#                            'open apartment and very comfortable.  Lindsay was '
#                            'an attentive and helpful host and I would highly '
#                            'recommend her place.'},
#               {'listing_id': '1043046',
#                'review_id': '79554474',
#                'date': datetime.datetime(2016, 6, 13, 0, 0),
#                'reviewer_id': '24557635',
#                'reviewer_name': 'Elisa',
#                'comments': 'My partner and myself stayed at Lindsays place for '
#                            '12 nights. She has been a fantastic host! She was '
#                            'at there to welcome us upon arrival and had great '
#                            'suggesttions for us about the area. The apartment '
#                            'is in a perfect location - could not be better! '
#                            'The train is literally at the doorstep. The bed '
#                            'was comfortable and the room airconditioned.  '},
#               {'listing_id': '1043046',
#                'review_id': '80328027',
#                'date': datetime.datetime(2016, 6, 17, 0, 0),
#                'reviewer_id': '10723051',
#                'reviewer_name': 'Yuejuan',
#                'comments': "True to the description, Lindsay's apartment is a "
#                            'very clean, quiet, sweet and cozy place which is '
#                            'so close to '
#                            'metro/cafe/deli/Starbucks/laundry...basically '
#                            'everything that can make our stay in New York '
#                            'comfortable and convenient. And Lindsay is very '
#                            'kind and helpful in giving us many information, '
#                            "thank you Lindsay, we'll definitely recommend your "
#                            'apartment to friends who plans to stay in the big '
#                            'apple. '},
#               {'listing_id': '1043046',
#                'review_id': '80687947',
#                'date': datetime.datetime(2016, 6, 19, 0, 0),
#                'reviewer_id': '64015836',
#                'reviewer_name': 'Amol',
#                'comments': 'Lindsay was great and very welcoming...it was our '
#                            'first Airbnb experience and it was awesome. \r'
#                            '<br/>\r'
#                            '<br/>Lindsay allowed us to checkin early in the '
#                            'morning which was very nice of her.\r'
#                            '<br/>\r'
#                            '<br/>The place is nice and cozy and as described '
#                            'in th post... with everything you need is with in '
#                            'walking distance.\r'
#                            '<br/>\r'
#                            '<br/>Would definitely stay there again.\r'
#                            '<br/>'},
#               {'listing_id': '1043046',
#                'review_id': '107486400',
#                'date': datetime.datetime(2016, 10, 10, 0, 0),
#                'reviewer_id': '5219859',
#                'reviewer_name': 'Christel',
#                'comments': "L'appartement était parfait: cosy, très bien situé "
#                            'avec des lignes de métro "au pied de '
#                            'l\'appartement". \r'
#                            '<br/>\r'
#                            '<br/>Lindsay nous a réservé un accueil chaleureux '
#                            'et proposé des adresses de restaurant et café à '
#                            'tester à proximité.\r'
#                            '<br/>\r'
#                            '<br/>Nous recommandons ce logement. \r'
#                            '<br/>\r'
#                            '<br/>Chrystel et Julien'},
#               {'listing_id': '1043046',
#                'review_id': '109129462',
#                'date': datetime.datetime(2016, 10, 19, 0, 0),
#                'reviewer_id': '8609092',
#                'reviewer_name': 'Tammy',
#                'comments': 'Lindsay was wonderful! Welcoming and informative. '
#                            'Lindsay was flexible with check-in and check-out '
#                            'time which made my life much easier. The location '
#                            'is perfect, a few steps from major subway lines, 1 '
#                            'block from Chelsea Market and the HighLine. '
#                            'Everything you need is nearby - CVS, groceries, '
#                            'nails place, coffee shops, dinners, restaurants '
#                            'and more. The apartment is located on the 2nd fl. '
#                            "so you'll only need to climb 1 floor with your "
#                            'luggage. The laundry is in the basement, was '
#                            'vacant every time I used it. The apartment was '
#                            'clean and quiet and very comfortable. It is '
#                            'perfect for 1 person, can also accommodate a '
#                            'couple. It is certainly larger than a hotel room. '
#                            'I would definitely come back and stay here. I '
#                            'highly recommend this place. Thank you Lindsay!'},
#               {'listing_id': '1043046',
#                'review_id': '110810352',
#                'date': datetime.datetime(2016, 10, 28, 0, 0),
#                'reviewer_id': '26754001',
#                'reviewer_name': 'Mari',
#                'comments': 'We had a fantastic stay in NYC at Lindsays place. '
#                            'Great neighbourhood, subway right outside - and '
#                            'the host was great. We had to contact Lindsay the '
#                            'first night about some small mixup, and she was '
#                            'easy to reach and very helpful. I would recommend '
#                            'a stay here for anyone who wants a fantastic stay '
#                            'in the city :-) '},
#               {'listing_id': '1043046',
#                'review_id': '112765391',
#                'date': datetime.datetime(2016, 11, 7, 0, 0),
#                'reviewer_id': '98712911',
#                'reviewer_name': 'Maybell',
#                'comments': 'Lindsay was very helpful and responsive anytime we '
#                            'had a question. The apartment is in Chelsea and '
#                            'close to restaurants and galleries. The train stop '
#                            'is also at the corner which was very '
#                            'convenient.<br/>'},
#               {'listing_id': '1043046',
#                'review_id': '114074700',
#                'date': datetime.datetime(2016, 11, 15, 0, 0),
#                'reviewer_id': '17275045',
#                'reviewer_name': 'Saar',
#                'comments': 'lindsay was a great host, the apartment was warm '
#                            'and comfortable and close to everything.\r'
#                            '<br/>check in/out was flexible :). '},
#               {'listing_id': '1043046',
#                'review_id': '116219581',
#                'date': datetime.datetime(2016, 11, 28, 0, 0),
#                'reviewer_id': '5308632',
#                'reviewer_name': 'Jamal',
#                'comments': "Lindsay's place is an adorable, comfortable studio "
#                            'that is central to EVERYTHING! Quiet and peaceful, '
#                            'it is a great place for a short or long stay. '
#                            'Lindsay is extremely communicative and '
#                            'responsive-- was an absolute pleasure to deal '
#                            'with. This place is a great value! '},
#               {'listing_id': '1043046',
#                'review_id': '121031634',
#                'date': datetime.datetime(2016, 12, 13, 0, 0),
#                'reviewer_id': '14658437',
#                'reviewer_name': 'David',
#                'comments': 'This is an awesome studio, literally steps from '
#                            'the A, C, and E subway lines. There is lots to do '
#                            'in the neighbourhood or jump on the subway to '
#                            'explore other parts of New York.\r'
#                            '<br/>\r'
#                            '<br/>Lindsay was very kind. When I arrived she was '
#                            'waiting for me. My initial questions about where '
#                            'the market is, restaurants, etc were already '
#                            'answered in the notes she had written out for '
#                            'me. \r'
#                            '<br/>\r'
#                            '<br/>For my stay, this was perfect. I got to fully '
#                            'take in the event I came to New York for, while '
#                            'also enjoying the city, especially now at '
#                            'Christmas time.'},
#               {'listing_id': '1043046',
#                'review_id': '125009915',
#                'date': datetime.datetime(2017, 1, 3, 0, 0),
#                'reviewer_id': '29167001',
#                'reviewer_name': 'Irina',
#                'comments': 'Lindsay is a super host! The Studio is lovely, in '
#                            'the best possible position. I definitely recommend '
#                            'it!! '},
#               {'listing_id': '1043046',
#                'review_id': '127218086',
#                'date': datetime.datetime(2017, 1, 16, 0, 0),
#                'reviewer_id': '5789473',
#                'reviewer_name': 'James',
#                'comments': "My boyfriend and I had a great stay in Lindsay's "
#                            'apartment. Lots of great restaurants, delis and '
#                            'grocery stores in the neighbourhood, and a '
#                            'well-equipped kitchen (though no microwave). The '
#                            'bookshelf is filled with great books and '
#                            "magazines.<br/>It's Manhattan, so the apartment "
#                            "isn't huge, but there was plenty of space for the "
#                            'two of us --- the apartment consists of a nice '
#                            'living-room area with a comfy chair, bed and large '
#                            'bookshelf, adjacent to a kitchen with a gas stove '
#                            'and standard kitchen stuff.<br/>We had a smooth '
#                            'check-in and a generous checkout time.'},
#               {'listing_id': '1043046',
#                'review_id': '163851314',
#                'date': datetime.datetime(2017, 6, 25, 0, 0),
#                'reviewer_id': '54112636',
#                'reviewer_name': 'Nadine',
#                'comments': 'Idéalement placé, accès au métro direct, '
#                            'calme<br/>parfait pour une personne seule ou un '
#                            'couple<br/>A noter : pas de lave linge (laverie en '
#                            "bas de l'immeuble), pas de micro onde<br/>"},
#               {'listing_id': '1043046',
#                'review_id': '135830081',
#                'date': datetime.datetime(2017, 3, 6, 0, 0),
#                'reviewer_id': '115862171',
#                'reviewer_name': 'Allie',
#                'comments': 'This is a great spot in the heart of Chelsea -- '
#                            'near subway stops, super easy to grab a cab, too. '
#                            "It's close to the East and West Village and you "
#                            'can walk most places. We took cabs/Lyfts/the '
#                            'Subway whenever it seemed a bit easier -- we never '
#                            'waited more than 5 minutes for a ride. Spot is '
#                            "exactly as it's described, super cozy and quaint. "
#                            'Two warnings -- the heat cannot be adjusted (you '
#                            'can open a window to cool it down and that works '
#                            'quite well) and the shower pelts you, and I mean '
#                            'pelts, with water. It was intense. My husband '
#                            'figured out if you leave the Bahrain faucet on a '
#                            'little it makes the shower head slightly less '
#                            'intense. Regardless it was really uncomfortable '
#                            'and lead us to shower less than we normally would '
#                            'to avoid it. But the spot is awesome, super safe '
#                            'neighborhood and close to a ton! '},
#               {'listing_id': '1043046',
#                'review_id': '138321165',
#                'date': datetime.datetime(2017, 3, 19, 0, 0),
#                'reviewer_id': '79603703',
#                'reviewer_name': 'Boris',
#                'comments': 'Great place, wonderful neighborhood and really '
#                            'quiet! <br/>The owner is responsive and friendly '
#                            '<br/>'},
#               {'listing_id': '1043046',
#                'review_id': '139262270',
#                'date': datetime.datetime(2017, 3, 24, 0, 0),
#                'reviewer_id': '99371542',
#                'reviewer_name': 'Lauren',
#                'comments': 'Lindsay was amazing!! She was so quick to offer '
#                            'advice about where to go around the '
#                            'apartment...And those were some of our favorite '
#                            'things! The apartment was super cute, and very '
#                            'clean. It was stocked with everything we needed '
#                            'and more. Honestly, I almost took the bedding with '
#                            "me, it was so comfortable! Lindsay wasn't there to "
#                            'meet us, but getting the key and getting inside '
#                            'was the easiest thing. This apartment is also in a '
#                            "perfect location (who knew we'd have a quiet "
#                            'nights sleep in the city?!), And is steps away '
#                            "from a subway station. Our trip couldn't have gone "
#                            'any better!!!!! Stay here for sure!! (I know we '
#                            'will stay again if we ever get back!!!)'},
#               {'listing_id': '1043046',
#                'review_id': '141306646',
#                'date': datetime.datetime(2017, 4, 2, 0, 0),
#                'reviewer_id': '10178515',
#                'reviewer_name': 'Elena',
#                'comments': 'Lindsay is a great host: communicative, precise '
#                            'and nice! The house is like in photo: super cozy, '
#                            'well equipped, silent, excellent position in '
#                            'Chelsea! The subway is a few steps from the house! '
#                            'We suggest this studio to everyone wants to visit '
#                            'NYC!! Thank you Lindsay!'},
#               {'listing_id': '1043046',
#                'review_id': '142305235',
#                'date': datetime.datetime(2017, 4, 7, 0, 0),
#                'reviewer_id': '11077421',
#                'reviewer_name': 'Gwynne',
#                'comments': "Lindsay's place was amazing! So close to "
#                            'everything. Restaurants, bars, shopping, and the '
#                            'metro station are all very close. The apartment is '
#                            'quiet and in a very safe building. I will always '
#                            'look to see if this place is available when I am '
#                            'in NYC.'},
#               {'listing_id': '1043046',
#                'review_id': '144711298',
#                'date': datetime.datetime(2017, 4, 16, 0, 0),
#                'reviewer_id': '25876395',
#                'reviewer_name': 'Teresa',
#                'comments': 'The apartment was exactly as described on airbnb. '
#                            'It was clean, well equipped and the location is '
#                            'just perfect. The subway (including L-train to '
#                            'williamsburg/brooklyn) is right in front of the '
#                            "door. <br/>Even though we didn't meet her in "
#                            'person, you can tell that lindsay is a very '
#                            'friendly and comprehensive host. Very good '
#                            'reachable by text message and answers right away '
#                            'if you should have any questions. The check-in was '
#                            'very flexible and uncomplicated. I would definetly '
#                            'come back. Thanks for making our stay '
#                            'unforgettable. '},
#               {'listing_id': '1043046',
#                'review_id': '147369111',
#                'date': datetime.datetime(2017, 4, 26, 0, 0),
#                'reviewer_id': '64587690',
#                'reviewer_name': 'Kati',
#                'comments': 'Super location at the centre of Manhattan. '
#                            'Everything is within walking distance or if you '
#                            'need to use the subway, then all the main subway '
#                            'lines are just a few blocks away. <br/>Apartment '
#                            'is very quiet an cozy, like you are not in a city '
#                            'that never sleeps :)<br/>We stayed for 8 nights at '
#                            'Lindsays place.<br/>The best airbnb experiences '
#                            "we've had!<br/>"},
#               {'listing_id': '1043046',
#                'review_id': '154246275',
#                'date': datetime.datetime(2017, 5, 23, 0, 0),
#                'reviewer_id': '37359107',
#                'reviewer_name': 'Darryl',
#                'comments': "Excellent stay in New York at Lindsay's place. "
#                            'Highly recommended.'},
#               {'listing_id': '1043046',
#                'review_id': '178470104',
#                'date': datetime.datetime(2017, 8, 5, 0, 0),
#                'reviewer_id': '107984740',
#                'reviewer_name': 'Megan',
#                'comments': 'This is such a fantastic apartment and quite '
#                            "spacious for a studio. It's exactly as per the "
#                            "pictures; fresh, airy and bright!<br/>It's super "
#                            'quiet considering the bustling location as it '
#                            'faces internal into a gorgeous courtyard rather '
#                            'than onto the street. <br/>It was a hot NYC month '
#                            'and the fan and AC did a great job, otherwise '
#                            'keeping the windows open worked great.<br/>The '
#                            'location is amazing, a 20 second walk to the '
#                            'subway and so close to walk everywhere trendy near '
#                            'the Chelsea, SOHO, West Village and Greenwich '
#                            'Village areas. With so many great places to eat '
#                            "close by there wasn't really a need to cook but "
#                            'when I did I had everything I needed.<br/>The '
#                            'bathroom was perfect for me and I found the shower '
#                            "pressure great as I'd seen previous comments about "
#                            'it.<br/>Lindsay was awesome to coordinate my '
#                            'arrival and took the time to explain everything to '
#                            'me. She then left me to enjoy my time for the '
#                            'month, checking in after 2 weeks to see if I '
#                            'needed anything. A perfect host!<br/>I would stay '
#                            'here again in a heartbeat, it truly felt like '
#                            'home!<br/>Thank you Lindsay! '},
#               {'listing_id': '1043046',
#                'review_id': '183949040',
#                'date': datetime.datetime(2017, 8, 18, 0, 0),
#                'reviewer_id': '34003740',
#                'reviewer_name': 'Taiana',
#                'comments': "I didn't get the chance to meet Lindsay in person, "
#                            'but her brother checked us in the apartment at '
#                            'moment we got to NYC. He explained everything we '
#                            'needed to know, and we felt like they were both '
#                            'available to help during our stay.<br/>The studio '
#                            'is exactly as shown in pictures and it had all the '
#                            'itens anyone could need.<br/>Lindsay is right when '
#                            'she said it is the best possible location in New '
#                            'York! It is very close to Chelsea Market and the '
#                            'Highline, and we enjoyed so much walking around '
#                            'this area, during the day and by night; the '
#                            'neighborhood had lot of cool options.<br/>We felt '
#                            'like home and would definitely recommend it :)'},
#               {'listing_id': '1043046',
#                'review_id': '187263636',
#                'date': datetime.datetime(2017, 8, 26, 0, 0),
#                'reviewer_id': '9430480',
#                'reviewer_name': 'Dina',
#                'comments': 'El apartamento es muy cálido y la ubicación e s '
#                            'perfecta para pasar unos días maravillosos en NY.'},
#               {'listing_id': '1043046',
#                'review_id': '192078185',
#                'date': datetime.datetime(2017, 9, 9, 0, 0),
#                'reviewer_id': '13901569',
#                'reviewer_name': 'Ann',
#                'comments': "We loved staying at Lindsay's studio for 8 nights "
#                            "this last week.  Couldn't have found a better "
#                            'location - minutes away from everything and a '
#                            'subway stop just steps from the front door of the '
#                            'building.  Felt safe everywhere we went & the room '
#                            'was quiet - even with the windows open!  Perfect '
#                            'room for 2 people - a comfy bed and warm shower.  '
#                            'Loved it all!  Lindsay was a wonderful and '
#                            'accommodating when she let us check in early in '
#                            'the morning after our red-eye flight into the '
#                            'city.  Totally recommend it!  Thank you Lindsay!'},
#               {'listing_id': '1043046',
#                'review_id': '195499796',
#                'date': datetime.datetime(2017, 9, 19, 0, 0),
#                'reviewer_id': '493564',
#                'reviewer_name': 'Sandro',
#                'comments': "Lindsay's house was perfect for our week in NY. It "
#                            'is spacious enough for two people, cozy, the bed '
#                            'is super comfy, the cleanliness was evident (and '
#                            'easy to maintain), the shower is perfect and, very '
#                            'importantly, it is quiet. It could not be better '
#                            'after a day of walking around the city. Apart from '
#                            'being in Chelsea, a very nice area, the subway is '
#                            'just steps from the door of the building. We did '
#                            'not know Lindsay, but she was always available to '
#                            'answer our questions during the reservation and '
#                            'stay. And responding too fast. The checkin and '
#                            'checkout were very simple. We highly recommend '
#                            "choosing Lindsay's house to stay in NY."},
#               {'listing_id': '1043046',
#                'review_id': '285000292',
#                'date': datetime.datetime(2018, 7, 2, 0, 0),
#                'reviewer_id': '948095',
#                'reviewer_name': 'Ellen',
#                'comments': 'Outstanding location. Exactly as shown in the '
#                            'pictures. Lindsay went out of her way to '
#                            'accommodate our extremely early arrival on the day '
#                            'we checked in, was truly great about making that '
#                            'work. Place very cute and sweet building. '
#                            'Literally steps from the A,C,E,L trains and '
#                            'crosstown bus. Could maybe benefit from one more '
#                            'chair for two people but we were comfortable and '
#                            'pleased with the value.'},
#               {'listing_id': '1043046',
#                'review_id': '295909892',
#                'date': datetime.datetime(2018, 7, 24, 0, 0),
#                'reviewer_id': '70770500',
#                'reviewer_name': 'Riccardo',
#                'comments': 'Lovely flat in one of the best locations of NYC, '
#                            'once you get out on the street it seems to be on a '
#                            'movie. The flat is tiny and typical old NY style '
#                            'but comfortable for 1-2 person with all facilities '
#                            'that you may need. Highly suggested if you prefer '
#                            'location to bigger dimensions '},
#               {'listing_id': '1043046',
#                'review_id': '197710711',
#                'date': datetime.datetime(2017, 9, 26, 0, 0),
#                'reviewer_id': '8219924',
#                'reviewer_name': 'Susanne',
#                'comments': "We stayed at Lindsay's apartment for 5 days. "
#                            "Although we didn't meet her in person, it was "
#                            'really easy and nice to communicate with her via '
#                            'Airbnb. She also left us little notes and fresh '
#                            'flowers in her apartment- which was really sweet. '
#                            'The location is situated perfectly to explore '
#                            'Manhattan and the rest of the town by foot, bike '
#                            'or subway. The next subway station (14 St) is '
#                            'literally 1 minute away from the apartment and you '
#                            'can reach the next citibike location in 2 minutes. '
#                            'The neighborhood is really nice (Chelsea market '
#                            'and the High Line just around the corner) and '
#                            'everything you need (cafes, bars, restaurants, '
#                            'pharmacies...) is in walking distance. The '
#                            'apartment itself was really clean and equipped '
#                            'with all necessities (it appeared a bit darker '
#                            'than on the pictures - but that was the only thing '
#                            'that differed from the pictures). We really liked '
#                            'our stay and would definitely come back!'},
#               {'listing_id': '1043046',
#                'review_id': '213299023',
#                'date': datetime.datetime(2017, 11, 20, 0, 0),
#                'reviewer_id': '41735304',
#                'reviewer_name': 'Karin',
#                'comments': "We spent 3 weeks in Lindsay's apartment and felt "
#                            'comfortable. The apartment is really well located, '
#                            'clean and relatively quiet.  Everything was fine. '
#                            'Lindsay was a very friendly host.'},
#               {'listing_id': '1043046',
#                'review_id': '216775656',
#                'date': datetime.datetime(2017, 12, 5, 0, 0),
#                'reviewer_id': '67943492',
#                'reviewer_name': 'Matt',
#                'comments': 'Lindsay’s place is the perfect place for a couple '
#                            'looking to explore the city. It’s right by the '
#                            'subway, Chelsea Market (amazing food) and so much '
#                            'more. I highly recommend this place. Don’t stay in '
#                            'a overpriced hotel when you can stay with the '
#                            'locals'},
#               {'listing_id': '1043046',
#                'review_id': '218914236',
#                'date': datetime.datetime(2017, 12, 15, 0, 0),
#                'reviewer_id': '107681370',
#                'reviewer_name': 'David',
#                'comments': 'Lindsay Is The perfect host. The appartment Is '
#                            'What you look. Great location And very warm '
#                            'Place!'},
#               {'listing_id': '1043046',
#                'review_id': '223671200',
#                'date': datetime.datetime(2018, 1, 1, 0, 0),
#                'reviewer_id': '129442568',
#                'reviewer_name': 'Keith',
#                'comments': 'The apartment was perfect! Brilliant location, '
#                            'safe and quiet. Lindsay was amazing waiting for us '
#                            'to arrive even when our flight was delayed and was '
#                            'really friendly! We would definitely come back :D'},
#               {'listing_id': '1043046',
#                'review_id': '233693585',
#                'date': datetime.datetime(2018, 2, 10, 0, 0),
#                'reviewer_id': '1615972',
#                'reviewer_name': 'Anirvan',
#                'comments': 'I stayed here for 4 weeks and it was a super '
#                            'comfortable stay. Location was great - less than '
#                            '100 feet from an ACE station entrance. Not too '
#                            'loud. Basic amenities and heating were great. '
#                            'Place was cozy, bed was comfortable.'},
#               {'listing_id': '1043046',
#                'review_id': '236148339',
#                'date': datetime.datetime(2018, 2, 18, 0, 0),
#                'reviewer_id': '7468612',
#                'reviewer_name': 'Calvin',
#                'comments': "This was my first time visiting NYC and Lindsay's "
#                            'apartment made me feel at home. The spot is very '
#                            'centrally located and you will find everything '
#                            'important within walking distance.<br/>If you '
#                            'wanna stay in a cozy place and experience NYC from '
#                            'a locals point of view, this is the place to '
#                            'stay!<br/>- Vicky<br/>I was here for work and '
#                            'stuck in a shitty box for accommodation, until I '
#                            "found Lindsay's spot. Centrally located, quiet "
#                            'apartment in the middle of a lively neighborhood. '
#                            'The subway is literally 10 steps from the front '
# ...
#                            'stay. Hot tub was an extra special addition to the '
#                            'enjoyment of our stay. The location was awesome. '
#                            'Just around the corner from the most amazing '
#                            'health food cafe called BKLYN Blend. Close to '
#                            'several grocery stores like Mr. Kiwi, Horse Radish '
#                            'and more, close to subway lines and a finely '
#                            'curated Wine Shop call Vin De Table.  Host cares '
#                            'about the comfort of the guests and is very '
#                            'helpful and responsive. We also checked out the '
#                            'Brooklyn Museum which was about 2.6 miles away so '
#                            'a short / cheap car ride away and is such a '
#                            'beautiful building with cool exhibitions and '
#                            'permanent collections. Highly recommend and would '
#                            'stay here again. Thank you!'},
#               {'listing_id': '10386341',
#                'review_id': '1036281667263281144',
#                'date': datetime.datetime(2023, 11, 30, 0, 0),
#                'reviewer_id': '337997141',
#                'reviewer_name': 'Babra Constanza',
#                'comments': 'Acogedor y muy limpio! Tuve una muy buena estadía '
#                            'en el lugar. 100% Recomendado. Jeremy es un súper '
#                            'anfitrión. El sector es todo lo que esperé. Si '
#                            'quieres llegar a un lugar que te reciba como en tu '
#                            'casa, después de haber caminado interminables '
#                            'horas, este es el airbnb correcto.'},
#               {'listing_id': '10386341',
#                'review_id': '1038539330402654337',
#                'date': datetime.datetime(2023, 12, 3, 0, 0),
#                'reviewer_id': '59654477',
#                'reviewer_name': 'Amanda',
#                'comments': 'Place super clean, and perfect size just as '
#                            'listed. It was very close to public transit that '
#                            'made it easy to get around!'},
#               {'listing_id': '10386341',
#                'review_id': '1044259609869466503',
#                'date': datetime.datetime(2023, 12, 11, 0, 0),
#                'reviewer_id': '39056242',
#                'reviewer_name': 'Charlotte',
#                'comments': 'Thank you for a wonderful stay at your private '
#                            'apartment. We felt very at home, with plenty of '
#                            'space and the beds were super comfy. We loved '
#                            'walking around the area and it was easy to get '
#                            'into Manhattan. Jeremy also provided an amazing '
#                            'restaurant recommendation which I am still '
#                            'dreaming about! Overall, a fab stay and would love '
#                            'to visit again! :)'},
#               {'listing_id': '10386341',
#                'review_id': '1046430645361058009',
#                'date': datetime.datetime(2023, 12, 14, 0, 0),
#                'reviewer_id': '548975484',
#                'reviewer_name': 'Kasey',
#                'comments': 'Jeremy’s place was very cozy. He was super '
#                            'responsive with messaging while we were there. '
#                            'Super friendly and helpful. We will definitely '
#                            'stay here again! Jeremy’s place is located near '
#                            'the subways and  convenient to explore all of NYC! '
#                            'We felt at home and safe during the duration of '
#                            'our stay!'},
#               {'listing_id': '10386341',
#                'review_id': '1048596212075100448',
#                'date': datetime.datetime(2023, 12, 17, 0, 0),
#                'reviewer_id': '429991560',
#                'reviewer_name': 'Alex',
#                'comments': 'Nice location chekin and check out'},
#               {'listing_id': '10386341',
#                'review_id': '1050769608529828921',
#                'date': datetime.datetime(2023, 12, 20, 0, 0),
#                'reviewer_id': '351917711',
#                'reviewer_name': 'Amanda',
#                'comments': 'Jeremy is a great host - very friendly, he was '
#                            'responsive from the get go with answering '
#                            'questions before and during my booking process all '
#                            'the way up to my departure. <br/>Even the simplest '
#                            'request - like the remote needing new batteries - '
#                            'he responded and took care of right away! '
#                            '<br/>Everything is exactly as pictured and '
#                            'described in the listing and I loved having my own '
#                            'space.  definitely get a large space for a great '
#                            "value!  Plus the hot tub (although I didn't use it "
#                            'this trip because I was too cold lol, but I will '
#                            'definitely return.)<br/>The only downside was the '
#                            'construction right next door, otherwise it seems '
#                            'to be a nice, quiet and private neighborhood.  But '
#                            'of course Jeremy has no control over construction '
#                            "and it is NYC after all 🙂 so that wasn't a big "
#                            'deal to me.<br/>Thanks for a great stay!  Happy '
#                            'Holidays to you and your family!'},
#               {'listing_id': '10386341',
#                'review_id': '1058823029754825737',
#                'date': datetime.datetime(2023, 12, 31, 0, 0),
#                'reviewer_id': '209199482',
#                'reviewer_name': 'Philippe',
#                'comments': 'Spacious place with privacy. Very central in '
#                            'Brooklyn and the access to Manhattan is easy. '
#                            'Super clean, Jeremy is great and offer a perfect '
#                            'service. We left our bags to enjoy our last day '
#                            'and it’s been very helpful.'},
#               {'listing_id': '10386341',
#                'review_id': '1063804376352613249',
#                'date': datetime.datetime(2024, 1, 7, 0, 0),
#                'reviewer_id': '13999775',
#                'reviewer_name': 'Julie',
#                'comments': 'Le séjour passé chez Jérémy était très bien ! Le '
#                            'logement était très propre et très chaleureux et '
#                            'les indications pour rentrer dans le logement '
#                            "étaient claires. La communication avec l'hôte "
#                            'était très facile également et ce avant et dès '
#                            'notre arrivée dans le airbnb.<br/>Nous avions bien '
#                            'apprécié le jacuzzi après une longue journée de '
#                            'marche à Manhattan.<br/>Pour ceux et celles qui '
#                            "viennent en voiture, sachez qu'il est difficile de "
#                            'se stationner surtout en semaine, car il faut '
#                            'changer de place de stationnement et les places '
#                            'sont peu nombreuses.  <br/>Sinon très bon séjour '
#                            '!'},
#               {'listing_id': '10386341',
#                'review_id': '1066787860147558002',
#                'date': datetime.datetime(2024, 1, 11, 0, 0),
#                'reviewer_id': '190902467',
#                'reviewer_name': 'Mallorie',
#                'comments': 'Jeremy and Carsten were incredible hosts! Such a '
#                            'fantastic spot in a quiet neighborhood with lots '
#                            'of great restaurants and coffee shops within '
#                            'walking distance. We cooked in the kitchen and '
#                            'relaxed in the hot tub almost every night which '
#                            'was the perfect cherry on top of an otherwise '
#                            'awesome space. I’d love to stay here again!'},
#               {'listing_id': '10386341',
#                'review_id': '1071795580920589621',
#                'date': datetime.datetime(2024, 1, 18, 0, 0),
#                'reviewer_id': '198436518',
#                'reviewer_name': 'Gavin',
#                'comments': 'Wonderfull stay. Jeremy is an a+ host. Cant wait '
#                            'to come back'},
#               {'listing_id': '10386341',
#                'review_id': '1073999858938399664',
#                'date': datetime.datetime(2024, 1, 21, 0, 0),
#                'reviewer_id': '267981888',
#                'reviewer_name': 'Torrye',
#                'comments': 'Definitely a great place to stay while visiting '
#                            'New York away from the city life!'},
#               {'listing_id': '10386341',
#                'review_id': '234007523',
#                'date': datetime.datetime(2018, 2, 11, 0, 0),
#                'reviewer_id': '11763950',
#                'reviewer_name': 'Brian',
#                'comments': 'Awesome space, love Jeremy!!'},
#               {'listing_id': '10386341',
#                'review_id': '92398711',
#                'date': datetime.datetime(2016, 8, 8, 0, 0),
#                'reviewer_id': '53310389',
#                'reviewer_name': 'Farshed',
#                'comments': 'Everything was great '},
#               {'listing_id': '10386341',
#                'review_id': '114830378',
#                'date': datetime.datetime(2016, 11, 20, 0, 0),
#                'reviewer_id': '21260671',
#                'reviewer_name': 'Johnna',
#                'comments': 'Great place! Fantastic and kind host! '},
#               {'listing_id': '10386341',
#                'review_id': '140534571',
#                'date': datetime.datetime(2017, 3, 30, 0, 0),
#                'reviewer_id': '30938038',
#                'reviewer_name': 'Diana',
#                'comments': 'Great place!'},
#               {'listing_id': '10386341',
#                'review_id': '153560495',
#                'date': datetime.datetime(2017, 5, 21, 0, 0),
#                'reviewer_id': '120732731',
#                'reviewer_name': 'Christie',
#                'comments': 'Definitely a clean and beautiful place! '},
#               {'listing_id': '10386341',
#                'review_id': '274599861',
#                'date': datetime.datetime(2018, 6, 9, 0, 0),
#                'reviewer_id': '65820833',
#                'reviewer_name': 'Peter',
#                'comments': 'Very clean and spacious. Excellent host.'},
#               {'listing_id': '10386341',
#                'review_id': '254914507',
#                'date': datetime.datetime(2018, 4, 18, 0, 0),
#                'reviewer_id': '38821991',
#                'reviewer_name': 'Anouk',
#                'comments': 'Absolut empfehlenswert!<br/>Anhand der guten '
#                            'Bewertungen zum Thema Sicherheit und gute Betten '
#                            'sind wir zuerst auf diese Unterkunft aufmerksam '
#                            'geworden.<br/>Wir waren sehr zufrieden mit unserer '
#                            'Woche in Jeremys Wohnung.<br/>Jeremy ist ein sehr '
#                            'guter Gastgeber, er hat nahezu prompt auf unsere '
#                            'Fragen reagiert und auch bei einem Problem, was '
#                            'wir hatten, war er sofort sehr '
#                            'hilfsbereit.<br/>Die Wohnung ist sehr schön '
#                            'eingerichtet, vom Fön über Mikrowelle und Toaster '
#                            'ist alles vorhanden was man benötigt, ebenso sehr '
#                            'viele Handtücher bezogene Betten etc.<br/>Die '
#                            'Betten sind einfach nur großartig! Riesig und '
#                            'extrem bequem, das macht sehr viel aus, wenn man '
#                            'den ganzen Tag auf den Beinen ist.<br/>Wie überall '
#                            'in Amerika scheinen die Wände aus Papier zu sein, '
#                            'die Vermieter wohnen oben drüber, Fernseher, '
#                            'Laufen und Klavier spielen war sehr deutlich zu '
#                            'hören. Wer sehr früh schlafen geht, könnte es als '
#                            'störend empfinden, ab 22/23 Uhr war es aber sehr '
#                            'ruhig, auch die Straße ist erstaunlich '
#                            'ruhig.<br/>Die Wohnung ist durch eine extra '
#                            'Metalltür gesichert, daher haben wir uns sowohl in '
#                            'der Wohnung als auch auf dem Weg zur U-Bahn (5 '
#                            'Minuten) sicher gefühlt. Es handelt sich um eine '
#                            'reine Wohngegend, die anderen dort lebenden '
#                            'Menschen gehen ihren eigenen Dingen nach, man wird '
#                            'weder angeschaut noch fühlt sich anderweitig '
#                            'unwohl.<br/>Mit der U-Bahn ist man in ungefähr '
#                            '35-45 Minuten am Broadway (1x umsteigen), was '
#                            'völlig ok ist, da man ja meist nur ein Mal rein '
#                            'und wieder zurück fährt. Unschlagbar ist die Lage '
#                            'in Brooklyn, in ca. 20 Minuten mit etwas Laufen '
#                            'ist man in Williamsburg, einfach großartig '
#                            '(samstags Smorgasburg, East River State Park) und '
#                            'auch in DUMBO ist man in ca. 25 Minuten. <br/>Es '
#                            'lohnt sich wirklich für Brooklyn mindestens einen '
#                            'oder besser zwei Tage einzuplanen!<br/>Insgesamt '
#                            'hatten wir eine wunderbare Zeit in der Wohnung und '
#                            'würden es jedem empfehlen bzw. auch selber wieder '
#                            'hinfahren.<br/>Danke an Jeremy!'},
#               {'listing_id': '10386341',
#                'review_id': '283719355',
#                'date': datetime.datetime(2018, 6, 30, 0, 0),
#                'reviewer_id': '94115205',
#                'reviewer_name': 'Kate',
#                'comments': 'Great hosts!'},
#               {'listing_id': '10386341',
#                'review_id': '425126886',
#                'date': datetime.datetime(2019, 3, 17, 0, 0),
#                'reviewer_id': '21974268',
#                'reviewer_name': 'Annie',
#                'comments': 'Was great.'},
#               {'listing_id': '10386341',
#                'review_id': '449409984',
#                'date': datetime.datetime(2019, 5, 6, 0, 0),
#                'reviewer_id': '244141490',
#                'reviewer_name': 'Pat',
#                'comments': 'quiet, clean and sunny apartment.'},
#               {'listing_id': '10386341',
#                'review_id': '475601654',
#                'date': datetime.datetime(2019, 6, 24, 0, 0),
#                'reviewer_id': '8291715',
#                'reviewer_name': 'Kelly',
#                'comments': 'Good spot, would stay here again.'},
#               {'listing_id': '10386341',
#                'review_id': '439090240072096550',
#                'date': datetime.datetime(2021, 8, 28, 0, 0),
#                'reviewer_id': '74189748',
#                'reviewer_name': 'Chad',
#                'comments': 'Great place.  Would stay here again.'},
#               {'listing_id': '10386341',
#                'review_id': '465206176662759943',
#                'date': datetime.datetime(2021, 10, 3, 0, 0),
#                'reviewer_id': '206652294',
#                'reviewer_name': 'Rhys',
#                'comments': "Fantastic place and location.  Couldn't ask for "
#                            'better.'}]}]
