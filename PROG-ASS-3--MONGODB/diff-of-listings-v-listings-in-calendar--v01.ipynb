# %%
import sys
import json
import csv
import yaml

import importlib

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('helper_functions/')
# import util as util
import util

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up, and focusing on airbnb database</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

db = client.airbnb

# %%
print(db.list_collection_names())
# Out:
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'calendar_by_agg', 'calendar_previously_built', 'listings']

# %% [markdown]
# <span style=color:blue>Copying the collection 'listings_previously_built' into listings_with_reviews'</span>
#
# <span style=color:blue>Following https://stackoverflow.com/questions/39788664/how-can-i-copy-one-collection-from-mongodb-using-pymongo-and-paste-to-another-em</span>

# %%
db.listings_with_reviews.drop()

pipeline = [ {'$match': {}},
             {'$out': 'listings_with_reviews'}
           ]
db.listings_previously_built.aggregate(pipeline)

print(db.list_collection_names())
# count1 = db.listings_previously_built.count_documents({})
print(f'Size of listings_previously_built is {db.listings_previously_built.count_documents({})}.')
print(f'Size of listings_with_reviews is {db.listings_with_reviews.count_documents({})}.')
# Out:
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings', 'listings_test', 'listings_with_reviews', 'calendar_by_agg', 'calendar_previously_built']
# Size of listings_previously_built is 39202.
# Size of listings_with_reviews is 39202.

# %%
pprint.pp(db.listings_with_reviews.find_one())
print('=======================================')
pprint.pp(db.listings_with_calendar.find_one())
# Out:
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}]}
# =======================================
# {'_id': '10000070',
#  'average_price': 85.0,
#  'earliest_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
# ...
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %%
# do a left join of listings_with_reviews and listings_with_calendar
# then look for docs in there with no value for the listings_with_calendar id



pipeline1 = [
    { '$lookup' : {
          'from': 'listings_with_calendar',
          'localField' : 'id',
          'foreignField' : '_id',
          'as' : 'cal_docs' 
        }
    },
    {'$match' : {
        'cal_docs' : {'$eq' : []}                
              }
  }
]

time1 = datetime.now()
test1 = db.listings_with_reviews.aggregate(pipeline1)
time2 = datetime.now()
print(f'This operation took {util.time_diff(time1, time2)} seconds.')
# Out:
# This operation took 5.653047 seconds.

# %%
print(type(test1))

print()
for doc in list(test1):
    # doc = test1.next()
    pprint.pp(doc['id'])
# Out:
# <class 'pymongo.command_cursor.CommandCursor'>
#
# '35384734'

# %%
"""
BTW, here are 2 queries in SQL to find this "missing" listing_id. 
The first one takes forever to run - more than 40 minutes
The second takes about 

-- optional for first query: create index on listing_id in calendar
create index if not exists listing_id_in_calendar
on calendar(listing_id)
-- took about 10 seconds

select id 
from listings l 
where id not in ( 
    select listing_id
    from calendar)
-- I gave up after about 40 minutes
    
-- in PostgreSQL, they use "EXCEPT" instead of "MINUS" (aargh!!!)
with ids_in_listings as
(select distinct id 
 from listings),
listing_ids_in_calendar as
(select distinct listing_id as id 
 from calendar)
(select id
 from ids_in_listings
 except
 select id 
 from listing_ids_in_calendar
)
-- takes about 2 seconds


"""
