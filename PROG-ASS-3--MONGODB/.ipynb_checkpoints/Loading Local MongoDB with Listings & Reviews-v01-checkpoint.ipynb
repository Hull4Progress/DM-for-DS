# %% [markdown]
# ### <span style=color:blue> Loading Listings & Reviews data from postgresql into local MongoDB    </span>

# %%
import sys
import json
import csv
import yaml

import importlib

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('helper_functions/')
# import util as util
import util

# %%
# test that utils.py has been imported well
util.hello_world()
# Out:
# hello world

# %% [markdown]
# <span style=color:blue>Getting PostgreSQL connection set up</span>

# %%
# Load the env file 

dotenv_path = 'env_variables.env'
load_dotenv(dotenv_path=dotenv_path)

# Import the env variables

load_dotenv()

schema = os.getenv('DISC_6_SCHEMA')
port = os.getenv('DISC_6_PORT')
host = os.getenv('DISC_6_HOST')
database = os.getenv('DISC_6_DB')
password = os.getenv('DISC_6_PASSWORD')
connection = os.getenv('DISC_6_CONNECTION')

# Create the db engine 

db_eng = create_engine(f"postgresql+psycopg2://{connection}:{password}@{host}:{port}/{database}",
                       connect_args={'options': '-csearch_path={}'.format(schema)},
                       isolation_level = 'SERIALIZABLE')

print("Successfully created db engine.")
# Out:
# Successfully created db engine.

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# <span style=color:blue>Setting up collection "listings" in mongodb</span>

# %%
# I have (or will have) a database "airbnb"
db = client.airbnb

# inside the "airbnb" database, I have (or will have) a collection "listings"
listings = db.listings
print(db.list_collection_names())
# Out:
# ['testing']

# %% [markdown]
# <span style=color:blue>Function to convert dates into datetimes.</span>
#
# <span style=color:blue>It also has conditions that turn various kinds of null values into None.  (Curiously this works on small dataframes, but left some values of "NaT" when applied on very large dataframes.  So, I had to apply the function on a dictionary built from the dataframes.)</span>

# %%
import math
n1 = math.nan
print(n1)
print(math.isnan(n1))

n2 = pd.NaT
print()
print(n2)
print(pd.isnull(n2))

testing = db.testing

dict = {'date': datetime(2023, 1, 1,0,0,0)}

ts = dict['date'].timestamp()
print()
print(ts)
output = db.testing.insert_one({'date': datetime.fromtimestamp(ts)})
print(db.testing.find_one({'_id': output.inserted_id}))

# also converts NaT to None, because MongoDB does not recognize NaT
def convert_date_to_datetime(dt):
    if dt is None:
        return None
    elif pd.isnull(dt):  # tests whether dt is the pandas value NaT ("not a time")
        # print('\nEntered the NaT case\n')
        return None
    elif dt != dt:
        return None        # could also use math.nan, I think
    else:
        temp = datetime(dt.year, dt.month, dt.day)
        ts = temp.timestamp()
        new_dt = datetime.fromtimestamp(ts)
        return new_dt

print('\nNow trying with the function')
print('Here are three dictionaries to test with.')
dict1 = {'foo':1, 'date': date(2023,1,2)}
dict2 = {'goo':2, 'date': math.nan}
dict3 = {'hoo':3, 'date': None}
dict4 = {'koo':4, 'date': pd.NaT}

if pd.isnull(dict4['date']):
    print("dict4['date'] tested positive as NaT")
else:
    print("dict4['date'] did not test positive as NaT")
    

print(dict1)
print(dict2)
print(dict3)
print(dict4)
dict1['date'] = convert_date_to_datetime(dict1['date'])
dict2['date'] = convert_date_to_datetime(dict2['date'])
dict3['date'] = convert_date_to_datetime(dict3['date'])
dict4['date'] = convert_date_to_datetime(dict4['date'])

# print(dict1)
# db.testing.insert_one(dict1)
print('\nAfter changing the dictionaries')
print(dict1)
print(dict2)
print(dict3)
print(dict4)

print('\nNow testing that the third and fourth dictionary can be uploaded into MongoDB successfully.')
output = db.testing.insert_one(dict3)
print(type(output))
print(db.testing.find_one({'_id': output.inserted_id}))
print()
output = db.testing.insert_one(dict4)
print(type(output))
print(db.testing.find_one({'_id': output.inserted_id}))
# Out:
# nan
# True
#
# NaT
# True
#
# 1672560000.0
# {'_id': ObjectId('664bbc4938b2bd10b476e159'), 'date': datetime.datetime(2023, 1, 1, 0, 0)}
#
# Now trying with the function
# Here are three dictionaries to test with.
# dict4['date'] tested positive as NaT
# {'foo': 1, 'date': datetime.date(2023, 1, 2)}
# {'goo': 2, 'date': nan}
# {'hoo': 3, 'date': None}
# {'koo': 4, 'date': NaT}
#
# After changing the dictionaries
# {'foo': 1, 'date': datetime.datetime(2023, 1, 2, 0, 0)}
# {'goo': 2, 'date': None}
# {'hoo': 3, 'date': None}
# {'koo': 4, 'date': None}
#
# Now testing that the third and fourth dictionary can be uploaded into MongoDB successfully.
# <class 'pymongo.results.InsertOneResult'>
# {'_id': ObjectId('664bbc4938b2bd10b476e15a'), 'hoo': 3, 'date': None}
#
# <class 'pymongo.results.InsertOneResult'>
# {'_id': ObjectId('664bbc4938b2bd10b476e15b'), 'koo': 4, 'date': None}

# %%
doc = db.testing.find_one()
obj_pointer = doc['_id']
print(type(obj_pointer))
print(obj_pointer)
print(doc)
print(type(doc['date']))
print(db.testing.find_one({'_id': obj_pointer}))
# Out:
# <class 'bson.objectid.ObjectId'>
# 664987068b80b91420d2b513
# {'_id': ObjectId('664987068b80b91420d2b513'), 'date': datetime.datetime(2023, 1, 1, 0, 0)}
# <class 'datetime.datetime'>
# {'_id': ObjectId('664987068b80b91420d2b513'), 'date': datetime.datetime(2023, 1, 1, 0, 0)}

# %% [markdown]
# <span style=color:blue>Dropping the collection "listings" to get a fresh start.    </span>

# %%
# recall that db is holding access to the airbnb database within the MongoDB client
db.listings.drop()
print(db.list_collection_names())
# Out:
# ['testing']

# %% [markdown]
# ### <span style=color:blue>As preparation for this, I have a table reviewm (for review_mongodb) in which I dropped the comments_tsv column (because not needed) and renamed column "id" to "review_id" (so that it is not repeating the "id" column of the listings table</span>

# %%
import importlib
import util
importlib.reload(util)

# q = util.build_query_full_join_listings_reviewsm()
# q = util.build_query_left_join_listings_reviewsm_null_right()
q = util.build_query_left_join_listings_reviewsm()

with db_eng.connect() as conn:
    # df_ljr100 = pd.read_sql(q, con=conn)
    df_ljr = pd.read_sql(q, con=conn)
    

# print(df_ljr100.head())
# print(df_ljr.head())
print(df_ljr_new.iloc[13870])
# Out:
# id                                                              1009467369984606523
# name                              Rental unit in New York · 2 bedrooms · 1 bed ·...
# host_id                                                                   305240193
# host_name                                                                      June
# neighbourhood_group                                                       Manhattan
# neighbourhood                                                              Gramercy
# latitude                                                                  40.736534
# longitude                                                                 -73.98062
# room_type                                                              Private room
# price                                                                         113.0
# minimum_nights                                                                   30
# number_of_reviews                                                                 0
# last_review                                                                     NaT
# reviews_per_month                                                               NaN
# calculated_host_listings_count                                                  333
# availability_365                                                                342
# number_of_reviews_ltm                                                             0
# license
# Name: 519326, dtype: object

# %%
# should be 998,310 rows.  This is
#     number of records in listings whose id do not show up in reviews['listing_id'] =  11,500
#   + number of reviews                                                              = 986,810
print(df_ljr.shape)
# Out:
# (998310, 24)

# %%
# cols = df_ljr100.columns.tolist()
cols = df_ljr.columns.tolist()
print(cols)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'license', 'listing_id', 'review_id', 'date', 'reviewer_id', 'reviewer_name', 'comments']

# %%
# to do a projection and remove duplicates
cols_of_listings = ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 
                    'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 
                    'minimum_nights', 'number_of_reviews', 'last_review', 
                    'reviews_per_month', 'calculated_host_listings_count', 
                    'availability_365', 'number_of_reviews_ltm', 'license']
cols_of_reviews = ['listing_id', 'review_id', 'date', 'reviewer_id', 
                   'reviewer_name', 'comments']

df_ljr_new = df_ljr.drop(cols_of_reviews, axis=1).drop_duplicates()

# df_ljr_new['last_review'] = df_ljr_new['last_review'].apply(lambda x: convert_date_to_datetime(x))
df_ljr_new['last_review'] = df_ljr_new['last_review'].apply(convert_date_to_datetime)

print(type(df_ljr_new.at[0,'last_review']))
print(str(df_ljr_new.at[0,'last_review']))

print(df_ljr_new.shape)
# print(df_ljr_new.head(10))

print(df_ljr_new.iloc[13870])
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# 2023-09-24 00:00:00
# (39202, 18)
# id                                                              1009467369984606523
# name                              Rental unit in New York · 2 bedrooms · 1 bed ·...
# host_id                                                                   305240193
# host_name                                                                      June
# neighbourhood_group                                                       Manhattan
# neighbourhood                                                              Gramercy
# latitude                                                                  40.736534
# longitude                                                                 -73.98062
# room_type                                                              Private room
# price                                                                         113.0
# minimum_nights                                                                   30
# number_of_reviews                                                                 0
# last_review                                                                     NaT
# reviews_per_month                                                               NaN
# calculated_host_listings_count                                                  333
# availability_365                                                                342
# number_of_reviews_ltm                                                             0
# license
# Name: 519326, dtype: object

# %%
dict_ljr_new = df_ljr_new.to_dict('records')
print(len(dict_ljr_new))
pprint.pp(dict_ljr_new[0])
# Out:
# 39202
# {'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': Timestamp('2023-09-24 00:00:00'),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': ''}

# %%
i = 0

for d in dict_ljr_new:
    i += 1

    df_reviews_one_listing = df_ljr.loc[df_ljr['id'] == d['id']].drop(cols_of_listings, axis=1)

    df_reviews_one_listing['date'] = df_reviews_one_listing['date'].apply(lambda x: convert_date_to_datetime(x))

    dicts_reviews_one_listing = df_reviews_one_listing.to_dict('records')

    if len(dicts_reviews_one_listing) == 1 and dicts_reviews_one_listing[0]['review_id'] is None:
        d['reviews'] = {}
    else:
        d['reviews'] = dicts_reviews_one_listing

    if i % 1000 == 0:
        print('Have now completed step number:', str(i))

print(len(dict_ljr_new))
pprint.pp(dict_ljr_new[-1:])
# Out:
# Have now completed step number: 1000
# Have now completed step number: 2000
# Have now completed step number: 3000
# Have now completed step number: 4000
# Have now completed step number: 5000
# Have now completed step number: 6000
# Have now completed step number: 7000
# Have now completed step number: 8000
# Have now completed step number: 9000
# Have now completed step number: 10000
# Have now completed step number: 11000
# Have now completed step number: 12000
# Have now completed step number: 13000
# Have now completed step number: 14000
# Have now completed step number: 15000
# Have now completed step number: 16000
# Have now completed step number: 17000
# Have now completed step number: 18000
# Have now completed step number: 19000
# Have now completed step number: 20000
# Have now completed step number: 21000
# Have now completed step number: 22000
# Have now completed step number: 23000
# Have now completed step number: 24000
# Have now completed step number: 25000
# Have now completed step number: 26000
# Have now completed step number: 27000
# Have now completed step number: 28000
# Have now completed step number: 29000
# Have now completed step number: 30000
# Have now completed step number: 31000
# Have now completed step number: 32000
# Have now completed step number: 33000
# Have now completed step number: 34000
# Have now completed step number: 35000
# Have now completed step number: 36000
# Have now completed step number: 37000
# Have now completed step number: 38000
# Have now completed step number: 39000
# 39202
# [{'id': '762393507139462217',
#   'name': 'Hotel in New York · 1 bedroom · 2 beds · 1 private bath',
#   'host_id': '202829797',
#   'host_name': 'Crystal',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Murray Hill',
#   'latitude': 40.749428,
#   'longitude': -73.97196,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 0,
#   'last_review': NaT,
#   'reviews_per_month': nan,
#   'calculated_host_listings_count': 3,
#   'availability_365': 364,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': {}}]

# %% [markdown]
# <span style=color:blue> Doing a bulk insert    </span>

# %%
print(len(dict_ljr_new))
# Out:
# 39202

# %% [markdown]
# <span style=color:blue>Now loading dict_ljr_new into mongodb.  The NaT values occurring in the 'last_review' field of listings need special treatment, unfortunately.     </span>
#
# <span style=color:blue>The loading is done 100 documents at a time, with a last small loat </span>

# %%
print(len(dict_ljr_new) % 100)
print(len(dict_ljr_new))
# Out:
# 2
# 39202

# %%
# CAUTION: the first step here erases db.listing
db.listings.drop()
print(db.list_collection_names())

# listings = db.listings

# successfully loaded up to i = 137, so uploaded up to number 13799  # oops - dropped the whole collection, sigh
# successfully loaded up to j = 6, so uploaded 13800 t0 13850


time1 = datetime.now()
for i in range(1,393):
# for j in range(0,10):
# for k in range(0,10):
    # testing for whether the 'last_review' value is NaT, and if so, changing it to None
    #    normally the "apply" function using the "change_date_to_datetime" should take care
    #    of this substitution, but it does not work on my mac for large df's.  
    #    (Oddly, it does work on small df's.)
    for j in range(0,100):
        if dict_ljr_new[100*i + j]['last_review'] != dict_ljr_new[100*i + j]['last_review']:
            dict_ljr_new[100*i + j]['last_review'] = None
    result = listings.insert_many(dict_ljr_new[100*i:100*(i+1)])
    # result = listings.insert_many(dict_ljr_new[13800 + 10*j:13800 + 10*(j+1)])
    # result = listings.insert_many(dict_ljr_new[13870 + k:13870 + k + 1])
    print('Last element of result for run number', str(i), 'was:')
    print(result.inserted_ids[-1:])
time2 = datetime.now()
print('The time to do the load of 39K documents into local mongodb, with a total of about 300MB was:')
print(util.time_diff(time1,time2))

print('\nThe last ObjectID in the collection is:')
print(result.inserted_ids[-1:])

# this is for the last 2 records in dict_ljr_new, but built for some number of records over 2
# again, testing for whether the 'last_review' value is NaT, and if so, changing it to None
for j in range(0,len(dict_ljr_new) % 100):
    if dict_ljr_new[39100 + j]['last_review'] != dict_ljr_new[39200 + j]['last_review']:
        dict_ljr_new[39200 + j]['last_review'] = None
result = listings.insert_many(dict_ljr_new[39200:])
print('\nLast element of result for the last run was:')
print(result.inserted_ids[-1:])


print('\nThe total number of documents in the collection db.listings is now:')
print(listings.count_documents({}))
# Out:
# ['testing']
# Last element of result for run number 1 was:
# [ObjectId('664b9cef38b2bd10b476abd4')]
# Last element of result for run number 2 was:
# [ObjectId('664b9cf038b2bd10b476ac38')]
# Last element of result for run number 3 was:
# [ObjectId('664b9cf038b2bd10b476ac9c')]
# Last element of result for run number 4 was:
# [ObjectId('664b9cf038b2bd10b476ad00')]
# Last element of result for run number 5 was:
# [ObjectId('664b9cf038b2bd10b476ad64')]
# Last element of result for run number 6 was:
# [ObjectId('664b9cf038b2bd10b476adc8')]
# Last element of result for run number 7 was:
# [ObjectId('664b9cf038b2bd10b476ae2c')]
# Last element of result for run number 8 was:
# [ObjectId('664b9cf138b2bd10b476ae90')]
# Last element of result for run number 9 was:
# [ObjectId('664b9cf138b2bd10b476aef4')]
# Last element of result for run number 10 was:
# [ObjectId('664b9cf138b2bd10b476af58')]
# Last element of result for run number 11 was:
# [ObjectId('664b9cf138b2bd10b476afbc')]
# Last element of result for run number 12 was:
# [ObjectId('664b9cf138b2bd10b476b020')]
# Last element of result for run number 13 was:
# [ObjectId('664b9cf138b2bd10b476b084')]
# Last element of result for run number 14 was:
# [ObjectId('664b9cf138b2bd10b476b0e8')]
# Last element of result for run number 15 was:
# [ObjectId('664b9cf138b2bd10b476b14c')]
# Last element of result for run number 16 was:
# [ObjectId('664b9cf138b2bd10b476b1b0')]
# Last element of result for run number 17 was:
# [ObjectId('664b9cf138b2bd10b476b214')]
# Last element of result for run number 18 was:
# [ObjectId('664b9cf138b2bd10b476b278')]
# Last element of result for run number 19 was:
# [ObjectId('664b9cf238b2bd10b476b2dc')]
# Last element of result for run number 20 was:
# [ObjectId('664b9cf238b2bd10b476b340')]
# Last element of result for run number 21 was:
# [ObjectId('664b9cf238b2bd10b476b3a4')]
# Last element of result for run number 22 was:
# [ObjectId('664b9cf238b2bd10b476b408')]
# Last element of result for run number 23 was:
# [ObjectId('664b9cf238b2bd10b476b46c')]
# Last element of result for run number 24 was:
# [ObjectId('664b9cf238b2bd10b476b4d0')]
# Last element of result for run number 25 was:
# [ObjectId('664b9cf238b2bd10b476b534')]
# Last element of result for run number 26 was:
# [ObjectId('664b9cf238b2bd10b476b598')]
# Last element of result for run number 27 was:
# [ObjectId('664b9cf238b2bd10b476b5fc')]
# Last element of result for run number 28 was:
# [ObjectId('664b9cf338b2bd10b476b660')]
# Last element of result for run number 29 was:
# [ObjectId('664b9cf338b2bd10b476b6c4')]
# Last element of result for run number 30 was:
# [ObjectId('664b9cf338b2bd10b476b728')]
# Last element of result for run number 31 was:
# [ObjectId('664b9cf338b2bd10b476b78c')]
# Last element of result for run number 32 was:
# [ObjectId('664b9cf338b2bd10b476b7f0')]
# Last element of result for run number 33 was:
# [ObjectId('664b9cf338b2bd10b476b854')]
# Last element of result for run number 34 was:
# [ObjectId('664b9cf338b2bd10b476b8b8')]
# Last element of result for run number 35 was:
# [ObjectId('664b9cf338b2bd10b476b91c')]
# Last element of result for run number 36 was:
# [ObjectId('664b9cf338b2bd10b476b980')]
# Last element of result for run number 37 was:
# [ObjectId('664b9cf338b2bd10b476b9e4')]
# Last element of result for run number 38 was:
# [ObjectId('664b9cf338b2bd10b476ba48')]
# Last element of result for run number 39 was:
# [ObjectId('664b9cf438b2bd10b476baac')]
# Last element of result for run number 40 was:
# [ObjectId('664b9cf438b2bd10b476bb10')]
# Last element of result for run number 41 was:
# [ObjectId('664b9cf438b2bd10b476bb74')]
# Last element of result for run number 42 was:
# [ObjectId('664b9cf438b2bd10b476bbd8')]
# Last element of result for run number 43 was:
# [ObjectId('664b9cf438b2bd10b476bc3c')]
# Last element of result for run number 44 was:
# [ObjectId('664b9cf438b2bd10b476bca0')]
# Last element of result for run number 45 was:
# [ObjectId('664b9cf438b2bd10b476bd04')]
# Last element of result for run number 46 was:
# [ObjectId('664b9cf438b2bd10b476bd68')]
# Last element of result for run number 47 was:
# [ObjectId('664b9cf438b2bd10b476bdcc')]
# Last element of result for run number 48 was:
# [ObjectId('664b9cf438b2bd10b476be30')]
# Last element of result for run number 49 was:
# [ObjectId('664b9cf438b2bd10b476be94')]
# Last element of result for run number 50 was:
# [ObjectId('664b9cf538b2bd10b476bef8')]
# Last element of result for run number 51 was:
# [ObjectId('664b9cf538b2bd10b476bf5c')]
# Last element of result for run number 52 was:
# [ObjectId('664b9cf538b2bd10b476bfc0')]
# Last element of result for run number 53 was:
# [ObjectId('664b9cf538b2bd10b476c024')]
# Last element of result for run number 54 was:
# [ObjectId('664b9cf538b2bd10b476c088')]
# Last element of result for run number 55 was:
# [ObjectId('664b9cf538b2bd10b476c0ec')]
# Last element of result for run number 56 was:
# [ObjectId('664b9cf538b2bd10b476c150')]
# Last element of result for run number 57 was:
# [ObjectId('664b9cf538b2bd10b476c1b4')]
# Last element of result for run number 58 was:
# [ObjectId('664b9cf538b2bd10b476c218')]
# Last element of result for run number 59 was:
# [ObjectId('664b9cf538b2bd10b476c27c')]
# Last element of result for run number 60 was:
# [ObjectId('664b9cf538b2bd10b476c2e0')]
# Last element of result for run number 61 was:
# [ObjectId('664b9cf538b2bd10b476c344')]
# Last element of result for run number 62 was:
# [ObjectId('664b9cf538b2bd10b476c3a8')]
# Last element of result for run number 63 was:
# [ObjectId('664b9cf538b2bd10b476c40c')]
# Last element of result for run number 64 was:
# [ObjectId('664b9cf538b2bd10b476c470')]
# Last element of result for run number 65 was:
# [ObjectId('664b9cf538b2bd10b476c4d4')]
# Last element of result for run number 66 was:
# [ObjectId('664b9cf538b2bd10b476c538')]
# Last element of result for run number 67 was:
# [ObjectId('664b9cf538b2bd10b476c59c')]
# Last element of result for run number 68 was:
# [ObjectId('664b9cf538b2bd10b476c600')]
# Last element of result for run number 69 was:
# [ObjectId('664b9cf538b2bd10b476c664')]
# Last element of result for run number 70 was:
# [ObjectId('664b9cf538b2bd10b476c6c8')]
# Last element of result for run number 71 was:
# [ObjectId('664b9cf538b2bd10b476c72c')]
# Last element of result for run number 72 was:
# [ObjectId('664b9cf538b2bd10b476c790')]
# Last element of result for run number 73 was:
# [ObjectId('664b9cf638b2bd10b476c7f4')]
# Last element of result for run number 74 was:
# [ObjectId('664b9cf638b2bd10b476c858')]
# Last element of result for run number 75 was:
# [ObjectId('664b9cf638b2bd10b476c8bc')]
# Last element of result for run number 76 was:
# [ObjectId('664b9cf638b2bd10b476c920')]
# Last element of result for run number 77 was:
# [ObjectId('664b9cf638b2bd10b476c984')]
# Last element of result for run number 78 was:
# [ObjectId('664b9cf638b2bd10b476c9e8')]
# Last element of result for run number 79 was:
# [ObjectId('664b9cf638b2bd10b476ca4c')]
# Last element of result for run number 80 was:
# [ObjectId('664b9cf638b2bd10b476cab0')]
# Last element of result for run number 81 was:
# [ObjectId('664b9cf638b2bd10b476cb14')]
# Last element of result for run number 82 was:
# [ObjectId('664b9cf638b2bd10b476cb78')]
# Last element of result for run number 83 was:
# [ObjectId('664b9cf638b2bd10b476cbdc')]
# Last element of result for run number 84 was:
# [ObjectId('664b9cf638b2bd10b476cc40')]
# Last element of result for run number 85 was:
# [ObjectId('664b9cf638b2bd10b476cca4')]
# Last element of result for run number 86 was:
# [ObjectId('664b9cf638b2bd10b476cd08')]
# Last element of result for run number 87 was:
# [ObjectId('664b9cf638b2bd10b476cd6c')]
# Last element of result for run number 88 was:
# [ObjectId('664b9cf638b2bd10b476cdd0')]
# Last element of result for run number 89 was:
# [ObjectId('664b9cf638b2bd10b476ce34')]
# Last element of result for run number 90 was:
# [ObjectId('664b9cf638b2bd10b476ce98')]
# Last element of result for run number 91 was:
# [ObjectId('664b9cf638b2bd10b476cefc')]
# Last element of result for run number 92 was:
# [ObjectId('664b9cf638b2bd10b476cf60')]
# Last element of result for run number 93 was:
# [ObjectId('664b9cf638b2bd10b476cfc4')]
# Last element of result for run number 94 was:
# [ObjectId('664b9cf638b2bd10b476d028')]
# Last element of result for run number 95 was:
# [ObjectId('664b9cf638b2bd10b476d08c')]
# Last element of result for run number 96 was:
# [ObjectId('664b9cf638b2bd10b476d0f0')]
# Last element of result for run number 97 was:
# [ObjectId('664b9cf638b2bd10b476d154')]
# Last element of result for run number 98 was:
# [ObjectId('664b9cf638b2bd10b476d1b8')]
# Last element of result for run number 99 was:
# [ObjectId('664b9cf638b2bd10b476d21c')]
# Last element of result for run number 100 was:
# [ObjectId('664b9cf638b2bd10b476d280')]
# Last element of result for run number 101 was:
# [ObjectId('664b9cf638b2bd10b476d2e4')]
# Last element of result for run number 102 was:
# [ObjectId('664b9cf638b2bd10b476d348')]
# Last element of result for run number 103 was:
# [ObjectId('664b9cf638b2bd10b476d3ac')]
# Last element of result for run number 104 was:
# [ObjectId('664b9cf638b2bd10b476d410')]
# Last element of result for run number 105 was:
# [ObjectId('664b9cf638b2bd10b476d474')]
# Last element of result for run number 106 was:
# [ObjectId('664b9cf638b2bd10b476d4d8')]
# Last element of result for run number 107 was:
# [ObjectId('664b9cf638b2bd10b476d53c')]
# Last element of result for run number 108 was:
# [ObjectId('664b9cf638b2bd10b476d5a0')]
# Last element of result for run number 109 was:
# [ObjectId('664b9cf738b2bd10b476d604')]
# Last element of result for run number 110 was:
# [ObjectId('664b9cf738b2bd10b476d668')]
# Last element of result for run number 111 was:
# [ObjectId('664b9cf738b2bd10b476d6cc')]
# Last element of result for run number 112 was:
# [ObjectId('664b9cf738b2bd10b476d730')]
# Last element of result for run number 113 was:
# [ObjectId('664b9cf738b2bd10b476d794')]
# Last element of result for run number 114 was:
# [ObjectId('664b9cf738b2bd10b476d7f8')]
# Last element of result for run number 115 was:
# [ObjectId('664b9cf738b2bd10b476d85c')]
# Last element of result for run number 116 was:
# [ObjectId('664b9cf738b2bd10b476d8c0')]
# Last element of result for run number 117 was:
# [ObjectId('664b9cf738b2bd10b476d924')]
# Last element of result for run number 118 was:
# [ObjectId('664b9cf738b2bd10b476d988')]
# Last element of result for run number 119 was:
# [ObjectId('664b9cf738b2bd10b476d9ec')]
# Last element of result for run number 120 was:
# [ObjectId('664b9cf738b2bd10b476da50')]
# Last element of result for run number 121 was:
# [ObjectId('664b9cf738b2bd10b476dab4')]
# Last element of result for run number 122 was:
# [ObjectId('664b9cf738b2bd10b476db18')]
# Last element of result for run number 123 was:
# [ObjectId('664b9cf738b2bd10b476db7c')]
# Last element of result for run number 124 was:
# [ObjectId('664b9cf738b2bd10b476dbe0')]
# Last element of result for run number 125 was:
# [ObjectId('664b9cf738b2bd10b476dc44')]
# Last element of result for run number 126 was:
# [ObjectId('664b9cf738b2bd10b476dca8')]
# Last element of result for run number 127 was:
# [ObjectId('664b9cf738b2bd10b476dd0c')]
# Last element of result for run number 128 was:
# [ObjectId('664b9cf738b2bd10b476dd70')]
# Last element of result for run number 129 was:
# [ObjectId('664b9cf738b2bd10b476ddd4')]
# Last element of result for run number 130 was:
# [ObjectId('664b9cf738b2bd10b476de38')]
# Last element of result for run number 131 was:
# [ObjectId('664b9cf738b2bd10b476de9c')]
# Last element of result for run number 132 was:
# [ObjectId('664b9cf738b2bd10b476df00')]
# Last element of result for run number 133 was:
# [ObjectId('664b9cf738b2bd10b476df64')]
# Last element of result for run number 134 was:
# [ObjectId('664b9cf738b2bd10b476dfc8')]
# Last element of result for run number 135 was:
# [ObjectId('664b9cf738b2bd10b476e02c')]
# Last element of result for run number 136 was:
# [ObjectId('664b9cf738b2bd10b476e090')]
# Last element of result for run number 137 was:
# [ObjectId('664b9cf738b2bd10b476e0f4')]
# Last element of result for run number 138 was:
# [ObjectId('664b9cf738b2bd10b476e158')]
# Last element of result for run number 139 was:
# [ObjectId('664be00c38b2bd10b476e1bf')]
# Last element of result for run number 140 was:
# [ObjectId('664be00c38b2bd10b476e223')]
# Last element of result for run number 141 was:
# [ObjectId('664be00c38b2bd10b476e287')]
# Last element of result for run number 142 was:
# [ObjectId('664be00c38b2bd10b476e2eb')]
# Last element of result for run number 143 was:
# [ObjectId('664be00c38b2bd10b476e34f')]
# Last element of result for run number 144 was:
# [ObjectId('664be00c38b2bd10b476e3b3')]
# Last element of result for run number 145 was:
# [ObjectId('664be00c38b2bd10b476e417')]
# Last element of result for run number 146 was:
# [ObjectId('664be00c38b2bd10b476e47b')]
# Last element of result for run number 147 was:
# [ObjectId('664be00c38b2bd10b476e4df')]
# Last element of result for run number 148 was:
# [ObjectId('664be00c38b2bd10b476e543')]
# Last element of result for run number 149 was:
# [ObjectId('664be00c38b2bd10b476e5a7')]
# Last element of result for run number 150 was:
# [ObjectId('664be00c38b2bd10b476e60b')]
# Last element of result for run number 151 was:
# [ObjectId('664be00c38b2bd10b476e66f')]
# Last element of result for run number 152 was:
# [ObjectId('664be00c38b2bd10b476e6d3')]
# Last element of result for run number 153 was:
# [ObjectId('664be00c38b2bd10b476e737')]
# Last element of result for run number 154 was:
# [ObjectId('664be00c38b2bd10b476e79b')]
# Last element of result for run number 155 was:
# [ObjectId('664be00c38b2bd10b476e7ff')]
# Last element of result for run number 156 was:
# [ObjectId('664be00c38b2bd10b476e863')]
# Last element of result for run number 157 was:
# [ObjectId('664be00c38b2bd10b476e8c7')]
# Last element of result for run number 158 was:
# [ObjectId('664be00c38b2bd10b476e92b')]
# Last element of result for run number 159 was:
# [ObjectId('664be00c38b2bd10b476e98f')]
# Last element of result for run number 160 was:
# [ObjectId('664be00c38b2bd10b476e9f3')]
# Last element of result for run number 161 was:
# [ObjectId('664be00c38b2bd10b476ea57')]
# Last element of result for run number 162 was:
# [ObjectId('664be00c38b2bd10b476eabb')]
# Last element of result for run number 163 was:
# [ObjectId('664be00c38b2bd10b476eb1f')]
# Last element of result for run number 164 was:
# [ObjectId('664be00c38b2bd10b476eb83')]
# Last element of result for run number 165 was:
# [ObjectId('664be00c38b2bd10b476ebe7')]
# Last element of result for run number 166 was:
# [ObjectId('664be00c38b2bd10b476ec4b')]
# Last element of result for run number 167 was:
# [ObjectId('664be00c38b2bd10b476ecaf')]
# Last element of result for run number 168 was:
# [ObjectId('664be00c38b2bd10b476ed13')]
# Last element of result for run number 169 was:
# [ObjectId('664be00c38b2bd10b476ed77')]
# Last element of result for run number 170 was:
# [ObjectId('664be00c38b2bd10b476eddb')]
# Last element of result for run number 171 was:
# [ObjectId('664be00c38b2bd10b476ee3f')]
# Last element of result for run number 172 was:
# [ObjectId('664be00c38b2bd10b476eea3')]
# Last element of result for run number 173 was:
# [ObjectId('664be00c38b2bd10b476ef07')]
# Last element of result for run number 174 was:
# [ObjectId('664be00c38b2bd10b476ef6b')]
# Last element of result for run number 175 was:
# [ObjectId('664be00c38b2bd10b476efcf')]
# Last element of result for run number 176 was:
# [ObjectId('664be00c38b2bd10b476f033')]
# Last element of result for run number 177 was:
# [ObjectId('664be00c38b2bd10b476f097')]
# Last element of result for run number 178 was:
# [ObjectId('664be00c38b2bd10b476f0fb')]
# Last element of result for run number 179 was:
# [ObjectId('664be00c38b2bd10b476f15f')]
# Last element of result for run number 180 was:
# [ObjectId('664be00c38b2bd10b476f1c3')]
# Last element of result for run number 181 was:
# [ObjectId('664be00c38b2bd10b476f227')]
# Last element of result for run number 182 was:
# [ObjectId('664be00c38b2bd10b476f28b')]
# Last element of result for run number 183 was:
# [ObjectId('664be00c38b2bd10b476f2ef')]
# Last element of result for run number 184 was:
# [ObjectId('664be00c38b2bd10b476f353')]
# Last element of result for run number 185 was:
# [ObjectId('664be00c38b2bd10b476f3b7')]
# Last element of result for run number 186 was:
# [ObjectId('664be00c38b2bd10b476f41b')]
# Last element of result for run number 187 was:
# [ObjectId('664be00c38b2bd10b476f47f')]
# Last element of result for run number 188 was:
# [ObjectId('664be00c38b2bd10b476f4e3')]
# Last element of result for run number 189 was:
# [ObjectId('664be00c38b2bd10b476f547')]
# Last element of result for run number 190 was:
# [ObjectId('664be00c38b2bd10b476f5ab')]
# Last element of result for run number 191 was:
# [ObjectId('664be00c38b2bd10b476f60f')]
# Last element of result for run number 192 was:
# [ObjectId('664be00c38b2bd10b476f673')]
# Last element of result for run number 193 was:
# [ObjectId('664be00c38b2bd10b476f6d7')]
# Last element of result for run number 194 was:
# [ObjectId('664be00c38b2bd10b476f73b')]
# Last element of result for run number 195 was:
# [ObjectId('664be00c38b2bd10b476f79f')]
# Last element of result for run number 196 was:
# [ObjectId('664be00c38b2bd10b476f803')]
# Last element of result for run number 197 was:
# [ObjectId('664be00c38b2bd10b476f867')]
# Last element of result for run number 198 was:
# [ObjectId('664be00c38b2bd10b476f8cb')]
# Last element of result for run number 199 was:
# [ObjectId('664be00c38b2bd10b476f92f')]
# Last element of result for run number 200 was:
# [ObjectId('664be00c38b2bd10b476f993')]
# Last element of result for run number 201 was:
# [ObjectId('664be00c38b2bd10b476f9f7')]
# Last element of result for run number 202 was:
# [ObjectId('664be00c38b2bd10b476fa5b')]
# Last element of result for run number 203 was:
# [ObjectId('664be00c38b2bd10b476fabf')]
# Last element of result for run number 204 was:
# [ObjectId('664be00d38b2bd10b476fb23')]
# Last element of result for run number 205 was:
# [ObjectId('664be00d38b2bd10b476fb87')]
# Last element of result for run number 206 was:
# [ObjectId('664be00d38b2bd10b476fbeb')]
# Last element of result for run number 207 was:
# [ObjectId('664be00d38b2bd10b476fc4f')]
# Last element of result for run number 208 was:
# [ObjectId('664be00d38b2bd10b476fcb3')]
# Last element of result for run number 209 was:
# [ObjectId('664be00d38b2bd10b476fd17')]
# Last element of result for run number 210 was:
# [ObjectId('664be00d38b2bd10b476fd7b')]
# Last element of result for run number 211 was:
# [ObjectId('664be00d38b2bd10b476fddf')]
# Last element of result for run number 212 was:
# [ObjectId('664be00d38b2bd10b476fe43')]
# Last element of result for run number 213 was:
# [ObjectId('664be00d38b2bd10b476fea7')]
# Last element of result for run number 214 was:
# [ObjectId('664be00d38b2bd10b476ff0b')]
# Last element of result for run number 215 was:
# [ObjectId('664be00e38b2bd10b476ff6f')]
# Last element of result for run number 216 was:
# [ObjectId('664be00e38b2bd10b476ffd3')]
# Last element of result for run number 217 was:
# [ObjectId('664be00e38b2bd10b4770037')]
# Last element of result for run number 218 was:
# [ObjectId('664be00e38b2bd10b477009b')]
# Last element of result for run number 219 was:
# [ObjectId('664be00e38b2bd10b47700ff')]
# Last element of result for run number 220 was:
# [ObjectId('664be00e38b2bd10b4770163')]
# Last element of result for run number 221 was:
# [ObjectId('664be00e38b2bd10b47701c7')]
# Last element of result for run number 222 was:
# [ObjectId('664be00e38b2bd10b477022b')]
# Last element of result for run number 223 was:
# [ObjectId('664be00e38b2bd10b477028f')]
# Last element of result for run number 224 was:
# [ObjectId('664be00e38b2bd10b47702f3')]
# Last element of result for run number 225 was:
# [ObjectId('664be00e38b2bd10b4770357')]
# Last element of result for run number 226 was:
# [ObjectId('664be00f38b2bd10b47703bb')]
# Last element of result for run number 227 was:
# [ObjectId('664be00f38b2bd10b477041f')]
# Last element of result for run number 228 was:
# [ObjectId('664be00f38b2bd10b4770483')]
# Last element of result for run number 229 was:
# [ObjectId('664be00f38b2bd10b47704e7')]
# Last element of result for run number 230 was:
# [ObjectId('664be00f38b2bd10b477054b')]
# Last element of result for run number 231 was:
# [ObjectId('664be00f38b2bd10b47705af')]
# Last element of result for run number 232 was:
# [ObjectId('664be00f38b2bd10b4770613')]
# Last element of result for run number 233 was:
# [ObjectId('664be00f38b2bd10b4770677')]
# Last element of result for run number 234 was:
# [ObjectId('664be00f38b2bd10b47706db')]
# Last element of result for run number 235 was:
# [ObjectId('664be00f38b2bd10b477073f')]
# Last element of result for run number 236 was:
# [ObjectId('664be01038b2bd10b47707a3')]
# Last element of result for run number 237 was:
# [ObjectId('664be01038b2bd10b4770807')]
# Last element of result for run number 238 was:
# [ObjectId('664be01038b2bd10b477086b')]
# Last element of result for run number 239 was:
# [ObjectId('664be01038b2bd10b47708cf')]
# Last element of result for run number 240 was:
# [ObjectId('664be01038b2bd10b4770933')]
# Last element of result for run number 241 was:
# [ObjectId('664be01038b2bd10b4770997')]
# Last element of result for run number 242 was:
# [ObjectId('664be01038b2bd10b47709fb')]
# Last element of result for run number 243 was:
# [ObjectId('664be01038b2bd10b4770a5f')]
# Last element of result for run number 244 was:
# [ObjectId('664be01038b2bd10b4770ac3')]
# Last element of result for run number 245 was:
# [ObjectId('664be01038b2bd10b4770b27')]
# Last element of result for run number 246 was:
# [ObjectId('664be01138b2bd10b4770b8b')]
# Last element of result for run number 247 was:
# [ObjectId('664be01138b2bd10b4770bef')]
# Last element of result for run number 248 was:
# [ObjectId('664be01138b2bd10b4770c53')]
# Last element of result for run number 249 was:
# [ObjectId('664be01138b2bd10b4770cb7')]
# Last element of result for run number 250 was:
# [ObjectId('664be01138b2bd10b4770d1b')]
# Last element of result for run number 251 was:
# [ObjectId('664be01138b2bd10b4770d7f')]
# Last element of result for run number 252 was:
# [ObjectId('664be01138b2bd10b4770de3')]
# Last element of result for run number 253 was:
# [ObjectId('664be01138b2bd10b4770e47')]
# Last element of result for run number 254 was:
# [ObjectId('664be01138b2bd10b4770eab')]
# Last element of result for run number 255 was:
# [ObjectId('664be01138b2bd10b4770f0f')]
# Last element of result for run number 256 was:
# [ObjectId('664be01138b2bd10b4770f73')]
# Last element of result for run number 257 was:
# [ObjectId('664be01138b2bd10b4770fd7')]
# Last element of result for run number 258 was:
# [ObjectId('664be01138b2bd10b477103b')]
# Last element of result for run number 259 was:
# [ObjectId('664be01138b2bd10b477109f')]
# Last element of result for run number 260 was:
# [ObjectId('664be01138b2bd10b4771103')]
# Last element of result for run number 261 was:
# [ObjectId('664be01138b2bd10b4771167')]
# Last element of result for run number 262 was:
# [ObjectId('664be01138b2bd10b47711cb')]
# Last element of result for run number 263 was:
# [ObjectId('664be01138b2bd10b477122f')]
# Last element of result for run number 264 was:
# [ObjectId('664be01138b2bd10b4771293')]
# Last element of result for run number 265 was:
# [ObjectId('664be01138b2bd10b47712f7')]
# Last element of result for run number 266 was:
# [ObjectId('664be01138b2bd10b477135b')]
# Last element of result for run number 267 was:
# [ObjectId('664be01138b2bd10b47713bf')]
# Last element of result for run number 268 was:
# [ObjectId('664be01138b2bd10b4771423')]
# Last element of result for run number 269 was:
# [ObjectId('664be01138b2bd10b4771487')]
# Last element of result for run number 270 was:
# [ObjectId('664be01138b2bd10b47714eb')]
# Last element of result for run number 271 was:
# [ObjectId('664be01138b2bd10b477154f')]
# Last element of result for run number 272 was:
# [ObjectId('664be01138b2bd10b47715b3')]
# Last element of result for run number 273 was:
# [ObjectId('664be01138b2bd10b4771617')]
# Last element of result for run number 274 was:
# [ObjectId('664be01138b2bd10b477167b')]
# Last element of result for run number 275 was:
# [ObjectId('664be01138b2bd10b47716df')]
# Last element of result for run number 276 was:
# [ObjectId('664be01138b2bd10b4771743')]
# Last element of result for run number 277 was:
# [ObjectId('664be01138b2bd10b47717a7')]
# Last element of result for run number 278 was:
# [ObjectId('664be01138b2bd10b477180b')]
# Last element of result for run number 279 was:
# [ObjectId('664be01238b2bd10b477186f')]
# Last element of result for run number 280 was:
# [ObjectId('664be01238b2bd10b47718d3')]
# Last element of result for run number 281 was:
# [ObjectId('664be01238b2bd10b4771937')]
# Last element of result for run number 282 was:
# [ObjectId('664be01238b2bd10b477199b')]
# Last element of result for run number 283 was:
# [ObjectId('664be01238b2bd10b47719ff')]
# Last element of result for run number 284 was:
# [ObjectId('664be01238b2bd10b4771a63')]
# Last element of result for run number 285 was:
# [ObjectId('664be01238b2bd10b4771ac7')]
# Last element of result for run number 286 was:
# [ObjectId('664be01238b2bd10b4771b2b')]
# Last element of result for run number 287 was:
# [ObjectId('664be01238b2bd10b4771b8f')]
# Last element of result for run number 288 was:
# [ObjectId('664be01238b2bd10b4771bf3')]
# Last element of result for run number 289 was:
# [ObjectId('664be01238b2bd10b4771c57')]
# Last element of result for run number 290 was:
# [ObjectId('664be01238b2bd10b4771cbb')]
# Last element of result for run number 291 was:
# [ObjectId('664be01238b2bd10b4771d1f')]
# Last element of result for run number 292 was:
# [ObjectId('664be01238b2bd10b4771d83')]
# Last element of result for run number 293 was:
# [ObjectId('664be01238b2bd10b4771de7')]
# Last element of result for run number 294 was:
# [ObjectId('664be01238b2bd10b4771e4b')]
# Last element of result for run number 295 was:
# [ObjectId('664be01238b2bd10b4771eaf')]
# Last element of result for run number 296 was:
# [ObjectId('664be01238b2bd10b4771f13')]
# Last element of result for run number 297 was:
# [ObjectId('664be01238b2bd10b4771f77')]
# Last element of result for run number 298 was:
# [ObjectId('664be01238b2bd10b4771fdb')]
# Last element of result for run number 299 was:
# [ObjectId('664be01238b2bd10b477203f')]
# Last element of result for run number 300 was:
# [ObjectId('664be01238b2bd10b47720a3')]
# Last element of result for run number 301 was:
# [ObjectId('664be01238b2bd10b4772107')]
# Last element of result for run number 302 was:
# [ObjectId('664be01238b2bd10b477216b')]
# Last element of result for run number 303 was:
# [ObjectId('664be01238b2bd10b47721cf')]
# Last element of result for run number 304 was:
# [ObjectId('664be01238b2bd10b4772233')]
# Last element of result for run number 305 was:
# [ObjectId('664be01238b2bd10b4772297')]
# Last element of result for run number 306 was:
# [ObjectId('664be01238b2bd10b47722fb')]
# Last element of result for run number 307 was:
# [ObjectId('664be01238b2bd10b477235f')]
# Last element of result for run number 308 was:
# [ObjectId('664be01238b2bd10b47723c3')]
# Last element of result for run number 309 was:
# [ObjectId('664be01238b2bd10b4772427')]
# Last element of result for run number 310 was:
# [ObjectId('664be01238b2bd10b477248b')]
# Last element of result for run number 311 was:
# [ObjectId('664be01238b2bd10b47724ef')]
# Last element of result for run number 312 was:
# [ObjectId('664be01238b2bd10b4772553')]
# Last element of result for run number 313 was:
# [ObjectId('664be01238b2bd10b47725b7')]
# Last element of result for run number 314 was:
# [ObjectId('664be01238b2bd10b477261b')]
# Last element of result for run number 315 was:
# [ObjectId('664be01238b2bd10b477267f')]
# Last element of result for run number 316 was:
# [ObjectId('664be01238b2bd10b47726e3')]
# Last element of result for run number 317 was:
# [ObjectId('664be01238b2bd10b4772747')]
# Last element of result for run number 318 was:
# [ObjectId('664be01238b2bd10b47727ab')]
# Last element of result for run number 319 was:
# [ObjectId('664be01238b2bd10b477280f')]
# Last element of result for run number 320 was:
# [ObjectId('664be01238b2bd10b4772873')]
# Last element of result for run number 321 was:
# [ObjectId('664be01238b2bd10b47728d7')]
# Last element of result for run number 322 was:
# [ObjectId('664be01238b2bd10b477293b')]
# Last element of result for run number 323 was:
# [ObjectId('664be01238b2bd10b477299f')]
# Last element of result for run number 324 was:
# [ObjectId('664be01238b2bd10b4772a03')]
# Last element of result for run number 325 was:
# [ObjectId('664be01238b2bd10b4772a67')]
# Last element of result for run number 326 was:
# [ObjectId('664be01238b2bd10b4772acb')]
# Last element of result for run number 327 was:
# [ObjectId('664be01238b2bd10b4772b2f')]
# Last element of result for run number 328 was:
# [ObjectId('664be01238b2bd10b4772b93')]
# Last element of result for run number 329 was:
# [ObjectId('664be01238b2bd10b4772bf7')]
# Last element of result for run number 330 was:
# [ObjectId('664be01238b2bd10b4772c5b')]
# Last element of result for run number 331 was:
# [ObjectId('664be01238b2bd10b4772cbf')]
# Last element of result for run number 332 was:
# [ObjectId('664be01238b2bd10b4772d23')]
# Last element of result for run number 333 was:
# [ObjectId('664be01238b2bd10b4772d87')]
# Last element of result for run number 334 was:
# [ObjectId('664be01238b2bd10b4772deb')]
# Last element of result for run number 335 was:
# [ObjectId('664be01238b2bd10b4772e4f')]
# Last element of result for run number 336 was:
# [ObjectId('664be01238b2bd10b4772eb3')]
# Last element of result for run number 337 was:
# [ObjectId('664be01238b2bd10b4772f17')]
# Last element of result for run number 338 was:
# [ObjectId('664be01238b2bd10b4772f7b')]
# Last element of result for run number 339 was:
# [ObjectId('664be01238b2bd10b4772fdf')]
# Last element of result for run number 340 was:
# [ObjectId('664be01338b2bd10b4773043')]
# Last element of result for run number 341 was:
# [ObjectId('664be01338b2bd10b47730a7')]
# Last element of result for run number 342 was:
# [ObjectId('664be01338b2bd10b477310b')]
# Last element of result for run number 343 was:
# [ObjectId('664be01338b2bd10b477316f')]
# Last element of result for run number 344 was:
# [ObjectId('664be01338b2bd10b47731d3')]
# Last element of result for run number 345 was:
# [ObjectId('664be01338b2bd10b4773237')]
# Last element of result for run number 346 was:
# [ObjectId('664be01338b2bd10b477329b')]
# Last element of result for run number 347 was:
# [ObjectId('664be01338b2bd10b47732ff')]
# Last element of result for run number 348 was:
# [ObjectId('664be01338b2bd10b4773363')]
# Last element of result for run number 349 was:
# [ObjectId('664be01338b2bd10b47733c7')]
# Last element of result for run number 350 was:
# [ObjectId('664be01338b2bd10b477342b')]
# Last element of result for run number 351 was:
# [ObjectId('664be01338b2bd10b477348f')]
# Last element of result for run number 352 was:
# [ObjectId('664be01338b2bd10b47734f3')]
# Last element of result for run number 353 was:
# [ObjectId('664be01338b2bd10b4773557')]
# Last element of result for run number 354 was:
# [ObjectId('664be01338b2bd10b47735bb')]
# Last element of result for run number 355 was:
# [ObjectId('664be01338b2bd10b477361f')]
# Last element of result for run number 356 was:
# [ObjectId('664be01338b2bd10b4773683')]
# Last element of result for run number 357 was:
# [ObjectId('664be01338b2bd10b47736e7')]
# Last element of result for run number 358 was:
# [ObjectId('664be01338b2bd10b477374b')]
# Last element of result for run number 359 was:
# [ObjectId('664be01338b2bd10b47737af')]
# Last element of result for run number 360 was:
# [ObjectId('664be01338b2bd10b4773813')]
# Last element of result for run number 361 was:
# [ObjectId('664be01338b2bd10b4773877')]
# Last element of result for run number 362 was:
# [ObjectId('664be01338b2bd10b47738db')]
# Last element of result for run number 363 was:
# [ObjectId('664be01338b2bd10b477393f')]
# Last element of result for run number 364 was:
# [ObjectId('664be01338b2bd10b47739a3')]
# Last element of result for run number 365 was:
# [ObjectId('664be01338b2bd10b4773a07')]
# Last element of result for run number 366 was:
# [ObjectId('664be01338b2bd10b4773a6b')]
# Last element of result for run number 367 was:
# [ObjectId('664be01338b2bd10b4773acf')]
# Last element of result for run number 368 was:
# [ObjectId('664be01338b2bd10b4773b33')]
# Last element of result for run number 369 was:
# [ObjectId('664be01338b2bd10b4773b97')]
# Last element of result for run number 370 was:
# [ObjectId('664be01338b2bd10b4773bfb')]
# Last element of result for run number 371 was:
# [ObjectId('664be01338b2bd10b4773c5f')]
# Last element of result for run number 372 was:
# [ObjectId('664be01338b2bd10b4773cc3')]
# Last element of result for run number 373 was:
# [ObjectId('664be01338b2bd10b4773d27')]
# Last element of result for run number 374 was:
# [ObjectId('664be01338b2bd10b4773d8b')]
# Last element of result for run number 375 was:
# [ObjectId('664be01338b2bd10b4773def')]
# Last element of result for run number 376 was:
# [ObjectId('664be01338b2bd10b4773e53')]
# Last element of result for run number 377 was:
# [ObjectId('664be01338b2bd10b4773eb7')]
# Last element of result for run number 378 was:
# [ObjectId('664be01338b2bd10b4773f1b')]
# Last element of result for run number 379 was:
# [ObjectId('664be01338b2bd10b4773f7f')]
# Last element of result for run number 380 was:
# [ObjectId('664be01338b2bd10b4773fe3')]
# Last element of result for run number 381 was:
# [ObjectId('664be01338b2bd10b4774047')]
# Last element of result for run number 382 was:
# [ObjectId('664be01338b2bd10b47740ab')]
# Last element of result for run number 383 was:
# [ObjectId('664be01338b2bd10b477410f')]
# Last element of result for run number 384 was:
# [ObjectId('664be01338b2bd10b4774173')]
# Last element of result for run number 385 was:
# [ObjectId('664be01338b2bd10b47741d7')]
# Last element of result for run number 386 was:
# [ObjectId('664be01338b2bd10b477423b')]
# Last element of result for run number 387 was:
# [ObjectId('664be01338b2bd10b477429f')]
# Last element of result for run number 388 was:
# [ObjectId('664be01338b2bd10b4774303')]
# Last element of result for run number 389 was:
# [ObjectId('664be01338b2bd10b4774367')]
# Last element of result for run number 390 was:
# [ObjectId('664be01338b2bd10b47743cb')]
# Last element of result for run number 391 was:
# [ObjectId('664be01338b2bd10b477442f')]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 20
#      12 for i in range(1,393):
#      13 # for j in range(0,10):
#      14 # for k in range(0,10):
#    (...)
#      17     #    of this substitution, but it does not work on my mac for large df's.
#      18     #    (Oddly, it does work on small df's.)
#      19     for j in range(0,100):
# ---> 20         if dict_ljr_new[100*i + j]['last_review'] != dict_ljr_new[100*i + j]['last_review']:
#      21             dict_ljr_new[100*i + j]['last_review'] = None
#      22     result = listings.insert_many(dict_ljr_new[100*i:100*(i+1)])
#
# IndexError: list index out of range

# %%
pprint.pp(dict_ljr_new[13800 + 69:13800 + 72])

print(df_ljr_new.iloc[13870])

# %%
"""
val_last_review = df_ljr_new.iloc[13870,df_ljr_new.columns.get_loc('last_review')]
print(val_last_review)
print(convert_date_to_datetime(val_last_review))

val_reviews_per_month = df_ljr_new.iloc[13870,df_ljr_new.columns.get_loc('reviews_per_month')]
print(val_reviews_per_month)
print(convert_date_to_datetime(val_last_review))



row = df_ljr_new.iloc[13870]
print(row)
    
doc = dict_ljr_new[13870]
pprint.pp(doc)
print()
row = df_ljr_new.iloc[13870]
print(row)
"""

df_test = df_ljr_new.copy()
df_test = df_test.iloc[13870:13872]
print(df_test.head())
df_test['last_review'] = df_test['last_review'].apply(lambda x: convert_date_to_datetime(x))
# df_test['last_review'] = df_test['last_review'].apply(convert_date_to_datetime)
print(df_test.head())



if dict_ljr_new[13870]['last_review'] != dict_ljr_new[13870]['last_review']:
    dict_ljr_new[13870]['last_review'] = None
pprint.pp(dict_ljr_new[13870])

# %%
# result = listings.insert_many(dict_ljr_new[0:1])
print('Last element of result for run number', str(i), 'was:')
print(result.inserted_ids[-1:])
print(type(result.inserted_ids[-1:][0]))
print(db.listings.find_one({'_id': result.inserted_ids[-1:][0]}))
# Out:
# Last element of result for run number 1 was:
# [ObjectId('664adfc48550e1de8d8d1dc7')]
# <class 'bson.objectid.ObjectId'>
# {'_id': ObjectId('664adfc48550e1de8d8d1dc7'), 'id': '47305871', 'name': 'Rental unit in New York · 1 bedroom · 1 bed · 0 shared baths', 'host_id': '305240193', 'host_name': 'June', 'neighbourhood_group': 'Manhattan', 'neighbourhood': 'Harlem', 'latitude': 40.821926, 'longitude': -73.956245, 'room_type': 'Private room', 'price': 46, 'minimum_nights': 30, 'number_of_reviews': 0, 'last_review': nan, 'reviews_per_month': None, 'calculated_host_listings_count': 333, 'availability_365': 160, 'number_of_reviews_ltm': 0, 'license': '', 'reviews': {}}

# %%
doc = db.testing.find_one()
obj_pointer = doc['_id']
print(type(obj_pointer))
print(obj_pointer)
# Out:
# <class 'bson.objectid.ObjectId'>
# 664987068b80b91420d2b513

# %%
print(db.list_collection_names())
# Out:
# ['testing', 'listings']

# %%
def write_dict_to_json(dict, filename):
    with open(filename, 'w') as fp:
        json.dump(dict, fp)

filename = 'listings_with_reviews_embedded.json'
# write_dict_to_json(dict_ljr100_left, filename)
# hmm -- timestamp is not json serializable !!
