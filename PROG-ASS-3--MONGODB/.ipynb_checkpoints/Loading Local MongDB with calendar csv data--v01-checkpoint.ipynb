# %% [markdown]
# ### <span style=color:blue> Loading Listings & Reviews data from postgresql into local MongoDB    </span>

# %%
import sys
import json
import csv
import yaml

import importlib

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('helper_functions/')
# import util as util
import util

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# <span style=color:blue>Getting access to airbnb database, and setting up collection "cal" to hold the calendar data in mongodb</span>

# %%
# I have (or will have) a database "airbnb"
db = client.airbnb

# inside the "airbnb" database, I have (or will have) a collection "listings"
cal = db.calendar

print('The list of all databases currently in the MongoDB client is:')
print(client.list_database_names())

print('\nThe list of all collections in the airbnb database is:')
print(db.list_collection_names())
# Note: calendar may not show up yet; it is created only when a first document is inserted into it
# Out:
# The list of all databases currently in the MongoDB client is:
# ['admin', 'airbnb', 'config', 'local', 'test']
#
# The list of all collections in the airbnb database is:
# ['testing', 'listings']

# %% [markdown]
# <span style=color:blue>FAILED ATTEMPT AT: Loading contents of calendar csv file into a dataframe</span>

# %%
"""
# This became a black hole!

filename = '/Users/rick/DM-for-DS--Davis-Spring-2024/DATA-SETS/AirBNB/New-York-City/calendar.csv'

# see https://stackoverflow.com/questions/24251219/pandas-read-csv-low-memory-and-dtype-options for
#    various info about including data types into the read_csv command
# see also https://pandas.pydata.org/pandas-docs/stable/user_guide/basics.html#basics-dtypes
# As for the date and available fields (intended as date type and boolean, respectively,
#    we import as strings and convert in the data frame
dtype = {"listing_id": str, "date": str, "available": str, 
        "price": str, "adjusted_price": str, "minimum_nights": int, "maximum_nights": int}

# the csv has nulls in "adjusted_price", which has type str,. so including keep_default_na=False, 
#    see https://stackoverflow.com/questions/10867028/get-pandas-read-csv-to-read-empty-values-as-empty-string-instead-of-nan

# there are 7000+ entries for minimum_nights and maximum_nights with NULL values
# so following this pattern:
#    df2 = pd.read_csv('test_int64.csv', converters={'nr_nan':lambda x: pd.NA if x == '' else int(x)})
#    df2.nr_nan = df2.nr_nan.astype('Int64')
# see https://stackoverflow.com/questions/70776957/pandas-read-csv-with-integer-columns-with-null-values-without-precision-loss
converters = {'nr_nan':lambda x: pd.NA if x == '' else int(x)}

df = pd.read_csv(filename, dtype=dtype, converters=converters, keep_default_na=False)
df.nr_nan = df.nr_nan.astype('Int64')

print('The datatypes for the fields of df are:')
print(df.types)

print('\nThe first few rows of df are:')
print(df.head())
"""
print('This was a black hole')
# Out:
# This was a black hole

# %% [markdown]
# <span style=color:blue>Loading contents of calendar csv file into a dataframe</span>
#
# <span style=color:blue>The system will give a warning, but it appears safe to ignore it.</span>

# %%
filename = '/Users/rick/DM-for-DS--Davis-Spring-2024/DATA-SETS/AirBNB/New-York-City/calendar.csv'

# Using partial list of dtypes, so that first several fields are interpreted as strings
# As for the date and available fields (intended as date type and boolean, respectively,
#    we import as strings and convert in the data frame
dtype = {"listing_id": str, "date": str, "available": str, 
        "price": str, "adjusted_price": str}
# note including these, because the null values make trouble:  , "minimum_nights": int, "maximum_nights": int}

# the csv has nulls in "adjusted_price", which has type str,. so including keep_default_na=False, 
#    see https://stackoverflow.com/questions/10867028/get-pandas-read-csv-to-read-empty-values-as-empty-string-instead-of-nan
         
df = pd.read_csv(filename, dtype=dtype, keep_default_na=False)
# Out:
# /var/folders/3l/gd1qj_mw8xl3gm001s6w9h180000gp/T/ipykernel_73872/2422796389.py:13: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, dtype=dtype, keep_default_na=False)

# %%
print('The datatypes for the fields of df are:')
print(df.dtypes)

print('\nThe first few rows of df are:')
print(df.head())
# Out:
# The datatypes for the fields of df are:
# listing_id        object
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights    object
# maximum_nights    object
# dtype: object
#
# The first few rows of df are:
#   listing_id        date available    price adjusted_price minimum_nights  \
# 0     144087  2024-02-10         t  $259.00                            30
# 1     144087  2024-02-11         t  $259.00                            30
# 2     144087  2024-02-12         t  $259.00                            30
# 3     144087  2024-02-13         t  $259.00                            30
# 4     144087  2024-02-14         t  $259.00                            30
#
#   maximum_nights
# 0            365
# 1            365
# 2            365
# 3            365
# 4            365

# %% [markdown]
# <span style=color:blue>Function to convert dates into datetimes.  This is useful because MongoDB recognizes datetime types but not date types.  So, will convert all dates into datetimes for insertion into MongoDB (after which we can do date arithmetic).</span>
#
# <span style=color:blue>It also has conditions that turn various kinds of null values into None.  (Note: curiously this works on small dataframes, but left some values of "NaT" when applied on very large dataframes.)</span>

# %%
# also converts NaT to None, because MongoDB does not recognize NaT
def convert_date_str_to_datetime(dt):
    if dt is None:
        return None
    elif pd.isnull(dt):  # tests whether dt is the pandas value NaT ("not a time")
        # print('\nEntered the NaT case\n')
        return None
    elif dt != dt:
        return None        # could also use math.nan, I think
    elif dt == '':
        return None
    else:
        year = int(dt[0:4])
        month = int(dt[5:7])
        day = int(dt[8:10])
        # print(year, month, day)
        temp = datetime(year, month, day)
        ts = temp.timestamp()
        new_dt = datetime.fromtimestamp(ts)
        return new_dt

print(convert_date_str_to_datetime('2024-05-23'))
# Out:
# 2024-05-23 00:00:00

# %% [markdown]
# <span style=color:blue>Function to convert the values of field "available" to booleans </span>

# %%
def convert_tf_to_boolean(val):
    if val == 't':
        return True
    elif val == 'f':
        return False
    else:
        return None

print(convert_tf_to_boolean('t'), convert_tf_to_boolean('f'), convert_tf_to_boolean('foo'))
# Out:
# True False None

# %% [markdown]
# <span style=color:blue>Cleaning up the values in df, to be more compatible with MongoDB  </span>

# %%
df['date'] = df['date'].apply(convert_date_str_to_datetime)
df['available'] = df['available'].apply(convert_tf_to_boolean)

print(df.head())

# %%
df['price'] = df['price'].apply(lambda x:x.replace('$','')) 

print(df.head())
# Out:
#   listing_id       date  available   price adjusted_price minimum_nights  \
# 0     144087 2024-02-10       True  259.00                            30
# 1     144087 2024-02-11       True  259.00                            30
# 2     144087 2024-02-12       True  259.00                            30
# 3     144087 2024-02-13       True  259.00                            30
# 4     144087 2024-02-14       True  259.00                            30
#
#   maximum_nights
# 0            365
# 1            365
# 2            365
# 3            365
# 4            365

# %% [markdown]
# ### <span style=color:blue>Now working to create a list of documents, where each document has a listing_id and then a list of dictionaries about available dates for that listing  </span>
#
# <span style=color:blue>First step is to get a dataframe with just the listing_ids</span>

# %%
cols = df.columns.tolist()
print(cols)
# Out:
# ['listing_id', 'date', 'available', 'price', 'adjusted_price', 'minimum_nights', 'maximum_nights']

# %%
other_cols = ['date', 'available', 'price', 'adjusted_price', 'minimum_nights', 'maximum_nights']

df_new = df.drop(other_cols, axis=1).drop_duplicates()

print(df.shape)
print(df_new.shape)
print(df_new.head())
# Out:
# (14299870, 7)
# (39201, 1)
#      listing_id
# 0        144087
# 152        2595
# 322       43105
# 507      144148
# 1310      44229

# %% [markdown]
# <span style=color:blue>Next, convert df_new into a list of dictionaries</span>

# %%
# I'm calling it "dict_new" but actually it is a list of dictionaries
dict_new = df_new.to_dict('records')

pprint.pp(dict_new[0:10])
# Out:
# [{'listing_id': '144087'},
#  {'listing_id': '2595'},
#  {'listing_id': '43105'},
#  {'listing_id': '144148'},
#  {'listing_id': '44229'},
#  {'listing_id': '5121'},
#  {'listing_id': '146726'},
#  {'listing_id': '6848'},
#  {'listing_id': '44973'},
#  {'listing_id': '6872'}]

# %% [markdown]
# <span style=color:blue>Now adding in all of the dates for each listing.  This might take an hour or more to run so plan accordingly</span>

# %%
i = 0

time1 = datetime.now()

# for d in dict_new[0:2]:
for d in dict_new:
    i += 1

    # print(d['listing_id'])

    df_cal_one_listing = df.loc[df['listing_id'] == d['listing_id']].drop(['listing_id'], axis=1)

    # print(df_cal_one_listing.head(30))

    dicts_cal_one_listing = df_cal_one_listing.to_dict('records')

    d['dates_info'] = dicts_cal_one_listing

    if i % 50 == 0:
        time2 = datetime.now()
        time_taken = util.time_diff(time1,time2)
        print('Have now completed step number:', str(i), 'and it took', str(time_taken), 'seconds' )
        time1 = datetime.now()

# print(len(dict_new))
pprint.pp(dict_new[-5:-1])
# Out:
# Have now completed step number: 50
# Have now completed step number: 100
# Have now completed step number: 150
# Have now completed step number: 200
# Have now completed step number: 250
# Have now completed step number: 300
# Have now completed step number: 350
# Have now completed step number: 400
# Have now completed step number: 450
# Have now completed step number: 500
# Have now completed step number: 550
# Have now completed step number: 600
# Have now completed step number: 650
# Have now completed step number: 700
# Have now completed step number: 750
# Have now completed step number: 800
# Have now completed step number: 850
# Have now completed step number: 900
# Have now completed step number: 950
# Have now completed step number: 1000
# Have now completed step number: 1050
# Have now completed step number: 1100
# Have now completed step number: 1150
# Have now completed step number: 1200
# Have now completed step number: 1250
# Have now completed step number: 1300
# Have now completed step number: 1350
# Have now completed step number: 1400
# Have now completed step number: 1450
# Have now completed step number: 1500
# Have now completed step number: 1550
# Have now completed step number: 1600
# Have now completed step number: 1650
# Have now completed step number: 1700
# Have now completed step number: 1750
# Have now completed step number: 1800
# Have now completed step number: 1850
# Have now completed step number: 1900
# Have now completed step number: 1950
# Have now completed step number: 2000
# Have now completed step number: 2050
# Have now completed step number: 2100
# Have now completed step number: 2150
# Have now completed step number: 2200
# Have now completed step number: 2250
# Have now completed step number: 2300
# Have now completed step number: 2350
# Have now completed step number: 2400
# Have now completed step number: 2450
# Have now completed step number: 2500
# Have now completed step number: 2550
# Have now completed step number: 2600
# Have now completed step number: 2650
# Have now completed step number: 2700
# Have now completed step number: 2750
# Have now completed step number: 2800
# Have now completed step number: 2850
# Have now completed step number: 2900
# Have now completed step number: 2950
# Have now completed step number: 3000
# Have now completed step number: 3050
# Have now completed step number: 3100
# Have now completed step number: 3150
# Have now completed step number: 3200
# Have now completed step number: 3250
# Have now completed step number: 3300
# Have now completed step number: 3350
# Have now completed step number: 3400
# Have now completed step number: 3450
# Have now completed step number: 3500
# Have now completed step number: 3550
# Have now completed step number: 3600
# Have now completed step number: 3650
# Have now completed step number: 3700
# Have now completed step number: 3750
# Have now completed step number: 3800
# Have now completed step number: 3850
# Have now completed step number: 3900
# Have now completed step number: 3950
# Have now completed step number: 4000
# Have now completed step number: 4050
# Have now completed step number: 4100
# Have now completed step number: 4150
# Have now completed step number: 4200
# Have now completed step number: 4250
# Have now completed step number: 4300
# Have now completed step number: 4350
# Have now completed step number: 4400
# Have now completed step number: 4450
# Have now completed step number: 4500
# Have now completed step number: 4550
# Have now completed step number: 4600
# Have now completed step number: 4650
# Have now completed step number: 4700
# Have now completed step number: 4750
# Have now completed step number: 4800
# Have now completed step number: 4850
# Have now completed step number: 4900
# Have now completed step number: 4950
# Have now completed step number: 5000
# Have now completed step number: 5050
# Have now completed step number: 5100
# Have now completed step number: 5150
# Have now completed step number: 5200
# Have now completed step number: 5250
# Have now completed step number: 5300
# Have now completed step number: 5350
# Have now completed step number: 5400
# Have now completed step number: 5450
# Have now completed step number: 5500
# Have now completed step number: 5550
# Have now completed step number: 5600
# Have now completed step number: 5650
# Have now completed step number: 5700
# Have now completed step number: 5750
# Have now completed step number: 5800
# Have now completed step number: 5850
# Have now completed step number: 5900
# Have now completed step number: 5950
# Have now completed step number: 6000
# Have now completed step number: 6050
# Have now completed step number: 6100
# Have now completed step number: 6150
# Have now completed step number: 6200
# Have now completed step number: 6250
# Have now completed step number: 6300
# Have now completed step number: 6350
# Have now completed step number: 6400
# Have now completed step number: 6450
# Have now completed step number: 6500
# Have now completed step number: 6550
# Have now completed step number: 6600
# Have now completed step number: 6650
# Have now completed step number: 6700
# Have now completed step number: 6750
# Have now completed step number: 6800
# Have now completed step number: 6850
# Have now completed step number: 6900
# Have now completed step number: 6950
# Have now completed step number: 7000
# Have now completed step number: 7050
# Have now completed step number: 7100
# Have now completed step number: 7150
# Have now completed step number: 7200
# Have now completed step number: 7250
# Have now completed step number: 7300
# Have now completed step number: 7350
# Have now completed step number: 7400
# Have now completed step number: 7450
# Have now completed step number: 7500
# Have now completed step number: 7550
# Have now completed step number: 7600
# Have now completed step number: 7650
# Have now completed step number: 7700
# Have now completed step number: 7750
# Have now completed step number: 7800
# Have now completed step number: 7850
# Have now completed step number: 7900
# Have now completed step number: 7950
# Have now completed step number: 8000
# Have now completed step number: 8050
# Have now completed step number: 8100
# Have now completed step number: 8150
# Have now completed step number: 8200
# Have now completed step number: 8250
# Have now completed step number: 8300
# Have now completed step number: 8350
# Have now completed step number: 8400
# Have now completed step number: 8450
# Have now completed step number: 8500
# Have now completed step number: 8550
# Have now completed step number: 8600
# Have now completed step number: 8650
# Have now completed step number: 8700
# Have now completed step number: 8750
# Have now completed step number: 8800
# Have now completed step number: 8850
# Have now completed step number: 8900
# Have now completed step number: 8950
# Have now completed step number: 9000
# Have now completed step number: 9050
# Have now completed step number: 9100
# Have now completed step number: 9150
# Have now completed step number: 9200
# Have now completed step number: 9250
# Have now completed step number: 9300
# Have now completed step number: 9350
# Have now completed step number: 9400
# Have now completed step number: 9450
# Have now completed step number: 9500
# Have now completed step number: 9550
# Have now completed step number: 9600
# Have now completed step number: 9650
# Have now completed step number: 9700
# Have now completed step number: 9750
# Have now completed step number: 9800
# Have now completed step number: 9850
# Have now completed step number: 9900
# Have now completed step number: 9950
# Have now completed step number: 10000
# Have now completed step number: 10050
# Have now completed step number: 10100
# Have now completed step number: 10150
# Have now completed step number: 10200
# Have now completed step number: 10250
# Have now completed step number: 10300
# Have now completed step number: 10350
# Have now completed step number: 10400
# Have now completed step number: 10450
# Have now completed step number: 10500
# Have now completed step number: 10550
# Have now completed step number: 10600
# Have now completed step number: 10650
# Have now completed step number: 10700
# Have now completed step number: 10750
# Have now completed step number: 10800
# Have now completed step number: 10850
# Have now completed step number: 10900
# Have now completed step number: 10950
# Have now completed step number: 11000
# Have now completed step number: 11050
# Have now completed step number: 11100
# Have now completed step number: 11150
# Have now completed step number: 11200
# Have now completed step number: 11250
# Have now completed step number: 11300
# Have now completed step number: 11350
# Have now completed step number: 11400
# Have now completed step number: 11450
# Have now completed step number: 11500
# Have now completed step number: 11550
# Have now completed step number: 11600
# Have now completed step number: 11650
# Have now completed step number: 11700
# Have now completed step number: 11750
# Have now completed step number: 11800
# Have now completed step number: 11850
# Have now completed step number: 11900
# Have now completed step number: 11950
# Have now completed step number: 12000
# Have now completed step number: 12050
# Have now completed step number: 12100
# Have now completed step number: 12150
# Have now completed step number: 12200
# Have now completed step number: 12250
# Have now completed step number: 12300
# Have now completed step number: 12350
# Have now completed step number: 12400
# Have now completed step number: 12450
# Have now completed step number: 12500
# Have now completed step number: 12550
# Have now completed step number: 12600
# Have now completed step number: 12650
# Have now completed step number: 12700
# Have now completed step number: 12750
# Have now completed step number: 12800
# Have now completed step number: 12850
# Have now completed step number: 12900
# Have now completed step number: 12950
# Have now completed step number: 13000
# Have now completed step number: 13050
# Have now completed step number: 13100
# Have now completed step number: 13150
# Have now completed step number: 13200
# Have now completed step number: 13250
# Have now completed step number: 13300
# Have now completed step number: 13350
# Have now completed step number: 13400
# Have now completed step number: 13450
# Have now completed step number: 13500
# Have now completed step number: 13550
# Have now completed step number: 13600
# Have now completed step number: 13650
# Have now completed step number: 13700
# Have now completed step number: 13750
# Have now completed step number: 13800
# Have now completed step number: 13850
# Have now completed step number: 13900
# Have now completed step number: 13950
# Have now completed step number: 14000
# Have now completed step number: 14050
# Have now completed step number: 14100
# Have now completed step number: 14150
# Have now completed step number: 14200
# Have now completed step number: 14250
# Have now completed step number: 14300
# Have now completed step number: 14350
# Have now completed step number: 14400
# Have now completed step number: 14450
# Have now completed step number: 14500
# Have now completed step number: 14550
# Have now completed step number: 14600
# Have now completed step number: 14650
# Have now completed step number: 14700
# Have now completed step number: 14750
# Have now completed step number: 14800
# Have now completed step number: 14850
# Have now completed step number: 14900
# Have now completed step number: 14950
# Have now completed step number: 15000
# Have now completed step number: 15050
# Have now completed step number: 15100
# Have now completed step number: 15150
# Have now completed step number: 15200
# Have now completed step number: 15250
# Have now completed step number: 15300
# Have now completed step number: 15350
# Have now completed step number: 15400
# Have now completed step number: 15450
# Have now completed step number: 15500
# Have now completed step number: 15550
# Have now completed step number: 15600
# Have now completed step number: 15650
# Have now completed step number: 15700
# Have now completed step number: 15750
# Have now completed step number: 15800
# Have now completed step number: 15850
# Have now completed step number: 15900
# Have now completed step number: 15950
# Have now completed step number: 16000
# Have now completed step number: 16050
# Have now completed step number: 16100
# Have now completed step number: 16150
# Have now completed step number: 16200
# Have now completed step number: 16250
# Have now completed step number: 16300
# Have now completed step number: 16350
# Have now completed step number: 16400
# Have now completed step number: 16450
# Have now completed step number: 16500
# Have now completed step number: 16550
# Have now completed step number: 16600
# Have now completed step number: 16650
# Have now completed step number: 16700
# Have now completed step number: 16750
# Have now completed step number: 16800
# Have now completed step number: 16850
# Have now completed step number: 16900
# Have now completed step number: 16950
# Have now completed step number: 17000
# Have now completed step number: 17050
# Have now completed step number: 17100
# Have now completed step number: 17150
# Have now completed step number: 17200
# Have now completed step number: 17250
# Have now completed step number: 17300
# Have now completed step number: 17350
# Have now completed step number: 17400
# Have now completed step number: 17450
# Have now completed step number: 17500
# Have now completed step number: 17550
# Have now completed step number: 17600
# Have now completed step number: 17650
# Have now completed step number: 17700
# Have now completed step number: 17750
# Have now completed step number: 17800
# Have now completed step number: 17850
# Have now completed step number: 17900
# Have now completed step number: 17950
# Have now completed step number: 18000
# Have now completed step number: 18050
# Have now completed step number: 18100
# Have now completed step number: 18150
# Have now completed step number: 18200
# Have now completed step number: 18250
# Have now completed step number: 18300
# Have now completed step number: 18350
# Have now completed step number: 18400
# Have now completed step number: 18450
# Have now completed step number: 18500
# Have now completed step number: 18550
# Have now completed step number: 18600
# Have now completed step number: 18650
# Have now completed step number: 18700
# Have now completed step number: 18750
# Have now completed step number: 18800
# Have now completed step number: 18850
# Have now completed step number: 18900
# Have now completed step number: 18950
# Have now completed step number: 19000
# Have now completed step number: 19050
# Have now completed step number: 19100
# Have now completed step number: 19150
# Have now completed step number: 19200
# Have now completed step number: 19250
# Have now completed step number: 19300
# Have now completed step number: 19350
# Have now completed step number: 19400
# Have now completed step number: 19450
# Have now completed step number: 19500
# Have now completed step number: 19550
# Have now completed step number: 19600
# Have now completed step number: 19650
# Have now completed step number: 19700
# Have now completed step number: 19750
# Have now completed step number: 19800
# Have now completed step number: 19850
# Have now completed step number: 19900
# Have now completed step number: 19950
# Have now completed step number: 20000
# Have now completed step number: 20050
# Have now completed step number: 20100
# Have now completed step number: 20150
# Have now completed step number: 20200
# Have now completed step number: 20250
# Have now completed step number: 20300
# Have now completed step number: 20350
# Have now completed step number: 20400
# Have now completed step number: 20450
# Have now completed step number: 20500
# Have now completed step number: 20550
# Have now completed step number: 20600
# Have now completed step number: 20650
# Have now completed step number: 20700
# Have now completed step number: 20750
# Have now completed step number: 20800
# Have now completed step number: 20850
# Have now completed step number: 20900
# Have now completed step number: 20950
# Have now completed step number: 21000
# Have now completed step number: 21050
# Have now completed step number: 21100
# Have now completed step number: 21150
# Have now completed step number: 21200
# Have now completed step number: 21250
# Have now completed step number: 21300
# Have now completed step number: 21350
# Have now completed step number: 21400
# Have now completed step number: 21450
# Have now completed step number: 21500
# Have now completed step number: 21550
# Have now completed step number: 21600
# Have now completed step number: 21650
# Have now completed step number: 21700
# Have now completed step number: 21750
# Have now completed step number: 21800
# Have now completed step number: 21850
# Have now completed step number: 21900
# Have now completed step number: 21950
# Have now completed step number: 22000
# Have now completed step number: 22050
# Have now completed step number: 22100
# Have now completed step number: 22150
# Have now completed step number: 22200
# Have now completed step number: 22250
# Have now completed step number: 22300
# Have now completed step number: 22350
# Have now completed step number: 22400
# Have now completed step number: 22450
# Have now completed step number: 22500
# Have now completed step number: 22550
# Have now completed step number: 22600
# Have now completed step number: 22650
# Have now completed step number: 22700
# Have now completed step number: 22750
# Have now completed step number: 22800
# Have now completed step number: 22850
# Have now completed step number: 22900
# Have now completed step number: 22950
# Have now completed step number: 23000
# Have now completed step number: 23050
# Have now completed step number: 23100
# Have now completed step number: 23150
# Have now completed step number: 23200
# Have now completed step number: 23250
# Have now completed step number: 23300
# Have now completed step number: 23350
# Have now completed step number: 23400
# Have now completed step number: 23450
# Have now completed step number: 23500
# Have now completed step number: 23550
# Have now completed step number: 23600
# Have now completed step number: 23650
# Have now completed step number: 23700
# Have now completed step number: 23750
# Have now completed step number: 23800
# Have now completed step number: 23850
# Have now completed step number: 23900
# Have now completed step number: 23950
# Have now completed step number: 24000
# Have now completed step number: 24050
# Have now completed step number: 24100
# Have now completed step number: 24150
# Have now completed step number: 24200
# Have now completed step number: 24250
# Have now completed step number: 24300
# Have now completed step number: 24350
# Have now completed step number: 24400
# Have now completed step number: 24450
# Have now completed step number: 24500
# Have now completed step number: 24550
# Have now completed step number: 24600
# Have now completed step number: 24650
# Have now completed step number: 24700
# Have now completed step number: 24750
# Have now completed step number: 24800
# Have now completed step number: 24850
# Have now completed step number: 24900
# Have now completed step number: 24950
# Have now completed step number: 25000
# Have now completed step number: 25050
# Have now completed step number: 25100
# Have now completed step number: 25150
# Have now completed step number: 25200
# Have now completed step number: 25250
# Have now completed step number: 25300
# Have now completed step number: 25350
# Have now completed step number: 25400
# Have now completed step number: 25450
# Have now completed step number: 25500
# Have now completed step number: 25550
# Have now completed step number: 25600
# Have now completed step number: 25650
# Have now completed step number: 25700
# Have now completed step number: 25750
# Have now completed step number: 25800
# Have now completed step number: 25850
# Have now completed step number: 25900
# Have now completed step number: 25950
# Have now completed step number: 26000
# Have now completed step number: 26050
# Have now completed step number: 26100
# Have now completed step number: 26150
# Have now completed step number: 26200
# Have now completed step number: 26250
# Have now completed step number: 26300
# Have now completed step number: 26350
# Have now completed step number: 26400
# Have now completed step number: 26450
# Have now completed step number: 26500
# Have now completed step number: 26550
# Have now completed step number: 26600
# Have now completed step number: 26650
# Have now completed step number: 26700
# Have now completed step number: 26750
# Have now completed step number: 26800
# Have now completed step number: 26850
# Have now completed step number: 26900
# Have now completed step number: 26950
# Have now completed step number: 27000
# Have now completed step number: 27050
# Have now completed step number: 27100
# Have now completed step number: 27150
# Have now completed step number: 27200
# Have now completed step number: 27250
# Have now completed step number: 27300
# Have now completed step number: 27350
# Have now completed step number: 27400
# Have now completed step number: 27450
# Have now completed step number: 27500
# Have now completed step number: 27550
# Have now completed step number: 27600
# Have now completed step number: 27650
# Have now completed step number: 27700
# Have now completed step number: 27750
# Have now completed step number: 27800
# Have now completed step number: 27850
# Have now completed step number: 27900
# Have now completed step number: 27950
# Have now completed step number: 28000
# Have now completed step number: 28050
# Have now completed step number: 28100
# Have now completed step number: 28150
# Have now completed step number: 28200
# Have now completed step number: 28250
# Have now completed step number: 28300
# Have now completed step number: 28350
# Have now completed step number: 28400
# Have now completed step number: 28450
# Have now completed step number: 28500
# Have now completed step number: 28550
# Have now completed step number: 28600
# Have now completed step number: 28650
# Have now completed step number: 28700
# Have now completed step number: 28750
# Have now completed step number: 28800
# Have now completed step number: 28850
# Have now completed step number: 28900
# Have now completed step number: 28950
# Have now completed step number: 29000
# Have now completed step number: 29050
# Have now completed step number: 29100
# Have now completed step number: 29150
# Have now completed step number: 29200
# Have now completed step number: 29250
# Have now completed step number: 29300
# Have now completed step number: 29350
# Have now completed step number: 29400
# Have now completed step number: 29450
# Have now completed step number: 29500
# Have now completed step number: 29550
# Have now completed step number: 29600
# Have now completed step number: 29650
# Have now completed step number: 29700
# Have now completed step number: 29750
# Have now completed step number: 29800
# Have now completed step number: 29850
# Have now completed step number: 29900
# Have now completed step number: 29950
# Have now completed step number: 30000
# Have now completed step number: 30050
# Have now completed step number: 30100
# Have now completed step number: 30150
# Have now completed step number: 30200
# Have now completed step number: 30250
# Have now completed step number: 30300
# Have now completed step number: 30350
# Have now completed step number: 30400
# Have now completed step number: 30450
# Have now completed step number: 30500
# Have now completed step number: 30550
# Have now completed step number: 30600
# Have now completed step number: 30650
# Have now completed step number: 30700
# Have now completed step number: 30750
# Have now completed step number: 30800
# Have now completed step number: 30850
# Have now completed step number: 30900
# Have now completed step number: 30950
# Have now completed step number: 31000
# Have now completed step number: 31050
# Have now completed step number: 31100
# Have now completed step number: 31150
# Have now completed step number: 31200
# Have now completed step number: 31250
# Have now completed step number: 31300
# Have now completed step number: 31350
# Have now completed step number: 31400
# Have now completed step number: 31450
# Have now completed step number: 31500
# Have now completed step number: 31550
# Have now completed step number: 31600
# Have now completed step number: 31650
# Have now completed step number: 31700
# Have now completed step number: 31750
# Have now completed step number: 31800
# Have now completed step number: 31850
# Have now completed step number: 31900
# Have now completed step number: 31950
# Have now completed step number: 32000
# Have now completed step number: 32050
# Have now completed step number: 32100
# Have now completed step number: 32150
# Have now completed step number: 32200
# Have now completed step number: 32250
# Have now completed step number: 32300
# Have now completed step number: 32350
# Have now completed step number: 32400
# Have now completed step number: 32450
# Have now completed step number: 32500
# Have now completed step number: 32550
# Have now completed step number: 32600
# Have now completed step number: 32650
# Have now completed step number: 32700
# Have now completed step number: 32750
# Have now completed step number: 32800
# Have now completed step number: 32850
# Have now completed step number: 32900
# Have now completed step number: 32950
# Have now completed step number: 33000
# Have now completed step number: 33050
# Have now completed step number: 33100
# Have now completed step number: 33150
# Have now completed step number: 33200
# Have now completed step number: 33250
# Have now completed step number: 33300
# Have now completed step number: 33350
# Have now completed step number: 33400
# Have now completed step number: 33450
# Have now completed step number: 33500
# Have now completed step number: 33550
# Have now completed step number: 33600
# Have now completed step number: 33650
# Have now completed step number: 33700
# Have now completed step number: 33750
# Have now completed step number: 33800
# Have now completed step number: 33850
# Have now completed step number: 33900
# Have now completed step number: 33950
# Have now completed step number: 34000
# Have now completed step number: 34050
# Have now completed step number: 34100
# Have now completed step number: 34150
# Have now completed step number: 34200
# Have now completed step number: 34250
# Have now completed step number: 34300
# Have now completed step number: 34350
# Have now completed step number: 34400
# Have now completed step number: 34450
# Have now completed step number: 34500
# Have now completed step number: 34550
# Have now completed step number: 34600
# Have now completed step number: 34650
# Have now completed step number: 34700
# Have now completed step number: 34750
# Have now completed step number: 34800
# Have now completed step number: 34850
# Have now completed step number: 34900
# Have now completed step number: 34950
# Have now completed step number: 35000
# Have now completed step number: 35050
# Have now completed step number: 35100
# Have now completed step number: 35150
# Have now completed step number: 35200
# Have now completed step number: 35250
# Have now completed step number: 35300
# Have now completed step number: 35350
# Have now completed step number: 35400
# Have now completed step number: 35450
# Have now completed step number: 35500
# Have now completed step number: 35550
# Have now completed step number: 35600
# Have now completed step number: 35650
# Have now completed step number: 35700
# Have now completed step number: 35750
# Have now completed step number: 35800
# Have now completed step number: 35850
# Have now completed step number: 35900
# Have now completed step number: 35950
# Have now completed step number: 36000
# Have now completed step number: 36050
# Have now completed step number: 36100
# Have now completed step number: 36150
# Have now completed step number: 36200
# Have now completed step number: 36250
# Have now completed step number: 36300
# Have now completed step number: 36350
# Have now completed step number: 36400
# Have now completed step number: 36450
# Have now completed step number: 36500
# Have now completed step number: 36550
# Have now completed step number: 36600
# Have now completed step number: 36650
# Have now completed step number: 36700
# Have now completed step number: 36750
# Have now completed step number: 36800
# Have now completed step number: 36850
# Have now completed step number: 36900
# Have now completed step number: 36950
# Have now completed step number: 37000
# Have now completed step number: 37050
# Have now completed step number: 37100
# Have now completed step number: 37150
# Have now completed step number: 37200
# Have now completed step number: 37250
# Have now completed step number: 37300
# Have now completed step number: 37350
# Have now completed step number: 37400
# Have now completed step number: 37450
# Have now completed step number: 37500
# Have now completed step number: 37550
# Have now completed step number: 37600
# Have now completed step number: 37650
# Have now completed step number: 37700
# Have now completed step number: 37750
# Have now completed step number: 37800
# Have now completed step number: 37850
# Have now completed step number: 37900
# Have now completed step number: 37950
# Have now completed step number: 38000
# Have now completed step number: 38050
# Have now completed step number: 38100
# Have now completed step number: 38150
# Have now completed step number: 38200
# Have now completed step number: 38250
# Have now completed step number: 38300
# Have now completed step number: 38350
# Have now completed step number: 38400
# Have now completed step number: 38450
# Have now completed step number: 38500
# Have now completed step number: 38550
# Have now completed step number: 38600
# Have now completed step number: 38650
# Have now completed step number: 38700
# Have now completed step number: 38750
# Have now completed step number: 38800
# Have now completed step number: 38850
# Have now completed step number: 38900
# Have now completed step number: 38950
# Have now completed step number: 39000
# Have now completed step number: 39050
# Have now completed step number: 39100
# Have now completed step number: 39150
# Have now completed step number: 39200
# [{'listing_id': '1080769743669960618',
#   'dates_info': [{'date': Timestamp('2024-02-06 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-07 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-08 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-09 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-10 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-11 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-12 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-13 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-14 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-15 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-16 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-17 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-18 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-19 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-20 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-21 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-22 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-23 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-24 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-25 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-26 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-27 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-28 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-02-29 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-01 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-02 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-03 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-04 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-05 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-06 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-07 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-08 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-09 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-10 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-11 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-12 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-13 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-14 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-15 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-16 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-17 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-18 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-19 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-20 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-21 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-22 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-23 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-24 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-25 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-26 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-27 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-28 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-29 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-30 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-03-31 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-01 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-02 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-03 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-04 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-05 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-06 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-07 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-08 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-09 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-10 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-11 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-12 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-13 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-14 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-15 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-16 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-04-17 00:00:00'),
#                   'available': True,
#                   'price': '156.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
# ...
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-05 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-06 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-07 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-08 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-09 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-10 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-11 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-12 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-13 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-14 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-15 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-16 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-17 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-18 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-19 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-20 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-21 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-22 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-23 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-24 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-25 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-26 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-27 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-28 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-29 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-30 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2024-12-31 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-01 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-02 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-03 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-04 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-05 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-06 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-07 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-08 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-09 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-10 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-11 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-12 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-13 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-14 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-15 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-16 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-17 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-18 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-19 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-20 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-21 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-22 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-23 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-24 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-25 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-26 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-27 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-28 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-29 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-30 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-01-31 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-02-01 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-02-02 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-02-03 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90},
#                  {'date': Timestamp('2025-02-04 00:00:00'),
#                   'available': False,
#                   'price': '250.00',
#                   'adjusted_price': '',
#                   'minimum_nights': 30,
#                   'maximum_nights': 90}]}]

# %% [markdown]
# <span style=color:blue>Now loading into MongoDB</span>

# %%
# CAUTION: the first step here erases db.listing
db.calendar.drop()
# print(db.list_collection_names())

cal = db.calendar


time1 = datetime.now()
# for i in range(0,392):
for i in range(0,1):
# for j in range(0,10):
# for k in range(0,10):
    # testing for whether the 'last_review' value is NaT, and if so, changing it to None
    #    normally the "apply" function using the "change_date_to_datetime" should take care
    #    of this substitution, but it does not work on my mac for large df's.  
    #    (Oddly, it does work on small df's.)
    # for j in range(0,100):
    #     if dict_ljr_new[100*i + j]['last_review'] != dict_ljr_new[100*i + j]['last_review']:
    #         dict_ljr_new[100*i + j]['last_review'] = None
    result = listings.insert_many(dict_new[100*i:100*(i+1)])
    # result = listings.insert_many(dict_ljr_new[13800 + 10*j:13800 + 10*(j+1)])
    # result = listings.insert_many(dict_ljr_new[13870 + k:13870 + k + 1])
    # print('Last element of result for run number', str(i), 'was:')
    # print(result.inserted_ids[-1:])

time2 = datetime.now()

print('\nThe last ObjectID in the collection is:')
print(result.inserted_ids[-1:])

print('\nThe time to do the load of 39K documents into local mongodb, with a total of about 300MB was:')
print(util.time_diff(time1,time2))



# this is for the last 2 records in dict_ljr_new, but built for some number of records over 2
# again, testing for whether the 'last_review' value is NaT, and if so, changing it to None
for j in range(0,len(dict_ljr_new) % 100):
    if dict_ljr_new[39100 + j]['last_review'] != dict_ljr_new[39200 + j]['last_review']:
        dict_ljr_new[39200 + j]['last_review'] = None
result = listings.insert_many(dict_ljr_new[39200:])
print('\nLast element of result for the last run was:')
print(result.inserted_ids[-1:])


print('\nThe total number of documents in the collection db.listings is now:')
print(listings.count_documents({}))
