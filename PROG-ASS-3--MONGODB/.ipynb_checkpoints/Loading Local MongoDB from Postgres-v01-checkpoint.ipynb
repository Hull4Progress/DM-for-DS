# %% [markdown]
# ### <span style=color:blue> Loading data from postgresql into mongodb (local)    </span>

# %%
import sys
import json
import csv
import yaml

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

import time
import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('helper_functions/')
import util as util

# %%
# test that utils.py has been imported well
util.hello_world()
# Out:
# hello world

# %% [markdown]
# <span style=color:blue>Getting PostgreSQL connection set up</span>

# %%
# Load the env file 

dotenv_path = 'env_variables.env'
load_dotenv(dotenv_path=dotenv_path)

# Import the env variables

load_dotenv()

schema = os.getenv('DISC_6_SCHEMA')
port = os.getenv('DISC_6_PORT')
host = os.getenv('DISC_6_HOST')
database = os.getenv('DISC_6_DB')
password = os.getenv('DISC_6_PASSWORD')
connection = os.getenv('DISC_6_CONNECTION')

# Create the db engine 

db_eng = create_engine(f"postgresql+psycopg2://{connection}:{password}@{host}:{port}/{database}",
                       connect_args={'options': '-csearch_path={}'.format(schema)},
                       isolation_level = 'SERIALIZABLE')

print("Successfully created db engine.")
# Out:
# Successfully created db engine.

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# <span style=color:blue>Setting up collection "listings" in mongodb</span>

# %%
# I have (or will have) a database "airbnb"
db = client.airbnb

# inside the "airbnb" database, I have (or will have) a collection "listings"
listings = db.listings

# %% [markdown]
# <span style=color:blue>Installing all indexes I can think of</span>

# %%
testing = db.testing

dict = {'date': datetime.datetime(2023, 1, 1,0,0,0)}

ts = dict['date'].timestamp()
print(ts)
db.testing.insert_one({'date': datetime.datetime.fromtimestamp(ts)})
# Out:
# 1672560000.0
# InsertOneResult(ObjectId('664987068b80b91420d2b513'), acknowledged=True)

# %% [markdown]
# ### <span style=color:blue>As preparation for this, I have a table reviewm (for review_mongodb) in which I dropped the comments_tsv column (because not needed) and renamed column "id" to "review_id" (so that it is not repeating the "id" column of the listings table</span>

# %%
q = util.build_query_full_join_listings_reviewsm_100()

with db_eng.connect() as conn:
    df_ljr100 = pd.read_sql(q, con=conn)

print(df_ljr100.head())
# Out:
#          id                                               name   host_id  \
# 0  10073940  Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1...  51688993
# 1  10073940  Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1...  51688993
# 2  10073940  Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1...  51688993
# 3  10073940  Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1...  51688993
# 4  10073940  Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1...  51688993
#
#   host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0     Taran              Queens       Jamaica  40.68826  -73.80384
# 1     Taran              Queens       Jamaica  40.68826  -73.80384
# 2     Taran              Queens       Jamaica  40.68826  -73.80384
# 3     Taran              Queens       Jamaica  40.68826  -73.80384
# 4     Taran              Queens       Jamaica  40.68826  -73.80384
#
#       room_type  price  ...  availability_365  number_of_reviews_ltm license  \
# 0  Private room  200.0  ...               365                     18
# 1  Private room  200.0  ...               365                     18
# 2  Private room  200.0  ...               365                     18
# 3  Private room  200.0  ...               365                     18
# 4  Private room  200.0  ...               365                     18
#
#    listing_id           review_id        date  reviewer_id reviewer_name  \
# 0    10073940            88607874  2016-07-25     78858146        Areefa
# 1    10073940            89002342  2016-07-26     42591774       Natasha
# 2    10073940  664446674127275929  2022-07-05    403864376          Kara
# 3    10073940           256352777  2018-04-22    178946045        Vivian
# 4    10073940           262647967  2018-05-09    180335063        Thomas
#
#                                             comments            datetime
# 0  This apartment is best described as a sanctuar... 2016-07-25 12:00:00
# 1  I am a mom of two children, one 4 year old and... 2016-07-26 12:00:00
# 2  Great host!  Very communicative, extremely cle... 2022-07-05 12:00:00
# 3  This apartment was great! It felt like my own ... 2018-04-22 12:00:00
# 4  Fantastic hosts! Quick to respond to emails an... 2018-05-09 12:00:00
#
# [5 rows x 25 columns]

# %%
cols = df_ljr100.columns.tolist()
print(cols)
# Out:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'license', 'listing_id', 'review_id', 'date', 'reviewer_id', 'reviewer_name', 'comments', 'datetime']

# %%
# to do a projection and remove duplicates
cols_of_listings = ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 
                    'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 
                    'minimum_nights', 'number_of_reviews', 'last_review', 
                    'reviews_per_month', 'calculated_host_listings_count', 
                    'availability_365', 'number_of_reviews_ltm', 'license']
cols_of_reviews = ['listing_id', 'review_id', 'date', 'reviewer_id', 
                   'reviewer_name', 'comments', 'datetime']

df_ljr100_left = df_ljr100.drop(cols_of_reviews, axis=1).drop_duplicates()


print(df_ljr100_left.shape)
print(df_ljr100_left.head(10))
# Out:
# (169, 18)
#                       id                                               name  \
# 0               10073940  Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1...
# 91   1004466409355496588  Bed and breakfast in Queens · ★4.61 · 1 bedroo...
# 92   1001759466923816441  Rental unit in Queens · 1 bedroom · 2 beds · 1...
# 93   1006068540323632978  Home in Queens · ★4.93 · 1 bedroom · 1 bed · 1...
# 94   1005207590507549831  Rental unit in Queens · ★4.85 · 1 bedroom · 1 ...
# 108  1005170940682176047  Home in Queens · ★4.75 · 1 bedroom · 1 bed · 1...
# 120  1005215166382279445  Hotel in Queens · 1 bedroom · 1 bed · 1 privat...
# 121  1005236888864691555  Hotel in Queens · ★3.80 · 1 bedroom · 1 bed · ...
# 123  1001730138556048837  Home in Queens · ★5.0 · 3 bedrooms · 3 beds · ...
# 128  1002217051026941997  Hotel in Queens · ★4.25 · 1 bedroom · 1 bed · ...
#
#        host_id     host_name neighbourhood_group     neighbourhood   latitude  \
# 0     51688993         Taran              Queens           Jamaica  40.688260
# 91   539071710         Cesar              Queens     East Elmhurst  40.767010
# 92   305387117  UltraDiamond              Queens  Long Island City  40.753520
# 93    72904238        Keqing              Queens     College Point  40.780586
# 94    47657014          Rose              Queens           Astoria  40.766727
# 108  508605356         Linda              Queens     Fresh Meadows  40.738880
# 120  537729916    Lakhwinder              Queens           Jamaica  40.693200
# 121  537729916    Lakhwinder              Queens           Jamaica  40.691910
# 123   72904238        Keqing              Queens     College Point  40.779100
# 128  537729916    Lakhwinder              Queens           Jamaica  40.691833
#
#      longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0   -73.803840     Private room  200.0              30                184
# 91  -73.867040     Private room  105.0               1                 23
# 92  -73.941400  Entire home/apt  179.0               7                  2
# 93  -73.842510     Private room   99.0               5                 14
# 94  -73.920425     Private room   88.0               3                 13
# 108 -73.788910     Private room   89.0               2                  8
# 120 -73.809160     Private room    NaN               1                  2
# 121 -73.807640     Private room    NaN               1                  5
# 123 -73.841700  Entire home/apt  199.0               5                  9
# 128 -73.807680     Private room    NaN               1                  4
#
#     last_review  reviews_per_month  calculated_host_listings_count  \
# 0    2023-09-17               1.95                               1
# 91   2024-01-30               6.63                               1
# 92   2023-12-09               0.86                               7
# 93   2024-01-27               4.29                               2
# 94   2024-01-31               3.79                               2
# 108  2024-01-07               2.93                               1
# 120  2024-01-02               0.91                               8
# 121  2023-12-31               1.36                               8
# 123  2024-01-25               2.55                               2
# 128  2024-01-01               1.18                               8
#
#      availability_365  number_of_reviews_ltm license
# 0                 365                     18
# 91                248                     23  Exempt
# 92                275                      2  Exempt
# 93                269                     14  Exempt
# 94                207                     13  Exempt
# 108               162                      8  Exempt
# 120               270                      2  Exempt
# 121               270                      5  Exempt
# 123               136                      9  Exempt
# 128               270                      4  Exempt

# %%
dict_ljr100_left = df_ljr100_left.to_dict('records')
print(len(dict_ljr100_left))
pprint.pp(dict_ljr100_left)
# Out:
# 169
# [{'id': '10073940',
#   'name': 'Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '51688993',
#   'host_name': 'Taran',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.68826,
#   'longitude': -73.80384,
#   'room_type': 'Private room',
#   'price': 200.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 184,
#   'last_review': datetime.date(2023, 9, 17),
#   'reviews_per_month': 1.95,
#   'calculated_host_listings_count': 1,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 18,
#   'license': ''},
#  {'id': '1004466409355496588',
#   'name': 'Bed and breakfast in Queens · ★4.61 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '539071710',
#   'host_name': 'Cesar',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'East Elmhurst',
#   'latitude': 40.76701,
#   'longitude': -73.86704,
#   'room_type': 'Private room',
#   'price': 105.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 23,
#   'last_review': datetime.date(2024, 1, 30),
#   'reviews_per_month': 6.63,
#   'calculated_host_listings_count': 1,
#   'availability_365': 248,
#   'number_of_reviews_ltm': 23,
#   'license': 'Exempt'},
#  {'id': '1001759466923816441',
#   'name': 'Rental unit in Queens · 1 bedroom · 2 beds · 1 bath',
#   'host_id': '305387117',
#   'host_name': 'UltraDiamond',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Long Island City',
#   'latitude': 40.75352,
#   'longitude': -73.9414,
#   'room_type': 'Entire home/apt',
#   'price': 179.0,
#   'minimum_nights': 7,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2023, 12, 9),
#   'reviews_per_month': 0.86,
#   'calculated_host_listings_count': 7,
#   'availability_365': 275,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1006068540323632978',
#   'name': 'Home in Queens · ★4.93 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '72904238',
#   'host_name': 'Keqing',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'College Point',
#   'latitude': 40.780586,
#   'longitude': -73.84251,
#   'room_type': 'Private room',
#   'price': 99.0,
#   'minimum_nights': 5,
#   'number_of_reviews': 14,
#   'last_review': datetime.date(2024, 1, 27),
#   'reviews_per_month': 4.29,
#   'calculated_host_listings_count': 2,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 14,
#   'license': 'Exempt'},
#  {'id': '1005207590507549831',
#   'name': 'Rental unit in Queens · ★4.85 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '47657014',
#   'host_name': 'Rose',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.766727,
#   'longitude': -73.920425,
#   'room_type': 'Private room',
#   'price': 88.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 13,
#   'last_review': datetime.date(2024, 1, 31),
#   'reviews_per_month': 3.79,
#   'calculated_host_listings_count': 2,
#   'availability_365': 207,
#   'number_of_reviews_ltm': 13,
#   'license': 'Exempt'},
#  {'id': '1005170940682176047',
#   'name': 'Home in Queens · ★4.75 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '508605356',
#   'host_name': 'Linda',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Fresh Meadows',
#   'latitude': 40.73888,
#   'longitude': -73.78891,
#   'room_type': 'Private room',
#   'price': 89.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 8,
#   'last_review': datetime.date(2024, 1, 7),
#   'reviews_per_month': 2.93,
#   'calculated_host_listings_count': 1,
#   'availability_365': 162,
#   'number_of_reviews_ltm': 8,
#   'license': 'Exempt'},
#  {'id': '1005215166382279445',
#   'name': 'Hotel in Queens · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.6932,
#   'longitude': -73.80916,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2024, 1, 2),
#   'reviews_per_month': 0.91,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1005236888864691555',
#   'name': 'Hotel in Queens · ★3.80 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.69191,
#   'longitude': -73.80764,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2023, 12, 31),
#   'reviews_per_month': 1.36,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt'},
#  {'id': '1001730138556048837',
#   'name': 'Home in Queens · ★5.0 · 3 bedrooms · 3 beds · 1 bath',
#   'host_id': '72904238',
#   'host_name': 'Keqing',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'College Point',
#   'latitude': 40.7791,
#   'longitude': -73.8417,
#   'room_type': 'Entire home/apt',
#   'price': 199.0,
#   'minimum_nights': 5,
#   'number_of_reviews': 9,
#   'last_review': datetime.date(2024, 1, 25),
#   'reviews_per_month': 2.55,
#   'calculated_host_listings_count': 2,
#   'availability_365': 136,
#   'number_of_reviews_ltm': 9,
#   'license': 'Exempt'},
#  {'id': '1002217051026941997',
#   'name': 'Hotel in Queens · ★4.25 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.691833,
#   'longitude': -73.80768,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 4,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 1.18,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 4,
#   'license': 'Exempt'},
#  {'id': '1006526346791543478',
#   'name': 'Home in Queens · ★4.90 · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '542685293',
#   'host_name': 'Raf',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.764732,
#   'longitude': -73.92191,
#   'room_type': 'Private room',
#   'price': 61.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 10,
#   'last_review': datetime.date(2024, 1, 21),
#   'reviews_per_month': 2.94,
#   'calculated_host_listings_count': 2,
#   'availability_365': 97,
#   'number_of_reviews_ltm': 10,
#   'license': 'Exempt'},
#  {'id': '1006786464665372746',
#   'name': 'Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '530349907',
#   'host_name': 'Wei',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'College Point',
#   'latitude': 40.780563,
#   'longitude': -73.84291,
#   'room_type': 'Entire home/apt',
#   'price': 105.0,
#   'minimum_nights': 5,
#   'number_of_reviews': 13,
#   'last_review': datetime.date(2024, 1, 21),
#   'reviews_per_month': 3.64,
#   'calculated_host_listings_count': 1,
#   'availability_365': 141,
#   'number_of_reviews_ltm': 13,
#   'license': 'Exempt'},
#  {'id': '1008761034690239341',
#   'name': 'Home in Queens · ★4.61 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '542685293',
#   'host_name': 'Raf',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Astoria',
#   'latitude': 40.76355,
#   'longitude': -73.92286,
#   'room_type': 'Private room',
#   'price': 64.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 18,
#   'last_review': datetime.date(2024, 1, 20),
#   'reviews_per_month': 5.29,
#   'calculated_host_listings_count': 2,
#   'availability_365': 158,
#   'number_of_reviews_ltm': 18,
#   'license': 'Exempt'},
#  {'id': '1008301599260572123',
#   'name': 'Home in Queens · ★4.87 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '76667010',
#   'host_name': 'Xiao',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'College Point',
#   'latitude': 40.78218,
#   'longitude': -73.84198,
#   'room_type': 'Private room',
#   'price': 89.0,
#   'minimum_nights': 5,
#   'number_of_reviews': 15,
#   'last_review': datetime.date(2024, 1, 15),
#   'reviews_per_month': 4.33,
#   'calculated_host_listings_count': 2,
#   'availability_365': 162,
#   'number_of_reviews_ltm': 15,
#   'license': 'Exempt'},
#  {'id': '1008315491855065333',
#   'name': 'Home in Queens · ★4.93 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '76667010',
#   'host_name': 'Xiao',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'College Point',
#   'latitude': 40.780144,
#   'longitude': -73.8425,
#   'room_type': 'Private room',
#   'price': 89.0,
#   'minimum_nights': 5,
#   'number_of_reviews': 14,
#   'last_review': datetime.date(2024, 1, 21),
#   'reviews_per_month': 4.04,
#   'calculated_host_listings_count': 2,
#   'availability_365': 167,
#   'number_of_reviews_ltm': 14,
#   'license': 'Exempt'},
#  {'id': '1008861763783445922',
#   'name': 'Hotel in Queens · ★4.57 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.692078,
#   'longitude': -73.80744,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 7,
#   'last_review': datetime.date(2023, 12, 30),
#   'reviews_per_month': 2.08,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 7,
#   'license': 'Exempt'},
#  {'id': '1008898957166303997',
#   'name': 'Hotel in Queens · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.69355,
#   'longitude': -73.80917,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 0.59,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1003438862092649925',
#   'name': 'Rental unit in Queens · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '341452050',
#   'host_name': 'Jesus',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Sunnyside',
#   'latitude': 40.74424,
#   'longitude': -73.9159,
#   'room_type': 'Private room',
#   'price': 30.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 31),
#   'reviews_per_month': 0.79,
#   'calculated_host_listings_count': 2,
#   'availability_365': 185,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1003700405706338295',
#   'name': 'Townhouse in Queens · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '462025910',
#   'host_name': 'Ying Ying',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Woodside',
#   'latitude': 40.75262,
#   'longitude': -73.90537,
#   'room_type': 'Private room',
#   'price': 32.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 11, 10),
#   'reviews_per_month': 0.32,
#   'calculated_host_listings_count': 4,
#   'availability_365': 254,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10038776',
#   'name': 'Home in Queens · ★4.59 · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '51531044',
#   'host_name': 'Angela',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jackson Heights',
#   'latitude': 40.75203,
#   'longitude': -73.87585,
#   'room_type': 'Private room',
#   'price': 60.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 145,
#   'last_review': datetime.date(2023, 10, 7),
#   'reviews_per_month': 1.51,
#   'calculated_host_listings_count': 2,
#   'availability_365': 364,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1005289392264251171',
#   'name': 'Home in Queens · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '506322547',
#   'host_name': 'Tania',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Woodhaven',
#   'latitude': 40.695736,
#   'longitude': -73.851654,
#   'room_type': 'Private room',
#   'price': 60.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2024, 1, 26),
#   'reviews_per_month': 1.18,
#   'calculated_host_listings_count': 4,
#   'availability_365': 246,
#   'number_of_reviews_ltm': 2,
#   'license': ''},
#  {'id': '1003608586010420731',
#   'name': 'Hotel in Queens · ★4.20 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.6917,
#   'longitude': -73.808655,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 1.49,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt'},
#  {'id': '10085478',
#   'name': 'Rental unit in Brooklyn · ★4.87 · Studio · 2 beds · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72858,
#   'longitude': -73.94534,
#   'room_type': 'Entire home/apt',
#   'price': 251.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 45,
#   'last_review': datetime.date(2024, 1, 20),
#   'reviews_per_month': 0.46,
#   'calculated_host_listings_count': 14,
#   'availability_365': 77,
#   'number_of_reviews_ltm': 3,
#   'license': 'Exempt'},
#  {'id': '10086307',
#   'name': 'Townhouse in New York · ★4.85 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '13792543',
#   'host_name': 'Gregory',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.80747,
#   'longitude': -73.95076,
#   'room_type': 'Private room',
#   'price': 190.0,
#   'minimum_nights': 4,
#   'number_of_reviews': 177,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 1.8,
#   'calculated_host_listings_count': 3,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 28,
#   'license': 'OSE-STRREG-0000215'},
#  {'id': '1004585445966518011',
#   'name': 'Rental unit in Queens · Studio · 2 beds · 1 bath',
#   'host_id': '341452050',
#   'host_name': 'Jesus',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Sunnyside',
#   'latitude': 40.745216,
#   'longitude': -73.91511,
#   'room_type': 'Entire home/apt',
#   'price': 75.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2024, 1, 24),
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 2,
#   'availability_365': 156,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10019312',
#   'name': 'Rental unit in New York · ★4.76 · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '44216429',
#   'host_name': 'Maria',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Gramercy',
#   'latitude': 40.73809,
#   'longitude': -73.98509,
#   'room_type': 'Private room',
#   'price': 98.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 194,
#   'last_review': datetime.date(2023, 11, 4),
#   'reviews_per_month': 1.96,
#   'calculated_host_listings_count': 2,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 17,
#   'license': ''},
#  {'id': '10032487',
#   'name': 'Rental unit in New York · ★4.85 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '51504193',
#   'host_name': 'Hans',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'SoHo',
#   'latitude': 40.72555,
#   'longitude': -73.9985,
#   'room_type': 'Entire home/apt',
#   'price': 105.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 20,
#   'last_review': datetime.date(2023, 11, 17),
#   'reviews_per_month': 0.21,
#   'calculated_host_listings_count': 1,
#   'availability_365': 117,
#   'number_of_reviews_ltm': 3,
#   'license': ''},
#  {'id': '10034187',
#   'name': 'Loft in Brooklyn · ★4.86 · Studio · 1 bed · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72889,
#   'longitude': -73.94397,
#   'room_type': 'Entire home/apt',
#   'price': 173.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 50,
#   'last_review': datetime.date(2021, 12, 11),
#   'reviews_per_month': 0.51,
#   'calculated_host_listings_count': 14,
#   'availability_365': 73,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt'},
#  {'id': '10035471',
#   'name': 'Rental unit in Brooklyn · ★4.81 · Studio · 2 beds · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72847,
#   'longitude': -73.94337,
#   'room_type': 'Entire home/apt',
#   'price': 251.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 69,
#   'last_review': datetime.date(2023, 1, 23),
#   'reviews_per_month': 0.7,
#   'calculated_host_listings_count': 14,
#   'availability_365': 75,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt'},
#  {'id': '1000041661179181846',
#   'name': 'Rental unit in New York · ★4.69 · 1 bedroom · 2 beds · 1 bath',
#   'host_id': '266818709',
#   'host_name': 'Nathan',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.771847,
#   'longitude': -73.95974,
#   'room_type': 'Entire home/apt',
#   'price': 231.0,
#   'minimum_nights': 4,
#   'number_of_reviews': 16,
#   'last_review': datetime.date(2024, 1, 14),
#   'reviews_per_month': 4.29,
#   'calculated_host_listings_count': 1,
#   'availability_365': 85,
#   'number_of_reviews_ltm': 16,
#   'license': 'Exempt'},
#  {'id': '1003903298252831632',
#   'name': 'Rental unit in The Bronx · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '299371992',
#   'host_name': 'Jose',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Allerton',
#   'latitude': 40.87122,
#   'longitude': -73.848755,
#   'room_type': 'Entire home/apt',
#   'price': 72.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2023, 12, 31),
#   'reviews_per_month': 0.74,
#   'calculated_host_listings_count': 4,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 2,
#   'license': ''},
#  {'id': '1007417751629640278',
#   'name': 'Home in Brooklyn · ★5.0 · 3 bedrooms · 4 beds · 2.5 baths',
#   'host_id': '25896614',
#   'host_name': 'Taylor',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bushwick',
#   'latitude': 40.6925,
#   'longitude': -73.90714,
#   'room_type': 'Entire home/apt',
#   'price': 350.0,
#   'minimum_nights': 5,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2024, 1, 2),
#   'reviews_per_month': 1.56,
#   'calculated_host_listings_count': 2,
#   'availability_365': 83,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt'},
#  {'id': '1008092185988638009',
#   'name': 'Rental unit in New York · ★4.70 · 2 bedrooms · 2 beds · 2 baths',
#   'host_id': '421995573',
#   'host_name': 'Eliza',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Theater District',
#   'latitude': 40.76091,
#   'longitude': -73.98452,
#   'room_type': 'Entire home/apt',
#   'price': 388.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 10,
#   'last_review': datetime.date(2024, 1, 25),
#   'reviews_per_month': 3.57,
#   'calculated_host_listings_count': 3,
#   'availability_365': 200,
#   'number_of_reviews_ltm': 10,
#   'license': 'OSE-STRREG-0000379'},
#  {'id': '1008157650770589470',
#   'name': 'Rental unit in New York · ★4.51 · 1 bedroom · 2 beds · 1 bath',
#   'host_id': '495061716',
#   'host_name': 'Crowne Plaza Times Square',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Theater District',
#   'latitude': 40.761322,
#   'longitude': -73.98587,
#   'room_type': 'Entire home/apt',
#   'price': 499.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 61,
#   'last_review': datetime.date(2024, 2, 6),
#   'reviews_per_month': 21.53,
#   'calculated_host_listings_count': 2,
#   'availability_365': 100,
#   'number_of_reviews_ltm': 61,
#   'license': 'Exempt'},
#  {'id': '1008785726031193489',
#   'name': 'Home in New York · ★5.0 · 1 bedroom · 3 beds · 1 bath',
#   'host_id': '209334556',
#   'host_name': 'J',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.761436,
#   'longitude': -73.998116,
#   'room_type': 'Entire home/apt',
#   'price': 291.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 12,
#   'last_review': datetime.date(2024, 1, 25),
#   'reviews_per_month': 4.93,
#   'calculated_host_listings_count': 1,
#   'availability_365': 191,
#   'number_of_reviews_ltm': 12,
#   'license': 'OSE-STRREG-0000320'},
#  {'id': '1009542110611743262',
#   'name': 'Rental unit in New York · ★4.31 · 2 bedrooms · 3 beds · 1 bath',
#   'host_id': '267175603',
#   'host_name': 'Sonia',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.75705,
#   'longitude': -73.99316,
#   'room_type': 'Entire home/apt',
#   'price': 197.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 13,
#   'last_review': datetime.date(2024, 1, 19),
#   'reviews_per_month': 4.02,
#   'calculated_host_listings_count': 1,
#   'availability_365': 61,
#   'number_of_reviews_ltm': 13,
#   'license': 'Exempt'},
#  {'id': '1001147',
#   'name': 'Rental unit in Brooklyn · ★4.87 · 1 bedroom · 1 bed · 1 private '
#           'bath',
#   'host_id': '3363720',
#   'host_name': 'Kate',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.68746,
#   'longitude': -73.91945,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 103,
#   'last_review': datetime.date(2019, 9, 3),
#   'reviews_per_month': 0.78,
#   'calculated_host_listings_count': 3,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10038410',
#   'name': 'Loft in Brooklyn · ★4.91 · Studio · 2 beds · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.7291,
#   'longitude': -73.94463,
#   'room_type': 'Entire home/apt',
#   'price': 224.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 55,
#   'last_review': datetime.date(2023, 12, 19),
#   'reviews_per_month': 0.56,
#   'calculated_host_listings_count': 14,
#   'availability_365': 86,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt'},
#  {'id': '10038693',
#   'name': 'Loft in Brooklyn · ★4.95 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72761,
#   'longitude': -73.94516,
#   'room_type': 'Entire home/apt',
#   'price': 173.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 38,
#   'last_review': datetime.date(2024, 1, 17),
#   'reviews_per_month': 0.43,
#   'calculated_host_listings_count': 14,
#   'availability_365': 76,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '10041002',
#   'name': 'Rental unit in Brooklyn · ★4.33 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '7503132',
#   'host_name': 'Whitney',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Clinton Hill',
#   'latitude': 40.68419,
#   'longitude': -73.96122,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 6,
#   'last_review': datetime.date(2016, 11, 27),
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10050536',
#   'name': 'Loft in Brooklyn · ★4.87 · Studio · 1 bed · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72843,
#   'longitude': -73.94531,
#   'room_type': 'Entire home/apt',
#   'price': 173.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 45,
#   'last_review': datetime.date(2022, 10, 22),
#   'reviews_per_month': 0.46,
#   'calculated_host_listings_count': 14,
#   'availability_365': 73,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt'},
#  {'id': '10057826',
#   'name': 'Rental unit in Brooklyn · ★4.67 · Studio · 2 beds · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72825,
#   'longitude': -73.94321,
#   'room_type': 'Entire home/apt',
#   'price': 251.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 12,
#   'last_review': datetime.date(2022, 11, 7),
#   'reviews_per_month': 0.12,
#   'calculated_host_listings_count': 14,
#   'availability_365': 82,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt'},
#  {'id': '10070693',
#   'name': 'Rental unit in New York · ★3.57 · Studio · 1 bed · 1 bath',
#   'host_id': '51651427',
#   'host_name': 'Sayaka',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.76009,
#   'longitude': -73.96129,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 7,
#   'last_review': datetime.date(2018, 1, 3),
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10089727',
#   'name': 'Hotel in New York · ★5.0 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '51772392',
#   'host_name': 'Mark',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.76252,
#   'longitude': -73.97552,
#   'room_type': 'Private room',
#   'price': 785.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 21,
#   'last_review': datetime.date(2022, 1, 21),
#   'reviews_per_month': 0.28,
#   'calculated_host_listings_count': 2,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt'},
#  {'id': '100002',
#   'name': 'Rental unit in New York · ★4.69 · 1 bedroom · 2 beds · 1 shared '
#           'bath',
#   'host_id': '523218',
#   'host_name': 'Giorgio',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Washington Heights',
#   'latitude': 40.85433,
#   'longitude': -73.9324,
#   'room_type': 'Private room',
#   'price': 62.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 150,
#   'last_review': datetime.date(2021, 8, 11),
#   'reviews_per_month': 0.97,
#   'calculated_host_listings_count': 1,
#   'availability_365': 173,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '100186',
#   'name': 'Rental unit in Brooklyn · ★4.94 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '526805',
#   'host_name': 'Mi',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Gowanus',
#   'latitude': 40.66952,
#   'longitude': -73.99201,
#   'room_type': 'Entire home/apt',
#   'price': 150.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 119,
#   'last_review': datetime.date(2023, 6, 17),
#   'reviews_per_month': 0.77,
#   'calculated_host_listings_count': 1,
#   'availability_365': 101,
#   'number_of_reviews_ltm': 3,
#   'license': ''},
#  {'id': '100368',
#   'name': 'Rental unit in New York · ★4.80 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '526105',
#   'host_name': 'Scott',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.74056,
#   'longitude': -74.00143,
#   'room_type': 'Entire home/apt',
#   'price': 198.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 38,
#   'last_review': datetime.date(2023, 7, 31),
#   'reviews_per_month': 0.25,
#   'calculated_host_listings_count': 1,
#   'availability_365': 57,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10031902',
#   'name': 'Rental unit in New York · ★5.0 · Studio · 1 bed · 1 bath',
#   'host_id': '51501835',
#   'host_name': 'Jeniffer',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.76372,
#   'longitude': -73.99318,
#   'room_type': 'Entire home/apt',
#   'price': 150.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 12,
#   'last_review': datetime.date(2023, 12, 15),
#   'reviews_per_month': 0.13,
#   'calculated_host_listings_count': 142,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 3,
#   'license': ''},
#  {'id': '10038170',
#   'name': 'Rental unit in Brooklyn · ★4.71 · Studio · 2 beds · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72917,
#   'longitude': -73.94398,
#   'room_type': 'Entire home/apt',
#   'price': 251.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 7,
#   'last_review': datetime.date(2022, 7, 14),
#   'reviews_per_month': 0.09,
#   'calculated_host_listings_count': 14,
#   'availability_365': 82,
#   'number_of_reviews_ltm': 0,
#   'license': 'Exempt'},
#  {'id': '10052587',
#   'name': 'Loft in Brooklyn · ★4.76 · Studio · 2 beds · 1 bath',
#   'host_id': '47554473',
#   'host_name': 'Henry Norman',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72892,
#   'longitude': -73.94363,
#   'room_type': 'Entire home/apt',
#   'price': 224.0,
#   'minimum_nights': 3,
#   'number_of_reviews': 51,
#   'last_review': datetime.date(2023, 11, 13),
#   'reviews_per_month': 0.52,
#   'calculated_host_listings_count': 14,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 1,
#   'license': 'Exempt'},
#  {'id': '10053993',
#   'name': 'Rental unit in New York · ★5.0 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '25821059',
#   'host_name': 'Jenna',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'West Village',
#   'latitude': 40.73495,
#   'longitude': -74.00854,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 6,
#   'last_review': datetime.date(2016, 7, 25),
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10069964',
#   'name': 'Rental unit in Brooklyn · ★5.0 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '12616662',
#   'host_name': 'Anthony',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.71777,
#   'longitude': -73.95382,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 3,
#   'last_review': datetime.date(2016, 5, 7),
#   'reviews_per_month': 0.03,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '1004971870241259997',
#   'name': 'Rental unit in Long Island City · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '5735865',
#   'host_name': 'Usquire',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Long Island City',
#   'latitude': 40.75617,
#   'longitude': -73.93637,
#   'room_type': 'Entire home/apt',
#   'price': 275.0,
#   'minimum_nights': 4,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 0.81,
#   'calculated_host_listings_count': 19,
#   'availability_365': 215,
#   'number_of_reviews_ltm': 1,
#   'license': 'Exempt'},
#  {'id': '1002366025511188301',
#   'name': 'Hotel in Queens · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '537729916',
#   'host_name': 'Lakhwinder',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.693703,
#   'longitude': -73.80698,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 9),
#   'reviews_per_month': 0.5,
#   'calculated_host_listings_count': 8,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 1,
#   'license': 'Exempt'},
#  {'id': '10097957',
#   'name': 'Rental unit in New York · ★5.0 · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '17501091',
#   'host_name': 'Sheng-Min',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.810265,
#   'longitude': -73.94696,
#   'room_type': 'Private room',
#   'price': 55.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 10,
#   'last_review': datetime.date(2023, 9, 27),
#   'reviews_per_month': 0.14,
#   'calculated_host_listings_count': 1,
#   'availability_365': 46,
#   'number_of_reviews_ltm': 5,
#   'license': ''},
#  {'id': '1000689815874814414',
#   'name': 'Rental unit in New York · ★4.87 · 1 bedroom · 1 bed · 3 baths',
#   'host_id': '3660702',
#   'host_name': 'Greg',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.74732,
#   'longitude': -73.98964,
#   'room_type': 'Private room',
#   'price': 107.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 15,
#   'last_review': datetime.date(2024, 1, 16),
#   'reviews_per_month': 4.02,
#   'calculated_host_listings_count': 7,
#   'availability_365': 121,
#   'number_of_reviews_ltm': 15,
#   'license': 'Exempt'},
#  {'id': '1009883',
#   'name': 'Townhouse in Brooklyn · ★5.0 · 2 bedrooms · 4 beds · 1.5 baths',
#   'host_id': '329436',
#   'host_name': 'Jana',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Carroll Gardens',
#   'latitude': 40.68272,
#   'longitude': -73.99204,
#   'room_type': 'Entire home/apt',
#   'price': 375.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 77,
#   'last_review': datetime.date(2023, 9, 4),
#   'reviews_per_month': 0.61,
#   'calculated_host_listings_count': 2,
#   'availability_365': 49,
#   'number_of_reviews_ltm': 8,
#   'license': ''},
#  {'id': '10032495',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '2830735',
#   'host_name': 'Joshua',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.80199,
#   'longitude': -73.96859,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2015, 12, 22),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10034090',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '7763913',
#   'host_name': 'Dawn',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.71035,
#   'longitude': -73.94497,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 7),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10000070',
#   'name': 'Rental unit in Brooklyn · ★4.65 · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '51372003',
#   'host_name': 'Ninell',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Flatbush',
#   'latitude': 40.64905,
#   'longitude': -73.96905,
#   'room_type': 'Private room',
#   'price': 85.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 20,
#   'last_review': datetime.date(2022, 12, 18),
#   'reviews_per_month': 0.2,
#   'calculated_host_listings_count': 2,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10082057',
#   'name': 'Home in Brooklyn · ★5.0 · 1 bedroom · 1 bed · 1.5 baths',
#   'host_id': '51734800',
#   'host_name': 'Laura',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Flatbush',
#   'latitude': 40.63,
#   'longitude': -73.96462,
#   'room_type': 'Private room',
#   'price': 55.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 7,
#   'last_review': datetime.date(2023, 8, 30),
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 2,
#   'availability_365': 280,
#   'number_of_reviews_ltm': 2,
#   'license': ''},
#  {'id': '10087874',
#   'name': 'Townhouse in Brooklyn  · ★5.0 · 2 bedrooms · 1 bed · 1.5 baths',
#   'host_id': '28840058',
#   'host_name': 'Karen',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.68058,
#   'longitude': -73.92038,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 4,
#   'last_review': datetime.date(2018, 1, 2),
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10088464',
#   'name': 'Rental unit in New York · ★4.50 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '51764491',
#   'host_name': 'Rachel',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72896,
#   'longitude': -73.98239,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 4,
#   'last_review': datetime.date(2016, 2, 1),
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10013750',
#   'name': 'Rental unit in New York · ★4.80 · 2 bedrooms · 1 bed · 1.5 shared '
#           'baths',
#   'host_id': '20222376',
#   'host_name': 'Olia',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Lower East Side',
#   'latitude': 40.7183,
#   'longitude': -73.99173,
#   'room_type': 'Private room',
#   'price': 98.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 44,
#   'last_review': datetime.date(2023, 10, 2),
#   'reviews_per_month': 0.47,
#   'calculated_host_listings_count': 1,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 10,
#   'license': ''},
#  {'id': '10010012',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '43014167',
#   'host_name': 'Mark',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Washington Heights',
#   'latitude': 40.83612,
#   'longitude': -73.93885,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 5, 20),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10011086',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '22257525',
#   'host_name': 'Andrea',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.824,
#   'longitude': -73.95314,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 8, 19),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10011850',
#   'name': 'Rental unit in New York · ★4.50 · Studio · 2 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.75104,
#   'longitude': -73.98276,
#   'room_type': 'Entire home/apt',
#   'price': 97.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 6,
#   'last_review': datetime.date(2023, 5, 6),
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 33,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10015137',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '51433399',
#   'host_name': 'Meghan',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Prospect-Lefferts Gardens',
#   'latitude': 40.66044,
#   'longitude': -73.95968,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 5),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10015195',
#   'name': 'Rental unit in New York · ★4.67 · Studio · 1 bed · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.7492,
#   'longitude': -73.98229,
#   'room_type': 'Entire home/apt',
#   'price': 110.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 3,
#   'last_review': datetime.date(2019, 9, 24),
#   'reviews_per_month': 0.03,
#   'calculated_host_listings_count': 33,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10016343',
#   'name': 'Rental unit in New York · Studio · 1 bed · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.75107,
#   'longitude': -73.98244,
#   'room_type': 'Entire home/apt',
#   'price': 108.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2024, 1, 20),
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 33,
#   'availability_365': 180,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10016503',
#   'name': 'Rental unit in New York · ★3.25 · 3 bedrooms · 3 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.75108,
#   'longitude': -73.98057,
#   'room_type': 'Entire home/apt',
#   'price': 129.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 4,
#   'last_review': datetime.date(2019, 10, 4),
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 33,
#   'availability_365': 180,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10016601',
#   'name': 'Rental unit in New York · ★4.20 · 2 bedrooms · 3 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Kips Bay',
#   'latitude': 40.74521,
#   'longitude': -73.97819,
#   'room_type': 'Entire home/apt',
#   'price': 109.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2019, 3, 17),
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 33,
#   'availability_365': 89,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10016832',
#   'name': 'Rental unit in New York · 2 bedrooms · 3 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Murray Hill',
#   'latitude': 40.74707,
#   'longitude': -73.97782,
#   'room_type': 'Entire home/apt',
#   'price': 150.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2018, 5, 19),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 33,
#   'availability_365': 181,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10017087',
#   'name': 'Rental unit in New York · ★2.83 · 2 bedrooms · 4 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Murray Hill',
#   'latitude': 40.74706,
#   'longitude': -73.97779,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 6,
#   'last_review': datetime.date(2023, 1, 1),
#   'reviews_per_month': 0.07,
#   'calculated_host_listings_count': 33,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10017170',
#   'name': 'Rental unit in New York · ★3.80 · 2 bedrooms · 3 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Murray Hill',
#   'latitude': 40.74709,
#   'longitude': -73.97816,
#   'room_type': 'Entire home/apt',
#   'price': 140.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2023, 4, 5),
#   'reviews_per_month': 0.06,
#   'calculated_host_listings_count': 33,
#   'availability_365': 150,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10017458',
#   'name': 'Rental unit in New York · ★4.0 · 2 bedrooms · 4 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Murray Hill',
#   'latitude': 40.74552,
#   'longitude': -73.97637,
#   'room_type': 'Entire home/apt',
#   'price': 101.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 4,
#   'last_review': datetime.date(2018, 8, 4),
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 33,
#   'availability_365': 161,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10017561',
#   'name': 'Rental unit in New York · ★3.75 · 2 bedrooms · 2 beds · 1 bath',
#   'host_id': '50760546',
#   'host_name': 'CRNY Monthly Rentals',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Murray Hill',
#   'latitude': 40.74656,
#   'longitude': -73.9762,
#   'room_type': 'Entire home/apt',
#   'price': 109.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 4,
#   'last_review': datetime.date(2018, 11, 2),
#   'reviews_per_month': 0.04,
#   'calculated_host_listings_count': 33,
#   'availability_365': 75,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10096515',
#   'name': 'Rental unit in New York · ★4.33 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '12485770',
#   'host_name': 'Raanan',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.73001,
#   'longitude': -73.97933,
#   'room_type': 'Entire home/apt',
#   'price': 120.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 9,
#   'last_review': datetime.date(2023, 11, 5),
#   'reviews_per_month': 0.1,
#   'calculated_host_listings_count': 5,
#   'availability_365': 273,
#   'number_of_reviews_ltm': 2,
#   'license': ''},
#  {'id': '10096773',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '34607505',
#   'host_name': 'Scott',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chelsea',
#   'latitude': 40.74577,
#   'longitude': -74.00074,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 3),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10099517',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '16869971',
#   'host_name': 'Han',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Roosevelt Island',
#   'latitude': 40.76908,
#   'longitude': -73.94504,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 5),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 2,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10022348',
#   'name': 'Rental unit in New York · ★4.77 · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '51462513',
#   'host_name': 'Lulu',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.7678,
#   'longitude': -73.96032,
#   'room_type': 'Entire home/apt',
#   'price': 145.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 22,
#   'last_review': datetime.date(2018, 4, 1),
#   'reviews_per_month': 0.23,
#   'calculated_host_listings_count': 1,
#   'availability_365': 180,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10034817',
#   'name': 'Rental unit in New York · ★5.0 · 2 bedrooms · 1 bed · 1 bath',
#   'host_id': '51501835',
#   'host_name': 'Jeniffer',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.76439,
#   'longitude': -73.99457,
#   'room_type': 'Entire home/apt',
#   'price': 180.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2024, 1, 21),
#   'reviews_per_month': 0.05,
#   'calculated_host_listings_count': 142,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10035098',
#   'name': 'Rental unit in New York · Studio · 2 beds · 1 bath',
#   'host_id': '51513795',
#   'host_name': 'Doug',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.77731,
#   'longitude': -73.98143,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 3),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10021499',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '48446355',
#   'host_name': 'Alexandra',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.71045,
#   'longitude': -73.9517,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 2),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10021643',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '44118283',
#   'host_name': 'Guillaume',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.79585,
#   'longitude': -73.9764,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 2, 15),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''},
#  {'id': '10031678',
#   'name': 'Rental unit in New York · ★4.93 · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '46540057',
#   'host_name': 'Charlie',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Chinatown',
#   'latitude': 40.71658,
#   'longitude': -73.99818,
#   'room_type': 'Shared room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 15,
#   'last_review': datetime.date(2017, 12, 18),
#   'reviews_per_month': 0.19,
# ...
#   'reviews_per_month': 1.0,
#   'calculated_host_listings_count': 8,
#   'availability_365': 283,
#   'number_of_reviews_ltm': 1,
#   'license': 'Exempt'},
#  {'id': '1008684865225089784',
#   'name': 'Guest suite in Brooklyn · ★5.0 · 1 bedroom · 2 beds · 1 private '
#           'bath',
#   'host_id': '37984527',
#   'host_name': 'Alexis',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Cypress Hills',
#   'latitude': 40.677567,
#   'longitude': -73.90605,
#   'room_type': 'Private room',
#   'price': 94.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 19,
#   'last_review': datetime.date(2024, 1, 31),
#   'reviews_per_month': 5.59,
#   'calculated_host_listings_count': 1,
#   'availability_365': 33,
#   'number_of_reviews_ltm': 19,
#   'license': 'OSE-STRREG-0000070'},
#  {'id': '1005833528005268756',
#   'name': 'Rental unit in New York · 1 bedroom · 1.5 baths',
#   'host_id': '247422117',
#   'host_name': 'Yuki',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.80841,
#   'longitude': -73.94966,
#   'room_type': 'Private room',
#   'price': 50.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 12),
#   'reviews_per_month': 0.53,
#   'calculated_host_listings_count': 2,
#   'availability_365': 121,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1006408371449823451',
#   'name': 'Rental unit in New York · 2 bedrooms · 2 beds · 2 baths',
#   'host_id': '107434423',
#   'host_name': 'Blueground',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.73241,
#   'longitude': -73.98748,
#   'room_type': 'Entire home/apt',
#   'price': 347.0,
#   'minimum_nights': 31,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2024, 1, 9),
#   'reviews_per_month': 0.91,
#   'calculated_host_listings_count': 827,
#   'availability_365': 352,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1006487297634998418',
#   'name': 'Guesthouse in Brooklyn · ★4.71 · 1 bedroom · 3 beds · 1 bath',
#   'host_id': '542706656',
#   'host_name': 'Arianna',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'East New York',
#   'latitude': 40.6702,
#   'longitude': -73.899284,
#   'room_type': 'Entire home/apt',
#   'price': 102.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 6,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 2.12,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 6,
#   'license': 'Exempt'},
#  {'id': '1006538240180611744',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '529333924',
#   'host_name': 'Taz',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.80756,
#   'longitude': -73.95317,
#   'room_type': 'Entire home/apt',
#   'price': 149.0,
#   'minimum_nights': 25,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2023, 11, 10),
#   'reviews_per_month': 0.65,
#   'calculated_host_listings_count': 4,
#   'availability_365': 238,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1006681477271989960',
#   'name': 'Rental unit in New York · 3 bedrooms · 4 beds · 1.5 baths',
#   'host_id': '370216107',
#   'host_name': 'Joan',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Greenwich Village',
#   'latitude': 40.734173,
#   'longitude': -73.99575,
#   'room_type': 'Entire home/apt',
#   'price': 313.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2024, 1, 29),
#   'reviews_per_month': 0.82,
#   'calculated_host_listings_count': 1,
#   'availability_365': 226,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1007164020066811197',
#   'name': 'Condo in New York · ★3.0 · Studio · 2 beds · 1 bath',
#   'host_id': '486475604',
#   'host_name': 'Mauricio',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.804447,
#   'longitude': -73.95424,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 1,
#   'number_of_reviews': 3,
#   'last_review': datetime.date(2023, 12, 24),
#   'reviews_per_month': 1.14,
#   'calculated_host_listings_count': 1,
#   'availability_365': 266,
#   'number_of_reviews_ltm': 3,
#   'license': 'Exempt'},
#  {'id': '1007269050220441363',
#   'name': 'Home in Brooklyn · 2 bedrooms · 2 baths',
#   'host_id': '396808869',
#   'host_name': 'Casa',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.68676,
#   'longitude': -73.93824,
#   'room_type': 'Entire home/apt',
#   'price': 275.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 31),
#   'reviews_per_month': 0.79,
#   'calculated_host_listings_count': 3,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1007601556813394060',
#   'name': 'Rental unit in New York · 4 bedrooms · 1 bed · 2 shared baths',
#   'host_id': '3223938',
#   'host_name': 'Eugene',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.8035,
#   'longitude': -73.96668,
#   'room_type': 'Private room',
#   'price': 56.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 15),
#   'reviews_per_month': 0.52,
#   'calculated_host_listings_count': 600,
#   'availability_365': 56,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1007999788231623746',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '436311597',
#   'host_name': 'Devora',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Bedford-Stuyvesant',
#   'latitude': 40.67859,
#   'longitude': -73.94486,
#   'room_type': 'Entire home/apt',
#   'price': 136.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2023, 12, 29),
#   'reviews_per_month': 1.36,
#   'calculated_host_listings_count': 8,
#   'availability_365': 287,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1008073352246997879',
#   'name': 'Townhouse in New York · ★5.0 · 3 bedrooms · 3 beds · 3 baths',
#   'host_id': '148272313',
#   'host_name': 'Steven',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Kips Bay',
#   'latitude': 40.744526,
#   'longitude': -73.97657,
#   'room_type': 'Entire home/apt',
#   'price': 1135.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 6,
#   'last_review': datetime.date(2024, 1, 15),
#   'reviews_per_month': 2.12,
#   'calculated_host_listings_count': 2,
#   'availability_365': 130,
#   'number_of_reviews_ltm': 6,
#   'license': 'Exempt'},
#  {'id': '1008100284888923836',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 2 beds · 1 bath',
#   'host_id': '50190063',
#   'host_name': 'Asaf',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Downtown Brooklyn',
#   'latitude': 40.691246,
#   'longitude': -73.983665,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 1),
#   'reviews_per_month': 0.44,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1008781781839490021',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 1 bed · 1 shared bath',
#   'host_id': '10457092',
#   'host_name': 'Anthony',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Williamsburg',
#   'latitude': 40.70171,
#   'longitude': -73.94322,
#   'room_type': 'Private room',
#   'price': 55.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2024, 1, 30),
#   'reviews_per_month': 0.88,
#   'calculated_host_listings_count': 4,
#   'availability_365': 269,
#   'number_of_reviews_ltm': 2,
#   'license': ''},
#  {'id': '1008957074079095931',
#   'name': 'Rental unit in New York · ★4.77 · Studio · 1 bed · 1 bath',
#   'host_id': '6742535',
#   'host_name': 'Sonia',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.73273,
#   'longitude': -73.98649,
#   'room_type': 'Entire home/apt',
#   'price': 195.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 13,
#   'last_review': datetime.date(2024, 1, 24),
#   'reviews_per_month': 3.64,
#   'calculated_host_listings_count': 1,
#   'availability_365': 24,
#   'number_of_reviews_ltm': 13,
#   'license': 'Exempt'},
#  {'id': '1008975153202791731',
#   'name': 'Guesthouse in New York · ★5.0 · 3 bedrooms · 4 beds · 2.5 baths',
#   'host_id': '248133997',
#   'host_name': 'Tsu',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Midtown',
#   'latitude': 40.761738,
#   'longitude': -73.97291,
#   'room_type': 'Entire home/apt',
#   'price': 483.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2024, 1, 31),
#   'reviews_per_month': 4.29,
#   'calculated_host_listings_count': 2,
#   'availability_365': 177,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt'},
#  {'id': '1008987937555990345',
#   'name': 'Rental unit in New York · ★4.63 · Studio · 1 bed · 1 bath',
#   'host_id': '7139930',
#   'host_name': 'Regina',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper East Side',
#   'latitude': 40.770706,
#   'longitude': -73.96007,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 2,
#   'number_of_reviews': 8,
#   'last_review': datetime.date(2024, 1, 28),
#   'reviews_per_month': 2.67,
#   'calculated_host_listings_count': 3,
#   'availability_365': 80,
#   'number_of_reviews_ltm': 8,
#   'license': 'Exempt'},
#  {'id': '1009851356023226507',
#   'name': 'Rental unit in Brooklyn · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '445024498',
#   'host_name': 'David',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Greenpoint',
#   'latitude': 40.72036,
#   'longitude': -73.94712,
#   'room_type': 'Entire home/apt',
#   'price': nan,
#   'minimum_nights': 7,
#   'number_of_reviews': 2,
#   'last_review': datetime.date(2024, 1, 15),
#   'reviews_per_month': 1.07,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 2,
#   'license': 'Exempt'},
#  {'id': '1009920147263075999',
#   'name': 'Rental unit in New York · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '107434423',
#   'host_name': 'Blueground',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'West Village',
#   'latitude': 40.730335,
#   'longitude': -74.005066,
#   'room_type': 'Entire home/apt',
#   'price': 300.0,
#   'minimum_nights': 31,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 24),
#   'reviews_per_month': 0.61,
#   'calculated_host_listings_count': 827,
#   'availability_365': 344,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1002762231875704553',
#   'name': 'Home in The Bronx · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '5652395',
#   'host_name': 'Julio',
#   'neighbourhood_group': 'Bronx',
#   'neighbourhood': 'Concourse Village',
#   'latitude': 40.819057,
#   'longitude': -73.92663,
#   'room_type': 'Private room',
#   'price': 50.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2024, 1, 1),
#   'reviews_per_month': 0.81,
#   'calculated_host_listings_count': 3,
#   'availability_365': 179,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1002825899474348002',
#   'name': 'Rental unit in Brooklyn · ★4.29 · 1 bedroom · 3 beds · 1 bath',
#   'host_id': '436311597',
#   'host_name': 'Devora',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Crown Heights',
#   'latitude': 40.67665,
#   'longitude': -73.94492,
#   'room_type': 'Entire home/apt',
#   'price': 154.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 7,
#   'last_review': datetime.date(2024, 1, 8),
#   'reviews_per_month': 2.04,
#   'calculated_host_listings_count': 8,
#   'availability_365': 305,
#   'number_of_reviews_ltm': 7,
#   'license': 'Exempt'},
#  {'id': '1002938301240121368',
#   'name': 'Home in Brooklyn · ★5.0 · 1 bedroom · 1 bath',
#   'host_id': '3818314',
#   'host_name': 'Levi',
#   'neighbourhood_group': 'Brooklyn',
#   'neighbourhood': 'Crown Heights',
#   'latitude': 40.6691,
#   'longitude': -73.94238,
#   'room_type': 'Entire home/apt',
#   'price': 175.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 9,
#   'last_review': datetime.date(2024, 2, 1),
#   'reviews_per_month': 2.41,
#   'calculated_host_listings_count': 3,
#   'availability_365': 295,
#   'number_of_reviews_ltm': 9,
#   'license': 'Exempt'},
#  {'id': '1003185235835253133',
#   'name': 'Rental unit in New York · ★4.0 · 2 bedrooms · 6 beds · 2 baths',
#   'host_id': '396845074',
#   'host_name': 'Ally',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'East Village',
#   'latitude': 40.72159,
#   'longitude': -73.97517,
#   'room_type': 'Entire home/apt',
#   'price': 735.0,
#   'minimum_nights': 7,
#   'number_of_reviews': 3,
#   'last_review': datetime.date(2023, 12, 28),
#   'reviews_per_month': 1.36,
#   'calculated_host_listings_count': 2,
#   'availability_365': 263,
#   'number_of_reviews_ltm': 3,
#   'license': 'Exempt'},
#  {'id': '1003437049851150279',
#   'name': 'Rental unit in New York · ★4.88 · Studio · 1 bed · 1 shared bath',
#   'host_id': '508344539',
#   'host_name': 'Sabrina',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Harlem',
#   'latitude': 40.827957,
#   'longitude': -73.942856,
#   'room_type': 'Private room',
#   'price': 81.0,
#   'minimum_nights': 1,
#   'number_of_reviews': 17,
#   'last_review': datetime.date(2024, 2, 1),
#   'reviews_per_month': 4.77,
#   'calculated_host_listings_count': 2,
#   'availability_365': 178,
#   'number_of_reviews_ltm': 17,
#   'license': 'OSE-STRREG-0000119'},
#  {'id': '1003861097745796435',
#   'name': 'Rental unit in New York · 2 bedrooms · 3 beds · 2 baths',
#   'host_id': '374444658',
#   'host_name': 'Ann',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.761177,
#   'longitude': -73.99033,
#   'room_type': 'Entire home/apt',
#   'price': 264.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 19),
#   'reviews_per_month': 0.56,
#   'calculated_host_listings_count': 1,
#   'availability_365': 338,
#   'number_of_reviews_ltm': 1,
#   'license': 'Exempt'},
#  {'id': '1008695241970793764',
#   'name': 'Rental unit in New York · ★5.0 · 4 bedrooms · 5 beds · 1 bath',
#   'host_id': '538722287',
#   'host_name': 'Isabel',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.799732,
#   'longitude': -73.96043,
#   'room_type': 'Entire home/apt',
#   'price': 326.0,
#   'minimum_nights': 6,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2024, 1, 23),
#   'reviews_per_month': 1.65,
#   'calculated_host_listings_count': 1,
#   'availability_365': 32,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt'},
#  {'id': '1003623057347580030',
#   'name': 'Rental unit in New York · 4 bedrooms · 4 beds · 3.5 baths',
#   'host_id': '17775359',
#   'host_name': 'Rove',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.7606,
#   'longitude': -73.99497,
#   'room_type': 'Entire home/apt',
#   'price': 324.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 11, 30),
#   'reviews_per_month': 0.43,
#   'calculated_host_listings_count': 57,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '1007421778971968598',
#   'name': 'Rental unit in Queens · 3 bedrooms · 2 baths',
#   'host_id': '183377855',
#   'host_name': 'William',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Flushing',
#   'latitude': 40.762016,
#   'longitude': -73.802246,
#   'room_type': 'Entire home/apt',
#   'price': 170.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 20),
#   'reviews_per_month': 0.61,
#   'calculated_host_listings_count': 1,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 1,
#   'license': ''},
#  {'id': '10057854',
#   'name': 'Rental unit in Queens · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '51614806',
#   'host_name': 'Justyna',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Long Island City',
#   'latitude': 40.74829,
#   'longitude': -73.94083,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 16),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': ''}]

# %%
for d in dict_ljr100_left:

# selection of df that has df['id'] = d['id']

# selection by columnm value:
#       df.loc[df['column_name'] == some_value]
    dicts_reviews_one_listing = df_ljr100.loc[df_ljr100['id'] == d['id']].drop(cols_of_listings, axis=1).to_dict('records')

    print('The length of dicts_reviews_one_listing for', d['id'], 'is:', len(dicts_reviews_one_listing))

    # dict3 = df3.to_dict('records')
    # print(dict3[0:10])

    d['reviews'] = dicts_reviews_one_listing

pprint.pp(dict_ljr100_left)
# Out:
# The length of dicts_reviews_one_listing for 10073940 is: 184
# The length of dicts_reviews_one_listing for 1004466409355496588 is: 23
# The length of dicts_reviews_one_listing for 1001759466923816441 is: 2
# The length of dicts_reviews_one_listing for 1006068540323632978 is: 14
# The length of dicts_reviews_one_listing for 1005207590507549831 is: 13
# The length of dicts_reviews_one_listing for 1005170940682176047 is: 8
# The length of dicts_reviews_one_listing for 1005215166382279445 is: 2
# The length of dicts_reviews_one_listing for 1005236888864691555 is: 5
# The length of dicts_reviews_one_listing for 1001730138556048837 is: 9
# The length of dicts_reviews_one_listing for 1002217051026941997 is: 4
# The length of dicts_reviews_one_listing for 1006526346791543478 is: 10
# The length of dicts_reviews_one_listing for 1006786464665372746 is: 13
# The length of dicts_reviews_one_listing for 1008761034690239341 is: 18
# The length of dicts_reviews_one_listing for 1008301599260572123 is: 15
# The length of dicts_reviews_one_listing for 1008315491855065333 is: 14
# The length of dicts_reviews_one_listing for 1008861763783445922 is: 7
# The length of dicts_reviews_one_listing for 1008898957166303997 is: 2
# The length of dicts_reviews_one_listing for 1003438862092649925 is: 1
# The length of dicts_reviews_one_listing for 1003700405706338295 is: 1
# The length of dicts_reviews_one_listing for 10038776 is: 145
# The length of dicts_reviews_one_listing for 1005289392264251171 is: 2
# The length of dicts_reviews_one_listing for 1003608586010420731 is: 5
# The length of dicts_reviews_one_listing for 10085478 is: 45
# The length of dicts_reviews_one_listing for 10086307 is: 177
# The length of dicts_reviews_one_listing for 1004585445966518011 is: 1
# The length of dicts_reviews_one_listing for 10019312 is: 194
# The length of dicts_reviews_one_listing for 10032487 is: 20
# The length of dicts_reviews_one_listing for 10034187 is: 50
# The length of dicts_reviews_one_listing for 10035471 is: 69
# The length of dicts_reviews_one_listing for 1000041661179181846 is: 16
# The length of dicts_reviews_one_listing for 1003903298252831632 is: 2
# The length of dicts_reviews_one_listing for 1007417751629640278 is: 5
# The length of dicts_reviews_one_listing for 1008092185988638009 is: 10
# The length of dicts_reviews_one_listing for 1008157650770589470 is: 61
# The length of dicts_reviews_one_listing for 1008785726031193489 is: 12
# The length of dicts_reviews_one_listing for 1009542110611743262 is: 13
# The length of dicts_reviews_one_listing for 1001147 is: 103
# The length of dicts_reviews_one_listing for 10038410 is: 55
# The length of dicts_reviews_one_listing for 10038693 is: 38
# The length of dicts_reviews_one_listing for 10041002 is: 6
# The length of dicts_reviews_one_listing for 10050536 is: 45
# The length of dicts_reviews_one_listing for 10057826 is: 12
# The length of dicts_reviews_one_listing for 10070693 is: 7
# The length of dicts_reviews_one_listing for 10089727 is: 21
# The length of dicts_reviews_one_listing for 100002 is: 150
# The length of dicts_reviews_one_listing for 100186 is: 119
# The length of dicts_reviews_one_listing for 100368 is: 38
# The length of dicts_reviews_one_listing for 10031902 is: 12
# The length of dicts_reviews_one_listing for 10038170 is: 7
# The length of dicts_reviews_one_listing for 10052587 is: 51
# The length of dicts_reviews_one_listing for 10053993 is: 6
# The length of dicts_reviews_one_listing for 10069964 is: 3
# The length of dicts_reviews_one_listing for 1004971870241259997 is: 1
# The length of dicts_reviews_one_listing for 1002366025511188301 is: 1
# The length of dicts_reviews_one_listing for 10097957 is: 10
# The length of dicts_reviews_one_listing for 1000689815874814414 is: 15
# The length of dicts_reviews_one_listing for 1009883 is: 77
# The length of dicts_reviews_one_listing for 10032495 is: 1
# The length of dicts_reviews_one_listing for 10034090 is: 1
# The length of dicts_reviews_one_listing for 10000070 is: 20
# The length of dicts_reviews_one_listing for 10082057 is: 7
# The length of dicts_reviews_one_listing for 10087874 is: 4
# The length of dicts_reviews_one_listing for 10088464 is: 4
# The length of dicts_reviews_one_listing for 10013750 is: 44
# The length of dicts_reviews_one_listing for 10010012 is: 1
# The length of dicts_reviews_one_listing for 10011086 is: 1
# The length of dicts_reviews_one_listing for 10011850 is: 6
# The length of dicts_reviews_one_listing for 10015137 is: 1
# The length of dicts_reviews_one_listing for 10015195 is: 3
# The length of dicts_reviews_one_listing for 10016343 is: 1
# The length of dicts_reviews_one_listing for 10016503 is: 4
# The length of dicts_reviews_one_listing for 10016601 is: 5
# The length of dicts_reviews_one_listing for 10016832 is: 1
# The length of dicts_reviews_one_listing for 10017087 is: 6
# The length of dicts_reviews_one_listing for 10017170 is: 5
# The length of dicts_reviews_one_listing for 10017458 is: 4
# The length of dicts_reviews_one_listing for 10017561 is: 4
# The length of dicts_reviews_one_listing for 10096515 is: 9
# The length of dicts_reviews_one_listing for 10096773 is: 1
# The length of dicts_reviews_one_listing for 10099517 is: 1
# The length of dicts_reviews_one_listing for 10022348 is: 22
# The length of dicts_reviews_one_listing for 10034817 is: 5
# The length of dicts_reviews_one_listing for 10035098 is: 1
# The length of dicts_reviews_one_listing for 10021499 is: 1
# The length of dicts_reviews_one_listing for 10021643 is: 1
# The length of dicts_reviews_one_listing for 10031678 is: 15
# The length of dicts_reviews_one_listing for 10035950 is: 1
# The length of dicts_reviews_one_listing for 10037605 is: 1
# The length of dicts_reviews_one_listing for 10037631 is: 1
# The length of dicts_reviews_one_listing for 10055925 is: 23
# The length of dicts_reviews_one_listing for 10038633 is: 1
# The length of dicts_reviews_one_listing for 10039992 is: 3
# The length of dicts_reviews_one_listing for 10040649 is: 1
# The length of dicts_reviews_one_listing for 10052289 is: 3
# The length of dicts_reviews_one_listing for 10058971 is: 1
# The length of dicts_reviews_one_listing for 10071156 is: 45
# The length of dicts_reviews_one_listing for 10065831 is: 1
# The length of dicts_reviews_one_listing for 10068269 is: 1
# The length of dicts_reviews_one_listing for 10068693 is: 1
# The length of dicts_reviews_one_listing for 10069376 is: 6
# The length of dicts_reviews_one_listing for 10071225 is: 1
# The length of dicts_reviews_one_listing for 10071464 is: 2
# The length of dicts_reviews_one_listing for 1002574228813307452 is: 16
# The length of dicts_reviews_one_listing for 1003603678526992890 is: 4
# The length of dicts_reviews_one_listing for 1006493433993270690 is: 1
# The length of dicts_reviews_one_listing for 1004275203463075946 is: 12
# The length of dicts_reviews_one_listing for 1001533760739742081 is: 25
# The length of dicts_reviews_one_listing for 1000611103131696812 is: 2
# The length of dicts_reviews_one_listing for 1000027657512767160 is: 8
# The length of dicts_reviews_one_listing for 1000155970237732964 is: 15
# The length of dicts_reviews_one_listing for 1000697739867775924 is: 7
# The length of dicts_reviews_one_listing for 1000637914058448005 is: 2
# The length of dicts_reviews_one_listing for 1000023148920376325 is: 1
# The length of dicts_reviews_one_listing for 1000126313762418098 is: 1
# The length of dicts_reviews_one_listing for 1000668332795817574 is: 12
# The length of dicts_reviews_one_listing for 1000673945014779673 is: 2
# The length of dicts_reviews_one_listing for 1000674434781153107 is: 8
# The length of dicts_reviews_one_listing for 1000691832643780415 is: 11
# The length of dicts_reviews_one_listing for 1000972009684425031 is: 1
# The length of dicts_reviews_one_listing for 1001017141965922396 is: 1
# The length of dicts_reviews_one_listing for 1001166370551563656 is: 11
# The length of dicts_reviews_one_listing for 1001281907891952723 is: 17
# The length of dicts_reviews_one_listing for 1001442118570469957 is: 6
# The length of dicts_reviews_one_listing for 1001502515015239083 is: 1
# The length of dicts_reviews_one_listing for 1001507167604490878 is: 1
# The length of dicts_reviews_one_listing for 1004249761260526414 is: 1
# The length of dicts_reviews_one_listing for 1004250291069589609 is: 1
# The length of dicts_reviews_one_listing for 1004361021892120992 is: 1
# The length of dicts_reviews_one_listing for 1004428776661057322 is: 1
# The length of dicts_reviews_one_listing for 1004787316686543797 is: 12
# The length of dicts_reviews_one_listing for 1005105866274513750 is: 6
# The length of dicts_reviews_one_listing for 1001535719995297015 is: 4
# The length of dicts_reviews_one_listing for 1001598392441206590 is: 1
# The length of dicts_reviews_one_listing for 1001737519563399181 is: 1
# The length of dicts_reviews_one_listing for 1002399932577027729 is: 10
# The length of dicts_reviews_one_listing for 1002338091891147677 is: 1
# The length of dicts_reviews_one_listing for 1005344875304169760 is: 6
# The length of dicts_reviews_one_listing for 1005455401581521842 is: 1
# The length of dicts_reviews_one_listing for 1005508981356579864 is: 1
# The length of dicts_reviews_one_listing for 1005760022125022077 is: 1
# The length of dicts_reviews_one_listing for 1005823132194616885 is: 1
# The length of dicts_reviews_one_listing for 1008684865225089784 is: 19
# The length of dicts_reviews_one_listing for 1005833528005268756 is: 1
# The length of dicts_reviews_one_listing for 1006408371449823451 is: 1
# The length of dicts_reviews_one_listing for 1006487297634998418 is: 6
# The length of dicts_reviews_one_listing for 1006538240180611744 is: 2
# The length of dicts_reviews_one_listing for 1006681477271989960 is: 2
# The length of dicts_reviews_one_listing for 1007164020066811197 is: 3
# The length of dicts_reviews_one_listing for 1007269050220441363 is: 1
# The length of dicts_reviews_one_listing for 1007601556813394060 is: 1
# The length of dicts_reviews_one_listing for 1007999788231623746 is: 2
# The length of dicts_reviews_one_listing for 1008073352246997879 is: 6
# The length of dicts_reviews_one_listing for 1008100284888923836 is: 1
# The length of dicts_reviews_one_listing for 1008781781839490021 is: 2
# The length of dicts_reviews_one_listing for 1008957074079095931 is: 13
# The length of dicts_reviews_one_listing for 1008975153202791731 is: 5
# The length of dicts_reviews_one_listing for 1008987937555990345 is: 8
# The length of dicts_reviews_one_listing for 1009851356023226507 is: 2
# The length of dicts_reviews_one_listing for 1009920147263075999 is: 1
# The length of dicts_reviews_one_listing for 1002762231875704553 is: 1
# The length of dicts_reviews_one_listing for 1002825899474348002 is: 7
# The length of dicts_reviews_one_listing for 1002938301240121368 is: 9
# The length of dicts_reviews_one_listing for 1003185235835253133 is: 3
# The length of dicts_reviews_one_listing for 1003437049851150279 is: 17
# The length of dicts_reviews_one_listing for 1003861097745796435 is: 1
# The length of dicts_reviews_one_listing for 1008695241970793764 is: 5
# The length of dicts_reviews_one_listing for 1003623057347580030 is: 1
# The length of dicts_reviews_one_listing for 1007421778971968598 is: 1
# The length of dicts_reviews_one_listing for 10057854 is: 1
# [{'id': '10073940',
#   'name': 'Home in Queens · ★4.77 · 1 bedroom · 1 bed · 1 private bath',
#   'host_id': '51688993',
#   'host_name': 'Taran',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Jamaica',
#   'latitude': 40.68826,
#   'longitude': -73.80384,
#   'room_type': 'Private room',
#   'price': 200.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 184,
#   'last_review': datetime.date(2023, 9, 17),
#   'reviews_per_month': 1.95,
#   'calculated_host_listings_count': 1,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 18,
#   'license': '',
#   'reviews': [{'listing_id': '10073940',
#                'review_id': '88607874',
#                'date': datetime.date(2016, 7, 25),
#                'reviewer_id': '78858146',
#                'reviewer_name': 'Areefa',
#                'comments': 'This apartment is best described as a sanctuary '
#                            'amidst the hustle and bustle of the Queens area - '
#                            'a great place to unwind. \r'
#                            '<br/>It was spotless when we arrived and the hosts '
#                            'did a good job of keeping the outside clean too. '
#                            "It's very conveniently located close to amenities, "
#                            "as well as the Van Wyck Expwy. What's also "
#                            'impessive is the ample parking available - a rare '
#                            'find in NYC! \r'
#                            '<br/>The hosts were always easy to contact when '
#                            'needed. \r'
#                            '<br/>Good job Taran and Najla! ',
#                'datetime': Timestamp('2016-07-25 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '89002342',
#                'date': datetime.date(2016, 7, 26),
#                'reviewer_id': '42591774',
#                'reviewer_name': 'Natasha',
#                'comments': 'I am a mom of two children, one 4 year old and a '
#                            'newborn so obviously when looking for a place to '
#                            'stay, cleanliness and hygiene were at the very top '
#                            'of my list. When I came across Najla and Taran’s '
#                            'place I immediately booked and we were so grateful '
#                            'when they accepted. From the beginning the '
#                            'communication was great with the hosts, they were '
#                            'gracious and polite and very accommodating. Our '
#                            'flight arrived late at night and we truly '
#                            'appreciated their warm welcome. When we got to '
#                            'their place we were so excited that it was exactly '
#                            'what they advertised, it smelt clean and fresh and '
#                            'was absolutely spotless. You can tell that they '
#                            'take great care and pride with their home.There '
#                            'was a Keurig machine which my husband loved and as '
#                            'a mom I felt comfortable enough to even let my '
#                            'kids crawl and play on their floors! Other things '
#                            'we loved, it was close to the highway, we got to '
#                            'their house in about the time they stated it was '
#                            'from JFK and there was always parking for our '
#                            'rental. Thank you for a great stay and we will '
#                            'definitely be seeing you again and recommending '
#                            'your place to our friends! ',
#                'datetime': Timestamp('2016-07-26 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '664446674127275929',
#                'date': datetime.date(2022, 7, 5),
#                'reviewer_id': '403864376',
#                'reviewer_name': 'Kara',
#                'comments': 'Great host!  Very communicative, extremely clean '
#                            'and modern. All night lighting outside and camera '
#                            'made my family feel safe. Would highly recommend.',
#                'datetime': Timestamp('2022-07-05 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '256352777',
#                'date': datetime.date(2018, 4, 22),
#                'reviewer_id': '178946045',
#                'reviewer_name': 'Vivian',
#                'comments': 'This apartment was great! It felt like my own home '
#                            'and was extremely clean. I would definitely stay '
#                            'here again. It’s a long apartment and very '
#                            'spacious and looks exactly like the pictures. Also '
#                            'a few corner stores in the area so that helped as '
#                            'far as the location. The hosts were nice and easy '
#                            'to contact as well.',
#                'datetime': Timestamp('2018-04-22 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '262647967',
#                'date': datetime.date(2018, 5, 9),
#                'reviewer_id': '180335063',
#                'reviewer_name': 'Thomas',
#                'comments': 'Fantastic hosts! Quick to respond to emails and '
#                            'incredible helpful. Lovely, clean apartment. All '
#                            'you could want for a trip to New York!',
#                'datetime': Timestamp('2018-05-09 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '96563986',
#                'date': datetime.date(2016, 8, 23),
#                'reviewer_id': '82939853',
#                'reviewer_name': 'Sherri',
#                'comments': 'Taran made us feel very welcoming, showing us '
#                            'around and very accommodating The place was very '
#                            'clean, spacious and modern and exactly the way it '
#                            'was in the picture. Also it was just a few steps '
#                            'away from the grocery store  I will definitely '
#                            'stay here again and recommend to others. Thank you '
#                            'for  having us and we had a wonderful stay.',
#                'datetime': Timestamp('2016-08-23 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '97945295',
#                'date': datetime.date(2016, 8, 29),
#                'reviewer_id': '62520189',
#                'reviewer_name': 'Shalini',
#                'comments': 'Great communication with host. They were there to '
#                            'greet us and checked in each day to ensure that '
#                            'everything was ok. The place looked exactly like '
#                            'the pictures, super clean and conveniently '
#                            'located. ',
#                'datetime': Timestamp('2016-08-29 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '101118658',
#                'date': datetime.date(2016, 9, 12),
#                'reviewer_id': '69471881',
#                'reviewer_name': 'Kwangpyo',
#                'comments': '늦은 시간임에도 저희를 숙소에서 친절히 기둘려주고 계셨습니다.\r'
#                            '<br/>매번 보내는 메세지에 신속히 답해주시고, 친절하셨습니다.',
#                'datetime': Timestamp('2016-09-12 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '101845704',
#                'date': datetime.date(2016, 9, 15),
#                'reviewer_id': '73685938',
#                'reviewer_name': 'Andrea',
#                'comments': "These two are amazing hosts. The best Airbnb I've "
#                            'EVER stayed. They were very hospitable, they left '
#                            'a book of things we could use such as food menus, '
#                            'wifi, things we needed to know...the place was '
#                            'gorgeous!!! The paint on the walls was clean and '
#                            'beautiful, the floors were gorgeous, all the '
#                            'furniture, they left us with all of the essentials '
#                            'we could need. It was altogether a great '
#                            'stay....going back in a couple of days :)',
#                'datetime': Timestamp('2016-09-15 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '107672085',
#                'date': datetime.date(2016, 10, 11),
#                'reviewer_id': '24277309',
#                'reviewer_name': 'Walter',
#                'comments': 'Taran and Najla were excellent hosts!  They were '
#                            'attentive during our stay and checked in on us '
#                            'throughout our stay to make sure we were '
#                            'comfortable and had everything we needed.   The '
#                            'apartment was clean and in working order.  I '
#                            'really enjoyed my stay in NYC because of the '
#                            'hosts!   5 stars across the board',
#                'datetime': Timestamp('2016-10-11 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '355761242',
#                'date': datetime.date(2018, 12, 5),
#                'reviewer_id': '165528625',
#                'reviewer_name': 'Yang',
#                'comments': 'This place is very clean and neat. Location is a '
#                            'bit hard to find. But overall is good.',
#                'datetime': Timestamp('2018-12-05 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '176742193',
#                'date': datetime.date(2017, 7, 31),
#                'reviewer_id': '130736117',
#                'reviewer_name': 'Dawn',
#                'comments': 'The apartment was immaculate and designed '
#                            "perfectly for it's purpose. We were there for the "
#                            'weekend to attend a concert at Citifield, only 15 '
#                            'minutes away so the location was great. Our hosts '
#                            'were always available to answer any questions.  '
#                            'The price worked out to be similar to a hotel room '
#                            'but with 3 people, it was so much more '
#                            'comfortable.',
#                'datetime': Timestamp('2017-07-31 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '242879763',
#                'date': datetime.date(2018, 3, 13),
#                'reviewer_id': '171643579',
#                'reviewer_name': 'Dorie',
#                'comments': 'Wonderful, great and large space during my '
#                            'work/pleasure trip back home to NY. Extremely '
#                            'clean and stylish with attention to detail.  '
#                            'Supermarket was right around the corner, which was '
#                            'great for groceries and quick NY style on-the-go '
#                            'breakfast.  Thank you Taran & Najla!  I love your '
#                            'decorating style!',
#                'datetime': Timestamp('2018-03-13 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '243588785',
#                'date': datetime.date(2018, 3, 16),
#                'reviewer_id': '147337402',
#                'reviewer_name': 'Wenjun',
#                'comments': 'The room is beautiful and clean, but the location '
#                            'is a little noisy.',
#                'datetime': Timestamp('2018-03-16 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '143180832',
#                'date': datetime.date(2017, 4, 10),
#                'reviewer_id': '57996328',
#                'reviewer_name': 'Tyler',
#                'comments': 'This was a great experience for my first time '
#                            'using AirBnB!  The hosts communication was '
#                            'awesome...its about $15 Uber ride from JFK...and '
#                            'about an $8 Uber to Jamaica train station...the '
#                            'host greeted us with a nice friendly smile and '
#                            'showed us around the adorable modern clean '
#                            "apartment...it's actually bigger in person...she "
#                            'informed us of all the rules staying there and '
#                            'also refilled the keurig cups a couple times '
#                            'during our stay...we had no problems with the area '
#                            'but the streets nearby could get pretty busy...we '
#                            'missed the part in the reservations about having '
#                            'gas available for the use of the stoves for less '
#                            'than 6 days and were a little '
#                            'disappointed...reason why we were getting an '
#                            'airbnb but, the microwave and leftovers saved '
#                            'us...the TV is great with the Roku...this was an '
#                            'all in all AMAZING EXPERIENCE AND BEAUTIFUL '
#                            'APARTMENT!!!! I definitely recommend this and '
#                            'would stay here again :)',
#                'datetime': Timestamp('2017-04-10 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '154044335',
#                'date': datetime.date(2017, 5, 22),
#                'reviewer_id': '124312660',
#                'reviewer_name': 'Corinne',
#                'comments': 'The place was VERY clean and modern!  It is just '
#                            'as it is pictured!  Taran and Najla were very '
#                            'attentive and accommodating.   WE enjoyed our '
#                            'stay.  The neighborhood was noisy, but that is to '
#                            'be expected in New York. It would be a good idea t '
#                            'bring a white noise machine with you if city noise '
#                            'bothers you when you are sleeping.',
#                'datetime': Timestamp('2017-05-22 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '155196592',
#                'date': datetime.date(2017, 5, 27),
#                'reviewer_id': '124116587',
#                'reviewer_name': 'Brandon',
#                'comments': 'It is a nice house. Great stay over there. '
#                            'Spacious apartment with clean bathroom. ',
#                'datetime': Timestamp('2017-05-27 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '156176009',
#                'date': datetime.date(2017, 5, 29),
#                'reviewer_id': '79007803',
#                'reviewer_name': 'Delphine',
#                'comments': 'This is the second time I stayed here in the last '
#                            'year and it was as pleasurable as the first time. '
#                            "Taran and Najla's place is exquisite. This is my "
#                            "go to place to stay whenever I'm in NYC. I "
#                            'recommend their place 100% to anyone looking for '
#                            'an extremely clean, well decorated place to stay. '
#                            'What you see is what you get. Great space, awesome '
#                            'price.',
#                'datetime': Timestamp('2017-05-29 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '157804667',
#                'date': datetime.date(2017, 6, 4),
#                'reviewer_id': '125092381',
#                'reviewer_name': 'Juan Camilo',
#                'comments': 'Taran & Najla fueron unos perfectos anfitriones, '
#                            'estuvieron pendiente de nosotros todos los días, '
#                            'nos explicaron como tomar el transporte, incluso '
#                            'estaban de viaje y se tomaron la molestia de '
#                            'llamarnos. El apartamento en perfectas '
#                            'condiciones, hermoso, muy bien cuidado y se puede '
#                            'llegar desde la estación de forma fácil. Son '
#                            'excelentes anfitriones y el lugar es perfecto para '
#                            'viajar, ',
#                'datetime': Timestamp('2017-06-04 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '173650048',
#                'date': datetime.date(2017, 7, 23),
#                'reviewer_id': '111131420',
#                'reviewer_name': 'Terrenique',
#                'comments': "Najla and Taran's home left my family and I "
#                            'talking for weeks! Comfortable and relaxing, it '
#                            'was the sweet escape! Many days instead of '
#                            'exploring New York we slept in and enjoyed each '
#                            "other's company. <br/>I loved how close the home "
#                            'was to the grocery store and bus stop! 5 stars '
#                            'thanks for everything guys!',
#                'datetime': Timestamp('2017-07-23 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '189714865',
#                'date': datetime.date(2017, 9, 2),
#                'reviewer_id': '60413154',
#                'reviewer_name': 'Alexis',
#                'comments': 'We stayed here for a family trip - 6 adults and a '
#                            'baby. The pictures are extremely accurate to what '
#                            'the house looks like, and our communication with '
#                            'the hosts was consistent as they quickly addressed '
#                            'any issues we had. We had some wifi issues, so if '
#                            'you need consistent and quality wifi, I would not '
#                            'count on that at the house. But the biggest '
#                            'problems we ran into were the location and noise. '
#                            'We often felt uncomfortable in the neighborhood, '
#                            'especially in the evenings. And ran into extreme '
#                            'noise issues throughout the night -- the bus being '
#                            'right outside the bedroom window, loud music from '
#                            'the front yards of the neighbors, people and cars '
#                            'blaring music or yelling on the street -- it made '
#                            'sleeping difficult, for both the adults and the '
#                            'baby. If you want a beautiful and clean home, and '
#                            'good hosts, then I definitely recommend this '
#                            'location. But the location and noise was a huge '
#                            'factor for our trip.',
#                'datetime': Timestamp('2017-09-02 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '193717261',
#                'date': datetime.date(2017, 9, 14),
#                'reviewer_id': '79609654',
#                'reviewer_name': '艳琼',
#                'comments': 'Nice place, located in Jamaica, close to JFK but '
#                            'the traffic seems terrible. The department is '
#                            "comfortable, peaceful and clean. It's suitable for "
#                            'a short stay with your friends or family. Thanks '
#                            'for the host again.',
#                'datetime': Timestamp('2017-09-14 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '201983377',
#                'date': datetime.date(2017, 10, 9),
#                'reviewer_id': '135351260',
#                'reviewer_name': 'Zachery',
#                'comments': 'What more could you want. Very stylish and clean '
#                            'apartment. Lovely hosts. Very close to the airport '
#                            'and with 2 shops right round the corner you '
#                            'couldn’t go wrong. This apartment is exactly how '
#                            'every apartment should be clean and welcoming. '
#                            'Would definitely stay again. Thanks',
#                'datetime': Timestamp('2017-10-09 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '207604638',
#                'date': datetime.date(2017, 10, 29),
#                'reviewer_id': '137116272',
#                'reviewer_name': 'Vianey',
#                'comments': 'La casa se ubica cerca del transporte (bus) y la '
#                            'casa en general es muy linda, amplia, limpia y '
#                            'confortable. Las dudas fueron resueltas con '
#                            'rapidez por parte de los anfitriones. Yo si '
#                            'recomendaría que te quieras en casa de Taran & '
#                            'Najla. :)',
#                'datetime': Timestamp('2017-10-29 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '214748495',
#                'date': datetime.date(2017, 11, 26),
#                'reviewer_id': '31613951',
#                'reviewer_name': 'Yuzhun',
#                'comments': 'Very clean and the host response really fast. Free '
#                            'parking is nice. Everything is just perfect. '
#                            'However, if you are a light sleeper you might be '
#                            'bothered with the outside noice at night.',
#                'datetime': Timestamp('2017-11-26 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '234055441',
#                'date': datetime.date(2018, 2, 11),
#                'reviewer_id': '158805146',
#                'reviewer_name': 'Kaori',
#                'comments': 'Taran & '
#                            'Najlaさんは、とても良いホストです。<br/>チェックイン前までの期間や滞在中でも、何か不明な点があれば迅速に対応してくださいました。<br/>Taran '
#                            '& '
#                            'Najlaさん宅に関しては、かなり満足しています。<br/>清潔で、内装も写真で見たそのままであり、<br/>水や電気・ガスの面でも不自由なことはありませんでした。<br/>ただ、周辺地域の騒音が少し気になりました。<br/>夜中でも車の音や人の話し声がはっきり聞こえるので、<br/>普段静かな地域で暮らしている方には向かないかもしれません。<br/>Taran '
#                            '& '
#                            'Najlaさんのおかげで、良い時間を過ごすことができました。<br/>本当にありがとうございました。',
#                'datetime': Timestamp('2018-02-11 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '240318491',
#                'date': datetime.date(2018, 3, 4),
#                'reviewer_id': '14338795',
#                'reviewer_name': 'Priya',
#                'comments': 'This place is exactly how it appears in the '
#                            'pictures. It is extremely clean. It was a perfect '
#                            'fit for our girls trip, five women stayed '
#                            'comfortably. The layout and design are beautiful '
#                            'and extremely modern. There are a lot of shops and '
#                            'restaurants in the area. I would definitely stay '
#                            'again.',
#                'datetime': Timestamp('2018-03-04 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '250879703',
#                'date': datetime.date(2018, 4, 6),
#                'reviewer_id': '52855536',
#                'reviewer_name': 'Casey-Heather',
#                'comments': "We stayed at Taran and Najla's home for a week and "
#                            'had a great experience.  The apartment was very '
#                            'clean and perfect amount of space for our family '
#                            'of 6.  Parking was not an issue at all for this '
#                            'New York apartment.  We really enjoyed our stay '
#                            'and would stay again.  Thank you!',
#                'datetime': Timestamp('2018-04-06 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '289155789',
#                'date': datetime.date(2018, 7, 11),
#                'reviewer_id': '160169118',
#                'reviewer_name': 'Ben',
#                'comments': "I did not enjoy staying at the Taran & Najla's "
#                            'Place. They charged me for cleaning and then I '
#                            'found out that there was a  "House Rule '
#                            'Memorandum" and I had to clean counters, floors , '
#                            ', fridge, dispose the garbage, ... Their add was '
#                            'not accurate. The add said there was a parking on '
#                            'premises and there was not. When I asked for my '
#                            'parking spot, they said when it is available. ',
#                'datetime': Timestamp('2018-07-11 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '272428199',
#                'date': datetime.date(2018, 6, 3),
#                'reviewer_id': '162962582',
#                'reviewer_name': 'Julie',
#                'comments': 'The apartment is GORGEOUS, clean, and spacious.  '
#                            'We stayed here with another couple for the weekend '
#                            'while enjoying the city.  Taran & Najilas '
#                            'beautifully decorated apartment felt like home '
#                            'after a long day touring Manhattan. The beds are '
#                            'comfortable, AC worked so well,  plenty of hot '
#                            'water and the wifi was strong. I slept like a baby '
#                            'and we all raved how nice the apartment was.  They '
#                            'thought of everything you could possibly need and '
#                            'checking in and out was a breeze.  I will '
#                            'definitely stay here again. Thank you again Taran '
#                            '& Najila!!',
#                'datetime': Timestamp('2018-06-03 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '276697993',
#                'date': datetime.date(2018, 6, 14),
#                'reviewer_id': '178877613',
#                'reviewer_name': 'Maria',
#                'comments': 'Es un lugar impecable, sus dueños han cuidado cada '
#                            'detalle para volverlo acogedor y confortable a sus '
#                            'visitantes. Mi familia y yo pasamos unas '
#                            'vacaciones maravillosas conociendo por primera vez '
#                            'a NY y volvería a utilizarlo si tuviera la '
#                            'oportunidad. Lo recomiendo al 100%. <br/>Muchas '
#                            'gracias Taran & Najla.',
#                'datetime': Timestamp('2018-06-14 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '294766207',
#                'date': datetime.date(2018, 7, 22),
#                'reviewer_id': '192608803',
#                'reviewer_name': 'Marianne',
#                'comments': 'Pros: beautiful, modern, spacious, and very clean '
#                            'home! Very close to Van Wyck expressway and steps '
#                            'from bus stop, less than 1 mile to metro station. '
#                            'Cons: noisy neighborhood, on-street parking space '
#                            'can be difficult to find and may have to park a '
#                            'block away. Be aware that oven/stove NOT available '
#                            'for stay <6days, no toaster/toaster oven. ',
#                'datetime': Timestamp('2018-07-22 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '303074122',
#                'date': datetime.date(2018, 8, 6),
#                'reviewer_id': '60281231',
#                'reviewer_name': 'Tara-Marie',
#                'comments': 'The home is just as beautiful in real life as it '
#                            'was in the pictures',
#                'datetime': Timestamp('2018-08-06 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '313011452',
#                'date': datetime.date(2018, 8, 24),
#                'reviewer_id': '141674827',
#                'reviewer_name': 'Jean Robert',
#                'comments': 'This house is amazing, very clean, very '
#                            'comfortable and accessible. I would definitely '
#                            'recommend this house to friends who would like to '
#                            'spend some times in in New York  specificly in '
#                            'Jamaica Queens. It is  very important to '
#                            "experience it to understand what I'm talking about "
#                            '. The area is noisy  , but clean and you have '
#                            'access to a supermarket about 1 minute working . '
#                            'It was really a very good experience for my family '
#                            'to leave in this house for 16 days. ',
#                'datetime': Timestamp('2018-08-24 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '318353040',
#                'date': datetime.date(2018, 9, 3),
#                'reviewer_id': '209807619',
#                'reviewer_name': 'Trisha',
#                'comments': 'Great spot with Deli close by. apartment was clean '
#                            'and tidy. Hosts clearly communicated so there were '
#                            'no misunderstandings. Easy to find street '
#                            'parking.  Overall a great place to stay.',
#                'datetime': Timestamp('2018-09-03 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '321582808',
#                'date': datetime.date(2018, 9, 10),
#                'reviewer_id': '34974334',
#                'reviewer_name': 'Azam',
#                'comments': 'Super clean and elegantly decorated space, super '
#                            'comfy beds and tons of space for NYC. Every thing '
#                            'you need for a few days (or longer). Appropriately '
#                            'stocked Kitchen Great iron free parking and nice '
#                            'towels.',
#                'datetime': Timestamp('2018-09-10 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '324197519',
#                'date': datetime.date(2018, 9, 16),
#                'reviewer_id': '66043516',
#                'reviewer_name': 'Krista',
#                'comments': 'The space was exactly what the pictures displayed. '
#                            'It was clean, nicely decorated, and comfortable. '
#                            'Communication was great. The check in and check '
#                            'out process was easy. Thanks again for '
#                            'everything!!',
#                'datetime': Timestamp('2018-09-16 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '327301425',
#                'date': datetime.date(2018, 9, 23),
#                'reviewer_id': '70343555',
#                'reviewer_name': 'Jacqueline',
#                'comments': 'T&N’s Home Looks just like the pictures. Very '
#                            'Clean, Stylish, Modern. There is only street '
#                            'parking available but we never struggled to find '
#                            'an open space. A tiny continent store on the '
#                            'corner if you wish to purchase juice milk snacks a '
#                            'toothbrush. It’s hard to find nice homes in Queens '
#                            'Extremely glad we found this place.',
#                'datetime': Timestamp('2018-09-23 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '328266835',
#                'date': datetime.date(2018, 9, 25),
#                'reviewer_id': '210000605',
#                'reviewer_name': 'Edmond',
#                'comments': 'Great place to stay.  Host are very responsive.',
#                'datetime': Timestamp('2018-09-25 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '330394202',
#                'date': datetime.date(2018, 9, 30),
#                'reviewer_id': '113239665',
#                'reviewer_name': 'Carmen',
#                'comments': "Taran & Najla's place is very nice, just as "
#                            'pictured.  It was difficult to find at first but '
#                            'once you get there you will have no problem.  The '
#                            'neighborhood is not best nor is it the quietest.  '
#                            'There is always something going on.  However, once '
#                            'inside the home you get a feel for a different '
#                            'environment.  Keep in mind, if you stay less than '
#                            '6 days, the stove is off limits.  This was '
#                            'understood before I booked but was one of the '
#                            'things we actually wanted.  The bodega around the '
#                            'corner does sell freshly made breakfast sandwiches '
#                            'which were very inexpensive and worth the money.',
#                'datetime': Timestamp('2018-09-30 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '333678367',
#                'date': datetime.date(2018, 10, 7),
#                'reviewer_id': '87390053',
#                'reviewer_name': 'Yimika',
#                'comments': 'I loved over stay here. Beautiful home, amazing '
#                            'hosts that made our stay enjoyable',
#                'datetime': Timestamp('2018-10-07 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '340034886',
#                'date': datetime.date(2018, 10, 22),
#                'reviewer_id': '56471174',
#                'reviewer_name': 'Nandi',
#                'comments': 'Taran & Najla’s place was clean and a great size '
#                            'for our party. The check-in process went smoothly '
#                            'and we didn’t have any issues with the accuracy of '
#                            'the listing. The beds were comfortable and we were '
#                            'able to use the full facilities of the house. '
#                            'Please note that this place can get a bit noisy on '
#                            'weekends because of a bus stop right outside the '
#                            'property and upstairs neighbors. Otherwise we '
#                            'enjoyed our stay and T&N’s hospitality.',
#                'datetime': Timestamp('2018-10-22 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '343424298',
#                'date': datetime.date(2018, 10, 31),
#                'reviewer_id': '110444189',
#                'reviewer_name': 'Roger',
#                'comments': 'En Tran i la Najla tenen un bonic espai a la vora '
#                            "de l'aeroport, allà a Jamaica, al costat de Long "
#                            'Island, per on vam poder fer un passeig abans de '
#                            "tornar per agafar l'últim viatgevde tornada a "
#                            'casa.',
#                'datetime': Timestamp('2018-10-31 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '347622318',
#                'date': datetime.date(2018, 11, 11),
#                'reviewer_id': '1135316',
#                'reviewer_name': 'Maritza',
#                'comments': 'Exactly the same as on pictures',
#                'datetime': Timestamp('2018-11-11 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '354985337',
#                'date': datetime.date(2018, 12, 2),
#                'reviewer_id': '82224432',
#                'reviewer_name': 'Roberto',
#                'comments': 'This place was immaculately clean and pristine '
#                            'when I stayed there. Beautiful, spacious, and '
#                            'modern interior (hard to come by in NYC)! The '
#                            "neighborhood wasn't the nicest of places, there "
#                            'are lots of rules set by the hosts, and you cannot '
#                            'change the thermostat temperature because it is '
#                            'locked with a code. Everything considered, I would '
#                            'highly recommend staying here.',
#                'datetime': Timestamp('2018-12-02 12:00:00')},
#               {'listing_id': '10073940',
#                'review_id': '356533999',
#                'date': datetime.date(2018, 12, 8),
#                'reviewer_id': '31277708',
# ...
#                            'recomendacion seria iluminacion en el cuarto, ya '
#                            'que es muy oscuro con solo una lampara pequeña y '
#                            'tambien quiza colocar un espejo. El lugar queda '
#                            'accesible y cercano a la estación de tren. Asi que '
#                            'podrias llegar facil a cualquier lado caminando '
#                            'hasta la estación. La comunicación con el '
#                            'anfitrión siempre fue buena, respondía bastante '
#                            'rápido.',
#                'datetime': Timestamp('2023-12-04 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1041366195541619663',
#                'date': datetime.date(2023, 12, 7),
#                'reviewer_id': '145012192',
#                'reviewer_name': 'Genesis',
#                'comments': 'By far one of cleanest (and prettiest) places I’ve '
#                            'stayed in. Would definitely recommend 10/10',
#                'datetime': Timestamp('2023-12-07 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1044950072340489633',
#                'date': datetime.date(2023, 12, 12),
#                'reviewer_id': '548319117',
#                'reviewer_name': 'Daniel',
#                'comments': "Sabrina's 5th floor condo's was impeccably clean, "
#                            'ambience great, and the incense at her door & she '
#                            'has going on in her unit & on the 1st floor was '
#                            'lovely smelling. She herself was easy to talk to '
#                            'and was responsive!',
#                'datetime': Timestamp('2023-12-12 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1052196051483174440',
#                'date': datetime.date(2023, 12, 22),
#                'reviewer_id': '48534450',
#                'reviewer_name': 'Sophie',
#                'comments': 'Lovely place and lovely guest. One of the cheapest '
#                            'places and nicest places you can find in NYC.',
#                'datetime': Timestamp('2023-12-22 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1060250375094849701',
#                'date': datetime.date(2024, 1, 2),
#                'reviewer_id': '408193273',
#                'reviewer_name': 'Anna',
#                'comments': 'Le logement était très propre et rangé à notre '
#                            'arrivée et le lit est très confortable. Après '
#                            'avoir eu quelques difficultés pour accéder à '
#                            'l’appartement la première fois, Sabrina m’a '
#                            'répondue en quelques minutes et a réglé le '
#                            'problème. <br/>Excellent accès à la ville via le '
#                            'métro à quelques mètres de l’appartement. <br/>Il '
#                            'faut juste savoir que l’appartement se situe au 4e '
#                            'étage sans ascenseur. <br/>Je recommande ! Merci '
#                            'pour ce séjour:)',
#                'datetime': Timestamp('2024-01-02 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1062357081193717466',
#                'date': datetime.date(2024, 1, 5),
#                'reviewer_id': '4534422',
#                'reviewer_name': 'Katya',
#                'comments': "J'ai adoré mon séjour chez Sabrina!<br/>Super "
#                            'gentille, réactive aux messages et répond '
#                            "rapidement. L'appartement est propre, voire "
#                            'immaculé et sent bon. <br/>Le lit est hyper '
#                            'confortable et que dire des oreillers, de vrais '
#                            'nuages. Mon conjoint et moi avons dormi comme à la '
#                            'maison!<br/>Le quartier regorge de petits '
#                            'restaurants délicieux et de pub intéressants! De '
#                            'plus le métro est à 3 minutes de marche.  Nous '
#                            'sommes venus en voiture et nous stationnez a été '
#                            "très facile!<br/>Oui c'est su 5e étage sans "
#                            'ascenseur, mais un peu de sport ne fait jamais mal '
#                            "à personne! On s'y habitue rapidement! 😁<br/>Je "
#                            'recommande fortement et y retournerai avec '
#                            'plaisir!',
#                'datetime': Timestamp('2024-01-05 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1064530776413691152',
#                'date': datetime.date(2024, 1, 8),
#                'reviewer_id': '191552072',
#                'reviewer_name': 'Takiyah',
#                'comments': 'Sabrina’s place was the perfect stay. Love the '
#                            'structure of the apartment itself. The bedroom is '
#                            'cozy, and the bathroom is right next to the '
#                            'bedroom. She does live there, but stays out the '
#                            'way and is super responsive & helpful. Will be '
#                            'booking again soon, thank you Sabrina!',
#                'datetime': Timestamp('2024-01-08 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1065341705039533790',
#                'date': datetime.date(2024, 1, 9),
#                'reviewer_id': '471032047',
#                'reviewer_name': 'Desjan',
#                'comments': 'Good hospitality, very clean and organized and the '
#                            'price was very affordable',
#                'datetime': Timestamp('2024-01-09 12:00:00')},
#               {'listing_id': '1003437049851150279',
#                'review_id': '1081991191034217817',
#                'date': datetime.date(2024, 2, 1),
#                'reviewer_id': '469257926',
#                'reviewer_name': 'Eudis',
#                'comments': 'Excelente experiencia. Barrio tranquilo y el '
#                            'alojamiento es tal cual como el anuncio. Fácil '
#                            'acceso al metro, a menos de 5 minutos caminando. '
#                            'En 20 minutos estás en Times Square. Aunque '
#                            'hablamos poco, Sabrina fue muy amable. Siempre '
#                            'estaba todo limpio y ordenado. Repetiría sin duda.',
#                'datetime': Timestamp('2024-02-01 12:00:00')}]},
#  {'id': '1003861097745796435',
#   'name': 'Rental unit in New York · 2 bedrooms · 3 beds · 2 baths',
#   'host_id': '374444658',
#   'host_name': 'Ann',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.761177,
#   'longitude': -73.99033,
#   'room_type': 'Entire home/apt',
#   'price': 264.0,
#   'minimum_nights': 2,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 19),
#   'reviews_per_month': 0.56,
#   'calculated_host_listings_count': 1,
#   'availability_365': 338,
#   'number_of_reviews_ltm': 1,
#   'license': 'Exempt',
#   'reviews': [{'listing_id': '1003861097745796435',
#                'review_id': '1050058897964809187',
#                'date': datetime.date(2023, 12, 19),
#                'reviewer_id': '229936730',
#                'reviewer_name': 'Danny',
#                'comments': 'Place is in perfect location,  host was great to '
#                            'deal with.',
#                'datetime': Timestamp('2023-12-19 12:00:00')}]},
#  {'id': '1008695241970793764',
#   'name': 'Rental unit in New York · ★5.0 · 4 bedrooms · 5 beds · 1 bath',
#   'host_id': '538722287',
#   'host_name': 'Isabel',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': 'Upper West Side',
#   'latitude': 40.799732,
#   'longitude': -73.96043,
#   'room_type': 'Entire home/apt',
#   'price': 326.0,
#   'minimum_nights': 6,
#   'number_of_reviews': 5,
#   'last_review': datetime.date(2024, 1, 23),
#   'reviews_per_month': 1.65,
#   'calculated_host_listings_count': 1,
#   'availability_365': 32,
#   'number_of_reviews_ltm': 5,
#   'license': 'Exempt',
#   'reviews': [{'listing_id': '1008695241970793764',
#                'review_id': '1020397644897989877',
#                'date': datetime.date(2023, 11, 8),
#                'reviewer_id': '429176257',
#                'reviewer_name': 'James',
#                'comments': 'Easy and Great experience! <br/>Great place '
#                            'between downtown and way uptown. Has everything '
#                            'you need, close to many stores for house '
#                            'necessities and 2 mins walk to the nearest Metro '
#                            'entrance (that can  put you on a Metro straight to '
#                            'Midtown around Timesquare or further '
#                            'Downtown).<br/>The host Isabel is very responsive! '
#                            'Our late check-in was accomodated with zero issues '
#                            'due to the active communication. <br/>The place '
#                            'itself has four rooms with airconditioning '
#                            '/heating. The kitchen area was  adequate for us to '
#                            'cook regular meals. <br/>Our group was 5 friends '
#                            'gathering for a reunion, worked perfectly for us. '
#                            'We definitely would go back!',
#                'datetime': Timestamp('2023-11-08 12:00:00')},
#               {'listing_id': '1008695241970793764',
#                'review_id': '1045708614143773703',
#                'date': datetime.date(2023, 12, 13),
#                'reviewer_id': '61827512',
#                'reviewer_name': 'Thai',
#                'comments': 'The location is at the north end of Central Park, '
#                            "there's a subway statition just a couple minutes "
#                            'walk around the corner. Central Park entrance is '
#                            'just across the street. Subway to Times Square is '
#                            'about 20 mins. There are restaurants, grocery '
#                            'store within 10 mins walking. The apartment is '
#                            'clean and secured, very roomy for a group of 4-5. '
#                            'We enjoyed out stay there and would love to stay '
#                            "there again if we're in the area.",
#                'datetime': Timestamp('2023-12-13 12:00:00')},
#               {'listing_id': '1008695241970793764',
#                'review_id': '1059487745137101403',
#                'date': datetime.date(2024, 1, 1),
#                'reviewer_id': '396498619',
#                'reviewer_name': 'Ernesto',
#                'comments': 'Great place to spend the vacations in New York. '
#                            'One thing that I liked the most about this Airbnb '
#                            'was that it is close to the subway station '
#                            'therefore I could go easily to all my '
#                            'destinations. I highly recommend this place',
#                'datetime': Timestamp('2024-01-01 12:00:00')},
#               {'listing_id': '1008695241970793764',
#                'review_id': '1065997358755480069',
#                'date': datetime.date(2024, 1, 10),
#                'reviewer_id': '547790401',
#                'reviewer_name': 'Patrick',
#                'comments': 'Isabel was a great host! We were provided '
#                            'incredibly detailed instructions for check-in and '
#                            'they were responsive. The apartment was wonderful '
#                            'and the rooms were spacious. We have nothing to '
#                            'complain about! With a station just around the '
#                            'corner it was easy to get anywhere we wanted and '
#                            'there were plenty of shops in walking distance as '
#                            'well. This was my first time using airbnb and I '
#                            'would highly recommend Isabel for anyone looking '
#                            'to spend time in Manhattan!',
#                'datetime': Timestamp('2024-01-10 12:00:00')},
#               {'listing_id': '1008695241970793764',
#                'review_id': '1075427697716681620',
#                'date': datetime.date(2024, 1, 23),
#                'reviewer_id': '127288434',
#                'reviewer_name': 'Cristian',
#                'comments': 'Everything was great, I definitely recommend this '
#                            'place.',
#                'datetime': Timestamp('2024-01-23 12:00:00')}]},
#  {'id': '1003623057347580030',
#   'name': 'Rental unit in New York · 4 bedrooms · 4 beds · 3.5 baths',
#   'host_id': '17775359',
#   'host_name': 'Rove',
#   'neighbourhood_group': 'Manhattan',
#   'neighbourhood': "Hell's Kitchen",
#   'latitude': 40.7606,
#   'longitude': -73.99497,
#   'room_type': 'Entire home/apt',
#   'price': 324.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 11, 30),
#   'reviews_per_month': 0.43,
#   'calculated_host_listings_count': 57,
#   'availability_365': 365,
#   'number_of_reviews_ltm': 1,
#   'license': '',
#   'reviews': [{'listing_id': '1003623057347580030',
#                'review_id': '1036248146397605612',
#                'date': datetime.date(2023, 11, 30),
#                'reviewer_id': '355547',
#                'reviewer_name': 'Silva',
#                'comments': 'Beautiful, clean and well appointed space! would '
#                            'book again in a heartbeat. everything was super '
#                            'clean, responsive host and a great location.',
#                'datetime': Timestamp('2023-11-30 12:00:00')}]},
#  {'id': '1007421778971968598',
#   'name': 'Rental unit in Queens · 3 bedrooms · 2 baths',
#   'host_id': '183377855',
#   'host_name': 'William',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Flushing',
#   'latitude': 40.762016,
#   'longitude': -73.802246,
#   'room_type': 'Entire home/apt',
#   'price': 170.0,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2023, 12, 20),
#   'reviews_per_month': 0.61,
#   'calculated_host_listings_count': 1,
#   'availability_365': 270,
#   'number_of_reviews_ltm': 1,
#   'license': '',
#   'reviews': [{'listing_id': '1007421778971968598',
#                'review_id': '1050789820497847472',
#                'date': datetime.date(2023, 12, 20),
#                'reviewer_id': '482869548',
#                'reviewer_name': 'Cc',
#                'comments': 'The best ever',
#                'datetime': Timestamp('2023-12-20 12:00:00')}]},
#  {'id': '10057854',
#   'name': 'Rental unit in Queens · 1 bedroom · 1 bed · 1 bath',
#   'host_id': '51614806',
#   'host_name': 'Justyna',
#   'neighbourhood_group': 'Queens',
#   'neighbourhood': 'Long Island City',
#   'latitude': 40.74829,
#   'longitude': -73.94083,
#   'room_type': 'Private room',
#   'price': nan,
#   'minimum_nights': 30,
#   'number_of_reviews': 1,
#   'last_review': datetime.date(2016, 1, 16),
#   'reviews_per_month': 0.01,
#   'calculated_host_listings_count': 1,
#   'availability_365': 0,
#   'number_of_reviews_ltm': 0,
#   'license': '',
#   'reviews': [{'listing_id': '10057854',
#                'review_id': '59839524',
#                'date': datetime.date(2016, 1, 16),
#                'reviewer_id': '51675676',
#                'reviewer_name': 'Shiori',
#                'comments': 'I stayed at their place for about a month. Hosts '
#                            "were really nice that they often asked me how I'm "
#                            'doing. The apartment was very beautiful that I '
#                            'felt I want to live. It was only 3min walk to '
#                            'Queensboro plaza station which is just a station '
#                            'away from Manhattan by N/Q train. ',
#                'datetime': Timestamp('2016-01-16 12:00:00')}]}]

# %% [markdown]
# <span style=color:blue> Doing a bulk insert    </span>

# %%
foo = datetime.date(2023, 6, 10)
print(foo)
goo = foo.replace(microsecond=0)
print(goo)
# Out:
# 2023-06-10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 foo = datetime.date(2023, 6, 10)
#       2 print(foo)
# ----> 3 goo = foo.replace(microsecond=0)
#       4 print(goo)
#
# TypeError: 'microsecond' is an invalid keyword argument for replace()

# %%
result = listings.insert_many(dict_ljr100_left)
print(result.inserted_ids)
# Out:
# ---------------------------------------------------------------------------
# InvalidDocument                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 result = listings.insert_many(dict_ljr100_left)
#       2 print(result.inserted_ids)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/collection.py:742, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741 blk.ops = list(gen())
# --> 742 blk.execute(write_concern, session, _Op.INSERT)
#     743 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/bulk.py:595, in _Bulk.execute(self, write_concern, session, operation)
#     593         return None
#     594 else:
# --> 595     return self.execute_command(generator, write_concern, session, operation)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/bulk.py:452, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     441     self._execute_command(
#     442         generator,
#     443         write_concern,
#    (...)
#     448         full_result,
#     449     )
#     451 client = self.collection.database.client
# --> 452 client._retryable_write(
#     453     self.is_retryable,
#     454     retryable_bulk,
#     455     session,
#     456     operation,
#     457     bulk=self,
#     458     operation_id=op_id,
#     459 )
#     461 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     462     _raise_bulk_write_error(full_result)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1569, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1555 """Execute an operation with consecutive retries if possible
#    1556
#    1557 Returns func()'s return value on success. On error retries the same
#    (...)
#    1566 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1567 """
#    1568 with self._tmp_session(session) as s:
# -> 1569     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1455, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1450 # Ensure that the options supports retry_writes and there is a valid session not in
#    1451 # transaction, otherwise, we will not support retry behavior for this txn.
#    1452 retryable = bool(
#    1453     retryable and self.options.retry_writes and session and not session.in_transaction
#    1454 )
# -> 1455 return self._retry_internal(
#    1456     func=func,
#    1457     session=session,
#    1458     bulk=bulk,
#    1459     operation=operation,
#    1460     retryable=retryable,
#    1461     operation_id=operation_id,
#    1462 )
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/mongo_client.py:2464, in _ClientConnectionRetryable._write(self)
#    2462             self._check_last_error()
#    2463             self._retryable = False
# -> 2464         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2465 except PyMongoError as exc:
#    2466     if not self._retryable:
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/bulk.py:441, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     438 def retryable_bulk(
#     439     session: Optional[ClientSession], conn: Connection, retryable: bool
#     440 ) -> None:
# --> 441     self._execute_command(
#     442         generator,
#     443         write_concern,
#     444         session,
#     445         conn,
#     446         op_id,
#     447         retryable,
#     448         full_result,
#     449     )
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/bulk.py:386, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     384 # Run as many ops as possible in one command.
#     385 if write_concern.acknowledged:
# --> 386     result, to_send = bwc.execute(cmd, ops, client)
#     388     # Retryable writeConcernErrors halt the execution of this run.
#     389     wce = result.get("writeConcernError", {})
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/message.py:959, in _BulkWriteContext.execute(self, cmd, docs, client)
#     956 def execute(
#     957     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]], client: MongoClient
#     958 ) -> tuple[Mapping[str, Any], list[Mapping[str, Any]]]:
# --> 959     request_id, msg, to_send = self.__batch_command(cmd, docs)
#     960     result = self.write_command(cmd, request_id, msg, to_send, client)
#     961     client._process_response(result, self.session)
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/message.py:949, in _BulkWriteContext.__batch_command(self, cmd, docs)
#     945 def __batch_command(
#     946     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]]
#     947 ) -> tuple[int, bytes, list[Mapping[str, Any]]]:
#     948     namespace = self.db_name + ".$cmd"
# --> 949     request_id, msg, to_send = _do_batched_op_msg(
#     950         namespace, self.op_type, cmd, docs, self.codec, self
#     951     )
#     952     if not to_send:
#     953         raise InvalidOperation("cannot do an empty bulk write")
#
# File ~/opt/anaconda3/lib/python3.11/site-packages/pymongo/message.py:1451, in _do_batched_op_msg(namespace, operation, command, docs, opts, ctx)
#    1449 if ctx.conn.compression_context:
#    1450     return _batched_op_msg_compressed(operation, command, docs, ack, opts, ctx)
# -> 1451 return _batched_op_msg(operation, command, docs, ack, opts, ctx)
#
# InvalidDocument: cannot encode object: datetime.date(2023, 9, 17), of type: <class 'datetime.date'>
