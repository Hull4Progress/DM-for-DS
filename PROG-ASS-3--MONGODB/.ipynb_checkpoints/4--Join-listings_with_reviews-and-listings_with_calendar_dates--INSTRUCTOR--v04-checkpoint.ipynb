# %% [markdown]
# ### <span style=color:blue> Joining listings_with_reviews and listings_with_calendar_dates    </span>

# %%
import sys
import json
import csv
import yaml

import importlib

import math

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
# NOTE: I moved my util.py to the directory "helper_functions" -- seems like a better name
sys.path.append('helper_functions/')
import util

# %%
# test that utils.py has been imported well
util.hello_world()
# Out:
# hello world

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

# I already have a database "airbnb"
db = client.airbnb

# checking collections in airbnb 
print(db.list_collection_names())
# Out:
# ['calendar', 'listings_with_calendar', 'testing', 'listings_previously_built', 'listings_with_reviews', 'listings_with_reviews_and_cal', 'calendar_previously_built', 'listings']

# %%
print(f'Size of listings_with_reviews is {db.listings_previously_built.count_documents({})}.')
print(f'Size of listings_with_calendar is {db.listings_with_calendar.count_documents({})}.')
print(f'Size of listings_with_calendar is {db.calendar_by_agg.count_documents({})}.')
# Out:
# Size of listings_with_reviews is 39202.
# Size of listings_with_calendar is 39201.
# Size of listings_with_calendar is 0.

# %%
pprint.pp(db.listings_with_reviews.find_one())
# Out:
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}]}

# %%
pprint.pp(db.listings_with_calendar.find_one())
# Out:
# {'_id': '10000070',
#  'average_price': 85.0,
#  'first_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 20, 0, 0),
# ...
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %%
db.listings_test1.drop()

pipeline = [
    { '$lookup': {
          'from': 'listings_with_calendar',
          'localField' : 'id',
          'foreignField' : '_id',
          'as' : 'cal_docs' 
        }
    },
    { '$out' : 'listings_test1' }
]

"""
result = db.listings_with_reviews.aggregate(pipeline)

pprint.pp(result.next())
"""

time1 = datetime.now()
result = db.listings_with_reviews.aggregate(pipeline)
time2 = datetime.now()
print(f'The time taken for this operation was {util.time_diff(time1,time2)} seconds.')

print()
print(db.list_collection_names())

size = db.listings_test1.count_documents({})
print(f'\nThe number of documents in listings_test1 is {size}.')

print()
pprint.pp(db.listings_test1.find_one())
# Out:
# The time taken for this operation was 40.434621 seconds.
#
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'listings_test1', 'listings_with_reviews', 'calendar_by_agg', 'calendar_previously_built', 'listings_with_reviews_and_cal', 'listings']
#
# The number of documents in listings_test1 is 39202.
#
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}],
#  'cal_docs': [{'_id': '51944693',
#                'average_price': 200.0,
#                'earliest_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#                'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#                'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                                'available': True,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                                'available': True,
# ...
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30},
#                               {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                                'available': False,
#                                'price': 200.0,
#                                'minimum_nights': 30,
#                                'maximum_nights': 30}]}]}

# %%
pprint.pp(db.listings_test1.find_one({'id': '35384734'}))
# Out:
# {'_id': ObjectId('664be01238b2bd10b477193c'),
#  'id': '35384734',
#  'name': 'Rental unit in New York · ★4.82 · Studio · 1 bed · 1 bath',
#  'host_id': '266380288',
#  'host_name': 'Rachel',
#  'neighbourhood_group': 'Manhattan',
#  'neighbourhood': 'West Village',
#  'latitude': 40.73924,
#  'longitude': -74.00366,
#  'room_type': 'Entire home/apt',
#  'price': nan,
#  'minimum_nights': 30,
#  'number_of_reviews': 22,
#  'last_review': datetime.datetime(2023, 10, 1, 0, 0),
#  'reviews_per_month': 0.41,
#  'calculated_host_listings_count': 5,
#  'availability_365': 0,
#  'number_of_reviews_ltm': 2,
#  'license': '',
#  'reviews': [{'listing_id': '35384734',
#               'review_id': '522113820',
#               'date': datetime.datetime(2019, 9, 1, 0, 0),
#               'reviewer_id': '69002790',
#               'reviewer_name': 'Sanjay',
#               'comments': 'The location is indeed spot on and very easily '
#                           'approachable right in the heart of Chelsea '
#                           '.<br/>Its a cozy and well maintained studio . The '
#                           'interiors are done tastefully . Valerie was very '
#                           'prompt and communicated pleasantly .<br/>The '
#                           'building though needs a major makeover . '
#                           '<br/>Looking forward to meeting Valerie in my next '
#                           'trip to NY .'},
#              {'listing_id': '35384734',
#               'review_id': '418811601213313897',
#               'date': datetime.datetime(2021, 7, 31, 0, 0),
#               'reviewer_id': '109688980',
#               'reviewer_name': 'Joseph',
#               'comments': 'Great location! Pictures and description are '
#                           'accurate. Came to NYC to work remotely and get a '
#                           'feel for the city - would definitely stay here '
#                           'again'},
#              {'listing_id': '35384734',
#               'review_id': '441254131026142744',
#               'date': datetime.datetime(2021, 8, 31, 0, 0),
#               'reviewer_id': '39142401',
#               'reviewer_name': 'Julie',
#               'comments': 'You need to stay her. Perfect location in Chelsea. '
#                           'Close to Chelsea Market, great coffee shops, '
#                           'restaurants and a short walk to the subway.'},
#              {'listing_id': '35384734',
#               'review_id': '561033227',
#               'date': datetime.datetime(2019, 11, 8, 0, 0),
#               'reviewer_id': '31422834',
#               'reviewer_name': 'Haley',
#               'comments': "We were very hopeful about staying in Valerie's "
#                           'place for 4 weeks while we were staying in NYC and '
#                           'we were pretty disappointed with our stay. While '
#                           'the location was good for what we needed, there '
#                           'were many things about the apartment that were not '
#                           'ideal (especially at such a high price '
#                           'point!)<br/>1. The apartment is clearly lived in by '
#                           'the owner when not rented, so the kitchen does not '
#                           "have place for a guest's dry goods or other kitchen "
#                           'items. Same with all of the other rooms--the fact '
#                           "that there was the owner's stuff EVERYWHERE made it "
#                           'very hard to make this place our own. <br/>2. The '
#                           'listing is much older than it looks in the '
#                           'pictures. The kitchen pots that are provided are in '
#                           'very poor condition (one smells like burning '
#                           'plastic every time it is used).<br/>3. The host '
#                           'does not provide more than a couple rolls of toilet '
#                           'paper, so if you are staying here long term, you '
#                           'will have to buy your own TP, soap, etc.<br/>4. The '
#                           'woman who is the contact while you are at the '
#                           'apartment (Rachel) was sometimes delayed in '
#                           'responding to messages. <br/>5. The heating is '
#                           'centralized in the building, so every morning get '
#                           'ready to wake up to super hot air on your feet '
#                           '(since the bed is right by the heater).<br/>6. The '
#                           'water in the shower was not reliable. We took many '
#                           'cold or luke-warm showers. This started to get '
#                           'better towards the end of our time there.<br/>7. '
#                           'The apartment has a very strange smell that we '
#                           "couldn't seem to get rid, and the bed is not very "
#                           "comfortable (the tiny couch isn't comfortable at "
#                           'all).<br/>8. The toilet has very weak plumbing, so '
#                           'the toilet plugged multiple times. The owner '
#                           "provides a super cheap plunger that doesn't work. "
#                           'Therefore, we had to wait for it to get unplugged '
#                           'until Rachel could send someone to plunge the '
#                           'toilet.'},
#              {'listing_id': '35384734',
#               'review_id': '577512892',
#               'date': datetime.datetime(2019, 12, 15, 0, 0),
#               'reviewer_id': '70343211',
#               'reviewer_name': 'Carly',
#               'comments': 'My partner and I stayed for ~40 days <br/>What was '
#                           'great: <br/>Phenomenal location and high ceilings. '
#                           'Check in was a breeze and we had zero issues with '
#                           'receiving mail here. Rachel’s response time was '
#                           'great and she was proactive about fixing/bettering '
#                           'issues.<br/>What the host can’t control:<br/>The '
#                           'building is tight and dated, and the unit faces '
#                           'construction and a playground so every weekday from '
#                           '9:30 am - 11 and 3 pm to 4:30 a daycare full of '
#                           'screaming/crying/playing 3-5 year old kids are '
#                           'released for recess and it will wake you up and '
#                           'irritate you :/ But on the weekends and rainy days '
#                           'it is very peaceful. <br/>What was '
#                           'misleading/things the host can control: <br/>The '
#                           'bed is not a Casper. This was a the main reason '
#                           'besides the location why we selected this place. I '
#                           'was disappointed to discover a very firm IKEA bed '
#                           'when I removed the unclean mattress cover to throw '
#                           'away. When I did this the head board that is not '
#                           'fixed securely to the wall also fell on me. The '
#                           'host did send us a new mattress cover, sheets, and '
#                           'a 3 inch foam mattress topper to mitigate the issue '
#                           'and I suggested she secure it for the next guest. '
#                           'Also the speaker was missing so she sent another. '
#                           '<br/>Her beloved awesome housekeeper unfortunately '
#                           'was not well when we stayed there so the apt wasn’t '
#                           'as clean as desired upon arrival. She used a new '
#                           'person that wasn’t thorough forgot to replace some '
#                           'of the listed items like toilet paper and took the '
#                           'spare keys so we were tasked with making more (host '
#                           'offered to pay for which was nice). I hope the '
#                           'rockstar housekeeper is well now and does a better '
#                           'job for the next guest. <br/>All in all- The '
#                           'location was great, the host did their best to '
#                           'correct the issues as they popped up (unfortunately '
#                           'there were quite a few), but the location can be '
#                           'noisy in an unexpected way, and some of the '
#                           'amenities hopefully are listed accurately now.'},
#              {'listing_id': '35384734',
#               'review_id': '594460766',
#               'date': datetime.datetime(2020, 1, 18, 0, 0),
#               'reviewer_id': '296731820',
#               'reviewer_name': 'Kia',
#               'comments': 'Just got back from staying here for a month. It was '
#                           'a very easy check in with great detailed '
#                           'information in her pdf prior to me arriving. I love '
#                           'that the building has an elevator and laundry on '
#                           'site and getting packages was so easy. The location '
#                           "was the best I've ever experienced in the city, and "
#                           'I lived in NYC for half my life. It was clean and '
#                           'organized with comfortable pillows/couch and plenty '
#                           'of storage space and hangers. Overall a wonderful '
#                           'experience and a great place to spend my Christmas '
#                           'and New Years. Valerie was very helpful and always '
#                           'made sure to check in to make sure everything was '
#                           'going okay. I look forward to staying there again '
#                           'in the future. <br/>-Kia'},
#              {'listing_id': '35384734',
#               'review_id': '618717944',
#               'date': datetime.datetime(2020, 3, 15, 0, 0),
#               'reviewer_id': '224536073',
#               'reviewer_name': 'Alexis',
#               'comments': 'Valerie was an awesome host and was very '
#                           'accommodating.'},
#              {'listing_id': '35384734',
#               'review_id': '631463144',
#               'date': datetime.datetime(2020, 6, 22, 0, 0),
#               'reviewer_id': '343468186',
#               'reviewer_name': 'Susan',
#               'comments': 'The Apt was perfect!  And  very clean! Big windows '
#                           'and great light! .. it has everything youd need .  '
#                           'Plus safe location !'},
#              {'listing_id': '35384734',
#               'review_id': '701146010',
#               'date': datetime.datetime(2020, 10, 17, 0, 0),
#               'reviewer_id': '351584935',
#               'reviewer_name': 'Julia',
#               'comments': 'I really enjoyed my stay at this studio apartment. '
#                           'The host was very communicative and respectful, and '
#                           'checked in often to see if I needed anything. The '
#                           'location is great and in a safe area. While the '
#                           'building is on the older side, the apartment itself '
#                           'was clean and tidy, and well taken care of. The '
#                           'studio was bright and light, and decorated '
#                           'elegantly with many cozy touches. I would highly '
#                           'recommend this place and this host!'},
#              {'listing_id': '35384734',
#               'review_id': '710941909',
#               'date': datetime.datetime(2020, 11, 23, 0, 0),
#               'reviewer_id': '22417689',
#               'reviewer_name': 'Rohan',
#               'comments': 'Fantastic spot. Right in between West Village and '
#                           'Chelsea. Great location next to the Subway too. '
#                           'Good food around, safe, clean, and lively. <br/>The '
#                           'inside was nice and clean and very well stocked. '
#                           'Having air conditioning and heating is very useful. '
#                           'Would definitely come back here again!'},
#              {'listing_id': '35384734',
#               'review_id': '739443708',
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'reviewer_id': '37082569',
#               'reviewer_name': 'Ali',
#               'comments': 'Cute little studio apartment in a fantastic '
#                           'location. Had everything I needed and really '
#                           'enjoyed staying here. Rachel & Valerie were '
#                           'incredibly helpful every step of the way!'},
#              {'listing_id': '35384734',
#               'review_id': '753714099',
#               'date': datetime.datetime(2021, 5, 1, 0, 0),
#               'reviewer_id': '36796717',
#               'reviewer_name': 'Steven',
#               'comments': 'Great studio apartment, comfortable and cozy and '
#                           'the location can’t be beat. Near some great '
#                           'restaurants and the high line. Host checked in on '
#                           'me frequently.'},
#              {'listing_id': '35384734',
#               'review_id': '463648395110513381',
#               'date': datetime.datetime(2021, 10, 1, 0, 0),
#               'reviewer_id': '1748723',
#               'reviewer_name': 'William',
#               'comments': 'Rachel and Valerie were outstanding hosts,  the apt '
#                           'was very clean and had all the essentials for a '
#                           'great stay.  They communicated super well and it '
#                           'was clear they cared about their guests with guides '
#                           'to the area and checking to make sure all was well '
#                           'during my stay.  I recommend without hesitation and '
#                           'I look forward to staying at W14th on my next visit '
#                           'to Manhattan.'},
#              {'listing_id': '35384734',
#               'review_id': '486169675847666312',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '415040358',
#               'reviewer_name': 'Apichai',
#               'comments': 'Thank you so much for allowing me to experience '
#                           'this lovely Chelsea apartment. This is one of the '
#                           'wonderful months in NYC.'},
#              {'listing_id': '35384734',
#               'review_id': '508004917148827747',
#               'date': datetime.datetime(2021, 12, 1, 0, 0),
#               'reviewer_id': '67125300',
#               'reviewer_name': 'Antonia',
#               'comments': "I had such a great Stay in Rachel's studio! The "
#                           'apartment is spacious and has everything one or two '
#                           'people could need. The bed is also SUPER '
#                           'comfortable. Good working appliances and when I '
#                           'arrived it was spotless. The location is so great '
#                           'if you are visiting New York or need an extended '
#                           'stay- very close to the subway to pop uptown and '
#                           'the L if you want to go across town or to Brooklyn. '
#                           'The building is very safe and I had no issues '
#                           'checking in, will definitely stay here again!'},
#              {'listing_id': '35384734',
#               'review_id': '594938588343889684',
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'reviewer_id': '145711962',
#               'reviewer_name': 'Janice',
#               'comments': 'I spent a month in this cozy studio apartment in a '
#                           'wonderful neighborhood close to several other '
#                           'wonderful neighborhoods.  Rachel is an extremely '
#                           'responsive and solicitous host who also gives you '
#                           'all the privacy you would want.  Check-in and '
#                           'check-out were easy and well-communicated, the '
#                           'building has an elevator and a laundry room, and is '
#                           'located on a street with several restaurants and '
#                           "delis.  (don't miss the Swedish bakery!)"},
#              {'listing_id': '35384734',
#               'review_id': '693442572829167031',
#               'date': datetime.datetime(2022, 8, 14, 0, 0),
#               'reviewer_id': '144908682',
#               'reviewer_name': 'Matt',
#               'comments': 'The apartment itself was everything it had been '
#                           'described to be, and Rachel was a wonderful host. '
#                           'Excellent communication, and Rachel was always on '
#                           'hand to help with any problems. The apartment had '
#                           'everything I needed and was in a terrific location. '
#                           'I stayed for three months and experienced no '
#                           'problems at all.'},
#              {'listing_id': '35384734',
#               'review_id': '750677361710556536',
#               'date': datetime.datetime(2022, 11, 1, 0, 0),
#               'reviewer_id': '458177032',
#               'reviewer_name': 'Tania',
#               'comments': 'The apartment is just as it looks in the pictures - '
#                           'clean, with lovely décor and very quiet.  You’re on '
#                           'the 4th floor of an elevator building and the '
#                           'building felt safe.  A very comfy bed, fantastic '
#                           'shower pressure and a laundry in the basement were '
#                           'wonderful to have.  The location is amazing, with '
#                           'Chelsea Market, the subway and lots of great '
#                           'restaurants and bars nearby.  Rachel was excellent '
#                           'to communicate with, she checked in with me before, '
#                           'during and after my stay.  Thank you again Rachel '
#                           'for a great stay!'},
#              {'listing_id': '35384734',
#               'review_id': '772456471531667427',
#               'date': datetime.datetime(2022, 12, 1, 0, 0),
#               'reviewer_id': '209794364',
#               'reviewer_name': 'Emilie',
#               'comments': 'Incredible month stay in the perfect NYC location. '
#                           'Apartment was exactly as advertised. Would '
#                           'definitely stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '903692436564101968',
#               'date': datetime.datetime(2023, 5, 31, 0, 0),
#               'reviewer_id': '40330705',
#               'reviewer_name': 'Jessica',
#               'comments': 'Rachel was a lovely host and her place was '
#                           'perfectly located and yet super quiet. The light is '
#                           'beautiful and the apartment had everything you’d '
#                           'need for a stay of any length.'},
#              {'listing_id': '35384734',
#               'review_id': '992851015788271855',
#               'date': datetime.datetime(2023, 10, 1, 0, 0),
#               'reviewer_id': '15140846',
#               'reviewer_name': 'Dan',
#               'comments': 'The location is seriously incredible - 60 seconds '
#                           'away from the 8th Ave station/bodegas/pizza/massage '
#                           'spa, 2 minutes to the High Line, and 6 minutes to '
#                           'the galleries in north Chelsea. Also, the block is '
#                           'surprisingly quiet and untrafficked during the '
#                           'week. The building is on the older side, but it has '
#                           "everything that you'll need, to include "
#                           'washer/dryer in the basement. Rachel is also very '
#                           'responsive. Would totally stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '728576635',
#               'date': datetime.datetime(2021, 2, 2, 0, 0),
#               'reviewer_id': '358506356',
#               'reviewer_name': 'Iryna',
#               'comments': 'Great place in a perfect location.'}],
#  'cal_docs': []}

# %%
# In the $unwind, using the option << "preserveNullAndEmptyArrays": true >>
#    so that we don't drop the listing with id = '35384734', which has empty array for cal_docs
# In general, if you do an $unwind, it converts a left outer join into a left (full) join,
#    because it removes documents that came from the left side, but have no matching records
#    from the right side.  By including the << "preserveNullAndEmptyArrays": true >> option,
#    you preserve the left join aspect of the $lookup
# This is following https://stackoverflow.com/questions/36725519/how-to-solve-empty-array-with-unwind

db.listings_test2.drop()

pipeline = [
    { '$lookup': {
          'from': 'listings_with_calendar',
          'localField' : 'id',
          'foreignField' : '_id',
          'as' : 'cal_docs' 
        }
    },
    { '$unwind': { 'path': '$cal_docs',  
                   'preserveNullAndEmptyArrays' : True
                 }
    },
    { '$out' : 'listings_test2'}
]

"""
result = db.listings_with_reviews.aggregate(pipeline)

pprint.pp(result.next())
"""
time1 = datetime.now()
result = db.listings_with_reviews.aggregate(pipeline)
time2 = datetime.now()
print(f'The time taken for this operation was {util.time_diff(time1,time2)} seconds.')

print()
print(db.list_collection_names())

size = db.listings_test2.count_documents({})
print(f'\nThe number of documents in listings_test2 is {size}.')

print()
pprint.pp(db.listings_test2.find_one())
# Out:
# The time taken for this operation was 36.539288 seconds.
#
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'listings_test1', 'listings_test2', 'listings_with_reviews', 'calendar_by_agg', 'calendar_previously_built', 'listings_with_reviews_and_cal', 'listings']
#
# The number of documents in listings_test2 is 39202.
#
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}],
#  'cal_docs': {'_id': '51944693',
#               'average_price': 200.0,
#               'earliest_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#               'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#               'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                               'available': True,
# ...
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30}]}}

# %%
pprint.pp(db.listings_test2.find_one({'id': '35384734'}))
# Out:
# {'_id': ObjectId('664be01238b2bd10b477193c'),
#  'id': '35384734',
#  'name': 'Rental unit in New York · ★4.82 · Studio · 1 bed · 1 bath',
#  'host_id': '266380288',
#  'host_name': 'Rachel',
#  'neighbourhood_group': 'Manhattan',
#  'neighbourhood': 'West Village',
#  'latitude': 40.73924,
#  'longitude': -74.00366,
#  'room_type': 'Entire home/apt',
#  'price': nan,
#  'minimum_nights': 30,
#  'number_of_reviews': 22,
#  'last_review': datetime.datetime(2023, 10, 1, 0, 0),
#  'reviews_per_month': 0.41,
#  'calculated_host_listings_count': 5,
#  'availability_365': 0,
#  'number_of_reviews_ltm': 2,
#  'license': '',
#  'reviews': [{'listing_id': '35384734',
#               'review_id': '522113820',
#               'date': datetime.datetime(2019, 9, 1, 0, 0),
#               'reviewer_id': '69002790',
#               'reviewer_name': 'Sanjay',
#               'comments': 'The location is indeed spot on and very easily '
#                           'approachable right in the heart of Chelsea '
#                           '.<br/>Its a cozy and well maintained studio . The '
#                           'interiors are done tastefully . Valerie was very '
#                           'prompt and communicated pleasantly .<br/>The '
#                           'building though needs a major makeover . '
#                           '<br/>Looking forward to meeting Valerie in my next '
#                           'trip to NY .'},
#              {'listing_id': '35384734',
#               'review_id': '418811601213313897',
#               'date': datetime.datetime(2021, 7, 31, 0, 0),
#               'reviewer_id': '109688980',
#               'reviewer_name': 'Joseph',
#               'comments': 'Great location! Pictures and description are '
#                           'accurate. Came to NYC to work remotely and get a '
#                           'feel for the city - would definitely stay here '
#                           'again'},
#              {'listing_id': '35384734',
#               'review_id': '441254131026142744',
#               'date': datetime.datetime(2021, 8, 31, 0, 0),
#               'reviewer_id': '39142401',
#               'reviewer_name': 'Julie',
#               'comments': 'You need to stay her. Perfect location in Chelsea. '
#                           'Close to Chelsea Market, great coffee shops, '
#                           'restaurants and a short walk to the subway.'},
#              {'listing_id': '35384734',
#               'review_id': '561033227',
#               'date': datetime.datetime(2019, 11, 8, 0, 0),
#               'reviewer_id': '31422834',
#               'reviewer_name': 'Haley',
#               'comments': "We were very hopeful about staying in Valerie's "
#                           'place for 4 weeks while we were staying in NYC and '
#                           'we were pretty disappointed with our stay. While '
#                           'the location was good for what we needed, there '
#                           'were many things about the apartment that were not '
#                           'ideal (especially at such a high price '
#                           'point!)<br/>1. The apartment is clearly lived in by '
#                           'the owner when not rented, so the kitchen does not '
#                           "have place for a guest's dry goods or other kitchen "
#                           'items. Same with all of the other rooms--the fact '
#                           "that there was the owner's stuff EVERYWHERE made it "
#                           'very hard to make this place our own. <br/>2. The '
#                           'listing is much older than it looks in the '
#                           'pictures. The kitchen pots that are provided are in '
#                           'very poor condition (one smells like burning '
#                           'plastic every time it is used).<br/>3. The host '
#                           'does not provide more than a couple rolls of toilet '
#                           'paper, so if you are staying here long term, you '
#                           'will have to buy your own TP, soap, etc.<br/>4. The '
#                           'woman who is the contact while you are at the '
#                           'apartment (Rachel) was sometimes delayed in '
#                           'responding to messages. <br/>5. The heating is '
#                           'centralized in the building, so every morning get '
#                           'ready to wake up to super hot air on your feet '
#                           '(since the bed is right by the heater).<br/>6. The '
#                           'water in the shower was not reliable. We took many '
#                           'cold or luke-warm showers. This started to get '
#                           'better towards the end of our time there.<br/>7. '
#                           'The apartment has a very strange smell that we '
#                           "couldn't seem to get rid, and the bed is not very "
#                           "comfortable (the tiny couch isn't comfortable at "
#                           'all).<br/>8. The toilet has very weak plumbing, so '
#                           'the toilet plugged multiple times. The owner '
#                           "provides a super cheap plunger that doesn't work. "
#                           'Therefore, we had to wait for it to get unplugged '
#                           'until Rachel could send someone to plunge the '
#                           'toilet.'},
#              {'listing_id': '35384734',
#               'review_id': '577512892',
#               'date': datetime.datetime(2019, 12, 15, 0, 0),
#               'reviewer_id': '70343211',
#               'reviewer_name': 'Carly',
#               'comments': 'My partner and I stayed for ~40 days <br/>What was '
#                           'great: <br/>Phenomenal location and high ceilings. '
#                           'Check in was a breeze and we had zero issues with '
#                           'receiving mail here. Rachel’s response time was '
#                           'great and she was proactive about fixing/bettering '
#                           'issues.<br/>What the host can’t control:<br/>The '
#                           'building is tight and dated, and the unit faces '
#                           'construction and a playground so every weekday from '
#                           '9:30 am - 11 and 3 pm to 4:30 a daycare full of '
#                           'screaming/crying/playing 3-5 year old kids are '
#                           'released for recess and it will wake you up and '
#                           'irritate you :/ But on the weekends and rainy days '
#                           'it is very peaceful. <br/>What was '
#                           'misleading/things the host can control: <br/>The '
#                           'bed is not a Casper. This was a the main reason '
#                           'besides the location why we selected this place. I '
#                           'was disappointed to discover a very firm IKEA bed '
#                           'when I removed the unclean mattress cover to throw '
#                           'away. When I did this the head board that is not '
#                           'fixed securely to the wall also fell on me. The '
#                           'host did send us a new mattress cover, sheets, and '
#                           'a 3 inch foam mattress topper to mitigate the issue '
#                           'and I suggested she secure it for the next guest. '
#                           'Also the speaker was missing so she sent another. '
#                           '<br/>Her beloved awesome housekeeper unfortunately '
#                           'was not well when we stayed there so the apt wasn’t '
#                           'as clean as desired upon arrival. She used a new '
#                           'person that wasn’t thorough forgot to replace some '
#                           'of the listed items like toilet paper and took the '
#                           'spare keys so we were tasked with making more (host '
#                           'offered to pay for which was nice). I hope the '
#                           'rockstar housekeeper is well now and does a better '
#                           'job for the next guest. <br/>All in all- The '
#                           'location was great, the host did their best to '
#                           'correct the issues as they popped up (unfortunately '
#                           'there were quite a few), but the location can be '
#                           'noisy in an unexpected way, and some of the '
#                           'amenities hopefully are listed accurately now.'},
#              {'listing_id': '35384734',
#               'review_id': '594460766',
#               'date': datetime.datetime(2020, 1, 18, 0, 0),
#               'reviewer_id': '296731820',
#               'reviewer_name': 'Kia',
#               'comments': 'Just got back from staying here for a month. It was '
#                           'a very easy check in with great detailed '
#                           'information in her pdf prior to me arriving. I love '
#                           'that the building has an elevator and laundry on '
#                           'site and getting packages was so easy. The location '
#                           "was the best I've ever experienced in the city, and "
#                           'I lived in NYC for half my life. It was clean and '
#                           'organized with comfortable pillows/couch and plenty '
#                           'of storage space and hangers. Overall a wonderful '
#                           'experience and a great place to spend my Christmas '
#                           'and New Years. Valerie was very helpful and always '
#                           'made sure to check in to make sure everything was '
#                           'going okay. I look forward to staying there again '
#                           'in the future. <br/>-Kia'},
#              {'listing_id': '35384734',
#               'review_id': '618717944',
#               'date': datetime.datetime(2020, 3, 15, 0, 0),
#               'reviewer_id': '224536073',
#               'reviewer_name': 'Alexis',
#               'comments': 'Valerie was an awesome host and was very '
#                           'accommodating.'},
#              {'listing_id': '35384734',
#               'review_id': '631463144',
#               'date': datetime.datetime(2020, 6, 22, 0, 0),
#               'reviewer_id': '343468186',
#               'reviewer_name': 'Susan',
#               'comments': 'The Apt was perfect!  And  very clean! Big windows '
#                           'and great light! .. it has everything youd need .  '
#                           'Plus safe location !'},
#              {'listing_id': '35384734',
#               'review_id': '701146010',
#               'date': datetime.datetime(2020, 10, 17, 0, 0),
#               'reviewer_id': '351584935',
#               'reviewer_name': 'Julia',
#               'comments': 'I really enjoyed my stay at this studio apartment. '
#                           'The host was very communicative and respectful, and '
#                           'checked in often to see if I needed anything. The '
#                           'location is great and in a safe area. While the '
#                           'building is on the older side, the apartment itself '
#                           'was clean and tidy, and well taken care of. The '
#                           'studio was bright and light, and decorated '
#                           'elegantly with many cozy touches. I would highly '
#                           'recommend this place and this host!'},
#              {'listing_id': '35384734',
#               'review_id': '710941909',
#               'date': datetime.datetime(2020, 11, 23, 0, 0),
#               'reviewer_id': '22417689',
#               'reviewer_name': 'Rohan',
#               'comments': 'Fantastic spot. Right in between West Village and '
#                           'Chelsea. Great location next to the Subway too. '
#                           'Good food around, safe, clean, and lively. <br/>The '
#                           'inside was nice and clean and very well stocked. '
#                           'Having air conditioning and heating is very useful. '
#                           'Would definitely come back here again!'},
#              {'listing_id': '35384734',
#               'review_id': '739443708',
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'reviewer_id': '37082569',
#               'reviewer_name': 'Ali',
#               'comments': 'Cute little studio apartment in a fantastic '
#                           'location. Had everything I needed and really '
#                           'enjoyed staying here. Rachel & Valerie were '
#                           'incredibly helpful every step of the way!'},
#              {'listing_id': '35384734',
#               'review_id': '753714099',
#               'date': datetime.datetime(2021, 5, 1, 0, 0),
#               'reviewer_id': '36796717',
#               'reviewer_name': 'Steven',
#               'comments': 'Great studio apartment, comfortable and cozy and '
#                           'the location can’t be beat. Near some great '
#                           'restaurants and the high line. Host checked in on '
#                           'me frequently.'},
#              {'listing_id': '35384734',
#               'review_id': '463648395110513381',
#               'date': datetime.datetime(2021, 10, 1, 0, 0),
#               'reviewer_id': '1748723',
#               'reviewer_name': 'William',
#               'comments': 'Rachel and Valerie were outstanding hosts,  the apt '
#                           'was very clean and had all the essentials for a '
#                           'great stay.  They communicated super well and it '
#                           'was clear they cared about their guests with guides '
#                           'to the area and checking to make sure all was well '
#                           'during my stay.  I recommend without hesitation and '
#                           'I look forward to staying at W14th on my next visit '
#                           'to Manhattan.'},
#              {'listing_id': '35384734',
#               'review_id': '486169675847666312',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '415040358',
#               'reviewer_name': 'Apichai',
#               'comments': 'Thank you so much for allowing me to experience '
#                           'this lovely Chelsea apartment. This is one of the '
#                           'wonderful months in NYC.'},
#              {'listing_id': '35384734',
#               'review_id': '508004917148827747',
#               'date': datetime.datetime(2021, 12, 1, 0, 0),
#               'reviewer_id': '67125300',
#               'reviewer_name': 'Antonia',
#               'comments': "I had such a great Stay in Rachel's studio! The "
#                           'apartment is spacious and has everything one or two '
#                           'people could need. The bed is also SUPER '
#                           'comfortable. Good working appliances and when I '
#                           'arrived it was spotless. The location is so great '
#                           'if you are visiting New York or need an extended '
#                           'stay- very close to the subway to pop uptown and '
#                           'the L if you want to go across town or to Brooklyn. '
#                           'The building is very safe and I had no issues '
#                           'checking in, will definitely stay here again!'},
#              {'listing_id': '35384734',
#               'review_id': '594938588343889684',
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'reviewer_id': '145711962',
#               'reviewer_name': 'Janice',
#               'comments': 'I spent a month in this cozy studio apartment in a '
#                           'wonderful neighborhood close to several other '
#                           'wonderful neighborhoods.  Rachel is an extremely '
#                           'responsive and solicitous host who also gives you '
#                           'all the privacy you would want.  Check-in and '
#                           'check-out were easy and well-communicated, the '
#                           'building has an elevator and a laundry room, and is '
#                           'located on a street with several restaurants and '
#                           "delis.  (don't miss the Swedish bakery!)"},
#              {'listing_id': '35384734',
#               'review_id': '693442572829167031',
#               'date': datetime.datetime(2022, 8, 14, 0, 0),
#               'reviewer_id': '144908682',
#               'reviewer_name': 'Matt',
#               'comments': 'The apartment itself was everything it had been '
#                           'described to be, and Rachel was a wonderful host. '
#                           'Excellent communication, and Rachel was always on '
#                           'hand to help with any problems. The apartment had '
#                           'everything I needed and was in a terrific location. '
#                           'I stayed for three months and experienced no '
#                           'problems at all.'},
#              {'listing_id': '35384734',
#               'review_id': '750677361710556536',
#               'date': datetime.datetime(2022, 11, 1, 0, 0),
#               'reviewer_id': '458177032',
#               'reviewer_name': 'Tania',
#               'comments': 'The apartment is just as it looks in the pictures - '
#                           'clean, with lovely décor and very quiet.  You’re on '
#                           'the 4th floor of an elevator building and the '
#                           'building felt safe.  A very comfy bed, fantastic '
#                           'shower pressure and a laundry in the basement were '
#                           'wonderful to have.  The location is amazing, with '
#                           'Chelsea Market, the subway and lots of great '
#                           'restaurants and bars nearby.  Rachel was excellent '
#                           'to communicate with, she checked in with me before, '
#                           'during and after my stay.  Thank you again Rachel '
#                           'for a great stay!'},
#              {'listing_id': '35384734',
#               'review_id': '772456471531667427',
#               'date': datetime.datetime(2022, 12, 1, 0, 0),
#               'reviewer_id': '209794364',
#               'reviewer_name': 'Emilie',
#               'comments': 'Incredible month stay in the perfect NYC location. '
#                           'Apartment was exactly as advertised. Would '
#                           'definitely stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '903692436564101968',
#               'date': datetime.datetime(2023, 5, 31, 0, 0),
#               'reviewer_id': '40330705',
#               'reviewer_name': 'Jessica',
#               'comments': 'Rachel was a lovely host and her place was '
#                           'perfectly located and yet super quiet. The light is '
#                           'beautiful and the apartment had everything you’d '
#                           'need for a stay of any length.'},
#              {'listing_id': '35384734',
#               'review_id': '992851015788271855',
#               'date': datetime.datetime(2023, 10, 1, 0, 0),
#               'reviewer_id': '15140846',
#               'reviewer_name': 'Dan',
#               'comments': 'The location is seriously incredible - 60 seconds '
#                           'away from the 8th Ave station/bodegas/pizza/massage '
#                           'spa, 2 minutes to the High Line, and 6 minutes to '
#                           'the galleries in north Chelsea. Also, the block is '
#                           'surprisingly quiet and untrafficked during the '
#                           'week. The building is on the older side, but it has '
#                           "everything that you'll need, to include "
#                           'washer/dryer in the basement. Rachel is also very '
#                           'responsive. Would totally stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '728576635',
#               'date': datetime.datetime(2021, 2, 2, 0, 0),
#               'reviewer_id': '358506356',
#               'reviewer_name': 'Iryna',
#               'comments': 'Great place in a perfect location.'}]}

# %%
db.listings_test1.drop()

pipeline = [
    { '$lookup': {
          'from': 'listings_with_calendar',
          'localField' : 'id',
          'foreignField' : '_id',
          'as' : 'cal_docs' 
        }
    },
    { '$unwind': { 'path': '$cal_docs',  
                   'preserveNullAndEmptyArrays' : True
                 }
    },
    { '$addFields': 
          {'average_price': '$$ROOT.cal_docs.average_price',
           'first_available_date': '$$ROOT.cal_docs.first_available_date',
           'last_available_date':  '$$ROOT.cal_docs.last_available_date',
           'dates_list': '$$ROOT.cal_docs.dates_list'
          }
    },
    { '$out' : 'listings_test1'}
]

"""
result = db.listings_with_reviews.aggregate(pipeline)

pprint.pp(result.next())
"""

time1 = datetime.now()
result = db.listings_with_reviews.aggregate(pipeline)
time2 = datetime.now()
print(f'The time taken for this operation was {util.time_diff(time1,time2)} seconds.')

print()
print(db.list_collection_names())

size = db.listings_test1.count_documents({})
print(f'\nThe number of documents in listings_test1 is {size}.')

print()
pprint.pp(db.listings_test1.find_one())
# Out:
# The time taken for this operation was 64.452248 seconds.
#
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'listings_test2', 'listings_with_reviews', 'listings_test1', 'calendar_by_agg', 'calendar_previously_built', 'listings_with_reviews_and_cal', 'listings']
#
# The number of documents in listings_test1 is 39202.
#
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}],
#  'cal_docs': {'_id': '51944693',
#               'average_price': 200.0,
#               'earliest_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#               'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#               'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                               'available': False,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                               'available': True,
#                               'price': 200.0,
#                               'minimum_nights': 30,
#                               'maximum_nights': 30},
#                              {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                               'available': True,
# ...
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %%
db.listings_test1.drop()

pipeline = [
    { '$lookup': {
          'from': 'listings_with_calendar',
          'localField' : 'id',
          'foreignField' : '_id',
          'as' : 'cal_docs' 
        }
    },
    { '$unwind': { 'path': '$cal_docs',  
                   'preserveNullAndEmptyArrays' : True
                 }
    },
    { '$addFields': 
          {'average_price': '$$ROOT.cal_docs.average_price',
           'first_available_date': '$$ROOT.cal_docs.first_available_date',
           'last_available_date':  '$$ROOT.cal_docs.last_available_date',
           'dates_list': '$$ROOT.cal_docs.dates_list'
          }
    },
    { '$unset': 'cal_docs' }      
]
"""

    { '$out' : 'listings_with_reviews_and_cal'}
"""
"""
result = db.listings_with_reviews.aggregate(pipeline)

pprint.pp(result.next())
"""

time1 = datetime.now()
result = db.listings_with_reviews.aggregate(pipeline)
time2 = datetime.now()
print(f'The time taken for this operation was {util.time_diff(time1,time2)} seconds.')

print()
print(db.list_collection_names())

size = db.listings_test1.count_documents({})
print(f'\nThe number of documents in listings_test1 is {size}.')

print()
pprint.pp(db.listings_test1.find_one())
# Out:
# The time taken for this operation was 0.193244 seconds.
#
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'listings_test2', 'listings_with_reviews', 'calendar_by_agg', 'calendar_previously_built', 'listings_with_reviews_and_cal', 'listings']
#
# The number of documents in listings_test1 is 0.
#
# None

# %%
db.listings_with_reviews_and_cal.drop()

pipeline = [
    { '$lookup': {
          'from': 'listings_with_calendar',
          'localField' : 'id',
          'foreignField' : '_id',
          'as' : 'cal_docs' 
        }
    },
    { '$unwind': { 'path': '$cal_docs',  
                   'preserveNullAndEmptyArrays' : True
                 }
    },
    { '$addFields': 
          {'average_price': '$$ROOT.cal_docs.average_price',
           'first_available_date': '$$ROOT.cal_docs.first_available_date',
           'last_available_date':  '$$ROOT.cal_docs.last_available_date',
           'dates_list': '$$ROOT.cal_docs.dates_list'
          }
    },
    { '$unset': 'cal_docs' },     
    { '$out' : 'listings_with_reviews_and_cal'}
]

time1 = datetime.now()
result = db.listings_with_reviews.aggregate(pipeline)
time2 = datetime.now()
print(f'The time taken for this operation was {util.time_diff(time1,time2)} seconds.')

print()
print(db.list_collection_names())

size = db.listings_with_reviews_and_cal.count_documents({})
print(f'\nThe number of documents in listings_with_reviews_and_cal is {size}.')

print()
pprint.pp(db.listings_with_reviews_and_cal.find_one())
# Out:
# The time taken for this operation was 22.612153 seconds.
#
# ['listings_with_reviews_and_cal', 'calendar', 'listings_with_calendar', 'testing', 'listings_previously_built', 'listings_with_reviews', 'calendar_previously_built', 'listings']
#
# The number of documents in listings_with_reviews_and_cal is 39202.
#
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}],
#  'average_price': 200.0,
#  'first_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 10, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 11, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 12, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 13, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 14, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 15, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 16, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 17, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 18, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 19, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 20, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 21, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 22, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 23, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 24, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 25, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 26, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 27, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 28, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 29, 0, 0),
#                  'available': True,
#                  'price': 200.0,
# ...
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %%
# the one listing that is not in listings_with_calendar
pprint.pp(db.listings_with_reviews_and_cal.find_one({'id': '35384734'}))
# Out:
# {'_id': ObjectId('664be01238b2bd10b477193c'),
#  'id': '35384734',
#  'name': 'Rental unit in New York · ★4.82 · Studio · 1 bed · 1 bath',
#  'host_id': '266380288',
#  'host_name': 'Rachel',
#  'neighbourhood_group': 'Manhattan',
#  'neighbourhood': 'West Village',
#  'latitude': 40.73924,
#  'longitude': -74.00366,
#  'room_type': 'Entire home/apt',
#  'price': nan,
#  'minimum_nights': 30,
#  'number_of_reviews': 22,
#  'last_review': datetime.datetime(2023, 10, 1, 0, 0),
#  'reviews_per_month': 0.41,
#  'calculated_host_listings_count': 5,
#  'availability_365': 0,
#  'number_of_reviews_ltm': 2,
#  'license': '',
#  'reviews': [{'listing_id': '35384734',
#               'review_id': '522113820',
#               'date': datetime.datetime(2019, 9, 1, 0, 0),
#               'reviewer_id': '69002790',
#               'reviewer_name': 'Sanjay',
#               'comments': 'The location is indeed spot on and very easily '
#                           'approachable right in the heart of Chelsea '
#                           '.<br/>Its a cozy and well maintained studio . The '
#                           'interiors are done tastefully . Valerie was very '
#                           'prompt and communicated pleasantly .<br/>The '
#                           'building though needs a major makeover . '
#                           '<br/>Looking forward to meeting Valerie in my next '
#                           'trip to NY .'},
#              {'listing_id': '35384734',
#               'review_id': '418811601213313897',
#               'date': datetime.datetime(2021, 7, 31, 0, 0),
#               'reviewer_id': '109688980',
#               'reviewer_name': 'Joseph',
#               'comments': 'Great location! Pictures and description are '
#                           'accurate. Came to NYC to work remotely and get a '
#                           'feel for the city - would definitely stay here '
#                           'again'},
#              {'listing_id': '35384734',
#               'review_id': '441254131026142744',
#               'date': datetime.datetime(2021, 8, 31, 0, 0),
#               'reviewer_id': '39142401',
#               'reviewer_name': 'Julie',
#               'comments': 'You need to stay her. Perfect location in Chelsea. '
#                           'Close to Chelsea Market, great coffee shops, '
#                           'restaurants and a short walk to the subway.'},
#              {'listing_id': '35384734',
#               'review_id': '561033227',
#               'date': datetime.datetime(2019, 11, 8, 0, 0),
#               'reviewer_id': '31422834',
#               'reviewer_name': 'Haley',
#               'comments': "We were very hopeful about staying in Valerie's "
#                           'place for 4 weeks while we were staying in NYC and '
#                           'we were pretty disappointed with our stay. While '
#                           'the location was good for what we needed, there '
#                           'were many things about the apartment that were not '
#                           'ideal (especially at such a high price '
#                           'point!)<br/>1. The apartment is clearly lived in by '
#                           'the owner when not rented, so the kitchen does not '
#                           "have place for a guest's dry goods or other kitchen "
#                           'items. Same with all of the other rooms--the fact '
#                           "that there was the owner's stuff EVERYWHERE made it "
#                           'very hard to make this place our own. <br/>2. The '
#                           'listing is much older than it looks in the '
#                           'pictures. The kitchen pots that are provided are in '
#                           'very poor condition (one smells like burning '
#                           'plastic every time it is used).<br/>3. The host '
#                           'does not provide more than a couple rolls of toilet '
#                           'paper, so if you are staying here long term, you '
#                           'will have to buy your own TP, soap, etc.<br/>4. The '
#                           'woman who is the contact while you are at the '
#                           'apartment (Rachel) was sometimes delayed in '
#                           'responding to messages. <br/>5. The heating is '
#                           'centralized in the building, so every morning get '
#                           'ready to wake up to super hot air on your feet '
#                           '(since the bed is right by the heater).<br/>6. The '
#                           'water in the shower was not reliable. We took many '
#                           'cold or luke-warm showers. This started to get '
#                           'better towards the end of our time there.<br/>7. '
#                           'The apartment has a very strange smell that we '
#                           "couldn't seem to get rid, and the bed is not very "
#                           "comfortable (the tiny couch isn't comfortable at "
#                           'all).<br/>8. The toilet has very weak plumbing, so '
#                           'the toilet plugged multiple times. The owner '
#                           "provides a super cheap plunger that doesn't work. "
#                           'Therefore, we had to wait for it to get unplugged '
#                           'until Rachel could send someone to plunge the '
#                           'toilet.'},
#              {'listing_id': '35384734',
#               'review_id': '577512892',
#               'date': datetime.datetime(2019, 12, 15, 0, 0),
#               'reviewer_id': '70343211',
#               'reviewer_name': 'Carly',
#               'comments': 'My partner and I stayed for ~40 days <br/>What was '
#                           'great: <br/>Phenomenal location and high ceilings. '
#                           'Check in was a breeze and we had zero issues with '
#                           'receiving mail here. Rachel’s response time was '
#                           'great and she was proactive about fixing/bettering '
#                           'issues.<br/>What the host can’t control:<br/>The '
#                           'building is tight and dated, and the unit faces '
#                           'construction and a playground so every weekday from '
#                           '9:30 am - 11 and 3 pm to 4:30 a daycare full of '
#                           'screaming/crying/playing 3-5 year old kids are '
#                           'released for recess and it will wake you up and '
#                           'irritate you :/ But on the weekends and rainy days '
#                           'it is very peaceful. <br/>What was '
#                           'misleading/things the host can control: <br/>The '
#                           'bed is not a Casper. This was a the main reason '
#                           'besides the location why we selected this place. I '
#                           'was disappointed to discover a very firm IKEA bed '
#                           'when I removed the unclean mattress cover to throw '
#                           'away. When I did this the head board that is not '
#                           'fixed securely to the wall also fell on me. The '
#                           'host did send us a new mattress cover, sheets, and '
#                           'a 3 inch foam mattress topper to mitigate the issue '
#                           'and I suggested she secure it for the next guest. '
#                           'Also the speaker was missing so she sent another. '
#                           '<br/>Her beloved awesome housekeeper unfortunately '
#                           'was not well when we stayed there so the apt wasn’t '
#                           'as clean as desired upon arrival. She used a new '
#                           'person that wasn’t thorough forgot to replace some '
#                           'of the listed items like toilet paper and took the '
#                           'spare keys so we were tasked with making more (host '
#                           'offered to pay for which was nice). I hope the '
#                           'rockstar housekeeper is well now and does a better '
#                           'job for the next guest. <br/>All in all- The '
#                           'location was great, the host did their best to '
#                           'correct the issues as they popped up (unfortunately '
#                           'there were quite a few), but the location can be '
#                           'noisy in an unexpected way, and some of the '
#                           'amenities hopefully are listed accurately now.'},
#              {'listing_id': '35384734',
#               'review_id': '594460766',
#               'date': datetime.datetime(2020, 1, 18, 0, 0),
#               'reviewer_id': '296731820',
#               'reviewer_name': 'Kia',
#               'comments': 'Just got back from staying here for a month. It was '
#                           'a very easy check in with great detailed '
#                           'information in her pdf prior to me arriving. I love '
#                           'that the building has an elevator and laundry on '
#                           'site and getting packages was so easy. The location '
#                           "was the best I've ever experienced in the city, and "
#                           'I lived in NYC for half my life. It was clean and '
#                           'organized with comfortable pillows/couch and plenty '
#                           'of storage space and hangers. Overall a wonderful '
#                           'experience and a great place to spend my Christmas '
#                           'and New Years. Valerie was very helpful and always '
#                           'made sure to check in to make sure everything was '
#                           'going okay. I look forward to staying there again '
#                           'in the future. <br/>-Kia'},
#              {'listing_id': '35384734',
#               'review_id': '618717944',
#               'date': datetime.datetime(2020, 3, 15, 0, 0),
#               'reviewer_id': '224536073',
#               'reviewer_name': 'Alexis',
#               'comments': 'Valerie was an awesome host and was very '
#                           'accommodating.'},
#              {'listing_id': '35384734',
#               'review_id': '631463144',
#               'date': datetime.datetime(2020, 6, 22, 0, 0),
#               'reviewer_id': '343468186',
#               'reviewer_name': 'Susan',
#               'comments': 'The Apt was perfect!  And  very clean! Big windows '
#                           'and great light! .. it has everything youd need .  '
#                           'Plus safe location !'},
#              {'listing_id': '35384734',
#               'review_id': '701146010',
#               'date': datetime.datetime(2020, 10, 17, 0, 0),
#               'reviewer_id': '351584935',
#               'reviewer_name': 'Julia',
#               'comments': 'I really enjoyed my stay at this studio apartment. '
#                           'The host was very communicative and respectful, and '
#                           'checked in often to see if I needed anything. The '
#                           'location is great and in a safe area. While the '
#                           'building is on the older side, the apartment itself '
#                           'was clean and tidy, and well taken care of. The '
#                           'studio was bright and light, and decorated '
#                           'elegantly with many cozy touches. I would highly '
#                           'recommend this place and this host!'},
#              {'listing_id': '35384734',
#               'review_id': '710941909',
#               'date': datetime.datetime(2020, 11, 23, 0, 0),
#               'reviewer_id': '22417689',
#               'reviewer_name': 'Rohan',
#               'comments': 'Fantastic spot. Right in between West Village and '
#                           'Chelsea. Great location next to the Subway too. '
#                           'Good food around, safe, clean, and lively. <br/>The '
#                           'inside was nice and clean and very well stocked. '
#                           'Having air conditioning and heating is very useful. '
#                           'Would definitely come back here again!'},
#              {'listing_id': '35384734',
#               'review_id': '739443708',
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'reviewer_id': '37082569',
#               'reviewer_name': 'Ali',
#               'comments': 'Cute little studio apartment in a fantastic '
#                           'location. Had everything I needed and really '
#                           'enjoyed staying here. Rachel & Valerie were '
#                           'incredibly helpful every step of the way!'},
#              {'listing_id': '35384734',
#               'review_id': '753714099',
#               'date': datetime.datetime(2021, 5, 1, 0, 0),
#               'reviewer_id': '36796717',
#               'reviewer_name': 'Steven',
#               'comments': 'Great studio apartment, comfortable and cozy and '
#                           'the location can’t be beat. Near some great '
#                           'restaurants and the high line. Host checked in on '
#                           'me frequently.'},
#              {'listing_id': '35384734',
#               'review_id': '463648395110513381',
#               'date': datetime.datetime(2021, 10, 1, 0, 0),
#               'reviewer_id': '1748723',
#               'reviewer_name': 'William',
#               'comments': 'Rachel and Valerie were outstanding hosts,  the apt '
#                           'was very clean and had all the essentials for a '
#                           'great stay.  They communicated super well and it '
#                           'was clear they cared about their guests with guides '
#                           'to the area and checking to make sure all was well '
#                           'during my stay.  I recommend without hesitation and '
#                           'I look forward to staying at W14th on my next visit '
#                           'to Manhattan.'},
#              {'listing_id': '35384734',
#               'review_id': '486169675847666312',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '415040358',
#               'reviewer_name': 'Apichai',
#               'comments': 'Thank you so much for allowing me to experience '
#                           'this lovely Chelsea apartment. This is one of the '
#                           'wonderful months in NYC.'},
#              {'listing_id': '35384734',
#               'review_id': '508004917148827747',
#               'date': datetime.datetime(2021, 12, 1, 0, 0),
#               'reviewer_id': '67125300',
#               'reviewer_name': 'Antonia',
#               'comments': "I had such a great Stay in Rachel's studio! The "
#                           'apartment is spacious and has everything one or two '
#                           'people could need. The bed is also SUPER '
#                           'comfortable. Good working appliances and when I '
#                           'arrived it was spotless. The location is so great '
#                           'if you are visiting New York or need an extended '
#                           'stay- very close to the subway to pop uptown and '
#                           'the L if you want to go across town or to Brooklyn. '
#                           'The building is very safe and I had no issues '
#                           'checking in, will definitely stay here again!'},
#              {'listing_id': '35384734',
#               'review_id': '594938588343889684',
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'reviewer_id': '145711962',
#               'reviewer_name': 'Janice',
#               'comments': 'I spent a month in this cozy studio apartment in a '
#                           'wonderful neighborhood close to several other '
#                           'wonderful neighborhoods.  Rachel is an extremely '
#                           'responsive and solicitous host who also gives you '
#                           'all the privacy you would want.  Check-in and '
#                           'check-out were easy and well-communicated, the '
#                           'building has an elevator and a laundry room, and is '
#                           'located on a street with several restaurants and '
#                           "delis.  (don't miss the Swedish bakery!)"},
#              {'listing_id': '35384734',
#               'review_id': '693442572829167031',
#               'date': datetime.datetime(2022, 8, 14, 0, 0),
#               'reviewer_id': '144908682',
#               'reviewer_name': 'Matt',
#               'comments': 'The apartment itself was everything it had been '
#                           'described to be, and Rachel was a wonderful host. '
#                           'Excellent communication, and Rachel was always on '
#                           'hand to help with any problems. The apartment had '
#                           'everything I needed and was in a terrific location. '
#                           'I stayed for three months and experienced no '
#                           'problems at all.'},
#              {'listing_id': '35384734',
#               'review_id': '750677361710556536',
#               'date': datetime.datetime(2022, 11, 1, 0, 0),
#               'reviewer_id': '458177032',
#               'reviewer_name': 'Tania',
#               'comments': 'The apartment is just as it looks in the pictures - '
#                           'clean, with lovely décor and very quiet.  You’re on '
#                           'the 4th floor of an elevator building and the '
#                           'building felt safe.  A very comfy bed, fantastic '
#                           'shower pressure and a laundry in the basement were '
#                           'wonderful to have.  The location is amazing, with '
#                           'Chelsea Market, the subway and lots of great '
#                           'restaurants and bars nearby.  Rachel was excellent '
#                           'to communicate with, she checked in with me before, '
#                           'during and after my stay.  Thank you again Rachel '
#                           'for a great stay!'},
#              {'listing_id': '35384734',
#               'review_id': '772456471531667427',
#               'date': datetime.datetime(2022, 12, 1, 0, 0),
#               'reviewer_id': '209794364',
#               'reviewer_name': 'Emilie',
#               'comments': 'Incredible month stay in the perfect NYC location. '
#                           'Apartment was exactly as advertised. Would '
#                           'definitely stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '903692436564101968',
#               'date': datetime.datetime(2023, 5, 31, 0, 0),
#               'reviewer_id': '40330705',
#               'reviewer_name': 'Jessica',
#               'comments': 'Rachel was a lovely host and her place was '
#                           'perfectly located and yet super quiet. The light is '
#                           'beautiful and the apartment had everything you’d '
#                           'need for a stay of any length.'},
#              {'listing_id': '35384734',
#               'review_id': '992851015788271855',
#               'date': datetime.datetime(2023, 10, 1, 0, 0),
#               'reviewer_id': '15140846',
#               'reviewer_name': 'Dan',
#               'comments': 'The location is seriously incredible - 60 seconds '
#                           'away from the 8th Ave station/bodegas/pizza/massage '
#                           'spa, 2 minutes to the High Line, and 6 minutes to '
#                           'the galleries in north Chelsea. Also, the block is '
#                           'surprisingly quiet and untrafficked during the '
#                           'week. The building is on the older side, but it has '
#                           "everything that you'll need, to include "
#                           'washer/dryer in the basement. Rachel is also very '
#                           'responsive. Would totally stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '728576635',
#               'date': datetime.datetime(2021, 2, 2, 0, 0),
#               'reviewer_id': '358506356',
#               'reviewer_name': 'Iryna',
#               'comments': 'Great place in a perfect location.'}]}

# %%
result = db.listings_with_reviews_and_cal.find({'id': { '$regex': '^3538473.*$'}})
print(len(list(result)))
# Out:
# 1

# %%
result = db.listings_with_reviews_and_cal.find({'id': { '$regex': '^35384...$'}})
print(len(list(result)))
# Out:
# 2

# %%
result = db.listings_with_reviews_and_cal.find({'id': { '$regex': '^35384...$'}})
for doc in result:
    pprint.pp(doc)
# Out:
# {'_id': ObjectId('664b9cf038b2bd10b476ac6b'),
#  'id': '35384123',
#  'name': 'Home in Queens · ★4.78 · 1 bedroom · 1 bed · 1 shared bath',
#  'host_id': '266360944',
#  'host_name': 'Olga',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Springfield Gardens',
#  'latitude': 40.6617,
#  'longitude': -73.76261,
#  'room_type': 'Private room',
#  'price': 70.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 96,
#  'last_review': datetime.datetime(2023, 9, 3, 0, 0),
#  'reviews_per_month': 1.7,
#  'calculated_host_listings_count': 1,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 17,
#  'license': '',
#  'reviews': [{'listing_id': '35384123',
#               'review_id': '957331027272749353',
#               'date': datetime.datetime(2023, 8, 13, 0, 0),
#               'reviewer_id': '130415543',
#               'reviewer_name': 'Rachel',
#               'comments': 'Great stay, flexible check in, easy to contact.'},
#              {'listing_id': '35384123',
#               'review_id': '424587480734838861',
#               'date': datetime.datetime(2021, 8, 8, 0, 0),
#               'reviewer_id': '340541040',
#               'reviewer_name': 'Hunter Alexis',
#               'comments': 'Amazing space & experience! Olga is wonderful!'},
#              {'listing_id': '35384123',
#               'review_id': '657926046042331420',
#               'date': datetime.datetime(2022, 6, 26, 0, 0),
#               'reviewer_id': '148651165',
#               'reviewer_name': 'Joseph',
#               'comments': 'Nice stay.  As advertised.  Olga was a great host.'},
#              {'listing_id': '35384123',
#               'review_id': '902210745280786905',
#               'date': datetime.datetime(2023, 5, 29, 0, 0),
#               'reviewer_id': '507908996',
#               'reviewer_name': 'Mohammad',
#               'comments': 'olga is the best host and a great host, a friendly '
#                           'senior, and provides the best advice. sure i will '
#                           'stay here again oncenin new york.'},
#              {'listing_id': '35384123',
#               'review_id': '399190608983206750',
#               'date': datetime.datetime(2021, 7, 4, 0, 0),
#               'reviewer_id': '25262581',
#               'reviewer_name': 'Patrick',
#               'comments': "Great stay in Queens. Ms. Olga's place is quiet,  "
#                           'immaculate and the bed is comfortable. She was a '
#                           'great host, and the nicest person. The bedroom had '
#                           'a stocked mini fridge and Keurig coffee machine.'},
#              {'listing_id': '35384123',
#               'review_id': '668778260459292674',
#               'date': datetime.datetime(2022, 7, 11, 0, 0),
#               'reviewer_id': '136586493',
#               'reviewer_name': 'Heidi',
#               'comments': 'Olga’s home is so wonderful! A beautiful garden, '
#                           'and Olga is so welcoming- it feels like coming '
#                           'home.'},
#              {'listing_id': '35384123',
#               'review_id': '718845023420052626',
#               'date': datetime.datetime(2022, 9, 18, 0, 0),
#               'reviewer_id': '259581883',
#               'reviewer_name': 'Luigi',
#               'comments': 'Ma’am Olga to was perfect, his hospitality and his '
#                           'generosity was there, despite my not very correct '
#                           'English I was able to make myself understood I '
#                           'recommend this apartment and ma’am Olga . '
#                           '☺️💖💯<br/>- The Queen is a beautiful place, I really '
#                           'liked the people and the city 💯💖🌳'},
#              {'listing_id': '35384123',
#               'review_id': '972481275552143355',
#               'date': datetime.datetime(2023, 9, 3, 0, 0),
#               'reviewer_id': '530489110',
#               'reviewer_name': 'Amir',
#               'comments': "It's good to stay at Olga's place.If I come again I "
#                           "will choose this place to stay again.And it's also "
#                           'near to JFK airport.'},
#              {'listing_id': '35384123',
#               'review_id': '737697715566999802',
#               'date': datetime.datetime(2022, 10, 14, 0, 0),
#               'reviewer_id': '461871082',
#               'reviewer_name': 'Richard',
#               'comments': 'Comfortable clean room and bathroom with clean '
#                           'towels. Communication was good. Very close to the '
#                           'airport. Olga made me feel at ease. I Would stay '
#                           'again.'},
#              {'listing_id': '35384123',
#               'review_id': '530391860',
#               'date': datetime.datetime(2019, 9, 15, 0, 0),
#               'reviewer_id': '75392017',
#               'reviewer_name': 'Johan',
#               'comments': 'Such a wonderful place to stay'},
#              {'listing_id': '35384123',
#               'review_id': '565175164',
#               'date': datetime.datetime(2019, 11, 17, 0, 0),
#               'reviewer_id': '303045746',
#               'reviewer_name': 'Yant07',
#               'comments': 'Perfect place. Will come back again. :)'},
#              {'listing_id': '35384123',
#               'review_id': '407183689974469463',
#               'date': datetime.datetime(2021, 7, 15, 0, 0),
#               'reviewer_id': '409264075',
#               'reviewer_name': 'Kafilet',
#               'comments': 'The place is very clean, close to JFK airport'},
#              {'listing_id': '35384123',
#               'review_id': '522492058',
#               'date': datetime.datetime(2019, 9, 2, 0, 0),
#               'reviewer_id': '55130264',
#               'reviewer_name': 'Gao',
#               'comments': '房东人很好，热情实在'},
#              {'listing_id': '35384123',
#               'review_id': '552353948',
#               'date': datetime.datetime(2019, 10, 21, 0, 0),
#               'reviewer_id': '292216929',
#               'reviewer_name': 'Andre',
#               'comments': 'Wonderful Host. Very clean and neat bedroom and '
#                           'bathroom. Close to public transportation.  She has '
#                           'a small dog fyi. Good stay for the price. Close to '
#                           'airport.'},
#              {'listing_id': '35384123',
#               'review_id': '576025686',
#               'date': datetime.datetime(2019, 12, 12, 0, 0),
#               'reviewer_id': '174767019',
#               'reviewer_name': 'Sy',
#               'comments': 'Olga is wonderful. Her house is pretty and clean. I '
#                           'had my own bathroom outside the bedroom. The '
#                           'bathroom was clean and the bedroom was comfortable. '
#                           'There are neighbors living upstairs so there was '
#                           'some noise in the evening but that was fine. Olga '
#                           'cooked breakfast for me and it was delicious. '
#                           '<br/>The place is close to the airport and it is '
#                           'easy to get an uber at noon.'},
#              {'listing_id': '35384123',
#               'review_id': '529631261894923145',
#               'date': datetime.datetime(2021, 12, 31, 0, 0),
#               'reviewer_id': '435666305',
#               'reviewer_name': 'Hongjia',
#               'comments': 'Great host!'},
#              {'listing_id': '35384123',
#               'review_id': '631907218234698849',
#               'date': datetime.datetime(2022, 5, 21, 0, 0),
#               'reviewer_id': '76200315',
#               'reviewer_name': 'Gemma',
#               'comments': 'Sweet host. Really comfy bed. Very helpful family.'},
#              {'listing_id': '35384123',
#               'review_id': '632555177311625218',
#               'date': datetime.datetime(2022, 5, 22, 0, 0),
#               'reviewer_id': '156939973',
#               'reviewer_name': 'Yash',
#               'comments': 'Really good stay. I just wish there was a window in '
#                           'the room'},
#              {'listing_id': '35384123',
#               'review_id': '647779990578636801',
#               'date': datetime.datetime(2022, 6, 12, 0, 0),
#               'reviewer_id': '193819086',
#               'reviewer_name': 'Samanvitha',
#               'comments': 'Olga has a lovely place with a flowery and '
#                           'decorative front yard and a backyard where she '
#                           'grows her own food. Plus Rocky is a very sweet dog '
#                           'and loves to make friends. Overall it was a really '
#                           'good stay.'},
#              {'listing_id': '35384123',
#               'review_id': '729752721136798499',
#               'date': datetime.datetime(2022, 10, 3, 0, 0),
#               'reviewer_id': '481624615',
#               'reviewer_name': 'Fatih',
#               'comments': 'Okay'},
#              {'listing_id': '35384123',
#               'review_id': '605046504835022256',
#               'date': datetime.datetime(2022, 4, 14, 0, 0),
#               'reviewer_id': '252109854',
#               'reviewer_name': 'Dan',
#               'comments': 'Warm and welcoming, Olga made my daughter feel at '
#                           'home while overnighting at JFK.'},
#              {'listing_id': '35384123',
#               'review_id': '897858163191728829',
#               'date': datetime.datetime(2023, 5, 23, 0, 0),
#               'reviewer_id': '397401508',
#               'reviewer_name': 'Meihui',
#               'comments': 'Olga’s place is exactly as described and is near '
#                           'the JFK airport. Olga is very friendly and has a '
#                           'lovely garden.'},
#              {'listing_id': '35384123',
#               'review_id': '650748856579087197',
#               'date': datetime.datetime(2022, 6, 16, 0, 0),
#               'reviewer_id': '6969190',
#               'reviewer_name': 'Theresa',
#               'comments': 'Room and bathroom are small but clean, and bed '
#                           'comfortable.'},
#              {'listing_id': '35384123',
#               'review_id': '616628707100758982',
#               'date': datetime.datetime(2022, 4, 30, 0, 0),
#               'reviewer_id': '327391589',
#               'reviewer_name': 'Mina',
#               'comments': 'awesome'},
#              {'listing_id': '35384123',
#               'review_id': '510816981337267495',
#               'date': datetime.datetime(2021, 12, 5, 0, 0),
#               'reviewer_id': '161519900',
#               'reviewer_name': 'Govinda Rajulu',
#               'comments': 'Very friendly'},
#              {'listing_id': '35384123',
#               'review_id': '519557901774150869',
#               'date': datetime.datetime(2021, 12, 17, 0, 0),
#               'reviewer_id': '401365',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Great location for an overnight to JFK, and Olga '
#                           'was a sweetheart!'},
#              {'listing_id': '35384123',
#               'review_id': '673219200558182958',
#               'date': datetime.datetime(2022, 7, 17, 0, 0),
#               'reviewer_id': '84020315',
#               'reviewer_name': 'Kira',
#               'comments': 'Excellent place to stay, I would highly recommend!'},
#              {'listing_id': '35384123',
#               'review_id': '921086709694683068',
#               'date': datetime.datetime(2023, 6, 24, 0, 0),
#               'reviewer_id': '94960278',
#               'reviewer_name': 'Muhammad',
#               'comments': "Loved the garden. It's a nice place."},
#              {'listing_id': '35384123',
#               'review_id': '947183612996141435',
#               'date': datetime.datetime(2023, 7, 30, 0, 0),
#               'reviewer_id': '473885578',
#               'reviewer_name': 'Lihua',
#               'comments': 'very good'},
#              {'listing_id': '35384123',
#               'review_id': '403536177063797398',
#               'date': datetime.datetime(2021, 7, 10, 0, 0),
#               'reviewer_id': '409264075',
#               'reviewer_name': 'Kafilet',
#               'comments': 'Close to JFK airport, availability of public '
#                           'transportation and close to shopping mall.'},
#              {'listing_id': '35384123',
#               'review_id': '667420568637742951',
#               'date': datetime.datetime(2022, 7, 9, 0, 0),
#               'reviewer_id': '95777781',
#               'reviewer_name': 'Morgan',
#               'comments': 'Olga was great - very helpful. Cute little room '
#                           'with an en-suite!'},
#              {'listing_id': '35384123',
#               'review_id': '470846731',
#               'date': datetime.datetime(2019, 6, 16, 0, 0),
#               'reviewer_id': '12952513',
#               'reviewer_name': 'Wendy',
#               'comments': 'I was the first guest at Olga and her mom’s Airbnb. '
#                           'A very sweet encounter! All accommodations are '
#                           'clean and fresh. Newly renovated bathroom is '
#                           'fantastic—really loved the mirror effect. Breakfast '
#                           'and coffee was offered. Mom’s garden is '
#                           'amazing!!!!! They have really gone above and beyond '
#                           'to provide the extras.'},
#              {'listing_id': '35384123',
#               'review_id': '485320662',
#               'date': datetime.datetime(2019, 7, 10, 0, 0),
#               'reviewer_id': '119503554',
#               'reviewer_name': '智仁',
#               'comments': 'I had a great experience when I stayed Olga’s '
#                           'home.He gave me many assistance and the location '
#                           'was near airport.'},
#              {'listing_id': '35384123',
#               'review_id': '488000257',
#               'date': datetime.datetime(2019, 7, 14, 0, 0),
#               'reviewer_id': '105238284',
#               'reviewer_name': 'Jialin',
#               'comments': 'Olga和Kayla给了我很多惊喜，Kayla还给了我很多出行建议，纽约西区大停电被我赶上，Olga和Kayla等到我很晚，非常感动。住在这里就是，舒适，安心，便捷，希望很快再回来。谢谢！'},
#              {'listing_id': '35384123',
#               'review_id': '502523300',
#               'date': datetime.datetime(2019, 8, 4, 0, 0),
#               'reviewer_id': '19303392',
#               'reviewer_name': 'Antonia',
#               'comments': 'Perfect place if you’re traveling from or to JFK. '
#                           'Besides, Olga was an awesome host, very friendly '
#                           'and helpful. I’ll come back again and hopefully I '
#                           'will have some time to enjoy NYC too. Thanks.'},
#              {'listing_id': '35384123',
#               'review_id': '518967078',
#               'date': datetime.datetime(2019, 8, 27, 0, 0),
#               'reviewer_id': '75092683',
#               'reviewer_name': 'Pavan',
#               'comments': 'Lovely stay and great host!'},
#              {'listing_id': '35384123',
#               'review_id': '523461165',
#               'date': datetime.datetime(2019, 9, 3, 0, 0),
#               'reviewer_id': '71148061',
#               'reviewer_name': 'Nick',
#               'comments': 'Olga a été une hôte très agréable et serviable '
#                           '(discussion autour du thé le matin et '
#                           'accompagnement "personnalisé" (en voiture à la gare '
#                           'avec Rocky^^)<br/>Un quartier très agréable de jour '
#                           'mais un peu hostile de nuit pour deux '
#                           'Frenchies...<br/>Mais Olga sera là pour vous '
#                           'accueillir, vous conseiller et vous faire visiter '
#                           'son fabuleux jardin!'},
#              {'listing_id': '35384123',
#               'review_id': '524290456',
#               'date': datetime.datetime(2019, 9, 5, 0, 0),
#               'reviewer_id': '99010760',
#               'reviewer_name': 'Jessica',
#               'comments': 'Olga is super nice. I arrived late (12:00am) during '
#                           'midnight to check in and she’s still waiting for '
#                           'me. The room is very clean and quiet, except a '
#                           'little hot (I guess it’s due to summer time). Easy '
#                           'to communicate, quiet room and good location close '
#                           'to JFK. Will come back next time if get the '
#                           'chance!'},
#              {'listing_id': '35384123',
#               'review_id': '526920811',
#               'date': datetime.datetime(2019, 9, 9, 0, 0),
#               'reviewer_id': '6949933',
#               'reviewer_name': 'Marco',
#               'comments': 'Friendly host, close to JFK airport, clean place - '
#                           'good for short term stay.'},
#              {'listing_id': '35384123',
#               'review_id': '529247506',
#               'date': datetime.datetime(2019, 9, 14, 0, 0),
#               'reviewer_id': '201460778',
#               'reviewer_name': 'Niki',
#               'comments': 'Olga is a friendly landlord.She helps me a lot .The '
#                           'bathroom is really pretty.'},
#              {'listing_id': '35384123',
#               'review_id': '530919770',
#               'date': datetime.datetime(2019, 9, 16, 0, 0),
#               'reviewer_id': '96599064',
#               'reviewer_name': 'Christine',
#               'comments': 'Great location, very clean and a great host!'},
#              {'listing_id': '35384123',
#               'review_id': '535973677',
#               'date': datetime.datetime(2019, 9, 25, 0, 0),
#               'reviewer_id': '259418614',
#               'reviewer_name': 'Lan',
#               'comments': 'Sooo awesome!Everything is what I want.And Olga is '
#                           "super nice,she's friendly and really good at "
#                           'cooking.She made me feel at home.And Rocky is a '
#                           'really cute dog.Oh I miss them so much, I hope to '
#                           'see them again'},
#              {'listing_id': '35384123',
#               'review_id': '537386544',
#               'date': datetime.datetime(2019, 9, 28, 0, 0),
#               'reviewer_id': '3371022',
#               'reviewer_name': 'Angelina',
#               'comments': "Olga's home exudes warmth. She is warm and very "
#                           'hospitable. The snacks, water n coffee in the room '
#                           'was much appreciated. THANK YOU Olga!!!'},
#              {'listing_id': '35384123',
#               'review_id': '539087919',
#               'date': datetime.datetime(2019, 9, 30, 0, 0),
#               'reviewer_id': '75092683',
#               'reviewer_name': 'Pavan',
#               'comments': 'Second time staying here. Great experience as '
#                           'always!'},
#              {'listing_id': '35384123',
#               'review_id': '545613564',
#               'date': datetime.datetime(2019, 10, 12, 0, 0),
#               'reviewer_id': '58289518',
#               'reviewer_name': 'Sadiyya',
#               'comments': 'Its a good place to crash for the night close to '
#                           'the airport.  Olga is warm and welcoming. The place '
#                           'was comfortable, clean and pleasant. Just ensure '
#                           'that you arrive earlier since its not easy to '
#                           'locate at night. Also make sure that you have a '
#                           'cell so that if she does not hear the door you can '
#                           'call her.'},
#              {'listing_id': '35384123',
#               'review_id': '558961490',
#               'date': datetime.datetime(2019, 11, 3, 0, 0),
#               'reviewer_id': '42895907',
#               'reviewer_name': 'Johnny',
#               'comments': 'Ogla is a wonderful person who keeps a beautiful '
#                           'home in a wonderful place. My experience was almost '
#                           'too good for what i deserve. After travelling for '
#                           "24hours i can't describe how much peace of mind i "
#                           'had landing at her place. I was 2 hours late but '
#                           "she was very forgiving. Couldn't ask for more."},
#              {'listing_id': '35384123',
#               'review_id': '428735039789826654',
#               'date': datetime.datetime(2021, 8, 14, 0, 0),
#               'reviewer_id': '195068795',
#               'reviewer_name': '佳威',
#               'comments': 'It’s really a nice living experience. I love the '
#                           'beautiful yard and cute dog. The environment is '
#                           'very quiet. It’s a good place to have a rest.'},
#              {'listing_id': '35384123',
#               'review_id': '454286010563660598',
#               'date': datetime.datetime(2021, 9, 18, 0, 0),
#               'reviewer_id': '412149805',
#               'reviewer_name': 'Poonchanok',
#               'comments': 'Olga’s home very nice. Everything good and clean. I '
#                           'love this house and close JFK too'},
#              {'listing_id': '35384123',
#               'review_id': '423806326699313071',
#               'date': datetime.datetime(2021, 8, 7, 0, 0),
#               'reviewer_id': '217085399',
#               'reviewer_name': 'Phil',
#               'comments': 'Host is very friendly and accommodating. I arrived '
#                           'late because of flight and ground transportation '
#                           'issues. Got in at 10:30pm and she was very '
#                           'understanding. Was nice to have a fridge and '
#                           'microwave in the room. Snacks and drinks provided. '
#                           'Only issue was climate control. If you like it '
#                           'cool, you may have an issue with it being too hot. '
#                           'I stayed during the middle of summer and it was 80 '
#                           'degrees in the house. I asked to cool it down and '
#                           'air was on for 5 minutes and then off the rest of '
#                           'the night. Wasn’t able to sleep until 1am and then '
#                           'woke up sweating. I turned the air on myself when I '
#                           'got you so that I wouldn’t be sweaty out of the '
#                           'shower. So I guess you can control the thermostat '
#                           'yourself.'},
#              {'listing_id': '35384123',
#               'review_id': '414371609537896831',
#               'date': datetime.datetime(2021, 7, 25, 0, 0),
#               'reviewer_id': '215403896',
#               'reviewer_name': 'Tim',
#               'comments': 'Great stay at Olga’s place.  She responds very '
#                           'quickly.  The room was clean and neat.  Mini fridge '
#                           'with water and drinks, kureg with coffee, and light '
#                           'snacks.  Quiet room.  It was slightly warm, but '
#                           'there is a nice fan that did the trick.  If you’re '
#                           'tall, watch the bathroom light.  Olga cooked '
#                           'breakfast in the morning which was a wonderful '
#                           'touch!   We had pleasant conversation and I’d '
#                           'definitely stay again!'},
#              {'listing_id': '35384123',
#               'review_id': '419487602897195469',
#               'date': datetime.datetime(2021, 8, 1, 0, 0),
#               'reviewer_id': '415739581',
#               'reviewer_name': 'Mischka',
#               'comments': 'Olga your place was amazing, the snacks, the '
#                           'callaloo for breakfast, the room I  slept in your '
#                           'garden our conversations were amazing! And I will '
#                           'be recommending you to friends who need somewhere '
#                           'to stay!'},
#              {'listing_id': '35384123',
#               'review_id': '455039368760816531',
#               'date': datetime.datetime(2021, 9, 19, 0, 0),
#               'reviewer_id': '122156408',
#               'reviewer_name': 'Natthakarn',
#               'comments': "Such a great stay. Olga's mom was so kind to let me "
#                           'check in early.<br/>The room and bathroom were '
#                           'sparking clean. The room was equipped with a '
#                           'fridge, microwave and lots of snacks! The bed was '
#                           "so comfy. Olga's mom was so sweet, she offered me a "
#                           'meal before I checked out. Also, walked me to the '
#                           'bus stop.<br/>I wanna give more than 5 stars to '
#                           'this place!'},
#              {'listing_id': '35384123',
#               'review_id': '460089905586739525',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '284584840',
#               'reviewer_name': 'Yuna',
#               'comments': 'Olga’s home was beautiful and had a nice ambience. '
#                           'The guest room was stocked with a mini-fridge and '
#                           'plenty of snacks/drinks. At the time I visited, the '
#                           'guest bathroom was private and conveniently located '
#                           'right across the hall. Olga and her family were '
#                           'super friendly and helpful. Very much enjoyed my '
#                           'stay.'},
#              {'listing_id': '35384123',
#               'review_id': '525324485833096698',
#               'date': datetime.datetime(2021, 12, 25, 0, 0),
#               'reviewer_id': '76642144',
#               'reviewer_name': 'Lorien',
#               'comments': 'Olga was quick in her responses, she was very '
#                           'welcoming, kind, and hospitable! <br/>It was about '
#                           'a 12 minute Uber ride from JFK airport to the '
#                           'Airbnb, which was very convenient.'},
#              {'listing_id': '35384123',
#               'review_id': '530355522883589011',
#               'date': datetime.datetime(2022, 1, 1, 0, 0),
#               'reviewer_id': '239574046',
#               'reviewer_name': 'Andreas',
#               'comments': "It's a place where Olga welcomes you. A strong, "
#                           'inspirational, and good character who contributed '
#                           'all her life to make this place a beautiful and '
#                           "cozy one. I'll never forget"},
#              {'listing_id': '35384123',
#               'review_id': '586138729118363444',
#               'date': datetime.datetime(2022, 3, 19, 0, 0),
#               'reviewer_id': '4264517',
#               'reviewer_name': 'Carolyn',
#               'comments': 'Beautiful place, very comfortable!'},
#              {'listing_id': '35384123',
#               'review_id': '594199273512271114',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '228777935',
#               'reviewer_name': 'Cera',
#               'comments': 'Olga is a wonderful host ever. She treated me more '
#                           'than a guest, she treated me like her children live '
#                           'in the house 😆😆. And the room is amazing. It’s '
#                           'clean and have everything inside (big bed, '
#                           'refrigerator, microwave and bathroom) and a small '
#                           'bar with full of snacks. If you looking for a place '
#                           'to stay in New York I recommend you Olga house. You '
#                           'will never regret😁😁.'},
#              {'listing_id': '35384123',
#               'review_id': '602855672577755669',
#               'date': datetime.datetime(2022, 4, 11, 0, 0),
#               'reviewer_id': '229668492',
#               'reviewer_name': 'Austin',
#               'comments': 'Great place at a great location.'},
#              {'listing_id': '35384123',
#               'review_id': '607183742019978254',
#               'date': datetime.datetime(2022, 4, 17, 0, 0),
#               'reviewer_id': '69196569',
#               'reviewer_name': 'Jay',
#               'comments': 'Quick stay after a late flight and an early report '
#                           'time at JFK. The room had everything I needed…I '
#                           'honestly felt like I was staying at my grandma’s '
#                           'house in the best way. <br/>Just wish this room had '
#                           'a fan…I run warm when I sleep. <br/>Bathroom was '
#                           'right across the hall and didn’t have to share with '
#                           'anyone. <br/>Got a late start, so had to catch an '
#                           'Uber, but Ms. Olga offered to walk me down to the '
#                           'bus stop that takes you to the airport. I’ll '
#                           'certainly do that next time I stay there. '
#                           '<br/>Loved the fresh flowers in the room too.'},
#              {'listing_id': '35384123',
#               'review_id': '611556489157223265',
#               'date': datetime.datetime(2022, 4, 23, 0, 0),
#               'reviewer_id': '18887106',
#               'reviewer_name': 'Pierre-Yves',
#               'comments': 'Thank you very much. I was able to rest well and '
#                           'thank you to William for walking with me to the bus '
#                           'stop. Ot was definitely very easy and fast to get '
#                           'to Jfk airport . Your place was perfectly clean and '
#                           'comfy. It was a perfect experience.'},
#              {'listing_id': '35384123',
#               'review_id': '663696381234121600',
#               'date': datetime.datetime(2022, 7, 4, 0, 0),
#               'reviewer_id': '209443994',
#               'reviewer_name': 'Thomas',
#               'comments': 'It might’ve been a nice place but I will never '
#                           'know. When I showed up at the exact time I was '
#                           'supposed to the gates were locked I wrote the owner '
#                           'and nobody ever showed up. It was terribly '
#                           'frustrating. This is the first time this happened '
#                           'to me at Airbnb. Airbnb gave this owner an '
#                           'excellent rating. I don’t know if what happened to '
#                           'me is the exception or the rule. Is now the next '
#                           'day and I still haven’t received a refund. Happens '
#                           'again I will give Airbnb a terrible rating'},
#              {'listing_id': '35384123',
#               'review_id': '612293449867757744',
#               'date': datetime.datetime(2022, 4, 24, 0, 0),
#               'reviewer_id': '53538723',
#               'reviewer_name': 'Elaine',
#               'comments': 'Olga is extremely welcoming and very hospitable. My '
#                           'flight was delayed and luggage lost they stayed up '
#                           'late to let me check in and her son kindly ran me '
#                           'to the store to get some clothes . Fab bedding and '
#                           'a very comfy bed . Tea/coffee and snacks available '
#                           'and drinks in the fridge . olga even offered me '
#                           "breakfast in the morning . It's literally around "
#                           'the corner from the local bus stop which took me to '
#                           "the train for central park ,my stay wasn't long but "
#                           "was a great one . I will be back when I'm next in "
#                           'new York . Hopefully with a gift for my new found '
#                           'friend Rocky her gorgeous friendly pooch'},
#              {'listing_id': '35384123',
#               'review_id': '627552705526356354',
#               'date': datetime.datetime(2022, 5, 15, 0, 0),
#               'reviewer_id': '104950455',
#               'reviewer_name': 'Windship',
#               'comments': "Olga is very authentic and she's one of a kind. I "
#                           'was travelling and had to catch up on a lot of '
#                           'sleep, otherwise I would have enjoyed spending more '
#                           "time with her, well, she's pretty active so it "
#                           'might not be possible for her either. The room '
#                           'downstairs is very compact and good for sleeping '
#                           'in. The room upstairs has natural light but less '
#                           "privacy, so it depends on your taste when she's "
#                           'renting both ...'},
#              {'listing_id': '35384123',
#               'review_id': '639785957804245081',
#               'date': datetime.datetime(2022, 6, 1, 0, 0),
#               'reviewer_id': '199552339',
#               'reviewer_name': 'Hannah',
#               'comments': 'Olga was a very responsive host. The room was very '
#                           'cozy and stocked with snacks and drinks. Both the '
#                           'room and bathroom were very clean.'},
#              {'listing_id': '35384123',
#               'review_id': '641940367076686150',
#               'date': datetime.datetime(2022, 6, 4, 0, 0),
#               'reviewer_id': '130743091',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Olga foi uma anfitriã perfeita ! recebeu nosso '
#                           'filho com muito carinho , super atenciosa é uma '
#                           'querida ! Recomendamos de todo o coração . somos '
#                           'gratos pela recepção dela.'},
#              {'listing_id': '35384123',
#               'review_id': '647038366234352163',
#               'date': datetime.datetime(2022, 6, 11, 0, 0),
#               'reviewer_id': '263058024',
#               'reviewer_name': 'Sabrina',
#               'comments': 'Very comfortable stay! It looks like you thought of '
#                           'it everything someone could need. Clean and '
#                           'beautiful place. Thank you! 🌺'},
#              {'listing_id': '35384123',
#               'review_id': '652881261193897259',
#               'date': datetime.datetime(2022, 6, 19, 0, 0),
#               'reviewer_id': '9523283',
#               'reviewer_name': 'Hillary',
#               'comments': 'Olga was the perfect host. Five stars all around. '
#                           'her place was clean, the snacks were stocked,  the '
#                           'room was cool. Toiletries are provided. I fell in '
#                           'love with Rocky her poodle and you will too. Had  a '
#                           'great sound sleep before an early AM departure to '
#                           "JFK. Can't emphasize enough how plentiful snacks "
#                           'were. A quiet and sound sleep was had and I must '
#                           "say this might be the best short stay I've ever had "
#                           'in an airbnb. Will be back. again.'},
#              {'listing_id': '35384123',
#               'review_id': '657192249024778326',
#               'date': datetime.datetime(2022, 6, 25, 0, 0),
#               'reviewer_id': '37795419',
#               'reviewer_name': 'Karmen',
#               'comments': 'I enjoyed my stay at Olga’s place very much! She '
#                           'was hospitable and generous. She grows beautiful '
#                           'gardens. The room was nice and the bed was super '
#                           'comfortable. She keeps snacks and beverages for her '
#                           'guests and keeps in touch. She’s great!'},
#              {'listing_id': '35384123',
#               'review_id': '662971079738764939',
#               'date': datetime.datetime(2022, 7, 3, 0, 0),
#               'reviewer_id': '82066137',
#               'reviewer_name': 'Olivia',
#               'comments': 'Olga is just wonderful. Rare to see these kind of '
#                           'kindness and warm hospitality these days. So '
#                           "thankful! It's perfect for those who need to be "
#                           'close to the JFK airport. The room/ bathroom is '
#                           'spotless. Thank you again!'},
#              {'listing_id': '35384123',
#               'review_id': '744160812716828173',
#               'date': datetime.datetime(2022, 10, 23, 0, 0),
#               'reviewer_id': '41770077',
#               'reviewer_name': 'Lorcan',
#               'comments': 'If you like clutter and lots of stuff everywhere '
#                           'this is the place for you! Crap everywhere I mean '
#                           'everywhere even in the room you rent. No space for '
#                           'any of your stuff. Same in bathroom.'},
#              {'listing_id': '35384123',
#               'review_id': '671663899249558498',
#               'date': datetime.datetime(2022, 7, 15, 0, 0),
#               'reviewer_id': '136586493',
#               'reviewer_name': 'Heidi',
#               'comments': 'My second time staying at Olga’s, because she is '
#                           'just the best! Fridge full of nice cold beverages, '
#                           'snacks, a lovely space of my own downstairs, plus a '
#                           'beautiful garden. Olga is amazing- so generous and '
#                           'welcoming, and made me feel relaxed and at home. '
#                           'Plus Rocky the poodle is the best buddy! I spent '
#                           'lovely evenings chatting with Olga in her garden, '
#                           'and it was a soothing home to return to after the '
#                           'bustle of Brooklyn. Can’t recommend enough!'},
#              {'listing_id': '35384123',
#               'review_id': '674560361288735909',
#               'date': datetime.datetime(2022, 7, 19, 0, 0),
#               'reviewer_id': '154955758',
#               'reviewer_name': 'Erin',
#               'comments': 'Overall, this was a great place to get a night’s '
#                           'sleep before an early departure from JFK. Olga was '
#                           'very friendly and accommodating and it was a quick '
#                           'ride to the airport. I did stay in a different room '
#                           'and had a different bathroom than the pictures in '
#                           'the listing show. It worked fine, but it wasn’t '
#                           'exactly what I expected. The door to my room did '
#                           'not latch or lock so I placed a trash can in front '
#                           'of it to keep it from opening. I felt safe in their '
#                           'house regardless, but a little more security would '
#                           'have been nice as a solo traveler. Overall I had a '
#                           'good experience and Olga keeps plenty of snacks and '
#                           'drinks stocked in the room.'},
#              {'listing_id': '35384123',
#               'review_id': '676764888021491892',
#               'date': datetime.datetime(2022, 7, 22, 0, 0),
#               'reviewer_id': '46781420',
#               'reviewer_name': 'Isabelle',
#               'comments': 'Le logement est parfait , très propre et dans un '
#                           'quartier très calme . Olga est extrêmement gentille '
#                           ', merci Olga pour toutes tes gentilles attentions'},
#              {'listing_id': '35384123',
#               'review_id': '682643510071339601',
#               'date': datetime.datetime(2022, 7, 30, 0, 0),
#               'reviewer_id': '206477359',
#               'reviewer_name': 'Eymeric',
#               'comments': 'Super séjour, Olga m’a accompagné jusqu’à l’arrêt '
#                           'de bus le lendemain'},
#              {'listing_id': '35384123',
#               'review_id': '699248698456639422',
#               'date': datetime.datetime(2022, 8, 22, 0, 0),
#               'reviewer_id': '129358315',
#               'reviewer_name': 'Matt',
#               'comments': 'A nice little room to stay in, no natural light but '
#                           'many chickens roaming the front yard which is '
#                           'always a bonus.'},
#              {'listing_id': '35384123',
#               'review_id': '716619924395125325',
#               'date': datetime.datetime(2022, 9, 15, 0, 0),
#               'reviewer_id': '7632976',
#               'reviewer_name': 'Jessica',
#               'comments': 'Olga is a gracious host, however being woken up '
#                           'early by her knocking on the door hours before '
#                           'checkout (on my one day to sleep in) wasn’t ideal! '
#                           '<br/>A good place to stay if you need a quick ride '
#                           'to the airport. The bathroom is also spectacular'},
#              {'listing_id': '35384123',
#               'review_id': '720293876423208822',
#               'date': datetime.datetime(2022, 9, 20, 0, 0),
#               'reviewer_id': '472907974',
#               'reviewer_name': 'Kullanid',
#               'comments': 'Olga is very kind.  Rocky is also cute ! The house '
#                           'is very very clean and quiet.  She made breakfast '
#                           'and dinner for me too ( it’s very yummy & not '
#                           'spicy) She look like a mother or an adult relative! '
#                           'loves to take care of the children! <br/>Good host '
#                           'and location!'},
#              {'listing_id': '35384123',
#               'review_id': '724672876123711498',
#               'date': datetime.datetime(2022, 9, 26, 0, 0),
#               'reviewer_id': '426362487',
#               'reviewer_name': 'Regina',
#               'comments': 'i stayed in a different room than the listing '
#                           'showed BUT it was more private. I had a small, but '
#                           'private bathroom as well as my own entrance. it has '
#                           'a fridge and microwave. she provided me with '
#                           'towels, soap, shampoo and conditioner as well as '
#                           'covid tests, masks and cleaning wipes. it’s close '
#                           'to the Q111 which is what i needed to get to queens '
#                           'and Manhattan. Communication was great and Olga '
#                           'allowed to check in early because it was pouring. '
#                           'if i ever go back to that area i will definitely be '
#                           'booking with her again. she has a cute little dog '
#                           'and chickens in the front. loved it a lot.'},
#              {'listing_id': '35384123',
#               'review_id': '880502715311929846',
#               'date': datetime.datetime(2023, 4, 29, 0, 0),
#               'reviewer_id': '416380423',
#               'reviewer_name': 'Clay',
#               'comments': 'What a wonderful place to stay near JFK. Ask Olga '
#                           'how you can actually walk! There are a lot of '
#                           'similar listings, but I highly recommend that you '
#                           'pick this one. You won’t find a kinder and more '
#                           'thoughtful host on Airbnb!'},
#              {'listing_id': '35384123',
#               'review_id': '896381729489882502',
#               'date': datetime.datetime(2023, 5, 21, 0, 0),
#               'reviewer_id': '287369395',
#               'reviewer_name': 'Zoombie',
#               'comments': 'Olga is a very kind and warm-hearted host. the room '
#                           'is a little bit small but it include all you need. '
#                           'And consider the price, I highly recommend this '
#                           'place for people want to stay for one night to '
#                           'catch on the flight.'},
#              {'listing_id': '35384123',
#               'review_id': '901492727487712461',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '241979204',
#               'reviewer_name': 'Lotus',
#               'comments': "Olga's garden is very pretty, and the house is in a "
#                           'very convenient location for a short stay near '
#                           'JFK.'},
#              {'listing_id': '35384123',
#               'review_id': '921788148664871622',
#               'date': datetime.datetime(2023, 6, 25, 0, 0),
#               'reviewer_id': '10678350',
#               'reviewer_name': 'Ken',
#               'comments': 'Had an amazing stay, unfortunately only one night '
#                           'but would definitely come back when I’m in the '
#                           'city! <br/>Olga was always super responsive and '
#                           'made me feel so welcome from the start! Actually '
#                           'got my own little place with own bathroom which I’m '
#                           'grateful for! Crisp linnen, super soft towels, '
#                           'snacks and fridge with cold water, everything I '
#                           'needed and more! Also super wel located at walking '
#                           'distance from JFK! Thanks Olga!'},
#              {'listing_id': '35384123',
#               'review_id': '941284267080705385',
#               'date': datetime.datetime(2023, 7, 22, 0, 0),
#               'reviewer_id': '442950410',
#               'reviewer_name': 'Adam',
#               'comments': 'The room was beautiful. There were snacks for me '
#                           'and drinks in the refrigerator. The shower was the '
#                           "best I've ever used in an Airbnb."},
#              {'listing_id': '35384123',
#               'review_id': '944236371850571875',
#               'date': datetime.datetime(2023, 7, 26, 0, 0),
#               'reviewer_id': '526236992',
#               'reviewer_name': 'Miranda',
#               'comments': '对于夜里需要坐飞机的我来说，这个房间很适合。它离机场很近，开车10分钟就可以到。房间很干净，还准备了零食，很好吃。房主非常友善，乐于助人，给我提供了很多帮助，非常感谢！'},
#              {'listing_id': '35384123',
#               'review_id': '964513657930896094',
#               'date': datetime.datetime(2023, 8, 23, 0, 0),
#               'reviewer_id': '332139627',
#               'reviewer_name': 'Shibu',
#               'comments': "Ma'am Olga is a very  nice person , will recommend "
#                           'her place  for  staying.'},
#              {'listing_id': '35384123',
#               'review_id': '966750295975696441',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '52828504',
#               'reviewer_name': 'Cagatay',
#               'comments': "I would definately stay again in Olga's place. She "
#                           'let me do a late check in and she was so kind. Also '
#                           "i would like to mention that i didn't even thought "
#                           'that i was paying for stay. She was like a family '
#                           "member who i haven't seen quite a while. She "
#                           'explained all house rules, where to find the stuff '
#                           'i would need in my stay. Also refrigerator was full '
#                           'of water and fruit juices free of charge. And that '
#                           'beautiful garden... By the way even my parking spot '
#                           'was reserved by Olga... Earned 5 stars...'},
#              {'listing_id': '35384123',
#               'review_id': '576815477',
#               'date': datetime.datetime(2019, 12, 14, 0, 0),
#               'reviewer_id': '104866540',
#               'reviewer_name': 'Wagner',
#               'comments': 'Great host and place!'},
#              {'listing_id': '35384123',
#               'review_id': '591530168',
#               'date': datetime.datetime(2020, 1, 11, 0, 0),
#               'reviewer_id': '104866540',
#               'reviewer_name': 'Wagner',
#               'comments': 'Great place and host!'},
#              {'listing_id': '35384123',
# ...
#                           'water in the shower was not reliable. We took many '
#                           'cold or luke-warm showers. This started to get '
#                           'better towards the end of our time there.<br/>7. '
#                           'The apartment has a very strange smell that we '
#                           "couldn't seem to get rid, and the bed is not very "
#                           "comfortable (the tiny couch isn't comfortable at "
#                           'all).<br/>8. The toilet has very weak plumbing, so '
#                           'the toilet plugged multiple times. The owner '
#                           "provides a super cheap plunger that doesn't work. "
#                           'Therefore, we had to wait for it to get unplugged '
#                           'until Rachel could send someone to plunge the '
#                           'toilet.'},
#              {'listing_id': '35384734',
#               'review_id': '577512892',
#               'date': datetime.datetime(2019, 12, 15, 0, 0),
#               'reviewer_id': '70343211',
#               'reviewer_name': 'Carly',
#               'comments': 'My partner and I stayed for ~40 days <br/>What was '
#                           'great: <br/>Phenomenal location and high ceilings. '
#                           'Check in was a breeze and we had zero issues with '
#                           'receiving mail here. Rachel’s response time was '
#                           'great and she was proactive about fixing/bettering '
#                           'issues.<br/>What the host can’t control:<br/>The '
#                           'building is tight and dated, and the unit faces '
#                           'construction and a playground so every weekday from '
#                           '9:30 am - 11 and 3 pm to 4:30 a daycare full of '
#                           'screaming/crying/playing 3-5 year old kids are '
#                           'released for recess and it will wake you up and '
#                           'irritate you :/ But on the weekends and rainy days '
#                           'it is very peaceful. <br/>What was '
#                           'misleading/things the host can control: <br/>The '
#                           'bed is not a Casper. This was a the main reason '
#                           'besides the location why we selected this place. I '
#                           'was disappointed to discover a very firm IKEA bed '
#                           'when I removed the unclean mattress cover to throw '
#                           'away. When I did this the head board that is not '
#                           'fixed securely to the wall also fell on me. The '
#                           'host did send us a new mattress cover, sheets, and '
#                           'a 3 inch foam mattress topper to mitigate the issue '
#                           'and I suggested she secure it for the next guest. '
#                           'Also the speaker was missing so she sent another. '
#                           '<br/>Her beloved awesome housekeeper unfortunately '
#                           'was not well when we stayed there so the apt wasn’t '
#                           'as clean as desired upon arrival. She used a new '
#                           'person that wasn’t thorough forgot to replace some '
#                           'of the listed items like toilet paper and took the '
#                           'spare keys so we were tasked with making more (host '
#                           'offered to pay for which was nice). I hope the '
#                           'rockstar housekeeper is well now and does a better '
#                           'job for the next guest. <br/>All in all- The '
#                           'location was great, the host did their best to '
#                           'correct the issues as they popped up (unfortunately '
#                           'there were quite a few), but the location can be '
#                           'noisy in an unexpected way, and some of the '
#                           'amenities hopefully are listed accurately now.'},
#              {'listing_id': '35384734',
#               'review_id': '594460766',
#               'date': datetime.datetime(2020, 1, 18, 0, 0),
#               'reviewer_id': '296731820',
#               'reviewer_name': 'Kia',
#               'comments': 'Just got back from staying here for a month. It was '
#                           'a very easy check in with great detailed '
#                           'information in her pdf prior to me arriving. I love '
#                           'that the building has an elevator and laundry on '
#                           'site and getting packages was so easy. The location '
#                           "was the best I've ever experienced in the city, and "
#                           'I lived in NYC for half my life. It was clean and '
#                           'organized with comfortable pillows/couch and plenty '
#                           'of storage space and hangers. Overall a wonderful '
#                           'experience and a great place to spend my Christmas '
#                           'and New Years. Valerie was very helpful and always '
#                           'made sure to check in to make sure everything was '
#                           'going okay. I look forward to staying there again '
#                           'in the future. <br/>-Kia'},
#              {'listing_id': '35384734',
#               'review_id': '618717944',
#               'date': datetime.datetime(2020, 3, 15, 0, 0),
#               'reviewer_id': '224536073',
#               'reviewer_name': 'Alexis',
#               'comments': 'Valerie was an awesome host and was very '
#                           'accommodating.'},
#              {'listing_id': '35384734',
#               'review_id': '631463144',
#               'date': datetime.datetime(2020, 6, 22, 0, 0),
#               'reviewer_id': '343468186',
#               'reviewer_name': 'Susan',
#               'comments': 'The Apt was perfect!  And  very clean! Big windows '
#                           'and great light! .. it has everything youd need .  '
#                           'Plus safe location !'},
#              {'listing_id': '35384734',
#               'review_id': '701146010',
#               'date': datetime.datetime(2020, 10, 17, 0, 0),
#               'reviewer_id': '351584935',
#               'reviewer_name': 'Julia',
#               'comments': 'I really enjoyed my stay at this studio apartment. '
#                           'The host was very communicative and respectful, and '
#                           'checked in often to see if I needed anything. The '
#                           'location is great and in a safe area. While the '
#                           'building is on the older side, the apartment itself '
#                           'was clean and tidy, and well taken care of. The '
#                           'studio was bright and light, and decorated '
#                           'elegantly with many cozy touches. I would highly '
#                           'recommend this place and this host!'},
#              {'listing_id': '35384734',
#               'review_id': '710941909',
#               'date': datetime.datetime(2020, 11, 23, 0, 0),
#               'reviewer_id': '22417689',
#               'reviewer_name': 'Rohan',
#               'comments': 'Fantastic spot. Right in between West Village and '
#                           'Chelsea. Great location next to the Subway too. '
#                           'Good food around, safe, clean, and lively. <br/>The '
#                           'inside was nice and clean and very well stocked. '
#                           'Having air conditioning and heating is very useful. '
#                           'Would definitely come back here again!'},
#              {'listing_id': '35384734',
#               'review_id': '739443708',
#               'date': datetime.datetime(2021, 3, 15, 0, 0),
#               'reviewer_id': '37082569',
#               'reviewer_name': 'Ali',
#               'comments': 'Cute little studio apartment in a fantastic '
#                           'location. Had everything I needed and really '
#                           'enjoyed staying here. Rachel & Valerie were '
#                           'incredibly helpful every step of the way!'},
#              {'listing_id': '35384734',
#               'review_id': '753714099',
#               'date': datetime.datetime(2021, 5, 1, 0, 0),
#               'reviewer_id': '36796717',
#               'reviewer_name': 'Steven',
#               'comments': 'Great studio apartment, comfortable and cozy and '
#                           'the location can’t be beat. Near some great '
#                           'restaurants and the high line. Host checked in on '
#                           'me frequently.'},
#              {'listing_id': '35384734',
#               'review_id': '463648395110513381',
#               'date': datetime.datetime(2021, 10, 1, 0, 0),
#               'reviewer_id': '1748723',
#               'reviewer_name': 'William',
#               'comments': 'Rachel and Valerie were outstanding hosts,  the apt '
#                           'was very clean and had all the essentials for a '
#                           'great stay.  They communicated super well and it '
#                           'was clear they cared about their guests with guides '
#                           'to the area and checking to make sure all was well '
#                           'during my stay.  I recommend without hesitation and '
#                           'I look forward to staying at W14th on my next visit '
#                           'to Manhattan.'},
#              {'listing_id': '35384734',
#               'review_id': '486169675847666312',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '415040358',
#               'reviewer_name': 'Apichai',
#               'comments': 'Thank you so much for allowing me to experience '
#                           'this lovely Chelsea apartment. This is one of the '
#                           'wonderful months in NYC.'},
#              {'listing_id': '35384734',
#               'review_id': '508004917148827747',
#               'date': datetime.datetime(2021, 12, 1, 0, 0),
#               'reviewer_id': '67125300',
#               'reviewer_name': 'Antonia',
#               'comments': "I had such a great Stay in Rachel's studio! The "
#                           'apartment is spacious and has everything one or two '
#                           'people could need. The bed is also SUPER '
#                           'comfortable. Good working appliances and when I '
#                           'arrived it was spotless. The location is so great '
#                           'if you are visiting New York or need an extended '
#                           'stay- very close to the subway to pop uptown and '
#                           'the L if you want to go across town or to Brooklyn. '
#                           'The building is very safe and I had no issues '
#                           'checking in, will definitely stay here again!'},
#              {'listing_id': '35384734',
#               'review_id': '594938588343889684',
#               'date': datetime.datetime(2022, 3, 31, 0, 0),
#               'reviewer_id': '145711962',
#               'reviewer_name': 'Janice',
#               'comments': 'I spent a month in this cozy studio apartment in a '
#                           'wonderful neighborhood close to several other '
#                           'wonderful neighborhoods.  Rachel is an extremely '
#                           'responsive and solicitous host who also gives you '
#                           'all the privacy you would want.  Check-in and '
#                           'check-out were easy and well-communicated, the '
#                           'building has an elevator and a laundry room, and is '
#                           'located on a street with several restaurants and '
#                           "delis.  (don't miss the Swedish bakery!)"},
#              {'listing_id': '35384734',
#               'review_id': '693442572829167031',
#               'date': datetime.datetime(2022, 8, 14, 0, 0),
#               'reviewer_id': '144908682',
#               'reviewer_name': 'Matt',
#               'comments': 'The apartment itself was everything it had been '
#                           'described to be, and Rachel was a wonderful host. '
#                           'Excellent communication, and Rachel was always on '
#                           'hand to help with any problems. The apartment had '
#                           'everything I needed and was in a terrific location. '
#                           'I stayed for three months and experienced no '
#                           'problems at all.'},
#              {'listing_id': '35384734',
#               'review_id': '750677361710556536',
#               'date': datetime.datetime(2022, 11, 1, 0, 0),
#               'reviewer_id': '458177032',
#               'reviewer_name': 'Tania',
#               'comments': 'The apartment is just as it looks in the pictures - '
#                           'clean, with lovely décor and very quiet.  You’re on '
#                           'the 4th floor of an elevator building and the '
#                           'building felt safe.  A very comfy bed, fantastic '
#                           'shower pressure and a laundry in the basement were '
#                           'wonderful to have.  The location is amazing, with '
#                           'Chelsea Market, the subway and lots of great '
#                           'restaurants and bars nearby.  Rachel was excellent '
#                           'to communicate with, she checked in with me before, '
#                           'during and after my stay.  Thank you again Rachel '
#                           'for a great stay!'},
#              {'listing_id': '35384734',
#               'review_id': '772456471531667427',
#               'date': datetime.datetime(2022, 12, 1, 0, 0),
#               'reviewer_id': '209794364',
#               'reviewer_name': 'Emilie',
#               'comments': 'Incredible month stay in the perfect NYC location. '
#                           'Apartment was exactly as advertised. Would '
#                           'definitely stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '903692436564101968',
#               'date': datetime.datetime(2023, 5, 31, 0, 0),
#               'reviewer_id': '40330705',
#               'reviewer_name': 'Jessica',
#               'comments': 'Rachel was a lovely host and her place was '
#                           'perfectly located and yet super quiet. The light is '
#                           'beautiful and the apartment had everything you’d '
#                           'need for a stay of any length.'},
#              {'listing_id': '35384734',
#               'review_id': '992851015788271855',
#               'date': datetime.datetime(2023, 10, 1, 0, 0),
#               'reviewer_id': '15140846',
#               'reviewer_name': 'Dan',
#               'comments': 'The location is seriously incredible - 60 seconds '
#                           'away from the 8th Ave station/bodegas/pizza/massage '
#                           'spa, 2 minutes to the High Line, and 6 minutes to '
#                           'the galleries in north Chelsea. Also, the block is '
#                           'surprisingly quiet and untrafficked during the '
#                           'week. The building is on the older side, but it has '
#                           "everything that you'll need, to include "
#                           'washer/dryer in the basement. Rachel is also very '
#                           'responsive. Would totally stay again!'},
#              {'listing_id': '35384734',
#               'review_id': '728576635',
#               'date': datetime.datetime(2021, 2, 2, 0, 0),
#               'reviewer_id': '358506356',
#               'reviewer_name': 'Iryna',
#               'comments': 'Great place in a perfect location.'}]}

# %%
print(db.list_collection_names())
# Out:
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'listings_test2', 'listings_with_reviews', 'calendar_by_agg', 'listings_with_reviews_and_cal', 'calendar_previously_built', 'listings']

# %%
db.listings_test1.drop()
db.listings_test2.drop()
print(db.listings_test.count_documents({}))
print(db.list_collection_names())
# Out:
# 72332
# ['listings_with_calendar', 'testing', 'listings_previously_built', 'listings_test', 'listings_with_reviews', 'calendar_by_agg', 'listings_with_reviews_and_cal', 'calendar_previously_built', 'listings']

# %% [markdown]
# ### <span style=color:blue>Producing json output    </span>

# %%
size = db.listings_with_reviews_and_cal.count_documents({})
print(f'\nThe number of documents in listings_with_reviews_and_cal is {size}.')

print()
doc = db.listings_with_reviews_and_cal.find_one({})
pprint.pp(doc)
# Out:
# The number of documents in listings_with_reviews_and_cal is 39202.
#
# {'_id': ObjectId('6651189238b2bd10b4774432'),
#  'id': '51944693',
#  'name': 'Home in Queens · ★4.82 · 1 bedroom · 5 beds · 1 bath',
#  'host_id': '91646104',
#  'host_name': 'Pao',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74395,
#  'longitude': -73.90858,
#  'room_type': 'Entire home/apt',
#  'price': 294.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 57,
#  'last_review': datetime.datetime(2023, 9, 24, 0, 0),
#  'reviews_per_month': 1.98,
#  'calculated_host_listings_count': 4,
#  'availability_365': 89,
#  'number_of_reviews_ltm': 23,
#  'license': '',
#  'reviews': [{'listing_id': '51944693',
#               'review_id': '883354811516703393',
#               'date': datetime.datetime(2023, 5, 3, 0, 0),
#               'reviewer_id': '78568329',
#               'reviewer_name': 'Laaziz',
#               'comments': 'Hôte très réactif et avenant. Logement très bien '
#                           'desservi, idéal pour visiter New York. Toutefois il '
#                           'ne faut pas avoir peur du bruit (proximité de la '
#                           'ligne de métro aérienne). Odeur persistante dans '
#                           'l’escalier de l’entrée. <br/>Arrivée et départ '
#                           'autonome appréciable. Quartier calme et sécurisé'},
#              {'listing_id': '51944693',
#               'review_id': '894958612605409458',
#               'date': datetime.datetime(2023, 5, 19, 0, 0),
#               'reviewer_id': '31215609',
#               'reviewer_name': 'Suppasit',
#               'comments': 'Nice place, comfy living room with friends. Pao is '
#                           'a great responsive host. We forget AirPod and he '
#                           'wait to return for us. Loudly with nearby high '
#                           'train. Overall is good for friend trip.'},
#              {'listing_id': '51944693',
#               'review_id': '897151957613869875',
#               'date': datetime.datetime(2023, 5, 22, 0, 0),
#               'reviewer_id': '17688815',
#               'reviewer_name': 'Ziya',
#               'comments': 'Pao’s place is a great place to stay- very close to '
#                           'the metro to take you into Manhattan. Note, the '
#                           'beds are mattresses on the floor and all in one '
#                           'shared space, and there is only one bathroom. Pao '
#                           'was very responsible whenever we needed anything.'},
#              {'listing_id': '51944693',
#               'review_id': '913809803180172843',
#               'date': datetime.datetime(2023, 6, 14, 0, 0),
#               'reviewer_id': '518486632',
#               'reviewer_name': 'Ernest',
#               'comments': 'It was such a hassle free stay! We felt at welcomed '
#                           'even before we arrived! Pao sent messages about our '
#                           'stay right after we booked. Check in and out were '
#                           'seemless! The place was clean and homey! We felt '
#                           'like it was a home and not a rental. Thank you Pao! '
#                           'We surely will love to stay in your place in our '
#                           'next visits in NYC! God bless you both!'},
#              {'listing_id': '51944693',
#               'review_id': '937035352711442723',
#               'date': datetime.datetime(2023, 7, 16, 0, 0),
#               'reviewer_id': '92504654',
#               'reviewer_name': 'Katie',
#               'comments': 'Really enjoyed our stay! Pao was incredible! Really '
#                           'responsive and hospitable!'},
#              {'listing_id': '51944693',
#               'review_id': '950729015520969881',
#               'date': datetime.datetime(2023, 8, 4, 0, 0),
#               'reviewer_id': '238048444',
#               'reviewer_name': 'Edoardo',
#               'comments': 'Good place to stay with group of 6+ people. Next to '
#                           'Woodside station. Neighbourhoods ok. Recommended👍🏼'},
#              {'listing_id': '51944693',
#               'review_id': '956495081693294732',
#               'date': datetime.datetime(2023, 8, 12, 0, 0),
#               'reviewer_id': '515282241',
#               'reviewer_name': 'Jacob',
#               'comments': 'Fantastic stay. No complaints. Host did not disturb '
#                           'us at any point during our stay, rare for airbnbs.'},
#              {'listing_id': '51944693',
#               'review_id': '987750783277373686',
#               'date': datetime.datetime(2023, 9, 24, 0, 0),
#               'reviewer_id': '10104820',
#               'reviewer_name': 'Robert',
#               'comments': 'Logement bien situé ( la station Woodside est '
#                           'accessible à pieds ). <br/>Pas mal d’équipements '
#                           'dans l’appartement avec une entrée autonome.  '
#                           '<br/>Par contre attention aux bruits de métro et '
#                           'd’avions qui sont très présents ( même la nuit ). '
#                           '<br/>L’hôte est très réactif'},
#              {'listing_id': '51944693',
#               'review_id': '567393547833848751',
#               'date': datetime.datetime(2022, 2, 21, 0, 0),
#               'reviewer_id': '16621870',
#               'reviewer_name': 'Francis',
#               'comments': 'Comfortable and spacious for our group of three. '
#                           'Great location close to the 7 and lots of great '
#                           "restaurants. Some train noise, but it's not loud. "
#                           'Friendly host who responds quickly. You do need to '
#                           'be comfortable on spiral stairs, and beds are low '
#                           'to the ground (because of low ceilings in the upper '
#                           'area).'},
#              {'listing_id': '51944693',
#               'review_id': '638389624660614492',
#               'date': datetime.datetime(2022, 5, 30, 0, 0),
#               'reviewer_id': '348121070',
#               'reviewer_name': 'Ahmod',
#               'comments': 'The place is great and so is the neighborhood'},
#              {'listing_id': '51944693',
#               'review_id': '739125084981982717',
#               'date': datetime.datetime(2022, 10, 16, 0, 0),
#               'reviewer_id': '142604893',
#               'reviewer_name': 'Bryan',
#               'comments': 'Great place! Convenient as it is close to the '
#                           'subway station. Clean place overall. Only issue is '
#                           'that there is a strong unpleasant smell in the '
#                           'stairway which can be smelt through some parts of '
#                           'the first floor. Other than that, this place has '
#                           'everything needed to explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '971036944720923351',
#               'date': datetime.datetime(2023, 9, 1, 0, 0),
#               'reviewer_id': '318584119',
#               'reviewer_name': 'Omar Hamalat',
#               'comments': 'It is a very comfortable place for the number of '
#                           'people who can stay there and it is very close to '
#                           'the subway.'},
#              {'listing_id': '51944693',
#               'review_id': '977565253827952973',
#               'date': datetime.datetime(2023, 9, 10, 0, 0),
#               'reviewer_id': '266443561',
#               'reviewer_name': 'Jerra',
#               'comments': 'Great place to stay. Good safe neighborhood is '
#                           'close to the necessary things like groceries and '
#                           'nightlife .'},
#              {'listing_id': '51944693',
#               'review_id': '983411852402944419',
#               'date': datetime.datetime(2023, 9, 18, 0, 0),
#               'reviewer_id': '360653194',
#               'reviewer_name': 'Loren',
#               'comments': 'Pao was very responsive and helpful. Got us things '
#                           'in a timely manner. Place was really nice and '
#                           'conveniently located.'},
#              {'listing_id': '51944693',
#               'review_id': '476800883068852132',
#               'date': datetime.datetime(2021, 10, 19, 0, 0),
#               'reviewer_id': '396700275',
#               'reviewer_name': 'Cate',
#               'comments': 'Great location and accommodating host.'},
#              {'listing_id': '51944693',
#               'review_id': '656505113492821921',
#               'date': datetime.datetime(2022, 6, 24, 0, 0),
#               'reviewer_id': '90451701',
#               'reviewer_name': 'Giovanni',
#               'comments': 'Great location and great place to spend a couple of '
#                           'nights when visiting NYC. Highly recommend.'},
#              {'listing_id': '51944693',
#               'review_id': '679652573103721350',
#               'date': datetime.datetime(2022, 7, 26, 0, 0),
#               'reviewer_id': '463620781',
#               'reviewer_name': 'Aarish',
#               'comments': 'The location was great, close to the subway station '
#                           'if you want to go to manhattan. Host is great and '
#                           'very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '907252834272035367',
#               'date': datetime.datetime(2023, 6, 5, 0, 0),
#               'reviewer_id': '160010734',
#               'reviewer_name': 'Aric',
#               'comments': 'Simply awesome people and an awesome place to stay. '
#                           'Will definitely book again!'},
#              {'listing_id': '51944693',
#               'review_id': '963793691602040112',
#               'date': datetime.datetime(2023, 8, 22, 0, 0),
#               'reviewer_id': '528264219',
#               'reviewer_name': 'Thanaporn',
#               'comments': 'The house is near the train. There is a little '
#                           'noise but overall okay. The house is very good.'},
#              {'listing_id': '51944693',
#               'review_id': '480406697622749070',
#               'date': datetime.datetime(2021, 10, 24, 0, 0),
#               'reviewer_id': '424810997',
#               'reviewer_name': '津本',
#               'comments': 'よかったです！！'},
#              {'listing_id': '51944693',
#               'review_id': '734083949713663486',
#               'date': datetime.datetime(2022, 10, 9, 0, 0),
#               'reviewer_id': '476465846',
#               'reviewer_name': 'Joshua',
#               'comments': '👍'},
#              {'listing_id': '51944693',
#               'review_id': '500708832360298283',
#               'date': datetime.datetime(2021, 11, 21, 0, 0),
#               'reviewer_id': '373885692',
#               'reviewer_name': 'Andres',
#               'comments': 'Great place , exactly as expected , great '
#                           'neighborhood, the line was a 3 min walk away !'},
#              {'listing_id': '51944693',
#               'review_id': '845650532974424531',
#               'date': datetime.datetime(2023, 3, 12, 0, 0),
#               'reviewer_id': '500446980',
#               'reviewer_name': 'Yuka',
#               'comments': 'よかった。トイレが壊れたが、すぐに対応してくれた。'},
#              {'listing_id': '51944693',
#               'review_id': '759424058862563840',
#               'date': datetime.datetime(2022, 11, 13, 0, 0),
#               'reviewer_id': '103824534',
#               'reviewer_name': 'Angel',
#               'comments': 'Good apartment, near subway, with everything you '
#                           'need to stay some days. Wifi and heating works very '
#                           'well.  Pao answers quickly when you need to contact '
#                           'him and solve anything you need.'},
#              {'listing_id': '51944693',
#               'review_id': '948608350144766620',
#               'date': datetime.datetime(2023, 8, 1, 0, 0),
#               'reviewer_id': '25964604',
#               'reviewer_name': 'Jonathan',
#               'comments': 'Had a great stay! Close to the metro and a bus to '
#                           'LaGuardia!'},
#              {'listing_id': '51944693',
#               'review_id': '713802921086507210',
#               'date': datetime.datetime(2022, 9, 11, 0, 0),
#               'reviewer_id': '472824796',
#               'reviewer_name': 'Apinan',
#               'comments': 'Good location'},
#              {'listing_id': '51944693',
#               'review_id': '966736716156881567',
#               'date': datetime.datetime(2023, 8, 26, 0, 0),
#               'reviewer_id': '458454193',
#               'reviewer_name': 'Dhruvil',
#               'comments': 'Good home'},
#              {'listing_id': '51944693',
#               'review_id': '717382980083165765',
#               'date': datetime.datetime(2022, 9, 16, 0, 0),
#               'reviewer_id': '474709081',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Awesome stay!'},
#              {'listing_id': '51944693',
#               'review_id': '584072151062316844',
#               'date': datetime.datetime(2022, 3, 16, 0, 0),
#               'reviewer_id': '375452546',
#               'reviewer_name': 'KoKo',
#               'comments': 'Good and clean apartment, friendly landlord'},
#              {'listing_id': '51944693',
#               'review_id': '901511049668500928',
#               'date': datetime.datetime(2023, 5, 28, 0, 0),
#               'reviewer_id': '484540810',
#               'reviewer_name': 'Marcela',
#               'comments': 'Buenos anfitriones'},
#              {'listing_id': '51944693',
#               'review_id': '911574665605429137',
#               'date': datetime.datetime(2023, 6, 11, 0, 0),
#               'reviewer_id': '503400540',
#               'reviewer_name': 'Jacob',
#               'comments': 'Highly recommend!!'},
#              {'listing_id': '51944693',
#               'review_id': '495644455146919507',
#               'date': datetime.datetime(2021, 11, 14, 0, 0),
#               'reviewer_id': '74587916',
#               'reviewer_name': 'Yu-Heng',
#               'comments': 'Nice location, only 6 min from subway by walk. The '
#                           'host is very accommodating.'},
#              {'listing_id': '51944693',
#               'review_id': '594126476264570382',
#               'date': datetime.datetime(2022, 3, 30, 0, 0),
#               'reviewer_id': '252273956',
#               'reviewer_name': 'Elie',
#               'comments': 'very close by sub to downtown Manhattan, great '
#                           'price for location!'},
#              {'listing_id': '51944693',
#               'review_id': '709392673053529605',
#               'date': datetime.datetime(2022, 9, 5, 0, 0),
#               'reviewer_id': '430454315',
#               'reviewer_name': 'Fiona',
#               'comments': 'Good location, subway is close by. Pao was '
#                           'accommodating and responsive.'},
#              {'listing_id': '51944693',
#               'review_id': '512978941599026358',
#               'date': datetime.datetime(2021, 12, 8, 0, 0),
#               'reviewer_id': '97286963',
#               'reviewer_name': 'Steven',
#               'comments': 'he is a wonderful host and a very nice apartment I '
#                           'recommend it to you.<br/>Thanks Pao'},
#              {'listing_id': '51944693',
#               'review_id': '475293330062078374',
#               'date': datetime.datetime(2021, 10, 17, 0, 0),
#               'reviewer_id': '92612288',
#               'reviewer_name': 'Maria Alejandra',
#               'comments': 'Excelente ubicación!<br/>Muy buena comunicación, '
#                           'atención y servicio. Recomendado!'},
#              {'listing_id': '51944693',
#               'review_id': '486191320060365105',
#               'date': datetime.datetime(2021, 11, 1, 0, 0),
#               'reviewer_id': '397413730',
#               'reviewer_name': 'Adam',
#               'comments': 'Went to a music festival with my friends for the '
#                           'week and stayed here. The house is really nice and '
#                           'comfortable and I was able to do pretty much '
#                           'everything I needed to do because the train station '
#                           'is so close.'},
#              {'listing_id': '51944693',
#               'review_id': '465111784563442407',
#               'date': datetime.datetime(2021, 10, 3, 0, 0),
#               'reviewer_id': '249242723',
#               'reviewer_name': 'Yarina',
#               'comments': 'Wonderful stay! Travelled with 6 other family '
#                           'members. Description was accurate, space was '
#                           'spacious, clean, and accommodating. The location '
#                           'was great as well. Would definitely stay here '
#                           'again!'},
#              {'listing_id': '51944693',
#               'review_id': '460059297930512330',
#               'date': datetime.datetime(2021, 9, 26, 0, 0),
#               'reviewer_id': '403518265',
#               'reviewer_name': 'Rose',
#               'comments': 'Beautiful apartment and Pao is a super lovely host, '
#                           'very easy to reach if you have any questions. Most '
#                           'things were provided (towels, sheets, dishes, '
#                           'spices, etc.) and the space fit 6 people '
#                           'surprisingly well given the size. The only real '
#                           'downsides were one bathroom and no dishwasher. The '
#                           'location was perfect for us, close to the subway so '
#                           'we were able to get around very easily and the '
#                           'neighborhood has a bunch of cheap food options. '
#                           'Overall, would definitely stay here again.'},
#              {'listing_id': '51944693',
#               'review_id': '850028790962753743',
#               'date': datetime.datetime(2023, 3, 18, 0, 0),
#               'reviewer_id': '480336464',
#               'reviewer_name': 'Thuc Anh',
#               'comments': 'Cozy place and very nice host!'},
#              {'listing_id': '51944693',
#               'review_id': '514510196981112491',
#               'date': datetime.datetime(2021, 12, 10, 0, 0),
#               'reviewer_id': '264812310',
#               'reviewer_name': 'Kacper',
#               'comments': 'Pao provided my group with an amazing experience. '
#                           'Super professional right from the start and super '
#                           'engaging. provided us with everything we needed and '
#                           'the apartment was splendid. Eorth every penny.'},
#              {'listing_id': '51944693',
#               'review_id': '521679825889586335',
#               'date': datetime.datetime(2021, 12, 20, 0, 0),
#               'reviewer_id': '150008279',
#               'reviewer_name': 'Brady',
#               'comments': 'Pao’s loft in Queens was an excellent stay for my '
#                           'group of 4. The location was great, train was close '
#                           'by, spacious, and was relatively relaxing and quiet '
#                           'by NY standards. The metro didn’t bother any of us '
#                           'getting to sleep every night. I have a couple of '
#                           'very minor complaints that weren’t deal breakers, '
#                           'which include the hairdryer being so small that it '
#                           'wasn’t really useful, the couches being a bit '
#                           'uncomfortable, and the TV being a little old/cheap '
#                           '(it still runs a Roku stick just fine so '
#                           'Netflix/Disney+ work great). None of these things '
#                           'were dealbreakers to me, as we were there on '
#                           'vacation and so we didn’t spend a majority of our '
#                           'time in Queens in the loft. This is a wonderful '
#                           'spot to stay and Pao was an excellent host. Thanks '
#                           'again Pao!'},
#              {'listing_id': '51944693',
#               'review_id': '610812106846948571',
#               'date': datetime.datetime(2022, 4, 22, 0, 0),
#               'reviewer_id': '24504591',
#               'reviewer_name': 'Deborah',
#               'comments': 'Buena ubicación y comunicación con el subway, por '
#                           'cierto pasa cerca de la casa.. y se oye.. pero te '
#                           'acostumbras rápido'},
#              {'listing_id': '51944693',
#               'review_id': '618126036356872760',
#               'date': datetime.datetime(2022, 5, 2, 0, 0),
#               'reviewer_id': '430235877',
#               'reviewer_name': 'Tomasz',
#               'comments': 'Mostly ok, but subway at the end of the block won’t '
#                           'let you sleep'},
#              {'listing_id': '51944693',
#               'review_id': '630397653721376529',
#               'date': datetime.datetime(2022, 5, 19, 0, 0),
#               'reviewer_id': '92682398',
#               'reviewer_name': 'Manon',
#               'comments': 'Nous avons passé une très chouette semaine dans cet '
#                           'airbnb. Nous étions quatre mais le logement peut '
#                           "accueillir plus de personnes. Nous n'avons manqué "
#                           'de rien.<br/>Pao est disponible pour répondre à '
#                           'toutes nos questions avant et pendant le voyage, Il '
#                           'est de bon conseil concernant les restaurants du '
#                           'coin, les déplacements, etc.<br/>Le logement est '
#                           'bien situé, le centre est facilement accessible en '
#                           'métro. Le quartier est bruyant (avions, trains) '
#                           "mais on s'y habitue après quelques jours."},
#              {'listing_id': '51944693',
#               'review_id': '665197303662816810',
#               'date': datetime.datetime(2022, 7, 6, 0, 0),
#               'reviewer_id': '457830841',
#               'reviewer_name': 'Natthanon',
#               'comments': 'The house location is very good near The train 7 '
#                           'line 52 and 61.We stay in second floor everything '
#                           'is good.The bad thing is the AC grille is very old '
#                           '.It falling out and very loud.'},
#              {'listing_id': '51944693',
#               'review_id': '675343393738720392',
#               'date': datetime.datetime(2022, 7, 20, 0, 0),
#               'reviewer_id': '48295632',
#               'reviewer_name': 'Juan Carlos',
#               'comments': 'Extraordinary place, great location, very well '
#                           'connected, is better to be in Queens than in the '
#                           'uptown of Manhattan. Supermarket across the street, '
#                           'bus stop, subway station, all you need for your '
#                           'visit to NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '694933235507322297',
#               'date': datetime.datetime(2022, 8, 16, 0, 0),
#               'reviewer_id': '138019694',
#               'reviewer_name': 'Laetitia',
#               'comments': 'Parfait ! Avec nos 5 enfants, nous nous sommes '
#                           'trouvés très bien dans cet appartement situé dans '
#                           'une petite maison. Très pratique et rapide pour ce '
#                           'rendre à Manhattan. <br/>Pao est un hôte '
#                           'arrangeant, agréable et efficace.<br/>Nous '
#                           'recommandons vivement.'},
#              {'listing_id': '51944693',
#               'review_id': '703560811248777708',
#               'date': datetime.datetime(2022, 8, 28, 0, 0),
#               'reviewer_id': '267027037',
#               'reviewer_name': 'Anne Lorraine',
#               'comments': 'We had a wonderful time. Everything was clean and '
#                           'cozy. It is also a good location to stay for '
#                           'transportation options.'},
#              {'listing_id': '51944693',
#               'review_id': '748547155357753696',
#               'date': datetime.datetime(2022, 10, 29, 0, 0),
#               'reviewer_id': '403131',
#               'reviewer_name': 'Lau',
#               'comments': "Un super séjour, hôte très a l'écoute et disponible "
#                           'pour répondre à nos demandes. Très bon emplacement, '
#                           'proche du métro, sur la ligne qui permet de '
#                           'rejoindre Manhattan en direct. Encore merci.'},
#              {'listing_id': '51944693',
#               'review_id': '754398703556725336',
#               'date': datetime.datetime(2022, 11, 6, 0, 0),
#               'reviewer_id': '341451144',
#               'reviewer_name': 'Glennis',
#               'comments': 'They stay was clean and spacious. I think it works '
#                           'for really well for larger groups. It’s super close '
#                           'to the subway which allows for  easy transportation '
#                           'in to the heart of the city. Overall, a great '
#                           'stay!'},
#              {'listing_id': '51944693',
#               'review_id': '765974764518857565',
#               'date': datetime.datetime(2022, 11, 22, 0, 0),
#               'reviewer_id': '388101890',
#               'reviewer_name': 'Julia',
#               'comments': 'There were rats during our first night there. The '
#                           "train would be mildly distracting at night but it's "
#                           "not disturbing sleep. There's a funky smell in the "
#                           'staircase up to the airbnb. The spiral staircase is '
#                           'small as hell. Everything is smaller than the '
#                           "photos but it's New York. It was a great place "
#                           "though, had great experiences. It's only 30 minutes "
#                           'from Times Square basically.'},
#              {'listing_id': '51944693',
#               'review_id': '946350420524593049',
#               'date': datetime.datetime(2023, 7, 29, 0, 0),
#               'reviewer_id': '418060623',
#               'reviewer_name': 'Kathleen',
#               'comments': 'Works well for a group, especially if you need to '
#                           'cook. Lots of grocery stores nearby. AC was great '
#                           'in nyc summer heat as well as hot showers even '
#                           'after many showers in a row. Many nice amenities in '
#                           'bathroom- scale was helpful for weighing suitcases! '
#                           'Dressing table upstairs was nice touch too. Very '
#                           'responsive host.'},
#              {'listing_id': '51944693',
#               'review_id': '786967080042132739',
#               'date': datetime.datetime(2022, 12, 21, 0, 0),
#               'reviewer_id': '481693026',
#               'reviewer_name': 'Lynn',
#               'comments': 'Great price for eight (8) people, which meant that '
#                           'six (6) very able-bodied young adults braved the '
#                           'narrow stairs day and night. The mattresses were '
#                           'all very comfortable. With only one bathroom and an '
#                           'open sleeping area, there is little privacy. Very '
#                           'close to subway stop. The frequent trains are '
#                           'audible, but quite muffled and not intrusive. Our '
#                           'group had varying reactions to the wet dog smell, '
#                           'from "barely noticable" to pervasive. <br/>Pao '
#                           'responded to our one need immediately. Our stay '
#                           'there was part of our wonderful trip, and we '
#                           'appreciated the family time in this cozy space.'},
#              {'listing_id': '51944693',
#               'review_id': '839893128323740183',
#               'date': datetime.datetime(2023, 3, 4, 0, 0),
#               'reviewer_id': '203653063',
#               'reviewer_name': 'Mai',
#               'comments': 'Good location, near the station with a lot of '
#                           'stores, supermarkets around. The house is clean, '
#                           'however with some smell (of dogs I guess). Pao is '
#                           'very friendly and helpful.'},
#              {'listing_id': '51944693',
#               'review_id': '855840354909772949',
#               'date': datetime.datetime(2023, 3, 26, 0, 0),
#               'reviewer_id': '72674928',
#               'reviewer_name': 'David',
#               'comments': 'this place has everything you need for an '
#                           'affordable price. its in a great location, right '
#                           'next to the subway (the noise is not bad at all). A '
#                           'lot of beds, a decent kitchen and a bathroom that '
#                           'worked well. not much to complain about. this place '
#                           'is a great deal if you are looking for a place to '
#                           'stay while you explore NYC.'},
#              {'listing_id': '51944693',
#               'review_id': '865955667410638646',
#               'date': datetime.datetime(2023, 4, 9, 0, 0),
#               'reviewer_id': '59354977',
#               'reviewer_name': 'Fernanda',
#               'comments': 'Excelente zona y espacio para hospedarse, con todas '
#                           'las comodidades que se necesitan, central, a 5 min '
#                           'del metro, muchos restaurantes sobre todo latinos '
#                           'por la zona, muy tranquilo a cualquier hora del '
#                           'día. Impecables las instalaciones, muy '
#                           'organizado.'}],
#  'average_price': 200.0,
#  'first_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 10, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 11, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 12, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 13, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 14, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 15, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 16, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 17, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 18, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 19, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 20, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 21, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 22, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 23, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 24, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 25, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 26, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 27, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 28, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 29, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 30, 0, 0),
#                  'available': True,
#                  'price': 200.0,
#                  'minimum_nights': 30,
# ...
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 200.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %%
# this function is cheating, and converts "reviews_id" in the reviews lists back to "id"
def convert_lwrc_to_json_and_convert_listing_id_to_id(doc):
    doc_new = {}
    # start by transferring all scalar keys over, then fix some of them
    for key in doc.keys():
        if key not in ['reviews', 'dates_list']:
            doc_new[key] = doc[key]
    # now fixing some possible issues
    doc_new['_id'] = str(doc['_id'])
    if doc['last_review'] == None:    # is null
        doc_new['last_review'] = None
    else:
        doc_new['last_review'] = doc['last_review'].strftime('%Y-%m-%d')
    if math.isnan(doc['price']):
        doc_new['price'] = None
    else:
        doc_new['price'] = doc['price']
    if math.isnan(doc['reviews_per_month']):
        doc_new['reviews_per_month'] = None
    else:
        doc_new['reviews_per_month'] = doc['reviews_per_month']
    # there is one document in the merger that has no calendar entries
    if 'first_available_date' in doc:
        if doc['first_available_date'] == None:
            doc_new['first_available_date'] = None
        else:
            doc_new['first_available_date'] = doc['first_available_date'].strftime('%Y-%m-%d')
    if 'last_available_date' in doc:
        if doc['last_available_date'] == None:
            doc_new['last_available_date'] = None
        else:
            doc_new['last_available_date'] = doc['last_available_date'].strftime('%Y-%m-%d')
    if 'average_price' in doc:
        doc_new['average_price'] = doc['average_price']
    
    # now dealing with the 'reviews' array
    rlist = []
    for r in doc['reviews']:
        r_new = {}
        r_new['date'] = r['date'].strftime('%Y-%m-%d')
        r_new['id'] = r['review_id']
        for key in r.keys():
            # I am cheating, and will rename the 'listing_id' column back to 'id'
            if key not in ['date', 'review_id']:
                r_new[key] = r[key]
        rlist.append(r_new)
    doc_new['reviews'] = rlist

    # now dealing with the 'dates_list' array
    dlist = []
    for d in doc['dates_list']:
        d_new = {}
        d_new['date'] = d['date'].strftime('%Y-%m-%d')
        for key in ['price', 'minimum_nights', 'maximum_nights', 'available']:
            d_new[key] = d[key]
        dlist.append(d_new)
    doc_new['dates_list'] = dlist
    
    return doc_new

# pprint.pp(doc)

pprint.pp(convert_lwrc_to_json_and_convert_listing_id_to_id(doc))
# Out:
# {'_id': '664be01338b2bd10b477426e',
#  'id': '1000128045386999700',
#  'name': 'Rental unit in Queens · 1 bedroom · 1 bed · 1 shared bath',
#  'host_id': '501499086',
#  'host_name': 'CrossOver',
#  'neighbourhood_group': 'Queens',
#  'neighbourhood': 'Woodside',
#  'latitude': 40.74052,
#  'longitude': -73.89424,
#  'room_type': 'Private room',
#  'price': 81.0,
#  'minimum_nights': 30,
#  'number_of_reviews': 0,
#  'last_review': None,
#  'reviews_per_month': None,
#  'calculated_host_listings_count': 162,
#  'availability_365': 270,
#  'number_of_reviews_ltm': 0,
#  'license': '',
#  'average_price': 81.0,
#  'first_available_date': '2024-02-06',
#  'last_available_date': '2025-02-04',
#  'reviews': [],
#  'dates_list': [{'date': '2024-02-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-02-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-03-31',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-04-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-05-31',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-06-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-07-31',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-08-31',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-09-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
#                 {'date': '2024-10-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': True},
# ...
#                 {'date': '2024-11-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-11-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2024-12-31',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-05',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-06',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-07',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-08',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-09',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-10',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-11',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-12',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-13',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-14',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-15',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-16',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-17',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-18',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-19',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-20',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-21',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-22',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-23',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-24',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-25',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-26',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-27',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-28',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-29',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-30',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-01-31',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-02-01',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-02-02',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-02-03',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False},
#                 {'date': '2025-02-04',
#                  'price': 81.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 365,
#                  'available': False}]}

# %%
print(db.listings_with_reviews_and_cal.count_documents({}))

cursor = db.listings_with_reviews_and_cal.find({'id' : {'$regex' : '^111.*$'}})
    
l = list(cursor)
print(len(l))
# Out:
# 39202
# 28

# %%
cursor = db.listings_with_reviews_and_cal.find({'id' : {'$regex' : '^111.*$'}})

output = []

for doc in cursor:
    output.append(convert_lwrc_to_json_and_convert_listing_id_to_id(doc))

print(len(output))
# Out:
# 28

# %%
dir = 'OUTPUTS'
filename = 'listings_with_reviews_and_cal_subset_111.json'
util.write_dict_to_dir_json(output, dir, filename)

# %%
cursor = db.listings_with_reviews_and_cal.find({'id' : {'$regex' : '^1000.*$'}})

output = []

for doc in cursor:
    output.append(convert_lwrc_to_json_and_convert_listing_id_to_id(doc))

print(len(output))
# Out:
# 43

# %%
dir = 'OUTPUTS'
filename = 'listings_with_reviews_and_cal_subset_1000.json'
util.write_dict_to_dir_json(output, dir, filename)
