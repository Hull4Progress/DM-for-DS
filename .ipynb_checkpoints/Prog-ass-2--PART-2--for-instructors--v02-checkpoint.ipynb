# %% [markdown]
# ## <span style=color:blue>Patterns used in Programming Assignment 2 Part 2(version using util.py file)  </span>

# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %%
# test that utils.py has been imported well
# util.hello_world()

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>
#
# <span style=color:blue>E.g., see https://docs.sqlalchemy.org/en/20/core/engines.html for how to construct the URLs that the create_engine command uses.  Also, one should store the user/password into environment variables and read them in to populate the URL.  </span>
#
# <span style=color:blue>E.g., see https://stackoverflow.com/questions/4906977/how-can-i-access-environment-variables-in-python for how to work with environment variables on mac, </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>Working with btree indexing</span>

# %% [markdown]
# <span style=color:blue>I will encourage students to build the following query, so that they have an idea of number of recods for each year in the reviews table </span>

# %%
q = """select left(to_char(date, 'YYYY-MM-DD'),4) as year, count(*)
from reviews
group by year
order by year"""

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('2009', 56),
#  ('2010', 449),
#  ('2011', 1905),
#  ('2012', 3872),
#  ('2013', 7317),
#  ('2014', 14203),
#  ('2015', 28465),
#  ('2016', 48527),
#  ('2017', 66146),
#  ('2018', 95137),
#  ('2019', 126469),
#  ('2020', 51172),
#  ('2021', 109415),
#  ('2022', 196136),
#  ('2023', 228831),
#  ('2024', 8710)]

# %% [markdown]
# <span style=color:blue>First, here is an example of the queries we are using for the testing with b-tree indexes </span>

# %%
date_start = '2015-01-01'
date_end = '2015-12-31'

q = util.build_query_listings_join_reviews(date_start, date_end)

print(q)
# Out:
# SELECT DISTINCT l.id, l.name
# FROM listings l, reviews r
# WHERE l.id = r.listing_id
#   AND r.date >= '2015-01-01'
#   AND r.date <= '2015-12-31'
# ORDER BY l.id;

# %% [markdown]
# <span style=color:blue>My big vision was to have the students set up some infrastructure so that they could easily experiment with a variety of different queries and indexes, and do explorations of things on their own.  So, in util.py I have some helper functions that enable someone to specify a list of indexes, and then run experiments for all combinations of that list.  However, at present I'm thinking that will take people to far into some weeds.   </span>
#
# <span style=color:blue>I am now thinking that I may ask the students to only build files like my files perf_test_v01.json and ts_perf_test_v01.json.  Or I might find time to do some update-based experiments, again for the same set of indexes that are involved with perf_test_v01.json and ts_perf_test_v01.json.  In either case, most likely, they will only have to think about the indexes date_in_reviews, id_in_listings, and comments_tsv_in_reviews. <span>
#
# <span style=color:blue>With regards to storing results, I was originally thinking about this assignment, and about enabling the students to explore different index combinations over time.  So I developed a helper function that would read a json file from my disk, add to it, and then write it out again.  That way, I would be adding performance information over many programming/execution sessions.  This is my function util.fetch_and_update_perf_data(perf_file, perf_summary).  However, I am now thinking that the students don't need to bother with that, given that they will be given quite specific files that they are supposed to generate.<span>

# %% [markdown]
# <span style=color:blue>This generates a json file 'perf_test_v01.json'.  </span>
#
# <span style=color:blue>This produces a lot of log info which may be helpful ... </span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

all_indexes = [['date','reviews'], ['date','calendar'], ['id','listings'], ['comments_tsv', 'reviews', 'gin']] 

q_dict = {}
# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_join_reviews(date_start, date_end)
# pprint.pp(q_dict)

q_dict['listings_join_reviews_2019'] = util.build_query_listings_join_reviews('2019-01-01', '2019-12-31')
# note: The reviews table has 126,469 entries in 2019


i_spec = [['id','listings'], ['date','reviews']]

perf_file = 'perf_test_v01.json'

# setting count to 3 for now so that things run faster
count = 3

for q in q_dict:
    print('\n====>>> Now working on query:', q)
    perf_summary = util.run_one_query_and_multi_index_specs(db_eng, all_indexes, q, q_dict[q], i_spec, count)
    # print('\nThe perf_summary of running query', q, 'is as follows:') 
    # pprint.pp(perf_summary)
    updated_perf_summary = util.fetch_and_update_perf_data(perf_file, perf_summary)

print('\nThe value of updated perf_summary is:')
pprint.pp(updated_perf_summary, sort_dicts=True)
# Out:
# ====>>> Now working on query: listings_join_review_2009
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2010
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2011
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2012
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2013
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2014
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2015
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2016
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2017
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2018
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2020
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2021
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2022
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2023
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2024
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# The value of updated perf_summary is:
# {'listings_join_review_2009': {'__': {'avg': 0.2004,
#                                       'count': 3,
#                                       'max': 0.2253,
#                                       'min': 0.1877,
#                                       'std': 0.0176,
#                                       'timestamp': '2024-05-07-08:36:17'},
#                                '__date_in_reviews__': {'avg': 0.0162,
#                                                        'count': 3,
#                                                        'max': 0.0199,
#                                                        'min': 0.0135,
#                                                        'std': 0.0027,
#                                                        'timestamp': '2024-05-07-08:36:18'},
#                                '__id_in_listings__': {'avg': 0.1788,
#                                                       'count': 3,
#                                                       'max': 0.1828,
#                                                       'min': 0.1739,
#                                                       'std': 0.0037,
#                                                       'timestamp': '2024-05-07-08:36:17'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0142,
#                                                                        'count': 3,
#                                                                        'max': 0.0148,
#                                                                        'min': 0.0138,
#                                                                        'std': 0.0005,
#                                                                        'timestamp': '2024-05-07-08:36:18'}},
#  'listings_join_review_2010': {'__': {'avg': 0.1954,
#                                       'count': 3,
#                                       'max': 0.2051,
#                                       'min': 0.1897,
#                                       'std': 0.0069,
#                                       'timestamp': '2024-05-07-08:36:19'},
#                                '__date_in_reviews__': {'avg': 0.0163,
#                                                        'count': 3,
#                                                        'max': 0.0191,
#                                                        'min': 0.0145,
#                                                        'std': 0.002,
#                                                        'timestamp': '2024-05-07-08:36:20'},
#                                '__id_in_listings__': {'avg': 0.1927,
#                                                       'count': 3,
#                                                       'max': 0.1962,
#                                                       'min': 0.1891,
#                                                       'std': 0.0029,
#                                                       'timestamp': '2024-05-07-08:36:19'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0149,
#                                                                        'count': 3,
#                                                                        'max': 0.016,
#                                                                        'min': 0.0139,
#                                                                        'std': 0.0008,
#                                                                        'timestamp': '2024-05-07-08:36:20'}},
#  'listings_join_review_2011': {'__': {'avg': 0.1909,
#                                       'count': 3,
#                                       'max': 0.1975,
#                                       'min': 0.1868,
#                                       'std': 0.0047,
#                                       'timestamp': '2024-05-07-08:36:21'},
#                                '__date_in_reviews__': {'avg': 0.0206,
#                                                        'count': 3,
#                                                        'max': 0.0248,
#                                                        'min': 0.0181,
#                                                        'std': 0.003,
#                                                        'timestamp': '2024-05-07-08:36:22'},
#                                '__id_in_listings__': {'avg': 0.2029,
#                                                       'count': 3,
#                                                       'max': 0.21,
#                                                       'min': 0.1986,
#                                                       'std': 0.0051,
#                                                       'timestamp': '2024-05-07-08:36:22'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0188,
#                                                                        'count': 3,
#                                                                        'max': 0.0193,
#                                                                        'min': 0.0181,
#                                                                        'std': 0.0005,
#                                                                        'timestamp': '2024-05-07-08:36:22'}},
#  'listings_join_review_2012': {'__': {'avg': 0.196,
#                                       'count': 3,
#                                       'max': 0.2124,
#                                       'min': 0.1872,
#                                       'std': 0.0116,
#                                       'timestamp': '2024-05-07-08:36:23'},
#                                '__date_in_reviews__': {'avg': 0.0239,
#                                                        'count': 3,
#                                                        'max': 0.0306,
#                                                        'min': 0.0201,
#                                                        'std': 0.0047,
#                                                        'timestamp': '2024-05-07-08:36:24'},
#                                '__id_in_listings__': {'avg': 0.1995,
#                                                       'count': 3,
#                                                       'max': 0.203,
#                                                       'min': 0.1973,
#                                                       'std': 0.0025,
#                                                       'timestamp': '2024-05-07-08:36:24'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0211,
#                                                                        'count': 3,
#                                                                        'max': 0.0214,
#                                                                        'min': 0.0209,
#                                                                        'std': 0.0002,
#                                                                        'timestamp': '2024-05-07-08:36:24'}},
#  'listings_join_review_2013': {'__': {'avg': 0.209,
#                                       'count': 3,
#                                       'max': 0.211,
#                                       'min': 0.2051,
#                                       'std': 0.0027,
#                                       'timestamp': '2024-05-07-08:36:25'},
#                                '__date_in_reviews__': {'avg': 0.0313,
#                                                        'count': 3,
#                                                        'max': 0.0383,
#                                                        'min': 0.0269,
#                                                        'std': 0.005,
#                                                        'timestamp': '2024-05-07-08:36:26'},
#                                '__id_in_listings__': {'avg': 0.1965,
#                                                       'count': 3,
#                                                       'max': 0.2028,
#                                                       'min': 0.1926,
#                                                       'std': 0.0045,
#                                                       'timestamp': '2024-05-07-08:36:26'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0265,
#                                                                        'count': 3,
#                                                                        'max': 0.027,
#                                                                        'min': 0.0262,
#                                                                        'std': 0.0004,
#                                                                        'timestamp': '2024-05-07-08:36:27'}},
#  'listings_join_review_2014': {'__': {'avg': 0.1994,
#                                       'count': 3,
#                                       'max': 0.2024,
#                                       'min': 0.1973,
#                                       'std': 0.0022,
#                                       'timestamp': '2024-05-07-08:36:27'},
#                                '__date_in_reviews__': {'avg': 0.0456,
#                                                        'count': 3,
#                                                        'max': 0.056,
#                                                        'min': 0.0399,
#                                                        'std': 0.0073,
#                                                        'timestamp': '2024-05-07-08:36:29'},
#                                '__id_in_listings__': {'avg': 0.1993,
#                                                       'count': 3,
#                                                       'max': 0.1996,
#                                                       'min': 0.1991,
#                                                       'std': 0.0002,
#                                                       'timestamp': '2024-05-07-08:36:28'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0425,
#                                                                        'count': 3,
#                                                                        'max': 0.0451,
#                                                                        'min': 0.0407,
#                                                                        'std': 0.0019,
#                                                                        'timestamp': '2024-05-07-08:36:29'}},
#  'listings_join_review_2015': {'__': {'avg': 0.2093,
#                                       'count': 3,
#                                       'max': 0.2131,
#                                       'min': 0.2069,
#                                       'std': 0.0027,
#                                       'timestamp': '2024-05-07-08:36:29'},
#                                '__date_in_reviews__': {'avg': 0.0789,
#                                                        'count': 3,
#                                                        'max': 0.0973,
#                                                        'min': 0.0692,
#                                                        'std': 0.013,
#                                                        'timestamp': '2024-05-07-08:36:31'},
#                                '__id_in_listings__': {'avg': 0.2175,
#                                                       'count': 3,
#                                                       'max': 0.2239,
#                                                       'min': 0.2068,
#                                                       'std': 0.0076,
#                                                       'timestamp': '2024-05-07-08:36:30'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.07,
#                                                                        'count': 3,
#                                                                        'max': 0.0712,
#                                                                        'min': 0.0694,
#                                                                        'std': 0.0008,
#                                                                        'timestamp': '2024-05-07-08:36:31'}},
#  'listings_join_review_2016': {'__': {'avg': 0.2303,
#                                       'count': 3,
#                                       'max': 0.2348,
#                                       'min': 0.2268,
#                                       'std': 0.0033,
#                                       'timestamp': '2024-05-07-08:36:32'},
#                                '__date_in_reviews__': {'avg': 0.0755,
#                                                        'count': 3,
#                                                        'max': 0.0934,
#                                                        'min': 0.0659,
#                                                        'std': 0.0127,
#                                                        'timestamp': '2024-05-07-08:36:34'},
#                                '__id_in_listings__': {'avg': 0.239,
#                                                       'count': 3,
#                                                       'max': 0.247,
#                                                       'min': 0.2304,
#                                                       'std': 0.0068,
#                                                       'timestamp': '2024-05-07-08:36:33'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0639,
#                                                                        'count': 3,
#                                                                        'max': 0.0647,
#                                                                        'min': 0.0632,
#                                                                        'std': 0.0006,
#                                                                        'timestamp': '2024-05-07-08:36:34'}},
#  'listings_join_review_2017': {'__': {'avg': 0.2658,
#                                       'count': 3,
#                                       'max': 0.2873,
#                                       'min': 0.2539,
#                                       'std': 0.0153,
#                                       'timestamp': '2024-05-07-08:36:35'},
#                                '__date_in_reviews__': {'avg': 0.113,
#                                                        'count': 3,
#                                                        'max': 0.1197,
#                                                        'min': 0.1071,
#                                                        'std': 0.0051,
#                                                        'timestamp': '2024-05-07-08:36:37'},
#                                '__id_in_listings__': {'avg': 0.2625,
#                                                       'count': 3,
#                                                       'max': 0.292,
#                                                       'min': 0.2459,
#                                                       'std': 0.0209,
#                                                       'timestamp': '2024-05-07-08:36:36'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1105,
#                                                                        'count': 3,
#                                                                        'max': 0.1126,
#                                                                        'min': 0.1078,
#                                                                        'std': 0.002,
#                                                                        'timestamp': '2024-05-07-08:36:37'}},
#  'listings_join_review_2018': {'__': {'avg': 0.4902,
#                                       'count': 3,
#                                       'max': 0.4953,
#                                       'min': 0.487,
#                                       'std': 0.0036,
#                                       'timestamp': '2024-05-07-08:36:38'},
#                                '__date_in_reviews__': {'avg': 0.1739,
#                                                        'count': 3,
#                                                        'max': 0.1763,
#                                                        'min': 0.1696,
#                                                        'std': 0.0031,
#                                                        'timestamp': '2024-05-07-08:36:41'},
#                                '__id_in_listings__': {'avg': 0.5102,
#                                                       'count': 3,
#                                                       'max': 0.5419,
#                                                       'min': 0.494,
#                                                       'std': 0.0224,
#                                                       'timestamp': '2024-05-07-08:36:40'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1754,
#                                                                        'count': 3,
#                                                                        'max': 0.1789,
#                                                                        'min': 0.1728,
#                                                                        'std': 0.0026,
#                                                                        'timestamp': '2024-05-07-08:36:42'}},
#  'listings_join_review_2019': {'__': {'avg': 0.5061,
#                                       'count': 3,
#                                       'max': 0.5097,
#                                       'min': 0.5041,
#                                       'std': 0.0026,
#                                       'timestamp': '2024-05-07-08:36:43'},
#                                '__date_in_reviews__': {'avg': 0.5085,
#                                                        'count': 3,
#                                                        'max': 0.5118,
#                                                        'min': 0.5028,
#                                                        'std': 0.0041,
#                                                        'timestamp': '2024-05-07-08:36:47'},
#                                '__id_in_listings__': {'avg': 0.5252,
#                                                       'count': 3,
#                                                       'max': 0.5569,
#                                                       'min': 0.5058,
#                                                       'std': 0.0226,
#                                                       'timestamp': '2024-05-07-08:36:45'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.5053,
#                                                                        'count': 3,
#                                                                        'max': 0.5105,
#                                                                        'min': 0.5009,
#                                                                        'std': 0.004,
#                                                                        'timestamp': '2024-05-07-08:36:49'}},
#  'listings_join_review_2020': {'__': {'avg': 0.2332,
#                                       'count': 3,
#                                       'max': 0.2416,
#                                       'min': 0.2289,
#                                       'std': 0.0059,
#                                       'timestamp': '2024-05-07-08:36:49'},
#                                '__date_in_reviews__': {'avg': 0.0921,
#                                                        'count': 3,
#                                                        'max': 0.1272,
#                                                        'min': 0.0744,
#                                                        'std': 0.0248,
#                                                        'timestamp': '2024-05-07-08:36:51'},
#                                '__id_in_listings__': {'avg': 0.2589,
#                                                       'count': 3,
#                                                       'max': 0.2853,
#                                                       'min': 0.2436,
#                                                       'std': 0.0188,
#                                                       'timestamp': '2024-05-07-08:36:50'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0736,
#                                                                        'count': 3,
#                                                                        'max': 0.0746,
#                                                                        'min': 0.0718,
#                                                                        'std': 0.0013,
#                                                                        'timestamp': '2024-05-07-08:36:51'}},
#  'listings_join_review_2021': {'__': {'avg': 0.5111,
#                                       'count': 3,
#                                       'max': 0.5268,
#                                       'min': 0.5012,
#                                       'std': 0.0112,
#                                       'timestamp': '2024-05-07-08:36:53'},
#                                '__date_in_reviews__': {'avg': 0.2123,
#                                                        'count': 3,
#                                                        'max': 0.2421,
#                                                        'min': 0.1956,
#                                                        'std': 0.0211,
#                                                        'timestamp': '2024-05-07-08:36:56'},
#                                '__id_in_listings__': {'avg': 0.5073,
#                                                       'count': 3,
#                                                       'max': 0.5081,
#                                                       'min': 0.5062,
#                                                       'std': 0.0008,
#                                                       'timestamp': '2024-05-07-08:36:55'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1939,
#                                                                        'count': 3,
#                                                                        'max': 0.1947,
#                                                                        'min': 0.1924,
#                                                                        'std': 0.001,
#                                                                        'timestamp': '2024-05-07-08:36:57'}},
#  'listings_join_review_2022': {'__': {'avg': 0.5664,
#                                       'count': 3,
#                                       'max': 0.5969,
#                                       'min': 0.5496,
#                                       'std': 0.0216,
#                                       'timestamp': '2024-05-07-08:36:58'},
#                                '__date_in_reviews__': {'avg': 0.5687,
#                                                        'count': 3,
#                                                        'max': 0.608,
#                                                        'min': 0.5477,
#                                                        'std': 0.0278,
#                                                        'timestamp': '2024-05-07-08:37:02'},
#                                '__id_in_listings__': {'avg': 0.5479,
#                                                       'count': 3,
#                                                       'max': 0.5498,
#                                                       'min': 0.5445,
#                                                       'std': 0.0024,
#                                                       'timestamp': '2024-05-07-08:37:00'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.55,
#                                                                        'count': 3,
#                                                                        'max': 0.5563,
#                                                                        'min': 0.5463,
#                                                                        'std': 0.0045,
#                                                                        'timestamp': '2024-05-07-08:37:04'}},
#  'listings_join_review_2023': {'__': {'avg': 0.2982,
#                                       'count': 3,
#                                       'max': 0.3336,
#                                       'min': 0.2793,
#                                       'std': 0.0251,
#                                       'timestamp': '2024-05-07-08:37:05'},
#                                '__date_in_reviews__': {'avg': 0.2869,
#                                                        'count': 3,
#                                                        'max': 0.3119,
#                                                        'min': 0.2721,
#                                                        'std': 0.0178,
#                                                        'timestamp': '2024-05-07-08:37:07'},
#                                '__id_in_listings__': {'avg': 0.2893,
#                                                       'count': 3,
#                                                       'max': 0.3264,
#                                                       'min': 0.27,
#                                                       'std': 0.0263,
#                                                       'timestamp': '2024-05-07-08:37:06'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.278,
#                                                                        'count': 3,
#                                                                        'max': 0.2844,
#                                                                        'min': 0.2736,
#                                                                        'std': 0.0046,
#                                                                        'timestamp': '2024-05-07-08:37:08'}},
#  'listings_join_review_2024': {'__': {'avg': 0.2054,
#                                       'count': 3,
#                                       'max': 0.2071,
#                                       'min': 0.2032,
#                                       'std': 0.0016,
#                                       'timestamp': '2024-05-07-08:37:09'},
#                                '__date_in_reviews__': {'avg': 0.0396,
#                                                        'count': 3,
#                                                        'max': 0.0504,
#                                                        'min': 0.0328,
#                                                        'std': 0.0077,
#                                                        'timestamp': '2024-05-07-08:37:10'},
#                                '__id_in_listings__': {'avg': 0.2029,
#                                                       'count': 3,
#                                                       'max': 0.2059,
#                                                       'min': 0.1992,
#                                                       'std': 0.0028,
#                                                       'timestamp': '2024-05-07-08:37:10'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.035,
#                                                                        'count': 3,
#                                                                        'max': 0.0355,
#                                                                        'min': 0.0346,
#                                                                        'std': 0.0004,
#                                                                        'timestamp': '2024-05-07-08:37:11'}},
#  'listings_join_reviews_2013': {'__': {'avg': 0.0238,
#                                        'max': 0.0327,
#                                        'min': 0.0215,
#                                        'std': 0.0023,
#                                        'timestamp': '2024-05-05-23:38:22'},
#                                 '__date_in_reviews__': {'avg': 0.0234,
#                                                         'max': 0.0265,
#                                                         'min': 0.022,
#                                                         'std': 0.0008,
#                                                         'timestamp': '2024-05-05-23:38:25'},
#                                 '__id_in_listings__': {'avg': 0.0235,
#                                                        'max': 0.026,
#                                                        'min': 0.0217,
#                                                        'std': 0.001,
#                                                        'timestamp': '2024-05-05-23:38:24'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.0232,
#                                                                         'max': 0.0262,
#                                                                         'min': 0.0217,
#                                                                         'std': 0.001,
#                                                                         'timestamp': '2024-05-05-23:38:26'}},
#  'listings_join_reviews_2014': {'__': {'avg': 0.0326,
#                                        'max': 0.1238,
#                                        'min': 0.0289,
#                                        'std': 0.0131,
#                                        'timestamp': '2024-05-05-23:37:16'},
#                                 '__date_in_reviews__': {'avg': 0.0316,
#                                                         'max': 0.035,
#                                                         'min': 0.029,
#                                                         'std': 0.0011,
#                                                         'timestamp': '2024-05-05-23:37:19'},
#                                 '__id_in_listings__': {'avg': 0.0311,
#                                                        'max': 0.0328,
#                                                        'min': 0.0297,
#                                                        'std': 0.0008,
#                                                        'timestamp': '2024-05-05-23:37:18'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.0319,
#                                                                         'max': 0.0355,
#                                                                         'min': 0.0301,
#                                                                         'std': 0.0013,
#                                                                         'timestamp': '2024-05-05-23:37:21'}},
#  'listings_join_reviews_2015': {'__': {'avg': 0.1274,
#                                        'max': 0.1654,
#                                        'min': 0.1179,
#                                        'std': 0.0083,
#                                        'timestamp': '2024-05-05-23:11:16'},
#                                 '__date_in_reviews__': {'avg': 0.0485,
#                                                         'max': 0.0549,
#                                                         'min': 0.0457,
#                                                         'std': 0.002,
#                                                         'timestamp': '2024-05-05-23:11:25'},
#                                 '__id_in_listings__': {'avg': 0.1212,
#                                                        'max': 0.1354,
#                                                        'min': 0.1169,
#                                                        'std': 0.0037,
#                                                        'timestamp': '2024-05-05-23:11:22'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.05,
#                                                                         'max': 0.0537,
#                                                                         'min': 0.0457,
#                                                                         'std': 0.0016,
#                                                                         'timestamp': '2024-05-05-23:11:28'}},
#  'listings_join_reviews_2017': {'__': {'avg': 0.1473,
#                                        'max': 0.1882,
#                                        'min': 0.1404,
#                                        'std': 0.0099,
#                                        'timestamp': '2024-05-06-09:14:06'},
#                                 '__date_in_reviews__': {'avg': 0.1141,
#                                                         'max': 0.1645,
#                                                         'min': 0.1063,
#                                                         'std': 0.0129,
#                                                         'timestamp': '2024-05-06-09:14:20'},
#                                 '__id_in_listings__': {'avg': 0.1521,
#                                                        'max': 0.1677,
#                                                        'min': 0.1427,
#                                                        'std': 0.0059,
#                                                        'timestamp': '2024-05-06-09:14:14'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.1108,
#                                                                         'max': 0.1473,
#                                                                         'min': 0.1037,
#                                                                         'std': 0.0086,
#                                                                         'timestamp': '2024-05-06-09:14:26'}},
#  'listings_join_reviews_2019': {'__': {'avg': 0.5277,
#                                        'count': 3,
#                                        'max': 0.5566,
#                                        'min': 0.5092,
#                                        'std': 0.0207,
#                                        'timestamp': '2024-05-07-08:37:12'},
#                                 '__date_in_reviews__': {'avg': 0.5125,
#                                                         'count': 3,
#                                                         'max': 0.5197,
#                                                         'min': 0.5029,
#                                                         'std': 0.0071,
#                                                         'timestamp': '2024-05-07-08:37:16'},
#                                 '__id_in_listings__': {'avg': 0.5147,
#                                                        'count': 3,
#                                                        'max': 0.5228,
#                                                        'min': 0.5106,
#                                                        'std': 0.0057,
#                                                        'timestamp': '2024-05-07-08:37:14'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.5279,
#                                                                         'count': 3,
#                                                                         'max': 0.5622,
#                                                                         'min': 0.5106,
#                                                                         'std': 0.0243,
#                                                                         'timestamp': '2024-05-07-08:37:18'}}}

# %% [markdown]
# ### <span style=color:blue>Working with text indexing</span>

# %% [markdown]
# <span style=color:blue>First, here are examples of the 2 kinds of query we are working with.  I might decide to ask the students to experiment with a second word.  (I need to find a word with different behavior!)</span>
#
# ### <span style=color:blue>NOTE: please see the double "%%" in the first query -- this is a kind of escape character so that sqlalchemy will be able to work with the "%" signs.  </span>

# %%
word = 'awesome'
start_date = '2015-01-01'
end_date = '2015-12-31'

q1 = util.build_query_reviews_no_index(word, start_date, end_date)
q2 = util.build_query_reviews_ts(word, start_date, end_date)

print('q1 is:')
print(q1)
print('\nq2 is:')
print(q2)
# Out:
# q1 is:
# SELECT *
# FROM reviews r
# WHERE comments ILIKE '%%awesome%%'
#   AND date >= '2015-01-01'
#   AND date <= '2015-12-31';
#
# q2 is:
# SELECT *
# FROM reviews r
# WHERE comments_tsv @@ to_tsquery('awesome')
#   AND date >= '2015-01-01'
#   AND date <= '2015-12-31';

# %% [markdown]
# <span style=color:blue>The next cell generates the file 'ts_pef_test_v01.json'<span>
#
# <span style=color:blue>For these experiments the "no-index" case is making a search against the comments column of reviews, whereas the "with-index" case is making a search against the comments_tsv column of reviews.  So I don't need to drop the index on comments_tsv when running the "no-index" case.  This makes it simpler than the b-tree situation</span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

perf_file = 'ts_perf_test_v01.json'

# using a low count so that the query without index runs reasonably quickly
count = 3

word = 'awesome'

# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    print('\nEntering loop for yr = ', str(yr))
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    perf_info = util.run_one_text_query_without_with_tsindex(db_eng, word, date_start, date_end, count)
    print('perf_file for the run for  is:')
    pprint.pp(perf_info)
    updated_perf_summary = util.fetch_and_update_ts_perf_data(perf_file, perf_info)

print('After running all years, the updated perf_summary file is:')
pprint.pp(updated_perf_summary)
# Out:
# Entering loop for yr =  2009
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0077,
#  'min': 0.0043,
#  'max': 0.0138,
#  'std': 0.0043,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0122,
#  'min': 0.0023,
#  'max': 0.0305,
#  'std': 0.013,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# perf_file for the run for  is:
# {'awesome_2009': {'no_index': {'avg': 0.0077,
#                                'min': 0.0043,
#                                'max': 0.0138,
#                                'std': 0.0043,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0122,
#                                     'min': 0.0023,
#                                     'max': 0.0305,
#                                     'std': 0.013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}}}
#
# Entering loop for yr =  2010
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0059,
#  'min': 0.0051,
#  'max': 0.0064,
#  'std': 0.0005,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0058,
#  'min': 0.0031,
#  'max': 0.0101,
#  'std': 0.003,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# perf_file for the run for  is:
# {'awesome_2010': {'no_index': {'avg': 0.0059,
#                                'min': 0.0051,
#                                'max': 0.0064,
#                                'std': 0.0005,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0058,
#                                     'min': 0.0031,
#                                     'max': 0.0101,
#                                     'std': 0.003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}}}
#
# Entering loop for yr =  2011
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0172,
#  'min': 0.0121,
#  'max': 0.0246,
#  'std': 0.0054,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0135,
#  'min': 0.0059,
#  'max': 0.0268,
#  'std': 0.0095,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# perf_file for the run for  is:
# {'awesome_2011': {'no_index': {'avg': 0.0172,
#                                'min': 0.0121,
#                                'max': 0.0246,
#                                'std': 0.0054,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0135,
#                                     'min': 0.0059,
#                                     'max': 0.0268,
#                                     'std': 0.0095,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}}}
#
# Entering loop for yr =  2012
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0343,
#  'min': 0.0255,
#  'max': 0.0519,
#  'std': 0.0124,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0248,
#  'min': 0.0109,
#  'max': 0.0513,
#  'std': 0.0187,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# perf_file for the run for  is:
# {'awesome_2012': {'no_index': {'avg': 0.0343,
#                                'min': 0.0255,
#                                'max': 0.0519,
#                                'std': 0.0124,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0248,
#                                     'min': 0.0109,
#                                     'max': 0.0513,
#                                     'std': 0.0187,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}}}
#
# Entering loop for yr =  2013
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.063,
#  'min': 0.045,
#  'max': 0.0937,
#  'std': 0.0218,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.04,
#  'min': 0.0202,
#  'max': 0.0796,
#  'std': 0.028,
#  'count': 3,
#  'timestamp': '2024-05-07-08:41:59'}
# perf_file for the run for  is:
# {'awesome_2013': {'no_index': {'avg': 0.063,
#                                'min': 0.045,
#                                'max': 0.0937,
#                                'std': 0.0218,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.04,
#                                     'min': 0.0202,
#                                     'max': 0.0796,
#                                     'std': 0.028,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}}}
#
# Entering loop for yr =  2014
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1123,
#  'min': 0.0825,
#  'max': 0.1711,
#  'std': 0.0416,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:00'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0737,
#  'min': 0.0405,
#  'max': 0.1398,
#  'std': 0.0467,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:00'}
# perf_file for the run for  is:
# {'awesome_2014': {'no_index': {'avg': 0.1123,
#                                'min': 0.0825,
#                                'max': 0.1711,
#                                'std': 0.0416,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:00'},
#                   'with_ts_index': {'avg': 0.0737,
#                                     'min': 0.0405,
#                                     'max': 0.1398,
#                                     'std': 0.0467,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:00'}}}
#
# Entering loop for yr =  2015
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1999,
#  'min': 0.1543,
#  'max': 0.2868,
#  'std': 0.0615,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:01'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1281,
#  'min': 0.0758,
#  'max': 0.2296,
#  'std': 0.0718,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:01'}
# perf_file for the run for  is:
# {'awesome_2015': {'no_index': {'avg': 0.1999,
#                                'min': 0.1543,
#                                'max': 0.2868,
#                                'std': 0.0615,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:01'},
#                   'with_ts_index': {'avg': 0.1281,
#                                     'min': 0.0758,
#                                     'max': 0.2296,
#                                     'std': 0.0718,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:01'}}}
#
# Entering loop for yr =  2016
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2706,
#  'min': 0.2353,
#  'max': 0.3355,
#  'std': 0.046,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:02'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0824,
#  'min': 0.064,
#  'max': 0.1186,
#  'std': 0.0256,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:02'}
# perf_file for the run for  is:
# {'awesome_2016': {'no_index': {'avg': 0.2706,
#                                'min': 0.2353,
#                                'max': 0.3355,
#                                'std': 0.046,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:02'},
#                   'with_ts_index': {'avg': 0.0824,
#                                     'min': 0.064,
#                                     'max': 0.1186,
#                                     'std': 0.0256,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:02'}}}
#
# Entering loop for yr =  2017
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.315,
#  'min': 0.2926,
#  'max': 0.3537,
#  'std': 0.0275,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:03'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1176,
#  'min': 0.1038,
#  'max': 0.1369,
#  'std': 0.0141,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:03'}
# perf_file for the run for  is:
# {'awesome_2017': {'no_index': {'avg': 0.315,
#                                'min': 0.2926,
#                                'max': 0.3537,
#                                'std': 0.0275,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:03'},
#                   'with_ts_index': {'avg': 0.1176,
#                                     'min': 0.1038,
#                                     'max': 0.1369,
#                                     'std': 0.0141,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:03'}}}
#
# Entering loop for yr =  2018
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1993,
#  'min': 0.1921,
#  'max': 0.2069,
#  'std': 0.006,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:04'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1495,
#  'min': 0.1391,
#  'max': 0.1651,
#  'std': 0.0112,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:04'}
# perf_file for the run for  is:
# {'awesome_2018': {'no_index': {'avg': 0.1993,
#                                'min': 0.1921,
#                                'max': 0.2069,
#                                'std': 0.006,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:04'},
#                   'with_ts_index': {'avg': 0.1495,
#                                     'min': 0.1391,
#                                     'max': 0.1651,
#                                     'std': 0.0112,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:04'}}}
#
# Entering loop for yr =  2019
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2714,
#  'min': 1.2402,
#  'max': 1.3119,
#  'std': 0.03,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:08'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2045,
#  'min': 0.1762,
#  'max': 0.2442,
#  'std': 0.0289,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:09'}
# perf_file for the run for  is:
# {'awesome_2019': {'no_index': {'avg': 1.2714,
#                                'min': 1.2402,
#                                'max': 1.3119,
#                                'std': 0.03,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:08'},
#                   'with_ts_index': {'avg': 0.2045,
#                                     'min': 0.1762,
#                                     'max': 0.2442,
#                                     'std': 0.0289,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:09'}}}
#
# Entering loop for yr =  2020
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1848,
#  'min': 0.1676,
#  'max': 0.2184,
#  'std': 0.0237,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:09'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0699,
#  'min': 0.0655,
#  'max': 0.0737,
#  'std': 0.0034,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:10'}
# perf_file for the run for  is:
# {'awesome_2020': {'no_index': {'avg': 0.1848,
#                                'min': 0.1676,
#                                'max': 0.2184,
#                                'std': 0.0237,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:09'},
#                   'with_ts_index': {'avg': 0.0699,
#                                     'min': 0.0655,
#                                     'max': 0.0737,
#                                     'std': 0.0034,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:10'}}}
#
# Entering loop for yr =  2021
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2536,
#  'min': 1.2492,
#  'max': 1.2583,
#  'std': 0.0037,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:13'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.163,
#  'min': 0.1535,
#  'max': 0.1815,
#  'std': 0.0131,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:14'}
# perf_file for the run for  is:
# {'awesome_2021': {'no_index': {'avg': 1.2536,
#                                'min': 1.2492,
#                                'max': 1.2583,
#                                'std': 0.0037,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:13'},
#                   'with_ts_index': {'avg': 0.163,
#                                     'min': 0.1535,
#                                     'max': 0.1815,
#                                     'std': 0.0131,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:14'}}}
#
# Entering loop for yr =  2022
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.273,
#  'min': 1.2625,
#  'max': 1.2893,
#  'std': 0.0116,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:18'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.3318,
#  'min': 0.2873,
#  'max': 0.3959,
#  'std': 0.0464,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:19'}
# perf_file for the run for  is:
# {'awesome_2022': {'no_index': {'avg': 1.273,
#                                'min': 1.2625,
#                                'max': 1.2893,
#                                'std': 0.0116,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:18'},
#                   'with_ts_index': {'avg': 0.3318,
#                                     'min': 0.2873,
#                                     'max': 0.3959,
#                                     'std': 0.0464,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:19'}}}
#
# Entering loop for yr =  2023
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.4878,
#  'min': 1.417,
#  'max': 1.5713,
#  'std': 0.0636,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:23'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.3333,
#  'min': 0.3125,
#  'max': 0.3611,
#  'std': 0.0204,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:24'}
# perf_file for the run for  is:
# {'awesome_2023': {'no_index': {'avg': 1.4878,
#                                'min': 1.417,
#                                'max': 1.5713,
#                                'std': 0.0636,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:23'},
#                   'with_ts_index': {'avg': 0.3333,
#                                     'min': 0.3125,
#                                     'max': 0.3611,
#                                     'std': 0.0204,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:24'}}}
#
# Entering loop for yr =  2024
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0368,
#  'min': 0.0345,
#  'max': 0.0413,
#  'std': 0.0032,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:24'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0224,
#  'min': 0.0215,
#  'max': 0.0238,
#  'std': 0.001,
#  'count': 3,
#  'timestamp': '2024-05-07-08:42:24'}
# perf_file for the run for  is:
# {'awesome_2024': {'no_index': {'avg': 0.0368,
#                                'min': 0.0345,
#                                'max': 0.0413,
#                                'std': 0.0032,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:24'},
#                   'with_ts_index': {'avg': 0.0224,
#                                     'min': 0.0215,
#                                     'max': 0.0238,
#                                     'std': 0.001,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:24'}}}
# After running all years, the updated perf_summary file is:
# {'awesome_2009': {'no_index': {'avg': 0.0077,
#                                'min': 0.0043,
#                                'max': 0.0138,
#                                'std': 0.0043,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0122,
#                                     'min': 0.0023,
#                                     'max': 0.0305,
#                                     'std': 0.013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}},
#  'awesome_2010': {'no_index': {'avg': 0.0059,
#                                'min': 0.0051,
#                                'max': 0.0064,
#                                'std': 0.0005,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0058,
#                                     'min': 0.0031,
#                                     'max': 0.0101,
#                                     'std': 0.003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}},
#  'awesome_2011': {'no_index': {'avg': 0.0172,
#                                'min': 0.0121,
#                                'max': 0.0246,
#                                'std': 0.0054,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0135,
#                                     'min': 0.0059,
#                                     'max': 0.0268,
#                                     'std': 0.0095,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}},
#  'awesome_2012': {'no_index': {'avg': 0.0343,
#                                'min': 0.0255,
#                                'max': 0.0519,
#                                'std': 0.0124,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.0248,
#                                     'min': 0.0109,
#                                     'max': 0.0513,
#                                     'std': 0.0187,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}},
#  'awesome_2013': {'no_index': {'avg': 0.063,
#                                'min': 0.045,
#                                'max': 0.0937,
#                                'std': 0.0218,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:41:59'},
#                   'with_ts_index': {'avg': 0.04,
#                                     'min': 0.0202,
#                                     'max': 0.0796,
#                                     'std': 0.028,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:41:59'}},
#  'awesome_2014': {'no_index': {'avg': 0.1123,
#                                'min': 0.0825,
#                                'max': 0.1711,
#                                'std': 0.0416,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:00'},
#                   'with_ts_index': {'avg': 0.0737,
#                                     'min': 0.0405,
#                                     'max': 0.1398,
#                                     'std': 0.0467,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:00'}},
#  'awesome_2015': {'no_index': {'avg': 0.1999,
#                                'min': 0.1543,
#                                'max': 0.2868,
#                                'std': 0.0615,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:01'},
#                   'with_ts_index': {'avg': 0.1281,
#                                     'min': 0.0758,
#                                     'max': 0.2296,
#                                     'std': 0.0718,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:01'}},
#  'awesome_2016': {'no_index': {'avg': 0.2706,
#                                'min': 0.2353,
#                                'max': 0.3355,
#                                'std': 0.046,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:02'},
#                   'with_ts_index': {'avg': 0.0824,
#                                     'min': 0.064,
#                                     'max': 0.1186,
#                                     'std': 0.0256,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:02'}},
#  'awesome_2017': {'no_index': {'avg': 0.315,
#                                'min': 0.2926,
#                                'max': 0.3537,
#                                'std': 0.0275,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:03'},
#                   'with_ts_index': {'avg': 0.1176,
#                                     'min': 0.1038,
#                                     'max': 0.1369,
#                                     'std': 0.0141,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:03'}},
#  'awesome_2018': {'no_index': {'avg': 0.1993,
#                                'min': 0.1921,
#                                'max': 0.2069,
#                                'std': 0.006,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:04'},
#                   'with_ts_index': {'avg': 0.1495,
#                                     'min': 0.1391,
#                                     'max': 0.1651,
#                                     'std': 0.0112,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:04'}},
#  'awesome_2019': {'no_index': {'avg': 1.2714,
#                                'min': 1.2402,
#                                'max': 1.3119,
#                                'std': 0.03,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:08'},
#                   'with_ts_index': {'avg': 0.2045,
#                                     'min': 0.1762,
#                                     'max': 0.2442,
#                                     'std': 0.0289,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:09'}},
#  'awesome_2020': {'no_index': {'avg': 0.1848,
#                                'min': 0.1676,
#                                'max': 0.2184,
#                                'std': 0.0237,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:09'},
#                   'with_ts_index': {'avg': 0.0699,
#                                     'min': 0.0655,
#                                     'max': 0.0737,
#                                     'std': 0.0034,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:10'}},
#  'awesome_2021': {'no_index': {'avg': 1.2536,
#                                'min': 1.2492,
#                                'max': 1.2583,
#                                'std': 0.0037,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:13'},
#                   'with_ts_index': {'avg': 0.163,
#                                     'min': 0.1535,
#                                     'max': 0.1815,
#                                     'std': 0.0131,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:14'}},
#  'awesome_2022': {'no_index': {'avg': 1.273,
#                                'min': 1.2625,
#                                'max': 1.2893,
#                                'std': 0.0116,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:18'},
#                   'with_ts_index': {'avg': 0.3318,
#                                     'min': 0.2873,
#                                     'max': 0.3959,
#                                     'std': 0.0464,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:19'}},
#  'awesome_2023': {'no_index': {'avg': 1.4878,
#                                'min': 1.417,
#                                'max': 1.5713,
#                                'std': 0.0636,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:23'},
#                   'with_ts_index': {'avg': 0.3333,
#                                     'min': 0.3125,
#                                     'max': 0.3611,
#                                     'std': 0.0204,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:24'}},
#  'awesome_2024': {'no_index': {'avg': 0.0368,
#                                'min': 0.0345,
#                                'max': 0.0413,
#                                'std': 0.0032,
#                                'count': 3,
#                                'timestamp': '2024-05-07-08:42:24'},
#                   'with_ts_index': {'avg': 0.0224,
#                                     'min': 0.0215,
#                                     'max': 0.0238,
#                                     'std': 0.001,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-08:42:24'}}}
