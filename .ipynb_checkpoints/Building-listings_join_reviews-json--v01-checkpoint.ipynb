# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>Cleaning up indexes before working to build reviews_join_listings.json </span>
#
# <span style=color:blue>This cell illustrates a few things.  First, I have a list of "all_indexes" which holds most (but actually not all) of the indexes I have been using; this includes all indexes used when building the three .json files.  I do not list comments_tsv_in_reviews in all_indexes, because comments_tsv_in_reviews gets special treatment, and once created is never dropped.  </span>
#
# <span style=color:blue>In this cell I drop all the indexes in all_indexes, and check that everything (except for comments_tsv_in_reviews) has been dropped.</span>

# %%
all_indexes = [['datetime','reviews'], 
               ['id','listings'],
               ['neighbourhood','listings'], 
               ['neighbourhood_group','listings'],
               ['price','listings']]                 # used when I was playing with price ranges

for i_spec in all_indexes:
    result = util.add_drop_index(db_eng, 'drop', i_spec)
    print('Inside the loop, here is the result of calling add_drop_index on the table "' \
          + str(i_spec[1]) + '"')
    # Note: add_drop_index is called multiple times for some tables
    # Also, when creating this notebook I have run this cell multiple times, so the indexes are already flushed out
    pprint.pp(result)

print('\n\nCurrent set of indexes in effect is:')
indexes_in_effect = util.fetch_all_index_info(db_eng, all_indexes)
pprint.pp(indexes_in_effect, width=150)
# Out:
# Inside the loop, here is the result of calling add_drop_index on the table "reviews"
# [('new_york_city', 'reviews', 'comments_tsv_in_reviews', None, 'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)')]
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# [('new_york_city', 'listings', 'neighbourhood_group_in_listings', None, 'CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)')]
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# [('new_york_city', 'listings', 'neighbourhood_group_in_listings', None, 'CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)')]
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# []
# Inside the loop, here is the result of calling add_drop_index on the table "listings"
# []
#
#
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}

# %% [markdown]
# ### <span style=color:blue>Now working to build the file listings_in_reviews.json    </span>

# %% [markdown]
# <span style=color:blue>First step is to build up a dictionary of the queries to be used</span>

# %%
q_dict = {}
# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    q_name = 'listings_join_reviews_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_join_reviews(date_start, date_end)
# pprint.pp(q_dict)

pprint.pp(q_dict['listings_join_reviews_2015'])
# Out:
# ('SELECT DISTINCT l.id, l.name\n'
#  'FROM listings l, reviews r \n'
#  'WHERE l.id = r.listing_id\n'
#  "  AND r.datetime >= '2015-01-01'\n"
#  "  AND r.datetime <= '2015-12-31'\n"
#  'ORDER BY l.id;')

# %% [markdown]
# <span style=color:blue>Now invoking a loop that will build the file</span>

# %%
# keeping all_indexes in this cell, in case I run the cell stand-alone during development 
all_indexes = [['datetime','reviews'], 
               ['id','listings'],
               ['neighbourhood','listings'], 
               ['neighbourhood_group','listings'],
               ['price','listings']]                 # used when I was playing with price ranges

i_spec_list = [['datetime','reviews'], ['id', 'listings']]

perf_file = 'listings_join_reviews_on_mac_v02.json'

# setting count to 3 for now so that things run faster
count = 50

for q in q_dict:    # for testing, replace q_dict with : ['listings_join_reviews_2015']:
    print('\n====>>> Now working on query:', q)
    perf_summary = util.run_one_query_and_multi_index_specs(db_eng, all_indexes, q, q_dict[q], i_spec_list, count)
    # print('\nThe perf_summary of running query', q, 'is as follows:') 
    # pprint.pp(perf_summary)
    updated_perf_summary = util.fetch_and_update_perf_data_deeper_merge(perf_file, perf_summary)

print('\nThe value of updated perf_summary is:')
pprint.pp(updated_perf_summary, sort_dicts=True)
# Out:
# ====>>> Now working on query: listings_join_reviews_2009
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
# Not successful in finding file perf_data/listings_join_reviews_on_mac_v02.json; so creating it
#
# ====>>> Now working on query: listings_join_reviews_2010
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2011
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2012
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2013
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2014
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2015
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2016
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2017
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2018
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2020
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2021
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2022
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2023
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2024
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# The value of updated perf_summary is:
# {'listings_join_reviews_2009': {'__': {'avg': 0.3367,
#                                        'exec_count': 50,
#                                        'max': 3.7037,
#                                        'min': 0.242,
#                                        'std': 0.4821,
#                                        'timestamp': '2024-05-10-18:31:16'},
#                                 '__datetime_in_reviews__': {'avg': 0.0143,
#                                                             'exec_count': 50,
#                                                             'max': 0.0223,
#                                                             'min': 0.013,
#                                                             'std': 0.0014,
#                                                             'timestamp': '2024-05-10-18:31:18'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0144,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0176,
#                                                                             'min': 0.0132,
#                                                                             'std': 0.0008,
#                                                                             'timestamp': '2024-05-10-18:31:31'},
#                                 '__id_in_listings__': {'avg': 0.2337,
#                                                        'exec_count': 50,
#                                                        'max': 0.2685,
#                                                        'min': 0.219,
#                                                        'std': 0.0119,
#                                                        'timestamp': '2024-05-10-18:31:30'}},
#  'listings_join_reviews_2010': {'__': {'avg': 0.2415,
#                                        'exec_count': 50,
#                                        'max': 0.2777,
#                                        'min': 0.2316,
#                                        'std': 0.0112,
#                                        'timestamp': '2024-05-10-18:31:43'},
#                                 '__datetime_in_reviews__': {'avg': 0.0163,
#                                                             'exec_count': 50,
#                                                             'max': 0.0399,
#                                                             'min': 0.0134,
#                                                             'std': 0.0041,
#                                                             'timestamp': '2024-05-10-18:31:45'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0154,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0215,
#                                                                             'min': 0.0137,
#                                                                             'std': 0.0014,
#                                                                             'timestamp': '2024-05-10-18:31:58'},
#                                 '__id_in_listings__': {'avg': 0.2368,
#                                                        'exec_count': 50,
#                                                        'max': 0.2552,
#                                                        'min': 0.2299,
#                                                        'std': 0.0058,
#                                                        'timestamp': '2024-05-10-18:31:57'}},
#  'listings_join_reviews_2011': {'__': {'avg': 0.2488,
#                                        'exec_count': 50,
#                                        'max': 0.2912,
#                                        'min': 0.2267,
#                                        'std': 0.0148,
#                                        'timestamp': '2024-05-10-18:32:11'},
#                                 '__datetime_in_reviews__': {'avg': 0.0168,
#                                                             'exec_count': 50,
#                                                             'max': 0.0227,
#                                                             'min': 0.0155,
#                                                             'std': 0.0011,
#                                                             'timestamp': '2024-05-10-18:32:12'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0169,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0194,
#                                                                             'min': 0.0153,
#                                                                             'std': 0.0009,
#                                                                             'timestamp': '2024-05-10-18:32:26'},
#                                 '__id_in_listings__': {'avg': 0.2442,
#                                                        'exec_count': 50,
#                                                        'max': 0.3138,
#                                                        'min': 0.2322,
#                                                        'std': 0.0134,
#                                                        'timestamp': '2024-05-10-18:32:24'}},
#  'listings_join_reviews_2012': {'__': {'avg': 0.2493,
#                                        'exec_count': 50,
#                                        'max': 0.2818,
#                                        'min': 0.2354,
#                                        'std': 0.0094,
#                                        'timestamp': '2024-05-10-18:32:38'},
#                                 '__datetime_in_reviews__': {'avg': 0.02,
#                                                             'exec_count': 50,
#                                                             'max': 0.0285,
#                                                             'min': 0.0179,
#                                                             'std': 0.0017,
#                                                             'timestamp': '2024-05-10-18:32:40'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0193,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0235,
#                                                                             'min': 0.0177,
#                                                                             'std': 0.001,
#                                                                             'timestamp': '2024-05-10-18:32:54'},
#                                 '__id_in_listings__': {'avg': 0.248,
#                                                        'exec_count': 50,
#                                                        'max': 0.2627,
#                                                        'min': 0.2353,
#                                                        'std': 0.0068,
#                                                        'timestamp': '2024-05-10-18:32:53'}},
#  'listings_join_reviews_2013': {'__': {'avg': 0.2447,
#                                        'exec_count': 50,
#                                        'max': 0.2777,
#                                        'min': 0.2343,
#                                        'std': 0.0087,
#                                        'timestamp': '2024-05-10-18:33:07'},
#                                 '__datetime_in_reviews__': {'avg': 0.0238,
#                                                             'exec_count': 50,
#                                                             'max': 0.0351,
#                                                             'min': 0.0221,
#                                                             'std': 0.0018,
#                                                             'timestamp': '2024-05-10-18:33:09'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0246,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0346,
#                                                                             'min': 0.0226,
#                                                                             'std': 0.0021,
#                                                                             'timestamp': '2024-05-10-18:33:23'},
#                                 '__id_in_listings__': {'avg': 0.2546,
#                                                        'exec_count': 50,
#                                                        'max': 0.3399,
#                                                        'min': 0.2369,
#                                                        'std': 0.0188,
#                                                        'timestamp': '2024-05-10-18:33:21'}},
#  'listings_join_reviews_2014': {'__': {'avg': 0.2651,
#                                        'exec_count': 50,
#                                        'max': 0.3247,
#                                        'min': 0.2424,
#                                        'std': 0.0172,
#                                        'timestamp': '2024-05-10-18:33:36'},
#                                 '__datetime_in_reviews__': {'avg': 0.0344,
#                                                             'exec_count': 50,
#                                                             'max': 0.0773,
#                                                             'min': 0.0307,
#                                                             'std': 0.0068,
#                                                             'timestamp': '2024-05-10-18:33:39'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0332,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0409,
#                                                                             'min': 0.0307,
#                                                                             'std': 0.0015,
#                                                                             'timestamp': '2024-05-10-18:33:54'},
#                                 '__id_in_listings__': {'avg': 0.2552,
#                                                        'exec_count': 50,
#                                                        'max': 0.2744,
#                                                        'min': 0.2369,
#                                                        'std': 0.0076,
#                                                        'timestamp': '2024-05-10-18:33:52'}},
#  'listings_join_reviews_2015': {'__': {'avg': 0.287,
#                                        'exec_count': 50,
#                                        'max': 0.4063,
#                                        'min': 0.2595,
#                                        'std': 0.0369,
#                                        'timestamp': '2024-05-10-18:34:08'},
#                                 '__datetime_in_reviews__': {'avg': 0.0533,
#                                                             'exec_count': 50,
#                                                             'max': 0.0862,
#                                                             'min': 0.0495,
#                                                             'std': 0.0049,
#                                                             'timestamp': '2024-05-10-18:34:12'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.054,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0607,
#                                                                             'min': 0.0507,
#                                                                             'std': 0.0021,
#                                                                             'timestamp': '2024-05-10-18:34:30'},
#                                 '__id_in_listings__': {'avg': 0.2956,
#                                                        'exec_count': 50,
#                                                        'max': 0.4164,
#                                                        'min': 0.2655,
#                                                        'std': 0.0331,
#                                                        'timestamp': '2024-05-10-18:34:27'}},
#  'listings_join_reviews_2016': {'__': {'avg': 0.2924,
#                                        'exec_count': 50,
#                                        'max': 0.3335,
#                                        'min': 0.2747,
#                                        'std': 0.0142,
#                                        'timestamp': '2024-05-10-18:34:45'},
#                                 '__datetime_in_reviews__': {'avg': 0.0698,
#                                                             'exec_count': 50,
#                                                             'max': 0.1158,
#                                                             'min': 0.064,
#                                                             'std': 0.0118,
#                                                             'timestamp': '2024-05-10-18:34:49'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0702,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.1174,
#                                                                             'min': 0.0645,
#                                                                             'std': 0.0115,
#                                                                             'timestamp': '2024-05-10-18:35:08'},
#                                 '__id_in_listings__': {'avg': 0.2938,
#                                                        'exec_count': 50,
#                                                        'max': 0.3396,
#                                                        'min': 0.2822,
#                                                        'std': 0.0114,
#                                                        'timestamp': '2024-05-10-18:35:04'}},
#  'listings_join_reviews_2017': {'__': {'avg': 0.3071,
#                                        'exec_count': 50,
#                                        'max': 0.3439,
#                                        'min': 0.2873,
#                                        'std': 0.0115,
#                                        'timestamp': '2024-05-10-18:35:24'},
#                                 '__datetime_in_reviews__': {'avg': 0.1493,
#                                                             'exec_count': 50,
#                                                             'max': 0.1533,
#                                                             'min': 0.1461,
#                                                             'std': 0.0017,
#                                                             'timestamp': '2024-05-10-18:35:32'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.1472,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.153,
#                                                                             'min': 0.1441,
#                                                                             'std': 0.0016,
#                                                                             'timestamp': '2024-05-10-18:35:56'},
#                                 '__id_in_listings__': {'avg': 0.3127,
#                                                        'exec_count': 50,
#                                                        'max': 0.372,
#                                                        'min': 0.2952,
#                                                        'std': 0.0141,
#                                                        'timestamp': '2024-05-10-18:35:47'}},
#  'listings_join_reviews_2018': {'__': {'avg': 0.6324,
#                                        'exec_count': 50,
#                                        'max': 0.6798,
#                                        'min': 0.6191,
#                                        'std': 0.0128,
#                                        'timestamp': '2024-05-10-18:36:27'},
#                                 '__datetime_in_reviews__': {'avg': 0.1925,
#                                                             'exec_count': 50,
#                                                             'max': 0.2377,
#                                                             'min': 0.1864,
#                                                             'std': 0.0111,
#                                                             'timestamp': '2024-05-10-18:36:38'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.1954,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.2408,
#                                                                             'min': 0.1874,
#                                                                             'std': 0.0114,
#                                                                             'timestamp': '2024-05-10-18:37:20'},
#                                 '__id_in_listings__': {'avg': 0.6418,
#                                                        'exec_count': 50,
#                                                        'max': 0.6907,
#                                                        'min': 0.6137,
#                                                        'std': 0.0154,
#                                                        'timestamp': '2024-05-10-18:37:10'}},
#  'listings_join_reviews_2019': {'__': {'avg': 0.6656,
#                                        'exec_count': 50,
#                                        'max': 0.7141,
#                                        'min': 0.6414,
#                                        'std': 0.0154,
#                                        'timestamp': '2024-05-10-18:37:54'},
#                                 '__datetime_in_reviews__': {'avg': 0.2471,
#                                                             'exec_count': 50,
#                                                             'max': 0.293,
#                                                             'min': 0.2354,
#                                                             'std': 0.0153,
#                                                             'timestamp': '2024-05-10-18:38:07'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.2485,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.3145,
#                                                                             'min': 0.2355,
#                                                                             'std': 0.0157,
#                                                                             'timestamp': '2024-05-10-18:38:54'},
#                                 '__id_in_listings__': {'avg': 0.6747,
#                                                        'exec_count': 50,
#                                                        'max': 0.7234,
#                                                        'min': 0.6522,
#                                                        'std': 0.0178,
#                                                        'timestamp': '2024-05-10-18:38:41'}},
#  'listings_join_reviews_2020': {'__': {'avg': 0.3097,
#                                        'exec_count': 50,
#                                        'max': 0.4472,
#                                        'min': 0.2876,
#                                        'std': 0.0284,
#                                        'timestamp': '2024-05-10-18:39:09'},
#                                 '__datetime_in_reviews__': {'avg': 0.1437,
#                                                             'exec_count': 50,
#                                                             'max': 0.1897,
#                                                             'min': 0.1343,
#                                                             'std': 0.0135,
#                                                             'timestamp': '2024-05-10-18:39:17'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.1431,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.1888,
#                                                                             'min': 0.1349,
#                                                                             'std': 0.013,
#                                                                             'timestamp': '2024-05-10-18:39:40'},
#                                 '__id_in_listings__': {'avg': 0.3026,
#                                                        'exec_count': 50,
#                                                        'max': 0.3507,
#                                                        'min': 0.2879,
#                                                        'std': 0.0126,
#                                                        'timestamp': '2024-05-10-18:39:32'}},
#  'listings_join_reviews_2021': {'__': {'avg': 0.6682,
#                                        'exec_count': 50,
#                                        'max': 0.7167,
#                                        'min': 0.646,
#                                        'std': 0.0162,
#                                        'timestamp': '2024-05-10-18:40:14'},
#                                 '__datetime_in_reviews__': {'avg': 0.2252,
#                                                             'exec_count': 50,
#                                                             'max': 0.2736,
#                                                             'min': 0.2144,
#                                                             'std': 0.0154,
#                                                             'timestamp': '2024-05-10-18:40:26'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.2226,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.2659,
#                                                                             'min': 0.2127,
#                                                                             'std': 0.0132,
#                                                                             'timestamp': '2024-05-10-18:41:11'},
#                                 '__id_in_listings__': {'avg': 0.667,
#                                                        'exec_count': 50,
#                                                        'max': 0.7271,
#                                                        'min': 0.646,
#                                                        'std': 0.0167,
#                                                        'timestamp': '2024-05-10-18:40:59'}},
#  'listings_join_reviews_2022': {'__': {'avg': 0.7161,
#                                        'exec_count': 50,
#                                        'max': 0.7645,
#                                        'min': 0.6857,
#                                        'std': 0.0197,
#                                        'timestamp': '2024-05-10-18:41:47'},
#                                 '__datetime_in_reviews__': {'avg': 0.7292,
#                                                             'exec_count': 50,
#                                                             'max': 0.8028,
#                                                             'min': 0.699,
#                                                             'std': 0.0268,
#                                                             'timestamp': '2024-05-10-18:42:24'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.7106,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.7544,
#                                                                             'min': 0.6899,
#                                                                             'std': 0.0201,
#                                                                             'timestamp': '2024-05-10-18:43:36'},
#                                 '__id_in_listings__': {'avg': 0.7124,
#                                                        'exec_count': 50,
#                                                        'max': 0.7628,
#                                                        'min': 0.6881,
#                                                        'std': 0.0215,
#                                                        'timestamp': '2024-05-10-18:43:00'}},
#  'listings_join_reviews_2023': {'__': {'avg': 0.7311,
#                                        'exec_count': 50,
#                                        'max': 0.7913,
#                                        'min': 0.6991,
#                                        'std': 0.0227,
#                                        'timestamp': '2024-05-10-18:44:12'},
#                                 '__datetime_in_reviews__': {'avg': 0.725,
#                                                             'exec_count': 50,
#                                                             'max': 0.7886,
#                                                             'min': 0.6954,
#                                                             'std': 0.0251,
#                                                             'timestamp': '2024-05-10-18:44:49'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.7345,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.7841,
#                                                                             'min': 0.7015,
#                                                                             'std': 0.0251,
#                                                                             'timestamp': '2024-05-10-18:46:04'},
#                                 '__id_in_listings__': {'avg': 0.7357,
#                                                        'exec_count': 50,
#                                                        'max': 0.7964,
#                                                        'min': 0.6997,
#                                                        'std': 0.0247,
#                                                        'timestamp': '2024-05-10-18:45:26'}},
#  'listings_join_reviews_2024': {'__': {'avg': 0.2575,
#                                        'exec_count': 50,
#                                        'max': 0.2977,
#                                        'min': 0.2401,
#                                        'std': 0.0121,
#                                        'timestamp': '2024-05-10-18:46:16'},
#                                 '__datetime_in_reviews__': {'avg': 0.0312,
#                                                             'exec_count': 50,
#                                                             'max': 0.0517,
#                                                             'min': 0.0288,
#                                                             'std': 0.0031,
#                                                             'timestamp': '2024-05-10-18:46:19'},
#                                 '__datetime_in_reviews__id_in_listings__': {'avg': 0.0315,
#                                                                             'exec_count': 50,
#                                                                             'max': 0.0421,
#                                                                             'min': 0.0289,
#                                                                             'std': 0.0022,
#                                                                             'timestamp': '2024-05-10-18:46:34'},
#                                 '__id_in_listings__': {'avg': 0.26,
#                                                        'exec_count': 50,
#                                                        'max': 0.3024,
#                                                        'min': 0.2451,
#                                                        'std': 0.0116,
#                                                        'timestamp': '2024-05-10-18:46:32'}}}
