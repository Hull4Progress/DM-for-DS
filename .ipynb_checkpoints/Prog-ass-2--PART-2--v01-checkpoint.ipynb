# %% [markdown]
# ## <span style=color:blue>Patterns used in Programming Assignment 2 Part 2(version using util.py file)  </span>

# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %%
# test that utils.py has been imported well
# util.hello_world()

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>
#
# <span style=color:blue>E.g., see https://docs.sqlalchemy.org/en/20/core/engines.html for how to construct the URLs that the create_engine command uses.  Also, one should store the user/password into environment variables and read them in to populate the URL.  </span>
#
# <span style=color:blue>E.g., see https://stackoverflow.com/questions/4906977/how-can-i-access-environment-variables-in-python for how to work with environment variables on mac, </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>Working with btree indexing</span>
#
# <span style=color:blue>This generates a json file 'perf_test_v01.json'.  </span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

all_indexes = [['date','reviews'], ['date','calendar'], ['id','listings'], ['comments_tsv', 'reviews', 'gin']] 

q_dict = {}
# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_join_reviews(date_start, date_end)
# pprint.pp(q_dict)

q_dict['listings_join_reviews_2019'] = util.build_query_listings_join_reviews('2019-01-01', '2019-12-31')
# note: The reviews table has 126,469 entries in 2019


i_spec = [['id','listings'], ['date','reviews']]

perf_file = 'perf_test_v01.json'

# setting count to 3 for now so that things run faster
count = 3

for q in q_dict:
    print('\n====>>> Now working on query:', q)
    perf_summary = util.run_one_query_and_multi_index_specs(db_eng, all_indexes, q, q_dict[q], i_spec, count)
    # print('\nThe perf_summary of running query', q, 'is as follows:') 
    # pprint.pp(perf_summary)
    updated_perf_summary = util.fetch_and_update_perf_data(perf_file, perf_summary)

print('\nThe value of updated perf_summary is:')
pprint.pp(updated_perf_summary, sort_dicts=True)
# Out:
# ====>>> Now working on query: listings_join_review_2009
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2010
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2011
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2012
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2013
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2014
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2015
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2016
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2017
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2018
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2020
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2021
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2022
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2023
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2024
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_reviews_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# The value of updated perf_summary is:
# {'listings_join_review_2009': {'__': {'avg': 0.1933,
#                                       'count': 3,
#                                       'max': 0.2083,
#                                       'min': 0.1858,
#                                       'std': 0.0106,
#                                       'timestamp': '2024-05-06-23:18:14'},
#                                '__date_in_reviews__': {'avg': 0.0147,
#                                                        'count': 3,
#                                                        'max': 0.0175,
#                                                        'min': 0.0132,
#                                                        'std': 0.002,
#                                                        'timestamp': '2024-05-06-23:18:15'},
#                                '__id_in_listings__': {'avg': 0.1722,
#                                                       'count': 3,
#                                                       'max': 0.1754,
#                                                       'min': 0.1668,
#                                                       'std': 0.0038,
#                                                       'timestamp': '2024-05-06-23:18:15'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0136,
#                                                                        'count': 3,
#                                                                        'max': 0.0137,
#                                                                        'min': 0.0136,
#                                                                        'std': 0.0001,
#                                                                        'timestamp': '2024-05-06-23:18:15'}},
#  'listings_join_review_2010': {'__': {'avg': 0.1851,
#                                       'count': 3,
#                                       'max': 0.1881,
#                                       'min': 0.183,
#                                       'std': 0.0022,
#                                       'timestamp': '2024-05-06-23:18:16'},
#                                '__date_in_reviews__': {'avg': 0.0172,
#                                                        'count': 3,
#                                                        'max': 0.0212,
#                                                        'min': 0.0143,
#                                                        'std': 0.0029,
#                                                        'timestamp': '2024-05-06-23:18:17'},
#                                '__id_in_listings__': {'avg': 0.1888,
#                                                       'count': 3,
#                                                       'max': 0.1965,
#                                                       'min': 0.1841,
#                                                       'std': 0.0055,
#                                                       'timestamp': '2024-05-06-23:18:17'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0153,
#                                                                        'count': 3,
#                                                                        'max': 0.0161,
#                                                                        'min': 0.0146,
#                                                                        'std': 0.0006,
#                                                                        'timestamp': '2024-05-06-23:18:18'}},
#  'listings_join_review_2011': {'__': {'avg': 0.191,
#                                       'count': 3,
#                                       'max': 0.1937,
#                                       'min': 0.189,
#                                       'std': 0.002,
#                                       'timestamp': '2024-05-06-23:18:18'},
#                                '__date_in_reviews__': {'avg': 0.0206,
#                                                        'count': 3,
#                                                        'max': 0.024,
#                                                        'min': 0.0186,
#                                                        'std': 0.0024,
#                                                        'timestamp': '2024-05-06-23:18:19'},
#                                '__id_in_listings__': {'avg': 0.1867,
#                                                       'count': 3,
#                                                       'max': 0.1891,
#                                                       'min': 0.1831,
#                                                       'std': 0.0026,
#                                                       'timestamp': '2024-05-06-23:18:19'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0176,
#                                                                        'count': 3,
#                                                                        'max': 0.0186,
#                                                                        'min': 0.0166,
#                                                                        'std': 0.0008,
#                                                                        'timestamp': '2024-05-06-23:18:20'}},
#  'listings_join_review_2012': {'__': {'avg': 0.195,
#                                       'count': 3,
#                                       'max': 0.1977,
#                                       'min': 0.1914,
#                                       'std': 0.0026,
#                                       'timestamp': '2024-05-06-23:18:20'},
#                                '__date_in_reviews__': {'avg': 0.023,
#                                                        'count': 3,
#                                                        'max': 0.0292,
#                                                        'min': 0.0199,
#                                                        'std': 0.0044,
#                                                        'timestamp': '2024-05-06-23:18:21'},
#                                '__id_in_listings__': {'avg': 0.1918,
#                                                       'count': 3,
#                                                       'max': 0.1972,
#                                                       'min': 0.1851,
#                                                       'std': 0.005,
#                                                       'timestamp': '2024-05-06-23:18:21'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0223,
#                                                                        'count': 3,
#                                                                        'max': 0.024,
#                                                                        'min': 0.0203,
#                                                                        'std': 0.0015,
#                                                                        'timestamp': '2024-05-06-23:18:22'}},
#  'listings_join_review_2013': {'__': {'avg': 0.1944,
#                                       'count': 3,
#                                       'max': 0.2019,
#                                       'min': 0.1901,
#                                       'std': 0.0053,
#                                       'timestamp': '2024-05-06-23:18:22'},
#                                '__date_in_reviews__': {'avg': 0.0301,
#                                                        'count': 3,
#                                                        'max': 0.0369,
#                                                        'min': 0.0259,
#                                                        'std': 0.0049,
#                                                        'timestamp': '2024-05-06-23:18:24'},
#                                '__id_in_listings__': {'avg': 0.1887,
#                                                       'count': 3,
#                                                       'max': 0.194,
#                                                       'min': 0.183,
#                                                       'std': 0.0045,
#                                                       'timestamp': '2024-05-06-23:18:23'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0281,
#                                                                        'count': 3,
#                                                                        'max': 0.0297,
#                                                                        'min': 0.027,
#                                                                        'std': 0.0011,
#                                                                        'timestamp': '2024-05-06-23:18:24'}},
#  'listings_join_review_2014': {'__': {'avg': 0.2028,
#                                       'count': 3,
#                                       'max': 0.2066,
#                                       'min': 0.2001,
#                                       'std': 0.0028,
#                                       'timestamp': '2024-05-06-23:18:24'},
#                                '__date_in_reviews__': {'avg': 0.0433,
#                                                        'count': 3,
#                                                        'max': 0.0541,
#                                                        'min': 0.0372,
#                                                        'std': 0.0077,
#                                                        'timestamp': '2024-05-06-23:18:26'},
#                                '__id_in_listings__': {'avg': 0.2027,
#                                                       'count': 3,
#                                                       'max': 0.2043,
#                                                       'min': 0.2003,
#                                                       'std': 0.0018,
#                                                       'timestamp': '2024-05-06-23:18:25'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0386,
#                                                                        'count': 3,
#                                                                        'max': 0.0394,
#                                                                        'min': 0.0378,
#                                                                        'std': 0.0007,
#                                                                        'timestamp': '2024-05-06-23:18:26'}},
#  'listings_join_review_2015': {'__': {'avg': 0.1978,
#                                       'count': 3,
#                                       'max': 0.1989,
#                                       'min': 0.1969,
#                                       'std': 0.0008,
#                                       'timestamp': '2024-05-06-23:18:27'},
#                                '__date_in_reviews__': {'avg': 0.0784,
#                                                        'count': 3,
#                                                        'max': 0.0973,
#                                                        'min': 0.0685,
#                                                        'std': 0.0134,
#                                                        'timestamp': '2024-05-06-23:18:28'},
#                                '__id_in_listings__': {'avg': 0.194,
#                                                       'count': 3,
#                                                       'max': 0.1952,
#                                                       'min': 0.1927,
#                                                       'std': 0.001,
#                                                       'timestamp': '2024-05-06-23:18:27'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0695,
#                                                                        'count': 3,
#                                                                        'max': 0.0697,
#                                                                        'min': 0.0691,
#                                                                        'std': 0.0002,
#                                                                        'timestamp': '2024-05-06-23:18:28'}},
#  'listings_join_review_2016': {'__': {'avg': 0.2273,
#                                       'count': 3,
#                                       'max': 0.2341,
#                                       'min': 0.2194,
#                                       'std': 0.006,
#                                       'timestamp': '2024-05-06-23:18:29'},
#                                '__date_in_reviews__': {'avg': 0.0924,
#                                                        'count': 3,
#                                                        'max': 0.1143,
#                                                        'min': 0.0732,
#                                                        'std': 0.0169,
#                                                        'timestamp': '2024-05-06-23:18:31'},
#                                '__id_in_listings__': {'avg': 0.2259,
#                                                       'count': 3,
#                                                       'max': 0.2285,
#                                                       'min': 0.2208,
#                                                       'std': 0.0036,
#                                                       'timestamp': '2024-05-06-23:18:30'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0652,
#                                                                        'count': 3,
#                                                                        'max': 0.0654,
#                                                                        'min': 0.0648,
#                                                                        'std': 0.0003,
#                                                                        'timestamp': '2024-05-06-23:18:31'}},
#  'listings_join_review_2017': {'__': {'avg': 0.2427,
#                                       'count': 3,
#                                       'max': 0.2489,
#                                       'min': 0.2378,
#                                       'std': 0.0046,
#                                       'timestamp': '2024-05-06-23:18:32'},
#                                '__date_in_reviews__': {'avg': 0.1278,
#                                                        'count': 3,
#                                                        'max': 0.1478,
#                                                        'min': 0.1169,
#                                                        'std': 0.0142,
#                                                        'timestamp': '2024-05-06-23:18:34'},
#                                '__id_in_listings__': {'avg': 0.2398,
#                                                       'count': 3,
#                                                       'max': 0.2489,
#                                                       'min': 0.2276,
#                                                       'std': 0.009,
#                                                       'timestamp': '2024-05-06-23:18:33'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1096,
#                                                                        'count': 3,
#                                                                        'max': 0.112,
#                                                                        'min': 0.1079,
#                                                                        'std': 0.0017,
#                                                                        'timestamp': '2024-05-06-23:18:34'}},
#  'listings_join_review_2018': {'__': {'avg': 0.4829,
#                                       'count': 3,
#                                       'max': 0.4935,
#                                       'min': 0.4682,
#                                       'std': 0.0107,
#                                       'timestamp': '2024-05-06-23:18:35'},
#                                '__date_in_reviews__': {'avg': 0.1837,
#                                                        'count': 3,
#                                                        'max': 0.211,
#                                                        'min': 0.1661,
#                                                        'std': 0.0196,
#                                                        'timestamp': '2024-05-06-23:18:38'},
#                                '__id_in_listings__': {'avg': 0.4451,
#                                                       'count': 3,
#                                                       'max': 0.4457,
#                                                       'min': 0.4444,
#                                                       'std': 0.0006,
#                                                       'timestamp': '2024-05-06-23:18:37'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1681,
#                                                                        'count': 3,
#                                                                        'max': 0.1725,
#                                                                        'min': 0.1623,
#                                                                        'std': 0.0043,
#                                                                        'timestamp': '2024-05-06-23:18:38'}},
#  'listings_join_review_2019': {'__': {'avg': 0.4884,
#                                       'count': 3,
#                                       'max': 0.4941,
#                                       'min': 0.4848,
#                                       'std': 0.004,
#                                       'timestamp': '2024-05-06-23:18:40'},
#                                '__date_in_reviews__': {'avg': 0.4947,
#                                                        'count': 3,
#                                                        'max': 0.4969,
#                                                        'min': 0.4909,
#                                                        'std': 0.0027,
#                                                        'timestamp': '2024-05-06-23:18:44'},
#                                '__id_in_listings__': {'avg': 0.4777,
#                                                       'count': 3,
#                                                       'max': 0.4829,
#                                                       'min': 0.4678,
#                                                       'std': 0.0069,
#                                                       'timestamp': '2024-05-06-23:18:41'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.4996,
#                                                                        'count': 3,
#                                                                        'max': 0.5175,
#                                                                        'min': 0.4897,
#                                                                        'std': 0.0127,
#                                                                        'timestamp': '2024-05-06-23:18:45'}},
#  'listings_join_review_2020': {'__': {'avg': 0.2248,
#                                       'count': 3,
#                                       'max': 0.2265,
#                                       'min': 0.2236,
#                                       'std': 0.0012,
#                                       'timestamp': '2024-05-06-23:18:46'},
#                                '__date_in_reviews__': {'avg': 0.0832,
#                                                        'count': 3,
#                                                        'max': 0.1099,
#                                                        'min': 0.0691,
#                                                        'std': 0.0188,
#                                                        'timestamp': '2024-05-06-23:18:47'},
#                                '__id_in_listings__': {'avg': 0.2238,
#                                                       'count': 3,
#                                                       'max': 0.2256,
#                                                       'min': 0.2204,
#                                                       'std': 0.0024,
#                                                       'timestamp': '2024-05-06-23:18:47'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0882,
#                                                                        'count': 3,
#                                                                        'max': 0.1179,
#                                                                        'min': 0.0708,
#                                                                        'std': 0.0211,
#                                                                        'timestamp': '2024-05-06-23:18:48'}},
#  'listings_join_review_2021': {'__': {'avg': 0.4838,
#                                       'count': 3,
#                                       'max': 0.49,
#                                       'min': 0.478,
#                                       'std': 0.0049,
#                                       'timestamp': '2024-05-06-23:18:49'},
#                                '__date_in_reviews__': {'avg': 0.2085,
#                                                        'count': 3,
#                                                        'max': 0.2395,
#                                                        'min': 0.1902,
#                                                        'std': 0.022,
#                                                        'timestamp': '2024-05-06-23:18:52'},
#                                '__id_in_listings__': {'avg': 0.4894,
#                                                       'count': 3,
#                                                       'max': 0.4931,
#                                                       'min': 0.4836,
#                                                       'std': 0.0042,
#                                                       'timestamp': '2024-05-06-23:18:51'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1905,
#                                                                        'count': 3,
#                                                                        'max': 0.1945,
#                                                                        'min': 0.187,
#                                                                        'std': 0.0031,
#                                                                        'timestamp': '2024-05-06-23:18:53'}},
#  'listings_join_review_2022': {'__': {'avg': 0.5542,
#                                       'count': 3,
#                                       'max': 0.5806,
#                                       'min': 0.5373,
#                                       'std': 0.0189,
#                                       'timestamp': '2024-05-06-23:18:54'},
#                                '__date_in_reviews__': {'avg': 0.5361,
#                                                        'count': 3,
#                                                        'max': 0.5631,
#                                                        'min': 0.5185,
#                                                        'std': 0.0194,
#                                                        'timestamp': '2024-05-06-23:18:58'},
#                                '__id_in_listings__': {'avg': 0.5199,
#                                                       'count': 3,
#                                                       'max': 0.5228,
#                                                       'min': 0.5167,
#                                                       'std': 0.0025,
#                                                       'timestamp': '2024-05-06-23:18:56'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.5162,
#                                                                        'count': 3,
#                                                                        'max': 0.5185,
#                                                                        'min': 0.5138,
#                                                                        'std': 0.0019,
#                                                                        'timestamp': '2024-05-06-23:19:00'}},
#  'listings_join_review_2023': {'__': {'avg': 0.2733,
#                                       'count': 3,
#                                       'max': 0.3028,
#                                       'min': 0.2578,
#                                       'std': 0.0209,
#                                       'timestamp': '2024-05-06-23:19:01'},
#                                '__date_in_reviews__': {'avg': 0.2928,
#                                                        'count': 3,
#                                                        'max': 0.3323,
#                                                        'min': 0.2593,
#                                                        'std': 0.0301,
#                                                        'timestamp': '2024-05-06-23:19:03'},
#                                '__id_in_listings__': {'avg': 0.2703,
#                                                       'count': 3,
#                                                       'max': 0.2997,
#                                                       'min': 0.2536,
#                                                       'std': 0.0208,
#                                                       'timestamp': '2024-05-06-23:19:02'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.2947,
#                                                                        'count': 3,
#                                                                        'max': 0.3124,
#                                                                        'min': 0.272,
#                                                                        'std': 0.0169,
#                                                                        'timestamp': '2024-05-06-23:19:04'}},
#  'listings_join_review_2024': {'__': {'avg': 0.1961,
#                                       'count': 3,
#                                       'max': 0.2008,
#                                       'min': 0.1892,
#                                       'std': 0.005,
#                                       'timestamp': '2024-05-06-23:19:05'},
#                                '__date_in_reviews__': {'avg': 0.0377,
#                                                        'count': 3,
#                                                        'max': 0.0475,
#                                                        'min': 0.0314,
#                                                        'std': 0.007,
#                                                        'timestamp': '2024-05-06-23:19:06'},
#                                '__id_in_listings__': {'avg': 0.1905,
#                                                       'count': 3,
#                                                       'max': 0.199,
#                                                       'min': 0.185,
#                                                       'std': 0.0061,
#                                                       'timestamp': '2024-05-06-23:19:05'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0345,
#                                                                        'count': 3,
#                                                                        'max': 0.0351,
#                                                                        'min': 0.0341,
#                                                                        'std': 0.0004,
#                                                                        'timestamp': '2024-05-06-23:19:06'}},
#  'listings_join_reviews_2013': {'__': {'avg': 0.0238,
#                                        'max': 0.0327,
#                                        'min': 0.0215,
#                                        'std': 0.0023,
#                                        'timestamp': '2024-05-05-23:38:22'},
#                                 '__date_in_reviews__': {'avg': 0.0234,
#                                                         'max': 0.0265,
#                                                         'min': 0.022,
#                                                         'std': 0.0008,
#                                                         'timestamp': '2024-05-05-23:38:25'},
#                                 '__id_in_listings__': {'avg': 0.0235,
#                                                        'max': 0.026,
#                                                        'min': 0.0217,
#                                                        'std': 0.001,
#                                                        'timestamp': '2024-05-05-23:38:24'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.0232,
#                                                                         'max': 0.0262,
#                                                                         'min': 0.0217,
#                                                                         'std': 0.001,
#                                                                         'timestamp': '2024-05-05-23:38:26'}},
#  'listings_join_reviews_2014': {'__': {'avg': 0.0326,
#                                        'max': 0.1238,
#                                        'min': 0.0289,
#                                        'std': 0.0131,
#                                        'timestamp': '2024-05-05-23:37:16'},
#                                 '__date_in_reviews__': {'avg': 0.0316,
#                                                         'max': 0.035,
#                                                         'min': 0.029,
#                                                         'std': 0.0011,
#                                                         'timestamp': '2024-05-05-23:37:19'},
#                                 '__id_in_listings__': {'avg': 0.0311,
#                                                        'max': 0.0328,
#                                                        'min': 0.0297,
#                                                        'std': 0.0008,
#                                                        'timestamp': '2024-05-05-23:37:18'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.0319,
#                                                                         'max': 0.0355,
#                                                                         'min': 0.0301,
#                                                                         'std': 0.0013,
#                                                                         'timestamp': '2024-05-05-23:37:21'}},
#  'listings_join_reviews_2015': {'__': {'avg': 0.1274,
#                                        'max': 0.1654,
#                                        'min': 0.1179,
#                                        'std': 0.0083,
#                                        'timestamp': '2024-05-05-23:11:16'},
#                                 '__date_in_reviews__': {'avg': 0.0485,
#                                                         'max': 0.0549,
#                                                         'min': 0.0457,
#                                                         'std': 0.002,
#                                                         'timestamp': '2024-05-05-23:11:25'},
#                                 '__id_in_listings__': {'avg': 0.1212,
#                                                        'max': 0.1354,
#                                                        'min': 0.1169,
#                                                        'std': 0.0037,
#                                                        'timestamp': '2024-05-05-23:11:22'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.05,
#                                                                         'max': 0.0537,
#                                                                         'min': 0.0457,
#                                                                         'std': 0.0016,
#                                                                         'timestamp': '2024-05-05-23:11:28'}},
#  'listings_join_reviews_2017': {'__': {'avg': 0.1473,
#                                        'max': 0.1882,
#                                        'min': 0.1404,
#                                        'std': 0.0099,
#                                        'timestamp': '2024-05-06-09:14:06'},
#                                 '__date_in_reviews__': {'avg': 0.1141,
#                                                         'max': 0.1645,
#                                                         'min': 0.1063,
#                                                         'std': 0.0129,
#                                                         'timestamp': '2024-05-06-09:14:20'},
#                                 '__id_in_listings__': {'avg': 0.1521,
#                                                        'max': 0.1677,
#                                                        'min': 0.1427,
#                                                        'std': 0.0059,
#                                                        'timestamp': '2024-05-06-09:14:14'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.1108,
#                                                                         'max': 0.1473,
#                                                                         'min': 0.1037,
#                                                                         'std': 0.0086,
#                                                                         'timestamp': '2024-05-06-09:14:26'}},
#  'listings_join_reviews_2019': {'__': {'avg': 0.4848,
#                                        'count': 3,
#                                        'max': 0.4957,
#                                        'min': 0.4747,
#                                        'std': 0.0086,
#                                        'timestamp': '2024-05-06-23:19:08'},
#                                 '__date_in_reviews__': {'avg': 0.5,
#                                                         'count': 3,
#                                                         'max': 0.5085,
#                                                         'min': 0.4921,
#                                                         'std': 0.0067,
#                                                         'timestamp': '2024-05-06-23:19:11'},
#                                 '__id_in_listings__': {'avg': 0.4827,
#                                                        'count': 3,
#                                                        'max': 0.4863,
#                                                        'min': 0.4759,
#                                                        'std': 0.0048,
#                                                        'timestamp': '2024-05-06-23:19:09'},
#                                 '__id_in_listings__date_in_reviews__': {'avg': 0.5125,
#                                                                         'count': 3,
#                                                                         'max': 0.5385,
#                                                                         'min': 0.4787,
#                                                                         'std': 0.025,
#                                                                         'timestamp': '2024-05-06-23:19:13'}}}

# %% [markdown]
# ### <span style=color:blue>Working with text indexing</span>
#
# <span style=color:blue>This generates the file 'ts_pef_test_v01.json'

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

perf_file = 'ts_perf_test_v01.json'

# using a low count so that the query without index runs reasonably quickly
count = 3

word = 'awesome'

# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    print('\nEntering loop for yr = ', str(yr))
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    perf_info = util.run_one_text_query_without_with_tsindex(db_eng, word, date_start, date_end, count)
    print('perf_file for the run for  is:')
    pprint.pp(perf_info)
    updated_perf_summary = util.fetch_and_update_ts_perf_data(perf_file, perf_info)

print('After running all years, the updated perf_summary file is:')
pprint.pp(updated_perf_summary)
# Out:
# Entering loop for yr =  2009
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2116,
#  'min': 1.1818,
#  'max': 1.247,
#  'std': 0.0269,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:35'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0726,
#  'min': 0.0704,
#  'max': 0.0768,
#  'std': 0.003,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:35'}
# perf_file for the run for  is:
# {'awesome_2009': {'no_index': {'avg': 1.2116,
#                                'min': 1.1818,
#                                'max': 1.247,
#                                'std': 0.0269,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:35'},
#                   'with_ts_index': {'avg': 0.0726,
#                                     'min': 0.0704,
#                                     'max': 0.0768,
#                                     'std': 0.003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:35'}}}
# Not successful in finding file perf_data/ts_perf_test_v01.json; so creating it
#
# Entering loop for yr =  2010
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1538,
#  'min': 1.1324,
#  'max': 1.183,
#  'std': 0.0214,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:39'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0714,
#  'min': 0.0687,
#  'max': 0.0759,
#  'std': 0.0032,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:39'}
# perf_file for the run for  is:
# {'awesome_2010': {'no_index': {'avg': 1.1538,
#                                'min': 1.1324,
#                                'max': 1.183,
#                                'std': 0.0214,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:39'},
#                   'with_ts_index': {'avg': 0.0714,
#                                     'min': 0.0687,
#                                     'max': 0.0759,
#                                     'std': 0.0032,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:39'}}}
#
# Entering loop for yr =  2011
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1828,
#  'min': 1.1618,
#  'max': 1.1966,
#  'std': 0.0151,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:43'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0687,
#  'min': 0.0671,
#  'max': 0.0704,
#  'std': 0.0013,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:43'}
# perf_file for the run for  is:
# {'awesome_2011': {'no_index': {'avg': 1.1828,
#                                'min': 1.1618,
#                                'max': 1.1966,
#                                'std': 0.0151,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:43'},
#                   'with_ts_index': {'avg': 0.0687,
#                                     'min': 0.0671,
#                                     'max': 0.0704,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:43'}}}
#
# Entering loop for yr =  2012
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1579,
#  'min': 1.1486,
#  'max': 1.1679,
#  'std': 0.0079,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:46'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0728,
#  'min': 0.0705,
#  'max': 0.0754,
#  'std': 0.002,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:47'}
# perf_file for the run for  is:
# {'awesome_2012': {'no_index': {'avg': 1.1579,
#                                'min': 1.1486,
#                                'max': 1.1679,
#                                'std': 0.0079,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:46'},
#                   'with_ts_index': {'avg': 0.0728,
#                                     'min': 0.0705,
#                                     'max': 0.0754,
#                                     'std': 0.002,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:47'}}}
#
# Entering loop for yr =  2013
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1783,
#  'min': 1.1546,
#  'max': 1.2127,
#  'std': 0.0249,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:50'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0707,
#  'min': 0.0695,
#  'max': 0.0726,
#  'std': 0.0013,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:50'}
# perf_file for the run for  is:
# {'awesome_2013': {'no_index': {'avg': 1.1783,
#                                'min': 1.1546,
#                                'max': 1.2127,
#                                'std': 0.0249,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:50'},
#                   'with_ts_index': {'avg': 0.0707,
#                                     'min': 0.0695,
#                                     'max': 0.0726,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:50'}}}
#
# Entering loop for yr =  2014
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1841,
#  'min': 1.1731,
#  'max': 1.1966,
#  'std': 0.0097,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:54'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0759,
#  'min': 0.0728,
#  'max': 0.079,
#  'std': 0.0025,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:54'}
# perf_file for the run for  is:
# {'awesome_2014': {'no_index': {'avg': 1.1841,
#                                'min': 1.1731,
#                                'max': 1.1966,
#                                'std': 0.0097,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:54'},
#                   'with_ts_index': {'avg': 0.0759,
#                                     'min': 0.0728,
#                                     'max': 0.079,
#                                     'std': 0.0025,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:54'}}}
#
# Entering loop for yr =  2015
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1721,
#  'min': 1.1413,
#  'max': 1.2062,
#  'std': 0.0266,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:58'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0781,
#  'min': 0.0766,
#  'max': 0.0796,
#  'std': 0.0012,
#  'count': 3,
#  'timestamp': '2024-05-06-23:07:58'}
# perf_file for the run for  is:
# {'awesome_2015': {'no_index': {'avg': 1.1721,
#                                'min': 1.1413,
#                                'max': 1.2062,
#                                'std': 0.0266,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:58'},
#                   'with_ts_index': {'avg': 0.0781,
#                                     'min': 0.0766,
#                                     'max': 0.0796,
#                                     'std': 0.0012,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:58'}}}
#
# Entering loop for yr =  2016
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.3155,
#  'min': 1.2349,
#  'max': 1.4383,
#  'std': 0.0882,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:02'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0798,
#  'min': 0.0793,
#  'max': 0.0805,
#  'std': 0.0005,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:02'}
# perf_file for the run for  is:
# {'awesome_2016': {'no_index': {'avg': 1.3155,
#                                'min': 1.2349,
#                                'max': 1.4383,
#                                'std': 0.0882,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:02'},
#                   'with_ts_index': {'avg': 0.0798,
#                                     'min': 0.0793,
#                                     'max': 0.0805,
#                                     'std': 0.0005,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:02'}}}
#
# Entering loop for yr =  2017
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1905,
#  'min': 1.151,
#  'max': 1.249,
#  'std': 0.0422,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:06'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0763,
#  'min': 0.0754,
#  'max': 0.0769,
#  'std': 0.0006,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:06'}
# perf_file for the run for  is:
# {'awesome_2017': {'no_index': {'avg': 1.1905,
#                                'min': 1.151,
#                                'max': 1.249,
#                                'std': 0.0422,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:06'},
#                   'with_ts_index': {'avg': 0.0763,
#                                     'min': 0.0754,
#                                     'max': 0.0769,
#                                     'std': 0.0006,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:06'}}}
#
# Entering loop for yr =  2018
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1479,
#  'min': 1.1379,
#  'max': 1.1566,
#  'std': 0.0077,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:09'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0783,
#  'min': 0.0775,
#  'max': 0.0792,
#  'std': 0.0007,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:10'}
# perf_file for the run for  is:
# {'awesome_2018': {'no_index': {'avg': 1.1479,
#                                'min': 1.1379,
#                                'max': 1.1566,
#                                'std': 0.0077,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:09'},
#                   'with_ts_index': {'avg': 0.0783,
#                                     'min': 0.0775,
#                                     'max': 0.0792,
#                                     'std': 0.0007,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:10'}}}
#
# Entering loop for yr =  2019
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1579,
#  'min': 1.1491,
#  'max': 1.1722,
#  'std': 0.0102,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:13'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0845,
#  'min': 0.0811,
#  'max': 0.0872,
#  'std': 0.0026,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:13'}
# perf_file for the run for  is:
# {'awesome_2019': {'no_index': {'avg': 1.1579,
#                                'min': 1.1491,
#                                'max': 1.1722,
#                                'std': 0.0102,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:13'},
#                   'with_ts_index': {'avg': 0.0845,
#                                     'min': 0.0811,
#                                     'max': 0.0872,
#                                     'std': 0.0026,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:13'}}}
#
# Entering loop for yr =  2020
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1614,
#  'min': 1.1391,
#  'max': 1.1795,
#  'std': 0.0168,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:17'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0765,
#  'min': 0.0745,
#  'max': 0.0783,
#  'std': 0.0016,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:17'}
# perf_file for the run for  is:
# {'awesome_2020': {'no_index': {'avg': 1.1614,
#                                'min': 1.1391,
#                                'max': 1.1795,
#                                'std': 0.0168,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:17'},
#                   'with_ts_index': {'avg': 0.0765,
#                                     'min': 0.0745,
#                                     'max': 0.0783,
#                                     'std': 0.0016,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:17'}}}
#
# Entering loop for yr =  2021
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2022,
#  'min': 1.1926,
#  'max': 1.2125,
#  'std': 0.0081,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:21'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.077,
#  'min': 0.0755,
#  'max': 0.0794,
#  'std': 0.0017,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:21'}
# perf_file for the run for  is:
# {'awesome_2021': {'no_index': {'avg': 1.2022,
#                                'min': 1.1926,
#                                'max': 1.2125,
#                                'std': 0.0081,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:21'},
#                   'with_ts_index': {'avg': 0.077,
#                                     'min': 0.0755,
#                                     'max': 0.0794,
#                                     'std': 0.0017,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:21'}}}
#
# Entering loop for yr =  2022
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1575,
#  'min': 1.1449,
#  'max': 1.1797,
#  'std': 0.0157,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:24'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0959,
#  'min': 0.0773,
#  'max': 0.132,
#  'std': 0.0255,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:25'}
# perf_file for the run for  is:
# {'awesome_2022': {'no_index': {'avg': 1.1575,
#                                'min': 1.1449,
#                                'max': 1.1797,
#                                'std': 0.0157,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:24'},
#                   'with_ts_index': {'avg': 0.0959,
#                                     'min': 0.0773,
#                                     'max': 0.132,
#                                     'std': 0.0255,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:25'}}}
#
# Entering loop for yr =  2023
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1924,
#  'min': 1.1762,
#  'max': 1.2148,
#  'std': 0.0164,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:28'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0802,
#  'min': 0.0791,
#  'max': 0.0822,
#  'std': 0.0014,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:28'}
# perf_file for the run for  is:
# {'awesome_2023': {'no_index': {'avg': 1.1924,
#                                'min': 1.1762,
#                                'max': 1.2148,
#                                'std': 0.0164,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:28'},
#                   'with_ts_index': {'avg': 0.0802,
#                                     'min': 0.0791,
#                                     'max': 0.0822,
#                                     'std': 0.0014,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:28'}}}
#
# Entering loop for yr =  2024
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.212,
#  'min': 1.2088,
#  'max': 1.2157,
#  'std': 0.0029,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:32'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0748,
#  'min': 0.0731,
#  'max': 0.0762,
#  'std': 0.0013,
#  'count': 3,
#  'timestamp': '2024-05-06-23:08:32'}
# perf_file for the run for  is:
# {'awesome_2024': {'no_index': {'avg': 1.212,
#                                'min': 1.2088,
#                                'max': 1.2157,
#                                'std': 0.0029,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:32'},
#                   'with_ts_index': {'avg': 0.0748,
#                                     'min': 0.0731,
#                                     'max': 0.0762,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:32'}}}
# After running all years, the updated perf_summary file is:
# {'awesome_2009': {'no_index': {'avg': 1.2116,
#                                'min': 1.1818,
#                                'max': 1.247,
#                                'std': 0.0269,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:35'},
#                   'with_ts_index': {'avg': 0.0726,
#                                     'min': 0.0704,
#                                     'max': 0.0768,
#                                     'std': 0.003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:35'}},
#  'awesome_2010': {'no_index': {'avg': 1.1538,
#                                'min': 1.1324,
#                                'max': 1.183,
#                                'std': 0.0214,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:39'},
#                   'with_ts_index': {'avg': 0.0714,
#                                     'min': 0.0687,
#                                     'max': 0.0759,
#                                     'std': 0.0032,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:39'}},
#  'awesome_2011': {'no_index': {'avg': 1.1828,
#                                'min': 1.1618,
#                                'max': 1.1966,
#                                'std': 0.0151,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:43'},
#                   'with_ts_index': {'avg': 0.0687,
#                                     'min': 0.0671,
#                                     'max': 0.0704,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:43'}},
#  'awesome_2012': {'no_index': {'avg': 1.1579,
#                                'min': 1.1486,
#                                'max': 1.1679,
#                                'std': 0.0079,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:46'},
#                   'with_ts_index': {'avg': 0.0728,
#                                     'min': 0.0705,
#                                     'max': 0.0754,
#                                     'std': 0.002,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:47'}},
#  'awesome_2013': {'no_index': {'avg': 1.1783,
#                                'min': 1.1546,
#                                'max': 1.2127,
#                                'std': 0.0249,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:50'},
#                   'with_ts_index': {'avg': 0.0707,
#                                     'min': 0.0695,
#                                     'max': 0.0726,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:50'}},
#  'awesome_2014': {'no_index': {'avg': 1.1841,
#                                'min': 1.1731,
#                                'max': 1.1966,
#                                'std': 0.0097,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:54'},
#                   'with_ts_index': {'avg': 0.0759,
#                                     'min': 0.0728,
#                                     'max': 0.079,
#                                     'std': 0.0025,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:54'}},
#  'awesome_2015': {'no_index': {'avg': 1.1721,
#                                'min': 1.1413,
#                                'max': 1.2062,
#                                'std': 0.0266,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:07:58'},
#                   'with_ts_index': {'avg': 0.0781,
#                                     'min': 0.0766,
#                                     'max': 0.0796,
#                                     'std': 0.0012,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:07:58'}},
#  'awesome_2016': {'no_index': {'avg': 1.3155,
#                                'min': 1.2349,
#                                'max': 1.4383,
#                                'std': 0.0882,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:02'},
#                   'with_ts_index': {'avg': 0.0798,
#                                     'min': 0.0793,
#                                     'max': 0.0805,
#                                     'std': 0.0005,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:02'}},
#  'awesome_2017': {'no_index': {'avg': 1.1905,
#                                'min': 1.151,
#                                'max': 1.249,
#                                'std': 0.0422,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:06'},
#                   'with_ts_index': {'avg': 0.0763,
#                                     'min': 0.0754,
#                                     'max': 0.0769,
#                                     'std': 0.0006,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:06'}},
#  'awesome_2018': {'no_index': {'avg': 1.1479,
#                                'min': 1.1379,
#                                'max': 1.1566,
#                                'std': 0.0077,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:09'},
#                   'with_ts_index': {'avg': 0.0783,
#                                     'min': 0.0775,
#                                     'max': 0.0792,
#                                     'std': 0.0007,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:10'}},
#  'awesome_2019': {'no_index': {'avg': 1.1579,
#                                'min': 1.1491,
#                                'max': 1.1722,
#                                'std': 0.0102,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:13'},
#                   'with_ts_index': {'avg': 0.0845,
#                                     'min': 0.0811,
#                                     'max': 0.0872,
#                                     'std': 0.0026,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:13'}},
#  'awesome_2020': {'no_index': {'avg': 1.1614,
#                                'min': 1.1391,
#                                'max': 1.1795,
#                                'std': 0.0168,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:17'},
#                   'with_ts_index': {'avg': 0.0765,
#                                     'min': 0.0745,
#                                     'max': 0.0783,
#                                     'std': 0.0016,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:17'}},
#  'awesome_2021': {'no_index': {'avg': 1.2022,
#                                'min': 1.1926,
#                                'max': 1.2125,
#                                'std': 0.0081,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:21'},
#                   'with_ts_index': {'avg': 0.077,
#                                     'min': 0.0755,
#                                     'max': 0.0794,
#                                     'std': 0.0017,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:21'}},
#  'awesome_2022': {'no_index': {'avg': 1.1575,
#                                'min': 1.1449,
#                                'max': 1.1797,
#                                'std': 0.0157,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:24'},
#                   'with_ts_index': {'avg': 0.0959,
#                                     'min': 0.0773,
#                                     'max': 0.132,
#                                     'std': 0.0255,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:25'}},
#  'awesome_2023': {'no_index': {'avg': 1.1924,
#                                'min': 1.1762,
#                                'max': 1.2148,
#                                'std': 0.0164,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:28'},
#                   'with_ts_index': {'avg': 0.0802,
#                                     'min': 0.0791,
#                                     'max': 0.0822,
#                                     'std': 0.0014,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:28'}},
#  'awesome_2024': {'no_index': {'avg': 1.212,
#                                'min': 1.2088,
#                                'max': 1.2157,
#                                'std': 0.0029,
#                                'count': 3,
#                                'timestamp': '2024-05-06-23:08:32'},
#                   'with_ts_index': {'avg': 0.0748,
#                                     'min': 0.0731,
#                                     'max': 0.0762,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-06-23:08:32'}}}

# %%
# the variable all_indexes will hold all of the indexes involved in your testing.
#   For now there are 3 indexes, but there will be more.  set of all indexes will get bigger once we do more explorations
# Here, a pair ['col','table'] refers to an index on column 'col' in table 'table'
# (in an ideal world, we would keep a copy of this on disk, probably in your computer's file system,
#   and read it in when we want to use it and/or add to it.  For the full Programming Assignment 2
#   we will be working with 4 to 6 indexes)

all_indexes = [['date','reviews'], ['date','calendar'], ['id','listings']] 


# pull in performance summary from previous tests done
perf_summary = fetch_perf_data('perf_summary.json')

# we will use the same query as above, and call it 'listings_join_reviews_2015'
#   in perf_summary.json, info about different runs for this query are
#   held in perf_summary[<<query_name>>]

# q = q_dict[query_name]
q_listings_join_reviews_2015 = """
SELECT DISTINCT l.id, l.name
FROM listings l, reviews r 
WHERE l.id = r.listing_id
  AND r.date >= '2015-01-01'
  AND r.date <= '2015-12-31'
ORDER BY l.id;
"""

query_name = 'listings_join_reviews_2015'


# here the spec is a listing of column-table pairs corresponding to indexes that are
#    to be included in the test
# I have run this jupyter cell on the 4 specs listed below
spec = [['id','listings'], ['date','reviews']]
# spec = [['date','reviews']]
# spec = [['id','listings']]
# spec = []

# count will hold the number of times we want to run the query
count = 50

print('Processing spec: ', str(spec), '\n')
for index in all_indexes:
    if index not in spec:
        mod_index = util.add_drop_index(db_eng, 'drop', index[0], index[1])
        print('\nAfter doing the drop for', str(index), 'the indexes on table "' + index[1] + '" are: ')
        print(mod_index)
        
for index in spec:
    mod_index = util.add_drop_index(db_eng, 'add', index[0], index[1])
    print('\nAfter doing the add for', str(index), 'the indexes on table "' + index[1] + '" are: ')
    print(mod_index)

time_list = []
for i in range(0,count):
    time_start = datetime.now()
    # Open new db connection for each execution of the query to avoid multithreading
    with db_eng.connect() as conn:
        df = pd.read_sql(q_listings_join_reviews_2015, con=conn)
    time_end = datetime.now()
    diff = time_diff(time_start, time_end)
    time_list.append(diff)
    
perf_profile = {}
perf_profile['avg'] = round(sum(time_list)/len(time_list), 4)
perf_profile['min'] = round(min(time_list), 4)
perf_profile['max'] = round(max(time_list), 4)
perf_profile['std'] = round(np.std(time_list), 4)

print('\nThe list of running times is as follows:')
pprint.pp(time_list)

print('\nThe statistics on the list of running times are as follows:')
pprint.pp(perf_profile)

# util.build_index_description_key() creates a listing of strings corresponding
#    to the entries in spec, and concatenates them in the ordering given by all_indexes
#    For example, the description_key associated with having indexes date_in_reviews and id_in_listings
#        would be __date_in_reviews__id_in_listings__'
#        (You probably want to use a uniform ordering of index names when you create these description_keys
key_value = util.build_index_description_key(all_indexes, spec)
print('\nThe new value for"' + key_value + '"will be', str(perf_profile))


# we may have run some other tests with the query q_listings_join_reviews_2015' and
#   we don't want to overwrite those.  So we need to get the full contents
#   of perf_summary['listings_join_reviews_2015'] and then
#   write (or overwrite) the value for the current list of indexes used

if query_name in perf_summary:
    perf_dict = perf_summary[query_name]
    print("\nBefore modifying perf_dict, the value of perf_summary[query_name] (if it existed) was: ")
    pprint.pp(perf_dict)
else:
    perf_dict = {}
    print("\nBefore modifying perf_dict, the value of perf_summary[query_name] had empty value")
print()
perf_dict[key_value] = perf_profile
perf_summary['listings_join_reviews_2015'] = perf_dict

print("\nAfter modifying perf_dict, the value of perf_summary[query_name] is: ")
pprint.pp(perf_summary[query_name])
print()

print('\nThe full value of perf_summary is:')
pprint.pp(perf_summary)

write_perf_data(perf_summary, 'perf_summary.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       8 all_indexes = [['date','reviews'], ['date','calendar'], ['id','listings']]
#      11 # pull in performance summary from previous tests done
# ---> 12 perf_summary = fetch_perf_data('perf_summary.json')
#      14 # we will use the same query as above, and call it 'listings_join_reviews_2015'
#      15 #   in perf_summary.json, info about different runs for this query are
#      16 #   held in perf_summary[<<query_name>>]
#      17
#      18 # q = q_dict[query_name]
#      19 q_listings_join_reviews_2015 = """
#      20 SELECT DISTINCT l.id, l.name
#      21 FROM listings l, reviews r
#    (...)
#      25 ORDER BY l.id;
#      26 """
#
# NameError: name 'fetch_perf_data' is not defined
