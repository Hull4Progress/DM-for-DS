# %% [markdown]
# ## <span style=color:blue>Patterns used in Programming Assignment 2 Part 2(version using util.py file)  </span>

# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %%
# test that utils.py has been imported well
# util.hello_world()

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>
#
# <span style=color:blue>E.g., see https://docs.sqlalchemy.org/en/20/core/engines.html for how to construct the URLs that the create_engine command uses.  Also, one should store the user/password into environment variables and read them in to populate the URL.  </span>
#
# <span style=color:blue>E.g., see https://stackoverflow.com/questions/4906977/how-can-i-access-environment-variables-in-python for how to work with environment variables on mac, </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>Working with btree indexing</span>

# %% [markdown]
# <span style=color:blue>I will encourage students to build a query that computes, for each year, the number of reviews that happened in that year. </span>

# %%
q = util.query_reviews_by_year_counts()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('2009', 56),
#  ('2010', 449),
#  ('2011', 1905),
#  ('2012', 3872),
#  ('2013', 7317),
#  ('2014', 14203),
#  ('2015', 28465),
#  ('2016', 48527),
#  ('2017', 66146),
#  ('2018', 95137),
#  ('2019', 126469),
#  ('2020', 51172),
#  ('2021', 109415),
#  ('2022', 196136),
#  ('2023', 228831),
#  ('2024', 8710)]

# %% [markdown]
# <span style=color:blue>Likewise, the next query gives a count of listings within the prices ranges 0 <= p < 100, 100 <= p < 200, ..., 900 <= p < 1000 and '1000_and_above'

# %%
q = util.query_listings_price_ranges_counts()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('0000s', 1735),
#  ('0100s', 6362),
#  ('0200s', 2875),
#  ('0300s', 1307),
#  ('0400s', 519),
#  ('0500s', 233),
#  ('0600s', 146),
#  ('0700s', 95),
#  ('0800s', 85),
#  ('0900s', 75),
#  ('1000_and_above', 226),
#  ('NULL', 7195)]

# %% [markdown]
# <span style=color:blue>And here is a query that gives the counts of occurrences in the reviews table, for three selected words</span>

# %%
q = util.query_reviews_words_counts()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

result_list = result.fetchall()

pprint.pp(result_list)
# Out:
# [('apartment', 195261), ('awesome', 27938), ('horrible', 859), (None, 762752)]

# %% [markdown]
# <span style=color:blue>First, here is an example of the queries we are using for the testing with b-tree indexes </span>

# %%
date_start = '2015-01-01'
date_end = '2015-12-31'

q = util.build_query_listings_join_reviews(date_start, date_end)

print(q)
# Out:
# SELECT DISTINCT l.id, l.name
# FROM listings l, reviews r
# WHERE l.id = r.listing_id
#   AND r.date >= '2015-01-01'
#   AND r.date <= '2015-12-31'
# ORDER BY l.id;

# %% [markdown]
# <span style=color:blue>My big vision was to have the students set up some infrastructure so that they could easily experiment with a variety of different queries and indexes, and do explorations of things on their own.  So, in util.py I have some helper functions that enable someone to specify a list of indexes, and then run experiments for all combinations of that list.  However, at present I'm thinking that will take people to far into some weeds.   </span>
#
# <span style=color:blue>I am now thinking that I may ask the students to only build files like my files perf_test_v01.json and ts_perf_test_v01.json.  Or I might find time to do some update-based experiments, again for the same set of indexes that are involved with perf_test_v01.json and ts_perf_test_v01.json.  In either case, most likely, they will only have to think about the indexes date_in_reviews, id_in_listings, and comments_tsv_in_reviews. <span>
#
# <span style=color:blue>With regards to storing results, I was originally thinking about this assignment, and about enabling the students to explore different index combinations over time.  So I developed a helper function that would read a json file from my disk, add to it, and then write it out again.  That way, I would be adding performance information over many programming/execution sessions.  This is my function util.fetch_and_update_perf_data(perf_file, perf_summary).  However, I am now thinking that the students don't need to bother with that, given that they will be given quite specific files that they are supposed to generate.<span>

# %% [markdown]
# <span style=color:blue>This generates a json file 'perf_test_v01.json'.  </span>
#
# <span style=color:blue>This produces a lot of log info which may be helpful ... </span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

all_indexes = [['date','reviews'], ['date','calendar'], ['id','listings'], ['comments_tsv', 'reviews', 'gin']] 

q_dict = {}
# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    q_dict[q_name] = util.build_query_listings_join_reviews(date_start, date_end)
# pprint.pp(q_dict)

i_spec = [['id','listings'], ['date','reviews']]

perf_file = 'listing_join_reviews_v01.json'

# setting count to 3 for now so that things run faster
count = 3

for q in q_dict:
    print('\n====>>> Now working on query:', q)
    perf_summary = util.run_one_query_and_multi_index_specs(db_eng, all_indexes, q, q_dict[q], i_spec, count)
    # print('\nThe perf_summary of running query', q, 'is as follows:') 
    # pprint.pp(perf_summary)
    updated_perf_summary = util.fetch_and_update_perf_data(perf_file, perf_summary)

print('\nThe value of updated perf_summary is:')
pprint.pp(updated_perf_summary, sort_dicts=True)
# Out:
# ====>>> Now working on query: listings_join_review_2009
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
# Not successful in finding file perf_data/listing_join_reviews_v01.json; so creating it
#
# ====>>> Now working on query: listings_join_review_2010
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2011
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2012
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2013
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2014
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2015
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2016
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2017
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2018
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2019
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2020
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2021
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2022
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2023
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# ====>>> Now working on query: listings_join_review_2024
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))"],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': []}
#
# Now invoking run_one_query
#
# Now working on the i_spec: [['id', 'listings'], ['date', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ["CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX date_in_reviews ON new_york_city.reviews USING btree (date)'],
#  'calendar': [],
#  'listings': ['CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)']}
#
# Now invoking run_one_query
#
# The value of updated perf_summary is:
# {'listings_join_review_2009': {'__': {'avg': 0.2034,
#                                       'count': 3,
#                                       'max': 0.2351,
#                                       'min': 0.1866,
#                                       'std': 0.0225,
#                                       'timestamp': '2024-05-07-19:16:12'},
#                                '__date_in_reviews__': {'avg': 0.0162,
#                                                        'count': 3,
#                                                        'max': 0.0186,
#                                                        'min': 0.0147,
#                                                        'std': 0.0018,
#                                                        'timestamp': '2024-05-07-19:16:13'},
#                                '__id_in_listings__': {'avg': 0.1817,
#                                                       'count': 3,
#                                                       'max': 0.1876,
#                                                       'min': 0.1704,
#                                                       'std': 0.008,
#                                                       'timestamp': '2024-05-07-19:16:12'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0152,
#                                                                        'count': 3,
#                                                                        'max': 0.0154,
#                                                                        'min': 0.015,
#                                                                        'std': 0.0002,
#                                                                        'timestamp': '2024-05-07-19:16:13'}},
#  'listings_join_review_2010': {'__': {'avg': 0.1973,
#                                       'count': 3,
#                                       'max': 0.2055,
#                                       'min': 0.1919,
#                                       'std': 0.0059,
#                                       'timestamp': '2024-05-07-19:16:14'},
#                                '__date_in_reviews__': {'avg': 0.0169,
#                                                        'count': 3,
#                                                        'max': 0.0201,
#                                                        'min': 0.0152,
#                                                        'std': 0.0023,
#                                                        'timestamp': '2024-05-07-19:16:15'},
#                                '__id_in_listings__': {'avg': 0.1901,
#                                                       'count': 3,
#                                                       'max': 0.1945,
#                                                       'min': 0.1872,
#                                                       'std': 0.0031,
#                                                       'timestamp': '2024-05-07-19:16:14'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0153,
#                                                                        'count': 3,
#                                                                        'max': 0.016,
#                                                                        'min': 0.0145,
#                                                                        'std': 0.0006,
#                                                                        'timestamp': '2024-05-07-19:16:15'}},
#  'listings_join_review_2011': {'__': {'avg': 0.1972,
#                                       'count': 3,
#                                       'max': 0.2029,
#                                       'min': 0.19,
#                                       'std': 0.0053,
#                                       'timestamp': '2024-05-07-19:16:16'},
#                                '__date_in_reviews__': {'avg': 0.0191,
#                                                        'count': 3,
#                                                        'max': 0.023,
#                                                        'min': 0.0167,
#                                                        'std': 0.0028,
#                                                        'timestamp': '2024-05-07-19:16:17'},
#                                '__id_in_listings__': {'avg': 0.2057,
#                                                       'count': 3,
#                                                       'max': 0.2066,
#                                                       'min': 0.2048,
#                                                       'std': 0.0007,
#                                                       'timestamp': '2024-05-07-19:16:17'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0177,
#                                                                        'count': 3,
#                                                                        'max': 0.0181,
#                                                                        'min': 0.0174,
#                                                                        'std': 0.0003,
#                                                                        'timestamp': '2024-05-07-19:16:17'}},
#  'listings_join_review_2012': {'__': {'avg': 0.2028,
#                                       'count': 3,
#                                       'max': 0.2054,
#                                       'min': 0.1994,
#                                       'std': 0.0025,
#                                       'timestamp': '2024-05-07-19:16:18'},
#                                '__date_in_reviews__': {'avg': 0.0238,
#                                                        'count': 3,
#                                                        'max': 0.0277,
#                                                        'min': 0.0218,
#                                                        'std': 0.0027,
#                                                        'timestamp': '2024-05-07-19:16:19'},
#                                '__id_in_listings__': {'avg': 0.1909,
#                                                       'count': 3,
#                                                       'max': 0.1922,
#                                                       'min': 0.1888,
#                                                       'std': 0.0015,
#                                                       'timestamp': '2024-05-07-19:16:19'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0216,
#                                                                        'count': 3,
#                                                                        'max': 0.022,
#                                                                        'min': 0.0214,
#                                                                        'std': 0.0002,
#                                                                        'timestamp': '2024-05-07-19:16:19'}},
#  'listings_join_review_2013': {'__': {'avg': 0.1997,
#                                       'count': 3,
#                                       'max': 0.2068,
#                                       'min': 0.1882,
#                                       'std': 0.0082,
#                                       'timestamp': '2024-05-07-19:16:20'},
#                                '__date_in_reviews__': {'avg': 0.0303,
#                                                        'count': 3,
#                                                        'max': 0.0351,
#                                                        'min': 0.0275,
#                                                        'std': 0.0034,
#                                                        'timestamp': '2024-05-07-19:16:21'},
#                                '__id_in_listings__': {'avg': 0.1912,
#                                                       'count': 3,
#                                                       'max': 0.1982,
#                                                       'min': 0.1873,
#                                                       'std': 0.0049,
#                                                       'timestamp': '2024-05-07-19:16:21'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0285,
#                                                                        'count': 3,
#                                                                        'max': 0.0298,
#                                                                        'min': 0.027,
#                                                                        'std': 0.0012,
#                                                                        'timestamp': '2024-05-07-19:16:21'}},
#  'listings_join_review_2014': {'__': {'avg': 0.1991,
#                                       'count': 3,
#                                       'max': 0.2089,
#                                       'min': 0.1925,
#                                       'std': 0.0071,
#                                       'timestamp': '2024-05-07-19:16:22'},
#                                '__date_in_reviews__': {'avg': 0.0433,
#                                                        'count': 3,
#                                                        'max': 0.0506,
#                                                        'min': 0.0387,
#                                                        'std': 0.0052,
#                                                        'timestamp': '2024-05-07-19:16:23'},
#                                '__id_in_listings__': {'avg': 0.1943,
#                                                       'count': 3,
#                                                       'max': 0.1953,
#                                                       'min': 0.1929,
#                                                       'std': 0.001,
#                                                       'timestamp': '2024-05-07-19:16:23'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.04,
#                                                                        'count': 3,
#                                                                        'max': 0.0408,
#                                                                        'min': 0.0394,
#                                                                        'std': 0.0006,
#                                                                        'timestamp': '2024-05-07-19:16:24'}},
#  'listings_join_review_2015': {'__': {'avg': 0.2067,
#                                       'count': 3,
#                                       'max': 0.2123,
#                                       'min': 0.2032,
#                                       'std': 0.004,
#                                       'timestamp': '2024-05-07-19:16:24'},
#                                '__date_in_reviews__': {'avg': 0.0733,
#                                                        'count': 3,
#                                                        'max': 0.0925,
#                                                        'min': 0.0637,
#                                                        'std': 0.0136,
#                                                        'timestamp': '2024-05-07-19:16:26'},
#                                '__id_in_listings__': {'avg': 0.2225,
#                                                       'count': 3,
#                                                       'max': 0.2264,
#                                                       'min': 0.2154,
#                                                       'std': 0.005,
#                                                       'timestamp': '2024-05-07-19:16:25'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0643,
#                                                                        'count': 3,
#                                                                        'max': 0.0683,
#                                                                        'min': 0.0617,
#                                                                        'std': 0.0029,
#                                                                        'timestamp': '2024-05-07-19:16:26'}},
#  'listings_join_review_2016': {'__': {'avg': 0.216,
#                                       'count': 3,
#                                       'max': 0.2163,
#                                       'min': 0.2154,
#                                       'std': 0.0004,
#                                       'timestamp': '2024-05-07-19:16:27'},
#                                '__date_in_reviews__': {'avg': 0.0712,
#                                                        'count': 3,
#                                                        'max': 0.0909,
#                                                        'min': 0.0612,
#                                                        'std': 0.0139,
#                                                        'timestamp': '2024-05-07-19:16:28'},
#                                '__id_in_listings__': {'avg': 0.2142,
#                                                       'count': 3,
#                                                       'max': 0.2146,
#                                                       'min': 0.2138,
#                                                       'std': 0.0003,
#                                                       'timestamp': '2024-05-07-19:16:27'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0605,
#                                                                        'count': 3,
#                                                                        'max': 0.0615,
#                                                                        'min': 0.0595,
#                                                                        'std': 0.0008,
#                                                                        'timestamp': '2024-05-07-19:16:28'}},
#  'listings_join_review_2017': {'__': {'avg': 0.2269,
#                                       'count': 3,
#                                       'max': 0.2278,
#                                       'min': 0.2263,
#                                       'std': 0.0007,
#                                       'timestamp': '2024-05-07-19:16:29'},
#                                '__date_in_reviews__': {'avg': 0.1088,
#                                                        'count': 3,
#                                                        'max': 0.1175,
#                                                        'min': 0.1017,
#                                                        'std': 0.0065,
#                                                        'timestamp': '2024-05-07-19:16:31'},
#                                '__id_in_listings__': {'avg': 0.2287,
#                                                       'count': 3,
#                                                       'max': 0.2296,
#                                                       'min': 0.2282,
#                                                       'std': 0.0006,
#                                                       'timestamp': '2024-05-07-19:16:30'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.107,
#                                                                        'count': 3,
#                                                                        'max': 0.1086,
#                                                                        'min': 0.105,
#                                                                        'std': 0.0015,
#                                                                        'timestamp': '2024-05-07-19:16:31'}},
#  'listings_join_review_2018': {'__': {'avg': 0.4605,
#                                       'count': 3,
#                                       'max': 0.4682,
#                                       'min': 0.4493,
#                                       'std': 0.0081,
#                                       'timestamp': '2024-05-07-19:16:33'},
#                                '__date_in_reviews__': {'avg': 0.1809,
#                                                        'count': 3,
#                                                        'max': 0.2027,
#                                                        'min': 0.1653,
#                                                        'std': 0.0159,
#                                                        'timestamp': '2024-05-07-19:16:35'},
#                                '__id_in_listings__': {'avg': 0.4525,
#                                                       'count': 3,
#                                                       'max': 0.4546,
#                                                       'min': 0.4495,
#                                                       'std': 0.0022,
#                                                       'timestamp': '2024-05-07-19:16:34'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1678,
#                                                                        'count': 3,
#                                                                        'max': 0.17,
#                                                                        'min': 0.1666,
#                                                                        'std': 0.0016,
#                                                                        'timestamp': '2024-05-07-19:16:36'}},
#  'listings_join_review_2019': {'__': {'avg': 0.4661,
#                                       'count': 3,
#                                       'max': 0.4706,
#                                       'min': 0.4603,
#                                       'std': 0.0043,
#                                       'timestamp': '2024-05-07-19:16:37'},
#                                '__date_in_reviews__': {'avg': 0.4897,
#                                                        'count': 3,
#                                                        'max': 0.5142,
#                                                        'min': 0.4736,
#                                                        'std': 0.0176,
#                                                        'timestamp': '2024-05-07-19:16:41'},
#                                '__id_in_listings__': {'avg': 0.4677,
#                                                       'count': 3,
#                                                       'max': 0.4703,
#                                                       'min': 0.4661,
#                                                       'std': 0.0018,
#                                                       'timestamp': '2024-05-07-19:16:39'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.4658,
#                                                                        'count': 3,
#                                                                        'max': 0.4711,
#                                                                        'min': 0.4602,
#                                                                        'std': 0.0045,
#                                                                        'timestamp': '2024-05-07-19:16:42'}},
#  'listings_join_review_2020': {'__': {'avg': 0.2249,
#                                       'count': 3,
#                                       'max': 0.2272,
#                                       'min': 0.2217,
#                                       'std': 0.0023,
#                                       'timestamp': '2024-05-07-19:16:43'},
#                                '__date_in_reviews__': {'avg': 0.1036,
#                                                        'count': 3,
#                                                        'max': 0.1175,
#                                                        'min': 0.0796,
#                                                        'std': 0.0171,
#                                                        'timestamp': '2024-05-07-19:16:44'},
#                                '__id_in_listings__': {'avg': 0.2233,
#                                                       'count': 3,
#                                                       'max': 0.2241,
#                                                       'min': 0.222,
#                                                       'std': 0.0009,
#                                                       'timestamp': '2024-05-07-19:16:44'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0696,
#                                                                        'count': 3,
#                                                                        'max': 0.0701,
#                                                                        'min': 0.0693,
#                                                                        'std': 0.0003,
#                                                                        'timestamp': '2024-05-07-19:16:45'}},
#  'listings_join_review_2021': {'__': {'avg': 0.4633,
#                                       'count': 3,
#                                       'max': 0.4659,
#                                       'min': 0.4618,
#                                       'std': 0.0019,
#                                       'timestamp': '2024-05-07-19:16:46'},
#                                '__date_in_reviews__': {'avg': 0.2004,
#                                                        'count': 3,
#                                                        'max': 0.2307,
#                                                        'min': 0.1838,
#                                                        'std': 0.0215,
#                                                        'timestamp': '2024-05-07-19:16:49'},
#                                '__id_in_listings__': {'avg': 0.4696,
#                                                       'count': 3,
#                                                       'max': 0.4793,
#                                                       'min': 0.4632,
#                                                       'std': 0.007,
#                                                       'timestamp': '2024-05-07-19:16:48'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.1851,
#                                                                        'count': 3,
#                                                                        'max': 0.1856,
#                                                                        'min': 0.1843,
#                                                                        'std': 0.0006,
#                                                                        'timestamp': '2024-05-07-19:16:49'}},
#  'listings_join_review_2022': {'__': {'avg': 0.5221,
#                                       'count': 3,
#                                       'max': 0.5426,
#                                       'min': 0.5078,
#                                       'std': 0.0149,
#                                       'timestamp': '2024-05-07-19:16:51'},
#                                '__date_in_reviews__': {'avg': 0.55,
#                                                        'count': 3,
#                                                        'max': 0.588,
#                                                        'min': 0.5295,
#                                                        'std': 0.0268,
#                                                        'timestamp': '2024-05-07-19:16:55'},
#                                '__id_in_listings__': {'avg': 0.5103,
#                                                       'count': 3,
#                                                       'max': 0.5147,
#                                                       'min': 0.5062,
#                                                       'std': 0.0035,
#                                                       'timestamp': '2024-05-07-19:16:52'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.5296,
#                                                                        'count': 3,
#                                                                        'max': 0.5348,
#                                                                        'min': 0.5267,
#                                                                        'std': 0.0037,
#                                                                        'timestamp': '2024-05-07-19:16:56'}},
#  'listings_join_review_2023': {'__': {'avg': 0.284,
#                                       'count': 3,
#                                       'max': 0.313,
#                                       'min': 0.2609,
#                                       'std': 0.0217,
#                                       'timestamp': '2024-05-07-19:16:57'},
#                                '__date_in_reviews__': {'avg': 0.283,
#                                                        'count': 3,
#                                                        'max': 0.3256,
#                                                        'min': 0.2605,
#                                                        'std': 0.0301,
#                                                        'timestamp': '2024-05-07-19:17:00'},
#                                '__id_in_listings__': {'avg': 0.2885,
#                                                       'count': 3,
#                                                       'max': 0.3216,
#                                                       'min': 0.2671,
#                                                       'std': 0.0237,
#                                                       'timestamp': '2024-05-07-19:16:58'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.2744,
#                                                                        'count': 3,
#                                                                        'max': 0.2845,
#                                                                        'min': 0.257,
#                                                                        'std': 0.0123,
#                                                                        'timestamp': '2024-05-07-19:17:01'}},
#  'listings_join_review_2024': {'__': {'avg': 0.2003,
#                                       'count': 3,
#                                       'max': 0.2025,
#                                       'min': 0.1969,
#                                       'std': 0.0024,
#                                       'timestamp': '2024-05-07-19:17:01'},
#                                '__date_in_reviews__': {'avg': 0.0391,
#                                                        'count': 3,
#                                                        'max': 0.048,
#                                                        'min': 0.0329,
#                                                        'std': 0.0064,
#                                                        'timestamp': '2024-05-07-19:17:03'},
#                                '__id_in_listings__': {'avg': 0.1949,
#                                                       'count': 3,
#                                                       'max': 0.2025,
#                                                       'min': 0.1911,
#                                                       'std': 0.0053,
#                                                       'timestamp': '2024-05-07-19:17:02'},
#                                '__id_in_listings__date_in_reviews__': {'avg': 0.0513,
#                                                                        'count': 3,
#                                                                        'max': 0.0772,
#                                                                        'min': 0.0345,
#                                                                        'std': 0.0186,
#                                                                        'timestamp': '2024-05-07-19:17:03'}}}

# %% [markdown]
# ### <span style=color:blue>Working with text indexing</span>

# %% [markdown]
# <span style=color:blue>First, here are examples of the 2 kinds of query we are working with.  I might decide to ask the students to experiment with a second word.  (I need to find a word with different behavior!)</span>
#
# ### <span style=color:blue>NOTE: please see the double "%%" in the first query -- this is a kind of escape character so that sqlalchemy will be able to work with the "%" signs.  </span>

# %%
word = 'awesome'
start_date = '2015-01-01'
end_date = '2015-12-31'

q1 = util.build_query_reviews_no_index(word, start_date, end_date)
q2 = util.build_query_reviews_ts(word, start_date, end_date)

print('q1 is:')
print(q1)
print('\nq2 is:')
print(q2)
# Out:
# q1 is:
# SELECT *
# FROM reviews r
# WHERE comments ILIKE '%%awesome%%'
#   AND date >= '2015-01-01'
#   AND date <= '2015-12-31';
#
# q2 is:
# SELECT *
# FROM reviews r
# WHERE comments_tsv @@ to_tsquery('awesome')
#   AND date >= '2015-01-01'
#   AND date <= '2015-12-31';

# %% [markdown]
# <span style=color:blue>The next cell generates the file 'ts_pef_test_v01.json'<span>
#
# <span style=color:blue>For these experiments the "no-index" case is making a search against the comments column of reviews, whereas the "with-index" case is making a search against the comments_tsv column of reviews.  So I don't need to drop the index on comments_tsv when running the "no-index" case.  This makes it simpler than the b-tree situation</span>

# %%
# testing function util.run_multiple_tests(db_eng, all_indexes, q_list, i_spec, perf_file, count)

perf_file = 'ts_perf_test_v01.json'

# using a low count so that the query without index runs reasonably quickly
count = 3

# reviews has data for years 2009 to 2024
for yr in range(2009,2025):
    print('\nEntering loop for yr = ', str(yr))
    q_name = 'listings_join_review_' + str(yr)
    date_start = str(yr) + '-01-01'
    date_end = str(yr) + '-12-31'
    for word in ['horrible', 'awesome', 'apartment']:
        print('Entering sub-loop for word: ', word)
        perf_info = util.run_one_text_query_without_with_tsindex(db_eng, word, date_start, date_end, count)
        print('perf_file for the run for year "', yr, '" and word "', word, '" is:')
        pprint.pp(perf_info)
        updated_perf_summary = util.fetch_and_update_ts_perf_data(perf_file, perf_info)




print('After running all years, the updated perf_summary info, in sorted order, is:')
# the sorted(...items()) returns list of ordered pairs; 
#     for each pair, the first element is a key in the dictionary
#                    and the second element is the value associated with that key
pprint.pp(sorted(updated_perf_summary.items()))
# Out:
# Entering loop for yr =  2009
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.005,
#  'min': 0.0042,
#  'max': 0.0065,
#  'std': 0.0011,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0042,
#  'min': 0.0031,
#  'max': 0.0055,
#  'std': 0.001,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2009 " and word " horrible " is:
# {'horrible_2009': {'no_ts_index': {'avg': 0.005,
#                                    'min': 0.0042,
#                                    'max': 0.0065,
#                                    'std': 0.0011,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0042,
#                                      'min': 0.0031,
#                                      'max': 0.0055,
#                                      'std': 0.001,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0034,
#  'min': 0.0029,
#  'max': 0.004,
#  'std': 0.0005,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0031,
#  'min': 0.0025,
#  'max': 0.0038,
#  'std': 0.0006,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2009 " and word " awesome " is:
# {'awesome_2009': {'no_ts_index': {'avg': 0.0034,
#                                   'min': 0.0029,
#                                   'max': 0.004,
#                                   'std': 0.0005,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:29'},
#                   'with_ts_index': {'avg': 0.0031,
#                                     'min': 0.0025,
#                                     'max': 0.0038,
#                                     'std': 0.0006,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0033,
#  'min': 0.0028,
#  'max': 0.004,
#  'std': 0.0005,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.002,
#  'min': 0.0019,
#  'max': 0.0021,
#  'std': 0.0001,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2009 " and word " apartment " is:
# {'apartment_2009': {'no_ts_index': {'avg': 0.0033,
#                                     'min': 0.0028,
#                                     'max': 0.004,
#                                     'std': 0.0005,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'},
#                     'with_ts_index': {'avg': 0.002,
#                                       'min': 0.0019,
#                                       'max': 0.0021,
#                                       'std': 0.0001,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:29'}}}
#
# Entering loop for yr =  2010
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0053,
#  'min': 0.0042,
#  'max': 0.0064,
#  'std': 0.0009,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0038,
#  'min': 0.0034,
#  'max': 0.0046,
#  'std': 0.0006,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2010 " and word " horrible " is:
# {'horrible_2010': {'no_ts_index': {'avg': 0.0053,
#                                    'min': 0.0042,
#                                    'max': 0.0064,
#                                    'std': 0.0009,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0038,
#                                      'min': 0.0034,
#                                      'max': 0.0046,
#                                      'std': 0.0006,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0051,
#  'min': 0.0047,
#  'max': 0.006,
#  'std': 0.0006,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.003,
#  'min': 0.0027,
#  'max': 0.0035,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2010 " and word " awesome " is:
# {'awesome_2010': {'no_ts_index': {'avg': 0.0051,
#                                   'min': 0.0047,
#                                   'max': 0.006,
#                                   'std': 0.0006,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:29'},
#                   'with_ts_index': {'avg': 0.003,
#                                     'min': 0.0027,
#                                     'max': 0.0035,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0059,
#  'min': 0.0053,
#  'max': 0.0067,
#  'std': 0.0006,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0038,
#  'min': 0.0037,
#  'max': 0.0041,
#  'std': 0.0002,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2010 " and word " apartment " is:
# {'apartment_2010': {'no_ts_index': {'avg': 0.0059,
#                                     'min': 0.0053,
#                                     'max': 0.0067,
#                                     'std': 0.0006,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'},
#                     'with_ts_index': {'avg': 0.0038,
#                                       'min': 0.0037,
#                                       'max': 0.0041,
#                                       'std': 0.0002,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:29'}}}
#
# Entering loop for yr =  2011
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0134,
#  'min': 0.0128,
#  'max': 0.0139,
#  'std': 0.0004,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.007,
#  'min': 0.0057,
#  'max': 0.0078,
#  'std': 0.0009,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2011 " and word " horrible " is:
# {'horrible_2011': {'no_ts_index': {'avg': 0.0134,
#                                    'min': 0.0128,
#                                    'max': 0.0139,
#                                    'std': 0.0004,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.007,
#                                      'min': 0.0057,
#                                      'max': 0.0078,
#                                      'std': 0.0009,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0128,
#  'min': 0.0125,
#  'max': 0.0131,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0065,
#  'min': 0.0061,
#  'max': 0.0068,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2011 " and word " awesome " is:
# {'awesome_2011': {'no_ts_index': {'avg': 0.0128,
#                                   'min': 0.0125,
#                                   'max': 0.0131,
#                                   'std': 0.0003,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:29'},
#                   'with_ts_index': {'avg': 0.0065,
#                                     'min': 0.0061,
#                                     'max': 0.0068,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0168,
#  'min': 0.016,
#  'max': 0.0173,
#  'std': 0.0006,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0122,
#  'min': 0.0111,
#  'max': 0.0133,
#  'std': 0.0009,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2011 " and word " apartment " is:
# {'apartment_2011': {'no_ts_index': {'avg': 0.0168,
#                                     'min': 0.016,
#                                     'max': 0.0173,
#                                     'std': 0.0006,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'},
#                     'with_ts_index': {'avg': 0.0122,
#                                       'min': 0.0111,
#                                       'max': 0.0133,
#                                       'std': 0.0009,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:29'}}}
#
# Entering loop for yr =  2012
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.025,
#  'min': 0.0228,
#  'max': 0.0282,
#  'std': 0.0024,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0112,
#  'min': 0.0105,
#  'max': 0.0126,
#  'std': 0.001,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2012 " and word " horrible " is:
# {'horrible_2012': {'no_ts_index': {'avg': 0.025,
#                                    'min': 0.0228,
#                                    'max': 0.0282,
#                                    'std': 0.0024,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0112,
#                                      'min': 0.0105,
#                                      'max': 0.0126,
#                                      'std': 0.001,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0246,
#  'min': 0.0244,
#  'max': 0.0248,
#  'std': 0.0002,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0118,
#  'min': 0.0115,
#  'max': 0.0121,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2012 " and word " awesome " is:
# {'awesome_2012': {'no_ts_index': {'avg': 0.0246,
#                                   'min': 0.0244,
#                                   'max': 0.0248,
#                                   'std': 0.0002,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:29'},
#                   'with_ts_index': {'avg': 0.0118,
#                                     'min': 0.0115,
#                                     'max': 0.0121,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0351,
#  'min': 0.0334,
#  'max': 0.0376,
#  'std': 0.0018,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0234,
#  'min': 0.0224,
#  'max': 0.024,
#  'std': 0.0007,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# perf_file for the run for year " 2012 " and word " apartment " is:
# {'apartment_2012': {'no_ts_index': {'avg': 0.0351,
#                                     'min': 0.0334,
#                                     'max': 0.0376,
#                                     'std': 0.0018,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:29'},
#                     'with_ts_index': {'avg': 0.0234,
#                                       'min': 0.0224,
#                                       'max': 0.024,
#                                       'std': 0.0007,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:29'}}}
#
# Entering loop for yr =  2013
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0424,
#  'min': 0.0396,
#  'max': 0.0472,
#  'std': 0.0034,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0216,
#  'min': 0.0187,
#  'max': 0.0267,
#  'std': 0.0036,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# perf_file for the run for year " 2013 " and word " horrible " is:
# {'horrible_2013': {'no_ts_index': {'avg': 0.0424,
#                                    'min': 0.0396,
#                                    'max': 0.0472,
#                                    'std': 0.0034,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0216,
#                                      'min': 0.0187,
#                                      'max': 0.0267,
#                                      'std': 0.0036,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:30'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0432,
#  'min': 0.0428,
#  'max': 0.0435,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0205,
#  'min': 0.0203,
#  'max': 0.0208,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# perf_file for the run for year " 2013 " and word " awesome " is:
# {'awesome_2013': {'no_ts_index': {'avg': 0.0432,
#                                   'min': 0.0428,
#                                   'max': 0.0435,
#                                   'std': 0.0003,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:30'},
#                   'with_ts_index': {'avg': 0.0205,
#                                     'min': 0.0203,
#                                     'max': 0.0208,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:30'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0631,
#  'min': 0.0604,
#  'max': 0.0645,
#  'std': 0.0019,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0446,
#  'min': 0.0438,
#  'max': 0.046,
#  'std': 0.001,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# perf_file for the run for year " 2013 " and word " apartment " is:
# {'apartment_2013': {'no_ts_index': {'avg': 0.0631,
#                                     'min': 0.0604,
#                                     'max': 0.0645,
#                                     'std': 0.0019,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:30'},
#                     'with_ts_index': {'avg': 0.0446,
#                                       'min': 0.0438,
#                                       'max': 0.046,
#                                       'std': 0.001,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:30'}}}
#
# Entering loop for yr =  2014
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0792,
#  'min': 0.0739,
#  'max': 0.0845,
#  'std': 0.0043,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0357,
#  'min': 0.0338,
#  'max': 0.0393,
#  'std': 0.0025,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:30'}
# perf_file for the run for year " 2014 " and word " horrible " is:
# {'horrible_2014': {'no_ts_index': {'avg': 0.0792,
#                                    'min': 0.0739,
#                                    'max': 0.0845,
#                                    'std': 0.0043,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:30'},
#                    'with_ts_index': {'avg': 0.0357,
#                                      'min': 0.0338,
#                                      'max': 0.0393,
#                                      'std': 0.0025,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:30'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.0832,
#  'min': 0.0823,
#  'max': 0.0841,
#  'std': 0.0007,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:31'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0369,
#  'min': 0.0361,
#  'max': 0.0379,
#  'std': 0.0008,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:31'}
# perf_file for the run for year " 2014 " and word " awesome " is:
# {'awesome_2014': {'no_ts_index': {'avg': 0.0832,
#                                   'min': 0.0823,
#                                   'max': 0.0841,
#                                   'std': 0.0007,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:31'},
#                   'with_ts_index': {'avg': 0.0369,
#                                     'min': 0.0361,
#                                     'max': 0.0379,
#                                     'std': 0.0008,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:31'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1203,
#  'min': 0.1198,
#  'max': 0.1206,
#  'std': 0.0003,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:31'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.085,
#  'min': 0.0827,
#  'max': 0.0885,
#  'std': 0.0025,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:31'}
# perf_file for the run for year " 2014 " and word " apartment " is:
# {'apartment_2014': {'no_ts_index': {'avg': 0.1203,
#                                     'min': 0.1198,
#                                     'max': 0.1206,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:31'},
#                     'with_ts_index': {'avg': 0.085,
#                                       'min': 0.0827,
#                                       'max': 0.0885,
#                                       'std': 0.0025,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:31'}}}
#
# Entering loop for yr =  2015
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1489,
#  'min': 0.1379,
#  'max': 0.1608,
#  'std': 0.0094,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:32'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0664,
#  'min': 0.0641,
#  'max': 0.0702,
#  'std': 0.0027,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:32'}
# perf_file for the run for year " 2015 " and word " horrible " is:
# {'horrible_2015': {'no_ts_index': {'avg': 0.1489,
#                                    'min': 0.1379,
#                                    'max': 0.1608,
#                                    'std': 0.0094,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:32'},
#                    'with_ts_index': {'avg': 0.0664,
#                                      'min': 0.0641,
#                                      'max': 0.0702,
#                                      'std': 0.0027,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:32'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1549,
#  'min': 0.153,
#  'max': 0.1562,
#  'std': 0.0014,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:33'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0763,
#  'min': 0.0753,
#  'max': 0.077,
#  'std': 0.0007,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:33'}
# perf_file for the run for year " 2015 " and word " awesome " is:
# {'awesome_2015': {'no_ts_index': {'avg': 0.1549,
#                                   'min': 0.153,
#                                   'max': 0.1562,
#                                   'std': 0.0014,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:33'},
#                   'with_ts_index': {'avg': 0.0763,
#                                     'min': 0.0753,
#                                     'max': 0.077,
#                                     'std': 0.0007,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:33'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2357,
#  'min': 0.2217,
#  'max': 0.2603,
#  'std': 0.0174,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:33'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1576,
#  'min': 0.1526,
#  'max': 0.1621,
#  'std': 0.0039,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:34'}
# perf_file for the run for year " 2015 " and word " apartment " is:
# {'apartment_2015': {'no_ts_index': {'avg': 0.2357,
#                                     'min': 0.2217,
#                                     'max': 0.2603,
#                                     'std': 0.0174,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:33'},
#                     'with_ts_index': {'avg': 0.1576,
#                                       'min': 0.1526,
#                                       'max': 0.1621,
#                                       'std': 0.0039,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:34'}}}
#
# Entering loop for yr =  2016
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2249,
#  'min': 0.2185,
#  'max': 0.2285,
#  'std': 0.0045,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:35'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0614,
#  'min': 0.0564,
#  'max': 0.0713,
#  'std': 0.0069,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:35'}
# perf_file for the run for year " 2016 " and word " horrible " is:
# {'horrible_2016': {'no_ts_index': {'avg': 0.2249,
#                                    'min': 0.2185,
#                                    'max': 0.2285,
#                                    'std': 0.0045,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:35'},
#                    'with_ts_index': {'avg': 0.0614,
#                                      'min': 0.0564,
#                                      'max': 0.0713,
#                                      'std': 0.0069,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:35'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2309,
#  'min': 0.2274,
#  'max': 0.2363,
#  'std': 0.0039,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:35'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0622,
#  'min': 0.0603,
#  'max': 0.0631,
#  'std': 0.0013,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:36'}
# perf_file for the run for year " 2016 " and word " awesome " is:
# {'awesome_2016': {'no_ts_index': {'avg': 0.2309,
#                                   'min': 0.2274,
#                                   'max': 0.2363,
#                                   'std': 0.0039,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:35'},
#                   'with_ts_index': {'avg': 0.0622,
#                                     'min': 0.0603,
#                                     'max': 0.0631,
#                                     'std': 0.0013,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:36'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.3443,
#  'min': 0.3217,
#  'max': 0.3799,
#  'std': 0.0255,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:37'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1759,
#  'min': 0.1556,
#  'max': 0.2009,
#  'std': 0.0188,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:37'}
# perf_file for the run for year " 2016 " and word " apartment " is:
# {'apartment_2016': {'no_ts_index': {'avg': 0.3443,
#                                     'min': 0.3217,
#                                     'max': 0.3799,
#                                     'std': 0.0255,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:37'},
#                     'with_ts_index': {'avg': 0.1759,
#                                       'min': 0.1556,
#                                       'max': 0.2009,
#                                       'std': 0.0188,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:37'}}}
#
# Entering loop for yr =  2017
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2611,
#  'min': 0.2455,
#  'max': 0.273,
#  'std': 0.0115,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:38'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0913,
#  'min': 0.0885,
#  'max': 0.0937,
#  'std': 0.0022,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:38'}
# perf_file for the run for year " 2017 " and word " horrible " is:
# {'horrible_2017': {'no_ts_index': {'avg': 0.2611,
#                                    'min': 0.2455,
#                                    'max': 0.273,
#                                    'std': 0.0115,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:38'},
#                    'with_ts_index': {'avg': 0.0913,
#                                      'min': 0.0885,
#                                      'max': 0.0937,
#                                      'std': 0.0022,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:38'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2983,
#  'min': 0.2924,
#  'max': 0.3093,
#  'std': 0.0078,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:39'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1033,
#  'min': 0.1023,
#  'max': 0.1044,
#  'std': 0.0009,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:40'}
# perf_file for the run for year " 2017 " and word " awesome " is:
# {'awesome_2017': {'no_ts_index': {'avg': 0.2983,
#                                   'min': 0.2924,
#                                   'max': 0.3093,
#                                   'std': 0.0078,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:39'},
#                   'with_ts_index': {'avg': 0.1033,
#                                     'min': 0.1023,
#                                     'max': 0.1044,
#                                     'std': 0.0009,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:40'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.398,
#  'min': 0.3958,
#  'max': 0.3995,
#  'std': 0.0016,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:41'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1914,
#  'min': 0.1754,
#  'max': 0.2202,
#  'std': 0.0204,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:41'}
# perf_file for the run for year " 2017 " and word " apartment " is:
# {'apartment_2017': {'no_ts_index': {'avg': 0.398,
#                                     'min': 0.3958,
#                                     'max': 0.3995,
#                                     'std': 0.0016,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:41'},
#                     'with_ts_index': {'avg': 0.1914,
#                                       'min': 0.1754,
#                                       'max': 0.2202,
#                                       'std': 0.0204,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:41'}}}
#
# Entering loop for yr =  2018
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1651,
#  'min': 0.1644,
#  'max': 0.1666,
#  'std': 0.0011,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:42'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1271,
#  'min': 0.1255,
#  'max': 0.1293,
#  'std': 0.0016,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:42'}
# perf_file for the run for year " 2018 " and word " horrible " is:
# {'horrible_2018': {'no_ts_index': {'avg': 0.1651,
#                                    'min': 0.1644,
#                                    'max': 0.1666,
#                                    'std': 0.0011,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:42'},
#                    'with_ts_index': {'avg': 0.1271,
#                                      'min': 0.1255,
#                                      'max': 0.1293,
#                                      'std': 0.0016,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:42'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1868,
#  'min': 0.1854,
#  'max': 0.1892,
#  'std': 0.0017,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:43'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1336,
#  'min': 0.1322,
#  'max': 0.1348,
#  'std': 0.0011,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:43'}
# perf_file for the run for year " 2018 " and word " awesome " is:
# {'awesome_2018': {'no_ts_index': {'avg': 0.1868,
#                                   'min': 0.1854,
#                                   'max': 0.1892,
#                                   'std': 0.0017,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:43'},
#                   'with_ts_index': {'avg': 0.1336,
#                                     'min': 0.1322,
#                                     'max': 0.1348,
#                                     'std': 0.0011,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:43'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.2974,
#  'min': 0.2709,
#  'max': 0.3157,
#  'std': 0.0192,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:44'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2476,
#  'min': 0.2262,
#  'max': 0.2831,
#  'std': 0.0253,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:45'}
# perf_file for the run for year " 2018 " and word " apartment " is:
# {'apartment_2018': {'no_ts_index': {'avg': 0.2974,
#                                     'min': 0.2709,
#                                     'max': 0.3157,
#                                     'std': 0.0192,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:44'},
#                     'with_ts_index': {'avg': 0.2476,
#                                       'min': 0.2262,
#                                       'max': 0.2831,
#                                       'std': 0.0253,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:45'}}}
#
# Entering loop for yr =  2019
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1021,
#  'min': 1.06,
#  'max': 1.1349,
#  'std': 0.0313,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:48'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1708,
#  'min': 0.1645,
#  'max': 0.1741,
#  'std': 0.0045,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:49'}
# perf_file for the run for year " 2019 " and word " horrible " is:
# {'horrible_2019': {'no_ts_index': {'avg': 1.1021,
#                                    'min': 1.06,
#                                    'max': 1.1349,
#                                    'std': 0.0313,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:48'},
#                    'with_ts_index': {'avg': 0.1708,
#                                      'min': 0.1645,
#                                      'max': 0.1741,
#                                      'std': 0.0045,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:49'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1879,
#  'min': 1.1531,
#  'max': 1.2075,
#  'std': 0.0247,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:52'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1694,
#  'min': 0.1693,
#  'max': 0.1697,
#  'std': 0.0002,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:53'}
# perf_file for the run for year " 2019 " and word " awesome " is:
# {'awesome_2019': {'no_ts_index': {'avg': 1.1879,
#                                   'min': 1.1531,
#                                   'max': 1.2075,
#                                   'std': 0.0247,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:52'},
#                   'with_ts_index': {'avg': 0.1694,
#                                     'min': 0.1693,
#                                     'max': 0.1697,
#                                     'std': 0.0002,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:53'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2681,
#  'min': 1.2306,
#  'max': 1.287,
#  'std': 0.0265,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:57'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2997,
#  'min': 0.2738,
#  'max': 0.3509,
#  'std': 0.0362,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:57'}
# perf_file for the run for year " 2019 " and word " apartment " is:
# {'apartment_2019': {'no_ts_index': {'avg': 1.2681,
#                                     'min': 1.2306,
#                                     'max': 1.287,
#                                     'std': 0.0265,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:57'},
#                     'with_ts_index': {'avg': 0.2997,
#                                       'min': 0.2738,
#                                       'max': 0.3509,
#                                       'std': 0.0362,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:21:57'}}}
#
# Entering loop for yr =  2020
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1679,
#  'min': 0.1521,
#  'max': 0.1975,
#  'std': 0.0209,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:58'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0569,
#  'min': 0.0536,
#  'max': 0.0604,
#  'std': 0.0028,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:58'}
# perf_file for the run for year " 2020 " and word " horrible " is:
# {'horrible_2020': {'no_ts_index': {'avg': 0.1679,
#                                    'min': 0.1521,
#                                    'max': 0.1975,
#                                    'std': 0.0209,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:58'},
#                    'with_ts_index': {'avg': 0.0569,
#                                      'min': 0.0536,
#                                      'max': 0.0604,
#                                      'std': 0.0028,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:58'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.1712,
#  'min': 0.1706,
#  'max': 0.1718,
#  'std': 0.0005,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.0649,
#  'min': 0.0628,
#  'max': 0.0679,
#  'std': 0.0022,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:59'}
# perf_file for the run for year " 2020 " and word " awesome " is:
# {'awesome_2020': {'no_ts_index': {'avg': 0.1712,
#                                   'min': 0.1706,
#                                   'max': 0.1718,
#                                   'std': 0.0005,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:59'},
#                   'with_ts_index': {'avg': 0.0649,
#                                     'min': 0.0628,
#                                     'max': 0.0679,
#                                     'std': 0.0022,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:59'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 0.206,
#  'min': 0.2001,
#  'max': 0.2154,
#  'std': 0.0067,
#  'count': 3,
#  'timestamp': '2024-05-07-19:21:59'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.116,
#  'min': 0.095,
#  'max': 0.1474,
#  'std': 0.0226,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:00'}
# perf_file for the run for year " 2020 " and word " apartment " is:
# {'apartment_2020': {'no_ts_index': {'avg': 0.206,
#                                     'min': 0.2001,
#                                     'max': 0.2154,
#                                     'std': 0.0067,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:59'},
#                     'with_ts_index': {'avg': 0.116,
#                                       'min': 0.095,
#                                       'max': 0.1474,
#                                       'std': 0.0226,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:22:00'}}}
#
# Entering loop for yr =  2021
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1571,
#  'min': 1.1228,
#  'max': 1.2001,
#  'std': 0.0321,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:03'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1422,
#  'min': 0.1367,
#  'max': 0.1454,
#  'std': 0.0039,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:04'}
# perf_file for the run for year " 2021 " and word " horrible " is:
# {'horrible_2021': {'no_ts_index': {'avg': 1.1571,
#                                    'min': 1.1228,
#                                    'max': 1.2001,
#                                    'std': 0.0321,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:03'},
#                    'with_ts_index': {'avg': 0.1422,
#                                      'min': 0.1367,
#                                      'max': 0.1454,
#                                      'std': 0.0039,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:04'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1617,
#  'min': 1.1442,
#  'max': 1.1781,
#  'std': 0.0139,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:07'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.1435,
#  'min': 0.1429,
#  'max': 0.1442,
#  'std': 0.0005,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:08'}
# perf_file for the run for year " 2021 " and word " awesome " is:
# {'awesome_2021': {'no_ts_index': {'avg': 1.1617,
#                                   'min': 1.1442,
#                                   'max': 1.1781,
#                                   'std': 0.0139,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:07'},
#                   'with_ts_index': {'avg': 0.1435,
#                                     'min': 0.1429,
#                                     'max': 0.1442,
#                                     'std': 0.0005,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:08'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2317,
#  'min': 1.2095,
#  'max': 1.2759,
#  'std': 0.0313,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:11'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.23,
#  'min': 0.2067,
#  'max': 0.2679,
#  'std': 0.027,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:12'}
# perf_file for the run for year " 2021 " and word " apartment " is:
# {'apartment_2021': {'no_ts_index': {'avg': 1.2317,
#                                     'min': 1.2095,
#                                     'max': 1.2759,
#                                     'std': 0.0313,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:11'},
#                     'with_ts_index': {'avg': 0.23,
#                                       'min': 0.2067,
#                                       'max': 0.2679,
#                                       'std': 0.027,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:22:12'}}}
#
# Entering loop for yr =  2022
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.0886,
#  'min': 1.0824,
#  'max': 1.0928,
#  'std': 0.0045,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:15'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2282,
#  'min': 0.2272,
#  'max': 0.2293,
#  'std': 0.0009,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:16'}
# perf_file for the run for year " 2022 " and word " horrible " is:
# {'horrible_2022': {'no_ts_index': {'avg': 1.0886,
#                                    'min': 1.0824,
#                                    'max': 1.0928,
#                                    'std': 0.0045,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:15'},
#                    'with_ts_index': {'avg': 0.2282,
#                                      'min': 0.2272,
#                                      'max': 0.2293,
#                                      'std': 0.0009,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:16'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.2214,
#  'min': 1.212,
#  'max': 1.2277,
#  'std': 0.0068,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:20'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2481,
#  'min': 0.2424,
#  'max': 0.2519,
#  'std': 0.0041,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:20'}
# perf_file for the run for year " 2022 " and word " awesome " is:
# {'awesome_2022': {'no_ts_index': {'avg': 1.2214,
#                                   'min': 1.212,
#                                   'max': 1.2277,
#                                   'std': 0.0068,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:20'},
#                   'with_ts_index': {'avg': 0.2481,
#                                     'min': 0.2424,
#                                     'max': 0.2519,
#                                     'std': 0.0041,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:20'}}}
# Entering sub-loop for word:  apartment
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.3292,
#  'min': 1.2969,
#  'max': 1.3576,
#  'std': 0.0249,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:24'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.4105,
#  'min': 0.392,
#  'max': 0.4243,
#  'std': 0.0136,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:26'}
# perf_file for the run for year " 2022 " and word " apartment " is:
# {'apartment_2022': {'no_ts_index': {'avg': 1.3292,
#                                     'min': 1.2969,
#                                     'max': 1.3576,
#                                     'std': 0.0249,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:24'},
#                     'with_ts_index': {'avg': 0.4105,
#                                       'min': 0.392,
#                                       'max': 0.4243,
#                                       'std': 0.0136,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:22:26'}}}
#
# Entering loop for yr =  2023
# Entering sub-loop for word:  horrible
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.074,
#  'min': 1.0641,
#  'max': 1.0908,
#  'std': 0.0119,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:29'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2557,
#  'min': 0.2522,
#  'max': 0.2612,
#  'std': 0.0039,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:30'}
# perf_file for the run for year " 2023 " and word " horrible " is:
# {'horrible_2023': {'no_ts_index': {'avg': 1.074,
#                                    'min': 1.0641,
#                                    'max': 1.0908,
#                                    'std': 0.0119,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:29'},
#                    'with_ts_index': {'avg': 0.2557,
#                                      'min': 0.2522,
#                                      'max': 0.2612,
#                                      'std': 0.0039,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:30'}}}
# Entering sub-loop for word:  awesome
# starting on query q1
# Perf profile for no index is:
# {'avg': 1.1884,
#  'min': 1.1486,
#  'max': 1.2309,
#  'std': 0.0337,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:33'}
# starting on query q2
# Perf profile for ts index is:
# {'avg': 0.2651,
#  'min': 0.2628,
#  'max': 0.2668,
#  'std': 0.0017,
#  'count': 3,
#  'timestamp': '2024-05-07-19:22:34'}
# perf_file for the run for year " 2023 " and word " awesome " is:
# {'awesome_2023': {'no_ts_index': {'avg': 1.1884,
#                                   'min': 1.1486,
#                                   'max': 1.2309,
#                                   'std': 0.0337,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:33'},
#                   'with_ts_index': {'avg': 0.2651,
#                                     'min': 0.2628,
#                                     'max': 0.2668,
#                                     'std': 0.0017,
# ...
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:39'},
#                   'with_ts_index': {'avg': 0.1033,
#                                     'min': 0.1023,
#                                     'max': 0.1044,
#                                     'std': 0.0009,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:40'}},
#  'awesome_2018': {'no_ts_index': {'avg': 0.1868,
#                                   'min': 0.1854,
#                                   'max': 0.1892,
#                                   'std': 0.0017,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:43'},
#                   'with_ts_index': {'avg': 0.1336,
#                                     'min': 0.1322,
#                                     'max': 0.1348,
#                                     'std': 0.0011,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:43'}},
#  'awesome_2019': {'no_ts_index': {'avg': 1.1879,
#                                   'min': 1.1531,
#                                   'max': 1.2075,
#                                   'std': 0.0247,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:52'},
#                   'with_ts_index': {'avg': 0.1694,
#                                     'min': 0.1693,
#                                     'max': 0.1697,
#                                     'std': 0.0002,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:53'}},
#  'awesome_2020': {'no_ts_index': {'avg': 0.1712,
#                                   'min': 0.1706,
#                                   'max': 0.1718,
#                                   'std': 0.0005,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:21:59'},
#                   'with_ts_index': {'avg': 0.0649,
#                                     'min': 0.0628,
#                                     'max': 0.0679,
#                                     'std': 0.0022,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:21:59'}},
#  'awesome_2021': {'no_ts_index': {'avg': 1.1617,
#                                   'min': 1.1442,
#                                   'max': 1.1781,
#                                   'std': 0.0139,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:07'},
#                   'with_ts_index': {'avg': 0.1435,
#                                     'min': 0.1429,
#                                     'max': 0.1442,
#                                     'std': 0.0005,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:08'}},
#  'awesome_2022': {'no_ts_index': {'avg': 1.2214,
#                                   'min': 1.212,
#                                   'max': 1.2277,
#                                   'std': 0.0068,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:20'},
#                   'with_ts_index': {'avg': 0.2481,
#                                     'min': 0.2424,
#                                     'max': 0.2519,
#                                     'std': 0.0041,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:20'}},
#  'awesome_2023': {'no_ts_index': {'avg': 1.1884,
#                                   'min': 1.1486,
#                                   'max': 1.2309,
#                                   'std': 0.0337,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:33'},
#                   'with_ts_index': {'avg': 0.2651,
#                                     'min': 0.2628,
#                                     'max': 0.2668,
#                                     'std': 0.0017,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:34'}},
#  'awesome_2024': {'no_ts_index': {'avg': 0.0325,
#                                   'min': 0.0316,
#                                   'max': 0.0337,
#                                   'std': 0.0009,
#                                   'count': 3,
#                                   'timestamp': '2024-05-07-19:22:40'},
#                   'with_ts_index': {'avg': 0.02,
#                                     'min': 0.0197,
#                                     'max': 0.0203,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:40'}},
#  'horrible_2009': {'no_ts_index': {'avg': 0.005,
#                                    'min': 0.0042,
#                                    'max': 0.0065,
#                                    'std': 0.0011,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0042,
#                                      'min': 0.0031,
#                                      'max': 0.0055,
#                                      'std': 0.001,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}},
#  'horrible_2010': {'no_ts_index': {'avg': 0.0053,
#                                    'min': 0.0042,
#                                    'max': 0.0064,
#                                    'std': 0.0009,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0038,
#                                      'min': 0.0034,
#                                      'max': 0.0046,
#                                      'std': 0.0006,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}},
#  'horrible_2011': {'no_ts_index': {'avg': 0.0134,
#                                    'min': 0.0128,
#                                    'max': 0.0139,
#                                    'std': 0.0004,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.007,
#                                      'min': 0.0057,
#                                      'max': 0.0078,
#                                      'std': 0.0009,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}},
#  'horrible_2012': {'no_ts_index': {'avg': 0.025,
#                                    'min': 0.0228,
#                                    'max': 0.0282,
#                                    'std': 0.0024,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0112,
#                                      'min': 0.0105,
#                                      'max': 0.0126,
#                                      'std': 0.001,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:29'}},
#  'horrible_2013': {'no_ts_index': {'avg': 0.0424,
#                                    'min': 0.0396,
#                                    'max': 0.0472,
#                                    'std': 0.0034,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:29'},
#                    'with_ts_index': {'avg': 0.0216,
#                                      'min': 0.0187,
#                                      'max': 0.0267,
#                                      'std': 0.0036,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:30'}},
#  'horrible_2014': {'no_ts_index': {'avg': 0.0792,
#                                    'min': 0.0739,
#                                    'max': 0.0845,
#                                    'std': 0.0043,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:30'},
#                    'with_ts_index': {'avg': 0.0357,
#                                      'min': 0.0338,
#                                      'max': 0.0393,
#                                      'std': 0.0025,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:30'}},
#  'horrible_2015': {'no_ts_index': {'avg': 0.1489,
#                                    'min': 0.1379,
#                                    'max': 0.1608,
#                                    'std': 0.0094,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:32'},
#                    'with_ts_index': {'avg': 0.0664,
#                                      'min': 0.0641,
#                                      'max': 0.0702,
#                                      'std': 0.0027,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:32'}},
#  'horrible_2016': {'no_ts_index': {'avg': 0.2249,
#                                    'min': 0.2185,
#                                    'max': 0.2285,
#                                    'std': 0.0045,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:35'},
#                    'with_ts_index': {'avg': 0.0614,
#                                      'min': 0.0564,
#                                      'max': 0.0713,
#                                      'std': 0.0069,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:35'}},
#  'horrible_2017': {'no_ts_index': {'avg': 0.2611,
#                                    'min': 0.2455,
#                                    'max': 0.273,
#                                    'std': 0.0115,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:38'},
#                    'with_ts_index': {'avg': 0.0913,
#                                      'min': 0.0885,
#                                      'max': 0.0937,
#                                      'std': 0.0022,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:38'}},
#  'horrible_2018': {'no_ts_index': {'avg': 0.1651,
#                                    'min': 0.1644,
#                                    'max': 0.1666,
#                                    'std': 0.0011,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:42'},
#                    'with_ts_index': {'avg': 0.1271,
#                                      'min': 0.1255,
#                                      'max': 0.1293,
#                                      'std': 0.0016,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:42'}},
#  'horrible_2019': {'no_ts_index': {'avg': 1.1021,
#                                    'min': 1.06,
#                                    'max': 1.1349,
#                                    'std': 0.0313,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:48'},
#                    'with_ts_index': {'avg': 0.1708,
#                                      'min': 0.1645,
#                                      'max': 0.1741,
#                                      'std': 0.0045,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:49'}},
#  'horrible_2020': {'no_ts_index': {'avg': 0.1679,
#                                    'min': 0.1521,
#                                    'max': 0.1975,
#                                    'std': 0.0209,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:21:58'},
#                    'with_ts_index': {'avg': 0.0569,
#                                      'min': 0.0536,
#                                      'max': 0.0604,
#                                      'std': 0.0028,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:21:58'}},
#  'horrible_2021': {'no_ts_index': {'avg': 1.1571,
#                                    'min': 1.1228,
#                                    'max': 1.2001,
#                                    'std': 0.0321,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:03'},
#                    'with_ts_index': {'avg': 0.1422,
#                                      'min': 0.1367,
#                                      'max': 0.1454,
#                                      'std': 0.0039,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:04'}},
#  'horrible_2022': {'no_ts_index': {'avg': 1.0886,
#                                    'min': 1.0824,
#                                    'max': 1.0928,
#                                    'std': 0.0045,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:15'},
#                    'with_ts_index': {'avg': 0.2282,
#                                      'min': 0.2272,
#                                      'max': 0.2293,
#                                      'std': 0.0009,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:16'}},
#  'horrible_2023': {'no_ts_index': {'avg': 1.074,
#                                    'min': 1.0641,
#                                    'max': 1.0908,
#                                    'std': 0.0119,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:29'},
#                    'with_ts_index': {'avg': 0.2557,
#                                      'min': 0.2522,
#                                      'max': 0.2612,
#                                      'std': 0.0039,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:30'}},
#  'horrible_2024': {'no_ts_index': {'avg': 0.0322,
#                                    'min': 0.03,
#                                    'max': 0.0361,
#                                    'std': 0.0028,
#                                    'count': 3,
#                                    'timestamp': '2024-05-07-19:22:40'},
#                    'with_ts_index': {'avg': 0.0199,
#                                      'min': 0.0197,
#                                      'max': 0.0202,
#                                      'std': 0.0002,
#                                      'count': 3,
#                                      'timestamp': '2024-05-07-19:22:40'}},
#  'apartment_2024': {'no_ts_index': {'avg': 0.0382,
#                                     'min': 0.0379,
#                                     'max': 0.0386,
#                                     'std': 0.0003,
#                                     'count': 3,
#                                     'timestamp': '2024-05-07-19:22:40'},
#                     'with_ts_index': {'avg': 0.0425,
#                                       'min': 0.0273,
#                                       'max': 0.0718,
#                                       'std': 0.0207,
#                                       'count': 3,
#                                       'timestamp': '2024-05-07-19:22:40'}}}

# %%
# Out:
# [('apartment_2009',
#   {'no_ts_index': {'avg': 0.0033,
#                    'min': 0.0028,
#                    'max': 0.004,
#                    'std': 0.0005,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.002,
#                      'min': 0.0019,
#                      'max': 0.0021,
#                      'std': 0.0001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2010',
#   {'no_ts_index': {'avg': 0.0059,
#                    'min': 0.0053,
#                    'max': 0.0067,
#                    'std': 0.0006,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0038,
#                      'min': 0.0037,
#                      'max': 0.0041,
#                      'std': 0.0002,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2011',
#   {'no_ts_index': {'avg': 0.0168,
#                    'min': 0.016,
#                    'max': 0.0173,
#                    'std': 0.0006,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0122,
#                      'min': 0.0111,
#                      'max': 0.0133,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2012',
#   {'no_ts_index': {'avg': 0.0351,
#                    'min': 0.0334,
#                    'max': 0.0376,
#                    'std': 0.0018,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0234,
#                      'min': 0.0224,
#                      'max': 0.024,
#                      'std': 0.0007,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('apartment_2013',
#   {'no_ts_index': {'avg': 0.0631,
#                    'min': 0.0604,
#                    'max': 0.0645,
#                    'std': 0.0019,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:30'},
#    'with_ts_index': {'avg': 0.0446,
#                      'min': 0.0438,
#                      'max': 0.046,
#                      'std': 0.001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('apartment_2014',
#   {'no_ts_index': {'avg': 0.1203,
#                    'min': 0.1198,
#                    'max': 0.1206,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:31'},
#    'with_ts_index': {'avg': 0.085,
#                      'min': 0.0827,
#                      'max': 0.0885,
#                      'std': 0.0025,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:31'}}),
#  ('apartment_2015',
#   {'no_ts_index': {'avg': 0.2357,
#                    'min': 0.2217,
#                    'max': 0.2603,
#                    'std': 0.0174,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:33'},
#    'with_ts_index': {'avg': 0.1576,
#                      'min': 0.1526,
#                      'max': 0.1621,
#                      'std': 0.0039,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:34'}}),
#  ('apartment_2016',
#   {'no_ts_index': {'avg': 0.3443,
#                    'min': 0.3217,
#                    'max': 0.3799,
#                    'std': 0.0255,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:37'},
#    'with_ts_index': {'avg': 0.1759,
#                      'min': 0.1556,
#                      'max': 0.2009,
#                      'std': 0.0188,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:37'}}),
#  ('apartment_2017',
#   {'no_ts_index': {'avg': 0.398,
#                    'min': 0.3958,
#                    'max': 0.3995,
#                    'std': 0.0016,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:41'},
#    'with_ts_index': {'avg': 0.1914,
#                      'min': 0.1754,
#                      'max': 0.2202,
#                      'std': 0.0204,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:41'}}),
#  ('apartment_2018',
#   {'no_ts_index': {'avg': 0.2974,
#                    'min': 0.2709,
#                    'max': 0.3157,
#                    'std': 0.0192,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:44'},
#    'with_ts_index': {'avg': 0.2476,
#                      'min': 0.2262,
#                      'max': 0.2831,
#                      'std': 0.0253,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:45'}}),
#  ('apartment_2019',
#   {'no_ts_index': {'avg': 1.2681,
#                    'min': 1.2306,
#                    'max': 1.287,
#                    'std': 0.0265,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:57'},
#    'with_ts_index': {'avg': 0.2997,
#                      'min': 0.2738,
#                      'max': 0.3509,
#                      'std': 0.0362,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:57'}}),
#  ('apartment_2020',
#   {'no_ts_index': {'avg': 0.206,
#                    'min': 0.2001,
#                    'max': 0.2154,
#                    'std': 0.0067,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:59'},
#    'with_ts_index': {'avg': 0.116,
#                      'min': 0.095,
#                      'max': 0.1474,
#                      'std': 0.0226,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:00'}}),
#  ('apartment_2021',
#   {'no_ts_index': {'avg': 1.2317,
#                    'min': 1.2095,
#                    'max': 1.2759,
#                    'std': 0.0313,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:11'},
#    'with_ts_index': {'avg': 0.23,
#                      'min': 0.2067,
#                      'max': 0.2679,
#                      'std': 0.027,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:12'}}),
#  ('apartment_2022',
#   {'no_ts_index': {'avg': 1.3292,
#                    'min': 1.2969,
#                    'max': 1.3576,
#                    'std': 0.0249,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:24'},
#    'with_ts_index': {'avg': 0.4105,
#                      'min': 0.392,
#                      'max': 0.4243,
#                      'std': 0.0136,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:26'}}),
#  ('apartment_2023',
#   {'no_ts_index': {'avg': 1.3937,
#                    'min': 1.3481,
#                    'max': 1.4245,
#                    'std': 0.0329,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:38'},
#    'with_ts_index': {'avg': 0.4205,
#                      'min': 0.3971,
#                      'max': 0.4624,
#                      'std': 0.0297,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:39'}}),
#  ('apartment_2024',
#   {'no_ts_index': {'avg': 0.0382,
#                    'min': 0.0379,
#                    'max': 0.0386,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:40'},
#    'with_ts_index': {'avg': 0.0425,
#                      'min': 0.0273,
#                      'max': 0.0718,
#                      'std': 0.0207,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:40'}}),
#  ('awesome_2009',
#   {'no_ts_index': {'avg': 0.0034,
#                    'min': 0.0029,
#                    'max': 0.004,
#                    'std': 0.0005,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0031,
#                      'min': 0.0025,
#                      'max': 0.0038,
#                      'std': 0.0006,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2010',
#   {'no_ts_index': {'avg': 0.0051,
#                    'min': 0.0047,
#                    'max': 0.006,
#                    'std': 0.0006,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.003,
#                      'min': 0.0027,
#                      'max': 0.0035,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2011',
#   {'no_ts_index': {'avg': 0.0128,
#                    'min': 0.0125,
#                    'max': 0.0131,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0065,
#                      'min': 0.0061,
#                      'max': 0.0068,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2012',
#   {'no_ts_index': {'avg': 0.0246,
#                    'min': 0.0244,
#                    'max': 0.0248,
#                    'std': 0.0002,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0118,
#                      'min': 0.0115,
#                      'max': 0.0121,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('awesome_2013',
#   {'no_ts_index': {'avg': 0.0432,
#                    'min': 0.0428,
#                    'max': 0.0435,
#                    'std': 0.0003,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:30'},
#    'with_ts_index': {'avg': 0.0205,
#                      'min': 0.0203,
#                      'max': 0.0208,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('awesome_2014',
#   {'no_ts_index': {'avg': 0.0832,
#                    'min': 0.0823,
#                    'max': 0.0841,
#                    'std': 0.0007,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:31'},
#    'with_ts_index': {'avg': 0.0369,
#                      'min': 0.0361,
#                      'max': 0.0379,
#                      'std': 0.0008,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:31'}}),
#  ('awesome_2015',
#   {'no_ts_index': {'avg': 0.1549,
#                    'min': 0.153,
#                    'max': 0.1562,
#                    'std': 0.0014,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:33'},
#    'with_ts_index': {'avg': 0.0763,
#                      'min': 0.0753,
#                      'max': 0.077,
#                      'std': 0.0007,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:33'}}),
#  ('awesome_2016',
#   {'no_ts_index': {'avg': 0.2309,
#                    'min': 0.2274,
#                    'max': 0.2363,
#                    'std': 0.0039,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:35'},
#    'with_ts_index': {'avg': 0.0622,
#                      'min': 0.0603,
#                      'max': 0.0631,
#                      'std': 0.0013,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:36'}}),
#  ('awesome_2017',
#   {'no_ts_index': {'avg': 0.2983,
#                    'min': 0.2924,
#                    'max': 0.3093,
#                    'std': 0.0078,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:39'},
#    'with_ts_index': {'avg': 0.1033,
#                      'min': 0.1023,
#                      'max': 0.1044,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:40'}}),
#  ('awesome_2018',
#   {'no_ts_index': {'avg': 0.1868,
#                    'min': 0.1854,
#                    'max': 0.1892,
#                    'std': 0.0017,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:43'},
#    'with_ts_index': {'avg': 0.1336,
#                      'min': 0.1322,
#                      'max': 0.1348,
#                      'std': 0.0011,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:43'}}),
#  ('awesome_2019',
#   {'no_ts_index': {'avg': 1.1879,
#                    'min': 1.1531,
#                    'max': 1.2075,
#                    'std': 0.0247,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:52'},
#    'with_ts_index': {'avg': 0.1694,
#                      'min': 0.1693,
#                      'max': 0.1697,
#                      'std': 0.0002,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:53'}}),
#  ('awesome_2020',
#   {'no_ts_index': {'avg': 0.1712,
#                    'min': 0.1706,
#                    'max': 0.1718,
#                    'std': 0.0005,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:59'},
#    'with_ts_index': {'avg': 0.0649,
#                      'min': 0.0628,
#                      'max': 0.0679,
#                      'std': 0.0022,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:59'}}),
#  ('awesome_2021',
#   {'no_ts_index': {'avg': 1.1617,
#                    'min': 1.1442,
#                    'max': 1.1781,
#                    'std': 0.0139,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:07'},
#    'with_ts_index': {'avg': 0.1435,
#                      'min': 0.1429,
#                      'max': 0.1442,
#                      'std': 0.0005,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:08'}}),
#  ('awesome_2022',
#   {'no_ts_index': {'avg': 1.2214,
#                    'min': 1.212,
#                    'max': 1.2277,
#                    'std': 0.0068,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:20'},
#    'with_ts_index': {'avg': 0.2481,
#                      'min': 0.2424,
#                      'max': 0.2519,
#                      'std': 0.0041,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:20'}}),
#  ('awesome_2023',
#   {'no_ts_index': {'avg': 1.1884,
#                    'min': 1.1486,
#                    'max': 1.2309,
#                    'std': 0.0337,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:33'},
#    'with_ts_index': {'avg': 0.2651,
#                      'min': 0.2628,
#                      'max': 0.2668,
#                      'std': 0.0017,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:34'}}),
#  ('awesome_2024',
#   {'no_ts_index': {'avg': 0.0325,
#                    'min': 0.0316,
#                    'max': 0.0337,
#                    'std': 0.0009,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:40'},
#    'with_ts_index': {'avg': 0.02,
#                      'min': 0.0197,
#                      'max': 0.0203,
#                      'std': 0.0003,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:40'}}),
#  ('horrible_2009',
#   {'no_ts_index': {'avg': 0.005,
#                    'min': 0.0042,
#                    'max': 0.0065,
#                    'std': 0.0011,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0042,
#                      'min': 0.0031,
#                      'max': 0.0055,
#                      'std': 0.001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2010',
#   {'no_ts_index': {'avg': 0.0053,
#                    'min': 0.0042,
#                    'max': 0.0064,
#                    'std': 0.0009,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0038,
#                      'min': 0.0034,
#                      'max': 0.0046,
#                      'std': 0.0006,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2011',
#   {'no_ts_index': {'avg': 0.0134,
#                    'min': 0.0128,
#                    'max': 0.0139,
#                    'std': 0.0004,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.007,
#                      'min': 0.0057,
#                      'max': 0.0078,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2012',
#   {'no_ts_index': {'avg': 0.025,
#                    'min': 0.0228,
#                    'max': 0.0282,
#                    'std': 0.0024,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0112,
#                      'min': 0.0105,
#                      'max': 0.0126,
#                      'std': 0.001,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:29'}}),
#  ('horrible_2013',
#   {'no_ts_index': {'avg': 0.0424,
#                    'min': 0.0396,
#                    'max': 0.0472,
#                    'std': 0.0034,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:29'},
#    'with_ts_index': {'avg': 0.0216,
#                      'min': 0.0187,
#                      'max': 0.0267,
#                      'std': 0.0036,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('horrible_2014',
#   {'no_ts_index': {'avg': 0.0792,
#                    'min': 0.0739,
#                    'max': 0.0845,
#                    'std': 0.0043,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:30'},
#    'with_ts_index': {'avg': 0.0357,
#                      'min': 0.0338,
#                      'max': 0.0393,
#                      'std': 0.0025,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:30'}}),
#  ('horrible_2015',
#   {'no_ts_index': {'avg': 0.1489,
#                    'min': 0.1379,
#                    'max': 0.1608,
#                    'std': 0.0094,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:32'},
#    'with_ts_index': {'avg': 0.0664,
#                      'min': 0.0641,
#                      'max': 0.0702,
#                      'std': 0.0027,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:32'}}),
#  ('horrible_2016',
#   {'no_ts_index': {'avg': 0.2249,
#                    'min': 0.2185,
#                    'max': 0.2285,
#                    'std': 0.0045,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:35'},
#    'with_ts_index': {'avg': 0.0614,
#                      'min': 0.0564,
#                      'max': 0.0713,
#                      'std': 0.0069,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:35'}}),
#  ('horrible_2017',
#   {'no_ts_index': {'avg': 0.2611,
#                    'min': 0.2455,
#                    'max': 0.273,
#                    'std': 0.0115,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:38'},
#    'with_ts_index': {'avg': 0.0913,
#                      'min': 0.0885,
#                      'max': 0.0937,
#                      'std': 0.0022,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:38'}}),
#  ('horrible_2018',
#   {'no_ts_index': {'avg': 0.1651,
#                    'min': 0.1644,
#                    'max': 0.1666,
#                    'std': 0.0011,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:42'},
#    'with_ts_index': {'avg': 0.1271,
#                      'min': 0.1255,
#                      'max': 0.1293,
#                      'std': 0.0016,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:42'}}),
#  ('horrible_2019',
#   {'no_ts_index': {'avg': 1.1021,
#                    'min': 1.06,
#                    'max': 1.1349,
#                    'std': 0.0313,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:48'},
#    'with_ts_index': {'avg': 0.1708,
#                      'min': 0.1645,
#                      'max': 0.1741,
#                      'std': 0.0045,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:49'}}),
#  ('horrible_2020',
#   {'no_ts_index': {'avg': 0.1679,
#                    'min': 0.1521,
#                    'max': 0.1975,
#                    'std': 0.0209,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:21:58'},
#    'with_ts_index': {'avg': 0.0569,
#                      'min': 0.0536,
#                      'max': 0.0604,
#                      'std': 0.0028,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:21:58'}}),
#  ('horrible_2021',
#   {'no_ts_index': {'avg': 1.1571,
#                    'min': 1.1228,
#                    'max': 1.2001,
#                    'std': 0.0321,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:03'},
#    'with_ts_index': {'avg': 0.1422,
#                      'min': 0.1367,
#                      'max': 0.1454,
#                      'std': 0.0039,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:04'}}),
#  ('horrible_2022',
#   {'no_ts_index': {'avg': 1.0886,
#                    'min': 1.0824,
#                    'max': 1.0928,
#                    'std': 0.0045,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:15'},
#    'with_ts_index': {'avg': 0.2282,
#                      'min': 0.2272,
#                      'max': 0.2293,
#                      'std': 0.0009,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:16'}}),
#  ('horrible_2023',
#   {'no_ts_index': {'avg': 1.074,
#                    'min': 1.0641,
#                    'max': 1.0908,
#                    'std': 0.0119,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:29'},
#    'with_ts_index': {'avg': 0.2557,
#                      'min': 0.2522,
#                      'max': 0.2612,
#                      'std': 0.0039,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:30'}}),
#  ('horrible_2024',
#   {'no_ts_index': {'avg': 0.0322,
#                    'min': 0.03,
#                    'max': 0.0361,
#                    'std': 0.0028,
#                    'count': 3,
#                    'timestamp': '2024-05-07-19:22:40'},
#    'with_ts_index': {'avg': 0.0199,
#                      'min': 0.0197,
#                      'max': 0.0202,
#                      'std': 0.0002,
#                      'count': 3,
#                      'timestamp': '2024-05-07-19:22:40'}})]

# %% [markdown]
# ### <span style=color:blue>Here is an interesting query, in which we can vary three things: price range of the listing, year of when a review was made, and whether one of the 3 main words is in the review.

# %%
q_using_ts_index = """select count(*)
from listings l, reviews r
where l.id = r.listing_id
  and r.date >= '2015-01-01' and r.date <= '2015-12-31'
  and comments_tsv @@ to_tsquery('awesome')
  and l.price >= 300 and l.price < 400"""

# notice that I'm using the double "%%"; sqlalchemy reads that as "%"
q_not_using_ts_index = """select count(*)
from listings l, reviews r
where l.id = r.listing_id
  and r.date >= '2015-01-01' and r.date <= '2015-12-31'
  and comments ilike '%%awesome%%'
  and l.price >= 300 and l.price < 400"""

count = 10
perf_with_ts_index, time_list = util.run_one_query(db_eng, q_using_ts_index, count)
perf_no_ts_index, time_list = util.run_one_query(db_eng, q_not_using_ts_index, count)

print('Perf profile when using ts index is:')
pprint.pp(perf_with_ts_index)

print('\nPerf profile when NOT using ts index is:')
pprint.pp(perf_no_ts_index)
# Out:
# Perf profile when using ts index is:
# {'avg': 0.0754,
#  'min': 0.069,
#  'max': 0.1181,
#  'std': 0.0143,
#  'count': 10,
#  'timestamp': '2024-05-07-19:13:16'}
#
# Perf profile when NOT using ts index is:
# {'avg': 0.1434,
#  'min': 0.1412,
#  'max': 0.1457,
#  'std': 0.0015,
#  'count': 10,
#  'timestamp': '2024-05-07-19:13:17'}

# %%
print('0100s'[1:4])
# Out:
# 100
