# %%
# These are boiler plate imports that seem useful
# Perhaps cleaner would be to delete or comment out the ones that aren't used in this script...

import sys
import json
import csv
import yaml

import copy

import pandas as pd
import numpy as np

import matplotlib as mpl

import time
from datetime import datetime
# see https://stackoverflow.com/questions/415511/how-do-i-get-the-current-time-in-python
#   for some basics about datetime

import pprint

# sqlalchemy 2.0 documentation: https://www.sqlalchemy.org/
import psycopg2
from sqlalchemy import create_engine, text as sql_text

# the following is deprecated, it seems, so using the sqlalchemy
# from pyscopg2 import sqlio

# the file in benchmarking/util.py should hold utilities useful for your benchmarking exercise
# In this notebook we have commented out all mentions of util, so that you can run
#    this notebook before setting up your benchmarking/util.py file
sys.path.append('benchmarking/')
import util
# to invoke a function "foo()" inside util.py, use "util.foo()"

# %% [markdown]
# ### <span style=color:blue>Setting up Postgres connection.  Note database name is "airbnb" </span>
#
# ### <span style=color:blue>Note: this should be modified so that the user name/password are not included into the program. </span>

# %%
# following https://www.geeksforgeeks.org/connecting-postgresql-with-sqlalchemy-in-python/

db_eng = create_engine('postgresql+psycopg2://postgres:postgres@localhost:5432/airbnb',
                       connect_args={'options': '-csearch_path={}'.format('new_york_city')},
                       isolation_level = 'SERIALIZABLE')
#    , echo=True)
#    , echo_pool="debug")

print("Successfully created db engine.")

# connect_args is used to set search_path to the schema 'new_york_city' in the airbnb database

# isolation_level SERIALIZABLE makes transactions happen in sequence, which is good 
#      for the benchmarking we will be doing

# for general info on sqlalchemy connections,
#    see: https://docs.sqlalchemy.org/en/20/core/connections.html

# echo from https://docs.sqlalchemy.org/en/20/core/engines.html
# Out:
# Successfully created db engine.

# %% [markdown]
# ### <span style=color:blue>The next segment is focused on the index datetime_in_reviews, including tests on time for updating the datetime attribute with/without that index </span>

# %%
ngroup = 'Manhattan'
days = 5

q = util.build_update_ngroup_datetime_in_reviews(db_eng, ngroup, days)
print(q)
print()

days = - days
neigh = 'Bedford-Stuyvesant'
q1 = util.build_update_neigh_datetime_in_reviews(db_eng, neigh, days)
print(q1)
# Out:
# UPDATE reviews r
# SET datetime = datetime + interval '5 days'
# FROM listings l
# WHERE l.id = r.listing_id
#   AND l.neighbourhood_group = 'Manhattan'
# RETURNING 'done';
#
# UPDATE reviews r
# SET datetime = datetime - interval '5 days'
# FROM listings l
# WHERE l.id = r.listing_id
#   AND l.neighbourhood = 'Bedford-Stuyvesant'
# RETURNING 'done';

# %%
all_indexes = [['datetime','reviews'], ['id','listings'],['neighbourhood', 'listings'], 
               ['neighbourhood_group','listings'],
               ['date','reviews'], ['price','listings'], ['comments_in_reviews']]
all_indexes = [['datetime','reviews'], ['id','listings'],['neighbourhood', 'listings'], ['date','reviews'], ['price','listings']]
i_spec_list = [['datetime','reviews'], ['neighbourhood', 'listings']]

for i_spec in all_indexes:
    result = util.add_drop_index(db_eng, 'drop', i_spec)
    pprint.pp(result)

print('\n\nCurrent set of indexes in effect is:')
indexes_in_effect = util.fetch_all_index_info(db_eng, i_spec_list)
pprint.pp(indexes_in_effect, width=150)
# Out:
# [('new_york_city', 'reviews', 'comments_tsv_in_reviews', None, 'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)')]
# [('new_york_city', 'listings', 'neighbourhood_in_listings', None, 'CREATE INDEX neighbourhood_in_listings ON new_york_city.listings USING btree (neighbourhood)')]
# []
# [('new_york_city', 'reviews', 'comments_tsv_in_reviews', None, 'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)')]
# []
#
#
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)'], 'listings': []}

# %%
all_indexes = [['id','listings'],['neighbourhood', 'listings'], ['neighbourhood_group','listings'],['datetime','reviews'],['date','reviews'], ['price','listings'], ['comments','reviews']]
i_spec_nbhd_list = [['datetime','reviews'],['neighbourhood','listings']]
i_spec_ngroup_list = [['datetime','reviews'],['neighbourhood_group','listings']]

neigh_list = ['Bedford-Stuyvesant',      # 99,705  about 20 vs 17.5
                'Long Island City',     # 10,895   about 2.58 vs 2.19
                'Fort Hamilton',        # 1,000           .72 vs .70
                'New Springville']       #  104

ngroup_list = ['Brooklyn',         # 432109
               'Manhattan',        # 341287
               'Queens',           # 173392
               'Bronx',            # 35296
               'Staten Island']    # 13726


neigh = 'New Springville'
# neigh = 'Fort Hamilton'           # done
# neigh = 'Long Island City'       # done
# neigh = 'Bedford-Stuyvesant'      # done
# neigh = 'Staten Island'         # done
# neigh = 'Bronx'               # done
# neigh = 'Queens'               # done
# neigh = 'Manhattan'           # done
# neigh = 'Brooklyn'    # will skip -- too big!!

days = 5 
count = 50
group = False  # we are running a neighbourhood_group, not a neighbourhood


if group:
    i_spec_list = i_spec_ngroup_list
else:
    i_spec_list = i_spec_nbhd_list

perf_dict = util.run_neigh_update_datetimes_multi_index_specs_ts(db_eng, group, neigh, days, all_indexes, i_spec_ngroup_list, count)
print('\nThe perf profile after running on neighborhood', neigh, 'is:')
# pprint.pp(sorted(perf_dict.items()))
pprint.pp(perf_dict)

perf_file = 'update_datetimes_query_v02.json'
query_name = 'update_datetimes_neigh_' + neigh
new_perf_summary = {}
new_perf_summary[query_name] = perf_dict
result = util.fetch_and_update_ts_perf_data_overwrite_for_query(perf_file, new_perf_summary)
print('\nContents of perf_file', perf_file, 'are now:')
pprint.pp(sorted(result.items()))
# Out:
# In neigh_updates routine, have set add_days to: True
#
# Now working on the i_specs: []
# Current set of indexes in effect is:
# {'listings': [], 'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)']}
# Will be running the query:
# UPDATE reviews r
# SET datetime = datetime + interval '5 days'
# FROM listings l
# WHERE l.id = r.listing_id
#   AND l.neighbourhood = 'New Springville'
# RETURNING 'done';
#
# Now invoking run_one_query
#
# In neigh_updates routine, have set add_days to: False
#
# Now working on the i_specs: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'listings': [],
#  'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)']}
# Will be running the query:
# UPDATE reviews r
# SET datetime = datetime - interval '5 days'
# FROM listings l
# WHERE l.id = r.listing_id
#   AND l.neighbourhood = 'New Springville'
# RETURNING 'done';
#
# Now invoking run_one_query
#
# In neigh_updates routine, have set add_days to: True
#
# Now working on the i_specs: [['neighbourhood_group', 'listings']]
# Current set of indexes in effect is:
# {'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)'],
#  'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)']}
# Will be running the query:
# UPDATE reviews r
# SET datetime = datetime + interval '5 days'
# FROM listings l
# WHERE l.id = r.listing_id
#   AND l.neighbourhood = 'New Springville'
# RETURNING 'done';
#
# Now invoking run_one_query
#
# In neigh_updates routine, have set add_days to: False
#
# Now working on the i_specs: [['datetime', 'reviews'], ['neighbourhood_group', 'listings']]
# Current set of indexes in effect is:
# {'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)'],
#  'reviews': ['CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)',
#              'CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)']}
# Will be running the query:
# UPDATE reviews r
# SET datetime = datetime - interval '5 days'
# FROM listings l
# WHERE l.id = r.listing_id
#   AND l.neighbourhood = 'New Springville'
# RETURNING 'done';
#
# Now invoking run_one_query
#
# The perf profile after running on neighborhood New Springville is:
# {'__': {'avg': 1.3212,
#         'min': 1.2904,
#         'max': 1.4782,
#         'std': 0.0304,
#         'exec_count': 50,
#         'timestamp': '2024-05-09-09:09:11'},
#  '__datetime_in_reviews__': {'avg': 1.3978,
#                              'min': 1.3046,
#                              'max': 1.8578,
#                              'std': 0.106,
#                              'exec_count': 50,
#                              'timestamp': '2024-05-09-09:10:22'},
#  '__neighbourhood_group_in_listings__': {'avg': 1.3406,
#                                          'min': 1.2841,
#                                          'max': 1.4015,
#                                          'std': 0.0213,
#                                          'exec_count': 50,
#                                          'timestamp': '2024-05-09-09:11:29'},
#  '__datetime_in_reviews__neighbourhood_group_in_listings__': {'avg': 1.3191,
#                                                               'min': 1.2694,
#                                                               'max': 1.447,
#                                                               'std': 0.0292,
#                                                               'exec_count': 50,
#                                                               'timestamp': '2024-05-09-09:12:36'}}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 46
#      44 new_perf_summary = {}
#      45 new_perf_summary[query_name] = perf_dict
# ---> 46 result = util.fetch_and_update_ts_perf_data_overwrite_for_query(perf_file, new_perf_summary)
#      47 print('\nContents of perf_file', perf_file, 'are now:')
#      48 pprint.pp(sorted(result.items()))
#
# AttributeError: module 'util' has no attribute 'fetch_and_update_ts_perf_data_overwrite_for_query'

# %%
q = util.query_neighbourhood_groups_listings_counts()

print(q)
print()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

pprint.pp(result.fetchall())
# Out:
# select count(*), neighbourhood_group
# from listings l, reviews r
# where l.id = r.listing_id
# group by neighbourhood_group
# order by count desc
#
# [(423109, 'Brooklyn'),
#  (341287, 'Manhattan'),
#  (173392, 'Queens'),
#  (35296, 'Bronx'),
#  (13726, 'Staten Island')]

# %%
q = util.query_neighbourhoods_listings_counts()

print(q)
print()

with db_eng.connect() as conn:
    result = conn.execute(sql_text(q))

pprint.pp(result.fetchall())
# Out:
# select count(*), neighbourhood, neighbourhood_group
# from listings l, reviews r
# where l.id = r.listing_id
# group by neighbourhood, neighbourhood_group
# order by count desc
#
# [(99705, 'Bedford-Stuyvesant', 'Brooklyn'),
#  (59240, 'Harlem', 'Manhattan'),
#  (52541, 'Williamsburg', 'Brooklyn'),
#  (35734, 'Crown Heights', 'Brooklyn'),
#  (33856, 'Bushwick', 'Brooklyn'),
#  (31521, "Hell's Kitchen", 'Manhattan'),
#  (30218, 'Midtown', 'Manhattan'),
#  (25166, 'East Village', 'Manhattan'),
#  (22276, 'Upper West Side', 'Manhattan'),
#  (20862, 'East Harlem', 'Manhattan'),
#  (20373, 'Astoria', 'Queens'),
#  (18856, 'Lower East Side', 'Manhattan'),
#  (18470, 'Chelsea', 'Manhattan'),
#  (17346, 'Upper East Side', 'Manhattan'),
#  (16426, 'East Flatbush', 'Brooklyn'),
#  (15913, 'Flushing', 'Queens'),
#  (13909, 'Park Slope', 'Brooklyn'),
#  (13526, 'East Elmhurst', 'Queens'),
#  (13491, 'Flatbush', 'Brooklyn'),
#  (12864, 'Greenpoint', 'Brooklyn'),
#  (12727, 'Clinton Hill', 'Brooklyn'),
#  (12560, 'Prospect-Lefferts Gardens', 'Brooklyn'),
#  (12329, 'Jamaica', 'Queens'),
#  (12213, 'Theater District', 'Manhattan'),
#  (11998, 'Washington Heights', 'Manhattan'),
#  (11841, 'Financial District', 'Manhattan'),
#  (11050, 'Canarsie', 'Brooklyn'),
#  (10859, 'Long Island City', 'Queens'),
#  (10851, 'East New York', 'Brooklyn'),
#  (9433, 'Sunset Park', 'Brooklyn'),
#  (9380, 'Fort Greene', 'Brooklyn'),
#  (8231, 'West Village', 'Manhattan'),
#  (7884, 'Chinatown', 'Manhattan'),
#  (7467, 'SoHo', 'Manhattan'),
#  (7247, 'Ditmars Steinway', 'Queens'),
#  (7156, 'Prospect Heights', 'Brooklyn'),
#  (7006, 'Sunnyside', 'Queens'),
#  (6570, 'Ridgewood', 'Queens'),
#  (6476, 'Elmhurst', 'Queens'),
#  (6417, 'Jackson Heights', 'Queens'),
#  (6031, 'South Slope', 'Brooklyn'),
#  (5908, 'Cypress Hills', 'Brooklyn'),
#  (5756, 'Gowanus', 'Brooklyn'),
#  (5453, 'Carroll Gardens', 'Brooklyn'),
#  (5385, 'Springfield Gardens', 'Queens'),
#  (5354, 'Woodside', 'Queens'),
#  (5241, 'Gramercy', 'Manhattan'),
#  (5098, 'St. Albans', 'Queens'),
#  (5056, 'Kips Bay', 'Manhattan'),
#  (3984, 'Brownsville', 'Brooklyn'),
#  (3856, 'Inwood', 'Manhattan'),
#  (3839, 'Boerum Hill', 'Brooklyn'),
#  (3836, 'Murray Hill', 'Manhattan'),
#  (3714, 'Sheepshead Bay', 'Brooklyn'),
#  (3532, 'South Ozone Park', 'Queens'),
#  (3500, 'Windsor Terrace', 'Brooklyn'),
#  (3455, 'Rosedale', 'Queens'),
#  (3406, 'Nolita', 'Manhattan'),
#  (3344, 'Rockaway Beach', 'Queens'),
#  (3217, 'Maspeth', 'Queens'),
#  (3105, 'Cobble Hill', 'Brooklyn'),
#  (2992, 'Queens Village', 'Queens'),
#  (2989, 'Arverne', 'Queens'),
#  (2912, 'Richmond Hill', 'Queens'),
#  (2879, 'Bay Ridge', 'Brooklyn'),
#  (2822, 'Concourse', 'Bronx'),
#  (2799, 'Forest Hills', 'Queens'),
#  (2751, 'Mott Haven', 'Bronx'),
#  (2744, 'Greenwich Village', 'Manhattan'),
#  (2740, 'Kensington', 'Brooklyn'),
#  (2720, 'Flatlands', 'Brooklyn'),
#  (2503, 'Woodhaven', 'Queens'),
#  (2469, 'Allerton', 'Bronx'),
#  (2450, 'St. George', 'Staten Island'),
#  (2272, 'Red Hook', 'Brooklyn'),
#  (2214, 'Flatiron District', 'Manhattan'),
#  (2190, 'Corona', 'Queens'),
#  (2122, 'Laurelton', 'Queens'),
#  (2108, 'Morningside Heights', 'Manhattan'),
#  (2086, 'Gravesend', 'Brooklyn'),
#  (2064, 'Little Italy', 'Manhattan'),
#  (2053, 'Midwood', 'Brooklyn'),
#  (2027, 'Borough Park', 'Brooklyn'),
#  (1951, 'Wakefield', 'Bronx'),
#  (1949, 'Brooklyn Heights', 'Brooklyn'),
#  (1908, 'DUMBO', 'Brooklyn'),
#  (1871, 'Tribeca', 'Manhattan'),
#  (1831, 'Pelham Gardens', 'Bronx'),
#  (1718, 'Downtown Brooklyn', 'Brooklyn'),
#  (1703, 'Ozone Park', 'Queens'),
#  (1627, 'Bensonhurst', 'Brooklyn'),
#  (1604, 'Tompkinsville', 'Staten Island'),
#  (1601, 'Williamsbridge', 'Bronx'),
#  (1527, 'Bayside', 'Queens'),
#  (1477, 'Longwood', 'Bronx'),
#  (1433, 'Glendale', 'Queens'),
#  (1411, 'Briarwood', 'Queens'),
#  (1363, 'Rego Park', 'Queens'),
#  (1205, 'Fresh Meadows', 'Queens'),
#  (1187, 'Two Bridges', 'Manhattan'),
#  (1166, 'College Point', 'Queens'),
#  (1126, 'Roosevelt Island', 'Manhattan'),
#  (1121, 'Baychester', 'Bronx'),
#  (1098, 'Schuylerville', 'Bronx'),
#  (1089, 'Cambria Heights', 'Queens'),
#  (1060, 'Howard Beach', 'Queens'),
#  (1033, 'Port Morris', 'Bronx'),
#  (1033, 'Concourse Village', 'Bronx'),
#  (1000, 'Fort Hamilton', 'Brooklyn'),
#  (979, 'Kingsbridge', 'Bronx'),
#  (977, 'Clason Point', 'Bronx'),
#  (976, 'Brighton Beach', 'Brooklyn'),
#  (971, 'Battery Park City', 'Manhattan'),
#  (961, 'Mount Hope', 'Bronx'),
#  (951, 'NoHo', 'Manhattan'),
#  (869, 'Kew Gardens Hills', 'Queens'),
#  (868, 'Kew Gardens', 'Queens'),
#  (822, 'Stapleton', 'Staten Island'),
#  (816, 'Mariners Harbor', 'Staten Island'),
#  (779, 'Columbia St', 'Brooklyn'),
#  (776, 'Throgs Neck', 'Bronx'),
#  (764, 'New Brighton', 'Staten Island'),
#  (759, 'Morris Park', 'Bronx'),
#  (726, 'Whitestone', 'Queens'),
#  (700, 'Fordham', 'Bronx'),
#  (688, 'Melrose', 'Bronx'),
#  (686, 'Norwood', 'Bronx'),
#  (683, 'Far Rockaway', 'Queens'),
#  (660, 'City Island', 'Bronx'),
#  (654, 'Claremont Village', 'Bronx'),
#  (654, 'Bath Beach', 'Brooklyn'),
#  (645, 'Belmont', 'Bronx'),
#  (612, 'Middle Village', 'Queens'),
#  (593, 'Bronxdale', 'Bronx'),
#  (571, 'Bergen Beach', 'Brooklyn'),
#  (570, 'Vinegar Hill', 'Brooklyn'),
#  (564, 'Huguenot', 'Staten Island'),
#  (558, 'West Brighton', 'Staten Island'),
#  (548, 'New Dorp Beach', 'Staten Island'),
#  (534, 'Unionport', 'Bronx'),
#  (533, 'Clifton', 'Staten Island'),
#  (526, 'Jamaica Estates', 'Queens'),
#  (505, 'Parkchester', 'Bronx'),
#  (498, 'Edenwald', 'Bronx'),
#  (483, 'Coney Island', 'Brooklyn'),
#  (463, 'Hollis', 'Queens'),
#  (462, 'Bellerose', 'Queens'),
#  (451, 'Shore Acres', 'Staten Island'),
#  (450, 'Pelham Bay', 'Bronx'),
#  (435, 'Arrochar', 'Staten Island'),
#  (424, 'Marble Hill', 'Manhattan'),
#  (418, 'Olinville', 'Bronx'),
#  (389, 'Manhattan Beach', 'Brooklyn'),
#  (384, 'Hunts Point', 'Bronx'),
#  (382, 'Grymes Hill', 'Staten Island'),
#  (369, 'Morrisania', 'Bronx'),
#  (367, 'Van Nest', 'Bronx'),
#  (366, 'University Heights', 'Bronx'),
#  (355, 'Midland Beach', 'Staten Island'),
#  (352, 'Eastchester', 'Bronx'),
#  (348, 'Edgemere', 'Queens'),
#  (335, 'Civic Center', 'Manhattan'),
#  (328, 'Rosebank', 'Staten Island'),
#  (327, 'Randall Manor', 'Staten Island'),
#  (314, 'Soundview', 'Bronx'),
#  (308, 'Stuyvesant Town', 'Manhattan'),
#  (302, 'Mount Eden', 'Bronx'),
#  (285, 'Bayswater', 'Queens'),
#  (254, 'Morris Heights', 'Bronx'),
#  (249, 'Tremont', 'Bronx'),
#  (241, 'Port Richmond', 'Staten Island'),
#  (237, 'Highbridge', 'Bronx'),
#  (236, 'Dyker Heights', 'Brooklyn'),
#  (226, 'Westchester Square', 'Bronx'),
#  (226, 'Riverdale', 'Bronx'),
#  (221, 'Belle Harbor', 'Queens'),
#  (215, 'Tottenville', 'Staten Island'),
#  (207, 'Concord', 'Staten Island'),
#  (206, 'Richmondtown', 'Staten Island'),
#  (204, 'Mill Basin', 'Brooklyn'),
#  (198, 'Bay Terrace', 'Queens'),
#  (197, 'Douglaston', 'Queens'),
#  (188, 'South Beach', 'Staten Island'),
#  (185, 'Sea Gate', 'Brooklyn'),
#  (179, 'Castleton Corners', 'Staten Island'),
#  (178, 'North Riverdale', 'Bronx'),
#  (176, 'Fieldston', 'Bronx'),
#  (167, 'Great Kills', 'Staten Island'),
#  (160, 'Spuyten Duyvil', 'Bronx'),
#  (160, 'Jamaica Hills', 'Queens'),
#  (160, 'Graniteville', 'Staten Island'),
#  (153, 'Silver Lake', 'Staten Island'),
#  (150, 'Castle Hill', 'Bronx'),
#  (143, 'Grant City', 'Staten Island'),
#  (129, 'Co-op City', 'Bronx'),
#  (123, 'Dongan Hills', 'Staten Island'),
#  (115, 'Breezy Point', 'Queens'),
#  (111, 'Oakwood', 'Staten Island'),
#  (106, 'Gerritsen Beach', 'Brooklyn'),
#  (104, 'New Springville', 'Staten Island'),
#  (90, "Bull's Head", 'Staten Island'),
#  (89, 'Emerson Hill', 'Staten Island'),
#  (74, 'East Morrisania', 'Bronx'),
#  (67, 'Woodlawn', 'Bronx'),
#  (66, "Prince's Bay", 'Staten Island'),
#  (61, 'Eltingville', 'Staten Island'),
#  (58, 'Arden Heights', 'Staten Island'),
#  (57, 'Lighthouse Hill', 'Staten Island'),
#  (54, 'Willowbrook', 'Staten Island'),
#  (46, 'Holliswood', 'Queens'),
#  (39, 'Howland Hook', 'Staten Island'),
#  (37, 'Todt Hill', 'Staten Island'),
#  (32, 'Westerleigh', 'Staten Island'),
#  (29, 'Neponsit', 'Queens'),
#  (26, 'Country Club', 'Bronx'),
#  (20, 'West Farms', 'Bronx'),
#  (19, 'Little Neck', 'Queens'),
#  (6, 'Woodrow', 'Staten Island'),
#  (4, 'Navy Yard', 'Brooklyn'),
#  (1, 'Rossville', 'Staten Island'),
#  (1, 'Chelsea, Staten Island', 'Staten Island'),
#  (1, 'Bay Terrace, Staten Island', 'Staten Island')]

# %%
# neigh = 'Bedford-Stuyvesant'      # 99,705  about 20 vs 17.5
neigh = 'Long Island City'      # 10,895   about 2.58 vs 2.19
# neigh = 'Fort Hamilton'         # 1,000           .72 vs .70
# neigh = 'New Springvile'        #  104
days = 5
neg_days = -5

# plus_5 = util.build_update_ngroup_datetime_in_reviews(db_eng, neigh, days)
plus_5 = util.build_update_neigh_datetime_in_reviews(db_eng, neigh, days)
print(plus_5)
print()

# minus_5 = util.build_update_ngroup_datetime_in_reviews(db_eng, neigh, neg_days)
minus_5 = util.build_update_neigh_datetime_in_reviews(db_eng, neigh, neg_days)
print(minus_5)
print()

i_spec_neigh = ['neighbourhood', 'listings']
util.add_drop_index(db_eng, 'add', i_spec_neigh)

i_spec = ['datetime','reviews']

count = 50

util.add_drop_index(db_eng, 'add', i_spec)
print('entering run_one_query for plus_5')
plus_profile, time_listing = util.run_one_query(db_eng, plus_5, count)
print('\nPlus_profile is:')
pprint.pp(plus_profile)

util.add_drop_index(db_eng, 'drop', i_spec)
print('entering run_one_query for minus_5')
minus_profile, time_listing = util.run_one_query(db_eng, minus_5, count)
print('\nMinus_profile is:')
pprint.pp(minus_profile)

# %%
ngroup = 'Brooklyn'
year = 2023
sword = 'awesome'

vec = [ngroup, year, sword]
ts_index = True

q = util.build_ngroup_year_datetime_sword(vec, ts_index)
print(q)
# Out:
# SELECT count(*)
# FROM listings l, reviews r
# WHERE l.id = r.listing_id
#   AND l.neighbourhood_group = 'Brooklyn'
#   AND r.datetime >= '2023-01-01' AND r.datetime <= '2023-12-31'
#   AND comments_tsv @@ to_tsquery('awesome');

# %%
ngroup = 'Brooklyn'
year = 2016
sword = 'awesome'

specs = [['datetime','reviews'], ['neighbourhood_group','listings'], ['id','listings']]

count = 3

q_vec = [ngroup, year, sword]

query_vec = util.q_vec_name(q_vec)

print(query_vec)

result = util.run_ngroup_year_sword_and_multi_index_specs_with_ts_ngroup(db_eng, q_vec, specs, count)

print('\n\nThe result of the run on', query_vec, 'with indexes', str(specs), 'is:')
pprint.pp(sorted(result.items()))
# Out:
# q_Brooklyn_2016_awesome
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['datetime', 'reviews']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['neighbourhood_group', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood_group', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['datetime', 'reviews'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['neighbourhood_group', 'listings'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['datetime', 'reviews'], ['neighbourhood_group', 'listings'], ['id', 'listings']]
# Current set of indexes in effect is:
# {'reviews': ['CREATE INDEX comments_tsv_in_reviews ON new_york_city.reviews USING gin (comments_tsv)',
#              "CREATE INDEX comments_in_reviews ON new_york_city.reviews USING gin (to_tsvector('simple'::regconfig, (comments)::text))",
#              'CREATE INDEX datetime_in_reviews ON new_york_city.reviews USING btree (datetime)'],
#  'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
#
# The result of the run on q_Brooklyn_2016_awesome with indexes [['datetime', 'reviews'], ['neighbourhood_group', 'listings'], ['id', 'listings']] is:
# [('__',
#   {'avg': 0.3278,
#    'min': 0.3146,
#    'max': 0.3398,
#    'std': 0.0103,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:30'}),
#  ('__comments_tsv_in_reviews__',
#   {'avg': 0.1198,
#    'min': 0.0985,
#    'max': 0.1572,
#    'std': 0.0265,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:29'}),
#  ('__datetime_in_reviews__',
#   {'avg': 0.3266,
#    'min': 0.3091,
#    'max': 0.3372,
#    'std': 0.0125,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:32'}),
#  ('__datetime_in_reviews__comments_tsv_in_reviews__',
#   {'avg': 0.0965,
#    'min': 0.0931,
#    'max': 0.1012,
#    'std': 0.0034,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:31'}),
#  ('__datetime_in_reviews__id_in_listings__',
#   {'avg': 0.3307,
#    'min': 0.3288,
#    'max': 0.3316,
#    'std': 0.0013,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:37'}),
#  ('__datetime_in_reviews__id_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.1016,
#    'min': 0.1011,
#    'max': 0.1025,
#    'std': 0.0006,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:36'}),
#  ('__datetime_in_reviews__neighbourhood_group_in_listings__',
#   {'avg': 0.3333,
#    'min': 0.3188,
#    'max': 0.3409,
#    'std': 0.0103,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:34'}),
#  ('__datetime_in_reviews__neighbourhood_group_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.0974,
#    'min': 0.0932,
#    'max': 0.1025,
#    'std': 0.0039,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:33'}),
#  ('__datetime_in_reviews__neighbourhood_group_in_listings__id_in_listings__',
#   {'avg': 0.319,
#    'min': 0.3149,
#    'max': 0.324,
#    'std': 0.0038,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:39'}),
#  ('__datetime_in_reviews__neighbourhood_group_in_listings__id_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.098,
#    'min': 0.0943,
#    'max': 0.1029,
#    'std': 0.0037,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:38'}),
#  ('__id_in_listings__',
#   {'avg': 0.326,
#    'min': 0.3147,
#    'max': 0.3324,
#    'std': 0.008,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:35'}),
#  ('__id_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.0991,
#    'min': 0.0957,
#    'max': 0.1028,
#    'std': 0.0029,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:35'}),
#  ('__neighbourhood_group_in_listings__',
#   {'avg': 0.3371,
#    'min': 0.3325,
#    'max': 0.3424,
#    'std': 0.0041,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:33'}),
#  ('__neighbourhood_group_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.0957,
#    'min': 0.0933,
#    'max': 0.0971,
#    'std': 0.0017,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:32'}),
#  ('__neighbourhood_group_in_listings__id_in_listings__',
#   {'avg': 0.3299,
#    'min': 0.3241,
#    'max': 0.3362,
#    'std': 0.0049,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:38'}),
#  ('__neighbourhood_group_in_listings__id_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.102,
#    'min': 0.0983,
#    'max': 0.1066,
#    'std': 0.0035,
#    'exec_count': 3,
#    'timestamp': '2024-05-08-09:55:37'})]

# %%
prange = '000s'
year = 2023
word = 'awesome'

vec = [prange, year, word]
ts_index = True

q1 = util.build_price_range_year_word(vec, ts_index)
print(q1)
# Out:
# SELECT *
# FROM listings l, reviews r
# WHERE l.id = r.listing_id
#   AND l.price >= 0 AND l.price < 100
#   AND r.datetime >= '2023-01-01' AND r.datetime <= '2023-12-31'
#   AND comments_tsv @@ to_tsquery('awesome');

# %%
all_indexes = [['date','reviews'], ['id','listings'], ['price','listings'], ['comments_tsv', 'reviews', 'gin']]
specs = [['date','reviews'], ['id','listings'], ['price','listings']]
specs = [['date','reviews'], ['price','listings']]

print(util.build_index_description_key_no_ts_index(specs))
print()
print(util.build_index_description_key_with_ts_index(specs))
# Out:
# __date_in_reviews__price_in_listings__
#
# __date_in_reviews__price_in_listings__comments_tsv_in_reviews__

# %%
prange = '300s'
year = 2016
word = 'awesome'

# note: the index comments_tsv_on_reviews will get special treatment, so not included
#       in the lists here
all_indexes = [['datetime','reviews'], ['price','listings'], ['id','listings'],['date','reviews'],['comments_in_reviews']]
specs = [['datetime','reviews'], ['price','listings'], ['id','listings']]
specs = [['datetime','reviews']] # not much diff to inlude or not
specs = [['price','listings']]   # not much diff to inlude or not
specs = [['id','listings']]

count = 50

q_vec = [prange, year, word]

query_vec = util.q_vec_name(q_vec)

print(query_vec)

result = util.run_prange_year_sword_and_multi_index_specs_with_ts(db_eng, q_vec, specs, count)

print('\n\nThe result of the run on', query_vec, 'with indexes', str(specs), 'is:')
pprint.pp(sorted(result.items()))
# Out:
# q_300s_2016_awesome
#
# Now working on the i_spec: []
# Current set of indexes in effect is:
# {'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
# Now working on the i_spec: [['id', 'listings']]
# Current set of indexes in effect is:
# {'listings': ['CREATE INDEX neighbourhood_group_in_listings ON new_york_city.listings USING btree (neighbourhood_group)',
#               'CREATE INDEX id_in_listings ON new_york_city.listings USING btree (id)',
#               'CREATE INDEX price_in_listings ON new_york_city.listings USING btree (price)']}
#
# Now invoking run_one_query with ts index
#
# Now invoking run_one_query no ts index
#
#
# The result of the run on q_300s_2016_awesome with indexes [['id', 'listings']] is:
# [('__',
#   {'avg': 0.2172,
#    'min': 0.2063,
#    'max': 0.2375,
#    'std': 0.0073,
#    'exec_count': 50,
#    'timestamp': '2024-05-08-10:32:42'}),
#  ('__comments_tsv_in_reviews__',
#   {'avg': 0.0151,
#    'min': 0.0139,
#    'max': 0.0212,
#    'std': 0.0013,
#    'exec_count': 50,
#    'timestamp': '2024-05-08-10:32:31'}),
#  ('__id_in_listings__',
#   {'avg': 0.2233,
#    'min': 0.2076,
#    'max': 0.2343,
#    'std': 0.0061,
#    'exec_count': 50,
#    'timestamp': '2024-05-08-10:32:54'}),
#  ('__id_in_listings__comments_tsv_in_reviews__',
#   {'avg': 0.0145,
#    'min': 0.0135,
#    'max': 0.0157,
#    'std': 0.0005,
#    'exec_count': 50,
#    'timestamp': '2024-05-08-10:32:42'})]
